# %% [markdown]
# ### Restart and run all

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
from datetime import date, timedelta
import calendar

engine = create_engine("sqlite:///c:\\ruby\\expense\\db\\development.sqlite3")
connection = engine.connect()

format_dict = {'amount':'{:,}','y_amt':'{:,}','yoy_gain':'{:,}',
               'q_amt_c':'{:,}','q_amt_p':'{:,}',
               'aq_amt':'{:,}','ay_amt':'{:,}','acc_gain':'{:,}',
               'latest_amt':'{:,}','previous_amt':'{:,}','inc_amt':'{:,}',
               'latest_amt_q':'{:,}','previous_amt_q':'{:,}','inc_amt_q':'{:,}',
               'latest_amt_y':'{:,}','previous_amt_y':'{:,}','inc_amt_y':'{:,}',
               'inc_pct':'{:.2f}','inc_pct_q':'{:.2f}','inc_pct_y':'{:.2f}'}
year = 2022
today = date.today()
today
# Out:
# datetime.date(2022, 10, 7)

# %%
sql = """
SELECT date, amount, C.name AS item, G.name AS kind, strftime("%m", date) as Month 
FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE strftime('%Y', date) = '2022'
"""
#sql = sql % year
print(sql)
# Out:
# SELECT date, amount, C.name AS item, G.name AS kind, strftime("%m", date) as Month
# FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE strftime('%Y', date) = '2022'

# %%
df_t = pd.read_sql(sql, connection)
df_t.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_64eff_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >amount</th>
#       <th class="col_heading level0 col2" >item</th>
#       <th class="col_heading level0 col3" >kind</th>
#       <th class="col_heading level0 col4" >Month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64eff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64eff_row0_col0" class="data row0 col0" >2022-01-02</td>
#       <td id="T_64eff_row0_col1" class="data row0 col1" >2,430</td>
#       <td id="T_64eff_row0_col2" class="data row0 col2" >Food</td>
#       <td id="T_64eff_row0_col3" class="data row0 col3" >Food</td>
#       <td id="T_64eff_row0_col4" class="data row0 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64eff_row1_col0" class="data row1 col0" >2022-01-06</td>
#       <td id="T_64eff_row1_col1" class="data row1 col1" >780</td>
#       <td id="T_64eff_row1_col2" class="data row1 col2" >Pets</td>
#       <td id="T_64eff_row1_col3" class="data row1 col3" >Pets</td>
#       <td id="T_64eff_row1_col4" class="data row1 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64eff_row2_col0" class="data row2 col0" >2022-01-07</td>
#       <td id="T_64eff_row2_col1" class="data row2 col1" >1,330</td>
#       <td id="T_64eff_row2_col2" class="data row2 col2" >Medicine</td>
#       <td id="T_64eff_row2_col3" class="data row2 col3" >Medicine</td>
#       <td id="T_64eff_row2_col4" class="data row2 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64eff_row3_col0" class="data row3 col0" >2022-01-07</td>
#       <td id="T_64eff_row3_col1" class="data row3 col1" >200</td>
#       <td id="T_64eff_row3_col2" class="data row3 col2" >Transportation</td>
#       <td id="T_64eff_row3_col3" class="data row3 col3" >Transportation</td>
#       <td id="T_64eff_row3_col4" class="data row3 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64eff_row4_col0" class="data row4 col0" >2022-01-08</td>
#       <td id="T_64eff_row4_col1" class="data row4 col1" >2,020</td>
#       <td id="T_64eff_row4_col2" class="data row4 col2" >Parent</td>
#       <td id="T_64eff_row4_col3" class="data row4 col3" >Parent</td>
#       <td id="T_64eff_row4_col4" class="data row4 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64eff_row5_col0" class="data row5 col0" >2022-01-08</td>
#       <td id="T_64eff_row5_col1" class="data row5 col1" >4,120</td>
#       <td id="T_64eff_row5_col2" class="data row5 col2" >Mother</td>
#       <td id="T_64eff_row5_col3" class="data row5 col3" >Parent</td>
#       <td id="T_64eff_row5_col4" class="data row5 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64eff_row6_col0" class="data row6 col0" >2022-01-08</td>
#       <td id="T_64eff_row6_col1" class="data row6 col1" >150</td>
#       <td id="T_64eff_row6_col2" class="data row6 col2" >Transportation</td>
#       <td id="T_64eff_row6_col3" class="data row6 col3" >Transportation</td>
#       <td id="T_64eff_row6_col4" class="data row6 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64eff_row7_col0" class="data row7 col0" >2022-01-09</td>
#       <td id="T_64eff_row7_col1" class="data row7 col1" >640</td>
#       <td id="T_64eff_row7_col2" class="data row7 col2" >Food</td>
#       <td id="T_64eff_row7_col3" class="data row7 col3" >Food</td>
#       <td id="T_64eff_row7_col4" class="data row7 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_64eff_row8_col0" class="data row8 col0" >2022-01-10</td>
#       <td id="T_64eff_row8_col1" class="data row8 col1" >180</td>
#       <td id="T_64eff_row8_col2" class="data row8 col2" >Food</td>
#       <td id="T_64eff_row8_col3" class="data row8 col3" >Food</td>
#       <td id="T_64eff_row8_col4" class="data row8 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_64eff_row9_col0" class="data row9 col0" >2022-01-10</td>
#       <td id="T_64eff_row9_col1" class="data row9 col1" >7,340</td>
#       <td id="T_64eff_row9_col2" class="data row9 col2" >Pets</td>
#       <td id="T_64eff_row9_col3" class="data row9 col3" >Pets</td>
#       <td id="T_64eff_row9_col4" class="data row9 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_64eff_row10_col0" class="data row10 col0" >2022-01-11</td>
#       <td id="T_64eff_row10_col1" class="data row10 col1" >3,790</td>
#       <td id="T_64eff_row10_col2" class="data row10 col2" >Pets</td>
#       <td id="T_64eff_row10_col3" class="data row10 col3" >Pets</td>
#       <td id="T_64eff_row10_col4" class="data row10 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_64eff_row11_col0" class="data row11 col0" >2022-01-12</td>
#       <td id="T_64eff_row11_col1" class="data row11 col1" >410</td>
#       <td id="T_64eff_row11_col2" class="data row11 col2" >Food</td>
#       <td id="T_64eff_row11_col3" class="data row11 col3" >Food</td>
#       <td id="T_64eff_row11_col4" class="data row11 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_64eff_row12_col0" class="data row12 col0" >2022-01-12</td>
#       <td id="T_64eff_row12_col1" class="data row12 col1" >410</td>
#       <td id="T_64eff_row12_col2" class="data row12 col2" >Food</td>
#       <td id="T_64eff_row12_col3" class="data row12 col3" >Food</td>
#       <td id="T_64eff_row12_col4" class="data row12 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_64eff_row13_col0" class="data row13 col0" >2022-01-12</td>
#       <td id="T_64eff_row13_col1" class="data row13 col1" >1,700</td>
#       <td id="T_64eff_row13_col2" class="data row13 col2" >Pets</td>
#       <td id="T_64eff_row13_col3" class="data row13 col3" >Pets</td>
#       <td id="T_64eff_row13_col4" class="data row13 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_64eff_row14_col0" class="data row14 col0" >2022-01-14</td>
#       <td id="T_64eff_row14_col1" class="data row14 col1" >330</td>
#       <td id="T_64eff_row14_col2" class="data row14 col2" >Books & Software</td>
#       <td id="T_64eff_row14_col3" class="data row14 col3" >Edutainment</td>
#       <td id="T_64eff_row14_col4" class="data row14 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_64eff_row15_col0" class="data row15 col0" >2022-01-16</td>
#       <td id="T_64eff_row15_col1" class="data row15 col1" >4,450</td>
#       <td id="T_64eff_row15_col2" class="data row15 col2" >Yearly Dropbox</td>
#       <td id="T_64eff_row15_col3" class="data row15 col3" >Edutainment</td>
#       <td id="T_64eff_row15_col4" class="data row15 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_64eff_row16_col0" class="data row16 col0" >2022-01-17</td>
#       <td id="T_64eff_row16_col1" class="data row16 col1" >700</td>
#       <td id="T_64eff_row16_col2" class="data row16 col2" >Pets</td>
#       <td id="T_64eff_row16_col3" class="data row16 col3" >Pets</td>
#       <td id="T_64eff_row16_col4" class="data row16 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_64eff_level0_ro

# %%
grouped = df_t.groupby("item")
grouped.sum().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f3fae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >item</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3fae_level0_row0" class="row_heading level0 row0" >Apple</th>
#       <td id="T_f3fae_row0_col0" class="data row0 col0" >1,520</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row1" class="row_heading level0 row1" >Books & Software</th>
#       <td id="T_f3fae_row1_col0" class="data row1 col0" >4,880</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row2" class="row_heading level0 row2" >CCF</th>
#       <td id="T_f3fae_row2_col0" class="data row2 col0" >3,000</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row3" class="row_heading level0 row3" >Food</th>
#       <td id="T_f3fae_row3_col0" class="data row3 col0" >37,945</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row4" class="row_heading level0 row4" >Fuel</th>
#       <td id="T_f3fae_row4_col0" class="data row4 col0" >13,970</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row5" class="row_heading level0 row5" >Funeral</th>
#       <td id="T_f3fae_row5_col0" class="data row5 col0" >45,000</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row6" class="row_heading level0 row6" >Google</th>
#       <td id="T_f3fae_row6_col0" class="data row6 col0" >1,530</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row7" class="row_heading level0 row7" >Internet Home</th>
#       <td id="T_f3fae_row7_col0" class="data row7 col0" >5,760</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row8" class="row_heading level0 row8" >Medicine</th>
#       <td id="T_f3fae_row8_col0" class="data row8 col0" >13,800</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row9" class="row_heading level0 row9" >Merit Making</th>
#       <td id="T_f3fae_row9_col0" class="data row9 col0" >24,100</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row10" class="row_heading level0 row10" >Miscellaneous</th>
#       <td id="T_f3fae_row10_col0" class="data row10 col0" >400</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row11" class="row_heading level0 row11" >Monthly Prime</th>
#       <td id="T_f3fae_row11_col0" class="data row11 col0" >950</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row12" class="row_heading level0 row12" >Mother</th>
#       <td id="T_f3fae_row12_col0" class="data row12 col0" >55,110</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row13" class="row_heading level0 row13" >Netflix</th>
#       <td id="T_f3fae_row13_col0" class="data row13 col0" >1,680</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row14" class="row_heading level0 row14" >Packt</th>
#       <td id="T_f3fae_row14_col0" class="data row14 col0" >3,060</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row15" class="row_heading level0 row15" >Parent</th>
#       <td id="T_f3fae_row15_col0" class="data row15 col0" >97,020</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row16" class="row_heading level0 row16" >Patreon</th>
#       <td id="T_f3fae_row16_col0" class="data row16 col0" >560</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row17" class="row_heading level0 row17" >Personal Care</th>
#       <td id="T_f3fae_row17_col0" class="data row17 col0" >3,810</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row18" class="row_heading level0 row18" >Pets</th>
#       <td id="T_f3fae_row18_col0" class="data row18 col0" >100,150</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row19" class="row_heading level0 row19" >Plum</th>
#       <td id="T_f3fae_row19_col0" class="data row19 col0" >24,400</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row20" class="row_heading level0 row20" >Shelter</th>
#       <td id="T_f3fae_row20_col0" class="data row20 col0" >43,200</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row21" class="row_heading level0 row21" >Telephone Dtac</th>
#       <td id="T_f3fae_row21_col0" class="data row21 col0" >2,880</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row22" class="row_heading level0 row22" >Transportation</th>
#       <td id="T_f3fae_row22_col0" class="data row22 col0" >990</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row23" class="row_heading level0 row23" >True Visions</th>
#       <td id="T_f3fae_row23_col0" class="data row23 col0" >22,800</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row24" class="row_heading level0 row24" >Vehicle</th>
#       <td id="T_f3fae_row24_col0" class="data row24 col0" >520</td>
#     </tr>
#     <tr>
#       <th id="T_f3fae_level0_row25" class="row_heading level0 row25" >Yearly Dropbox</th>
#       <td id="T_f3fae_row25_col0" class="data row25 col0" >4,450</td>
#     </tr>
#   </tbody>
# </table>

# %%
grouped = df_t.groupby("kind")
grouped.sum().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3328d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >kind</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3328d_level0_row0" class="row_heading level0 row0" >Apparel</th>
#       <td id="T_3328d_row0_col0" class="data row0 col0" >3,810</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row1" class="row_heading level0 row1" >Communication</th>
#       <td id="T_3328d_row1_col0" class="data row1 col0" >31,440</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row2" class="row_heading level0 row2" >Edutainment</th>
#       <td id="T_3328d_row2_col0" class="data row2 col0" >17,680</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row3" class="row_heading level0 row3" >Food</th>
#       <td id="T_3328d_row3_col0" class="data row3 col0" >37,945</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row4" class="row_heading level0 row4" >Luxury</th>
#       <td id="T_3328d_row4_col0" class="data row4 col0" >3,000</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row5" class="row_heading level0 row5" >Medicine</th>
#       <td id="T_3328d_row5_col0" class="data row5 col0" >13,800</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row6" class="row_heading level0 row6" >Movies</th>
#       <td id="T_3328d_row6_col0" class="data row6 col0" >950</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row7" class="row_heading level0 row7" >Others</th>
#       <td id="T_3328d_row7_col0" class="data row7 col0" >69,500</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row8" class="row_heading level0 row8" >Parent</th>
#       <td id="T_3328d_row8_col0" class="data row8 col0" >152,130</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row9" class="row_heading level0 row9" >Pets</th>
#       <td id="T_3328d_row9_col0" class="data row9 col0" >100,150</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row10" class="row_heading level0 row10" >Shelter</th>
#       <td id="T_3328d_row10_col0" class="data row10 col0" >67,600</td>
#     </tr>
#     <tr>
#       <th id="T_3328d_level0_row11" class="row_heading level0 row11" >Transportation</th>
#       <td id="T_3328d_row11_col0" class="data row11 col0" >15,480</td>
#     </tr>
#   </tbody>
# </table>

# %%
monthly = df_t.groupby("Month")
monthly.sum().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_70c06_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Month</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70c06_level0_row0" class="row_heading level0 row0" >01</th>
#       <td id="T_70c06_row0_col0" class="data row0 col0" >62,710</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row1" class="row_heading level0 row1" >02</th>
#       <td id="T_70c06_row1_col0" class="data row1 col0" >27,160</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row2" class="row_heading level0 row2" >03</th>
#       <td id="T_70c06_row2_col0" class="data row2 col0" >97,220</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row3" class="row_heading level0 row3" >04</th>
#       <td id="T_70c06_row3_col0" class="data row3 col0" >71,150</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row4" class="row_heading level0 row4" >05</th>
#       <td id="T_70c06_row4_col0" class="data row4 col0" >56,640</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row5" class="row_heading level0 row5" >06</th>
#       <td id="T_70c06_row5_col0" class="data row5 col0" >72,560</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row6" class="row_heading level0 row6" >07</th>
#       <td id="T_70c06_row6_col0" class="data row6 col0" >26,960</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row7" class="row_heading level0 row7" >08</th>
#       <td id="T_70c06_row7_col0" class="data row7 col0" >53,940</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row8" class="row_heading level0 row8" >09</th>
#       <td id="T_70c06_row8_col0" class="data row8 col0" >35,345</td>
#     </tr>
#     <tr>
#       <th id="T_70c06_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_70c06_row9_col0" class="data row9 col0" >9,800</td>
#     </tr>
#   </tbody>
# </table>

# %%
expense = grouped.amount.sum()
sum(expense)
# Out:
# 513485
