# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/BBB_development')
conbb = engine.connect()
    
data_path = '../data/'
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Inquiry

# %%
sql = '''
SELECT title, code, name, views
FROM songs
JOIN artists ON artist_id = artists.id
WHERE code <> '' 
AND views > 2999999999
ORDER BY views DESC
'''
songs = pd.read_sql(sql,conbb)
songs
# Out:
#                 title         code                                name  \
# 0          Baby Shark  XqZsoesa55w                            Pinkfong
# 1        Shape of You  JGwWNGJdvx8                          Ed Sheeran
# 2       See You Again  RgKAFK5djSk  Wiz Khalifa featuring Charlie Puth
# 3         Uptown Funk  OPf0YbXqDm0    Mark Ronson featuring Bruno Mars
# 4       Gangnam Style  9bZkp7q19f0                                 Psy
# 5               Sugar  09R8_2nJtjg                            Maroon 5
# 6                Roar  CevxZvSJLk8                          Katy Perry
# 7      Counting Stars  hT_nvWreIhg                         OneRepublic
# 8               Sorry  fRh_vgS2dFE                       Justin Bieber
# 9   Thinking Out Loud  lp-EO5I60KA                          Ed Sheeran
# 10     Girls Like You  aJOTlE1K90k                            Maroon 5
# 11         Dark Horse  0KSOMA3QBU0        Katy Perry featuring Juicy J
# 12         Let Her Go  RBumgq5yVrA                           Passenger
# 13       Shake It Off  nfWlot6h_JM                        Taylor Swift
# 14            Perfect  2Vv-BfVoq4g                          Ed Sheeran
#
#           views
# 0   10333137131
# 1    5646996878
# 2    5442932116
# 3    4494174328
# 4    4364336550
# 5    3659537658
# 6    3540895308
# 7    3528534409
# 8    3521780925
# 9    3418404141
# 10   3251094531
# 11   3237441316
# 12   3190125678
# 13   3151619552
# 14   3114236814

# %%
sr = songs['code']
vids= sr.values.tolist()
vids
# Out:
# ['lDK9QqIzhwk',
#  'lcOxhH8N3Bo',
#  'pa14VNsdSYM',
#  'izGwDsrQ1eQ',
#  'pAgnJDJN4VA',
#  'sOnqjkJTMaA',
#  '9BMwcO6_hyA',
#  'oRdxUFDoQe0',
#  'IdneKLhsWOQ',
#  'gOsM-DYAEhY']
