# %%
from bs4 import BeautifulSoup
import requests

# %%
inp_file = 'b7906.html'
url = 'https://www.santiwebsite.com/songs/' + inp_file
url
# Out:
# 'https://www.santiwebsite.com/songs/b7906.html'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="fyXHt/YHNLy/wdi8t3A5C93Dz6hgZg+QwyaLFpJCAzFpJOwFXavfBB+cvjMYXJIkfhzQAb6U/8e7i6ylLaMh4w==" name="csrf-token"/>
# <title>
#      I Will Survive
#     </title>
# <link href="css/bootstrap.css" rel="stylesheet" type="text/css"/>
# <link href="css/yt-style.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <nav class="navbar navbar-expand-md navbar-light bg-light">
# <a class="navbar-brand" href="#">
#     Songs to Remember
#    </a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon">
# </span>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item active">
# <a class="nav-link" href="uploaded.html">
#        Uploaded Songs
#       </a>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#        Playlists
#       </a>
# <div aria-labelledby="navbarDropdown" class="dropdown-menu">
# <a class="dropdown-item" href="pl_Adele.html">
#         Adele
#        </a>
# <a class="dropdown-item" href="pl_carpenters.html">
#         Carpenters
#        </a>
# <a class="dropdown-item" href="pl_Elton_John.html">
#         Elton John
#        </a>
# <div class="dropdown-divider">
# </div>
# <a class="dropdown-item" href="yt_Adele.html">
#         Adele
#        </a>
# <a class="dropdown-item" href="yt_The_Carpenters.html">
#         Carpenters
#        </a>
# <a class="dropdown-item" href="yt_Elton_John.html">
#         Elton John
#        </a>
# <a class="dropdown-item" href="yt_Female_Singers.html">
#         Female Singers
#        </a>
# </div>
# </li>
# </ul>
# </div>
# </nav>
# <div class="container">
# <div class="row">
# <!-- start of left column -->
# <div class="col-lg-6 col-md-6 col-xs-12">
# <div class="card card-inverse" style="background:#000;">
# <!-- start of youtube section -->
# <div class="card-block" style="align:center;">
# <object>
# <param name="movie"/>
# <param name="wmode" value="transparent"/>
# <param name="allowFullScreen" value="true"/>
# <param name="allowScriptAccess" value="always"/>
# <embed allowfullscreen="true" allowscriptaccess="always" height="200" src="https://www.youtube.com/v/KjNjplL6ayI?version=3" type="application/x-shockwave-flash" width="400" wmode="transparent"/>
# </object>
# </div>
# <!-- end of card-block -->
# </div>
# <!-- end of card -->
# <!-- end of youtube section -->
# <!-- start of summary table section -->
# <div class="card text-center text-white bg-dark">
# <div class="card-header">
#        I Will Survive
#       </div>
# <div class="card-block">
# <table class="table">
# <tbody>
# <tr>
# <td>
#            Year:
#           </td>
# <td>
#            1979
#           </td>
# </tr>
# <tr>
# <td>
#            Rank:
#           </td>
# <td>
#            6
#           </td>
# </tr>
# <tr>
# <td>
#            Duration:
#           </td>
# <td>
#            3:06
#           </td>
# </tr>
# </tbody>
# </table>
# </div>
# <!-- end of card-block -->
# </div>
# <!-- end of card -->
# <!-- end of summary table section -->
# <!-- start of image section -->
# <div class="card text-center text-white bg-dark">
# <div class="card-header">
#        Gloria Gaynor
#       </div>
# <img alt="Gloria gaynor" class="card-img-top img-fluid" src="uploads/artist/Gloria_Gaynor.jpg"/>
# <div class="card-footer">
# <a class="btn btn-info" href="https://en.wikipedia.org/wiki/Gloria_Gaynor" target="_new">
#         Artist Wiki
#        </a>
# </div>
# </div>
# <!-- enf of card -->
# <!-- end of image section -->
# </div>
# <!-- end of Left col -->
# <!-- start of right column -->
# <div class="col-lg-6 col-md-6 col-xs-12">
# <div class="card text-center text-white bg-dark">
# <div class="card-header">
# <audio controls="controls" preload="auto" src="uploads/song/I_Will_Survive.m4a">
# </audio>
# </div>
# <div class="card-block">
# <span class="h4 card-title">
#         I Will Survive
#        </span>
# <p>
#         At first I was afraid, I was petrified
#         <br/>
#         Kept thinking I could never live without you by my side
#         <br/>
#         But then I spent so many nights thinking how you did me wrong
#         <br/>
#         And I grew strong, and I learned how to get along
#        </p>
# <p>
#         And so you're back from outer space
#         <br/>
#         I just walked in to find you here with that sad look upon your face
#         <br/>
#         I should have changed that stupid lock
#         <br/>
#         I should have made you leave your key
#         <br/>
#         If I had known for just one second you'd be back to bother me
#        </p>
# <p>
#         Go on now, go. Walk out the door
#         <br/>
#         Just turn around now 'cause you're not welcome anymore
#         <br/>
#         Weren't you the one who tried to hurt me with goodbye?
#         <br/>
#         Did you think I'd crumble?
#         <br/>
#         Did you think I'd lay down and die?
#        </p>
# <p>
#         Oh, no, not I
#         <br/>
#         I will survive
#         <br/>
#         Oh, as long as I know how to love I know I'll stay alive
#         <br/>
#         I've got all my life to live
#         <br/>
#         I've got all my love to give
#         <br/>
#         And I'll survive
#         <br/>
#         I will survive, hey, hey
#        </p>
# <p>
#         It took all the strength I had not to fall apart
#         <br/>
#         Kept trying hard to mend the pieces of my broken heart
#         <br/>
#         And I spent, oh, so many nights just feeling sorry for myself
#         <br/>
#         I used to cry but now I hold my head up high
#        </p>
# <p>
#         And you see me somebody new
#         <br/>
#         I'm not that chained-up little person still in love with you
#         <br/>
#         And so you felt like dropping in
#         <br/>
#         And just expect me to be free
#         <br/>
#         And now I'm saving all my loving for someone who's loving me
#        </p>
# <p>
#         [2x]
#         <br/>
#         Go on now, go. Walk out the door
#         <br/>
#         Just turn around now 'cause you're not welcome anymore
#         <br/>
#         Weren't you the one who tried to break me with goodbye?
#         <br/>
#         Did you think I'd crumble?
#         <br/>
#         Did you think I'd lay down and die?
#         <br/>
#         Oh, no, not I
#         <br/>
#         I will survive
#         <br/>
#         Oh, as long as I know how to love I know I'll stay alive
#         <br/>
#         I've got all my life to live
#         <br/>
#         I've got all my love to give
#         <br/>
#         And I'll survive
#         <br/>
#         I will survive
#        </p>
# <a class="btn btn-primary" href="https://en.wikipedia.org/wiki/I_Will_Survive" target="_new">
#         Read More
#        </a>
# </div>
# <!-- end of card block -->
# </div>
# <!-- end of card -->
# </div>
# <!-- end of rght col -->
# </div>
# <!-- end of row -->
# <script src="js/jquery.min.js" type="text/javascript">
# </script>
# <script src="js/tether.min.js" type="text/javascript">
# </script>
# <script src="js/bootstrap.js" type="text/javascript">
# </script>
# </div>
# <!-- end of container from application -->
# <footer>
# <p>
#     Â© 2018 Santi All Rights Reserved. All Wrongs Reversed.
#    </p>
# </footer>
# </body>
# </html>

# %%
#using local file
#with open(inp_file,"r") as file:
#	soup = BeautifulSoup(file)
#print(soup)

# %%
obj_entry = soup.object
embed_entry = obj_entry.embed
print(embed_entry["src"])
# Out:
# https://www.youtube.com/v/KjNjplL6ayI?version=3

# %%
embed_entry["src"] = "https://www.youtube.com/v/ARt9HV9T0w8?version=3"
print(embed_entry["src"])
# Out:
# https://www.youtube.com/v/ARt9HV9T0w8?version=3

# %%
html = soup.prettify("utf-8")
with open(inp_file, "wb") as file:
    file.write(html)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="fyXHt/YHNLy/wdi8t3A5C93Dz6hgZg+QwyaLFpJCAzFpJOwFXavfBB+cvjMYXJIkfhzQAb6U/8e7i6ylLaMh4w==" name="csrf-token"/>
# <title>
#      I Will Survive
#     </title>
# <link href="css/bootstrap.css" rel="stylesheet" type="text/css"/>
# <link href="css/yt-style.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <nav class="navbar navbar-expand-md navbar-light bg-light">
# <a class="navbar-brand" href="#">
#     Songs to Remember
#    </a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon">
# </span>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item active">
# <a class="nav-link" href="uploaded.html">
#        Uploaded Songs
#       </a>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#        Playlists
#       </a>
# <div aria-labelledby="navbarDropdown" class="dropdown-menu">
# <a class="dropdown-item" href="pl_Adele.html">
#         Adele
#        </a>
# <a class="dropdown-item" href="pl_carpenters.html">
#         Carpenters
#        </a>
# <a class="dropdown-item" href="pl_Elton_John.html">
#         Elton John
#        </a>
# <div class="dropdown-divider">
# </div>
# <a class="dropdown-item" href="yt_Adele.html">
#         Adele
#        </a>
# <a class="dropdown-item" href="yt_The_Carpenters.html">
#         Carpenters
#        </a>
# <a class="dropdown-item" href="yt_Elton_John.html">
#         Elton John
#        </a>
# <a class="dropdown-item" href="yt_Female_Singers.html">
#         Female Singers
#        </a>
# </div>
# </li>
# </ul>
# </div>
# </nav>
# <div class="container">
# <div class="row">
# <!-- start of left column -->
# <div class="col-lg-6 col-md-6 col-xs-12">
# <div class="card card-inverse" style="background:#000;">
# <!-- start of youtube section -->
# <div class="card-block" style="align:center;">
# <object>
# <param name="movie"/>
# <param name="wmode" value="transparent"/>
# <param name="allowFullScreen" value="true"/>
# <param name="allowScriptAccess" value="always"/>
# <embed allowfullscreen="true" allowscriptaccess="always" height="200" src="https://www.youtube.com/v/ARt9HV9T0w8?version=3" type="application/x-shockwave-flash" width="400" wmode="transparent"/>
# </object>
# </div>
# <!-- end of card-block -->
# </div>
# <!-- end of card -->
# <!-- end of youtube section -->
# <!-- start of summary table section -->
# <div class="card text-center text-white bg-dark">
# <div class="card-header">
#        I Will Survive
#       </div>
# <div class="card-block">
# <table class="table">
# <tbody>
# <tr>
# <td>
#            Year:
#           </td>
# <td>
#            1979
#           </td>
# </tr>
# <tr>
# <td>
#            Rank:
#           </td>
# <td>
#            6
#           </td>
# </tr>
# <tr>
# <td>
#            Duration:
#           </td>
# <td>
#            3:06
#           </td>
# </tr>
# </tbody>
# </table>
# </div>
# <!-- end of card-block -->
# </div>
# <!-- end of card -->
# <!-- end of summary table section -->
# <!-- start of image section -->
# <div class="card text-center text-white bg-dark">
# <div class="card-header">
#        Gloria Gaynor
#       </div>
# <img alt="Gloria gaynor" class="card-img-top img-fluid" src="uploads/artist/Gloria_Gaynor.jpg"/>
# <div class="card-footer">
# <a class="btn btn-info" href="https://en.wikipedia.org/wiki/Gloria_Gaynor" target="_new">
#         Artist Wiki
#        </a>
# </div>
# </div>
# <!-- enf of card -->
# <!-- end of image section -->
# </div>
# <!-- end of Left col -->
# <!-- start of right column -->
# <div class="col-lg-6 col-md-6 col-xs-12">
# <div class="card text-center text-white bg-dark">
# <div class="card-header">
# <audio controls="controls" preload="auto" src="uploads/song/I_Will_Survive.m4a">
# </audio>
# </div>
# <div class="card-block">
# <span class="h4 card-title">
#         I Will Survive
#        </span>
# <p>
#         At first I was afraid, I was petrified
#         <br/>
#         Kept thinking I could never live without you by my side
#         <br/>
#         But then I spent so many nights thinking how you did me wrong
#         <br/>
#         And I grew strong, and I learned how to get along
#        </p>
# <p>
#         And so you're back from outer space
#         <br/>
#         I just walked in to find you here with that sad look upon your face
#         <br/>
#         I should have changed that stupid lock
#         <br/>
#         I should have made you leave your key
#         <br/>
#         If I had known for just one second you'd be back to bother me
#        </p>
# <p>
#         Go on now, go. Walk out the door
#         <br/>
#         Just turn around now 'cause you're not welcome anymore
#         <br/>
#         Weren't you the one who tried to hurt me with goodbye?
#         <br/>
#         Did you think I'd crumble?
#         <br/>
#         Did you think I'd lay down and die?
#        </p>
# <p>
#         Oh, no, not I
#         <br/>
#         I will survive
#         <br/>
#         Oh, as long as I know how to love I know I'll stay alive
#         <br/>
#         I've got all my life to live
#         <br/>
#         I've got all my love to give
#         <br/>
#         And I'll survive
#         <br/>
#         I will survive, hey, hey
#        </p>
# <p>
#         It took all the strength I had not to fall apart
#         <br/>
#         Kept trying hard to mend the pieces of my broken heart
#         <br/>
#         And I spent, oh, so many nights just feeling sorry for myself
#         <br/>
#         I used to cry but now I hold my head up high
#        </p>
# <p>
#         And you see me somebody new
#         <br/>
#         I'm not that chained-up little person still in love with you
#         <br/>
#         And so you felt like dropping in
#         <br/>
#         And just expect me to be free
#         <br/>
#         And now I'm saving all my loving for someone who's loving me
#        </p>
# <p>
#         [2x]
#         <br/>
#         Go on now, go. Walk out the door
#         <br/>
#         Just turn around now 'cause you're not welcome anymore
#         <br/>
#         Weren't you the one who tried to break me with goodbye?
#         <br/>
#         Did you think I'd crumble?
#         <br/>
#         Did you think I'd lay down and die?
#         <br/>
#         Oh, no, not I
#         <br/>
#         I will survive
#         <br/>
#         Oh, as long as I know how to love I know I'll stay alive
#         <br/>
#         I've got all my life to live
#         <br/>
#         I've got all my love to give
#         <br/>
#         And I'll survive
#         <br/>
#         I will survive
#        </p>
# <a class="btn btn-primary" href="https://en.wikipedia.org/wiki/I_Will_Survive" target="_new">
#         Read More
#        </a>
# </div>
# <!-- end of card block -->
# </div>
# <!-- end of card -->
# </div>
# <!-- end of rght col -->
# </div>
# <!-- end of row -->
# <script src="js/jquery.min.js" type="text/javascript">
# </script>
# <script src="js/tether.min.js" type="text/javascript">
# </script>
# <script src="js/bootstrap.js" type="text/javascript">
# </script>
# </div>
# <!-- end of container from application -->
# <footer>
# <p>
#     Â© 2018 Santi All Rights Reserved. All Wrongs Reversed.
#    </p>
# </footer>
# </body>
# </html>
