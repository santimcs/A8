# %%
import pandas as pd
from datetime import datetime, timedelta
from apiclient.discovery import build

YOUTUBE_DEVELOPER_KEY = 'AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys'

youtube = build('youtube', 'v3', developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_channel(channel_name):
    return youtube.search().list(q=channel_name, type='channel', part='id,snippet').execute()['items'][0]


def get_videos(channel_id, part='id,snippet', limit=10):
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part=part, 
                                           maxResults=min(limit, 50),
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None or len(videos) >= limit:
            break

    return videos

def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
        
    return stats

def parse_count(video):
    return video['id'],video['statistics']['viewCount']

def parse_publish_date(video):
    return video['snippet']['resourceId']['videoId'],datetime.strptime(video['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%S.000Z"),video['snippet']['title']

# %%
channel_name = 'BUDDHADHARM'
channel_id = get_channel(channel_name)['id']['channelId']
channel_id
# Out:
# 'UCBOC9pRgDaEFr3owKu6G8kA'

# %%
channel_id = 'UCBOC9pRgDaEFr3owKu6G8kA'

# %%
videos = get_videos(channel_id, limit=6500)
videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': 'tFF-fFNMe0I3l1HWoq9ND1mORqw',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmhka2pxb2swRFA4',
#   'snippet': {'publishedAt': '2019-08-02T00:30:50Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'ความถูกต้องทั้งกายและจิต',
#    'description': 'ความความถูกต้องทั้งกายและจิต\nพุทธทาส อินทปัญโญ\nความถูกต้องของความเป็นมนุษย์\nสวนโมกขพลาราม\n๑๑ กรกฎาคม ๒๕๒๔\nถูกต้องทั้งกายและจิต',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hdkjqok0DP8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/hdkjqok0DP8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/hdkjqok0DP8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/hdkjqok0DP8/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'hdkjqok0DP8'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'lOWPA15LjfDKCOcVR4oArSNhu58',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLnBVR1J5QXMxcE9v',
#   'snippet': {'publishedAt': '2019-08-02T00:27:09Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '"สมฺมตฺตา"ภาวะแห่งความถูกต้อง',
#    'description': '"สมฺมตฺตา"ภาวะแห่งความถูกต้อง\n\nภาษาบาลี "สมฺมตฺตา"\nแปลว่า ภาวะแห่งความถูกต้อง\n\nที่ไหนมีภาวะแห่งความถูกต้อง\nที่นั่นไม่มีปัญหา\n\nที่ไหนมี\n "มิจฺฉตฺตา" ภาวะแห่งความผิดพลาด\nที่นั่นจะมีปัญหา.\n\n\n\n\nความถูกต้อง\nนำไปสู่จุดหมายปลายทางที่ควรปรารถนา\nคนก็มีความปรารถนาปลายทางอย่างหนึ่ง\nได้กิน ได้เล่น \nได้เรื่องกิน  เรื่องกาม เรื่องเกียรติ ก็พอแล้ว\nสำหรับความเป็นคน\n\n\nแต่เป็นมนุษย์นั้นมันไปไกลกว่านั้น\nคือความถูกต้องชนิดที่เหนือไปกว่า\nเรื่องกิน เรื่องกาม เรื่องเกียรติ\n\nก็คือเรื่องธรรมะ สงบเย็น \nเป็นความหลุดพ้นจากกิเลส\nเรียกว่าเป็นมนุษย์ เพราะใจมันสูง\nมีความถูกต้องก็ไปได้ถึงสุดยอดของความเป็นมนุษย์\n\n\n\n"ธรรมะ คือระบบปฏิบัติที่ถูกต้อง แก่ความเป็นมนุษย์ทุกขั้นทุกตอน แห่งวิวัฒนาการของชีวิตของเขา\nทั้งในแง่ของปัจเจกชน และทั้งในแง่รวมเป็นสังคม"\n\n\nเราจะมีความเป็นมนุษย์ให้ถูกต้อง\nเราก็ต้องมีสัมมาทิฏฐิ;\nความรู้ ความเข้าใจ ความเชื่อ ความคิด ความเห็นที่ถูกต้อง เป็นสัมมาทิฏฐิ\n\n\nพระพุทธเจ้าท่านตรัสว่า\nสัมมาทิฏฐิเป็นตัวนำ เป็นรุ่งอรุณของทุกสิ่ง\nคือพอเราเห็นรุ่งอรุณ แสงเงินแสงทอง ขึ้นมาทางทิศตะวันออก\nเราก็รู้ว่า โอ้เวลากลางวันมาแล้วโว้ย\nพระพุทธเจ้าท่านตรัสว่า สัมมาทิฏฐิเป็นรุ่งอรุณของธรรมะอื่น\n\n\nอะไรเป็นเหตุปัจจัยที่ให้ชีวิตของเรามีอยู่ได้ หรือเป็นไปได้?\nเรียกสั้น ๆว่า เหตุปัขขัยของชีวิตที่เป็นอยู่ได้ในปัจจุบันนี้\nหรือควรจะมีจะเป็นอยู่ในปัจจุบันนี้;จะต้องมีความรู้ความเข้าใจที่ถูกต้องเกี่ยวกับเรื่องนี้',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pUGRyAs1pOo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/pUGRyAs1pOo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/pUGRyAs1pOo/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/pUGRyAs1pOo/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 1,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'pUGRyAs1pOo'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'YhBlevBl3nTBLKwGG6dvo3eLbak',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmlaZjNCSFM3UkF3',
#   'snippet': {'publishedAt': '2019-08-02T00:19:06Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'คำจำกัดความของ"ธรรมะ" ที่เป็นสากล',
#    'description': 'พุทธทาส อินทปัญโญ\nความถูกต้องของความเป็นมนุษย์\nสวนโมกขพลาราม\n๑๑ กรกฎาคม ๒๕๒๔\n\nคำจำกัดความของ"ธรรมะ" ที่เป็นสากล\n\nลูกเด็กๆเหล่านี้ช่วยจำกันไว้ให้ดี\nนี่เป็นคำบัญญัติที่ดีที่สุด จะใช้ได้ตลอดกาล\n\nธรรมะ...ระบบ...คือระบบปฏิบัตินะ!\nไม่ใช่ระบบบ้าน้ำลาย\n\n"ธรรมะคือระบบปฏิบัติที่ถูกต้องแก่ความเป็นมนุษย์ทุกขั้นทุกตอนแห่งวิวัฒนาการของชีวิตของเข
',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iZf3BHS7RAw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/iZf3BHS7RAw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/iZf3BHS7RAw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/iZf3BHS7RAw/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 2,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'iZf3BHS7RAw'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'F_yCTZa-uMWcEb7T2psVtxaDqNY',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkJ5dGM1MEhCM0dN',
#   'snippet': {'publishedAt': '2015-07-16T05:44:51Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'สันทิฏฐิกธรรมต่อธรรมและรสของธรรม',
#    'description': 'พุทธทาส อินฺทปญฺโญ  \nหัวข้อบรรยาย สันทิฏฐิกธรรมต่อธรรมและรสของธรรม\nธรรมบรรยายประจำวันเสาร์ ภาควิสาขบูชา\nธรรมโฆษณ์\xa0๑๓.ข ชุดสันทิฏฐิกธรรม\nลานหินโค้ง สวนโมกขพลาราม\n27 มิถุนายน 2524',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bytc50HB3GM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Bytc50HB3GM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Bytc50HB3GM/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Bytc50HB3GM/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 3,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Bytc50HB3GM'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'dof55y8b5X7HmL2r__LJVRvpQV0',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkhYQVVScHBJeTBB',
#   'snippet': {'publishedAt': '2015-07-16T04:16:26Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'สันทิฏฐิกธรรมต่อสนามรบในตัวเรา',
#    'description': 'พุทธทาส อินฺทปญฺโญ  \nหัวข้อบรรยาย สันทิฏฐิกธรรมต่อสนามรบในตัวเรา\nธรรมบรรยายประจำวันเสาร์ ภาควิสาขบูชา\nธรรมโฆษณ์\xa0๑๓.ข ชุดสันทิฏฐิกธรรม\nลานหินโค้ง สวนโมกขพลาราม\n13 มิถุนายน 2524',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HXAURppIy0A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/HXAURppIy0A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/HXAURppIy0A/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/HXAURppIy0A/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 4,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'HXAURppIy0A'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'hlqq8gcl8ec9CyDzEHroFKP72_A',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkthT09ycDFwVzdZ',
#   'snippet': {'publishedAt': '2015-07-16T03:32:12Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'สันทิฏฐิกธรรมในผลของศาสนา',
#    'description': 'พุทธทาส อินฺทปญฺโญ  \nหัวข้อบรรยายสันทิฏฐิกธรรมในผลของศาสนา\n ธรรมบรรยายประจำวันเสาร์ ภาควิสาขบูชา\nธรรมโฆษณ์\xa0๑๓.ข ชุดสันทิฏฐิกธรรม\nลานหินโค้ง สวนโมกขพลาราม\n6 มิถุนายน 2524',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KaOOrp1pW7Y/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/KaOOrp1pW7Y/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/KaOOrp1pW7Y/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/KaOOrp1pW7Y/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 5,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'KaOOrp1pW7Y'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '89Brszjy72vlaiwr79PaEifDJ4A',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLldBYVdkY1dxc3Vj',
#   'snippet': {'publishedAt': '2015-07-15T08:33:05Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'สันทิฏฐิกธรรมในอะไรๆ ในตัวเราเอง',
#    'description': 'พุทธทาส อินฺทปญฺโญ  \nหัวข้อบรรยาย สันทิฏฐิกธรรมในอะไรๆ ในตัวเราเอง\nธรรมบรรยายประจำวันเสาร์ ภาควิสาขบูชา\nธรรมโฆษณ์\xa0๑๓.ข ชุดสันทิฏฐิกธรรม\nลานหินโค้ง สวนโมกขพลาราม\n30 พฤษภาคม 2524',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WAaWdcWqsuc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/WAaWdcWqsuc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/WAaWdcWqsuc/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/WAaWdcWqsuc/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 6,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'WAaWdcWqsuc'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '-XEl41-BqkYbRChPG8qjKABfqjM',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmlLU1VyeHJHXzBN',
#   'snippet': {'publishedAt': '2015-07-15T06:44:47Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'สันทิฏฐิกธรรมเกี่ยวกับกิเลส',
#    'description': 'พุทธทาส อินฺทปญฺโญ  \nหัวข้อบรรยาย สันทิฏฐิกธรรมเกี่ยวกับกิเลส\nธรรมบรรยายประจำวันเสาร์ ภาควิสาขบูชา\nธรรมโฆษณ์\xa0๑๓.ข ชุดสันทิฏฐิกธรรม\nลานหินโค้ง สวนโมกขพลาราม\n23 พฤษภาคม 2524',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iKSUrxrG_0M/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/iKSUrxrG_0M/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/iKSUrxrG_0M/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/iKSUrxrG_0M/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 7,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'iKSUrxrG_0M'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'CopvTM-D643E7crBOg2twaiVOds',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkQyUEhkMVRMZjl3',
#   'snippet': {'publishedAt': '2015-07-15T05:41:23Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'สันทิฏฐิกธรรมของสัมปรายภพ',
#    'description': 'พุทธทาส อินฺทปญฺโญ  \nหัวข้อบรรยาย สันทิฏฐิกธรรมของสัมปรายภพ\nธรรมบรรยายประจำวันเสาร์ ภาควิสาขบูชา\nธรรมโฆษณ์\xa0๑๓.ข ชุดสันทิฏฐิกธรรม\nลานหินโค้ง สวนโมกขพลาราม\n16 พฤษภาคม 2524',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D2PHd1TLf9w/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/D2PHd1TLf9w/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/D2PHd1TLf9w/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/D2PHd1TLf9w/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 8,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'D2PHd1TLf9w'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'Qt0k94PG3vSMrtFiU5uu1s2FT_A',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmZleGUwVFZyRE40',
#   'snippet': {'publishedAt': '2015-07-15T04:59:54Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'สันทิฏฐิกธรรมของธรรมสโมธาน',
#    'description': 'พุทธทาส อินฺทปญฺโญ  \nหัวข้อบรรยาย สันทิฏฐิกธรรมของธรรมสโมธาน\nธรรมบรรยายประจำวันเสาร์ ภาควิสาขบูชา\nธรรมโฆษณ์\xa0๑๓.ข ชุดสันทิฏฐิกธรรม\nลานหินโค้ง สวนโมกขพลาราม\n9 พฤษภาคม 2524',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fexe0TVrDN4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/fexe0TVrDN4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/fexe0TVrDN4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/fexe0TVrDN4/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 9,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'fexe0TVrDN4'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'OJeUAtsRFC-W1vaU_vGoz3MyOoQ',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkRYdDZVcGcweXA4',
#   'snippet': {'publishedAt': '2015-07-13T22:11:57Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'สันทิฏฐิกธรรมของไตรสิกขา',
#    'description': 'พุทธทาส อินฺทปญฺโญ  \nหัวข้อบรรยาย สันทิฏฐิกธรรมของไตรสิกขา\nธรรมบรรยายประจำวันเสาร์ ภาควิสาขบูชา\nธรรมโฆษณ์\xa0๑๓.ข ชุดสันทิฏฐิกธรรม\nลานหินโค้ง สวนโมกขพลาราม\n2 พฤษภาคม 2524',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi
z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'ฟ้าสางทางมัชชวิรัติและอบายมุข',
#    'description': 'พุทธทาส อินฺทปญฺโญ\nธรรมบรรยายประจำวันเสาร์ ภาคอาสาฬหบูชา\nสวนโมกขพลาราม\n3 กันยายน 2526',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BlQi0-B_PFA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/BlQi0-B_PFA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/BlQi0-B_PFA/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/BlQi0-B_PFA/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 20,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'BlQi0-B_PFA'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'pYP7Ynei5NibpZQEoCWEuzhfGAU',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkt3bWJWZzhhSXRz',
#   'snippet': {'publishedAt': '2015-06-06T00:27:24Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'ฟ้าสางทางภาษาพูด,การสวดมนต์และ มังสวิรัติ',
#    'description': 'พุทธทาส อินฺทปญฺโญ\nธรรมบรรยายประจำวันเสาร์ ภาคอาสาฬหบูชา\nสวนโมกขพลาราม\n27 สิงหาคม 2526',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KwmbVg8aIts/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/KwmbVg8aIts/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/KwmbVg8aIts/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/KwmbVg8aIts/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 21,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'KwmbVg8aIts'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'VsWdxbUULJs3L7xn42S9eyO5qLg',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLjZ4N205Q2tLQ1Y0',
#   'snippet': {'publishedAt': '2015-06-05T23:45:53Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'ฟ้าสางทางฝ่ายบรรพชิต',
#    'description': 'พุทธทาส อินฺทปญฺโญ\nธรรมบรรยายประจำวันเสาร์ ภาคอาสาฬหบูชา\nสวนโมกขพลาราม\n20 สิงหาคม 2526',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6x7m9CkKCV4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/6x7m9CkKCV4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/6x7m9CkKCV4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/6x7m9CkKCV4/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 22,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '6x7m9CkKCV4'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'tuql8nOysG6hAWsP6YM-mFXP7Vk',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmQwUXM4LTFRd1Rz',
#   'snippet': {'publishedAt': '2015-06-03T06:48:35Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'ฟ้าสางทางอุบาสก',
#    'description': 'พุทธทาส อินฺทปญฺโญ\nธรรมบรรยายประจำวันเสาร์ ภาคอาสาฬหบูชา\nสวนโมกขพลาราม\n13 สิงหาคม 2526',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/d0Qs8-1QwTs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/d0Qs8-1QwTs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/d0Qs8-1QwTs/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/d0Qs8-1QwTs/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 23,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'd0Qs8-1QwTs'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'hhWLTazSVzX53GkXsUXT4WxDNo8',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLlk1Ym9vTHNzVGxn',
#   'snippet': {'publishedAt': '2015-06-03T06:17:28Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'ฟ้าสางทางปรมัตถ์และ อภิธรรม',
#    'description': 'พุทธทาส อินฺทปญฺโญ\nธรรมบรรยายประจำวันเสาร์ ภาคอาสาฬหบูชา\nสวนโมกขพลาราม\n13 สิงหาคม 2526',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y5booLssTlg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Y5booLssTlg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Y5booLssTlg/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Y5booLssTlg/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 24,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Y5booLssTlg'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'NcxZTJUrgSsNy_5Q9YL-bUtInoE',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLjhtNnJTUnkxVFQ4',
#   'snippet': {'publishedAt': '2015-06-03T04:31:53Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'ฟ้าสางในเรื่องทางจิต ตอนที่ ๒',
#    'description': 'พุทธทาส อินฺทปญฺโญ\nธรรมบรรยายประจำวันเสาร์ ภาคอาสาฬหบูชา\nสวนโมกขพลาราม\n30 กรกฎาคา 2526',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8m6rSRy1TT8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/8m6rSRy1TT8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/8m6rSRy1TT8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/8m6rSRy1TT8/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 25,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '8m6rSRy1TT8'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 
z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'หลักปฏิบัติเกี่ยวกับไตรลักษณ์ ตอนที่ ๑.',
#    'description': 'ธรรมโฆษณ์ ชุดโอสาเรตัพพธรรม\nธรรมบรรยายประจำวันเสาร์\nบรรยายโดย พุทธทาส อินฺทปญฺโญ\nสวนโมกขพลาราม อ.ไชยา สุราษฎร์ธานี\n3 เมษายน - 26 มิถุนายน 2514',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aRNdoQdIeC8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/aRNdoQdIeC8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/aRNdoQdIeC8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/aRNdoQdIeC8/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 36,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'aRNdoQdIeC8'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '1kiX2NabGWta-6i0RXPP8iet9r0',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmQ4b2xiZHVkSXZB',
#   'snippet': {'publishedAt': '2015-05-22T08:49:20Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'หลักปฏิบัติดับทุกข์โดยอย่าให้กระแสปฏิจจสมุปบาทเกิดได้ ตอนที่ ๓.',
#    'description': 'ธรรมโฆษณ์ ชุดโอสาเรตัพพธรรม\nธรรมบรรยายประจำวันเสาร์\nบรรยายโดย พุทธทาส อินฺทปญฺโญ\nสวนโมกขพลาราม อ.ไชยา สุราษฎร์ธานี\n3 เมษายน - 26 มิถุนายน 2514',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/d8olbdudIvA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/d8olbdudIvA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/d8olbdudIvA/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/d8olbdudIvA/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 37,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'd8olbdudIvA'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '97PXrhoBSDHOu_TVa7vcisnpU8s',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLldtUlZUQ1E5NVNB',
#   'snippet': {'publishedAt': '2015-05-22T08:27:26Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': 'หลักปฏิบัติดับทุกข์โดยอย่าให้กระแสปฏิจจสมุปบาทเกิดได้ ตอนที่ ๒.',
#    'description': 'ธรรมโฆษณ์ ชุดโอสาเรตัพพธรรม\nธรรมบรรยายประจำวันเสาร์\nบรรยายโดย พุทธทาส อินฺทปญฺโญ\nสวนโมกขพลาราม อ.ไชยา สุราษฎร์ธานี\n3 เมษายน - 26 มิถุนายน 2514',
# ...
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/MzVSrNX-FMk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/MzVSrNX-FMk/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/MzVSrNX-FMk/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 986,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'MzVSrNX-FMk'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '2hcbz40ZIbQLWiQYriQV0Tvnyfk',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLi1WOUdDcjZNaU5F',
#   'snippet': {'publishedAt': '2013-03-22T03:33:02Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '在家人應該學習什麼？ฆราวาสควรเรียนเรื่องอะไร?',
#    'description': 'หลักธรรมสำหรับนักศึกษา\nพุทธทาส อินฺทปญฺโญ\nฆราวาสควรเรียนเรื่องอะไร ?\n\n\nหอประชุมมหาวิทยาลัยธรรมศาสตร์\n๑๓ มกราคม ๒๕๐๙\n法音叢書\n《一問一智慧》\n在家人應該學習什麼？\n\n\n佛使比丘\n於一九六六年一月\n在曼谷湯馬沙大學',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-V9GCr6MiNE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/-V9GCr6MiNE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/-V9GCr6MiNE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/-V9GCr6MiNE/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 987,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '-V9GCr6MiNE'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'CGpZA5jDAG4HiQB69vdAgIzFf5Q',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLnVwWVhQZ1lTZEhF',
#   'snippet': {'publishedAt': '2013-03-17T02:22:30Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '可以用什麼比喻「法」?ธรรมเปรียบเหมือนอะไร?',
#    'description': '法音叢書\n《一問一智慧》\n\n\n佛使比丘\n於一九六六年一月\n在曼谷湯馬沙大學\n\nหลักธรรมสำหรับนักศึกษา\nธรรมนี้เปรียบเหมือนอะไร?\nพุทธทาส อินฺทปญฺโญ\nหอประชุมมหาวิทยาลัยธรรมศาสตร์\n\n๑๓ มกราคม ๒๕๐๙',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/upYXPgYSdHE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/upYXPgYSdHE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/upYXPgYSdHE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/upYXPgYSdHE/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 988,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'upYXPgYSdHE'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'sP7mQ9eAAbywxtxg3bzCTRvo8bM',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkx1UTdQVm9MVy1n',
#   'snippet': {'publishedAt': '2013-03-16T00:15:52Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '可以去那兒學習？พุทธศาสนาเรียนที่ตรงไหน ?',
#    'description': '可以去那兒學習？\n可以到那兒研究？\n\n\n法音叢書《一問一智慧》\n於一九六六年一月\n在曼谷湯馬沙大學\n\nพุทธศาสนาเรียนกันที่ตรงไหน ?\n\nหลักธรรมสำหรับนักศึกษา\nพุทธทาส อินฺทปญฺโญ\nหอประชุมมหาวิทยาลัยธรรมศาสตร์\n๑๓ มกราคม ๒๕๐๙',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LuQ7PVoLW-g/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LuQ7PVoLW-g/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LuQ7PVoLW-g/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/LuQ7PVoLW-g/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 989,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'LuQ7PVoLW-g'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'resRQnxvCbBDHuE4B8iu0HSrRPc',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkVYZDU2cUZxWFZJ',
#   'snippet': {'publishedAt': '2013-03-15T06:47:29Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '如何修習不執著？วิธีไม่ยึดมั่นถือมั่น',
#    'description': '如何修習不執著？\n佛使比丘\n\n法音叢書 《一問一智慧》\n於一九六六年一月\n在曼谷湯馬沙大學\n\nมีหลักปฏิบัติอย่างไร ?\nเกี่ยวกับความไม่ยึดมั่นถือมั่น \nพุทธทาส อินฺทปญฺโญ\n\nหลักธรรมสำหรับนักศึกษา\nหอประชุมมหาวิทยาลัยธรรมศาสตร์\n๑๓ มกราคม ๒๕๐๙',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EXd56qFqXVI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/EXd56qFqXVI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/EXd56qFqXVI/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/EXd56qFqXVI/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 990,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'EXd56qFqXVI'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'vMZhda3_Iv2NbGnv4DedzZNmPnE',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmtzQnoyUTVWOEJF',
#   'snippet': {'publishedAt': '2013-03-02T00:36:19Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '佛教中最簡要的根本思想是什麼？ใจความสำคัญสั้นที่สุด ของพุทธศาสนา?',
#    'description': '佛教中最簡要的根本思想是什麼？\n佛使比丘\n法音叢書 《一問一智慧》\n於一九六六年一月\n在曼谷湯馬沙大學\n\nใจความสำคัญสั้นที่สุด\nของพุทธศาสนา คืออะไร?\nพุทธทาส อินฺทปญฺโญ\nหลักธรรมสำหรับนักศึกษา\nหอประชุมมหาวิทยาลัยธรรมศาสตร์\n๑๓ มกราคม ๒๕๐๙',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ksBz2Q5V8BE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ksBz2Q5V8BE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ksBz2Q5V8BE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/ksBz2Q5V8BE/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 991,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'ksBz2Q5V8BE'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'aKqM3Tc7WmMUqEdsD_h4XzWsfX8',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLkZoN3B2MWlwZzJB',
#   'snippet': {'publishedAt': '2013-03-01T21:05:08Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '佛陀有什麼特別的教導？พระพุทธเจ้าสอนอย่างไร?',
#    'description': '佛陀有什麼特別的教導？\n佛使比丘\n法音叢書 《一問一智慧》\n於一九六六年一月\n在曼谷湯馬沙大學\nพระพุทธเจ้าท่านสอนว่าอย่างไร?\nพุทธทาส อินฺทปญฺโญ\n\nหลักธรรมสำหรับนักศึกษา\nหอประชุมมหาวิทยาลัยธรรมศาสตร์\n๑๓ มกราคม ๒๕๐๙',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Fh7pv1ipg2A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Fh7pv1ipg2A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Fh7pv1ipg2A/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Fh7pv1ipg2A/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 992,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Fh7pv1ipg2A'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'oI3ckDQtGnIdGxfrclilEAjEF3Q',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLnhVUF9MeGVXWnFR',
#   'snippet': {'publishedAt': '2013-02-28T21:43:05Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '佛陀教導什麼？พระพุทธเจ้าท่านสอนอะไร?',
#    'description': '佛陀教導什麼？\n佛使比丘\n法音叢書 《一問一智慧》\n於一九六六年一月\n在曼谷湯馬沙大學\nพระพุทธเจ้าท่านสอนอะไร ?\nพุทธทาส อินฺทปญฺโญ\nหลักธรรมสำหรับนักศึกษา\nหอประชุมมหาวิทยาลัยธรรมศาสตร์\n๑๓ มกราคม ๒๕๐๙',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xUP_LxeWZqQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/xUP_LxeWZqQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/xUP_LxeWZqQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/xUP_LxeWZqQ/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 993,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'xUP_LxeWZqQ'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'l7wpyLoGHZkpoRKNiQGw4pW2f6I',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLjVadFZUNTcwZktv',
#   'snippet': {'publishedAt': '2013-02-28T01:13:49Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '"กายานุปัสสนา"',
#    'description': 'ปทานุกรมเพื่อการปฏิบัติธรรม\nพุทธทาส อินฺทปญฺโญ\nบันทึกปทานุกรมบนธรรมมาสน์\nสวนโมกขพลาราม\n๑ มิถุนายน ๒๕๑๗',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5ZtVT570fKo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5ZtVT570fKo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5ZtVT570fKo/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/5ZtVT570fKo/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 994,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '5ZtVT570fKo'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'WQDjYpDp6UMFhvKIaQx71zlYlHs',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLk1QTGpBblJueU40',
#   'snippet': {'publishedAt': '2013-02-28T00:56:15Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '"กายสักขี"',
#    'description': 'ปทานุกรมเพื่อการปฏิบัติธรรม\nพุทธทาส อินฺทปญฺโญ\nบันทึกปทานุกรมบนธรรมมาสน์\nสวนโมกขพลาราม\n๑ มิถุนายน ๒๕๑๗',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MPLjAnRnyN4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/MPLjAnRnyN4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/MPLjAnRnyN4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/MPLjAnRnyN4/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 995,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'MPLjAnRnyN4'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'ycYHLSUCr3WbTKgMNgs_iqfMFhM',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmdWUXNYbTVTSVNV',
#   'snippet': {'publishedAt': '2013-02-28T00:31:56Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '"กายสมาจารบริสุทธิ์"',
#    'description': 'ปทานุกรมเพื่อการปฏิบัติธรรม\nพุทธทาส อินฺทปญฺโญ\nบันทึกปทานุกรมบนธรรมมาสน์\nสวนโมกขพลาราม\n๑ มิถุนายน ๒๕๑๗',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gVQsXm5SISU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/gVQsXm5SISU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/gVQsXm5SISU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/gVQsXm5SISU/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 996,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'gVQsXm5SISU'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '4HDPX2pI7VaiyBSoLyvh0HJI1Ws',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLmNNNTZCNF9mOUpn',
#   'snippet': {'publishedAt': '2013-02-28T00:16:04Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '"กายวิญญัตติ"',
#    'description': 'ปทานุกรมเพื่อการปฏิบัติธรรม\nพุทธทาส อินฺทปญฺโญ\nบันทึกปทานุกรมบนธรรมมาสน์\nสวนโมกขพลาราม\n๑ มิถุนายน ๒๕๑๗',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cM56B4_f9Jg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/cM56B4_f9Jg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/cM56B4_f9Jg/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/cM56B4_f9Jg/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 997,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'cM56B4_f9Jg'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '3I6BkU801DBSJBjUCTatGs-UF_Y',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLjZPelRSd1FyamV3',
#   'snippet': {'publishedAt': '2013-02-27T23:50:52Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '"กายคตาสติ"',
#    'description': 'ปทานุกรมเพื่อการปฏิบัติธรรม\nพุทธทาส อินฺทปญฺโญ\nบันทึกปทานุกรมบนธรรมมาสน์\nสวนโมกขพลาราม\n๑ มิถุนายน ๒๕๑๗',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6OzTRwQrjew/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/6OzTRwQrjew/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/6OzTRwQrjew/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/6OzTRwQrjew/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 998,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '6OzTRwQrjew'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'i4zaVzvqEXxquh4UiHDUVv7-fso',
#   'id': 'VVVCT0M5cFJnRGFFRnIzb3dLdTZHOGtBLjVZVkExbW12MHM4',
#   'snippet': {'publishedAt': '2013-02-27T23:28:40Z',
#    'channelId': 'UCBOC9pRgDaEFr3owKu6G8kA',
#    'title': '"กายกัมมมัญญตา"',
#    'description': 'ปทานุกรมเพื่อการปฏิบัติธรรม\nพุทธทาส อินฺทปญฺโญ\nบันทึกปทานุกรมบนธรรมมาสน์\nสวนโมกขพลาราม\n๑ มิถุนายน ๒๕๑๗',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5YVA1mmv0s8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5YVA1mmv0s8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5YVA1mmv0s8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/5YVA1mmv0s8/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Buddhadharm',
#    'playlistId': 'UUBOC9pRgDaEFr3owKu6G8kA',
#    'position': 999,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '5YVA1mmv0s8'},
#    'videoOwnerChannelTitle': 'Buddhadharm',
#    'videoOwnerChannelId': 'UCBOC9pRgDaEFr3owKu6G8kA'}},
#  ...]

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
len(video_ids)
# Out:
# 2802

# %%
stats = get_videos_stats(video_ids)
len(stats)
# Out:
# 2802

# %%
most_viewed = sorted(stats, key=lambda x:int(x['statistics']['viewCount']), reverse=True)

# %%
counts = [parse_count(video) for video in most_viewed]
len(counts)
# Out:
# 2802

# %%
df_count = pd.DataFrame(data = counts , columns=['videoId','viewCount'])
df_count.head(11)
# Out:
#         videoId viewCount
# 0   KC8vphi-P5w    864664
# 1   uqhC0VsZjx4    538697
# 2   97rhaQpC17c    446219
# 3   lYRNIs2svSo    414427
# 4   XS5XLQAbKpU    363802
# 5   ZC_Tcimg0pw    347209
# 6   O6ltdKUpPbY    316609
# 7   wwO8pnpSKmw    302936
# 8   rzZcS1FFeYc    214867
# 9   QRaZk8HW5rQ    192028
# 10  5ySl9zT5Tq4    189511

# %%
df_count["viewCount"] = df_count["viewCount"].astype("float")

# %%
df_count.sort_values(by=['viewCount'],ascending=[False]).head()
# Out:
#        videoId  viewCount
# 0  KC8vphi-P5w   864664.0
# 1  uqhC0VsZjx4   538697.0
# 2  97rhaQpC17c   446219.0
# 3  lYRNIs2svSo   414427.0
# 4  XS5XLQAbKpU   363802.0

# %%
df_count.to_excel('c:\\a8\\excel\\BUDDHADHARM.xlsx')

# %%
publish_dates = [parse_publish_date(video) for video in videos]
len(publish_dates)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8756/127792961.py in <module>
# ----> 1 publish_dates = [parse_publish_date(video) for video in videos]
#       2 len(publish_dates)
#
# ~\AppData\Local\Temp/ipykernel_8756/127792961.py in <listcomp>(.0)
# ----> 1 publish_dates = [parse_publish_date(video) for video in videos]
#       2 len(publish_dates)
#
# ~\AppData\Local\Temp/ipykernel_8756/945484612.py in parse_publish_date(video)
#      37
#      38 def parse_publish_date(video):
# ---> 39     return video['snippet']['resourceId']['videoId'],datetime.strptime(video['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%S.000Z"),video['snippet']['title']
#
# C:\ProgramData\Anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# C:\ProgramData\Anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '2022-06-24T08:53:14Z' does not match format '%Y-%m-%dT%H:%M:%S.000Z'

# %%
df_date = pd.DataFrame(data = publish_dates , columns=['videoId','publishedAt','title'])
df_date.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18276/3901591932.py in <module>
# ----> 1 df_date = pd.DataFrame(data = publish_dates , columns=['videoId','publishedAt','title'])
#       2 df_date.head()
#
# NameError: name 'publish_dates' is not defined

# %%
dfd = pd.merge(df_date, df_count, on='videoId', how='inner')
dfd.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18276/2227057804.py in <module>
# ----> 1 dfd = pd.merge(df_date, df_count, on='videoId', how='inner')
#       2 dfd.info()
#
# NameError: name 'df_date' is not defined

# %%
dfd.sort_values(by=['publishedAt'],ascending=[False]).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18276/4131825677.py in <module>
# ----> 1 dfd.sort_values(by=['publishedAt'],ascending=[False]).head()
#
# NameError: name 'dfd' is not defined

# %%
df_count_date = pd.merge(df_count, df_date, how='inner', on='videoId')
df_count_date.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18276/2609005373.py in <module>
# ----> 1 df_count_date = pd.merge(df_count, df_date, how='inner', on='videoId')
#       2 df_count_date.head(10)
#
# NameError: name 'df_date' is not defined

# %%
df_count_date.to_excel('c:\\aab\\excel\\traversy media.xlsx')
