# %%
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine
from apiclient.discovery import build
api_key = 'AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys'
youtube = build('youtube', 'v3', developerKey=api_key)

engine = create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/BBB_development')
conbb = engine.connect()
    
data_path = '../data/'

def get_viewCounts(vids):
    videos = []
    for vid in vids:
        res = youtube.videos().list(id=vid,part='statistics',maxResults=1).execute()
        videos += res['items']
    return videos

def parse_count(video):
    return video['id'],video['statistics']['viewCount']

# %%
today = date.today()
today
# Out:
# datetime.date(2021, 2, 4)

# %% [markdown]
# ### Songs with youtube code

# %%
sql = '''
SELECT year, rank, nbr, title, A.name,  code, publish_date, views
FROM songs S
JOIN artists A ON artist_id = A.id
WHERE  code <> '' 
ORDER BY views DESC
'''
songs = pd.read_sql(sql,conbb)
len(songs)
# Out:
# 1233

# %%
sr = songs['code']
vids= sr.values.tolist()
len(vids)
# Out:
# 1233

# %%
stat_videos = get_viewCounts(vids)
len(stat_videos)

# %%
counts = [parse_count(video) for video in stat_videos]
len(counts)
# Out:
# 1201

# %%
df_count = pd.DataFrame(data = counts , columns=['videoId','viewCount'])
df_count.columns
# Out:
# Index(['videoId', 'viewCount'], dtype='object')

# %%
df_count["viewCount"] = df_count["viewCount"].astype("int64")

# %%
df_count.rename(columns = {"videoId" : "code", "viewCount" : "views"}, inplace = True)
df_count.columns
# Out:
# Index(['code', 'views'], dtype='object')

# %%
dfd = pd.merge(songs, df_count, on='code', how='inner')
dfd.shape
# Out:
# (1201, 9)

# %%
df_count.dtypes
# Out:
# code     object
# views     int64
# dtype: object

# %%
df_count.to_sql('df_count', engine, if_exists='replace')

# %%
sql = """
UPDATE songs AS s
SET views = d.views, processed = true
FROM df_count AS d
WHERE s.code = d.code
"""
print(sql)
# Out:
# UPDATE songs AS s
# SET views = d.views, processed = true
# FROM df_count AS d
# WHERE s.code = d.code

# %%
with engine.begin() as conn:     # TRANSACTION
    conn.execute(sql)

# %%
sql = '''
SELECT S.id, year, rank, nbr, title, A.name,  code, views
FROM songs S
JOIN artists A ON artist_id = A.id
WHERE  code <> '' AND processed = false
ORDER BY views DESC
'''
songs = pd.read_sql(sql,conbb)
songs
# Out:
#       id  year  rank  nbr                                             title  \
# 0   5490  2015    65   99                                      Drag Me Down
# 1   5856  1971   109   99                                Stairway to Heaven
# 2    119  1961    19   99                                 Hit the Road Jack
# 3   2112  1981    18   99                                Just the Two of Us
# 4    333  1963    35   99                                        Be My Baby
# 5    829  1968    31   99                                   Born to Be Wild
# 6   5847  1963   101   99                               Blowin’ in the Wind
# 7   1062  1970    67    9                                     Fire and Rain
# 8   1367  1973    72   99                                             Clair
# 9    699  1967     1   99                                  To Sir With Love
# 10   800  1968     2   99                                      Love is Blue
# 11  1899  1979     5   99                                          Reunited
# 12  2185  1981    91   99                                          Suddenly
WHERE processed = true
"""
rp = conbb.execute(sql)
rp.rowcount
# Out:
# 1201

# %%
sql = """
SELECT year, rank, nbr, title, A.name,  code, publish_date, views, mp3, duration
FROM songs S
JOIN artists A ON artist_id = A.id
LEFT JOIN lyrics L ON song_id = S.id
WHERE  code <> '' AND uploaded = False AND views > 500000000
ORDER BY views DESC
"""
df = pd.read_sql(sql, conbb)
df.head(10)
# Out:
#    year  rank  nbr                         title  \
# 0  2016    73   99          Hymn for the Weekend
# 1  2017    16   99                     24K Magic
# 2  2011    14   99  Last Friday Night (T.G.I.F.)
# 3  2005    60   99                    La Tortura
# 4  2005    32   99                      My Humps
# 5  2014    17   99                 Say Something
# 6  1997     4   99             Un-Break My Heart
# 7  1995     1   99            Gangsta's Paradise
# 8  2012    21   99           Where Have You Been
# 9  2009     4   99               I Gotta Feeling
#
#                                        name         code publish_date  \
# 0                                  Coldplay  YykjpeuMNEk   2016-01-29
# 1                                Bruno Mars  UqyT8IEBkvY   2016-10-06
# 2                                Katy Perry  KlyXNRrsk4A   2011-06-12
# 3          Shakira featuring Alejandro Sanz  Dsp_8Lm1eSk   2019-12-12
# 4                       The Black Eyed Peas  iEe_eraFWWs   2009-06-17
# 5  A Great Big World and Christina Aguilera  -2U0Ivkn2Ds   2019-12-13
# 6                              Toni Braxton  p2Rch6WvPJE   2009-10-25
# 7                     Coolio featuring L.V.  fPO76Jlnz6c   2017-08-01
# 8                                   Rihanna  HBxt_v0WF6Y   2019-12-11
# 9                       The Black Eyed Peas  uSD4vsh1zDA   2009-12-23
#
#         views                     mp3  duration
# 0  1394820685                    None       300
# 1  1342568121                    None       300
# 2  1307248606                    None       300
# 3   564999853                    None       300
# 4   562500326                    None       300
# 5   538940252                    None       300
# 6   531967194                    None       300
# 7   521472001  Gangsta_s_Paradise.mp3       241
# 8   504573954                    None       300
# 9   501905246                    None       300

# %%
sql = """
SELECT year, rank, nbr, title, A.name,  code, publish_date, views, mp3, duration, uploaded
FROM songs S
JOIN artists A ON artist_id = A.id
LEFT JOIN lyrics L ON song_id = S.id
WHERE  code <> '' AND uploaded = False 
ORDER BY views DESC
"""
songs = pd.read_sql(sql, conbb)
songs.head(10)
# Out:
#    year  rank  nbr                         title  \
# 0  2016    73   99          Hymn for the Weekend
# 1  2017    16   99                     24K Magic
# 2  2011    14   99  Last Friday Night (T.G.I.F.)
# 3  2005    60   99                    La Tortura
# 4  2005    32   99                      My Humps
# 5  2014    17   99                 Say Something
# 6  1997     4   99             Un-Break My Heart
# 7  1995     1   99            Gangsta's Paradise
# 8  2012    21   99           Where Have You Been
# 9  2009     4   99               I Gotta Feeling
#
#                                        name         code publish_date  \
# 0                                  Coldplay  YykjpeuMNEk   2016-01-29
# 1                                Bruno Mars  UqyT8IEBkvY   2016-10-06
# 2                                Katy Perry  KlyXNRrsk4A   2011-06-12
# 3          Shakira featuring Alejandro Sanz  Dsp_8Lm1eSk   2019-12-12
# 4                       The Black Eyed Peas  iEe_eraFWWs   2009-06-17
# 5  A Great Big World and Christina Aguilera  -2U0Ivkn2Ds   2019-12-13
# 6                              Toni Braxton  p2Rch6WvPJE   2009-10-25
# 7                     Coolio featuring L.V.  fPO76Jlnz6c   2017-08-01
# 8                                   Rihanna  HBxt_v0WF6Y   2019-12-11
# 9                       The Black Eyed Peas  uSD4vsh1zDA   2009-12-23
#
#         views                     mp3  duration  uploaded
# 0  1394820685                    None       300     False
# 1  1342568121                    None       300     False
# 2  1307248606                    None       300     False
# 3   564999853                    None       300     False
# 4   562500326                    None       300     False
# 5   538940252                    None       300     False
# 6   531967194                    None       300     False
# 7   521472001  Gangsta_s_Paradise.mp3       241     False
# 8   504573954                    None       300     False
# 9   501905246                    None       300     False

# %%
sql = """
SELECT code, count(*)
FROM songs S
WHERE code <> ''
GROUP BY code
HAVING count(*) > 1
"""
df = pd.read_sql(sql, conbb)
df.head()
# Out:
# Empty DataFrame
# Columns: [code, count]
# Index: []

# %%
sr = df["code"]
vids = sr.values.tolist()
in_p = ", ".join(map(lambda vid: "'%s'" % vid, vids))
in_p
# Out:
# ''

# %%
sql = """
SELECT * FROM songs 
WHERE code IN (%s)
ORDER BY year, rank
"""
sql = sql % (in_p)
df_dups = pd.read_sql(sql, conbb)
df_dups
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute_no_params(self, cursor, statement, context)
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#
# SyntaxError: syntax error at or near ")"
# LINE 3: WHERE code IN ()
#                        ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-21-6114323bacaf> in <module>
#       5 """
#       6 sql = sql % (in_p)
# ----> 7 df_dups = pd.read_sql(sql, conbb)
#       8 df_dups
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     507         )
#     508     else:
# --> 509         return pandas_sql.read_query(
#     510             sql,
#     511             index_col=index_col,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1293         args = _convert_params(sql, params)
#    1294
# -> 1295         result = self.execute(*args)
#    1296         columns = result.keys()
#    1297
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1159     def execute(self, *args, **kwargs):
#    1160         """Simple passthrough to SQLAlchemy connectable"""
# -> 1161         return self.connectable.execution_options(no_parameters=True).execute(
#    1162             *args, **kwargs
#    1163         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1001         """
#    1002         if isinstance(object_, util.string_types[0]):
# -> 1003             return self._execute_text(object_, multiparams, params)
#    1004         try:
#    1005             meth = object_._execute_on_connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1170         dialect = self.dialect
#    1171         parameters = _distill_params(multiparams, params)
# -> 1172         ret = self._execute_context(
#    1173             dialect,
#    1174             dialect.execution_ctx_cls._init_statement,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1264                             break
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#    1268                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute_no_params(self, cursor, statement, context)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#     598     def is_disconnect(self, e, connection, cursor):
#
# ProgrammingError: (psycopg2.errors.SyntaxError) syntax error at or near ")"
# LINE 3: WHERE code IN ()
#                        ^
#
# [SQL:
# SELECT * FROM songs
# WHERE code IN ()
# ORDER BY year, rank
# ]
# (Background on this error at: http://sqlalche.me/e/13/f405)
