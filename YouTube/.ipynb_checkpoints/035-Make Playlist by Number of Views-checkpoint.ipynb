# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/BBB_development')
conbb = engine.connect()
    
data_path = '../data/'

# %% [markdown]
# ### Inquiry

# %%
sql = '''
SELECT title, code, name, views
FROM songs
JOIN artists ON artist_id = artists.id
WHERE views BETWEEN 2000000000 AND 2999999999
ORDER BY views DESC
'''
songs = pd.read_sql(sql,conbb)
songs
# Out:
#                         title         code  \
# 0              Girls Like You  aJOTlE1K90k
# 1                  Let Her Go  RBumgq5yVrA
# 2                        Roar
# 3                       Hello  YQHsXMglC9A
# 4                     Perfect  2Vv-BfVoq4g
# 5                 Blank Space  e-ORhEE9VVg
# 6                      Closer  PT2_F-1esPk
# 7       We Don't Talk Anymore  3AtDnEC4zak
# 8                    Rockabye  papuvlVeZg8
# 9   This Is What You Came For  kOkQ4T5WO9E
# 10                       Baby  kffacxfA7G4
# 11                     Closer
# 12        All About That Bass  7PCkvCPvDXk
# 13             Work from Home  5GL9JoH4Sws
# 14                  New Rules  k2qgadSvNyU
# 15                 Chandelier  2vjPBrBU-TM
# 16        Love Me Like You Do  AJtDXIazrMo
# 17       Love the Way You Lie  uelHwf8o7_U
# 18          What Do You Mean?  DK_0jXPuIr0
# 19              The Lazy Song  fLexgOxsZu0
# 20           Treat You Better  lY2yjAdbvdQ
# 21                 Wake Me Up  IcrbM1l_BoI
#
#                                                name       views
# 0                                          Maroon 5  2983718362
# 1                                         Passenger  2938864878
# 2                                        Katy Perry  2826458754
# 3                                             Adele  2805157225
# 4                                        Ed Sheeran  2779401417
# 5                                      Taylor Swift  2740129501
# 6                 The Chainsmokers featuring Halsey  2636758118
# 7               Charlie Puth featuring Selena Gomez  2606829213
# 8   Clean Bandit featuring Sean Paul and Anne-Marie  2494020189
# 9                   Calvin Harris featuring Rihanna  2447536981
# 10                 Justin Bieber featuring Ludacris  2447176176
# 11                The Chainsmokers featuring Halsey  2440438094
# 12                                   Meghan Trainor  2437989335
# 13            Fifth Harmony featuring Ty Dolla $ign  2416034167
# 14                                         Dua Lipa  2375599801
# 15                                              Sia  2360477581
# 16                                   Ellie Goulding  2184085564
# 17                         Eminem featuring Rihanna  2180647899
# 18                                    Justin Bieber  2141291949
# 19                                       Bruno Mars  2086394967
# 20                                     Shawn Mendes  2048795778
# 21                                           Avicii  2037068602

# %%
sr = songs['code']
vids= sr.values.tolist()
vids
# Out:
# ['XqZsoesa55w',
#  'JGwWNGJdvx8',
#  'RgKAFK5djSk',
#  'OPf0YbXqDm0',
#  '9bZkp7q19f0',
#  '09R8_2nJtjg',
#  'fRh_vgS2dFE',
#  'CevxZvSJLk8',
#  'hT_nvWreIhg',
#  'lp-EO5I60KA',
#  'nfWlot6h_JM',
#  '0KSOMA3QBU0']
