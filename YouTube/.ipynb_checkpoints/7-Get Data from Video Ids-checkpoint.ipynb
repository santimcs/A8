# %%
import pandas as pd
from datetime import datetime, timedelta
from apiclient.discovery import build

YOUTUBE_DEVELOPER_KEY = 'AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys'

youtube = build('youtube', 'v3', developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_channel(channel_name):
    return youtube.search().list(q=channel_name, type='channel', part='id,snippet').execute()['items'][0]


def get_videos(channel_id, part='id,snippet', limit=10):
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part=part, 
                                           maxResults=min(limit, 50),
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None or len(videos) >= limit:
            break

    return videos

def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
        
    return stats

def parse_count(video):
    return video['id'],video['statistics']['viewCount']

def parse_publish_date(video):
    return video['snippet']['resourceId']['videoId'],datetime.strptime(video['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%S.000Z"),video['snippet']['title']

# %%
res = youtube.search().list(part='snippet', 
                            q='UCkbl59_mrmuCL6aJgrlHnEQ',
                            type='channel').execute()
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/9W4EkBC0jZegLCtIbzLLlHcNCfc"',
#  'regionCode': 'TH',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/9wYaqAe_RCliIVzOuc7HPCLfjdY"',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ'},
#    'snippet': {'publishedAt': '2018-07-30T15:55:45.000Z',
#     'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#     'title': 'Crayons and Carry-Ons',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-G72LdOkx0_0/AAAAAAAAAAI/AAAAAAAAAAA/cOBc434Cciw/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-G72LdOkx0_0/AAAAAAAAAAI/AAAAAAAAAAA/cOBc434Cciw/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-G72LdOkx0_0/AAAAAAAAAAI/AAAAAAAAAAA/cOBc434Cciw/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'channelTitle': 'Crayons and Carry-Ons',
#     'liveBroadcastContent': 'none'}}]}

# %%
channel_name = 'Crayons and Carry-Ons'
channel_id = get_channel(channel_name)['id']['channelId']
channel_id
# Out:
# 'UCkbl59_mrmuCL6aJgrlHnEQ'

# %%
videos = get_videos(channel_id, limit=6500)
videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Cxy76U5rwogh5DbSB5JSBCyfEkE"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLngtYUNyU2pIM3Nj',
#   'snippet': {'publishedAt': '2019-05-13T14:54:07.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'Books That Heal - An Amazing Organization',
#    'description': "Books That Heal is a nonprofit organization based out of NYC, founded by Michael Flatley.  They help pediatric patients battling chronic illnesses write and illustrate their very own children's books to become published authors and illustrators. \n\nOnce the book is created, Books That Heal hosts book signing events to celebrate each child’s story; to surround the child with their friends, family and support teams and to help raise funds for the family or their foundation.\n\nCheck them out at www.booksthatheal.org",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x-aCrSjH3sc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/x-aCrSjH3sc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/x-aCrSjH3sc/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/x-aCrSjH3sc/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/x-aCrSjH3sc/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'x-aCrSjH3sc'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/AkeFhUvaDL_8ae4qaf2VnnE2ozk"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLkRUWmt0TUN3cEZn',
#   'snippet': {'publishedAt': '2019-03-22T00:23:00.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'Kuala Lumpur | CELEBRATING THAIPUSAM FESTIVAL AT THE BATU CAVES',
#    'description': "We fell in love with Kuala Lumpur! It is such a family-friendly city, filled with great people and delicious food. We happened to visit during Thaipusam, a huge Hindu festival and it was one of the coolest things we've ever experienced. Check it out!",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DTZktMCwpFg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/DTZktMCwpFg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/DTZktMCwpFg/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/DTZktMCwpFg/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/DTZktMCwpFg/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 1,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'DTZktMCwpFg'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/kDK7o6iO5Se3u2zDPCE1fJlOTTM"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLkFVZVV4cnI1azFJ',
#   'snippet': {'publishedAt': '2019-02-18T11:59:45.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'PENANG, MALAYSIA | GEORGE TOWN, BATU FERRINGHI AND KEK LOK SI TEMPLE',
#    'description': 'We spent about a week in Penang, Malaysia. We found some amazing street art in George Town, Rowan learned how to swim at the Hard Rock Hotel in Batu Ferringhi and we visited Kek Lok Si, a beautiful temple! Thanks for watching!',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AUeUxrr5k1I/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/AUeUxrr5k1I/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/AUeUxrr5k1I/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/AUeUxrr5k1I/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/AUeUxrr5k1I/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 2,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'AUeUxrr5k1I'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/j5pUBj3hMjC82PYheL_vhYXIX9Q"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLk54emhUV3dHUW93',
#   'snippet': {'publishedAt': '2019-02-09T13:35:10.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'LANGKAWI, MALAYSIA | ORIENTAL VILLAGE | SCARIEST CABLECAR RIDE',
#    'description': "We went to Langkawi for three days.  Even though the weather wasn't ideal, we still had a great time and really liked the island.  We rented a car and explored the beaches, small towns and we also rode the scariest cablecar we've ever been on!",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NxzhTWwGQow/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/NxzhTWwGQow/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/NxzhTWwGQow/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/NxzhTWwGQow/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/NxzhTWwGQow/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 3,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'NxzhTWwGQow'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/sF5wcmlEhLVcmDmodNNDuiUgjFc"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLkg2WnVXOUhkQXJZ',
#   'snippet': {'publishedAt': '2019-01-14T09:09:01.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'BALI | EXPLORING UBUD, CANGGU, SANUR AND NUSA LEMBONGAN',
#    'description': 'We spent two weeks exploring Bali! We went temple hopping and almost got attacked by monkeys in Ubud, visited the beaches of Canggu and Sanur and fell in love with the crystal clear blue water on Nusa Lembongan. Check it out!\n\nCheck out our daily posts on our Instagram page! https://www.instagram.com/crayons_and_carryons/?hl=en\n\n\n\nMusic Credits:\n\nVibe With Me by Joakim Karud\nDreams by Joakim Karud',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/H6ZuW9HdArY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/H6ZuW9HdArY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/H6ZuW9HdArY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/H6ZuW9HdArY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/H6ZuW9HdArY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 4,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'H6ZuW9HdArY'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/pFtm3LM4dtmYqqJZ2gYzx5S6PPc"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLnZiWUlfckFJc1M0',
#   'snippet': {'publishedAt': '2018-12-17T18:11:48.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'ROAD TRIP TO PAI, THAILAND | BAMBOO BRIDGE, LAND SPLIT, PAI CANYON AND MEMORIAL BRIDGE',
#    'description': 'We decided to take a mini vacation from Chiang Mai so we rented a car and headed north for Pai! We had such a great time exploring this small, hippie village! \n\nFollow Us On Instagram: https://www.instagram.com/crayons_and_carryons/\n\nPai Village Boutique Resort: \nhttp://www.paivillage.com',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vbYI_rAIsS4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/vbYI_rAIsS4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/vbYI_rAIsS4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/vbYI_rAIsS4/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/vbYI_rAIsS4/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 5,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'vbYI_rAIsS4'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/IUUNpBrNRwZieFy5beUXaC6mwL4"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLnBrWDFtMUdjOS1z',
#   'snippet': {'publishedAt': '2018-12-04T04:04:44.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'DAY IN THE LIFE | LIVING IN CHIANG MAI, THAILAND',
#    'description': 'Check out what an average day living in Chiang Mai, Thailand looks like.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pkX1m1Gc9-s/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/pkX1m1Gc9-s/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/pkX1m1Gc9-s/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/pkX1m1Gc9-s/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/pkX1m1Gc9-s/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 6,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'pkX1m1Gc9-s'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/IaJII5ohfVk-QheuqTjvgjSSvO4"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLjNId2x6Z0xrRkJF',
#   'snippet': {'publishedAt': '2018-11-24T12:53:34.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'MURPHY TURNS ONE IN THAILAND | THE LANTERN FESTIVAL',
#    'description': 'Our little Murphy turned one in Chiang Mai, Thailand so we celebrated by visiting the zoo! \n\nWe also attended the Loy Krathong and Yee Peng Lantern Festival. It was absolutely amazing! \n\nThank you for following our adventures!',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3HwlzgLkFBE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/3HwlzgLkFBE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/3HwlzgLkFBE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/3HwlzgLkFBE/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/3HwlzgLkFBE/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 7,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '3HwlzgLkFBE'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/uMkA5kYd1PdDdfT7CiJPtrmy_rU"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLkd0aXRpQ2VESWNF',
#   'snippet': {'publishedAt': '2018-11-15T11:13:31.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'CHIANG MAI LIVING | APARTMENT TOUR | DOI INTHANON NATIONAL PARK',
#    'description': "Thanks for tuning into our 5th vlog! We are getting settled into our apartment here in Chiang Mai, Thailand so we wanted to give you a look inside. We've also been busy visiting temples, markets, cafes and we took an awesome day trip to Doi Inthanon National Park! Check it out! :)",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GtitiCeDIcE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/GtitiCeDIcE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/GtitiCeDIcE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/GtitiCeDIcE/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/GtitiCeDIcE/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 8,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'GtitiCeDIcE'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/bFVpIQpmLeI_2sK1qQWuPNKYxo8"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLlRTMG1vRXhFek5r',
#   'snippet': {'publishedAt': '2018-11-03T13:48:02.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'WELCOME TO THAILAND | OUR FIRST WEEK IN CHIANG MAI',
#    'description': 'After working hard and saving for months our trip around the world has officially begun! Our first week in Chiang Mai, Thailand has been filled with temples, coffee, markets, so much delicious food and lots more. Check out what we have been up to!\n\nOur Airbnb - https://www.airbnb.com/rooms/28502656',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TS0moExEzNk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/TS0moExEzNk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/TS0moExEzNk/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/TS0moExEzNk/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/TS0moExEzNk/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 9,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'TS0moExEzNk'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/naHu1QZOHEVCd5lGkA1H-ti3O0o"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLkdldjByQS1rRXRv',
#   'snippet': {'publishedAt': '2018-10-25T02:47:04.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'YOU ASKED, WE ANSWERED | LEAVING FOR THAILAND TOMORROW',
#    'description': "Thanks for joining us for vlog #3! We are about to embark on our 6 month adventure through SE Asia! In this vlog, we will let you know what we've been up to before we leave and we also answer some great questions from our followers! Enjoy! :)\n\nAdirondack Cruise & Charter - http://www.adkcruise.com",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Gev0rA-kEto/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Gev0rA-kEto/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Gev0rA-kEto/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Gev0rA-kEto/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/Gev0rA-kEto/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 10,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Gev0rA-kEto'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oxi6tZVW_vJdGREyf2dOmWBWvGU"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLmdpQ2M2cWxOQnp3',
#   'snippet': {'publishedAt': '2018-09-24T19:27:04.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'OLD ORCHARD BEACH, BAR HARBOR AND ACADIA NATIONAL PARK',
#    'description': "We had to switch up our plans to visit North Carolina when Hurricane Florence decided to roll through but in the end we had the best time in Maine! In this video you'll see some of the highlights of our little trip! Hope you enjoy! :)\n\nMaine Blog Post : https://www.crayonsandcarryons.com/bar-harbor-and-acadia-national-park/\n\nInstagram: https://www.instagram.com/crayons_and_carryons/",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/giCc6qlNBzw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/giCc6qlNBzw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/giCc6qlNBzw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/giCc6qlNBzw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/giCc6qlNBzw/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 11,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'giCc6qlNBzw'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/qfIvuM69dEmFaqeluOUuc_PW1u8"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLjRJM0Vta3BvNWY4',
#   'snippet': {'publishedAt': '2018-09-11T19:07:55.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'DAY IN THE GARDEN || YADDO GARDENS, SARATOGA SPRINGS',
#    'description': 'Short clip of our day at Yaddo Gardens.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4I3Emkpo5f8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/4I3Emkpo5f8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/4I3Emkpo5f8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/4I3Emkpo5f8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/4I3Emkpo5f8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 12,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '4I3Emkpo5f8'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/MaLazM5JJUEvrE3U7D5CkS0tEPU"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLksteG5rTnlydmxR',
#   'snippet': {'publishedAt': '2018-09-05T11:43:53.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'OUR FIRST VLOG | WHY WE SOLD EVERYTHING TO TRAVEL THE WORLD',
#    'description': "Welcome to our first vlog! In this video we talk about why we decided to sell everything to travel the world and also let you know where we will be traveling to in these next few months. You'll also see some video of the cutest kids in the world (we might be slightly biased)! Hope you enjoy! :)\n\nWebsite: http://www.crayonsandcarryons.com\nInstagram: http://www.instagram.com/crayons_and_carryons\nFacebook: http://www.facebook.com/crayonsandcarryons",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/K-xnkNyrvlQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/K-xnkNyrvlQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/K-xnkNyrvlQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/K-xnkNyrvlQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/K-xnkNyrvlQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 13,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'K-xnkNyrvlQ'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/eONYfwCbtlYN4rzLYD6ccT9NHdE"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLl9FRHdpWnlkQ21F',
#   'snippet': {'publishedAt': '2018-09-05T01:35:14.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'DAY AT THE BEACH || LAKE LUZERNE, NEW YORK',
#    'description': 'Short clip of our day at the beach!',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_EDwiZydCmE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/_EDwiZydCmE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/_EDwiZydCmE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/_EDwiZydCmE/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/_EDwiZydCmE/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 14,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '_EDwiZydCmE'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/1RLz0polYHmmHvXV7Wzz8bO8ay0"',
#   'id': 'VVVrYmw1OV9tcm11Q0w2YUpncmxIbkVRLjlLaHdMZWlQa0Vz',
#   'snippet': {'publishedAt': '2018-09-04T23:58:56.000Z',
#    'channelId': 'UCkbl59_mrmuCL6aJgrlHnEQ',
#    'title': 'DAY IN THE PARK || GLENS FALLS, NEW YORK',
#    'description': 'Short clip of our day! :)',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9KhwLeiPkEs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9KhwLeiPkEs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9KhwLeiPkEs/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/9KhwLeiPkEs/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/9KhwLeiPkEs/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crayons and Carry-Ons',
#    'playlistId': 'UUkbl59_mrmuCL6aJgrlHnEQ',
#    'position': 15,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '9KhwLeiPkEs'}}}]

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
len(video_ids)
# Out:
# 16

# %%
stats = get_videos_stats(video_ids)
len(stats)
# Out:
# 16

# %%
most_viewed = sorted(stats, key=lambda x:int(x['statistics']['viewCount']), reverse=True)

# %%
for video in most_viewed:
    print(video['id'], video['statistics']['viewCount'])
# Out:
# GtitiCeDIcE 1469
# 3HwlzgLkFBE 1248
# TS0moExEzNk 1152
# pkX1m1Gc9-s 1102
# K-xnkNyrvlQ 758
# H6ZuW9HdArY 537
# vbYI_rAIsS4 481
# NxzhTWwGQow 444
# Gev0rA-kEto 353
# giCc6qlNBzw 330
# AUeUxrr5k1I 292
# DTZktMCwpFg 96
# 9KhwLeiPkEs 54
# 4I3Emkpo5f8 41
# _EDwiZydCmE 41
# x-aCrSjH3sc 15

# %%
counts = [parse_count(video) for video in most_viewed]
len(counts)
# Out:
# 16

# %%
df_count = pd.DataFrame(data = counts , columns=['videoId','viewCount'])
df_count
# Out:
#         videoId viewCount
# 0   GtitiCeDIcE      1469
# 1   3HwlzgLkFBE      1248
# 2   TS0moExEzNk      1152
# 3   pkX1m1Gc9-s      1102
# 4   K-xnkNyrvlQ       758
# 5   H6ZuW9HdArY       537
# 6   vbYI_rAIsS4       481
# 7   NxzhTWwGQow       444
# 8   Gev0rA-kEto       353
# 9   giCc6qlNBzw       330
# 10  AUeUxrr5k1I       292
# 11  DTZktMCwpFg        96
# 12  9KhwLeiPkEs        54
# 13  4I3Emkpo5f8        41
# 14  _EDwiZydCmE        41
# 15  x-aCrSjH3sc        15

# %%
df_count["viewCount"] = df_count["viewCount"].astype("float")

# %%
df_count.sort_values(by=['viewCount'],ascending=[False])
# Out:
#         videoId  viewCount
# 0   GtitiCeDIcE     1469.0
# 1   3HwlzgLkFBE     1248.0
# 2   TS0moExEzNk     1152.0
# 3   pkX1m1Gc9-s     1102.0
# 4   K-xnkNyrvlQ      758.0
# 5   H6ZuW9HdArY      537.0
# 6   vbYI_rAIsS4      481.0
# 7   NxzhTWwGQow      444.0
# 8   Gev0rA-kEto      353.0
# 9   giCc6qlNBzw      330.0
# 10  AUeUxrr5k1I      292.0
# 11  DTZktMCwpFg       96.0
# 12  9KhwLeiPkEs       54.0
# 13  4I3Emkpo5f8       41.0
# 14  _EDwiZydCmE       41.0
# 15  x-aCrSjH3sc       15.0

# %%
publish_dates = [parse_publish_date(video) for video in videos]
len(publish_dates)
# Out:
# 16

# %%
df_date = pd.DataFrame(data = publish_dates , columns=['videoId','publishedAt','title'])
df_date
# Out:
#         videoId         publishedAt  \
# 0   x-aCrSjH3sc 2019-05-13 14:54:07
# 1   DTZktMCwpFg 2019-03-22 00:23:00
# 2   AUeUxrr5k1I 2019-02-18 11:59:45
# 3   NxzhTWwGQow 2019-02-09 13:35:10
# 4   H6ZuW9HdArY 2019-01-14 09:09:01
# 5   vbYI_rAIsS4 2018-12-17 18:11:48
# 6   pkX1m1Gc9-s 2018-12-04 04:04:44
# 7   3HwlzgLkFBE 2018-11-24 12:53:34
# 8   GtitiCeDIcE 2018-11-15 11:13:31
# 9   TS0moExEzNk 2018-11-03 13:48:02
# 10  Gev0rA-kEto 2018-10-25 02:47:04
# 11  giCc6qlNBzw 2018-09-24 19:27:04
# 12  4I3Emkpo5f8 2018-09-11 19:07:55
# 13  K-xnkNyrvlQ 2018-09-05 11:43:53
# 14  _EDwiZydCmE 2018-09-05 01:35:14
# 15  9KhwLeiPkEs 2018-09-04 23:58:56
#
#                                                 title
# 0           Books That Heal - An Amazing Organization
# 1   Kuala Lumpur | CELEBRATING THAIPUSAM FESTIVAL ...
# 2   PENANG, MALAYSIA | GEORGE TOWN, BATU FERRINGHI...
# 3   LANGKAWI, MALAYSIA | ORIENTAL VILLAGE | SCARIE...
# 4   BALI | EXPLORING UBUD, CANGGU, SANUR AND NUSA ...
# 5   ROAD TRIP TO PAI, THAILAND | BAMBOO BRIDGE, LA...
# 6    DAY IN THE LIFE | LIVING IN CHIANG MAI, THAILAND
# 7   MURPHY TURNS ONE IN THAILAND | THE LANTERN FES...
# 8   CHIANG MAI LIVING | APARTMENT TOUR | DOI INTHA...
# 9   WELCOME TO THAILAND | OUR FIRST WEEK IN CHIANG...
# 10  YOU ASKED, WE ANSWERED | LEAVING FOR THAILAND ...
# 11  OLD ORCHARD BEACH, BAR HARBOR AND ACADIA NATIO...
# 12  DAY IN THE GARDEN || YADDO GARDENS, SARATOGA S...
# 13  OUR FIRST VLOG | WHY WE SOLD EVERYTHING TO TRA...
# 14         DAY AT THE BEACH || LAKE LUZERNE, NEW YORK
# 15           DAY IN THE PARK || GLENS FALLS, NEW YORK

# %%
dfd = pd.merge(df_date, df_count, on='videoId', how='inner')
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 15
# Data columns (total 4 columns):
# videoId        16 non-null object
# publishedAt    16 non-null datetime64[ns]
# title          16 non-null object
# viewCount      16 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 640.0+ bytes

# %%
dfd.sort_values(by=['publishedAt'],ascending=[False])
# Out:
#         videoId         publishedAt  \
# 0   x-aCrSjH3sc 2019-05-13 14:54:07
# 1   DTZktMCwpFg 2019-03-22 00:23:00
# 2   AUeUxrr5k1I 2019-02-18 11:59:45
# 3   NxzhTWwGQow 2019-02-09 13:35:10
# 4   H6ZuW9HdArY 2019-01-14 09:09:01
# 5   vbYI_rAIsS4 2018-12-17 18:11:48
# 6   pkX1m1Gc9-s 2018-12-04 04:04:44
# 7   3HwlzgLkFBE 2018-11-24 12:53:34
# 8   GtitiCeDIcE 2018-11-15 11:13:31
# 9   TS0moExEzNk 2018-11-03 13:48:02
# 10  Gev0rA-kEto 2018-10-25 02:47:04
# 11  giCc6qlNBzw 2018-09-24 19:27:04
# 12  4I3Emkpo5f8 2018-09-11 19:07:55
# 13  K-xnkNyrvlQ 2018-09-05 11:43:53
# 14  _EDwiZydCmE 2018-09-05 01:35:14
# 15  9KhwLeiPkEs 2018-09-04 23:58:56
#
#                                                 title  viewCount
# 0           Books That Heal - An Amazing Organization       15.0
# 1   Kuala Lumpur | CELEBRATING THAIPUSAM FESTIVAL ...       96.0
# 2   PENANG, MALAYSIA | GEORGE TOWN, BATU FERRINGHI...      292.0
# 3   LANGKAWI, MALAYSIA | ORIENTAL VILLAGE | SCARIE...      444.0
# 4   BALI | EXPLORING UBUD, CANGGU, SANUR AND NUSA ...      537.0
# 5   ROAD TRIP TO PAI, THAILAND | BAMBOO BRIDGE, LA...      481.0
# 6    DAY IN THE LIFE | LIVING IN CHIANG MAI, THAILAND     1102.0
# 7   MURPHY TURNS ONE IN THAILAND | THE LANTERN FES...     1248.0
# 8   CHIANG MAI LIVING | APARTMENT TOUR | DOI INTHA...     1469.0
# 9   WELCOME TO THAILAND | OUR FIRST WEEK IN CHIANG...     1152.0
# 10  YOU ASKED, WE ANSWERED | LEAVING FOR THAILAND ...      353.0
# 11  OLD ORCHARD BEACH, BAR HARBOR AND ACADIA NATIO...      330.0
# 12  DAY IN THE GARDEN || YADDO GARDENS, SARATOGA S...       41.0
# 13  OUR FIRST VLOG | WHY WE SOLD EVERYTHING TO TRA...      758.0
# 14         DAY AT THE BEACH || LAKE LUZERNE, NEW YORK       41.0
# 15           DAY IN THE PARK || GLENS FALLS, NEW YORK       54.0

# %%
req = youtube.search().list(q='TMr6subvuQI',part='snippet',type='video',maxResults=1)

# %%
res = req.execute()
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/R0Zi2lQSTYETiRh5Qk9lyoOQnQ0"',
#  'nextPageToken': 'CAEQAA',
#  'regionCode': 'TH',
#  'pageInfo': {'totalResults': 121, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/5HWuB5HncfSmy47H54z3VKqGfXE"',
#    'id': {'kind': 'youtube#video', 'videoId': 'TMr6subvuQI'},
#    'snippet': {'publishedAt': '2018-07-31T13:00:06.000Z',
#     'channelId': 'UCNdqGgAK2u-EucN4IAIqP7Q',
#     'title': 'ความเงียบดังที่สุด - Getsunova [Official MV]',
#     'description': 'เพลง ความเงียบดังที่สุด ศิลปิน GETSUNOVA ซิงเกิลล่าสุด ที่พวกเขาเลือกมาให...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TMr6subvuQI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TMr6subvuQI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TMr6subvuQI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'OfficialWhiteMusic',
#     'liveBroadcastContent': 'none'}}]}

# %%
#for item in res['items']:
print(item['id']['videoId'],item['snippet']['title'],item['snippet']['publishedAt'])
# Out:
# TMr6subvuQI ความเงียบดังที่สุด - Getsunova [Official MV] 2018-07-31T13:00:06.000Z

# %%
def get_videos_dates(video_ids):
    dates = []
    for video in video_ids:
        #res = youtube.videos().list(id=','.join(video_ids[i]),
                                   #part='statistics').execute()
        res = youtube.search().list(q=video,part='snippet',type='video',maxResults=1).execute()
        temp = item['id']['videoId'],item['snippet']['title'],item['snippet']['publishedAt']
        dates += temp
        
    return dates

# %%
publish_dates = [get_videos_date(video) for video in videos]
len(publish_dates)
# Out:
# ['x-aCrSjH3sc',
#  'DTZktMCwpFg',
#  'AUeUxrr5k1I',
#  'NxzhTWwGQow',
#  'H6ZuW9HdArY',
#  'vbYI_rAIsS4',
#  'pkX1m1Gc9-s',
#  '3HwlzgLkFBE',
#  'GtitiCeDIcE',
#  'TS0moExEzNk',
#  'Gev0rA-kEto',
#  'giCc6qlNBzw',
#  '4I3Emkpo5f8',
#  'K-xnkNyrvlQ',
#  '_EDwiZydCmE',
#  '9KhwLeiPkEs']

# %%
dates = get_videos_dates(video_ids)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-84-f6147586baa9> in <module>
# ----> 1 dates = get_videos_dates(video_ids)
#
# <ipython-input-82-df2111b1a0a8> in get_videos_dates(video_ids)
#       4         #res = youtube.videos().list(id=','.join(video_ids[i]),
#       5                                    #part='statistics').execute()
# ----> 6         res = youtube.search().list(q=video,part='snippet',type='video',maxResults=1).execute()
#       7         temp = item['id']['videoId'],item['snippet']['title'],item['snippet']['publishedAt']
#       8         dates += temp
#
# ~\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131         return positional_wrapper
#     132
#
# ~\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     849       callback(resp)
#     850     if resp.status >= 300:
# --> 851       raise HttpError(resp, content, uri=self.uri)
#     852     return self.postproc(resp, content)
#     853
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/search?q=x-aCrSjH3sc&part=snippet&type=video&maxResults=1&key=AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.">

# %%
dates
# Out:
# ['TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z',
#  'TMr6subvuQI',
#  'ความเงียบดังที่สุด - Getsunova [Official MV]',
#  '2018-07-31T13:00:06.000Z']
