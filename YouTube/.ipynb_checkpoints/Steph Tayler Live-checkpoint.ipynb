# %%
import pandas as pd
from datetime import datetime, timedelta
from apiclient.discovery import build

YOUTUBE_DEVELOPER_KEY = 'AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys'

youtube = build('youtube', 'v3', developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_channel(channel_name):
    return youtube.search().list(q=channel_name, type='channel', part='id,snippet').execute()['items'][0]


def get_videos(channel_id, part='id,snippet', limit=10):
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part=part, 
                                           maxResults=min(limit, 50),
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None or len(videos) >= limit:
            break

    return videos

def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
        
    return stats

def parse_count(video):
    return video['id'],video['statistics']['viewCount']

def parse_publish_date(video):
    return video['snippet']['resourceId']['videoId'],datetime.strptime(video['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%S.000Z"),video['snippet']['title']

# %%
channel_name = 'traversy media'
channel_id = get_channel(channel_name)['id']['channelId']
channel_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e86781e51964> in <module>
#       1 channel_name = 'traversy media'
# ----> 2 channel_id = get_channel(channel_name)['id']['channelId']
#       3 channel_id
#
# NameError: name 'get_channel' is not defined

# %%
channel_id = 'UC29ju8bIPH5as8OGnQzwJyA'

# %%
videos = get_videos(channel_id, limit=6500)
videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Jw8CEp6VoWN6_exfmX7SrAkhSos"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLkJ3aFRLSkZwS1N3',
#   'snippet': {'publishedAt': '2019-05-30T16:16:41.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Quick & Easy CSS Loaders',
#    'description': 'In this video we are going to build 3 different animated CSS loaders and add a little JavaScript to load in some static content. \n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nLoader 1 - Florin Pop | @florinpop1705 \nhttps://codepen.io/FlorinPop17/pen/NJJoYx\nLoader 3 - Maedah Batool | @MaedahBatool \nhttps://codepen.io/MaedahBatool/pen/wZxMjZ?editors=1100\n\nComplete Code:\nhttps://codepen.io/bradtraversy/pen/Xwxvzp\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BwhTKJFpKSw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/BwhTKJFpKSw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/BwhTKJFpKSw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/BwhTKJFpKSw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/BwhTKJFpKSw/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'BwhTKJFpKSw'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/D9CxG-uYpkKb605LxZCb0z5xCmU"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjZIMXdmdFBTMG9v',
#   'snippet': {'publishedAt': '2019-05-27T12:54:56.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Build a PWA With Vue & Ionic 4',
#    'description': 'In this project we will built a progressive web app with Vue.js and Ionic 4. We will use the @ionic/vue package and the @vue/pwa plugin to do this.\n\nCode: \nhttps://github.com/bradtraversy/zip-info-pwa\n\nSponsor: Freelancer Bundle (Use "brad25" for 25% off)\nhttps://studywebdevelopment.com/freelancing.html\n\n@ionic/vue Info:\nhttps://blog.ionicframework.com/announcing-the-ionic-vue-beta/\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6H1wftPS0oo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/6H1wftPS0oo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/6H1wftPS0oo/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/6H1wftPS0oo/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/6H1wftPS0oo/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 1,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '6H1wftPS0oo'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oSg9tS68Njl60CdQOaHeirkNFTg"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLlA3dDEzU0d5dFJr',
#   'snippet': {'publishedAt': '2019-05-21T13:11:13.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Build a Netflix Landing Page Clone with HTML, CSS & JS',
#    'description': 'In this video, we will re-create the Netflix landing page using HTML, CSS and a bit of JavaScript for the tabs. We will use modern CSS3+ techniques like Grid, Flex, overlays, shadows, etc\n\nCode:\nhttps://codepen.io/bradtraversy/pen/yWPONg\n\nModern HTML & CSS Udemy Course Promo:\nhttps://www.udemy.com/course/modern-html-css-from-the-beginning/?couponCode=TRAVERSYMEDIA\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nCode:\nhttps://codepen.io/bradtraversy/pen/VOpZvp\nTextures:\nhttps://github.com/mrdoob/three.js/tree/master/examples/textures\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/P7t13SGytRk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/P7t13SGytRk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/P7t13SGytRk/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/P7t13SGytRk/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/P7t13SGytRk/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 2,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'P7t13SGytRk'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/pn2wTTen5ILLT9Y7eqxmHxDJ3Hc"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLnpSbzJ0dlFwdXM4',
#   'snippet': {'publishedAt': '2019-05-19T16:01:23.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'TypeScript Setup With Node & Express',
#    'description': 'In this video we will setup a Node/Express/TypeScript/Nodemon environment with TS-Node.\n\nTypeScript Crash Course:\nhttps://www.youtube.com/watch?v=rAy_3SIqT-E&t=1407s\n\nNode-TS Repo:\nhttps://github.com/TypeStrong/ts-node\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zRo2tvQpus8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zRo2tvQpus8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/zRo2tvQpus8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/zRo2tvQpus8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/zRo2tvQpus8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 3,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'zRo2tvQpus8'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/1jMLAU3lNkosb-gjRx0ELHam320"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjhqUDR4cGdhNnlZ',
#   'snippet': {'publishedAt': '2019-05-15T15:39:30.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Getting Started With Three.js',
#    'description': 'In this video we will look at the Three JS animation library using the WebGL renderer.\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nCode:\nhttps://codepen.io/bradtraversy/pen/VOpZvp\nTextures:\nhttps://github.com/mrdoob/three.js/tree/master/examples/textures\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8jP4xpga6yY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/8jP4xpga6yY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/8jP4xpga6yY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/8jP4xpga6yY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/8jP4xpga6yY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 4,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '8jP4xpga6yY'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/PpkIVsYVRUbAX3oMX4kAYXlF8qo"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLk93VzBfN3Bfajg0',
#   'snippet': {'publishedAt': '2019-05-10T15:35:04.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'What Makes A Great Programmer? 10 Characteristics',
#    'description': 'In this video we will look at some common characteristic traits that many great programmers have in common\n\nSponsor: Freelancer Bundle (Use "brad25" for 25% off)\nhttps://studywebdevelopment.com/freelancing.html\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OwW0_7p_j84/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/OwW0_7p_j84/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/OwW0_7p_j84/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/OwW0_7p_j84/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/OwW0_7p_j84/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 5,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'OwW0_7p_j84'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JDUn27mjvbozvyABTAd7_jiwo8Q"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLk9OM0k1TjNQWktz',
#   'snippet': {'publishedAt': '2019-05-08T11:48:53.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'JS Package Spotlight Ep.1 -  Moment, BcryptJS, JWT Simple, Request & More',
#    'description': 'In this episode we will look at the following NPM/JavaScript packages....\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nMoment (2:30) - https://github.com/moment/moment\nNode Slug (10:19) - https://github.com/Trott/node-slug\nBctypt.js (12:58) - https://github.com/dcodeIO/bcrypt.js/\nJwt-Simple (19:46) - https://github.com/hokaccha/node-jwt-simple\nNode Config (24:30) - https://github.com/lorenwest/node-config\nNode UUID (28:00) - https://github.com/kelektiv/node-uuid\nRequest (29:58) - https://github.com/request/request\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ON3I5N3PZKs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ON3I5N3PZKs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ON3I5N3PZKs/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/ON3I5N3PZKs/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/ON3I5N3PZKs/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 6,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'ON3I5N3PZKs'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/dCdkUimFAO9VuZ1zkDA9TbP3B7Y"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmlZTTJ6RlAzWm4w',
#   'snippet': {'publishedAt': '2019-05-03T17:55:12.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'HTTP Crash Course & Exploration',
#    'description': 'In this video we will talk about HTTP and what it is, the request/response cycle, status codes, header/body and more. We will use Postman/Express.js to give examples\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iYM2zFP3Zn0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/iYM2zFP3Zn0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/iYM2zFP3Zn0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/iYM2zFP3Zn0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/iYM2zFP3Zn0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 7,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'iYM2zFP3Zn0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/FQzyOiNcFrQphuHfhUqB2ienzBw"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmx0emxoQXhKcjc0',
#   'snippet': {'publishedAt': '2019-05-01T17:31:26.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Nuxt JS Crash Course',
#    'description': 'In this video we will look at Vue.js server side rendering with Nuxt.js. We will build a dadjokes app. This requires at least minimal Vue.js experience.\n\nSponsor: Freelancer Bundle (Use "brad25" for 25% off)\nhttps://studywebdevelopment.com/freelancing.html\n\nCode:\nhttps://github.com/bradtraversy/nuxt_dadjokes\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia\n\nAPI Link:\nhttps://icanhazdadjoke.com/api',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ltzlhAxJr74/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ltzlhAxJr74/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ltzlhAxJr74/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/ltzlhAxJr74/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/ltzlhAxJr74/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 8,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'ltzlhAxJr74'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/6FRYMK2ART_6iG3RpUKeSlXSEII"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLk93bGxwcGRGUTNV',
#   'snippet': {'publishedAt': '2019-04-30T13:23:14.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Social Network Theme With Sass - Part 4',
#    'description': 'In this part we will add the rest of the pages, finish up the utility classes and make the site responsive with media queries\n\nCode:\nhttps://github.com/bradtraversy/devconnector_theme_sass\n\nMERN Course With Full App:\nhttps://www.udemy.com/mern-stack-front-to-back/?couponCode=TRAVERSYMEDIA\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OwllppdFQ3U/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/OwllppdFQ3U/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/OwllppdFQ3U/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/OwllppdFQ3U/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/OwllppdFQ3U/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 9,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'OwllppdFQ3U'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/SCdbWZacurrpuwg2dg7jV3bQps0"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmo5ZDdlOV9mVnUw',
#   'snippet': {'publishedAt': '2019-04-30T13:20:51.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Social Network Theme With Sass - Part 3',
#    'description': 'In this part we will work on the profile list and single profile page and work with CSS grid template areas, flex and more\n\nCode:\nhttps://github.com/bradtraversy/devconnector_theme_sass\n\nMERN Course With Full App:\nhttps://www.udemy.com/mern-stack-front-to-back/?couponCode=TRAVERSYMEDIA\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j9d7e9_fVu0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/j9d7e9_fVu0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/j9d7e9_fVu0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/j9d7e9_fVu0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/j9d7e9_fVu0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 10,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'j9d7e9_fVu0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/FZyehb0TO_c19wqebtFQL873W40"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLnhveEp4aWZOV1BF',
#   'snippet': {'publishedAt': '2019-04-30T13:05:22.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Social Network Theme With Sass - Part 2',
#    'description': 'In this part we will create the login and register pages with more utility classes as well as generate some margin and padding classes using Sass logic\n\nCode:\nhttps://github.com/bradtraversy/devconnector_theme_sass\n\nMERN Course With Full App:\nhttps://www.udemy.com/mern-stack-front-to-back/?couponCode=TRAVERSYMEDIA\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xoxJxifNWPE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/xoxJxifNWPE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/xoxJxifNWPE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/xoxJxifNWPE/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/xoxJxifNWPE/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 11,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'xoxJxifNWPE'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/uylx8TRvQMhzs1lFnwgzJLI1Zhw"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLklGTTloYmFwZUEw',
#   'snippet': {'publishedAt': '2019-04-30T13:05:06.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Social Network Theme With Sass - Part 1',
#    'description': 'In this part we will setup Sass, create the landing page with navigation, image overlay, Sass variables, mixins and functions\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nCode:\nhttps://github.com/bradtraversy/devconnector_theme_sass\n\nMERN Course With Full App:\nhttps://www.udemy.com/mern-stack-front-to-back/?couponCode=TRAVERSYMEDIA\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IFM9hbapeA0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/IFM9hbapeA0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/IFM9hbapeA0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/IFM9hbapeA0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/IFM9hbapeA0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 12,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'IFM9hbapeA0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/XX5UYSMZxdtC-6C09JYwn_bJsEw"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjFpeXNOVXJJM2x3',
#   'snippet': {'publishedAt': '2019-04-27T14:23:28.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Quick Autocomplete App With JS & JSON',
#    'description': 'In this project we will build a simple web app that searches a JSON file using the Fetch API, Async/Await, Regex and high order array methods. \n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nStates.json Gist:\nhttps://gist.github.com/bradtraversy/20dee7787486d10db3bd1f55fae5fdf4\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1iysNUrI3lw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/1iysNUrI3lw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/1iysNUrI3lw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/1iysNUrI3lw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/1iysNUrI3lw/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 13,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '1iysNUrI3lw'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/easdR_rM6fKovmg4Bfpr1YM_sEQ"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmVSWkh6aTNsLTRR',
#   'snippet': {'publishedAt': '2019-04-24T16:51:58.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Front End, Back End & Full Stack Web Development',
#    'description': 'In this video we wil discuss the technologies and responsabilities needed to become a front end, back end and full stack web developer.\n\nSponsor: Freelancer Bundle (Use "brad25" for 25% off)\nhttps://studywebdevelopment.com/freelancing.html\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eRZHzi3l-4Q/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/eRZHzi3l-4Q/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/eRZHzi3l-4Q/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/eRZHzi3l-4Q/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/eRZHzi3l-4Q/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 14,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'eRZHzi3l-4Q'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/KPzImqDA-gsaIblbaJpFkPzq5DM"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjl5bGo5TlIwTGNn',
#   'snippet': {'publishedAt': '2019-04-22T20:51:55.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'MySQL Crash Course | Learn SQL',
#    'description': 'In this video we will look at installing mysql, creating users, writing SQL queries via the shell and Workbench and even implementing MySQL into Node.js at the end.\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nMySQL Cheat Sheet:\nhttps://gist.github.com/bradtraversy/c831baaad44343cc945e76c2e30927b3\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9ylj9NR0Lcg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9ylj9NR0Lcg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9ylj9NR0Lcg/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/9ylj9NR0Lcg/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/9ylj9NR0Lcg/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 15,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '9ylj9NR0Lcg'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/pY_aSyDLhPNG_P5IYLicU-fqKOU"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLkZNaFZYT0E1NHg4',
#   'snippet': {'publishedAt': '2019-04-19T19:13:02.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Netlify Dev Crash Course | Easy Dev & Deploy',
#    'description': 'In this video we will experiment with the Netlify Dev which is part of the CLI and allows us to utilize the power of Netlify on your local machine\n\nRead More:\nhttps://www.netlify.com/products/dev/\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FMhVXOA54x8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/FMhVXOA54x8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/FMhVXOA54x8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/FMhVXOA54x8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/FMhVXOA54x8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 16,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'FMhVXOA54x8'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/5Km3Kx8IAJsLmwZH7-NxqaKMwEM"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLm1VZG82dzg3cmg0',
#   'snippet': {'publishedAt': '2019-04-17T17:23:39.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Sliding Sign In & Sign Up Form',
#    'description': "In this video we will be creating a sign in/up form with some animation using CSS and a tiny bit of JavaScript. Thanks to Florin Pop for creating this project and letting me create a video with it.\n\nFlorin's Website & Written Tutorial:\nhttps://www.florin-pop.com/blog/2019/03/double-slider-sign-in-up-form/\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nCode:\nhttps://codepen.io/FlorinPop17/pen/vPKWjd\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mUdo6w87rh4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/mUdo6w87rh4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/mUdo6w87rh4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/mUdo6w87rh4/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/mUdo6w87rh4/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 17,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'mUdo6w87rh4'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/GNOv3IEmfIQ-7QstUbifLtkBPNc"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLkdpUTJmTTMyNU8w',
#   'snippet': {'publishedAt': '2019-04-15T20:09:38.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'The Introvert Developer: The Good & Bad',
#    'description': 'In this discussion, we will talk about some of the good and bad of being an introvert developer.\n\nEduonix Easter Sale!! - http://bit.ly/Traversy_Media\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GiQ2fM325O0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/GiQ2fM325O0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/GiQ2fM325O0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/GiQ2fM325O0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/GiQ2fM325O0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 18,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'GiQ2fM325O0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/CHkJRnJ-GOq29UEVK8RNVNz0vyc"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLkxkRjJSY2VsUmcw',
#   'snippet': {'publishedAt': '2019-04-12T14:13:01.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': '15 VS Code Extensions For Front-End Developers in 2019',
#    'description': 'In this video I will go over and 15 of my favorite Visual Studio Code extensions for front end development in 2019. I will show you how each one works, settings and more\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LdF2RcelRg0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LdF2RcelRg0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LdF2RcelRg0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/LdF2RcelRg0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/LdF2RcelRg0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 19,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'LdF2RcelRg0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/6J3JRa5Txi81zEx_U-xRH9xqJ00"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmI2T2UycHVUZE1R',
#   'snippet': {'publishedAt': '2019-04-10T11:50:19.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'React File Uploader With Express (Using React Hooks)',
#    'description': 'In this project we will build a full stack file upload with React and Express. We will construct the UI with a Bootstrap elements and make them function\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nCode:\nhttps://github.com/bradtraversy/react_file_uploader\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/b6Oe2puTdMQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/b6Oe2puTdMQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/b6Oe2puTdMQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/b6Oe2puTdMQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/b6Oe2puTdMQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 20,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'b6Oe2puTdMQ'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/O6o1ihatJkQWUGlUQKMNip9kRbQ"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLnJhb09vV1U3REkw',
#   'snippet': {'publishedAt': '2019-04-07T13:04:16.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'My Top 10 Learning Methods For Self Taught Developers',
#    'description': 'In this video I want to discuss different ways of learning how to code and my experience with each one.\n\nSponsor: Freelancer Bundle (Use "brad25" for 25% off)\nhttps://studywebdevelopment.com/freelancing.html\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses:\nhttps://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/raoOoWU7DI0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/raoOoWU7DI0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/raoOoWU7DI0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/raoOoWU7DI0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/raoOoWU7DI0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 21,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'raoOoWU7DI0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/voErVmxA0FHjsyso3LeR5UU-cDs"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLkRaZzZVZlM1elln',
#   'snippet': {'publishedAt': '2019-04-04T14:58:42.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Pure CSS Hamburger Menu & Overlay',
#    'description': 'In this video we will create a landing page with a pure CSS responsive hamburger menu (No JavaScript) with a bit of animation using CSS transitions.\n\nCSS Starts - 6:27\nMenu CSS Starts - 15:40\n\nSponsor: Freelancer Bundle (Use "brad25" for 25% off)\nhttps://studywebdevelopment.com/freelancing.html\n\nCode:\nhttps://codepen.io/bradtraversy/pen/vMGBjQ\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nModern HTML & CSS From The Beginning:\nhttps://www.udemy.com/modern-html-css-from-the-beginning/?couponCode=TRAVERSYMEDIA\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DZg6UfS5zYg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/DZg6UfS5zYg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/DZg6UfS5zYg/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/DZg6UfS5zYg/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/DZg6UfS5zYg/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 22,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'DZg6UfS5zYg'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Czuj1vL31Ak3xrEsatZmeX9d7VM"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLlFTVG53c1pqMnlj',
#   'snippet': {'publishedAt': '2019-04-02T17:13:09.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Python Face Recognition Tutorial',
#    'description': 'In this video we will be using the Python Face Recognition library to do a few things\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nExamples & Docs:\nhttps://github.com/bradtraversy/face_recognition_examples\nhttps://github.com/ageitgey/face_recognition\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QSTnwsZj2yc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/QSTnwsZj2yc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/QSTnwsZj2yc/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/QSTnwsZj2yc/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/QSTnwsZj2yc/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 23,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'QSTnwsZj2yc'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/CcNTzd_maBLGCfjEBoWPsMM9oLQ"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjlFbW4yWVFORGww',
#   'snippet': {'publishedAt': '2019-03-28T17:40:33.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'VSCode In The Cloud - Setup a Remote Dev Environment',
#    'description': 'In this video we will setup a complete remote development environment using code-server on a Vultr cloud server.\n\ncode-server Repo:\nhttps://github.com/codercom/code-server\n\nVultr: Get $50 credit\nhttps://www.vultr.com/?ref=7992714-4F\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9Emn2YQNDl0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9Emn2YQNDl0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9Emn2YQNDl0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/9Emn2YQNDl0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/9Emn2YQNDl0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 24,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '9Emn2YQNDl0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Ji2TsC3zZnAfWeDTxoksF3B_-Wo"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLndxaE5vREU2cGI0',
#   'snippet': {'publishedAt': '2019-03-25T21:48:36.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'NestJS Crash Course',
#    'description': 'In this video we will explore the Nest JS Node.js framework which allows you to build fast and scalable server-side apps and APIs.\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nCode:\nhttps://github.com/bradtraversy/nestjs_rest_api\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nNest JS Docs:\nhttps://docs.nestjs.com\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wqhNoDE6pb4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/wqhNoDE6pb4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/wqhNoDE6pb4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/wqhNoDE6pb4/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/wqhNoDE6pb4/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 25,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'wqhNoDE6pb4'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/e9q5RS-RWdAJ7V7tH5KmhAMUEf4"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmZMRmF5b2VBelFB',
#   'snippet': {'publishedAt': '2019-03-22T17:39:13.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Overwhelmed With Web Development Technology',
#    'description': 'In this video I want to talk about being overwhelmed with the vast amount of technology that web development includes (Languages, frameworks, libraries, etc)\n\nSponsor: Freelancer Bundle (Use "brad25" for 25% off)\nhttps://studywebdevelopment.com/freelancing.html\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fLFayoeAzQA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/fLFayoeAzQA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/fLFayoeAzQA/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/fLFayoeAzQA/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/fLFayoeAzQA/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 26,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'fLFayoeAzQA'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/hcLXPgEe-WywD7SPqaRwIPqGBjU"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLndXV05yQU5OTzFr',
#   'snippet': {'publishedAt': '2019-03-20T11:16:38.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Full Screen Responsive Image Slider | No Libraries',
#    'description': 'In this video we will create a responsive image & content slider using just HTML, CSS transitions and a little bit of ES6 JavaScript.\n\nSponsor: DevMountain Bootcamp\nhttps://goo.gl/6q0dEa\n\nCode:\nhttps://codepen.io/bradtraversy/pen/oVPBaa\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nWebsite & Udemy Courses\nhttp://www.traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wWWNrANNO1k/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/wWWNrANNO1k/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/wWWNrANNO1k/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/wWWNrANNO1k/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/wWWNrANNO1k/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 27,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'wWWNrANNO1k'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/LWCeog6PN0tihLgKLpfeEooceyM"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjVsVlFnWnpMTUhj',
#   'snippet': {'publishedAt': '2019-03-16T16:43:10.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Vuex Crash Course | State Management',
#    'description': 'In this video we will build an application using Vue.js with the Vuex state management library.\n\nCheck Out My Sponsor - Monday.com\nhttp://go.thoughtleaders.io/955920190318\n\nCode:\nhttps://github.com/bradtraversy/vuex_todo_manager\n\n💖 Become a Patron: Show support & get perks!\nhttp://www.patreon.com/traversymedia\n\nVue.js Crash Course:\nhttps://www.youtube.com/watch?v=Wy9q22isx3U&t=1217s\n\nWebsite & Udemy Courses:\nhttps://traversymedia.com\n\nFollow Traversy Media:\nhttps://www.facebook.com/traversymedia\nhttps://www.twitter.com/traversymedia\nhttps://www.instagram.com/traversymedia',
# ...
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 695,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '-YBsEFfvew4'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/nFr5KWWLZv3CWLO7z2-4E8iN2sY"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjJsUXhTaVVMNHpr',
#   'snippet': {'publishedAt': '2013-02-22T15:17:44.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Install Joomla 2.5 on Xampp',
#    'description': 'Quick video on how to install Joomla 2.5 on a Xampp server',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2lQxSiUL4zk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/2lQxSiUL4zk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/2lQxSiUL4zk/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/2lQxSiUL4zk/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/2lQxSiUL4zk/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 696,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '2lQxSiUL4zk'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/qeZj7R0hfRrXfHkPJKk0zb-zJAM"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLm1OMmpUTEctZHNJ',
#   'snippet': {'publishedAt': '2013-02-22T15:14:04.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Remove Phoca Gallery 3.2.3 Footer Text',
#    'description': 'Please donate to http://phoca.cz if you remove this footer. Visit http://www.techguywebsolutions.com/remove-powered-by-phoca-gallery-version-3.2.html for more info\nIF YOU ARE LOOKING FOR PHOCA VERSION 3.2.5 or 4.0, SEE HERE - http://www.techguywebsolutions.com/remove-phoca-gallery-footer-version-3.2.5.html',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mN2jTLG-dsI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/mN2jTLG-dsI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/mN2jTLG-dsI/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/mN2jTLG-dsI/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/mN2jTLG-dsI/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 697,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'mN2jTLG-dsI'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/vENp8_OEiAjI90SW6z3NCBoeSJA"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjl1dUctZnQzTkUw',
#   'snippet': {'publishedAt': '2012-10-19T16:01:06.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Connect Joomla Site With Dreamweaver',
#    'description': 'Simple tutorial on how to connect Dreamweaver to a Joomla website in order to program a Joomla template.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9uuG-ft3NE0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9uuG-ft3NE0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9uuG-ft3NE0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/9uuG-ft3NE0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/9uuG-ft3NE0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 698,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '9uuG-ft3NE0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/djahcuqpqLs2tMhn7e9zy6So7d8"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjFsQk5oVmpId0Qw',
#   'snippet': {'publishedAt': '2012-06-14T13:14:41.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'PHP Arrays & Foreach Loops',
#    'description': 'Quick video on simple php arrays and looping through them with foreach()',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1lBNhVjHwD0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/1lBNhVjHwD0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/1lBNhVjHwD0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/1lBNhVjHwD0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/1lBNhVjHwD0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 699,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '1lBNhVjHwD0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/QI87Pjb3-N1Is5TbHp0-KH9M_l0"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLm84LUtCWVcybFVZ',
#   'snippet': {'publishedAt': '2012-06-07T18:06:14.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Use A Custom Font On Your Website Using CSS',
#    'description': 'Quick tutorial on how to use a custom font on your html website using css.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o8-KBYW2lUY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/o8-KBYW2lUY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/o8-KBYW2lUY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/o8-KBYW2lUY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/o8-KBYW2lUY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 700,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'o8-KBYW2lUY'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/pReyjF9nzrzAKVm6f3d59gGg0K4"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmFBb1lhWnpXUmd3',
#   'snippet': {'publishedAt': '2012-06-01T16:51:14.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Import & Export A MySQL Database',
#    'description': 'This is a simple tutorial on how to transfer your MySQL database to a new server or new account.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aAoYaZzWRgw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/aAoYaZzWRgw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/aAoYaZzWRgw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/aAoYaZzWRgw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/aAoYaZzWRgw/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 701,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'aAoYaZzWRgw'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/HaU2x0WAPX4QAEan36QQMgtmJJE"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLm55VE1DV3FGUERv',
#   'snippet': {'publishedAt': '2012-05-11T19:53:53.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Connect Dreamweaver to your website',
#    'description': 'Manage your website through Dreamweaver',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nyTMCWqFPDo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/nyTMCWqFPDo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/nyTMCWqFPDo/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/nyTMCWqFPDo/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/nyTMCWqFPDo/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 702,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'nyTMCWqFPDo'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/RIfaOWX_doGgO_NOSc_waUnjsD8"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmdsTnZVMWpJZENR',
#   'snippet': {'publishedAt': '2011-05-27T14:52:38.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Create a Joomla Blog',
#    'description': 'THIS IS FOR A JOOMLA 1.5 SITE. FOR 2.5, SEE - http://www.youtube.com/watch?v=CBW12hKcqrY\nTutorial on how to add a blog to a Joomla 1.5 website with commenting functionality. Agian, this is Joomla 1.5 but 2.5 and 3.0 are similar. For Joomla related development, visit http://www.techguywebsolutions.com',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/glNvU1jIdCQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/glNvU1jIdCQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/glNvU1jIdCQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/glNvU1jIdCQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/glNvU1jIdCQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 703,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'glNvU1jIdCQ'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rFliWzY0xljl_p1t_T86tv2MwoQ"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLnpJTlhidG5UVW1V',
#   'snippet': {'publishedAt': '2011-05-26T16:56:06.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Adding and linking an article in Joomla',
#    'description': 'Tutorial on adding an article to your joomla site ans also linking the article to a menu',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zINXbtnTUmU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zINXbtnTUmU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/zINXbtnTUmU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/zINXbtnTUmU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/zINXbtnTUmU/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 704,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'zINXbtnTUmU'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/LrlDMPPOej7Q_k6MHMipuiaxSoA"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLnczVHFvVGNoeXlZ',
#   'snippet': {'publishedAt': '2010-08-03T18:00:21.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Create and connect to FTP',
#    'description': 'How to create an FTP account in cPanel then connect to it via Filezilla',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w3TqoTchyyY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/w3TqoTchyyY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/w3TqoTchyyY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 705,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'w3TqoTchyyY'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ui40AUwo1BnYckDt1PjO837U-Y4"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmlDUlpTcXFfNGk0',
#   'snippet': {'publishedAt': '2010-08-03T17:26:30.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Install & Uninstall Joomla Extensions',
#    'description': 'How to add and remove 3rd party extensions to and from your Joomla 1.5 website - This is a very old tutorial. I am sorry for the horrible sound :)',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iCRZSqq_4i4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/iCRZSqq_4i4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/iCRZSqq_4i4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 706,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'iCRZSqq_4i4'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ZGD-5fHcoiOPrFc9H8Vl26zw1Jk"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjR3S1lVckV6LUlZ',
#   'snippet': {'publishedAt': '2010-08-03T16:49:39.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Create a MySQL database in cPanel',
#    'description': 'Step by step instructions on creating a MySQL database from within cPanel',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4wKYUrEz-IY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/4wKYUrEz-IY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/4wKYUrEz-IY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 707,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '4wKYUrEz-IY'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/1NY7DG24vu4fJfNOVs0CN1dx1Tw"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLmJWQ2VyRWJoNDhV',
#   'snippet': {'publishedAt': '2010-08-03T15:49:45.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Adding & Checking Emails in cPanel',
#    'description': 'How to create an email account and also how to check your emails on a cpanel host',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bVCerEbh48U/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/bVCerEbh48U/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/bVCerEbh48U/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 708,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'bVCerEbh48U'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/h3yAl0CDMueE-EuJXwDNH3XzDtM"',
#   'id': 'VVUyOWp1OGJJUEg1YXM4T0duUXp3SnlBLjd5ZzdfX1VTbjZN',
#   'snippet': {'publishedAt': '2010-08-03T15:26:44.000Z',
#    'channelId': 'UC29ju8bIPH5as8OGnQzwJyA',
#    'title': 'Changing Your DNS/Nameservers',
#    'description': 'This is a quick tutorial on how to change your dns to pint to a new hosting account.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7yg7__USn6M/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/7yg7__USn6M/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/7yg7__USn6M/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Traversy Media',
#    'playlistId': 'UU29ju8bIPH5as8OGnQzwJyA',
#    'position': 709,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '7yg7__USn6M'}}}]

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
len(video_ids)
# Out:
# 710

# %%
stats = get_videos_stats(video_ids)
len(stats)
# Out:
# 710

# %%
most_viewed = sorted(stats, key=lambda x:int(x['statistics']['viewCount']), reverse=True)

# %%
counts = [parse_count(video) for video in most_viewed]
len(counts)
# Out:
# 710

# %%
df_count = pd.DataFrame(data = counts , columns=['videoId','viewCount'])
df_count.head()
# Out:
#        videoId viewCount
# 0  Wm6CUkswsNw   1785436
# 1  UB1O30fR-EE   1495585
# 2  vEROU2XtPR8   1295059
# 3  pWbMrx5rVBE   1161988
# 4  yfoY53QXEnI   1033257

# %%
df_count["viewCount"] = df_count["viewCount"].astype("float")

# %%
df_count.sort_values(by=['viewCount'],ascending=[False]).head()
# Out:
#        videoId  viewCount
# 0  Wm6CUkswsNw  1785436.0
# 1  UB1O30fR-EE  1495585.0
# 2  vEROU2XtPR8  1295059.0
# 3  pWbMrx5rVBE  1161988.0
# 4  yfoY53QXEnI  1033257.0

# %%
publish_dates = [parse_publish_date(video) for video in videos]
len(publish_dates)
# Out:
# 710

# %%
df_date = pd.DataFrame(data = publish_dates , columns=['videoId','publishedAt','title'])
df_date.head()
# Out:
#        videoId         publishedAt  \
# 0  BwhTKJFpKSw 2019-05-30 16:16:41
# 1  6H1wftPS0oo 2019-05-27 12:54:56
# 2  P7t13SGytRk 2019-05-21 13:11:13
# 3  zRo2tvQpus8 2019-05-19 16:01:23
# 4  8jP4xpga6yY 2019-05-15 15:39:30
#
#                                                title
# 0                           Quick & Easy CSS Loaders
# 1                     Build a PWA With Vue & Ionic 4
# 2  Build a Netflix Landing Page Clone with HTML, ...
# 3               TypeScript Setup With Node & Express
# 4                      Getting Started With Three.js

# %%
dfd = pd.merge(df_date, df_count, on='videoId', how='inner')
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 710 entries, 0 to 709
# Data columns (total 4 columns):
# videoId        710 non-null object
# publishedAt    710 non-null datetime64[ns]
# title          710 non-null object
# viewCount      710 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 27.7+ KB

# %%
dfd.sort_values(by=['publishedAt'],ascending=[False]).head()
# Out:
#        videoId         publishedAt  \
# 0  BwhTKJFpKSw 2019-05-30 16:16:41
# 1  6H1wftPS0oo 2019-05-27 12:54:56
# 2  P7t13SGytRk 2019-05-21 13:11:13
# 3  zRo2tvQpus8 2019-05-19 16:01:23
# 4  8jP4xpga6yY 2019-05-15 15:39:30
#
#                                                title  viewCount
# 0                           Quick & Easy CSS Loaders    19029.0
# 1                     Build a PWA With Vue & Ionic 4    18545.0
# 2  Build a Netflix Landing Page Clone with HTML, ...    47745.0
# 3               TypeScript Setup With Node & Express    21607.0
# 4                      Getting Started With Three.js    43375.0

# %%
df_count_date = pd.merge(df_count, df_date, how='inner', on='videoId')
df_count_date.head(10)
# Out:
#        videoId  viewCount         publishedAt  \
# 0  Wm6CUkswsNw  1785436.0 2016-12-25 16:11:06
# 1  UB1O30fR-EE  1495585.0 2017-07-17 14:38:43
# 2  vEROU2XtPR8  1295059.0 2016-03-24 16:18:08
# 3  pWbMrx5rVBE  1161988.0 2016-09-04 20:47:56
# 4  yfoY53QXEnI  1033257.0 2017-07-19 15:01:36
# 5  KhzGSHNhnbI   925600.0 2017-07-07 16:51:18
# 6  SWYqp7iY_Tc   922057.0 2017-02-05 20:03:20
# 7  Zftx68K-1D4   884527.0 2017-12-06 12:01:41
# 8  9hDKfBKuXjI   818926.0 2016-12-20 16:58:20
# 9  jV8B24rSN5o   783555.0 2017-08-01 16:03:58
#
#                                              title
# 0  Build An HTML5 Website With A Responsive Layout
# 1         HTML Crash Course For Absolute Beginners
# 2            JavaScript Fundamentals For Beginners
# 3                            MongoDB In 30 Minutes
# 4          CSS Crash Course For Absolute Beginners
# 5                            Angular In 60 Minutes
# 6          Git & GitHub Crash Course For Beginners
# 7      Web Development in 2018 - A Practical Guide
# 8      Web Development In 2017 - A Practical Guide
# 9                     CSS Grid Layout Crash Course

# %%
df_count_date.to_excel('c:\\aab\\excel\\traversy media.xlsx')
