# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/BBB_development')
conbb = engine.connect()
    
data_path = '../data/'
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Inquiry

# %%
sql = '''
SELECT title, code, name, views
FROM songs
JOIN artists ON artist_id = artists.id
WHERE code <> '' 
AND views BETWEEN 900000000 AND 999999999
ORDER BY views DESC
'''
songs = pd.read_sql(sql,conbb)
songs
# Out:
#                     title         code  \
# 0              Wide Awake  k0BWlvnBmIE
# 1     The Final Countdown  9jK-NcRmVcw
# 2              Poker Face  bESGLojNYSo
# 3          One More Night  fwK7ggA3-bU
# 4                Rockstar  UceaB4D0jpo
# 5                   Happy  ZbZSe6N_BXs
# 6      Losing My Religion  xwtdhWltSIg
# 7        Story of My Life  W-TE_Ys4iwM
# 8          Wind of Change  n4RjJKxsamQ
# 9                 Friends  jzD_yyEcp0M
# 10  Every Breath You Take  OMOGaugKpzs
# 11                 Psycho  au2n7VVGv_c
# 12         Scream & Shout  kYtGl1dX5qI
# 13          Old Town Road  r7qovpFAGrQ
# 14     Give Me Everything  EPo5wWmKEaI
# 15     Gangsta's Paradise  fPO76Jlnz6c
# 16             Part of Me  uuwfgXD8qV8
# 17  The One That Got Away  Ahha3Cqe_fk
#
#                                            name      views
# 0                                    Katy Perry  978905138
# 1                                        Europe  976625941
# 2                                     Lady Gaga  969457520
# 3                                      Maroon 5  969243674
# 4               Post Malone featuring 21 Savage  967137041
# 5                             Pharrell Williams  961960512
# 6                                        R.E.M.  942360204
# 7                                 One Direction  942134346
# 8                                     Scorpions  939516354
# 9                                    Marshmello  935557368
# 10                                   The Police  934811884
# 11                                  Post Malone  932067922
# 12           will.i.am featuring Britney Spears  922982793
# 13                                    Lil Nas X  916995947
# 14  Pitbull featuring Ne-Yo, Afrojack and Nayer  916633761
# 15                        Coolio featuring L.V.  910310715
# 16                                   Katy Perry  906482700
# 17                                   Katy Perry  903778776

# %%
sr = songs['code']
vids= sr.values.tolist()
vids
# Out:
# ['W-TE_Ys4iwM',
#  'uuwfgXD8qV8',
#  '9jK-NcRmVcw',
#  'au2n7VVGv_c',
#  'kYtGl1dX5qI',
#  'jzD_yyEcp0M',
#  'bESGLojNYSo',
#  'UceaB4D0jpo',
#  'n4RjJKxsamQ',
#  'OMOGaugKpzs',
#  'Ahha3Cqe_fk',
#  'EPo5wWmKEaI',
#  'pa14VNsdSYM',
#  'xwtdhWltSIg']
