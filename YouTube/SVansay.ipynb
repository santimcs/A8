# %%
#%load_ext nb_black
import pandas as pd
from datetime import datetime, timedelta
#from google.oauth2 import service_account
from apiclient.discovery import build

YOUTUBE_DEVELOPER_KEY = "AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys"
youtube = build("youtube", "v3", developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_channel(channel_name):
    return (
        youtube.search()
        .list(q=channel_name, type="channel", part="id,snippet")
        .execute()["items"][0]
    )


def get_videos(channel_id, part="id,snippet", limit=10):
    res = youtube.channels().list(id=channel_id, part="contentDetails").execute()
    playlist_id = res["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    videos = []
    next_page_token = None

    while 1:
        res = (
            youtube.playlistItems()
            .list(
                playlistId=playlist_id,
                part=part,
                maxResults=min(limit, 50),
                pageToken=next_page_token,
            )
            .execute()
        )
        videos += res["items"]
        next_page_token = res.get("nextPageToken")

        if next_page_token is None or len(videos) >= limit:
            break

    return videos


def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = (
            youtube.videos()
            .list(id=",".join(video_ids[i : i + 50]), part="statistics")
            .execute()
        )
        stats += res["items"]

    return stats


def parse_count(video):
    return video["id"], video["statistics"]["viewCount"]


def parse_publish_date(video):
    return (
        video["snippet"]["resourceId"]["videoId"],
        datetime.strptime(video["snippet"]["publishedAt"], "%Y-%m-%dT%H:%M:%S.000Z"),
        video["snippet"]["title"],
    )

# %%
channel_name = "SVansay"
channel_id = get_channel(channel_name)["id"]["channelId"]
channel_id
# Out:
# 'UC3KdZe9VSKpEZZELEETtEzQ'

# %%
videos = get_videos(channel_id, limit=6500)
videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': 'JfE6cvKOtpfJeHw1MnHHwWYjI8w',
#   'id': 'VVUzS2RaZTlWU0twRVpaRUxFRVR0RXpRLlYwYVNPOW1KQXJj',
#   'snippet': {'publishedAt': '2022-01-23T00:26:45Z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title': 'Down Home  (1963)  -  RICKY NELSON  -  Lyrics',
#    'description': "Down Home  (1963)  -  RICKY NELSON  -  Lyrics\nDown home, oh, down home\nThere used to be rivers and trees\nFresh bread every single morning\nAnd sweet magnolia in the breeze\n\nOh, fishing lines and young dreams\nOh I hear them calling to me\nBut there's no way to get down home\n'Cause down home's just a memory\n\nWish I could leave this big town\nCity living ain't living to me\nBut there's no way to get down home\nNo you can't retrieve it\n'Cause once you leave it\n\nOh, down home's just a memory\nDown home\nOh, down home \n\nSVansay (Vanhxay)",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/V0aSO9mJArc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/V0aSO9mJArc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/V0aSO9mJArc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SVansay',
#    'playlistId': 'UU3KdZe9VSKpEZZELEETtEzQ',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'V0aSO9mJArc'},
#    'videoOwnerChannelTitle': 'SVansay',
#    'videoOwnerChannelId': 'UC3KdZe9VSKpEZZELEETtEzQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'WKcSpsZyh1pGlWH9ahI9kj_3mYs',
#   'id': 'VVUzS2RaZTlWU0twRVpaRUxFRVR0RXpRLnhGaEs1NV9QSjJV',
#   'snippet': {'publishedAt': '2021-12-29T21:58:20Z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title
z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title': 'Secret Love  (1963)  -  CLIFF RICHARD  -  Lyrics',
#    'description': "#oldies\nSecret Love  (1963)  -  CLIFF RICHARD  -  Lyrics\nOnce I had a secret love\nThat lived within the heart of me\nAll too soon my secret love\nBecame impatient to be free\n\nSo I told a friendly star\nThe way that dreamers often do\nJust how wonderful you are\nAnd why I'm so in love with you\n\nNow I shout it from the highest hill\nEven told the golden daffodil\nAt last my heart's an open door\nAnd my secret love's no secret anymore\n\n\n\nSVansay (Vanhxay)",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dgWu942t3-g/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/dgWu942t3-g/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/dgWu942t3-g/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/dgWu942t3-g/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/dgWu942t3-g/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'SVansay',
#    'playlistId': 'UU3KdZe9VSKpEZZELEETtEzQ',
#    'position': 20,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'dgWu942t3-g'},
#    'videoOwnerChannelTitle': 'SVansay',
#    'videoOwnerChannelId': 'UC3KdZe9VSKpEZZELEETtEzQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'neKMCq_lZFFibHvSxviThBTdrFc',
#   'id': 'VVUzS2RaZTlWU0twRVpaRUxFRVR0RXpRLmpfZWZ3MS0zT3ZV',
#   'snippet': {'publishedAt': '2020-11-15T08:20:40Z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title': 'Morning Has Broken  (1971)  -  CAT STEVENS  -  Lyrics',
#    'description': "#oldies\nMorning Has Broken  (1971)  -  CAT STEVENS  -  Lyrics\nMorning has broken like the first morning\nBlackbird has spoken like the first bird\nPraise for the singing, praise for the morning\nPraise for them springing fresh from the world\n\nSweet the rains new fall, sunlit from Heaven\nLike the first dewfall on the first grass\nPraise for the sweetness of the wet garden\nSprung in completeness where His feet pass\n\nMine is the sunlight, mine is the morning\nBorn of the one light, Eden saw play\nPraise with elation, praise every morning\nGod's recreation of the new day\n\nMorning has broken like the first morning\nBlackbird has spoken like the first bird\nPraise for the singing, praise for the morning\nPraise for them springing fresh from the world\n\n\nSVansay (Vanhxay)",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j_efw1-3OvU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/j_efw1-3OvU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/j_efw1-3OvU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/j_efw1-3OvU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/j_efw1-3OvU/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'SVansay',
#    'playlistId': 'UU3KdZe9VSKpEZZELEETtEzQ',
#    'position': 21,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'j_efw1-3OvU'},
#    'videoOwnerChannelTitle': 'SVansay',
#    'videoOwnerChannelId': 'UC3KdZe9VSKpEZZELEETtEzQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '3Wp_IIDhYhfTKrvOHGi8SlslCqM',
#   'id': 'VVUzS2RaZTlWU0twRVpaRUxFRVR0RXpRLlByQTdVU3llWFJ3',
#   'snippet': {'publishedAt': '2020-11-07T09:51:16Z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title': 'Try To Remember  (1965)  -  THE BROTHERS FOUR  -  Lyrics',
#    'description': "# oldies\nTry To Remember  (1965)  -  THE BROTHERS FOUR  -  Lyrics\nTry to remember the kind of September\nWhen life was slow and oh, so mellow\nTry to remember the kind of September\nWhen grass was green and grain was yellow\n\nTry to remember the kind of September\nWhen you were a tender and callow fellow\nTry to remember and if you remember\nThen follow, follow\n\nTry to remember when life was so tender\nThat no one wept, except the willow\nTry to remember the time of September\nWhen love was an ember about to billow\nTry to remember and if you remember\nThen follow, follow\n\nDeep in December, it's nice to remember\nAlthough you know the snow will follow\nDeep in December, it's nice to remember\nThe fire of September that made us mellow\nDeep in December our hearts should remember\nAnd follow, follow, follow\n\n\nSVansay (Vanhxay)",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PrA7USyeXRw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/PrA7USyeXRw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/PrA7USyeXRw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/PrA7USyeXRw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/PrA7USyeXRw/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'SVansay',
#    'playlistId': 'UU3KdZe9VSKpEZZELEETtEzQ',
#    'position': 22,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'PrA7USyeXRw'},
#    'videoOwnerChannelTitle': 'SVansay',
#    'videoOwnerChannelId': 'UC3KdZe9VSKpEZZELEETtEzQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'DQhfFveD6GCvtOEioVmm6QDvzQg',
#   'id': 'VVUzS2RaZTlWU0twRVpaRUxFRVR0RXpRLjlGaElYYVlMY1Bj',
#   'snippet': {'publishedAt': '2020-10-30T09:47:46Z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title
},
#    'videoOwnerChannelTitle': 'SVansay',
#    'videoOwnerChannelId': 'UC3KdZe9VSKpEZZELEETtEzQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'Q5QdJsEY_jdWb8u-WstYT9KBTt8',
#   'id': 'VVUzS2RaZTlWU0twRVpaRUxFRVR0RXpRLjBNUFpoZk1nNWRn',
#   'snippet': {'publishedAt': '2010-05-26T18:54:59Z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title': "Le loup et l'agneau de Jean de la Fontaine",
#    'description': "Le loup et l'agneau.  Cité par Edward CE1",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0MPZhfMg5dg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/0MPZhfMg5dg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/0MPZhfMg5dg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SVansay',
#    'playlistId': 'UU3KdZe9VSKpEZZELEETtEzQ',
#    'position': 278,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '0MPZhfMg5dg'},
#    'videoOwnerChannelTitle': 'SVansay',
#    'videoOwnerChannelId': 'UC3KdZe9VSKpEZZELEETtEzQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'ddn6Htx-usc1tZOZTsrIFgl_q90',
#   'id': 'VVUzS2RaZTlWU0twRVpaRUxFRVR0RXpRLm55ZnVCeXE0RUFV',
#   'snippet': {'publishedAt': '2009-12-01T21:42:14Z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title': "Edward Singhavara's first hunt.",
#    'description': 'Les Invalides, Paris, France.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nyfuByq4EAU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/nyfuByq4EAU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/nyfuByq4EAU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/nyfuByq4EAU/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'SVansay',
#    'playlistId': 'UU3KdZe9VSKpEZZELEETtEzQ',
#    'position': 279,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'nyfuByq4EAU'},
#    'videoOwnerChannelTitle': 'SVansay',
#    'videoOwnerChannelId': 'UC3KdZe9VSKpEZZELEETtEzQ'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'OUFPLfMRgce1_cgOJoSEm6RPukA',
#   'id': 'VVUzS2RaZTlWU0twRVpaRUxFRVR0RXpRLk0zY2VXc0Z1Qm9r',
#   'snippet': {'publishedAt': '2009-10-29T21:18:36Z',
#    'channelId': 'UC3KdZe9VSKpEZZELEETtEzQ',
#    'title': 'Edward Singhavara at 4',
#    'description': 'by S.Vansay',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/M3ceWsFuBok/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/M3ceWsFuBok/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/M3ceWsFuBok/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SVansay',
#    'playlistId': 'UU3KdZe9VSKpEZZELEETtEzQ',
#    'position': 280,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'M3ceWsFuBok'},
#    'videoOwnerChannelTitle': 'SVansay',
#    'videoOwnerChannelId': 'UC3KdZe9VSKpEZZELEETtEzQ'}}]

# %%
video_ids = list(map(lambda x: x["snippet"]["resourceId"]["videoId"], videos))
len(video_ids)
# Out:
# 281

# %%
stats = get_videos_stats(video_ids)
len(stats)
# Out:
# 281

# %%
most_viewed = sorted(
    stats, key=lambda x: int(x["statistics"]["viewCount"]), reverse=True
)

# %%
counts = [parse_count(video) for video in most_viewed]
len(counts)
# Out:
# 281

# %%
df_count = pd.DataFrame(data=counts, columns=["videoId", "viewCount"])
df_count.head()
# Out:
#        videoId viewCount
# 0  9IWxocGm21U  14441427
# 1  5GWDgirgsq4  14427359
# 2  AlSjx6F5Pl8  11303578
# 3  IVxFbpMhn64   9255196
# 4  vaX0iqyzK7Q   8836617

# %%
df_count["viewCount"] = df_count["viewCount"].astype("float")

# %%
df_count.sort_values(by=["viewCount"], ascending=[False]).head()
# Out:
#        videoId   viewCount
# 0  9IWxocGm21U  14441427.0
# 1  5GWDgirgsq4  14427359.0
# 2  AlSjx6F5Pl8  11303578.0
# 3  IVxFbpMhn64   9255196.0
# 4  vaX0iqyzK7Q   8836617.0

# %%
publish_dates = [parse_publish_date(video) for video in videos]
len(publish_dates)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6612/127792961.py in <module>
# ----> 1 publish_dates = [parse_publish_date(video) for video in videos]
#       2 len(publish_dates)
#
# ~\AppData\Local\Temp/ipykernel_6612/127792961.py in <listcomp>(.0)
# ----> 1 publish_dates = [parse_publish_date(video) for video in videos]
#       2 len(publish_dates)
#
# ~\AppData\Local\Temp/ipykernel_6612/2880592691.py in parse_publish_date(video)
#      54     return (
#      55         video["snippet"]["resourceId"]["videoId"],
# ---> 56         datetime.strptime(video["snippet"]["publishedAt"], "%Y-%m-%dT%H:%M:%S.000Z"),
#      57         video["snippet"]["title"],
#      58     )
#
# C:\ProgramData\Anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# C:\ProgramData\Anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '2022-01-23T00:26:45Z' does not match format '%Y-%m-%dT%H:%M:%S.000Z'

# %%
df_date = pd.DataFrame(data=publish_dates, columns=["videoId", "publishedAt", "title"])
df_date.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6612/782925079.py in <module>
# ----> 1 df_date = pd.DataFrame(data=publish_dates, columns=["videoId", "publishedAt", "title"])
#       2 df_date.head()
#
# NameError: name 'publish_dates' is not defined

# %%
dfd = pd.merge(df_date, df_count, on="videoId", how="inner")
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 243
# Data columns (total 4 columns):
# videoId        244 non-null object
# publishedAt    244 non-null datetime64[ns]
# title          244 non-null object
# viewCount      244 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 9.5+ KB

# %%
dfd.sort_values(by=["publishedAt"], ascending=[False]).head()
# Out:
#        videoId         publishedAt  \
# 0  Z5pfG2KXz4o 2019-12-24 18:19:29
# 1  c3iSNTiBq8Q 2019-12-21 18:43:29
# 2  JUqPXXCUOns 2019-11-01 22:59:31
# 3  Ud4OK1lwt50 2019-10-21 09:33:11
# 4  2eXDr8KIM64 2019-10-18 22:51:00
#
#                                                title  viewCount
# 0  Tequila  (1961)  -  THE VENTURES  -  Music  (G...     1335.0
# 1         Feelings  (1978)  -  PERRY COMO  -  Lyrics     2833.0
# 2  Where Is Your Heart  (1961)  -  CONNIE FRANCIS...    14553.0
# 3  Unchained Melody  (1965)  -  RIGHTEOUS BROTHER...    17514.0
# 4   Flaming Star (1960)  -  ELVIS PRESLEY  -  Lyrics     7502.0

# %%
df_count_date = pd.merge(df_count, df_date, how="inner", on="videoId")
# df_count_date.to_excel('c:\\aab\\data\\svansay.xlsx',encoding='utf-8')
songs = df_count_date.sort_values(by=["viewCount"], ascending=[False])
songs.title.head(36)
# Out:
# 0     Tennessee Waltz ( 1959 ) - CONNIE FRANCIS - Ly...
# 1                               Aubrey - BREAD - Lyrics
# 2     Cotton Fields (1969)  -  CREEDENCE CLEARWATER ...
# 3     Sad Movies ( Make me cry ) - SUE THOMPSON - Wi...
# 4     The End Of The World - SKEETER DAVIS - With ly...
# 5     The Way It Used To Be ( 1969 ) - ENGELBERT HUM...
# 6     Judy Judy Judy ( 1963 ) - JOHNNY TILLOTSON - L...
# 7      Evergreen Tree ( 1960 ) - CLIFF RICHARD - Lyrics
# 8                   Diana ( 1957 ) - PAUL ANKA - Lyrics
# 9     Why Do I Love You So ( 1960 ) - JOHNNY TILLOTS...
# 10    You Don't Have To Say You Love Me ( 1966 ) - D...
# 11    Killing Me Softly With Her Song ( 1973 ) - PER...
# 12             More Than I Can Say - LEO SAYER - Lyrics
# 13    Oh! Suzanna ( Rare ) ( 1848's Cover by CONNIE ...
# 14           It's Impossible - PERRY COMO - With lyrics
# 15    No More ( Another version. Rare ) 1973 - ELVIS...
# 16    Summer Kisses Winter Tears ( 1960 ) - ELVIS PR...
# 17      Rhythm Of The Rain - THE CASCADES - With lyrics
# 18    Sealed With A Kiss ( 1962 ) - BRIAN HYLAND - L...
# 19      Look for a star ( 1960 ) - Garry Miles - Lyrics
# 20     Changing Partners ( 1953 ) - PATTI PAGE - Lyrics
# 21      Greenfields (1960) - THE BROTHERS FOUR - Lyrics
# 22    The Girl Of My Best Friend ( 1960 ) - ELVIS PR...
# 23         Angel ( RARE ) 1962 - ELVIS PRESLEY - Lyrics
# 24    You Mean Everything To Me - NEIL SEDAKA - With...
# 25      Poor Boy ( Rare ) - CLIFF RICHARD - With lyrics
# 26    Tous Les Garçons Et Les Filles ( 1962 ) - FRAN...
# 27    Love Me With All Of Your Heart ( 1970 ) - ENGE...
# 28    Whispering Pines ( 1959 )  -  JOHNNY HORTON  -...
# 29               Pretend ( 1960 ) - BRENDA LEE - Lyrics
# 30    Send Me The Pillow That You Dream On ( 1957 ) ...
# 31      Outsider ( Rare ) - CLIFF RICHARD - With lyrics
# 32    His Lastest Flame ( 1961 ) - ELVIS PRESLEY - L...
# 33    The Last Leaf ( Rare ) 1963 - The Cascades - w...
# 34              Spanish Harlem - CLIFF RICHARD - Lyrics
# 35    Raindrops Keep Falling On My Head ( 1969 ) - B...
# Name: title, dtype: object

# %%
artist = 'THE CASCADES'
print(artist)
filter = songs[songs['title'].str.contains(artist)]
filter.head(13)
# Out:
# THE CASCADES
#         videoId  viewCount         publishedAt  \
# 17  pt57gA1_W7c  1438498.0 2014-04-19 07:43:04
# 37  ekYqiZvfi90   514870.0 2015-02-11 12:08:06
#
#                                               title
# 17  Rhythm Of The Rain - THE CASCADES - With lyrics
# 37  Dreamin' ( Rare ) 1960s - THE CASCADES - Lyrics

# %%
artist = 'Engelbert Humperdinck'
print(artist)
filter2 = songs[songs['title'].str.contains(artist)]
filter2.head(13)
# Out:
# Engelbert Humperdinck
#          videoId  viewCount         publishedAt  \
# 89   EAM2ajaMx3I    95078.0 2017-02-23 23:36:57
# 211  4HUcr1AEHms     9797.0 2019-08-16 09:36:12
#
#                                                  title
# 89   There Goes My Everything ( 1967 ) -  Engelbert...
# 211  A Time For Us (Love Theme from Romeo & Juliet)...

# %%
sr = filter['videoId'].head(13)
sr.shape
# Out:
# (7,)

# %%
vids= sr.values.tolist()
vids
# Out:
# ['pKqfYRpc_9U',
#  'K81MZplOnfU',
#  'u5KV1_lFwQo',
#  '036Vm1d2FEI',
#  'KsdTvFpggG4',
#  'NjzxRRA1_4s',
#  'B1fmyPVR078']

# %%
filter.to_excel('c:\\aab\\data\\connie_francis.xlsx',encoding='utf-8')
