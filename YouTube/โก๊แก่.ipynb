# %%
import pandas as pd
from datetime import datetime, timedelta
from apiclient.discovery import build
YOUTUBE_DEVELOPER_KEY = 'AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys'
youtube = build('youtube', 'v3', developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_channel(channel_name):
    return youtube.search().list(q=channel_name, type='channel', part='id,snippet').execute()['items'][0]


def get_videos(channel_id, part='id,snippet', limit=10):
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part=part, 
                                           maxResults=min(limit, 50),
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None or len(videos) >= limit:
            break

    return videos

def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
        
    return stats

def parse_count(video):
    return video['id'],video['statistics']['viewCount']

def parse_publish_date(video):
    return video['snippet']['resourceId']['videoId'],datetime.strptime(video['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%S.000Z"),video['snippet']['title']

# %%
channel_name = 'Salmon House'
channel_id = get_channel(channel_name)['id']['channelId']
channel_id
# Out:
# 'UCF4jQCA959hTvWNsXU5uHkA'

# %%
videos = get_videos(channel_id, limit=6500)
videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/DHrpk4pD8r3xh0wcdOijZSuA2rQ"',
#   'id': 'VVVGNGpRQ0E5NTloVHZXTnNYVTV1SGtBLkJ6YUw1QUROTDRJ',
#   'snippet': {'publishedAt': '2019-07-30T12:06:27.000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': 'แรงสะใจต้องSHARP',
#    'description': 'ไม่รู้โฆษณาอะไร แต่... #แรงสะใจต้องSHARP',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BzaL5ADNL4I/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/BzaL5ADNL4I/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/BzaL5ADNL4I/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/BzaL5ADNL4I/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/BzaL5ADNL4I/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Salmon House',
#    'playlistId': 'UUF4jQCA959hTvWNsXU5uHkA',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'BzaL5ADNL4I'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/7LJJZaxx7xhIGncVrJS9ecB7iXM"',
#   'id': 'VVVGNGpRQ0E5NTloVHZXTnNYVTV1SGtBLmZTZDY0bVZERm9V',
#   'snippet': {'publishedAt': '2019-08-01T12:00:06.000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': 'จะรุนแรงไปทำไม',
#    'description': 'จะนิ่มนวลไปทำไม!?\n.\n.\n.\n.\n.\n.\nก็เพราะนิ่มนวลแล้วไม่ทำให้สิวอักเสบไง\nซื้อได้ที่ Watsons, Tsuruha, LAB และร้านขายยาชั้นนำทั่วไป',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fSd64mVDFoU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/fSd64mVDFoU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/fSd64mVDFoU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/fSd64mVDFoU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/fSd64mVDFoU/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Salmon House',
#    'playlistId': 'UUF4jQCA959hTvWNsXU5uHkA',
#    'position': 1,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'fSd64mVDFoU'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/g-iu8IdbWDfC3gbRMiAsBiW1QLw"',
#   'id': 'VVVGNGpRQ0E5NTloVHZXTnNYVTV1SGtBLkI3VUVoT2drNXR3',
#   'snippet': {'publishedAt': '2019-07-09T08:47:24.000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': 'เรไร amulet ศรัทธาแก้ทุกปัญหา',
#    'description': 'ไม่เชื่ออย่าลบหลู่ ไม่เชื่ออย่าลบหลู่ ไม่เชื่ออย่าลบหลู่ ไม่เชื่ออย่าลบหลู่\n#SalmonHouseSkit\n------------\nปีนี้เรามี skit เยอะนะ\nอย่าลืมกด see first เพจเราไว้จะได้ไม่พลาดคลิปต่อๆ ไปนะครับ',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi

#    'resourceId': {'kind': 'youtube#video', 'videoId': 'x0cz4Ac0d78'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/IswO9qJ02O85pnpZKE9pmXoHD_M"',
#   'id': 'VVVGNGpRQ0E5NTloVHZXTnNYVTV1SGtBLjdqMW1vQ2k1NnRj',
#   'snippet': {'publishedAt': '2015-02-16T12:55:18.000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': 'โก๋แก่ presents - Bangkok 1st Time : ตอนชื่อไทยครั้งแรก',
#    'description': "ติดตามข่าวสารของ Bangkok 1st Time | ฝรั่งคะนองกรุง ได้ที่:\nhttp://facebook.com/salmonhousetv\n\nEP. 1 : ตอนชื่อไทยครั้งแรก\nเมืองนอกเมืองนา ไม่ได้พิถีพิถันเรื่องการตั้งชื่อสักเท่าไหร่\nพอลุงมาเมืองไทย ก็พบว่าชื่อไทยนั้นสวยงาม มีความหมาย\nแถมยังมีฟังก์ชั่นวิเศษบางอย่างซ่อนอยู่\nลุงจึงอยากมีชื่อไทยบ้าง\nโดยที่ลุงไม่รู้ซะแล้วว่า การตั้งชื่อไทยนั้นมัน...'พิถีพิถัน' แค่ไหน",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7j1moCi56tc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/7j1moCi56tc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/7j1moCi56tc/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/7j1moCi56tc/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/7j1moCi56tc/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Salmon House',
#    'playlistId': 'UUF4jQCA959hTvWNsXU5uHkA',
#    'position': 122,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '7j1moCi56tc'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/wcEJ1Ps9_CIK373K6FPiyiBLGQE"',
#   'id': 'VVVGNGpRQ0E5NTloVHZXTnNYVTV1SGtBLm5vYXFBYjlhV2RB',
#   'snippet': {'publishedAt': '2015-02-10T12:57:23.000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': '[Trailer] Bangkok 1st Time | ฝรั่งคะนองกรุง',
#    'description': "ลุงเนลสันกลับมาแล้ว! \nใน 'Bangkok 1st Time | ฝรั่งคะนองกรุง'\nเต็มอิ่มกับ 6 ตอนใหม่ \nเริ่มตอนแรก 16 กุมภาพันธ์นี้\nและคะนองกันอย่างต่อเนื่อง ทุกวันหวยออก เวลา 20.00 น.\nที่ http://youtube.com/salmonchannel ที่เดียวเท่านั้น!\n\nกด subscribe รอได้เลย!\n\nFor more information :\nSalmon House\nhttp://facebook.com/salmonhousetv",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/noaqAb9aWdA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/noaqAb9aWdA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/noaqAb9aWdA/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/noaqAb9aWdA/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/noaqAb9aWdA/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Salmon House',
#    'playlistId': 'UUF4jQCA959hTvWNsXU5uHkA',
#    'position': 123,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'noaqAb9aWdA'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/xTaLwb2VqE9tIR01aeiTFjEb9rg"',
#   'id': 'VVVGNGpRQ0E5NTloVHZXTnNYVTV1SGtBLjZqb3RweU5mZGpF',
#   'snippet': {'publishedAt': '2014-12-11T10:34:42.000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': 'ซีนีม่า ปาระเบิด : Sur-Real',
#    'description': 'เทปนี้บอสใหญ่สปอนเซอร์มาเอง แล้วพิธีกรปากหมาหน้ากวน มันจะเอาตัวรอดกันยังไง\n\nสนทนาปาระเบิด : วิชัยและกตัญญูจะมาทำตัวเนรคุณด้วยการทิ้งบอมบ์ใส่สปอนเซอร์ของตัวเอง ในหนัง Sur-Real\n\nทิ้งบอมบ์ : พี่ต้นแห่งโก๋ฟิล์ม มาเล่าให้ฟังว่า การทำหนังอินดี้ค่ายเล็กมีเรื่องปวดตับอย่างไรบ้าง?',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6jotpyNfdjE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/6jotpyNfdjE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/6jotpyNfdjE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/6jotpyNfdjE/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/6jotpyNfdjE/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Salmon House',
#    'playlistId': 'UUF4jQCA959hTvWNsXU5uHkA',
#    'position': 124,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '6jotpyNfdjE'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/vXKSzJNf7mYhlBYbLg5Nn9VWL10"',
#   'id': 'VVVGNGpRQ0E5NTloVHZXTnNYVTV1SGtBLm83bzgtOW1QQ1ZF',
#   'snippet': {'publishedAt': '2014-11-19T05:37:47.000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': 
000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': 'ซีนีม่า...ปาระเบิด (2/3) : ช่วง ทิ้งบอมบ์ : หนังไทย อะไรๆก็จีทีเอช',
#    'description': 'ซีนีม่า...ปาระเบิด\nรายการคุยหนัง โดยเนิร์ดหนังขี้รำคาญ\nปาระเบิดใส่หนังกันด้วยความรักและความรำคาญ\nตรงไหนดีก็ชมกันให้เขิน ตรงไหนห่วยก็บอมบ์กันให้อาย\n\nช่วงที่ 2 ช่วง “ทิ้งบอมบ์”\nคุยกันแบบเนิร์ดๆ เรื่องประเด็นที่น่าพูดถึงจากหนังที่กำลังเป็นกระแส \nดีบ้าง เกรียนบ้าง แล้วแต่อารมณ์และทรงผมของพิธีกร',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GJzMulbnEq8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/GJzMulbnEq8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/GJzMulbnEq8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/GJzMulbnEq8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/GJzMulbnEq8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Salmon House',
#    'playlistId': 'UUF4jQCA959hTvWNsXU5uHkA',
#    'position': 131,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'GJzMulbnEq8'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/XytI8iDrMUzPJlC4DsT82ZBXG-E"',
#   'id': 'VVVGNGpRQ0E5NTloVHZXTnNYVTV1SGtBLmkyb3hJUWVZenJB',
#   'snippet': {'publishedAt': '2014-08-21T06:06:50.000Z',
#    'channelId': 'UCF4jQCA959hTvWNsXU5uHkA',
#    'title': 'ซีนีม่า...ปาระเบิด (1/3) : ช่วง ปาระเบิด : ฝากไว้ในกายเธอ',
#    'description': 'ซีนีม่า...ปาระเบิด\nรายการคุยหนัง โดยเนิร์ดหนังขี้รำคาญ\nปาระเบิดใส่หนังกันด้วยความรักและความรำคาญ\nตรงไหนดีก็ชมกันให้เขิน ตรงไหนห่วยก็บอมบ์กันให้อาย\n\nช่วงที่ 1 ช่วง “ปาระเบิด” \nจับเอาหนังที่อยู่ในกระแสมาปาระเบิด อะไรสิ่งน่ารำคาญ อะไรคือสิ่งดีงาม\nชำแหละกันอย่างเนิร์ดๆ และเกรียนๆ',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i2oxIQeYzrA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/i2oxIQeYzrA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/i2oxIQeYzrA/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/i2oxIQeYzrA/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/i2oxIQeYzrA/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Salmon House',
#    'playlistId': 'UUF4jQCA959hTvWNsXU5uHkA',
#    'position': 132,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'i2oxIQeYzrA'}}}]

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
len(video_ids)
# Out:
# 133

# %%
stats = get_videos_stats(video_ids)
len(stats)
# Out:
# 133

# %%
most_viewed = sorted(stats, key=lambda x:int(x['statistics']['viewCount']), reverse=True)

# %%
counts = [parse_count(video) for video in most_viewed]
len(counts)
# Out:
# 133

# %%
df_count = pd.DataFrame(data = counts , columns=['videoId','viewCount'])
df_count.head()
# Out:
#        videoId viewCount
# 0  u06GqlNiJUY   4450118
# 1  mcuUJw9hMmI   1701519
# 2  x0cz4Ac0d78   1243176
# 3  7j1moCi56tc   1214482
# 4  Dgi35zQ8Auk   1105252

# %%
df_count["viewCount"] = df_count["viewCount"].astype("float")

# %%
df_count.sort_values(by=['viewCount'],ascending=[False]).head()
# Out:
#        videoId  viewCount
# 0  u06GqlNiJUY  4450118.0
# 1  mcuUJw9hMmI  1701519.0
# 2  x0cz4Ac0d78  1243176.0
# 3  7j1moCi56tc  1214482.0
# 4  Dgi35zQ8Auk  1105252.0

# %%
publish_dates = [parse_publish_date(video) for video in videos]
len(publish_dates)
# Out:
# 133

# %%
df_date = pd.DataFrame(data = publish_dates , columns=['videoId','publishedAt','title'])
df_date.head()
# Out:
#        videoId         publishedAt                          title
# 0  BzaL5ADNL4I 2019-07-30 12:06:27               แรงสะใจต้องSHARP
# 1  fSd64mVDFoU 2019-08-01 12:00:06                 จะรุนแรงไปทำไม
# 2  B7UEhOgk5tw 2019-07-09 08:47:24  เรไร amulet ศรัทธาแก้ทุกปัญหา
# 3  uyoN0rZrRV4 2019-05-07 14:44:20       นักเลงกระบะซิ่งเขารู้กัน
# 4  AQajTmSjwaw 2019-03-27 08:30:00              หน้าใส ใจฟู ดูนี่

# %%
dfd = pd.merge(df_date, df_count, on='videoId', how='inner')
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133 entries, 0 to 132
# Data columns (total 4 columns):
# videoId        133 non-null object
# publishedAt    133 non-null datetime64[ns]
# title          133 non-null object
# viewCount      133 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 5.2+ KB

# %%
dfd.sort_values(by=['publishedAt'],ascending=[False]).head()
# Out:
#        videoId         publishedAt                          title  viewCount
# 1  fSd64mVDFoU 2019-08-01 12:00:06                 จะรุนแรงไปทำไม     8995.0
# 0  BzaL5ADNL4I 2019-07-30 12:06:27               แรงสะใจต้องSHARP     8127.0
# 2  B7UEhOgk5tw 2019-07-09 08:47:24  เรไร amulet ศรัทธาแก้ทุกปัญหา    51751.0
# 3  uyoN0rZrRV4 2019-05-07 14:44:20       นักเลงกระบะซิ่งเขารู้กัน   421383.0
# 4  AQajTmSjwaw 2019-03-27 08:30:00              หน้าใส ใจฟู ดูนี่    12395.0

# %%
df_count_date = pd.merge(df_count, df_date, how='inner', on='videoId')
df_count_date.head(10)
# Out:
#        videoId  viewCount         publishedAt  \
# 0  u06GqlNiJUY  4450118.0 2016-08-09 12:56:36
# 1  mcuUJw9hMmI  1701519.0 2015-04-01 13:00:47
# 2  x0cz4Ac0d78  1243176.0 2015-03-01 13:34:13
# 3  7j1moCi56tc  1214482.0 2015-02-16 12:55:18
# 4  Dgi35zQ8Auk  1105252.0 2015-04-11 12:55:54
# 5  U9EsAHwCpiU  1093167.0 2017-06-28 14:05:38
# 6  -wxHJYriKuk  1008033.0 2015-03-16 12:59:59
# 7  TU7L0VmVYEk   928809.0 2015-04-16 12:29:57
# 8  3KWCtsiZJqQ   843879.0 2018-12-04 06:00:12
# 9  nqOVp_lz670   717782.0 2016-04-04 12:58:42
#
#                                                title
# 0                     วิดีโอสาธิตความปลอดภัยบนรถเมล์
# 1  โก๋แก่ presents - Bangkok 1st Time : ตอนสั่งอา...
# 2  โก๋แก่ presents - Bangkok 1st Time : ตอนเล่นหว...
# 3  โก๋แก่ presents - Bangkok 1st Time : ตอนชื่อไท...
# 4                       SIRI VS. VERY THAI SENTENCES
# 5            Pre-Sum Skills [Okamoto x Salmon House]
# 6  โก๋แก่ presents - Bangkok 1st Time : ตอนพ่นกำแ...
# 7  โก๋แก่ presents - Bangkok 1st Time : ตอนเจอพริ...
# 8  รีวิวเจอพ่อตาครั้งแรก : Chocolate Ville X Salm...
# 9                            A cameraman, literally.

# %%
df_count_date.to_excel('c:\\aab\\excel\\PMC Official MV.xlsx')
