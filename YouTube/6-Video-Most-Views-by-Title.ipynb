# %%
api_key = 'AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys'

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
req = youtube.search().list(part='snippet',
                            q='MGhMdT_C-vQ',
                            type='videoid',
                            maxResults=1)

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res = req.execute()

# %%
res['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/d4DlKf5EcCXoz90BKrE6zD8knkk"',
#  'id': {'kind': 'youtube#video', 'videoId': 'MGhMdT_C-vQ'},
#  'snippet': {'publishedAt': '2016-09-25T01:01:06.000Z',
#   'channelId': 'UCsV06YMAIr-0HaHXlkglqQg',
#   'title': 'Eagles - Hotel California   (Live &#39;77) Lyrics (Blocked in US)',
#   'description': 'On a dark desert highway, cool wind in my hair Warm smell of colitas, rising up through the air Up ahead in the distance, I saw a shimmering light My head grew ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MGhMdT_C-vQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/MGhMdT_C-vQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/MGhMdT_C-vQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Margin Walker',
#   'liveBroadcastContent': 'none'}}

# %%
def get_channel_videos(channel_id):
    
    # get Uploads playlist id
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos

# %%
# crayons and carry-ons = 'UCkbl59_mrmuCL6aJgrlHnEQ'

# %%
videos = get_channel_videos('UCyEd6QBSgat5kkC6svyjudA')

# %%
len(videos)
# Out:
# 942

# %%
def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
        
    return stats

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))

# %%
stats = get_videos_stats(video_ids)

# %%
len(stats)
# Out:
# 942

# %%
most_disliked = sorted(stats, key=lambda x:int(x['statistics']['viewCount']), reverse=True)

# %%
for video in most_disliked:
    print(video['id'], video['statistics']['viewCount'])
# Out:
# 3w6UuOARJxs 15020301
# rOAbYFdNQEo 13072519
# WErpgU9XS8Q 9157310
# Cm2dczXpBG0 7632935
# Xdya8eym9nM 6632974
# n6VQsOvNvyQ 6063573
# FLmNLrog6dQ 5643222
# OO9kSxcT9Rg 5347210
# C5U3dMkYbog 4991006
# _AuXvnCLERA 4895577
# lDoLLhswOwY 4861617
# SaBefg-mRL4 4834360
# jrMsWztL1n8 4827221
# CodtdeXZhJA 4509630
# ssshx__9azA 4396502
# vkhOnPaKZ8U 4288288
# pBPXxO9E-fQ 4035364
# A3xHJzNNM2A 4021073
# rtarxm5EJRk 3827451
# CEHayLnKvwY 3706951
# 9GiIjuu71dg 3609825
# keZjgPiJJO8 3587690
# 1zr_ZRPmVxI 3582372
# Rj9LXnVkHlg 3544486
# UHvdmu2ocwE 3541230
# cF7hnBuHlAI 3476553
# VfNqA2ukNrk 3451595
# iR_VQJtwfmE 3324457
# seByECDiyQo 3194796
# 5oj_tT6pOOg 3169654
# M243PCvVnJM 3080804
# 87If-Q2pJWQ 3076961
# YvlYjLPgrCE 3056843
# Y1YN3f4yRW8 2971760
# vv8LUSqT3JQ 2933846
# mH227HILqII 2923414
# e2RBRUFwmuw 2904076
# 4sMejozB6XU 2902423
# AQIExuYef3Y 2891008
# BqdFvgaiynM 2887259
# DMlITdf3w-o 2845495
# NgHnXl9P39c 2831073
# 9R-8TvtW94c 2814022
# -xb0gIhaWbM 2806744
# Zi2Myjoms0Y 2758338
# ...
