# %%
import pandas as pd
from datetime import datetime, timedelta
from apiclient.discovery import build
YOUTUBE_DEVELOPER_KEY = 'AIzaSyBYOWoFmf3cG5Ez653Qdmw9xHmchEMz4Ys'
youtube = build('youtube', 'v3', developerKey=YOUTUBE_DEVELOPER_KEY)

# %%
def get_channel(channel_name):
    return youtube.search().list(q=channel_name, type='channel', part='id,snippet').execute()['items'][0]


def get_videos(channel_id, part='id,snippet', limit=10):
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part=part, 
                                           maxResults=min(limit, 50),
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None or len(videos) >= limit:
            break

    return videos

def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
        
    return stats

def parse_count(video):
    return video['id'],video['statistics']['viewCount']

def parse_publish_date(video):
    return video['snippet']['resourceId']['videoId'],datetime.strptime(video['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%S.000Z"),video['snippet']['title']

# %%
channel_name = 'TheCaroleKing'
channel_id = get_channel(channel_name)['id']['channelId']
channel_id
# Out:
# 'UCaS5rLrxc6pQDWwpWyQyXUg'

# %%
videos = get_videos(channel_id, limit=6500)
videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/hICALyJPUAdCBe_gcL0uETBIUfU"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLlhkZWM0SVpKWTI4',
#   'snippet': {'publishedAt': '2019-06-18T15:41:06.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'Girl Power - Carole King',
#    'description': 'Carole King was inspired to write "Girl Power" after Mia Hamm\'s iconic win.  Released in 2007 on Rockingale Records.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Xdec4IZJY28/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Xdec4IZJY28/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Xdec4IZJY28/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Xdec4IZJY28'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/XJIUdwNfOwkxEHgc8B-zbASeNwQ"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLjVlUVU4dG5OQmRN',
#   'snippet': {'publishedAt': '2019-05-28T15:06:57.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'Carole King - Live at Montreux Trailer 30sec.',
#    'description': 'Carole King - Live At Montreux 1973 out June 14 on CD, DVD/CD and LP.  Available to pre-order now from http://smarturl.it/CaroleKingMontreux and our store at http://bit.ly/CaroleKing_Montreux\n\nCarole King’s very first performance outside of the U.S. took place in 1973, at The Montreux Pavillon as part of the world-famous Montreux Jazz Festival.\n\nReleased for the very first time, this concert film was captured two years after she altered the course of pop history with ‘Tapestry’, and one month after she issued the album ‘Fantasy’. Carole performs with heartfelt energy, playing classic hits such as “It’s Too Late”, “I Feel The Earth Move”, “You’ve Got A Friend” plus standout tracks from Fantasy - “Believe in Humanity” and “Corazón”- as she is backed by an ensemble of top musicians including Tom Scott, Ms. Bobbye Hall and David T. Walker.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5eQU8tnNBdM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5eQU8tnNBdM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5eQU8tnNBdM/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/5eQU8tnNBdM/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/5eQU8tnNBdM/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 1,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '5eQU8tnNBdM'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU
',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LDg2XxySNkU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LDg2XxySNkU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LDg2XxySNkU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/LDg2XxySNkU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/LDg2XxySNkU/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 32,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'LDg2XxySNkU'}}},
#  {'kind': 'youtube#playlistItem',
# ...
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Qu_4McwEeIE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Qu_4McwEeIE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Qu_4McwEeIE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Qu_4McwEeIE/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/Qu_4McwEeIE/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 110,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Qu_4McwEeIE'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/-nT8Lb3WGRbECI0p2Sdi6otsymw"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLlJhWnNRRmdWaF9j',
#   'snippet': {'publishedAt': '2011-10-07T20:23:38.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'Carole King - "A Holiday Carole" EPK',
#    'description': 'Label: Rockingale Records/Concord Music Group-UMG \nAll Rights Reserved',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RaZsQFgVh_c/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/RaZsQFgVh_c/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/RaZsQFgVh_c/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/RaZsQFgVh_c/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/RaZsQFgVh_c/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 111,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'RaZsQFgVh_c'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/QODK60s0VOzpR3lY-nCivQ6yY1Y"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLjFENkVDVnVWeFhj',
#   'snippet': {'publishedAt': '2011-02-03T01:56:23.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'Love Makes the World',
#    'description': 'This is the music video from "Love Makes the World" title track of Carole\'s "Love Makes the World" album.\n\nRockingale Records\n© All Rights Reserved',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1D6ECVuVxXc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/1D6ECVuVxXc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/1D6ECVuVxXc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 112,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '1D6ECVuVxXc'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/Pn3FEGF8OOxvcrNhhx4T9OX6iyM"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLkV4VkNzckdRb3VR',
#   'snippet': {'publishedAt': '2011-01-08T18:32:57.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'Smackwater Jack',
#    'description': 'Carole King, Rudy Guess, and Gary Burr perform "Smackwater Jack" from "The Living Room Tour" which was filmed in Temecula, California in 2005. Courtesy of Carole King: Welcome To My Living Room DVD\r\nAll Rights Reserved\r\nCopyright 2007 Rockingale Records',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ExVCsrGQouQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ExVCsrGQouQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ExVCsrGQouQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 113,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'ExVCsrGQouQ'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/sTAlQvM_weXHwWNk8eU4-B8x3CI"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLktDM3NTTnFCSlE4',
#   'snippet': {'publishedAt': '2010-07-20T05:39:55.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'Carole and James Extend a Heartfelt Thank You To All Who Came Out to See Them Perform in 2010',
#    'description': 'Carole King and James Taylor  - Troubadour Reunion Tour 2010\r\nAll Rights Reserved  \r\nCopyright 2010 Syzygy Productions, LLC',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KC3sSNqBJQ8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/KC3sSNqBJQ8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/KC3sSNqBJQ8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/KC3sSNqBJQ8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/KC3sSNqBJQ8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 114,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'KC3sSNqBJQ8'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/wBydiVZ0661SuSZjmNXe5dvF0sc"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLmhaalBMcU9fbUJB',
#   'snippet': {'publishedAt': '2010-07-12T04:04:51.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'WAY OVER YONDER     Words and Music by Carole King',
#    'description': 'Honoring the American Wild Horse\nCarole King and James Taylor - Troubadour Reunion Tour 2010\nAll Rights Reserved  \nCopyright 2010 Syzygy Productions, LLC\n\nThe beautiful "wild ones", as they are referred to by photographer Elissa Kline, appear in this stunning slideshow living wild on the remote and austere 160,000 public lands area of the Challis Mountains in Idaho, as they have for hundreds of years.  That is, until the Bureau of Land Management (BLM) roundup in July 2009. \n\nMore than half of the 400 horses on that range were removed and shipped to destinations unknown. Years and generations of de
000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'Carole King & James Taylor | Troubadour Reunion',
#    'description': 'Promotion for the Carole King and James Taylor Troubador Reunion World tour.  Saturday, March 27th, 2010 at the Rod Laver Arena.\r\n\r\nWorld Tour beginning early 2010!  Please visit http://www.caroleking.com for more information!',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GDr0nEIRI4A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/GDr0nEIRI4A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/GDr0nEIRI4A/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 121,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'GDr0nEIRI4A'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/OG4psmJqm9mPChM2e6rhEmtW_4I"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLktybWRLWnU4RnZj',
#   'snippet': {'publishedAt': '2009-11-12T23:41:46.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': 'Carole King and James Taylor | Troubadour Reunion Tour 2010',
#    'description': 'World Tour beginning Early 2010!  Please visit http://www.CaroleKing.com for more information!',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KrmdKZu8Fvc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/KrmdKZu8Fvc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/KrmdKZu8Fvc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 122,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'KrmdKZu8Fvc'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/vzFvlUwFAEWasVPxiHAU417Xi9c"',
#   'id': 'VVVhUzVyTHJ4YzZwUURXd3BXeVF5WFVnLkJPT0Y3X1JCM0Rj',
#   'snippet': {'publishedAt': '2009-09-11T22:05:58.000Z',
#    'channelId': 'UCaS5rLrxc6pQDWwpWyQyXUg',
#    'title': '"Safe Again" - Carole King',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BOOF7_RB3Dc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/BOOF7_RB3Dc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/BOOF7_RB3Dc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'TheCaroleKing',
#    'playlistId': 'UUaS5rLrxc6pQDWwpWyQyXUg',
#    'position': 123,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'BOOF7_RB3Dc'}}}]

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
len(video_ids)
# Out:
# 124

# %%
stats = get_videos_stats(video_ids)
len(stats)
# Out:
# 124

# %%
most_viewed = sorted(stats, key=lambda x:int(x['statistics']['viewCount']), reverse=True)

# %%
counts = [parse_count(video) for video in most_viewed]
len(counts)
# Out:
# 124

# %%
df_count = pd.DataFrame(data = counts , columns=['videoId','viewCount'])
df_count.head()
# Out:
#        videoId viewCount
# 0  gc93thQVIV8    241628
# 1  cRPls7hjRfs    232062
# 2  vIBhzZxy3bs    158509
# 3  rJGPXP7i-RM    145338
# 4  zaPYz-6Bji4    134620

# %%
df_count["viewCount"] = df_count["viewCount"].astype("float")

# %%
df_count.sort_values(by=['viewCount'],ascending=[False]).head()
# Out:
#        videoId  viewCount
# 0  gc93thQVIV8   241628.0
# 1  cRPls7hjRfs   232062.0
# 2  vIBhzZxy3bs   158509.0
# 3  rJGPXP7i-RM   145338.0
# 4  zaPYz-6Bji4   134620.0

# %%
publish_dates = [parse_publish_date(video) for video in videos]
len(publish_dates)
# Out:
# 124

# %%
df_date = pd.DataFrame(data = publish_dates , columns=['videoId','publishedAt','title'])
df_date.head()
# Out:
#        videoId         publishedAt  \
# 0  Xdec4IZJY28 2019-06-18 15:41:06
# 1  5eQU8tnNBdM 2019-05-28 15:06:57
# 2  JPczvGZoW9A 2018-12-21 07:58:53
# 3  cRPls7hjRfs 2018-11-13 16:38:38
# 4  gc93thQVIV8 2018-10-29 15:00:17
#
#                                            title
# 0                       Girl Power - Carole King
# 1  Carole King - Live at Montreux Trailer 30sec.
# 2    Happy Holidays from Carole King Productions
# 3                  "It's Too Late" - Carole King
# 4                       Carole King - One (2018)

# %%
dfd = pd.merge(df_date, df_count, on='videoId', how='inner')
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 0 to 123
# Data columns (total 4 columns):
# videoId        124 non-null object
# publishedAt    124 non-null datetime64[ns]
# title          124 non-null object
# viewCount      124 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 4.8+ KB

# %%
dfd.sort_values(by=['publishedAt'],ascending=[False]).head()
# Out:
#        videoId         publishedAt  \
# 6  ew_MFY5MWXc 2019-07-12 15:49:12
# 0  Xdec4IZJY28 2019-06-18 15:41:06
# 1  5eQU8tnNBdM 2019-05-28 15:06:57
# 2  JPczvGZoW9A 2018-12-21 07:58:53
# 3  cRPls7hjRfs 2018-11-13 16:38:38
#
#                                            title  viewCount
# 6      Welcome To My Living Room - Medley Part 2      924.0
# 0                       Girl Power - Carole King     3296.0
# 1  Carole King - Live at Montreux Trailer 30sec.     8096.0
# 2    Happy Holidays from Carole King Productions     1320.0
# 3                  "It's Too Late" - Carole King   232062.0

# %%
df_count_date = pd.merge(df_count, df_date, how='inner', on='videoId')
#df_count_date.to_excel('c:\\aab\\data\\eagle_rock.xlsx',encoding='utf-8')
songs = df_count_date.sort_values(by=['viewCount'],ascending=[False]).head(12)
songs
# Out:
#         videoId  viewCount         publishedAt  \
# 0   gc93thQVIV8   241628.0 2018-10-29 15:00:17
# 1   cRPls7hjRfs   232062.0 2018-11-13 16:38:38
# 2   vIBhzZxy3bs   158509.0 2014-03-13 15:14:39
# 3   rJGPXP7i-RM   145338.0 2018-04-05 00:15:37
# 4   zaPYz-6Bji4   134620.0 2017-01-26 19:08:08
# 5   0AjiuDHe9uc    58697.0 2016-09-27 15:08:50
# 6   EiJ0uK8qYXM    55182.0 2009-11-24 01:44:44
# 7   q1aZRgajWgY    46951.0 2013-08-02 13:12:11
# 8   RGpR9AzVyDk    46088.0 2016-05-11 02:55:33
# 9   1D6ECVuVxXc    42355.0 2011-02-03 01:56:23
# 10  -9JdmHOsWtU    38010.0 2017-06-16 07:17:49
# 11  IrzjDVH4XcA    36667.0 2016-04-25 15:16:02
#
#                                                 title
# 0                            Carole King - One (2018)
# 1                       "It's Too Late" - Carole King
# 2                 Carole King "Beautiful" with Lyrics
# 3                         "So Far Away" - Carole King
# 4                       One Small Voice - Carole King
# 5                     "Way Over Yonder" - Carole King
# 6     Carole King • James Taylor | Troubadour Reunion
# 7            "I Believe In Loving You" by Carole King
# 8                    "The Loco Motion" -  Carole King
# 9                                Love Makes the World
# 10  "Been To Canaan" - Words and Music by Carole King
# 11     "Take Good Care Of My Baby" - Carole King Demo

# %%
sr = songs['videoId']
sr.shape
# Out:
# (12,)

# %%
vids= sr.values.tolist()
vids
# Out:
# ['gc93thQVIV8',
#  'cRPls7hjRfs',
#  'vIBhzZxy3bs',
#  'rJGPXP7i-RM',
#  'zaPYz-6Bji4',
#  '0AjiuDHe9uc',
#  'EiJ0uK8qYXM',
#  'q1aZRgajWgY',
#  'RGpR9AzVyDk',
#  '1D6ECVuVxXc',
#  '-9JdmHOsWtU',
#  'IrzjDVH4XcA']
