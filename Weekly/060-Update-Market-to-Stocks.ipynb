# %% [markdown]
# ### portpg: stocks
# ### stock:  price

# %% [markdown]
# ### Restart & Run All Cells

# %%
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine1 = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine1.connect()

engine2 = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine2.connect()

pd.set_option('display.float_format','{:,.2f}'.format)

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"

today = date.today()
week_str = today.strftime('%Y-%U')
today, week_str
# Out:
# (datetime.date(2022, 12, 19), '2022-51')

# %%
sql = '''
SELECT name, market
FROM stocks
'''
stocks_lite = pd.read_sql(sql, conlite)
stocks_lite
# Out:
#       name  market
# 0      MCS     SET
# 1    PTTGC   SET50
# 2    JASIF     SET
# 3      DIF     SET
# 4    WHAIR     SET
# ..     ...     ...
# 58      CK  SET100
# 59    MEGA  SET100
# 60    SIRI     SET
# 61      AH     SET
# 62  SINGER  SET100
#
# [63 rows x 2 columns]

# %%
sql = '''
SELECT name, market, id
FROM stocks
'''
stocks_pg = pd.read_sql(sql, conpg)
stocks_pg
# Out:
#        name                                         market   id
# 0       CBG                    SET50 / SETCLMV / SETWB      760
# 1    CENTEL                           SET100 / SETTHSI      761
# 2       CHG                     SET100 / SETHD / SETWB      762
# 3    BTSGIF                                        SET      759
# 4       ASK                                        SET      732
# ..      ...                                            ...  ...
# 228  INTUCH          SET50 / SETCLMV / SETHD / SETTHSI      810
# 229     LHK                                        SET      831
# 230     LPH                                       sSET      834
# 231    ONEE                                     SET100      950
# 232     OSP  SET50 / SETCLMV / SETHD / SETTHSI / SETWB      852
#
# [233 rows x 3 columns]

# %%
df_merge = pd.merge(stocks_lite, stocks_pg, on='name', how='inner')
df_merge
# Out:
#       name market_x                        market_y   id
# 0      MCS      SET                        sSET      842
# 1    PTTGC    SET50   SET50 / SETCLMV / SETTHSI      866
# 2    JASIF      SET                         SET      814
# 3      DIF      SET                         SET      777
# 4    WHAIR      SET                         SET      802
# ..     ...      ...                             ...  ...
# 58      CK   SET100  SET100 / SETCLMV / SETTHSI      763
# 59    MEGA   SET100    SET100 / SETCLMV / SETWB      843
# 60    SIRI      SET                     SETTHSI      886
# 61      AH      SET              sSET / SETTHSI      721
# 62  SINGER   SET100              SET100 / SETWB      885
#
# [63 rows x 4 columns]

# %%
set50 = df_merge.market_y.str.contains('SET50')
filter_50 = df_merge[set50].copy()
filter_50['market_x'] = 'SET50'
filter_50.sort_values(by=['name'],ascending=[True])
# Out:
#      name market_x                                       market_y   id
# 24  BANPU    SET50                  SET50 / SETCLMV / SETTHSI      738
# 38    BBL    SET50          SET50 / SETCLMV / SETHD / SETTHSI      740
# 57   BDMS    SET50          SET50 / SETCLMV / SETTHSI / SETWB      745
# 39    BEM    SET50                    SET50 / SETTHSI / SETWB      748
# 22     BH    SET50                    SET50 / SETCLMV / SETWB      752
# 41  CPALL    SET50                    SET50 / SETTHSI / SETWB      767
# 56    CPF    SET50  SET50 / SETCLMV / SETHD / SETTHSI / SETWB      768
# 42    CPN    SET50                            SET50 / SETTHSI      769
# 43     EA    SET50                            SET50 / SETTHSI      781
# 45  HMPRO    SET50                    SET50 / SETTHSI / SETWB      801
# 23    IVL    SET50                            SET50 / SETTHSI      813
# 30  JMART    SET50                                      SET50      815
# 31    JMT    SET50                                      SET50      816
# 11    KCE    SET50                                      SET50      819
# 49    KTB    SET50                    SET50 / SETHD / SETTHSI      824
# 50     LH    SET50                              SET50 / SETHD      829
# 26  PTTEP    SET50          SET50 / SETCLMV / SETHD / SETTHSI      865
# 1   PTTGC    SET50                  SET50 / SETCLMV / SETTHSI      866
# 36    SCB    SET50                  SET50 / SETCLMV / SETTHSI      949
# 6     SCC    SET50          SET50 / SETCLMV / SETHD / SETTHSI      879
# 25    TTB    SET50                    SET50 / SETHD / SETTHSI      933

# %%
set100 = df_merge.market_y.str.contains('SET100')
filter_100 = df_merge[set100].copy()
filter_100['market_x'] = 'SET100'
filter_100.sort_values(by=['name'],ascending=[True])
# Out:
#       name market_x                                market_y   id
# 9      BCH   SET100    SET100 / SETCLMV / SETHD / SETWB      741
# 58      CK   SET100          SET100 / SETCLMV / SETTHSI      763
# 27     CKP   SET100          SET100 / SETCLMV / SETTHSI      764
# 55    COM7   SET100            SET100 / SETTHSI / SETWB      765
# 10  DOHOME   SET100                      SET100 / SETWB      778
# 48     KKP   SET100  SET100 / SETCLMV / SETHD / SETTHSI      822
# 59    MEGA   SET100            SET100 / SETCLMV / SETWB      843
# 19     ORI   SET100            SET100 / SETHD / SETTHSI      851
# 52      QH   SET100                      SET100 / SETHD      867
# 13     RCL   SET100            SET100 / SETCLMV / SETWB      870
# 62  SINGER   SET100                      SET100 / SETWB      885
# 33   SPALI   SET100                      SET100 / SETHD      892
# 5      STA   SET100            SET100 / SETTHSI / SETWB      898
# 8    SYNEX   SET100                    SET100 / SETTHSI      906

# %%
setmai = df_merge.market_y.str.contains('mai')
filter_mai = df_merge[setmai].copy()
filter_mai['market_x'] = 'mai'
filter_mai.sort_values(by=['name'],ascending=[True])
# Out:
# Empty DataFrame
# Columns: [name, market_x, market_y, id]
# Index: []

# %%
filter_set = df_merge[~(set100 | set50 | setmai)].copy()
filter_set['market_x'] = 'SET'
filter_set.sort_values(by=['name'],ascending=[True])
# Out:
#        name market_x                    market_y   id
# 61       AH      SET          sSET / SETTHSI      721
# 37      AIT      SET                    sSET      724
# 21      ASK      SET                     SET      732
# 15      ASP      SET                    sSET      733
# 40      BPP      SET       SETCLMV / SETTHSI      757
# 29  CPNREIT      SET                     SET      771
# 20      DCC      SET                     SET      774
# 3       DIF      SET                     SET      777
# 44     GFPT      SET  sSET / SETTHSI / SETWB      791
# 28   GVREIT      SET                     SET      798
# 46     ICHI      SET          sSET / SETCLMV      804
# 47      III      SET                    sSET      953
# 2     JASIF      SET                     SET      814
# 17    MAKRO      SET                     SET      839
# 0       MCS      SET                    sSET      842
# 7       NER      SET                    sSET      847
# 51      PSH      SET                 SETTHSI      860
# 32    SAPPE      SET                    sSET      875
# 53       SC      SET          sSET / SETTHSI      878
# 16     SCCC      SET       SETCLMV / SETTHSI      880
# 18     SENA      SET                    sSET      882
# 60     SIRI      SET                 SETTHSI      886
# 34      SVI      SET                     SET      905
# 35    TFFIF      SET                     SET      909
# 54      TFG      SET                     SET      910
# 12      TMT      SET          sSET / SETTHSI      921
# 4     WHAIR      SET                     SET      802
# 14    WHART      SET                     SET      945

# %%
filter_all = pd.concat([filter_50, filter_100, filter_mai, filter_set], axis=0)
type(filter_all)
# Out:
# pandas.core.frame.DataFrame

# %%
filter_all.to_sql('filter_all', engine1, if_exists='replace')

# %%
sql = '''
UPDATE stocks
  SET
    market = (SELECT filter_all.market_x FROM filter_all WHERE filter_all.name = stocks.name)
'''
rp = conlite.execute(sql)
rp.rowcount
# Out:
# 63
