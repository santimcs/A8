# %% [markdown]
# ### portpg: stocks
# ### stock:  price

# %% [markdown]
# ### Restart & Run All Cells

# %%
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine1 = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine1.connect()

engine2 = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine2.connect()

pd.set_option('display.float_format','{:,.2f}'.format)

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"

today = date.today()
week_str = today.strftime('%Y-%U')
today, week_str
# Out:
# (datetime.date(2022, 4, 14), '2022-15')

# %%
sql = '''
SELECT name, market
FROM stocks
'''
stocks_lite = pd.read_sql(sql, conlite)
stocks_lite
# Out:
#       name  market
# 0      MCS     SET
# 1    PTTGC   SET50
# 2    JASIF     SET
# 3      DIF     SET
# 4    HREIT     SET
# 5     MEGA  SET100
# 6      JMT  SET100
# 7     GULF   SET50
# 8    TISCO   SET50
# 9      TQM  SET100
# 10     STA  SET100
# 11   RATCH   SET50
# 12     SCC   SET50
# 13     NER     SET
# 14   SYNEX  SET100
# 15     BCH  SET100
# 16  DOHOME  SET100
# 17     PTT   SET50
# 18     RJH     SET
# 19  SINGER  SET100
# 20     KCE   SET50
# 21   KBANK   SET50
# 22     TMT     SET
# 23   STARK  SET100
# 24     RCL  SET100
# 25      IP     mai
# 26   SPALI  SET100
# 27     SVI     SET
# 28     ASK     SET
# 29   WHART     SET
# 30     BBL   SET50
# 31     SCB   SET50
# 32   CPNCG     SET
# 33     ASP     SET
# 34     KKP  SET100
# 35    SCCC     SET
# 36     SNC     SET
# 37   MAKRO     SET
# 38   ASIAN     SET
# 39     BAM  SET100
# 40    BDMS   SET50
# 41     CHG  SET100
# 42  GLOBAL   SET50
# 43    SENA     SET
# 44   TPIPL     SET
# 45      TU   SET50
# 46   VIBHA     SET
# 47   AMATA  SET100
# 48     ORI  SET100
# 49     PTL     SET
# 50  AIMIRT     SET
# 51   JMART  SET100
# 52     BAY     SET
# 53      EA   SET50
# 54      SC     SET

# %%
sql = '''
SELECT name, market, id
FROM stocks
'''
stocks_pg = pd.read_sql(sql, conpg)
stocks_pg.shape[0]
# Out:
# 339

# %%
df_merge = pd.merge(stocks_lite, stocks_pg, on='name', how='inner')
df_merge.shape[0]
# Out:
# 55

# %%
set50 = df_merge.market_y.str.contains('SET50')
filter_50 = df_merge[set50].copy()
filter_50['market_x'] = 'SET50'
filter_50.sort_values(by=['name'],ascending=[True])
# Out:
#       name market_x                                       market_y   id
# 30     BBL    SET50                    SET50 / SETHD / SETTHSI       54
# 40    BDMS    SET50          SET50 / SETCLMV / SETTHSI / SETWB       58
# 53      EA    SET50                            SET50 / SETTHSI      153
# 42  GLOBAL    SET50          SET50 / SETCLMV / SETTHSI / SETWB      198
# 7     GULF    SET50                  SET50 / SETCLMV / SETTHSI      207
# 21   KBANK    SET50                  SET50 / SETCLMV / SETTHSI      253
# 20     KCE    SET50                                      SET50      256
# 17     PTT    SET50          SET50 / SETCLMV / SETHD / SETTHSI      389
# 1    PTTGC    SET50                  SET50 / SETCLMV / SETTHSI      391
# 11   RATCH    SET50          SET50 / SETCLMV / SETHD / SETTHSI      399
# 31     SCB    SET50                  SET50 / SETCLMV / SETTHSI      432
# 12     SCC    SET50          SET50 / SETCLMV / SETHD / SETTHSI      433
# 8    TISCO    SET50                    SET50 / SETHD / SETTHSI      539
# 45      TU    SET50  SET50 / SETCLMV / SETHD / SETTHSI / SETWB      591

# %%
set100 = df_merge.market_y.str.contains('SET100')
filter_100 = df_merge[set100].copy()
filter_100['market_x'] = 'SET100'
filter_100.sort_values(by=['name'],ascending=[True])
# Out:
#       name market_x                                market_y   id
# 47   AMATA   SET100          SET100 / SETCLMV / SETTHSI       24
# 39     BAM   SET100                              SET100      680
# 15     BCH   SET100                      SET100 / SETWB       55
# 41     CHG   SET100                      SET100 / SETWB      101
# 16  DOHOME   SET100                      SET100 / SETWB      670
# 51   JMART   SET100                              SET100      244
# 6      JMT   SET100                              SET100      245
# 34     KKP   SET100  SET100 / SETCLMV / SETHD / SETTHSI      262
# 5     MEGA   SET100            SET100 / SETCLMV / SETWB      303
# 48     ORI   SET100            SET100 / SETHD / SETTHSI      347
# 24     RCL   SET100                    SET100 / SETCLMV      401
# 19  SINGER   SET100                              SET100      452
# 26   SPALI   SET100                      SET100 / SETHD      470
# 10     STA   SET100            SET100 / SETTHSI / SETWB      489
# 23   STARK   SET100                    SET100 / SETCLMV      712
# 14   SYNEX   SET100                    SET100 / SETTHSI      504
# 9      TQM   SET100                    SET100 / SETTHSI      664

# %%
setmai = df_merge.market_y.str.contains('mai')
filter_mai = df_merge[setmai].copy()
filter_mai['market_x'] = 'mai'
filter_mai.sort_values(by=['name'],ascending=[True])
# Out:
#    name market_x market_y   id
# 25   IP      mai  mai      713

# %%
filter_set = df_merge[~(set100 | set50 | setmai)].copy()
filter_set['market_x'] = 'SET'
filter_set.sort_values(by=['name'],ascending=[True])
# Out:
#       name market_x               market_y   id
# 50  AIMIRT      SET                SET       13
# 38   ASIAN      SET     sSET / SETTHSI       40
# 28     ASK      SET                SET       42
# 33     ASP      SET               sSET       44
# 52     BAY      SET                SET       53
# 32   CPNCG      SET                SET      126
# 3      DIF      SET                SET      146
# 4    HREIT      SET                SET      217
# 2    JASIF      SET                SET      241
# 37   MAKRO      SET                SET      291
# 0      MCS      SET               sSET      301
# 13     NER      SET               sSET      651
# 49     PTL      SET                SET      388
# 18     RJH      SET               sSET      404
# 54      SC      SET     sSET / SETTHSI      431
# 35    SCCC      SET  SETCLMV / SETTHSI      434
# 43    SENA      SET               sSET      443
# 36     SNC      SET     sSET / SETTHSI      465
# 27     SVI      SET                SET      500
# 22     TMT      SET     sSET / SETTHSI      553
# 44   TPIPL      SET                SET      568
# 46   VIBHA      SET              SETWB      619
# 29   WHART      SET                SET      630

# %%
filter_all = pd.concat([filter_50, filter_100, filter_mai, filter_set], axis=0)
type(filter_all)
# Out:
# pandas.core.frame.DataFrame

# %%
filter_all.to_sql('filter_all', engine1, if_exists='replace')

# %%
sql = '''
UPDATE stocks
  SET
    market = (SELECT filter_all.market_x FROM filter_all WHERE filter_all.name = stocks.name)
'''
rp = conlite.execute(sql)
rp.rowcount
# Out:
# 55
