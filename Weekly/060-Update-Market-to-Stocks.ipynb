# %% [markdown]
# ### portpg: stocks
# ### stock:  price

# %% [markdown]
# ### Restart & Run All Cells

# %%
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine1 = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine1.connect()

engine2 = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine2.connect()

pd.set_option('display.float_format','{:,.2f}'.format)

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"

today = date.today()
week_str = today.strftime('%Y-%U')
today, week_str
# Out:
# (datetime.date(2022, 7, 31), '2022-31')

# %%
sql = '''
SELECT name, market
FROM stocks
'''
stocks_lite = pd.read_sql(sql, conlite)
stocks_lite
# Out:
#       name  market
# 0      MCS     SET
# 1    PTTGC   SET50
# 2    JASIF     SET
# 3      DIF     SET
# 4    WHAIR     SET
# 5     MEGA  SET100
# 6     GULF   SET50
# 7    TISCO   SET50
# 8      STA  SET100
# 9      SCC   SET50
# 10     NER     SET
# 11   SYNEX  SET100
# 12     BCH  SET100
# 13  DOHOME  SET100
# 14  SINGER  SET100
# 15     KCE   SET50
# 16     TMT     SET
# 17     RCL  SET100
# 18   WHART     SET
# 19     ASP     SET
# 20    SCCC     SET
# 21     SNC     SET
# 22   MAKRO     SET
# 23    SENA     SET
# 24   TPIPL     SET
# 25     ORI  SET100
# 26     DCC     SET
# 27     AIT     SET
# 28     ASK     SET
# 29     BAY     SET
# 30    BCPG  SET100
# 31      BH   SET50
# 32     BPP     SET
# 33    ESSO  SET100
# 34     GGC     SET
# 35     IVL   SET50
# 36     MST     SET
# 37    SMPC     SET
# 38    SPRC  SET100
# 39     TOP   SET50
# 40     RBF  SET100
# 41   COTTO     SET
# 42     BGC     SET
# 43      AP  SET100
# 44   BANPU   SET50
# 45     SSP     SET
# 46  STANLY     SET
# 47   DELTA   SET50
# 48     TTB   SET50

# %%
sql = '''
SELECT name, market, id
FROM stocks
'''
stocks_pg = pd.read_sql(sql, conpg)
stocks_pg
# Out:
#         name                                         market   id
# 0      CPALL                    SET50 / SETTHSI / SETWB      767
# 1        CPF  SET50 / SETCLMV / SETHD / SETTHSI / SETWB      768
# 2        CPN                            SET50 / SETTHSI      769
# 3      CPNCG                                        SET      770
# 4    CPNREIT                                        SET      771
# ..       ...                                            ...  ...
# 225      PTT          SET50 / SETCLMV / SETHD / SETTHSI      864
# 226      SCB                  SET50 / SETCLMV / SETTHSI      949
# 227      SKR                                        SET      889
# 228      SSP                             sSET / SETCLMV      897
# 229       TU            SET50 / SETCLMV / SETHD / SETWB      936
#
# [230 rows x 3 columns]

# %%
df_merge = pd.merge(stocks_lite, stocks_pg, on='name', how='inner')
df_merge
# Out:
#       name market_x                                market_y   id
# 0      MCS      SET                                sSET      842
# 1    PTTGC    SET50           SET50 / SETCLMV / SETTHSI      866
# 2    JASIF      SET                                 SET      814
# 3      DIF      SET                                 SET      777
# 4    WHAIR      SET                                 SET      802
# 5     MEGA   SET100            SET100 / SETCLMV / SETWB      843
# 6     GULF    SET50           SET50 / SETCLMV / SETTHSI      796
# 7    TISCO    SET50             SET50 / SETHD / SETTHSI      917
# 8      STA   SET100            SET100 / SETTHSI / SETWB      898
# 9      SCC    SET50   SET50 / SETCLMV / SETHD / SETTHSI      879
# 10     NER      SET                                sSET      847
# 11   SYNEX   SET100                    SET100 / SETTHSI      906
# 12     BCH   SET100    SET100 / SETCLMV / SETHD / SETWB      741
# 13  DOHOME   SET100                      SET100 / SETWB      778
# 14  SINGER   SET100                      SET100 / SETWB      885
# 15     KCE    SET50                               SET50      819
# 16     TMT      SET                      sSET / SETTHSI      921
# 17     RCL   SET100            SET100 / SETCLMV / SETWB      870
# 18   WHART      SET                                 SET      945
# 19     ASP      SET                                sSET      733
# 20    SCCC      SET                   SETCLMV / SETTHSI      880
# 21     SNC      SET                      sSET / SETTHSI      891
# 22   MAKRO      SET                                 SET      839
# 23    SENA      SET                                sSET      882
# 24   TPIPL      SET                                 SET      925
# 25     ORI   SET100            SET100 / SETHD / SETTHSI      851
# 26     DCC      SET                                 SET      774
# 27     AIT      SET                                sSET      724
# 28     ASK      SET                                 SET      732
# 29     BAY      SET                                 SET      739
# 30    BCPG   SET100  SET100 / SETCLMV / SETHD / SETTHSI      743
# 31      BH    SET50             SET50 / SETCLMV / SETWB      752
# 32     BPP      SET                   SETCLMV / SETTHSI      757
# 33    ESSO   SET100                              SET100      787
# 34     GGC      SET                                 SET      792
# 35     IVL    SET50                     SET50 / SETTHSI      813
# 36     MST      SET                                 SET      845
# 37    SMPC      SET                                sSET      890
# 38    SPRC   SET100                    SET100 / SETCLMV      895
# 39     TOP    SET50           SET50 / SETCLMV / SETTHSI      924
# 40     RBF   SET100            SET100 / SETCLMV / SETWB      869
# 41   COTTO      SET                                 SET      766
# 42     BGC      SET            sSET / SETCLMV / SETTHSI      750
# 43      AP   SET100                      SET100 / SETHD      730
# 44   BANPU    SET50           SET50 / SETCLMV / SETTHSI      738
# 45     SSP      SET                      sSET / SETCLMV      897
# 46  STANLY      SET                                sSET      899
# 47   DELTA    SET50                                 SET      776
# 48     TTB    SET50             SET50 / SETHD / SETTHSI      933

# %%
set50 = df_merge.market_y.str.contains('SET50')
filter_50 = df_merge[set50].copy()
filter_50['market_x'] = 'SET50'
filter_50.sort_values(by=['name'],ascending=[True])
# Out:
#      name market_x                               market_y   id
# 44  BANPU    SET50          SET50 / SETCLMV / SETTHSI      738
# 31     BH    SET50            SET50 / SETCLMV / SETWB      752
# 6    GULF    SET50          SET50 / SETCLMV / SETTHSI      796
# 35    IVL    SET50                    SET50 / SETTHSI      813
# 15    KCE    SET50                              SET50      819
# 1   PTTGC    SET50          SET50 / SETCLMV / SETTHSI      866
# 9     SCC    SET50  SET50 / SETCLMV / SETHD / SETTHSI      879
# 7   TISCO    SET50            SET50 / SETHD / SETTHSI      917
# 39    TOP    SET50          SET50 / SETCLMV / SETTHSI      924
# 48    TTB    SET50            SET50 / SETHD / SETTHSI      933

# %%
set100 = df_merge.market_y.str.contains('SET100')
filter_100 = df_merge[set100].copy()
filter_100['market_x'] = 'SET100'
filter_100.sort_values(by=['name'],ascending=[True])
# Out:
#       name market_x                                market_y   id
# 43      AP   SET100                      SET100 / SETHD      730
# 12     BCH   SET100    SET100 / SETCLMV / SETHD / SETWB      741
# 30    BCPG   SET100  SET100 / SETCLMV / SETHD / SETTHSI      743
# 13  DOHOME   SET100                      SET100 / SETWB      778
# 33    ESSO   SET100                              SET100      787
# 5     MEGA   SET100            SET100 / SETCLMV / SETWB      843
# 25     ORI   SET100            SET100 / SETHD / SETTHSI      851
# 40     RBF   SET100            SET100 / SETCLMV / SETWB      869
# 17     RCL   SET100            SET100 / SETCLMV / SETWB      870
# 14  SINGER   SET100                      SET100 / SETWB      885
# 38    SPRC   SET100                    SET100 / SETCLMV      895
# 8      STA   SET100            SET100 / SETTHSI / SETWB      898
# 11   SYNEX   SET100                    SET100 / SETTHSI      906

# %%
setmai = df_merge.market_y.str.contains('mai')
filter_mai = df_merge[setmai].copy()
filter_mai['market_x'] = 'mai'
filter_mai.sort_values(by=['name'],ascending=[True])
# Out:
# Empty DataFrame
# Columns: [name, market_x, market_y, id]
# Index: []

# %%
filter_set = df_merge[~(set100 | set50 | setmai)].copy()
filter_set['market_x'] = 'SET'
filter_set.sort_values(by=['name'],ascending=[True])
# Out:
#       name market_x                      market_y   id
# 27     AIT      SET                      sSET      724
# 28     ASK      SET                       SET      732
# 19     ASP      SET                      sSET      733
# 29     BAY      SET                       SET      739
# 42     BGC      SET  sSET / SETCLMV / SETTHSI      750
# 32     BPP      SET         SETCLMV / SETTHSI      757
# 41   COTTO      SET                       SET      766
# 26     DCC      SET                       SET      774
# 47   DELTA      SET                       SET      776
# 3      DIF      SET                       SET      777
# 34     GGC      SET                       SET      792
# 2    JASIF      SET                       SET      814
# 22   MAKRO      SET                       SET      839
# 0      MCS      SET                      sSET      842
# 36     MST      SET                       SET      845
# 10     NER      SET                      sSET      847
# 20    SCCC      SET         SETCLMV / SETTHSI      880
# 23    SENA      SET                      sSET      882
# 37    SMPC      SET                      sSET      890
# 21     SNC      SET            sSET / SETTHSI      891
# 45     SSP      SET            sSET / SETCLMV      897
# 46  STANLY      SET                      sSET      899
# 16     TMT      SET            sSET / SETTHSI      921
# 24   TPIPL      SET                       SET      925
# 4    WHAIR      SET                       SET      802
# 18   WHART      SET                       SET      945

# %%
filter_all = pd.concat([filter_50, filter_100, filter_mai, filter_set], axis=0)
type(filter_all)
# Out:
# pandas.core.frame.DataFrame

# %%
filter_all.to_sql('filter_all', engine1, if_exists='replace')

# %%
sql = '''
UPDATE stocks
  SET
    market = (SELECT filter_all.market_x FROM filter_all WHERE filter_all.name = stocks.name)
'''
rp = conlite.execute(sql)
rp.rowcount
# Out:
# 49
