# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

pd.set_option('display.max_row',None)

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2022, 12, 13), datetime.date(2022, 12, 12))

# %%
#today = today - timedelta(days=4)
#wkago = today - timedelta(days=5)
wkago = date(2022, 12, 9)
today, wkago
# Out:
# (datetime.date(2022, 12, 13), datetime.date(2022, 12, 9))

# %% [markdown]
# ### Get past one quarter data

# %%
sql = """
SELECT name
FROM buy 
ORDER BY name
"""
df = pd.read_sql(sql, const)

names = df['name'].values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'ASP', 'BCH', 'CPNREIT', 'DCC', 'DIF', 'DOHOME', 'GVREIT', 'IVL', 'JASIF', 'KCE', 'MAKRO', 'MCS', 'NER', 'ORI', 'PTTGC', 'RCL', 'SCC', 'SCCC', 'SENA', 'STA', 'SYNEX', 'TFFIF', 'TMT', 'WHAIR', 'WHART'"

# %%
one_qtr_ago = yesterday - timedelta(days=90)
one_qtr_ago

sql = """
SELECT * 
FROM price 
WHERE date >= '%s' AND name IN (%s) 
ORDER BY name, date"""
sql = sql % (one_qtr_ago, in_p)
print(sql)
# Out:
# SELECT *
# FROM price
# WHERE date >= '2022-08-25' AND name IN ('ASP', 'BCH', 'CPNREIT', 'DCC', 'DIF', 'DOHOME', 'GVREIT', 'IVL', 'JASIF', 'KCE', 'MAKRO', 'MCS', 'NER', 'ORI', 'PTTGC', 'RCL', 'SCC', 'SCCC', 'SENA', 'STA', 'SYNEX', 'TMT', 'WHAIR', 'WHART')
# ORDER BY name, date

# %%
df = pd.read_sql(sql, const)
df.shape
# Out:
# (1488, 7)

# %%
data_path = "../data/"
file_name = "Quarterly-Price-by-Name.csv"
output_file = data_path + file_name

df.set_index("name", inplace=True)
df.to_csv(output_file, header=None)

# %% [markdown]
# ### Command Line Call Lwr-Dly & Upr-Dly Process

# %%
name = 'BCH'

# %%
data_path = "../csv/"
file_name   = name + '-lower.csv'
input_file = data_path + file_name
col_names   = ['name','fm_date','to_date','days','fm_price','to_price','chg_amt','chg_pct','spd','avg','maxp','minp','qty']
df_lower = pd.read_csv(input_file, sep=',',  index_col=None, names=col_names)
df_lower.sort_values(by=['to_date'],ascending=[False])
# Out:
#    name     fm_date     to_date  days  fm_price  to_price  chg_amt  chg_pct  \
# 12  BCH  2022-11-18  2022-11-22     2      20.0      19.8     -0.2    -1.00
# 11  BCH  2022-11-16  2022-11-17     1      20.2      19.8     -0.4    -1.98
# 10  BCH  2022-11-10  2022-11-11     1      19.8      19.7     -0.1    -0.51
# 9   BCH  2022-11-01  2022-11-09     6      18.9      18.8     -0.1    -0.53
# 8   BCH  2022-10-20  2022-10-21     1      17.7      17.5     -0.2    -1.13
# 7   BCH  2022-10-18  2022-10-19     1      17.4      17.3     -0.1    -0.57
# 6   BCH  2022-10-05  2022-10-17     8      17.4      17.1     -0.3    -1.72
# 5   BCH  2022-09-30  2022-10-03     1      17.8      16.9     -0.9    -5.06
# 4   BCH  2022-09-22  2022-09-29     5      18.8      17.7     -1.1    -5.85
# 3   BCH  2022-09-12  2022-09-20     6      19.1      18.4     -0.7    -3.66
# 2   BCH  2022-09-05  2022-09-08     3      19.1      18.8     -0.3    -1.57
# 1   BCH  2022-08-30  2022-08-31     1      18.9      18.7     -0.2    -1.06
# 0   BCH  2022-08-25  2022-08-29     2      19.0      18.6     -0.4    -2.11
#
#     spd  avg  maxp  minp       qty
# 12   -2   -1  20.0  19.6  26462118
# 11   -4   -4  20.2  19.7  23300894
# 10   -1   -1  19.9  19.2  27478078
# 9    -1   -1  19.0  18.6  76018418
# 8    -2   -2  17.7  17.3   9562143
# 7    -1   -1  17.5  17.2   8416496
# 6    -3   -1  17.5  17.0  50005270
# 5    -9   -9  17.9  16.8  29450223
# 4   -11   -3  18.9  17.6  72494693
# 3    -7   -2  19.2  18.3  87311400
# 2    -3   -1  19.1  18.8  40588611
# 1    -2   -2  18.7  18.4  27432072
# 0    -4   -2  19.0  18.5  65738431

# %%
df_lower[df_lower['chg_pct'] <= -5].sort_values(by=['to_date'],ascending=[False])
# Out:
#   name     fm_date     to_date  days  fm_price  to_price  chg_amt  chg_pct  \
# 5  BCH  2022-09-30  2022-10-03     1      17.8      16.9     -0.9    -5.06
# 4  BCH  2022-09-22  2022-09-29     5      18.8      17.7     -1.1    -5.85
#
#    spd  avg  maxp  minp       qty
# 5   -9   -9  17.9  16.8  29450223
# 4  -11   -3  18.9  17.6  72494693

# %%
data_path = "../csv/"
file_name   = name + '-upper.csv'
input_file = data_path + file_name
col_names   = ['name','fm_date','to_date','days','fm_price','to_price','chg_amt','chg_pct','spd','avg','maxp','minp','qty']
df_upper = pd.read_csv(input_file, sep=',',  index_col=None, names=col_names)
df_upper.sort_values(by=['to_date'],ascending=[False])
# Out:
#    name     fm_date     to_date  days  fm_price  to_price  chg_amt  chg_pct  \
# 12  BCH  2022-11-22  2022-11-23     1      19.8      19.9      0.1     0.51
# 11  BCH  2022-11-17  2022-11-18     1      19.8      20.0      0.2     1.01
# 10  BCH  2022-11-11  2022-11-16     3      19.7      20.2      0.5     2.54
# 9   BCH  2022-11-02  2022-11-10     6      18.8      19.8      1.0     5.32
# 8   BCH  2022-10-21  2022-11-01     7      17.5      18.9      1.4     8.00
# 7   BCH  2022-10-19  2022-10-20     1      17.3      17.7      0.4     2.31
# 6   BCH  2022-10-17  2022-10-18     1      17.1      17.4      0.3     1.75
# 5   BCH  2022-10-03  2022-10-06     3      16.9      17.4      0.5     2.96
# 4   BCH  2022-09-28  2022-09-30     2      17.7      17.8      0.1     0.56
# 3   BCH  2022-09-20  2022-09-22     2      18.4      18.8      0.4     2.17
# 2   BCH  2022-09-07  2022-09-14     5      18.8      19.1      0.3     1.60
# 1   BCH  2022-08-31  2022-09-05     3      18.7      19.1      0.4     2.14
# 0   BCH  2022-08-29  2022-08-30     1      18.6      18.9      0.3     1.61
#
#     spd  avg  maxp  minp        qty
# 12    1    1  19.9  19.6    6852693
# 11    2    2  20.0  19.7   11704205
# 10    5    1  20.2  19.4   64092517
# 9    10    1  19.8  18.0  134188555
# 8    14    2  18.9  17.4  117355423
# 7     4    4  17.9  17.3   23858988
# 6     3    3  17.6  17.1    7548778
# 5     5    1  17.5  16.8   44289533
# 4     1    0  18.0  17.6   23017271
# 3     4    2  18.9  18.4   21642091
# 2     3    0  19.2  18.8   43339513
# 1     4    1  19.2  18.7   72408097
# 0     3    3  18.9  18.7   16334785

# %%
df_upper[df_upper['chg_pct'] >= 5].sort_values(by=['to_date'],ascending=[False])
# Out:
#    name     fm_date     to_date  days  fm_price  to_price  chg_amt  chg_pct  \
# 47  BCH  2022-11-02  2022-11-10     6      18.8      19.8      1.0     5.32
# 46  BCH  2022-10-21  2022-11-01     7      17.5      18.9      1.4     8.00
# 30  BCH  2022-06-30  2022-07-06     4      18.7      20.5      1.8     9.63
# 29  BCH  2022-06-22  2022-06-24     2      18.0      18.9      0.9     5.00
# 26  BCH  2022-05-26  2022-05-31     3      18.6      20.3      1.7     9.14
# 24  BCH  2022-05-12  2022-05-13     1      19.0      20.0      1.0     5.26
# 18  BCH  2022-04-05  2022-04-11     4      20.7      22.4      1.7     8.21
# 15  BCH  2022-03-09  2022-03-21     8      20.1      21.8      1.7     8.46
# 13  BCH  2022-02-25  2022-03-03     4      19.0      20.0      1.0     5.26
# 12  BCH  2022-02-11  2022-02-22     7      18.0      19.6      1.6     8.89
# 6   BCH  2022-01-04  2022-01-06     2      19.5      20.9      1.4     7.18
# 1   BCH  2021-11-24  2021-11-29     3      19.8      21.7      1.9     9.60
#
#     spd  avg  maxp  minp        qty
# 47   10    1  19.8  18.0  134188555
# 46   14    2  18.9  17.4  117355423
# 30   18    4  20.6  18.6  132411590
# 29    9    4  18.9  17.9   31811393
# 26   17    5  20.3  18.5   68412358
# 24   10   10  20.0  19.2   21122243
# 18   17    4  22.5  20.7   95303263
# 15   17    2  21.9  20.0  250948593
# 13   10    2  20.0  19.0  114753239
# 12   16    2  19.9  17.7  171293904
# 6    14    7  21.1  19.4  113988193
# 1    19    6  22.1  19.6  182702673

# %% [markdown]
# ### Concat

# %%
frames = [df_lower, df_upper]
result = pd.concat(frames)
result.sort_values(by=['to_date'],ascending=[False])
# Out:
#    name     fm_date     to_date  days  fm_price  to_price  chg_amt  chg_pct  \
# 49  BCH  2022-11-17  2022-11-18     1      19.8      20.0      0.2     1.01
# 48  BCH  2022-11-16  2022-11-17     1      20.2      19.8     -0.4    -1.98
# 48  BCH  2022-11-11  2022-11-16     3      19.7      20.2      0.5     2.54
# 1    -3   -3  21.8  21.0   48941981
# 1    19    6  22.1  19.6  182702673
# 0    -2   -1  20.1  19.8   11591198
# 0     1    1  20.0  19.7   22211823

# %% [markdown]
# ### Sales table in port_lite

# %%
sql = """
SELECT *
FROM sales
WHERE to_date = '%s'"""
sql = sql % today
print(sql)
df_sales = pd.read_sql(sql, conlite)
df_sales
# Out:
# SELECT *
# FROM sales
# WHERE to_date = '2022-10-26'
#          id     name     fm_date     to_date  days  fm_price  to_price  diff  \
# 0   1175891      ASP  2022-10-20  2022-10-26     4      3.00      3.02  0.02
# 1   1176469   GVREIT  2022-10-07  2022-10-26    13      8.95      8.70 -0.25
# 2   1176639    JASIF  2022-10-18  2022-10-26     6      8.35      7.90 -0.45
# 3   1176747    LANNA  2022-10-20  2022-10-26     4     19.40     18.70 -0.70
# 4   1176927      PTT  2022-10-17  2022-10-26     7     34.25     35.00  0.75
# 5   1177013    PTTGC  2022-10-20  2022-10-26     4     41.50     42.00  0.50
# 6   1177341     SCCC  2022-10-20  2022-10-26     4    146.50    151.00  4.50
# 7   1177538      STA  2022-10-19  2022-10-26     5     18.60     18.20 -0.40
# 8   1177632      TTB  2022-10-11  2022-10-26    11      1.20      1.38  0.18
# 9   1177633      BCH  2022-10-21  2022-10-26     3     17.50     18.40  0.90
# 10  1177634      IVL  2022-10-21  2022-10-26     3     40.50     41.00  0.50
# 11  1177636      BLA  2022-10-21  2022-10-26     3     32.75     32.25 -0.50
# 12  1177637      MCS  2022-10-21  2022-10-26     3      9.95      9.55 -0.40
# 13  1177638  CPNREIT  2022-10-25  2022-10-26     1     18.30     18.60  0.30
# 14  1177639      RCL  2022-10-25  2022-10-26     1     27.75     28.50  0.75
# 15  1177640      SSP  2022-10-25  2022-10-26     1      9.55      9.65  0.10
# 16  1177641      ASK  2022-10-25  2022-10-26     1     31.75     32.00  0.25
# 17  1177642    BANPU  2022-10-25  2022-10-26     1     12.40     12.50  0.10
# 18  1177643      SCB  2022-10-25  2022-10-26     1    105.50    106.00  0.50
# 19  1177644      BAM  2022-10-25  2022-10-26     1     15.20     15.10 -0.10
#
#       pct  ttl_spread  avg_spread  max_price  min_price         qty  \
# 0    0.67           1           0       3.04       0.67    12755179
# 1   -2.79          -5          -1       8.75      -2.79      819748
# 2   -5.39          -9          -2       8.00      -5.39    29270550
# 3   -3.61          -7          -2      18.90      -3.09     6232371
# 4    2.19           3           0      35.25       2.19   246286312
# 5    1.20           2           0      42.25       1.20    27357397
# 6    3.07           9           2     151.00       2.39      277652
# 7   -2.15          -4          -1      18.50      -1.61     5181136
# 8   15.00          18           1       1.38       1.32  4010738608
# 9    5.14           9           3      18.50       0.57    38378280
# 10   1.23           2           0      41.00       0.62    16783938
# 11  -1.53          -2          -1      32.50      -0.76    11318396
# 12  -4.02          -8          -3       9.75      -2.51     4590749
# 13   1.64           3           3      18.60      18.30      453707
# 14   2.70           3           3      29.00      27.75     5210719
