# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

format_dict = {
               'price':'{:.2f}','buy_p':'{:.2f}','sell_p':'{:.2f}','diff':'{:.2f}',
               'ppu':'{:.4f}',
               'net':'{:,.2f}','fee':'{:,.2f}','vat':'{:,.2f}',
               'buy_amt':'{:,.2f}','sell_amt':'{:,.2f}','profit':'{:,.2f}',
               'div_amt':'{:,.2f}','ttl_amt':'{:,.2f}','pct':'{:,.2f}',
               'qty':'{:,}','number':'{:,}','days':'{:,}'
              }
pd.set_option("display.max_rows", None)

cols = 'name ttl_qty buy_amt ppu div_amt buy_date x_date p_date days pct year quarter'.split()
colt = 'name ttl_qty buy_amt ppu div_amt buy_date x_date p_date days pct year quarter number'.split()

# %%
name = 'JASIF'

# %% [markdown]
# ### 1ST Batch

# %%
div_year = 2018
div_quarter = 1
ids = '515'

# %%
sql = '''
SELECT T.name, SUM(qty) AS ttl_qty, 
SUM(B.net) AS buy_amt, MIN(date) AS buy_date
FROM buys B
JOIN stocks T ON B.stock_id = T.id 
WHERE B.id IN (%s)
GROUP BY T.name'''
sql = sql % (ids)
buys = pd.read_sql(sql, conpf)
buys
# Out:
#     name  ttl_qty    buy_amt    buy_date
# 0  JASIF  60000.0  601328.94  2018-05-17

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name = '%s'
AND ((year = %s AND quarter >= %s) 
OR (year > %s))
ORDER BY name, year DESC, quarter DESC
"""
sql = sql % (name, div_year, div_quarter, div_year)
dividends = pd.read_sql(sql, conpf)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col0" class="data row0 col0" >198</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col2" class="data row0 col2" >2020</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col3" class="data row0 col3" >4</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col4" class="data row0 col4" >130,000</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2500</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col6" class="data row0 col6" >32,500.00</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col7" class="data row0 col7" >2021-02-24</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow0_col8" class="data row0 col8" >2021-03-15</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col0" class="data row1 col0" >191</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col2" class="data row1 col2" >2020</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col4" class="data row1 col4" >130,000</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2500</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col6" class="data row1 col6" >32,500.00</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col7" class="data row1 col7" >2020-11-18</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow1_col8" class="data row1 col8" >2020-12-04</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col0" class="data row2 col0" >101</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col1" class="data row2 col1" >JASIF</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col2" class="data row2 col2" >2020</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col3" class="data row2 col3" >2</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col4" class="data row2 col4" >100,000</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col5" class="data row2 col5" >0.2500</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col6" class="data row2 col6" >25,000.00</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col7" class="data row2 col7" >2020-09-22</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow2_col8" class="data row2 col8" >2020-09-22</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col0" class="data row3 col0" >5</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col1" class="data row3 col1" >JASIF</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col2" class="data row3 col2" >2020</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col4" class="data row3 col4" >100,000</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col5" class="data row3 col5" >0.2400</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col6" class="data row3 col6" >24,000.00</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col7" class="data row3 col7" >2020-06-15</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow3_col8" class="data row3 col8" >2020-06-15</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col0" class="data row4 col0" >30</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col1" class="data row4 col1" >JASIF</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col2" class="data row4 col2" >2019</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col3" class="data row4 col3" >4</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col4" class="data row4 col4" >130,000</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col5" class="data row4 col5" >0.2000</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col6" class="data row4 col6" >26,000.00</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col7" class="data row4 col7" >2020-03-04</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow4_col8" class="data row4 col8" >2020-03-04</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col0" class="data row5 col0" >37</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col1" class="data row5 col1" >JASIF</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col2" class="data row5 col2" >2019</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col3" class="data row5 col3" >3</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col4" class="data row5 col4" >90,000</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col5" class="data row5 col5" >0.2300</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col6" class="data row5 col6" >20,700.00</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col7" class="data row5 col7" >2019-12-02</td>
#                         <td id="T_b1a3d433_bd25_11eb_b629_5ebaef7ebc1brow5_col8" class="data row5 col8" >2019-12-02</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a3d433_bd25_11eb

# %%
df_merge = pd.merge(buys, dividends, on='name', how='inner')
df_merge['div_amt'] = df_merge.ppu * df_merge.ttl_qty
df_merge['days'] = df_merge.p_date - df_merge.buy_date
df_merge['days'] = df_merge['days']/np.timedelta64(1,'D')
df_merge['days'] = df_merge['days'].astype(int)
df_merge['pct'] = round(df_merge['div_amt']/df_merge['buy_amt']*36500/df_merge['days'],2)
df_merge[cols]
# Out:
#      name  ttl_qty    buy_amt   ppu  div_amt    buy_date      x_date  \
# 0   JASIF  60000.0  601328.94  0.25  15000.0  2018-05-17  2021-02-24
# 1   JASIF  60000.0  601328.94  0.25  15000.0  2018-05-17  2020-11-18
# 2   JASIF  60000.0  601328.94  0.25  15000.0  2018-05-17  2020-09-22
# 3   JASIF  60000.0  601328.94  0.24  14400.0  2018-05-17  2020-06-15
# 4   JASIF  60000.0  601328.94  0.20  12000.0  2018-05-17  2020-03-04
# 5   JASIF  60000.0  601328.94  0.23  13800.0  2018-05-17  2019-12-02
# 6   JASIF  60000.0  601328.94  0.23  13800.0  2018-05-17  2019-09-05
# 7   JASIF  60000.0  601328.94  0.24  14400.0  2018-05-17  2019-06-07
# 8   JASIF  60000.0  601328.94  0.23  13800.0  2018-05-17  2019-03-19
# 9   JASIF  60000.0  601328.94  0.22  13200.0  2018-05-17  2018-12-11
# 10  JASIF  60000.0  601328.94  0.23  13800.0  2018-05-17  2018-09-11
# 11  JASIF  60000.0  601328.94  0.22  13200.0  2018-05-17  2018-06-12
#
#         p_date  days    pct  year  quarter
# 0   2021-03-15  1033   0.88  2020        4
# 1   2020-12-04   932   0.98  2020        3
# 2   2020-09-22   859   1.06  2020        2
# 3   2020-06-15   760   1.15  2020        1
# 4   2020-03-04   657   1.11  2019        4
# 5   2019-12-02   564   1.49  2019        3
# 6   2019-09-05   476   1.76  2019        2
# 7   2019-06-07   386   2.26  2019        1
# 8   2019-03-19   306   2.74  2018        4
# 9   2018-12-11   208   3.85  2018        3
# 10  2018-09-11   117   7.16  2018        2
# 11  2018-06-12    26  30.82  2018        1

# %%
df_grp =df_merge.groupby(['name'])['div_amt'].sum()
div1 = df_grp
div1
# Out:
# name
# JASIF    167400.0
# Name: div_amt, dtype: float64

# %%
file_name = 'div-' + name + '.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
data_file, output_file, box_file
# Out:
# ('../data/div-JASIF.csv',
#  '\\Users\\User\\iCloudDrive\\div-JASIF.csv',
#  '\\Users\\User\\Dropbox\\div-JASIF.csv')

# %%
df_merge[colt].to_csv(output_file)
df_merge[colt].to_csv(data_file)
df_merge[colt].to_csv(box_file)

# %% [markdown]
# ### Second batch of purchase

# %%
div_year = 2018
div_quarter = 2
to_div_quarter = 3
ids = '516'

# %%
sql = '''
SELECT T.name, SUM(qty) AS ttl_qty, 
SUM(B.net) AS buy_amt, MIN(date) AS buy_date
FROM buys B
JOIN stocks T ON B.stock_id = T.id 
WHERE B.id IN (%s)
GROUP BY T.name'''
sql = sql % (ids)
buys = pd.read_sql(sql, conpf)
buys
# Out:
#     name  ttl_qty    buy_amt    buy_date
# 0  JASIF  10000.0  100221.49  2018-09-01

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name = '%s'
AND ((year = %s AND quarter = %s) 
OR (year = %s AND quarter = %s))
ORDER BY name, year DESC, quarter DESC
"""
sql = sql % (name, div_year, div_quarter, div_year, to_div_quarter)
dividends = pd.read_sql(sql, conpf)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col0" class="data row0 col0" >82</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col2" class="data row0 col2" >2018</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col3" class="data row0 col3" >3</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col4" class="data row0 col4" >70,000</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2200</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col6" class="data row0 col6" >15,400.00</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col7" class="data row0 col7" >2018-12-11</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow0_col8" class="data row0 col8" >2018-12-11</td>
#             </tr>
#             <tr>
#                         <th id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col0" class="data row1 col0" >93</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col2" class="data row1 col2" >2018</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col3" class="data row1 col3" >2</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col4" class="data row1 col4" >70,000</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2300</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col6" class="data row1 col6" >16,100.00</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col7" class="data row1 col7" >2018-09-11</td>
#                         <td id="T_2c277633_bd27_11eb_b273_5ebaef7ebc1brow1_col8" class="data row1 col8" >2018-09-11</td>
#             </tr>
#     </tbody></table>

# %%
df_merge = pd.merge(buys, dividends, on='name', how='inner')
df_merge['div_amt'] = df_merge.ppu * df_merge.ttl_qty
df_merge['days'] = df_merge.p_date - df_merge.buy_date
df_merge['days'] = df_merge['days']/np.timedelta64(1,'D')
df_merge['days'] = df_merge['days'].astype(int)
df_merge['pct'] = round(df_merge['div_amt']/df_merge['buy_amt']*36500/df_merge['days'],2)
df_merge[cols]
# Out:
#     name  ttl_qty    buy_amt   ppu  div_amt    buy_date      x_date  \
# 0  JASIF  10000.0  100221.49  0.22   2200.0  2018-09-01  2018-12-11
# 1  JASIF  10000.0  100221.49  0.23   2300.0  2018-09-01  2018-09-11
#
#        p_date  days    pct  year  quarter
# 0  2018-12-11   101   7.93  2018        3
# 1  2018-09-11    10  83.76  2018        2

# %%
df_grp =df_merge.groupby(['name'])['div_amt'].sum()
div2 = df_grp
div2
# Out:
# name
# JASIF    4500.0
# Name: div_amt, dtype: float64

# %%
df_merge[colt].to_csv(output_file,mode='a',header=False)
df_merge[colt].to_csv(data_file,mode='a',header=False)
df_merge[colt].to_csv(box_file,mode='a',header=False)

# %% [markdown]
# ### Third batch of purchase (must change qty of record 516 to zero)

# %%
div_year = 2019
div_quarter = 3
ids = '517'

# %%
sql = '''
SELECT T.name, SUM(qty) AS ttl_qty, 
SUM(B.net) AS buy_amt, MIN(date) AS buy_date
FROM buys B
JOIN stocks T ON B.stock_id = T.id 
WHERE B.id IN (%s)
GROUP BY T.name'''
sql = sql % (ids)
buys = pd.read_sql(sql, conpf)
buys
# Out:
#     name  ttl_qty    buy_amt    buy_date
# 0  JASIF  30000.0  300664.47  2019-12-01

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name = '%s'
AND ((year = %s AND quarter >= %s) 
OR (year > %s))
ORDER BY name, year DESC, quarter DESC
"""
sql = sql % (name, div_year, div_quarter, div_year)
dividends = pd.read_sql(sql, conpf)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col0" class="data row0 col0" >198</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col2" class="data row0 col2" >2020</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col3" class="data row0 col3" >4</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col4" class="data row0 col4" >130,000</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2500</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col6" class="data row0 col6" >32,500.00</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col7" class="data row0 col7" >2021-02-24</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow0_col8" class="data row0 col8" >2021-03-15</td>
#             </tr>
#             <tr>
#                         <th id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col0" class="data row1 col0" >191</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col2" class="data row1 col2" >2020</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col4" class="data row1 col4" >130,000</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2500</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col6" class="data row1 col6" >32,500.00</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col7" class="data row1 col7" >2020-11-18</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow1_col8" class="data row1 col8" >2020-12-04</td>
#             </tr>
#             <tr>
#                         <th id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col0" class="data row2 col0" >101</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col1" class="data row2 col1" >JASIF</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col2" class="data row2 col2" >2020</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col3" class="data row2 col3" >2</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col4" class="data row2 col4" >100,000</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col5" class="data row2 col5" >0.2500</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col6" class="data row2 col6" >25,000.00</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col7" class="data row2 col7" >2020-09-22</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow2_col8" class="data row2 col8" >2020-09-22</td>
#             </tr>
#             <tr>
#                         <th id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col0" class="data row3 col0" >5</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col1" class="data row3 col1" >JASIF</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col2" class="data row3 col2" >2020</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col4" class="data row3 col4" >100,000</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col5" class="data row3 col5" >0.2400</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col6" class="data row3 col6" >24,000.00</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col7" class="data row3 col7" >2020-06-15</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow3_col8" class="data row3 col8" >2020-06-15</td>
#             </tr>
#             <tr>
#                         <th id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col0" class="data row4 col0" >30</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col1" class="data row4 col1" >JASIF</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col2" class="data row4 col2" >2019</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col3" class="data row4 col3" >4</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col4" class="data row4 col4" >130,000</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col5" class="data row4 col5" >0.2000</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col6" class="data row4 col6" >26,000.00</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col7" class="data row4 col7" >2020-03-04</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow4_col8" class="data row4 col8" >2020-03-04</td>
#             </tr>
#             <tr>
#                         <th id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col0" class="data row5 col0" >37</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col1" class="data row5 col1" >JASIF</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col2" class="data row5 col2" >2019</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col3" class="data row5 col3" >3</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col4" class="data row5 col4" >90,000</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col5" class="data row5 col5" >0.2300</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col6" class="data row5 col6" >20,700.00</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col7" class="data row5 col7" >2019-12-02</td>
#                         <td id="T_f382abd9_bd27_11eb_84dc_5ebaef7ebc1brow5_col8" class="data row5 col8" >2019-12-02</td>
#             </tr>
#     </tbody></table>

# %%
df_merge = pd.merge(buys, dividends, on='name', how='inner')
df_merge['div_amt'] = df_merge.ppu * df_merge.ttl_qty
df_merge['days'] = df_merge.p_date - df_merge.buy_date
df_merge['days'] = df_merge['days']/np.timedelta64(1,'D')
df_merge['days'] = df_merge['days'].astype(int)
df_merge['pct'] = round(df_merge['div_amt']/df_merge['buy_amt']*36500/df_merge['days'],2)
df_merge[cols]
# Out:
#     name  ttl_qty    buy_amt   ppu  div_amt    buy_date      x_date  \
# 0  JASIF  30000.0  300664.47  0.25   7500.0  2019-12-01  2021-02-24
# 1  JASIF  30000.0  300664.47  0.25   7500.0  2019-12-01  2020-11-18
# 2  JASIF  30000.0  300664.47  0.25   7500.0  2019-12-01  2020-09-22
# 3  JASIF  30000.0  300664.47  0.24   7200.0  2019-12-01  2020-06-15
# 4  JASIF  30000.0  300664.47  0.20   6000.0  2019-12-01  2020-03-04
# 5  JASIF  30000.0  300664.47  0.23   6900.0  2019-12-01  2019-12-02
#
#        p_date  days     pct  year  quarter
# 0  2021-03-15   470    1.94  2020        4
# 1  2020-12-04   369    2.47  2020        3
# 2  2020-09-22   296    3.08  2020        2
# 3  2020-06-15   197    4.44  2020        1
# 4  2020-03-04    94    7.75  2019        4
# 5  2019-12-02     1  837.64  2019        3

# %%
df_grp =df_merge.groupby(['name'])['div_amt'].sum()
div3 = df_grp
div3
# Out:
# name
# JASIF    42600.0
# Name: div_amt, dtype: float64

# %%
df_merge[colt].to_csv(output_file,mode='a',header=False)
df_merge[colt].to_csv(data_file,mode='a',header=False)
df_merge[colt].to_csv(box_file,mode='a',header=False)

# %% [markdown]
# ### 4th Batch

# %%
div_year = 2019
div_quarter = 4
ids = '769'

# %%
sql = '''
SELECT T.name, SUM(qty) AS ttl_qty, 
SUM(B.net) AS buy_amt, MIN(date) AS buy_date
FROM buys B
JOIN stocks T ON B.stock_id = T.id 
WHERE B.id IN (%s)
GROUP BY T.name'''
sql = sql % (ids)
buys = pd.read_sql(sql, conpf)
buys
# Out:
#     name  ttl_qty    buy_amt    buy_date
# 0  JASIF  10000.0  100221.49  2020-03-01

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name = '%s'
AND ((year = %s AND quarter >= %s) 
OR (year > %s))
ORDER BY name, year DESC, quarter DESC
"""
sql = sql % (name, div_year, div_quarter, div_year)
dividends = pd.read_sql(sql, conpf)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col0" class="data row0 col0" >198</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col2" class="data row0 col2" >2020</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col3" class="data row0 col3" >4</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col4" class="data row0 col4" >130,000</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2500</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col6" class="data row0 col6" >32,500.00</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col7" class="data row0 col7" >2021-02-24</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow0_col8" class="data row0 col8" >2021-03-15</td>
#             </tr>
#             <tr>
#                         <th id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col0" class="data row1 col0" >191</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col2" class="data row1 col2" >2020</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col4" class="data row1 col4" >130,000</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2500</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col6" class="data row1 col6" >32,500.00</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col7" class="data row1 col7" >2020-11-18</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow1_col8" class="data row1 col8" >2020-12-04</td>
#             </tr>
#             <tr>
#                         <th id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col0" class="data row2 col0" >101</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col1" class="data row2 col1" >JASIF</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col2" class="data row2 col2" >2020</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col3" class="data row2 col3" >2</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col4" class="data row2 col4" >100,000</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col5" class="data row2 col5" >0.2500</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col6" class="data row2 col6" >25,000.00</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col7" class="data row2 col7" >2020-09-22</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow2_col8" class="data row2 col8" >2020-09-22</td>
#             </tr>
#             <tr>
#                         <th id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col0" class="data row3 col0" >5</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col1" class="data row3 col1" >JASIF</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col2" class="data row3 col2" >2020</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col4" class="data row3 col4" >100,000</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col5" class="data row3 col5" >0.2400</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col6" class="data row3 col6" >24,000.00</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col7" class="data row3 col7" >2020-06-15</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow3_col8" class="data row3 col8" >2020-06-15</td>
#             </tr>
#             <tr>
#                         <th id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col0" class="data row4 col0" >30</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col1" class="data row4 col1" >JASIF</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col2" class="data row4 col2" >2019</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col3" class="data row4 col3" >4</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col4" class="data row4 col4" >130,000</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col5" class="data row4 col5" >0.2000</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col6" class="data row4 col6" >26,000.00</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col7" class="data row4 col7" >2020-03-04</td>
#                         <td id="T_34382c2a_bd2a_11eb_9212_5ebaef7ebc1brow4_col8" class="data row4 col8" >2020-03-04</td>
#             </tr>
#     </tbody></table>

# %%
df_merge = pd.merge(buys, dividends, on='name', how='inner')
df_merge['div_amt'] = df_merge.ppu * df_merge.ttl_qty
df_merge['days'] = df_merge.p_date - df_merge.buy_date
df_merge['days'] = df_merge['days']/np.timedelta64(1,'D')
df_merge['days'] = df_merge['days'].astype(int)
df_merge['pct'] = round(df_merge['div_amt']/df_merge['buy_amt']*36500/df_merge['days'],2)
df_merge[cols]
# Out:
#     name  ttl_qty    buy_amt   ppu  div_amt    buy_date      x_date  \
# 0  JASIF  10000.0  100221.49  0.25   2500.0  2020-03-01  2021-02-24
# 1  JASIF  10000.0  100221.49  0.25   2500.0  2020-03-01  2020-11-18
# 2  JASIF  10000.0  100221.49  0.25   2500.0  2020-03-01  2020-09-22
# 3  JASIF  10000.0  100221.49  0.24   2400.0  2020-03-01  2020-06-15
# 4  JASIF  10000.0  100221.49  0.20   2000.0  2020-03-01  2020-03-04
#
#        p_date  days     pct  year  quarter
# 0  2021-03-15   379    2.40  2020        4
# 1  2020-12-04   278    3.28  2020        3
# 2  2020-09-22   205    4.44  2020        2
# 3  2020-06-15   106    8.25  2020        1
# 4  2020-03-04     3  242.80  2019        4

# %%
df_grp =df_merge.groupby(['name'])['div_amt'].sum()
div4 = df_grp
div4
# Out:
# name
# JASIF    11900.0
# Name: div_amt, dtype: float64

# %%
df_merge[colt].to_csv(output_file,mode='a',header=False)
df_merge[colt].to_csv(data_file,mode='a',header=False)
df_merge[colt].to_csv(box_file,mode='a',header=False)

# %% [markdown]
# ### 5th Batch

# %%
div_year = 2020
div_quarter = 3
ids = '767'

# %%
sql = '''
SELECT T.name, SUM(qty) AS ttl_qty, 
SUM(B.net) AS buy_amt, MIN(date) AS buy_date
FROM buys B
JOIN stocks T ON B.stock_id = T.id 
WHERE B.id IN (%s)
GROUP BY T.name'''
sql = sql % (ids)
buys = pd.read_sql(sql, conpf)
buys
# Out:
#     name  ttl_qty    buy_amt    buy_date
# 0  JASIF  30000.0  300664.47  2020-11-01

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name = '%s'
AND ((year = %s AND quarter >= %s) 
OR (year > %s))
ORDER BY name, year DESC, quarter DESC
"""
sql = sql % (name, div_year, div_quarter, div_year)
dividends = pd.read_sql(sql, conpf)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col0" class="data row0 col0" >198</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col2" class="data row0 col2" >2020</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col3" class="data row0 col3" >4</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col4" class="data row0 col4" >130,000</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2500</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col6" class="data row0 col6" >32,500.00</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col7" class="data row0 col7" >2021-02-24</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow0_col8" class="data row0 col8" >2021-03-15</td>
#             </tr>
#             <tr>
#                         <th id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col0" class="data row1 col0" >191</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col2" class="data row1 col2" >2020</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col4" class="data row1 col4" >130,000</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2500</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col6" class="data row1 col6" >32,500.00</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col7" class="data row1 col7" >2020-11-18</td>
#                         <td id="T_97affd52_bd2a_11eb_b206_5ebaef7ebc1brow1_col8" class="data row1 col8" >2020-12-04</td>
#             </tr>
#     </tbody></table>

# %%
df_merge = pd.merge(buys, dividends, on='name', how='inner')
df_merge['div_amt'] = df_merge.ppu * df_merge.ttl_qty
df_merge['days'] = df_merge.p_date - df_merge.buy_date
df_merge['days'] = df_merge['days']/np.timedelta64(1,'D')
df_merge['days'] = df_merge['days'].astype(int)
df_merge['pct'] = round(df_merge['div_amt']/df_merge['buy_amt']*36500/df_merge['days'],2)
df_merge[cols]
# Out:
#     name  ttl_qty    buy_amt   ppu  div_amt    buy_date      x_date  \
# 0  JASIF  30000.0  300664.47  0.25   7500.0  2020-11-01  2021-02-24
# 1  JASIF  30000.0  300664.47  0.25   7500.0  2020-11-01  2020-11-18
#
#        p_date  days    pct  year  quarter
# 0  2021-03-15   134   6.79  2020        4
# 1  2020-12-04    33  27.59  2020        3

# %%
df_grp =df_merge.groupby(['name'])['div_amt'].sum()
div5 = df_grp
div5
# Out:
# name
# JASIF    15000.0
# Name: div_amt, dtype: float64

# %%
df_merge[colt].to_csv(output_file,mode='a',header=False)
df_merge[colt].to_csv(data_file,mode='a',header=False)
df_merge[colt].to_csv(box_file,mode='a',header=False)

# %% [markdown]
# ### End of process

# %%
name = 'JASIF'
div_year = 2018
div_quarter = 1

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name = '%s'
AND ((year = %s AND quarter >= %s) 
OR (year > %s))
ORDER BY name, year, quarter
"""
sql = sql % (name, div_year, div_quarter, div_year)
dividends = pd.read_sql(sql, conpf)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col0" class="data row0 col0" >99</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col2" class="data row0 col2" >2018</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col3" class="data row0 col3" >1</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col4" class="data row0 col4" >60,000</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2200</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col6" class="data row0 col6" >13,200.00</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col7" class="data row0 col7" >2018-06-12</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow0_col8" class="data row0 col8" >2018-06-12</td>
#             </tr>
#             <tr>
#                         <th id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col0" class="data row1 col0" >93</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col2" class="data row1 col2" >2018</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col3" class="data row1 col3" >2</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col4" class="data row1 col4" >70,000</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2300</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col6" class="data row1 col6" >16,100.00</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col7" class="data row1 col7" >2018-09-11</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow1_col8" class="data row1 col8" >2018-09-11</td>
#             </tr>
#             <tr>
#                         <th id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col0" class="data row2 col0" >82</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col1" class="data row2 col1" >JASIF</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col2" class="data row2 col2" >2018</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col3" class="data row2 col3" >3</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col4" class="data row2 col4" >70,000</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col5" class="data row2 col5" >0.2200</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col6" class="data row2 col6" >15,400.00</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col7" class="data row2 col7" >2018-12-11</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow2_col8" class="data row2 col8" >2018-12-11</td>
#             </tr>
#             <tr>
#                         <th id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col0" class="data row3 col0" >75</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col1" class="data row3 col1" >JASIF</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col2" class="data row3 col2" >2018</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col3" class="data row3 col3" >4</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col4" class="data row3 col4" >60,000</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col5" class="data row3 col5" >0.2300</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col6" class="data row3 col6" >13,800.00</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col7" class="data row3 col7" >2019-03-19</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow3_col8" class="data row3 col8" >2019-03-19</td>
#             </tr>
#             <tr>
#                         <th id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col0" class="data row4 col0" >53</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col1" class="data row4 col1" >JASIF</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col2" class="data row4 col2" >2019</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col3" class="data row4 col3" >1</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col4" class="data row4 col4" >60,000</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col5" class="data row4 col5" >0.2400</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col6" class="data row4 col6" >14,400.00</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col7" class="data row4 col7" >2019-06-07</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow4_col8" class="data row4 col8" >2019-06-07</td>
#             </tr>
#             <tr>
#                         <th id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col0" class="data row5 col0" >50</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col1" class="data row5 col1" >JASIF</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col2" class="data row5 col2" >2019</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col3" class="data row5 col3" >2</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col4" class="data row5 col4" >60,000</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col5" class="data row5 col5" >0.2300</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col6" class="data row5 col6" >13,800.00</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col7" class="data row5 col7" >2019-09-05</td>
#                         <td id="T_d8d3f04f_bd2a_11eb_8bb1_5ebaef7ebc1brow5_col8" class="data row5 col8" >2019-09-05</td>
#             </tr>
#             <tr>
#                         <th id="T_d8d3f04f_bd2a_11eb_8bb1_5

# %%
dividends.div_amt.sum()
# Out:
# 247400.0
