# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

# %%
format_dict = {
               'price':'{:.2f}','buy_p':'{:.2f}','sell_p':'{:.2f}','diff':'{:.2f}',
               'ppu':'{:.4f}',
               'net':'{:,.2f}','fee':'{:,.2f}','vat':'{:,.2f}',
               'buy_amt':'{:,.2f}','cost_amt':'{:,.2f}','sell_amt':'{:,.2f}','profit':'{:,.2f}',
               'div_amt':'{:,.2f}','ttl_amt':'{:,.2f}','pct':'{:,.2f}',
               'sales_prf':'{:,.2f}','dividend':'{:,.2f}','net_div':'{:,.2f}','total_prf':'{:,.2f}',    
               'qty':'{:,}','number':'{:,}','days':'{:,}'
              }
pd.set_option("display.max_rows", None)

# %%
kind = 'DOS'
div_year = 2021
div_quarter = 1
sell_year = 2021

# %% [markdown]
# ### Stocks that are sold on specified year

# %%
sql = '''
SELECT T.name, qty, S.price AS sell_p, B.price AS buy_p, S.price - B.price AS diff,
(S.net - B.net) AS sales_prf,round(D.net * qty / number,2) AS net_div,
((S.net - B.net) + round(D.net * qty / number,2)) AS total_prf, B.net AS cost_amt,
ROUND((S.net-B.net+(D.net * qty / number))/B.net*36500/DATEDIFF(S.date,B.date),2) AS pct,
B.date AS buy_date, D.x_date, S.date AS sell_date,  DATEDIFF(S.date,B.date) AS days, number, ppu, 
S.id AS sid, dividend_id AS div_id, D.id AS did, B.kind
FROM sells S
JOIN buys B ON S.buy_id = B.id 
JOIN stocks T ON B.stock_id = T.id 
JOIN dividends D ON S.dividend_id = D.id
WHERE YEAR(s.date) = %s
AND S.date >= D.x_date
ORDER BY T.name, S.date'''
sql = sql % (sell_year)
print(sql)
# Out:
# SELECT T.name, qty, S.price AS sell_p, B.price AS buy_p, S.price - B.price AS diff,
# (S.net - B.net) AS sales_prf,round(D.net * qty / number,2) AS net_div,
# ((S.net - B.net) + round(D.net * qty / number,2)) AS total_prf, B.net AS cost_amt,
# ROUND((S.net-B.net+(D.net * qty / number))/B.net*36500/DATEDIFF(S.date,B.date),2) AS pct,
# B.date AS buy_date, D.x_date, S.date AS sell_date,  DATEDIFF(S.date,B.date) AS days, number, ppu,
# S.id AS sid, dividend_id AS div_id, D.id AS did, B.kind
# FROM sells S
# JOIN buys B ON S.buy_id = B.id
# JOIN stocks T ON B.stock_id = T.id
# JOIN dividends D ON S.dividend_id = D.id
# WHERE YEAR(s.date) = 2021
# AND S.date >= D.x_date
# ORDER BY T.name, S.date

# %%
sells = pd.read_sql(sql, conpf)
sells.sort_values(['name','sell_date'],ascending=[True,True]).style.format(format_dict)
# Out:
# <style  type="text/css" >
# ...

# %%
mask_name = sells.name == 'WHART'
filter = sells[mask_name]
cols = 'name qty sell_p buy_p diff sales_prf ppu net_div total_prf cost_amt pct buy_date x_date sell_date days number sid div_id did kind'.split()
filter[cols].style.format(format_dict)
# Out:
# <style  type="text/css" >
# ...

# %%
mask_kind = sells.kind == 'DOS'
filter = sells[mask_kind]
filter.set_index('name',inplace=True)
cols = 'qty sell_p buy_p diff sales_prf ppu net_div total_prf cost_amt pct buy_date x_date sell_date days number sid div_id did kind'.split()
filter[cols]
# Out:
#             qty  sell_p  buy_p  diff  sales_prf     ppu   net_div  total_prf  \
# name
# CPTGF     10000    8.95    8.9  0.05     104.63  0.1800   1620.00    1724.63
# DTAC       9000   32.50   33.0 -0.50   -5805.69  2.1200  17172.00   11366.31
# EGATIF    10000   12.10   12.2 -0.10   -1538.22  0.2000   2000.00     461.78
# GVREIT    18000   11.10   11.0  0.10     918.91  0.2037   3299.94    4218.85
# MBAX      20000    6.60    7.7 -1.10  -22633.46  0.5600  10080.00  -12553.46
# MC        10000   10.70   10.6  0.10     528.23  0.3500   3150.00    3678.23
# POPF      10000   11.00   10.9  0.10     514.94  0.2470   2223.00    2737.94
# SUPEREIF  10000   11.00   10.9  0.10     514.94  0.2670   2670.00    3184.94
# TIP        3000   30.25   30.0  0.25     349.66  1.3000   3510.00    3859.66
# UTP        6000   18.00   17.8  0.20     724.23  0.3900   2340.00    3064.23
# WHART     10000   11.50   11.4  0.10     492.79  0.1195   1075.50    1568.29
# ...

# %% [markdown]
# ### If found error, unbind sells from dividends

# %%
sql = '''
UPDATE sells
SET dividend_id = 0
WHERE id = 657 AND dividend_id = 219'''
#rp = conpf.execute(sql)
#rp.rowcount

# %%
file_name = 'prf-w-div.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
data_file, output_file, box_file
# Out:
# ('../data/prf-w-div.csv',
#  '\\Users\\User\\iCloudDrive\\prf-w-div.csv',
#  '\\Users\\User\\Dropbox\\prf-w-div.csv')

# %%
filter.dtypes
# Out:
# qty            int64
# sell_p       float64
# buy_p        float64
# diff         float64
# sales_prf    float64
# net_div      float64
# total_prf    float64
# cost_amt     float64
# pct          float64
# buy_date      object
# x_date        object
# sell_date     object
# days           int64
# number         int64
# ppu          float64
# sid            int64
# div_id         int64
# did            int64
# kind          object
# dtype: object

# %%
colt = 'qty ppu net_div sell_p buy_p sales_prf total_prf pct buy_date x_date sell_date days'.split()

# %%
filter[colt].to_csv(output_file)
filter[colt].to_csv(data_file)
filter[colt].to_csv(box_file)

# %%
filter[colt].to_csv(output_file,mode='a',header=False)
filter[colt].to_csv(data_file,mode='a',header=False)
filter[colt].to_csv(box_file,mode='a',header=False)
