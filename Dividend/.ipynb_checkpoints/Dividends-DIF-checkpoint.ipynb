# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

# %%
format_dict = {
               'price':'{:.2f}','buy_p':'{:.2f}','sell_p':'{:.2f}','diff':'{:.2f}',
               'ppu':'{:.4f}',
               'net':'{:,.2f}','fee':'{:,.2f}','vat':'{:,.2f}',
               'buy_amt':'{:,.2f}','sell_amt':'{:,.2f}','profit':'{:,.2f}',
               'div_amt':'{:,.2f}','ttl_amt':'{:,.2f}','pct':'{:,.2f}',
               'qty':'{:,}','number':'{:,}','days':'{:,}'
              }
pd.set_option("display.max_rows", None)

# %%
name = 'JASIF'
div_year = 2018
div_quarter = 1

# %% [markdown]
# ### Stocks that are sold on specified year

# %%
sql = '''
SELECT T.name, SUM(qty) AS ttl_qty, 
SUM(B.net) AS buy_amt, MIN(date) AS buy_date
FROM buys B
JOIN stocks T ON B.stock_id = T.id 
WHERE B.id IN (515,516,517)
GROUP BY T.name'''
print(sql)

# %%
buys = pd.read_sql(sql, conpf)
buys
# Out:
#     name   ttl_qty    buy_amt    buy_date
# 0  JASIF  100000.0  1002214.9  2018-05-17

# %% [markdown]
# ### Bind sell to dividend record process

# %%
sr = buys["name"]
names = sr.values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'JASIF'"

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name IN (%s)
AND ((year = %s AND quarter >= %s) 
OR (year > %s))
ORDER BY name, year DESC, quarter DESC
"""
#sql = sql % (in_p)
sql = sql % (in_p, div_year, div_quarter, div_year)
dividends = pd.read_sql(sql, conpf)
#dividends.set_index(['name'],inplace=True)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col0" class="data row0 col0" >198</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col2" class="data row0 col2" >2020</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col3" class="data row0 col3" >4</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col4" class="data row0 col4" >130,000</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2500</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col6" class="data row0 col6" >32,500.00</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col7" class="data row0 col7" >2021-02-24</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow0_col8" class="data row0 col8" >2021-03-15</td>
#             </tr>
#             <tr>
#                         <th id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col0" class="data row1 col0" >191</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col2" class="data row1 col2" >2020</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col4" class="data row1 col4" >130,000</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2500</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col6" class="data row1 col6" >32,500.00</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col7" class="data row1 col7" >2020-11-18</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow1_col8" class="data row1 col8" >2020-12-04</td>
#             </tr>
#             <tr>
#                         <th id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col0" class="data row2 col0" >101</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col1" class="data row2 col1" >JASIF</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col2" class="data row2 col2" >2020</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col3" class="data row2 col3" >2</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col4" class="data row2 col4" >100,000</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col5" class="data row2 col5" >0.2500</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col6" class="data row2 col6" >25,000.00</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col7" class="data row2 col7" >2020-09-22</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow2_col8" class="data row2 col8" >2020-09-22</td>
#             </tr>
#             <tr>
#                         <th id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col0" class="data row3 col0" >5</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col1" class="data row3 col1" >JASIF</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col2" class="data row3 col2" >2020</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col4" class="data row3 col4" >100,000</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col5" class="data row3 col5" >0.2400</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col6" class="data row3 col6" >24,000.00</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col7" class="data row3 col7" >2020-06-15</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow3_col8" class="data row3 col8" >2020-06-15</td>
#             </tr>
#             <tr>
#                         <th id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col0" class="data row4 col0" >30</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col1" class="data row4 col1" >JASIF</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col2" class="data row4 col2" >2019</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col3" class="data row4 col3" >4</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col4" class="data row4 col4" >130,000</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col5" class="data row4 col5" >0.2000</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col6" class="data row4 col6" >26,000.00</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col7" class="data row4 col7" >2020-03-04</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow4_col8" class="data row4 col8" >2020-03-04</td>
#             </tr>
#             <tr>
#                         <th id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col0" class="data row5 col0" >37</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col1" class="data row5 col1" >JASIF</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col2" class="data row5 col2" >2019</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col3" class="data row5 col3" >3</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col4" class="data row5 col4" >90,000</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col5" class="data row5 col5" >0.2300</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col6" class="data row5 col6" >20,700.00</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col7" class="data row5 col7" >2019-12-02</td>
#                         <td id="T_af2879df_bbaa_11eb_a263_5ebaef7ebc1brow5_col8" class="data row5 col8" >2019-12-02</td>
#             </tr>
#             <tr>
#                         <th id="T_af2879df_bbaa_11eb

# %%
df_merge = pd.merge(buys, dividends, on='name', how='inner')
df_merge
# Out:
#      name   ttl_qty    buy_amt    buy_date   id  year  quarter  number   ppu  \
# 0   JASIF  100000.0  1002214.9  2018-05-17  198  2020        4  130000  0.25
# 1   JASIF  100000.0  1002214.9  2018-05-17  191  2020        3  130000  0.25
# 2   JASIF  100000.0  1002214.9  2018-05-17  101  2020        2  100000  0.25
# 3   JASIF  100000.0  1002214.9  2018-05-17    5  2020        1  100000  0.24
# 4   JASIF  100000.0  1002214.9  2018-05-17   30  2019        4  130000  0.20
# 5   JASIF  100000.0  1002214.9  2018-05-17   37  2019        3   90000  0.23
# 6   JASIF  100000.0  1002214.9  2018-05-17   50  2019        2   60000  0.23
# 7   JASIF  100000.0  1002214.9  2018-05-17   53  2019        1   60000  0.24
# 8   JASIF  100000.0  1002214.9  2018-05-17   75  2018        4   60000  0.23
# 9   JASIF  100000.0  1002214.9  2018-05-17   82  2018        3   70000  0.22
# 10  JASIF  100000.0  1002214.9  2018-05-17   93  2018        2   70000  0.23
# 11  JASIF  100000.0  1002214.9  2018-05-17   99  2018        1   60000  0.22
#
#     div_amt      x_date      p_date
# 0   32500.0  2021-02-24  2021-03-15
# 1   32500.0  2020-11-18  2020-12-04
# 2   25000.0  2020-09-22  2020-09-22
# 3   24000.0  2020-06-15  2020-06-15
# 4   26000.0  2020-03-04  2020-03-04
# 5   20700.0  2019-12-02  2019-12-02
# 6   13800.0  2019-09-05  2019-09-05
# 7   14400.0  2019-06-07  2019-06-07
# 8   13800.0  2019-03-19  2019-03-19
# 9   15400.0  2018-12-11  2018-12-11
# 10  16100.0  2018-09-11  2018-09-11
# 11  13200.0  2018-06-12  2018-06-12

# %%
cols = 'name ttl_qty buy_amt ppu div_amt buy_date p_date days pct'.split()

# %%
df_merge['div_amt'] = df_merge.ppu * df_merge.ttl_qty
df_merge['days'] = df_merge.p_date - df_merge.buy_date
df_merge['days'] = df_merge['days']/np.timedelta64(1,'D')
df_merge['days'] = df_merge['days'].astype(int)
df_merge['pct'] = round(df_merge['div_amt']/df_merge['buy_amt']*36500/df_merge['days'],2)
df_merge[cols]
# Out:
#      name   ttl_qty    buy_amt   ppu  div_amt    buy_date      p_date  days  \
# 0   JASIF  100000.0  1002214.9  0.25  25000.0  2018-05-17  2021-03-15  1033
# 1   JASIF  100000.0  1002214.9  0.25  25000.0  2018-05-17  2020-12-04   932
# 2   JASIF  100000.0  1002214.9  0.25  25000.0  2018-05-17  2020-09-22   859
# 3   JASIF  100000.0  1002214.9  0.24  24000.0  2018-05-17  2020-06-15   760
# 4   JASIF  100000.0  1002214.9  0.20  20000.0  2018-05-17  2020-03-04   657
# 5   JASIF  100000.0  1002214.9  0.23  23000.0  2018-05-17  2019-12-02   564
# 6   JASIF  100000.0  1002214.9  0.23  23000.0  2018-05-17  2019-09-05   476
# 7   JASIF  100000.0  1002214.9  0.24  24000.0  2018-05-17  2019-06-07   386
# 8   JASIF  100000.0  1002214.9  0.23  23000.0  2018-05-17  2019-03-19   306
# 9   JASIF  100000.0  1002214.9  0.22  22000.0  2018-05-17  2018-12-11   208
# 10  JASIF  100000.0  1002214.9  0.23  23000.0  2018-05-17  2018-09-11   117
# 11  JASIF  100000.0  1002214.9  0.22  22000.0  2018-05-17  2018-06-12    26
#
#       pct
# 0    0.88
# 1    0.98
# 2    1.06
# 3    1.15
# 4    1.11
# 5    1.49
# 6    1.76
# 7    2.26
# 8    2.74
# 9    3.85
# 10   7.16
# 11  30.82

# %%
df_grp =df_merge.groupby(['name'])['div_amt'].sum()
div1 = df_grp
div1
# Out:
# name
# JASIF    279000.0
# Name: div_amt, dtype: float64

# %%
colt = 'name ttl_qty buy_amt ppu div_amt buy_date p_date days pct'.split()

# %%
file_name = 'div-jasif.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
data_file, output_file, box_file
# Out:
# ('../data/div-jasif.csv',
#  '\\Users\\User\\iCloudDrive\\div-jasif.csv',
#  '\\Users\\User\\Dropbox\\div-jasif.csv')

# %%
df_merge[colt].to_csv(output_file)
df_merge[colt].to_csv(data_file)
df_merge[colt].to_csv(box_file)

# %% [markdown]
# ### Second batch of purchase

# %%
div_year = 2020
div_quarter = 2

# %%
sql = '''
SELECT T.name, SUM(qty) AS ttl_qty, 
SUM(B.net) AS buy_amt, MIN(date) AS buy_date
FROM buys B
JOIN stocks T ON B.stock_id = T.id 
WHERE B.id IN (767,769)
GROUP BY T.name'''
print(sql)
# Out:
# SELECT T.name, SUM(qty) AS ttl_qty,
# SUM(B.net) AS buy_amt, MIN(date) AS buy_date
# FROM buys B
# JOIN stocks T ON B.stock_id = T.id
# WHERE B.id IN (767,769)
# GROUP BY T.name

# %%
buys = pd.read_sql(sql, conpf)
buys
# Out:
#     name  ttl_qty    buy_amt    buy_date
# 0  JASIF  20000.0  200442.98  2020-09-14

# %%
sr = buys["name"]
names = sr.values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'JASIF'"

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name IN (%s)
AND ((year = %s AND quarter >= %s) 
OR (year > %s))
ORDER BY name, year DESC, quarter DESC
"""
sql = sql % (in_p, div_year, div_quarter, div_year)
dividends = pd.read_sql(sql, conpf)
#dividends.set_index(['name'],inplace=True)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_11425107_bbac_11eb_9524_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11425107_bbac_11eb_9524_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col0" class="data row0 col0" >198</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col2" class="data row0 col2" >2020</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col3" class="data row0 col3" >4</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col4" class="data row0 col4" >130,000</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2500</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col6" class="data row0 col6" >32,500.00</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col7" class="data row0 col7" >2021-02-24</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow0_col8" class="data row0 col8" >2021-03-15</td>
#             </tr>
#             <tr>
#                         <th id="T_11425107_bbac_11eb_9524_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col0" class="data row1 col0" >191</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col2" class="data row1 col2" >2020</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col4" class="data row1 col4" >130,000</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2500</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col6" class="data row1 col6" >32,500.00</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col7" class="data row1 col7" >2020-11-18</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow1_col8" class="data row1 col8" >2020-12-04</td>
#             </tr>
#             <tr>
#                         <th id="T_11425107_bbac_11eb_9524_5ebaef7ebc1blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col0" class="data row2 col0" >101</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col1" class="data row2 col1" >JASIF</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col2" class="data row2 col2" >2020</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col3" class="data row2 col3" >2</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col4" class="data row2 col4" >100,000</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col5" class="data row2 col5" >0.2500</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col6" class="data row2 col6" >25,000.00</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col7" class="data row2 col7" >2020-09-22</td>
#                         <td id="T_11425107_bbac_11eb_9524_5ebaef7ebc1brow2_col8" class="data row2 col8" >2020-09-22</td>
#             </tr>
#     </tbody></table>

# %%
df_merge = pd.merge(buys, dividends, on='name', how='inner')
df_merge
# Out:
#     name  ttl_qty    buy_amt    buy_date   id  year  quarter  number   ppu  \
# 0  JASIF  20000.0  200442.98  2020-09-14  198  2020        4  130000  0.25
# 1  JASIF  20000.0  200442.98  2020-09-14  191  2020        3  130000  0.25
# 2  JASIF  20000.0  200442.98  2020-09-14  101  2020        2  100000  0.25
#
#    div_amt      x_date      p_date
# 0  32500.0  2021-02-24  2021-03-15
# 1  32500.0  2020-11-18  2020-12-04
# 2  25000.0  2020-09-22  2020-09-22

# %%
df_merge['div_amt'] = df_merge.ppu * df_merge.ttl_qty
df_merge['days'] = df_merge.p_date - df_merge.buy_date
df_merge['days'] = df_merge['days']/np.timedelta64(1,'D')
df_merge['days'] = df_merge['days'].astype(int)
df_merge['pct'] = round(df_merge['div_amt']/df_merge['buy_amt']*36500/df_merge['days'],2)
df_merge[cols]
# Out:
#     name  ttl_qty    buy_amt   ppu  div_amt    buy_date      p_date  days  \
# 0  JASIF  20000.0  200442.98  0.25   5000.0  2020-09-14  2021-03-15   182
# 1  JASIF  20000.0  200442.98  0.25   5000.0  2020-09-14  2020-12-04    81
# 2  JASIF  20000.0  200442.98  0.25   5000.0  2020-09-14  2020-09-22     8
#
#       pct
# 0    5.00
# 1   11.24
# 2  113.81

# %%
df_grp =df_merge.groupby(['name'])['div_amt'].sum()
div2 = df_grp
div2
# Out:
# name
# JASIF    15000.0
# Name: div_amt, dtype: float64

# %%
df_merge[colt].to_csv(output_file,mode='a',header=False)
df_merge[colt].to_csv(data_file,mode='a',header=False)
df_merge[colt].to_csv(box_file,mode='a',header=False)

# %% [markdown]
# ### Third batch of purchase

# %%
div_year = 2020
div_quarter = 3

# %%
sql = '''
SELECT T.name, SUM(qty) AS ttl_qty, 
SUM(B.net) AS buy_amt, MIN(date) AS buy_date
FROM buys B
JOIN stocks T ON B.stock_id = T.id 
WHERE B.id IN (787)
GROUP BY T.name'''
print(sql)
# Out:
# SELECT T.name, SUM(qty) AS ttl_qty,
# SUM(B.net) AS buy_amt, MIN(date) AS buy_date
# FROM buys B
# JOIN stocks T ON B.stock_id = T.id
# WHERE B.id IN (787)
# GROUP BY T.name

# %%
buys = pd.read_sql(sql, conpf)
buys
# Out:
#     name  ttl_qty    buy_amt    buy_date
# 0  JASIF  10000.0  100221.49  2020-11-11

# %%
sr = buys["name"]
names = sr.values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'JASIF'"

# %%
sql = """
SELECT id, name, year, quarter, number, ppu, net AS div_amt, x_date, p_date
FROM dividends
WHERE name IN (%s)
AND ((year = %s AND quarter >= %s) 
OR (year > %s))
ORDER BY name, year DESC, quarter DESC
"""
sql = sql % (in_p, div_year, div_quarter, div_year)
dividends = pd.read_sql(sql, conpf)
dividends.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >year</th>        <th class="col_heading level0 col3" >quarter</th>        <th class="col_heading level0 col4" >number</th>        <th class="col_heading level0 col5" >ppu</th>        <th class="col_heading level0 col6" >div_amt</th>        <th class="col_heading level0 col7" >x_date</th>        <th class="col_heading level0 col8" >p_date</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col0" class="data row0 col0" >198</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col1" class="data row0 col1" >JASIF</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col2" class="data row0 col2" >2020</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col3" class="data row0 col3" >4</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col4" class="data row0 col4" >130,000</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col5" class="data row0 col5" >0.2500</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col6" class="data row0 col6" >32,500.00</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col7" class="data row0 col7" >2021-02-24</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow0_col8" class="data row0 col8" >2021-03-15</td>
#             </tr>
#             <tr>
#                         <th id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col0" class="data row1 col0" >191</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col1" class="data row1 col1" >JASIF</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col2" class="data row1 col2" >2020</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col4" class="data row1 col4" >130,000</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col5" class="data row1 col5" >0.2500</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col6" class="data row1 col6" >32,500.00</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col7" class="data row1 col7" >2020-11-18</td>
#                         <td id="T_40e9b262_bbad_11eb_a318_5ebaef7ebc1brow1_col8" class="data row1 col8" >2020-12-04</td>
#             </tr>
#     </tbody></table>

# %%
df_merge = pd.merge(buys, dividends, on='name', how='inner')
df_merge
# Out:
#     name  ttl_qty    buy_amt    buy_date   id  year  quarter  number   ppu  \
# 0  JASIF  10000.0  100221.49  2020-11-11  198  2020        4  130000  0.25
# 1  JASIF  10000.0  100221.49  2020-11-11  191  2020        3  130000  0.25
#
#    div_amt      x_date      p_date
# 0  32500.0  2021-02-24  2021-03-15
# 1  32500.0  2020-11-18  2020-12-04

# %%
df_merge['div_amt'] = df_merge.ppu * df_merge.ttl_qty
df_merge['days'] = df_merge.p_date - df_merge.buy_date
df_merge['days'] = df_merge['days']/np.timedelta64(1,'D')
df_merge['days'] = df_merge['days'].astype(int)
df_merge['pct'] = round(df_merge['div_amt']/df_merge['buy_amt']*36500/df_merge['days'],2)
df_merge[cols]
# Out:
#     name  ttl_qty    buy_amt   ppu  div_amt    buy_date      p_date  days  \
# 0  JASIF  10000.0  100221.49  0.25   2500.0  2020-11-11  2021-03-15   124
# 1  JASIF  10000.0  100221.49  0.25   2500.0  2020-11-11  2020-12-04    23
#
#      pct
# 0   7.34
# 1  39.59

# %%
df_grp =df_merge.groupby(['name'])['div_amt'].sum()
div3 = df_grp
div3
# Out:
# name
# JASIF    5000.0
# Name: div_amt, dtype: float64

# %%
df_merge[colt].to_csv(output_file,mode='a',header=False)
df_merge[colt].to_csv(data_file,mode='a',header=False)
df_merge[colt].to_csv(box_file,mode='a',header=False)
