# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from glob import glob

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()

engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

pd.set_option('max_rows',None)

data_path = "../data/"

# %%
year = 2021
quarter = 3
year, quarter
# Out:
# (2021, 3)

# %%
sql = """
SELECT name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, ticker_id
FROM epss
WHERE year = %s AND quarter = %s
ORDER BY name
"""
sql = sql % (year, quarter)
epss = pd.read_sql(sql, conlt)
epss.shape
# Out:
# (339, 8)

# %%
epss['grade'] = 0
epss.columns
# Out:
# Index(['name', 'year', 'quarter', 'q_amt', 'y_amt', 'aq_amt', 'ay_amt',
#        'ticker_id', 'grade'],
#       dtype='object')

# %%
def grade(vals):
    qc, qp, aqc, aqp = vals
    if aqc >= aqp:
        if qc >= qp:
            return 1
        else:
            return 2
    else:
        if qc < qp:
            return 4
        else:
            return 3

# %%
epss["grade"] = epss[["q_amt", "y_amt","aq_amt", "ay_amt"]].apply(grade, axis=1)
epss.shape
# Out:
# (339, 9)

# %%
mask1 = epss["grade"] == 1
epss[mask1].shape
# Out:
# (178, 9)

# %%
mask2 = epss["grade"] == 2
epss[mask2].shape
# Out:
# (64, 9)

# %%
mask3 = epss["grade"] == 3
epss[mask3].shape
# Out:
# (18, 9)

# %%
mask4 = epss["grade"] == 4
epss[mask4].shape
# Out:
# (79, 9)

# %%
g4 = epss[mask4]
g4.sort_values(by='name',ascending=True)
# Out:
#          name  year  quarter    q_amt    y_amt    aq_amt    ay_amt  ticker_id  \
# 1         AAV  2021        3 -2098280 -1836836  -5654741  -3649643        732
# 3      ADVANC  2021        3  6374062  6512671  20058768  20269979          6
# 8          AJ  2021        3   -40687   161276    232939    376017         12
# 13      AMATA  2021        3   228699   268949    661503    706845         21
# 15       ANAN  2021        3  -251932   292328   -237330   -132180         23
# 16        AOT  2021        3 -4078474 -2933905 -11164537   8048456         24
# 20      ARROW  2021        3    21810    38231    124424    136299         31
# 27         BA  2021        3 -6976909 -1569113  -8408459  -4882489         45
# 28       BAFS  2021        3  -199130  -179606   -563114   -253123         46
# 39        BEM  2021        3   108382   821598    614184   1481502         57
# 45        BJC  2021        3   367144  1062362   2202205   2647775         65
# 46        BKI  2021        3  -885306   761572    824694   2362677         68
# 51        CBG  2021        3   601200   969607   2268088   2651891         87
# 62      CPALL  2021        3  1493009  3997703   6281763  12529841        116
# 63        CPF  2021        3 -5374323  7474412   6308438  19613857        117
# 65        CPN  2021        3   229183  2480539   5332402   7539651        121
# 66      CPNCG  2021        3    95741   122396    280146    379315        122
# 67    CPNREIT  2021        3  -845932  -493762   -282281    351586        647
# 70        CSC  2021        3    43214    79324    164134    204556        127
# 77      DELTA  2021        3  1191265  2642094   4603421   5520092        138
# 82       DTAC  2021        3   832029  1435662   3184855   4826057        144
# 88       EGCO  2021        3  1073796  2267431   3169664   6929107        157
# 94     FSMART  2021        3    95010   122935    319282    353768        178
# 98       GFPT  2021        3   -87286   342068    155147    889680        187
# 100     GLAND  2021        3   145073   178248    454434    658887        192
# 112       HTC  2021        3   125509   168338    459979    480874        212
# 133     JASIF  2021        3  1674580  2469911   5526806   6498413        234
# 137    JUBILE  2021        3    30404    96352    118309    178823        240
# 152      LHSC  2021        3  -141793   101192    -70914    124127        272
# 153       LIT  2021        3    -1371    16360      1373     51877        273
# 155       LPN  2021        3    26458   102534    270308    472942        276
# 157         M  2021        3  -257391   464969   -268078    557993        279
# 160      MBAX  2021        3    35634    60117     25051    160320        288
# 175     NOBLE  2021        3   149606   523987    935504   1238292        328
# 177       NTV  2021        3    17124    66353     87406    155185        332
# 182       OSP  2021        3   580199   923336   2404026   2653526        681
# 186       PDG  2021        3    11213    13416     42645     77053        347
# 190     PLANB  2021        3   -53515     1092    -87189        24        358
# 192      POPF  2021        3   112538   138916    253726    458970        364
# 193      PORT  2021        3    12213    23437     27124     37610        658
# 198       PSH  2021        3   330563   603397   1364168   1942106        377
# 200       PTG  2021        3    63001   509011   1092092   1222243        381
# 204        QH  2021        3   262938   575040   1175744   1543626        388
# 205      QHHR  2021        3    -3309    34014     24529     80978        692
# 207       RBF  2021        3   133598   140946    316596    397261        703
# 213        RS  2021        3     -345   130607    193466    425702        408
# 217       S11  2021        3   108081   120435    301346    395156        412
# 218    SABINA  2021        3    55168    85768    196224    206657        413
# 220    SAMART  2021        3  -109958   -59588   -291274   -220592        416
# 231       SCN  2021        3     2391    13135     41419     46798        431
# 232      SENA  2021        3   166420   278213    613251    737476        437
# 233        SF  2021        3   123298   268660    908822    922576        438
# 241       SKE  2021        3     3103     6809     21529     32618        660
# 245      SMPC  2021        3   166896   180459    455539    508968        455
# 249    SORKON  2021        3     8813    39408     92473    103910        459
# 252      SPCG  2021        3   540838   684843   1877976   2097126        464
# 256    SPRIME  2021        3    78163   191466    318411    392732        705
# 263      STEC  2021        3   136078   234510    334981    624791        484
# 266       SUN  2021        3    53200    86162    143125    153099        667
# 268  SUPEREIF  2021        3    37194   172644    378328    664816        706
# 270       SVH  2021        3   366928   406143   1077566   1103169        490
# 275     TASCO  2021        3   378435  1862393   1668115   2797550        502
# 278     TFFIF  2021        3   240117   279526    955665   1136027        686
# 279       TFG  2021        3  -455631  1062633    419435   2134956        513
# 280    TFMAMA  2021        3   984331   987676   2707305   3135126        695
# 281     THANI  2021        3   400950   472194   1255439   1380348        522
# 284      THRE  2021        3  -331346    74297   -213516    161435        525
# 287      TIF1  2021        3    13912    15552     25101     31792        718
# 288     TIPCO  2021        3   100937   335606    308117    358889        530
# 292       TKN  2021        3    19253    88902     97695    263492        533
# 298       TOA  2021        3   268181   523606   1482548   1538165        645
# 302     TPIPP  2021        3   942973  1206335   3192055   3345131        560
# 306      TRUE  2021        3  -602813   104157  -1482755   1205216        571
# 321       UTP  2021        3   216597   240125    739917    774012        605
# 322        UV  2021        3   -57860    34298     32419     93922        606
# 330       WHA  2021        3   160313   428558    555227   1069874        619
# 336        WP  2021        3    14543    62799     74573    120871        697
# 337     YUASA  2021        3    10072    49311     73315     98979        630
# 338       ZEN  2021        3   -61752    45543   -100894    -79642        689
#
#      grade
# 1        4
# 3        4
# 8        4
# 13       4
# 15       4
# 16       4
# 20       4
# 27       4
# 28       4
# 39       4
# 45       4
# 46       4
# 51       4
# 62       4
# 63       4
# 65       4
# 66       4
# 67       4
# 70       4
# 77       4
# 82       4
# 88       4
# 94       4
# 98       4
# 100      4
# 112      4
# 133      4
# 137      4
# 152      4
# 153      4
# 155      4
# 157      4
# 160      4
# 175      4
# 177      4
# 182      4
# 186      4
# 190      4
# 192      4
# 193      4
# 198      4
# 200      4
# 204      4
# 205      4
# 207      4
# 213      4
# 217      4
# 218      4
# 220      4
# 231      4
# 232      4
# 233      4
# 241      4
# 245      4
# 249      4
# 252      4
# 256      4
# 263      4
# 266      4
# 268      4
# 270      4
# 275      4
# 278      4
# 279      4
# 280      4
# 281      4
# 284      4
# 287      4
# 288      4
# 292      4
# 298      4
# 302      4
# 306      4
# 321      4
# 322      4
# 330      4
# 336      4
# 337      4
# 338      4

# %% [markdown]
# ### New feature: Exempt SET50 & SET100

# %%
sql = '''
SELECT name, market
FROM stocks
ORDER BY name'''
lt_stocks = pd.read_sql(sql, conlt)
lt_stocks.shape
# Out:
# (356, 2)

# %%
filters = [
   (lt_stocks.market.str.contains('SET50')),
   (lt_stocks.market.str.contains('SET100'))    
]
values = ['SET50','SET100']
lt_stocks["mrkt"] = np.select(filters, values, default='SETMAI')

# %%
g4.dtypes
# Out:
# name         object
# year          int64
# quarter       int64
# q_amt         int64
# y_amt         int64
# aq_amt        int64
# ay_amt        int64
# ticker_id     int64
# grade         int64
# dtype: object

# %%
g4_merge = pd.merge(g4,lt_stocks,on='name',how='inner')
g4_merge.dtypes
# Out:
# name         object
# year          int64
# quarter       int64
# q_amt         int64
# y_amt         int64
# aq_amt        int64
# ay_amt        int64
# ticker_id     int64
# grade         int64
# market       object
# mrkt         object
# dtype: object

# %%
mrkt_mask = g4_merge['mrkt'] == 'SETMAI'
g4_filter = g4_merge[mrkt_mask].copy()
g4_filter.shape
# Out:
# (54, 11)

# %%
format_dict = {
               'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}'
}
pd.set_option("display.max_rows", None)

# %%
g4_filter.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2fba6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >aq_amt</th>
#       <th class="col_heading level0 col6" >ay_amt</th>
#       <th class="col_heading level0 col7" >ticker_id</th>
#       <th class="col_heading level0 col8" >grade</th>
#       <th class="col_heading level0 col9" >market</th>
#       <th class="col_heading level0 col10" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fba6_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_2fba6_row0_col0" class="data row0 col0" >AJ</td>
#       <td id="T_2fba6_row0_col1" class="data row0 col1" >2021</td>
#       <td id="T_2fba6_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_2fba6_row0_col3" class="data row0 col3" >-40,687</td>
#       <td id="T_2fba6_row0_col4" class="data row0 col4" >161,276</td>
#       <td id="T_2fba6_row0_col5" class="data row0 col5" >232,939</td>
#       <td id="T_2fba6_row0_col6" class="data row0 col6" >376,017</td>
#       <td id="T_2fba6_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_2fba6_row0_col8" class="data row0 col8" >4</td>
#       <td id="T_2fba6_row0_col9" class="data row0 col9" >sSET / SETCLMV    </td>
#       <td id="T_2fba6_row0_col10" class="data row0 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_2fba6_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_2fba6_row1_col0" class="data row1 col0" >ANAN</td>
#       <td id="T_2fba6_row1_col1" class="data row1 col1" >2021</td>
#       <td id="T_2fba6_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_2fba6_row1_col3" class="data row1 col3" >-251,932</td>
#       <td id="T_2fba6_row1_col4" class="data row1 col4" >292,328</td>
#       <td id="T_2fba6_row1_col5" class="data row1 col5" >-237,330</td>
#       <td id="T_2fba6_row1_col6" class="data row1 col6" >-132,180</td>
#       <td id="T_2fba6_row1_col7" class="data row1 col7" >23</td>
#       <td id="T_2fba6_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_2fba6_row1_col9" class="data row1 col9" >sSET    </td>
#       <td id="T_2fba6_row1_col10" class="data row1 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_2fba6_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_2fba6_row2_col0" class="data row2 col0" >ARROW</td>
#       <td id="T_2fba6_row2_col1" class="data row2 col1" >2021</td>
#       <td id="T_2fba6_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_2fba6_row2_col3" class="data row2 col3" >21,810</td>
#       <td id="T_2fba6_row2_col4" class="data row2 col4" >38,231</td>
#       <td id="T_2fba6_row2_col5" class="data row2 col5" >124,424</td>
#       <td id="T_2fba6_row2_col6" class="data row2 col6" >136,299</td>
#       <td id="T_2fba6_row2_col7" class="data row2 col7" >31</td>
#       <td id="T_2fba6_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_2fba6_row2_col9" class="data row2 col9" >mai    </td>
#       <td id="T_2fba6_row2_col10" class="data row2 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_2fba6_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_2fba6_row3_col0" class="data row3 col0" >BA</td>
#       <td id="T_2fba6_row3_col1" class="data row3 col1" >2021</td>
#       <td id="T_2fba6_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_2fba6_row3_col3" class="data row3 col3" >-6,976,909</td>
#       <td id="T_2fba6_row3_col4" class="data row3 col4" >-1,569,113</td>
#       <td id="T_2fba6_row3_col5" class="data row3 col5" >-8,408,459</td>
#       <td id="T_2fba6_row3_col6" class="data row3 col6" >-4,882,489</td>
#       <td id="T_2fba6_row3_col7" class="data row3 col7" >45</td>
#       <td id="T_2fba6_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_2fba6_row3_col9" class="data row3 col9" >sSET    </td>
#       <td id="T_2fba6_row3_col10" class="data row3 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_2fba6_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_2fba6_row4_col0" class="data row4 col0" >BAFS</td>
#       <td id="T_2fba6_row4_col1" class="data row4 col1" >2021</td>
#       <td id="T_2fba6_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_2fba6_row4_col3" class="data row4 col3" >-199,130</td>
#       <td id="T_2fba6_row4_col4" class="data row4 col4" >-179,606</td>
#       <td id="T_2fba6_row4_col5" class="data row4 col5" >-563,114</td>
#       <td id="T_2fba6_row4_col6" class="data row4 col6" >-253,123</td>
#       <td id="T_2fba6_row4_col7" class="data row4 col7" >46</td>
#       <td id="T_2fba6_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_2fba6_row4_col9" class="data row4 col9" >sSET / SETTHSI    </td>
#       <td id="T_2fba6_row4_col10" class="data row4 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_2fba6_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_2fba6_row5_col0" class="data row5 col0" >BKI</td>
#       <td id="T_2fba6_row5_col1" class="data row5 col1" >2021</td>
#       <td id="T_2fba6_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_2fba6_row5_col3" class="data row5 col3" >-885,306</td>
#       <td id="T_2fba6_row5_col4" class="data row5 col4" >761,572</td>
#       <td id="T_2fba6_row5_col5" class="data row5 col5" >824,694</td>
#       <td id="T_2fba6_row5_col6" class="data row5 col6" >2,362,677</td>
#       <td id="T_2fba6_row5_col7" class="data row5 col7" >68</td>
#       <td id="T_2fba6_row5_col8" class="data row5 col8" >4</td>
#       <td id="T_2fba6_row5_col9" class="data row5 col9" >SET    </td>
#       <td id="T_2fba6_row5_col10" class="data row5 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_2fba6_level0_row6" class="row_heading level0 row6" >16</th>
#       <td id="T_2fba6_row6_col0" class="data row6 col0" >CPNCG</td>
#       <td id="T_2fba6_row6_col1" class="data row6 col1" >2021</td>
#       <td id="T_2fba6_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_2fba6_row6_col3" class="data row6 col3" >95,741</td>
#       <td id="T_2fba6_row6_col4" class="data row6 col4" >122,396</td>
#       <td id="T_2fba6_row6_col5" class="data row6 col5" >280,146</td>
#       <td id="T_2fba6_row6_col6" class="data row6 col6" >379,315</td>
#       <td id="T_2fba6_row6_col7" class="data row6 col7" >122</td>
#       <td id="T_2fba6_row6_col8" class="data row6 col8" >4</td>
#       <td id="T_2fba6_row6_col9" class="data row6 col9" >SET    </td>
#       <td id="T_2fba6_row6_col10" class="data row6 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_2fba6_level0_row7" class="row_heading level0 row7" >17</th>
#       <td id="T_2fba6_row7_col0" class="data row7 col0" >CPNREIT</td>
#       <td id="T_2fba6_row7_col1" class="data row7 col1" >2021</td>
#       <td id="T_2fba6_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_2fba6_row7_col3" class="data row7 col3" >-845,932</td>
#       <td id="T_2fba6_row7_col4" class="data row7 col4" >-493,762</td>
#       <td id="T_2fba6_row7_col5" class="data row7 col5" >-282,281</td>
#       <td id="T_2fba6_row7_col6" class="data row7 col6" >351,586</td>
#       <td id="T_2fba6_row7_col7" class="data row7 col7" >647</td>
#       <td id="T_2fba6_row7_col8" class="data row7 col8" >4</td>
#       <td id="T_2fba6_row7_col9" class="data row7 col9" >SET    </td>
#       <td id="T_2fba6_row7_col10" class="data row7 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_2fba6_level0_row8" class="row_heading level0 row8" >18</th>
#       <td id="T_2fba6_row8_col0" class="data row8 col0" >CSC</td>
#       <td id="T_2fba6_row8_col1" class="data row8 col1" >2021</td>
#       <td id="T_2fba6_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_2fba6_row8_col3" class="data row8 col3" >43,214</td>
#       <td id="T_2fba6_row8_col4" class="data row8 col4" >79,324</td>
#       <td id="T_2fba6_row8_col5" class="dat

# %% [markdown]
# ### End of New feature

# %%
mask41 = g4_filter.aq_amt < 300_000
g4_filter[mask41].shape
# Out:
# (32, 11)

# %%
mask42 = g4_filter.q_amt < 100_000
g4_filter[mask42].shape
# Out:
# (36, 11)

# %%
mask43 = g4_filter.ay_amt < 300_000
g4_filter[mask43].shape
# Out:
# (25, 11)

# %%
mask44 = g4_filter.market.str.contains('mai')
g4_filter[mask44].shape
# Out:
# (7, 11)

# %%
filter1 = g4_filter[mask41 & mask42 & mask43 & ~mask44]
filter1.sort_values(by='name',ascending=True).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8651_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >aq_amt</th>
#       <th class="col_heading level0 col6" >ay_amt</th>
#       <th class="col_heading level0 col7" >ticker_id</th>
#       <th class="col_heading level0 col8" >grade</th>
#       <th class="col_heading level0 col9" >market</th>
#       <th class="col_heading level0 col10" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8651_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_b8651_row0_col0" class="data row0 col0" >ANAN</td>
#       <td id="T_b8651_row0_col1" class="data row0 col1" >2021</td>
#       <td id="T_b8651_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_b8651_row0_col3" class="data row0 col3" >-251,932</td>
#       <td id="T_b8651_row0_col4" class="data row0 col4" >292,328</td>
#       <td id="T_b8651_row0_col5" class="data row0 col5" >-237,330</td>
#       <td id="T_b8651_row0_col6" class="data row0 col6" >-132,180</td>
#       <td id="T_b8651_row0_col7" class="data row0 col7" >23</td>
#       <td id="T_b8651_row0_col8" class="data row0 col8" >4</td>
#       <td id="T_b8651_row0_col9" class="data row0 col9" >sSET    </td>
#       <td id="T_b8651_row0_col10" class="data row0 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_b8651_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_b8651_row1_col0" class="data row1 col0" >BA</td>
#       <td id="T_b8651_row1_col1" class="data row1 col1" >2021</td>
#       <td id="T_b8651_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_b8651_row1_col3" class="data row1 col3" >-6,976,909</td>
#       <td id="T_b8651_row1_col4" class="data row1 col4" >-1,569,113</td>
#       <td id="T_b8651_row1_col5" class="data row1 col5" >-8,408,459</td>
#       <td id="T_b8651_row1_col6" class="data row1 col6" >-4,882,489</td>
#       <td id="T_b8651_row1_col7" class="data row1 col7" >45</td>
#       <td id="T_b8651_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_b8651_row1_col9" class="data row1 col9" >sSET    </td>
#       <td id="T_b8651_row1_col10" class="data row1 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_b8651_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_b8651_row2_col0" class="data row2 col0" >BAFS</td>
#       <td id="T_b8651_row2_col1" class="data row2 col1" >2021</td>
#       <td id="T_b8651_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_b8651_row2_col3" class="data row2 col3" >-199,130</td>
#       <td id="T_b8651_row2_col4" class="data row2 col4" >-179,606</td>
#       <td id="T_b8651_row2_col5" class="data row2 col5" >-563,114</td>
#       <td id="T_b8651_row2_col6" class="data row2 col6" >-253,123</td>
#       <td id="T_b8651_row2_col7" class="data row2 col7" >46</td>
#       <td id="T_b8651_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_b8651_row2_col9" class="data row2 col9" >sSET / SETTHSI    </td>
#       <td id="T_b8651_row2_col10" class="data row2 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_b8651_level0_row3" class="row_heading level0 row3" >18</th>
#       <td id="T_b8651_row3_col0" class="data row3 col0" >CSC</td>
#       <td id="T_b8651_row3_col1" class="data row3 col1" >2021</td>
#       <td id="T_b8651_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_b8651_row3_col3" class="data row3 col3" >43,214</td>
#       <td id="T_b8651_row3_col4" class="data row3 col4" >79,324</td>
#       <td id="T_b8651_row3_col5" class="data row3 col5" >164,134</td>
#       <td id="T_b8651_row3_col6" class="data row3 col6" >204,556</td>
#       <td id="T_b8651_row3_col7" class="data row3 col7" >127</td>
#       <td id="T_b8651_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_b8651_row3_col9" class="data row3 col9" >SET    </td>
#       <td id="T_b8651_row3_col10" class="data row3 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_b8651_level0_row4" class="row_heading level0 row4" >28</th>
#       <td id="T_b8651_row4_col0" class="data row4 col0" >LHSC</td>
#       <td id="T_b8651_row4_col1" class="data row4 col1" >2021</td>
#       <td id="T_b8651_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_b8651_row4_col3" class="data row4 col3" >-141,793</td>
#       <td id="T_b8651_row4_col4" class="data row4 col4" >101,192</td>
#       <td id="T_b8651_row4_col5" class="data row4 col5" >-70,914</td>
#       <td id="T_b8651_row4_col6" class="data row4 col6" >124,127</td>
#       <td id="T_b8651_row4_col7" class="data row4 col7" >272</td>
#       <td id="T_b8651_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_b8651_row4_col9" class="data row4 col9" >SET    </td>
#       <td id="T_b8651_row4_col10" class="data row4 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_b8651_level0_row5" class="row_heading level0 row5" >34</th>
#       <td id="T_b8651_row5_col0" class="data row5 col0" >NTV</td>
#       <td id="T_b8651_row5_col1" class="data row5 col1" >2021</td>
#       <td id="T_b8651_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_b8651_row5_col3" class="data row5 col3" >17,124</td>
#       <td id="T_b8651_row5_col4" class="data row5 col4" >66,353</td>
#       <td id="T_b8651_row5_col5" class="data row5 col5" >87,406</td>
#       <td id="T_b8651_row5_col6" class="data row5 col6" >155,185</td>
#       <td id="T_b8651_row5_col7" class="data row5 col7" >332</td>
#       <td id="T_b8651_row5_col8" class="data row5 col8" >4</td>
#       <td id="T_b8651_row5_col9" class="data row5 col9" >SET    </td>
#       <td id="T_b8651_row5_col10" class="data row5 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_b8651_level0_row6" class="row_heading level0 row6" >39</th>
#       <td id="T_b8651_row6_col0" class="data row6 col0" >PORT</td>
#       <td id="T_b8651_row6_col1" class="data row6 col1" >2021</td>
#       <td id="T_b8651_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_b8651_row6_col3" class="data row6 col3" >12,213</td>
#       <td id="T_b8651_row6_col4" class="data row6 col4" >23,437</td>
#       <td id="T_b8651_row6_col5" class="data row6 col5" >27,124</td>
#       <td id="T_b8651_row6_col6" class="data row6 col6" >37,610</td>
#       <td id="T_b8651_row6_col7" class="data row6 col7" >658</td>
#       <td id="T_b8651_row6_col8" class="data row6 col8" >4</td>
#       <td id="T_b8651_row6_col9" class="data row6 col9" >SET    </td>
#       <td id="T_b8651_row6_col10" class="data row6 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_b8651_level0_row7" class="row_heading level0 row7" >43</th>
#       <td id="T_b8651_row7_col0" class="data row7 col0" >QHHR</td>
#       <td id="T_b8651_row7_col1" class="data row7 col1" >2021</td>
#       <td id="T_b8651_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_b8651_row7_col3" class="data row7 col3" >-3,309</td>
#       <td id="T_b8651_row7_col4" class="data row7 col4" >34,014</td>
#       <td id="T_b8651_row7_col5" class="data row7 col5" >24,529</td>
#       <td id="T_b8651_row7_col6" class="data row7 col6" >80,978</td>
#       <td id="T_b8651_row7_col7" class="data row7 col7" >692</td>
#       <td id="T_b8651_row7_col8" class="data row7 col8" >4</td>
#       <td id="T_b8651_row7_col9" class="data row7 col9" >SET    </td>
#       <td id="T_b8651_row7_col10" class="data row7 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_b8651_level0_row8" class="row_heading level0 row8" >47</th>
#       <td id="T_b8651_row8_col0" class="data row8 col0" >SABINA</td>
#       <td id="T_b8651_row8_col1" class="data row8 col1" >2021</td>
#       <td id="T_b8651_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_b8651_row8_col3" class="data row8 col3" >55,168</td>
#       <td id="T_b8651_row8_col4" class="data row8 col4" >85,768</td>
#       <td id="T_b8651_row8_col5" class="data row8 col5" >196,224<

# %%
filter1.shape
# Out:
# (19, 11)

# %% [markdown]
# ### End of Modified Filter Criteria

# %%
#filter1 = filter1.drop(51)
filter1.shape
# Out:
# (19, 11)

# %%
loss = filter1['name']
file_name = 'loss.csv'
data_file = data_path + file_name
loss.to_csv(data_file, index=False, header=False)

# %%
### Backup exempts before insert new records

# %%
sql = '''
SELECT name
FROM exempts
ORDER BY name'''
exempts = pd.read_sql(sql, conlt)
exempts.tail()
# Out:
#        name
# 277  WINNER
# 278     WPH
# 279      XO
# 280    ZIGA
# 281   ZMICO

# %%
file_name = 'exempts-21q3.csv'
data_file = data_path + file_name
data_file
# Out:
# '../data/exempts-21q3.csv'

# %%
exempts.to_csv(data_file, index=False, header=False)

# %%
### End of Backup exempts before insert new records

# %%
### Check whether record already existed

# %%
df_merge = pd.merge(filter1, exempts, on='name', how='outer', indicator=True)
df_merge1 = df_merge[df_merge['_merge'] == 'left_only']
df_merge1.shape
# Out:
# (19, 12)

# %%
### Check with buys table in Portfolio database

# %%
sql = '''
SELECT DISTINCT name 
FROM buys B
JOIN stocks S
ON B.stock_id = S.id
ORDER BY name'''
buys = pd.read_sql(sql, conpf)
buys.shape
# Out:
# (134, 1)

# %%
df_merge1 = df_merge1.drop('_merge', 1)
df_merge1.shape
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_2192/3427655093.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_merge1 = df_merge1.drop('_merge', 1)
# (19, 11)

# %%
df_merge2 = pd.merge(df_merge1, buys, on='name', how='outer', indicator=True)
final2 = df_merge2[df_merge2['_merge'] == 'left_only']
final2.shape
# Out:
# (17, 12)

# %%
df_merge2 = pd.merge(df_merge1, buys, on='name', how='outer', indicator=True)
tmp = df_merge2[df_merge2['_merge'] == 'both']
tmp
# Out:
#    name    year  quarter      q_amt      y_amt     aq_amt     ay_amt  \
# 0  ANAN  2021.0      3.0  -251932.0   292328.0  -237330.0  -132180.0
# 1    BA  2021.0      3.0 -6976909.0 -1569113.0 -8408459.0 -4882489.0
#
#    ticker_id  grade    market    mrkt _merge
# 0       23.0    4.0  sSET      SETMAI   both
# 1       45.0    4.0  sSET      SETMAI   both

# %%
sr = final2['name']
file_name = 'loss.csv'
data_file = data_path + file_name
sr.to_csv(data_file, index=False, header=False)

# %%
rcds = sr.values.tolist()
rcds
# Out:
# ['BAFS',
#  'CSC',
#  'LHSC',
#  'NTV',
#  'PORT',
#  'QHHR',
#  'SABINA',
#  'SAMART',
#  'SCN',
#  'SKE',
#  'SORKON',
#  'SUN',
#  'THRE',
#  'TIF1',
#  'UV',
#  'WP',
#  'ZEN']

# %%
for rcd in rcds:
    print(rcd)
# Out:
# BAFS
# CSC
# LHSC
# NTV
# PORT
# QHHR
# SABINA
# SAMART
# SCN
# SKE
# SORKON
# SUN
# THRE
# TIF1
# UV
# WP
# ZEN

# %%
sql = '''
SELECT COUNT(*)
FROM exempts'''
tmp_bf = pd.read_sql(sql, conlt)
tmp_bf
# Out:
#    COUNT(*)
# 0       282

# %%
for rcd in rcds:
    conlt.execute("""INSERT INTO exempts (name) \
VALUES(?)""", rcd)

# %%
sql = '''
SELECT COUNT(*)
FROM exempts'''
tmp_af = pd.read_sql(sql, conlt)
tmp_af
# Out:
#    COUNT(*)
# 0       299
