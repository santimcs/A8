# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

# %%
year = 2022
month = 2
year, month
# Out:
# (2022, 2)

# %% [markdown]
# ### Calculate profits

# %%
format_dict = {
    'qty':'{:,}',
    'buy_price':'{:.2f}','sell_price':'{:.2f}',
    'profit':'{:,.2f}','buy_amt':'{:,.2f}','sell_amt':'{:,.2f}',
}

# %%
sql = '''
SELECT name, sells.date AS sell_date, qty,
buys.price AS buy_price, buys.net AS buy_amt, 
sells.price AS sell_price, sells.net AS sell_amt, profit 
FROM sells 
JOIN buys ON sells.buy_id = buys.id
JOIN stocks ON buys.stock_id = stocks.id
WHERE YEAR(sells.date) = %s AND MONTH(sells.date) = %s
ORDER BY sells.date, name'''
sql = sql % (year, month)
print(sql)
# Out:
# SELECT name, sells.date AS sell_date, qty,
# buys.price AS buy_price, buys.net AS buy_amt,
# sells.price AS sell_price, sells.net AS sell_amt, profit
# FROM sells
# JOIN buys ON sells.buy_id = buys.id
# JOIN stocks ON buys.stock_id = stocks.id
# WHERE YEAR(sells.date) = 2022 AND MONTH(sells.date) = 2
# ORDER BY sells.date, name

# %%
sells_df = pd.read_sql(sql, conpf)
sells_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_be6fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_date</th>
#       <th class="col_heading level0 col2" >qty</th>
#       <th class="col_heading level0 col3" >buy_price</th>
#       <th class="col_heading level0 col4" >buy_amt</th>
#       <th class="col_heading level0 col5" >sell_price</th>
#       <th class="col_heading level0 col6" >sell_amt</th>
#       <th class="col_heading level0 col7" >profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be6fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be6fb_row0_col0" class="data row0 col0" >IP</td>
#       <td id="T_be6fb_row0_col1" class="data row0 col1" >2022-02-01</td>
#       <td id="T_be6fb_row0_col2" class="data row0 col2" >3,000</td>
#       <td id="T_be6fb_row0_col3" class="data row0 col3" >20.20</td>
#       <td id="T_be6fb_row0_col4" class="data row0 col4" >60,734.22</td>
#       <td id="T_be6fb_row0_col5" class="data row0 col5" >22.00</td>
#       <td id="T_be6fb_row0_col6" class="data row0 col6" >65,853.82</td>
#       <td id="T_be6fb_row0_col7" class="data row0 col7" >5,119.60</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be6fb_row1_col0" class="data row1 col0" >CKP</td>
#       <td id="T_be6fb_row1_col1" class="data row1 col1" >2022-02-02</td>
#       <td id="T_be6fb_row1_col2" class="data row1 col2" >10,000</td>
#       <td id="T_be6fb_row1_col3" class="data row1 col3" >5.00</td>
#       <td id="T_be6fb_row1_col4" class="data row1 col4" >50,110.75</td>
#       <td id="T_be6fb_row1_col5" class="data row1 col5" >5.50</td>
#       <td id="T_be6fb_row1_col6" class="data row1 col6" >54,878.18</td>
#       <td id="T_be6fb_row1_col7" class="data row1 col7" >4,767.43</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be6fb_row2_col0" class="data row2 col0" >MCS</td>
#       <td id="T_be6fb_row2_col1" class="data row2 col1" >2022-02-03</td>
#       <td id="T_be6fb_row2_col2" class="data row2 col2" >5,000</td>
#       <td id="T_be6fb_row2_col3" class="data row2 col3" >16.70</td>
#       <td id="T_be6fb_row2_col4" class="data row2 col4" >83,684.95</td>
#       <td id="T_be6fb_row2_col5" class="data row2 col5" >14.70</td>
#       <td id="T_be6fb_row2_col6" class="data row2 col6" >73,337.20</td>
#       <td id="T_be6fb_row2_col7" class="data row2 col7" >-10,347.75</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be6fb_row3_col0" class="data row3 col0" >IMH</td>
#       <td id="T_be6fb_row3_col1" class="data row3 col1" >2022-02-09</td>
#       <td id="T_be6fb_row3_col2" class="data row3 col2" >3,000</td>
#       <td id="T_be6fb_row3_col3" class="data row3 col3" >17.60</td>
#       <td id="T_be6fb_row3_col4" class="data row3 col4" >52,916.95</td>
#       <td id="T_be6fb_row3_col5" class="data row3 col5" >20.70</td>
#       <td id="T_be6fb_row3_col6" class="data row3 col6" >61,962.45</td>
#       <td id="T_be6fb_row3_col7" class="data row3 col7" >9,045.50</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be6fb_row4_col0" class="data row4 col0" >IVL</td>
#       <td id="T_be6fb_row4_col1" class="data row4 col1" >2022-02-09</td>
#       <td id="T_be6fb_row4_col2" class="data row4 col2" >1,200</td>
#       <td id="T_be6fb_row4_col3" class="data row4 col3" >42.00</td>
#       <td id="T_be6fb_row4_col4" class="data row4 col4" >50,511.63</td>
#       <td id="T_be6fb_row4_col5" class="data row4 col5" >50.50</td>
#       <td id="T_be6fb_row4_col6" class="data row4 col6" >60,465.78</td>
#       <td id="T_be6fb_row4_col7" class="data row4 col7" >9,954.15</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be6fb_row5_col0" class="data row5 col0" >TOP</td>
#       <td id="T_be6fb_row5_col1" class="data row5 col1" >2022-02-09</td>
#       <td id="T_be6fb_row5_col2" class="data row5 col2" >2,000</td>
#       <td id="T_be6fb_row5_col3" class="data row5 col3" >50.50</td>
#       <td id="T_be6fb_row5_col4" class="data row5 col4" >101,223.70</td>
#       <td id="T_be6fb_row5_col5" class="data row5 col5" >54.00</td>
#       <td id="T_be6fb_row5_col6" class="data row5 col6" >107,760.79</td>
#       <td id="T_be6fb_row5_col7" class="data row5 col7" >6,537.09</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be6fb_row6_col0" class="data row6 col0" >IMH</td>
#       <td id="T_be6fb_row6_col1" class="data row6 col1" >2022-02-10</td>
#       <td id="T_be6fb_row6_col2" class="data row6 col2" >3,000</td>
#       <td id="T_be6fb_row6_col3" class="data row6 col3" >17.60</td>
#       <td id="T_be6fb_row6_col4" class="data row6 col4" >52,916.95</td>
#       <td id="T_be6fb_row6_col5" class="data row6 col5" >21.10</td>
#       <td id="T_be6fb_row6_col6" class="data row6 col6" >63,159.80</td>
#       <td id="T_be6fb_row6_col7" class="data row6 col7" >10,242.85</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be6fb_row7_col0" class="data row7 col0" >IMH</td>
#       <td id="T_be6fb_row7_col1" class="data row7 col1" >2022-02-11</td>
#       <td id="T_be6fb_row7_col2" class="data row7 col2" >3,000</td>
#       <td id="T_be6fb_row7_col3" class="data row7 col3" >17.60</td>
#       <td id="T_be6fb_row7_col4" class="data row7 col4" >52,916.95</td>
#       <td id="T_be6fb_row7_col5" class="data row7 col5" >18.40</td>
#       <td id="T_be6fb_row7_col6" class="data row7 col6" >55,077.74</td>
#       <td id="T_be6fb_row7_col7" class="data row7 col7" >2,160.79</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be6fb_row8_col0" class="data row8 col0" >EPG</td>
#       <td id="T_be6fb_row8_col1" class="data row8 col1" >2022-02-14</td>
#       <td id="T_be6fb_row8_col2" class="data row8 col2" >24,000</td>
#       <td id="T_be6fb_row8_col3" class="data row8 col3" >10.90</td>
#       <td id="T_be6fb_row8_col4" class="data row8 col4" >262,179.42</td>
#       <td id="T_be6fb_row8_col5" class="data row8 col5" >10.30</td>
#       <td id="T_be6fb_row8_col6" class="data row8 col6" >246,652.48</td>
#       <td id="T_be6fb_row8_col7" class="data row8 col7" >-15,526.94</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be6fb_row9_col0" class="data row9 col0" >TOP</td>
#       <td id="T_be6fb_row9_col1" class="data row9 col1" >2022-02-14</td>
#       <td id="T_be6fb_row9_col2" class="data row9 col2" >2,000</td>
#       <td id="T_be6fb_row9_col3" class="data row9 col3" >50.50</td>
#       <td id="T_be6fb_row9_col4" class="data row9 col4" >101,223.70</td>
#       <td id="T_be6fb_row9_col5" class="data row9 col5" >53.75</td>
#       <td id="T_be6fb_row9_col6" class="data row9 col6" >107,261.89</td>
#       <td id="T_be6fb_row9_col7" class="data row9 col7" >6,038.19</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_be6fb_row10_col0" class="data row10 col0" >TSTH</td>
#       <td id="T_be6fb_row10_col1" class="data row10 col1" >2022-02-15</td>
#       <td id="T_be6fb_row10_col2" class="data row10 col2" >64,700</td>
#       <td id="T_be6fb_row10_col3" class="data row10 col3" >1.50</td>
#       <td id="T_be6fb_row10_col4" class="data row10 col4" >97,264.95</td>
#       <td id="T_be6fb_row10_col5" class="data row10 col5" >1.43</td>
#       <td id="T_be6fb_row10_col6" class="data row10 col6" >92,316.07</td>
#       <td id="T_be6fb_row10_col7" class="data row10 col7" >-4,948.88</td>
#     </tr>
#     <tr>
#       <th id="T_be6fb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_be6fb_row11_col0" class="data row11 col0" >TSTH</td>
#       <td id="T_be6fb_row11_col1" class="data

# %%
flt_format = '{:,.2f}'
flt_format.format(sells_df.profit.sum())
# Out:
# '-81,958.99'
