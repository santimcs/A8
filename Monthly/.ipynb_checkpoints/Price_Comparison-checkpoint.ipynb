# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
from datetime import date, timedelta
import calendar

pd.options.display.max_rows = 8

engine = create_engine('mysql+pymysql://root:@localhost:3306/stock')
conmy = engine.connect()
# Out:
# C:\Users\admin1\Anaconda2\lib\site-packages\matplotlib\__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
#month = date(2017, 11, 30)
#month

# %%
#month = month.replace(month=10, day=31)
#month

# %%
today = date.today() 
today
# Out:
# datetime.date(2018, 5, 31)

# %%
today = date(2018, 5, 17)
today
# Out:
# datetime.date(2018, 5, 17)

# %%
#last_day = month.replace(day=calendar.monthrange(month.year, month.month)[1])
#last_day

# %% [markdown]
# ### If end of month is holiday, replace with last business day

# %%
#last_day =last_day.replace(day=29) 
#last_day

# %%
sql = '''
SELECT B.name, B.date, volbuy, volbuy * B.price AS cost_amount, \
volbuy * P.price AS market_value, period \
FROM buy B JOIN price P USING (name) \
WHERE active=1 AND P.date = "%s" \
ORDER BY period, B.name
'''
sql = sql % today
print(sql)
# Out:
# SELECT B.name, B.date, volbuy, volbuy * B.price AS cost_amount, volbuy * P.price AS market_value, period FROM buy B JOIN price P USING (name) WHERE active=1 AND P.date = "2018-05-31" ORDER BY period, B.name

# %%
df = pd.read_sql(sql, conmy, parse_dates=['date'], index_col='name')
df.shape
# Out:
# (31, 5)

# %%
file_name   = 'stock-by-grade.csv'
output_file = '../data/' + file_name
df_out = df
df_out.to_csv(output_file)

# %%
name = 'AMATA'

# %%
df.ix[name]
# Out:
# date            2018-01-26 00:00:00
# volbuy                        12000
# cost_amount                  300000
# market_value                 258000
# period                    day trade
# Name: AMATA, dtype: object

# %%
sql = 'UPDATE buy SET period = "3" WHERE name = "%s"'
sql = sql % name
sql
# Out:
# 'UPDATE buy SET period = "3" WHERE name = "AMATA"'

# %%
rp = conmy.execute(sql)
rp.rowcount
# Out:
# 1

# %%
df.period.replace(['1','2','3','4'], ['disposal','high dividend','long term','short term'], inplace=True)
grouped = df.groupby(by='period')
grouped['cost_amount','market_value'].sum()
# Out:
#                cost_amount  market_value
# period
# disposal         2062400.0     1159700.0
# high dividend    3088356.0     2587500.0
# long term        2657200.0     2605550.0
# short term       2719000.0     2760050.0

# %%
cost_summary = grouped.sum().cost_amount
cost_summary
# Out:
# period
# disposal         2062400.0
# high dividend    3088356.0
# long term        2657200.0
# short term       2719000.0
# Name: cost_amount, dtype: float64

# %%
fig_path = '../fig/Portfolio-at-Cost-1805.png'
with plt.style.context('my_custom_style'):
    plt.figure(figsize=(12, 12))
    ax = cost_summary.plot.pie(colors=['green','red','orange','cyan'],
                               startangle=90,
                               autopct='%1.1f%%')
    plt.savefig(fig_path)

# %%
market_summary = grouped.sum().market_value
market_summary
# Out:
# period
# disposal         1159700.0
# high dividend    2587500.0
# long term        2605550.0
# short term       2760050.0
# Name: market_value, dtype: float64

# %%
fig_path = '../fig/Portfolio-at-Market-1805.png'
with plt.style.context('my_custom_style'):
    plt.figure(figsize=(12, 12))
    ax = market_summary.plot.pie(colors=['green','red','orange','cyan'],
                               startangle=90,
                               autopct='%1.1f%%')
    plt.savefig(fig_path)
