# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
from datetime import date, timedelta
import calendar

pd.options.display.max_rows = 8

engine = create_engine('sqlite:///c:\\ruby\\expense\\db\\development.sqlite3')
connection = engine.connect()
# Out:
# C:\Users\admin1\Anaconda2\lib\site-packages\matplotlib\__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
sql = 'SELECT C.name AS item, G.name AS kind FROM categories C \
       JOIN groups G ON group_id = G.id'
df_c = pd.read_sql(sql, connection)
df_c
# Out:
#                 item         kind
# 0   Books & Software  Edutainment
# 1                CCF       Luxury
# 2          Cigarette       Luxury
# 3               Food         Food
# ..               ...          ...
# 21       Family Mart       Others
# 22              Plum      Shelter
# 23            Family      Shelter
# 24          iPad Pro  Edutainment
#
# [25 rows x 2 columns]

# %%
month = date(2018, 6, 01)
bom = month
eom = month.replace(day=calendar.monthrange(month.year, month.month)[1])
bom, eom
# Out:
# (datetime.date(2018, 6, 1), datetime.date(2018, 6, 30))

# %%
sql = '''
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date BETWEEN "%s" AND "%s" 
ORDER BY date
'''
sql = sql % (bom, eom)
print(sql)
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date BETWEEN "2018-06-01" AND "2018-06-30"
# ORDER BY date

# %%
df_t = pd.read_sql(sql, connection)
df_t
# Out:
#           date  amount            item            kind
# 0   2018-06-02     330  Transportation  Transportation
# 1   2018-06-04     170            Food            Food
# 2   2018-06-05   24120            Plum         Shelter
# 3   2018-06-05     480            Food            Food
# ..         ...     ...             ...             ...
# 24  2018-06-30   10000          Parent          Parent
# 25  2018-06-30    3530        iPad Pro     Edutainment
# 26  2018-06-30     320  Telephone Dtac   Communication
# 27  2018-06-30     130          ITUNES          Luxury
#
# [28 rows x 4 columns]

# %%
grouped = df_t.groupby('kind')
grouped.sum()
# Out:
#                 amount
# kind
# Apparel            380
# Communication      960
# Edutainment       3530
# Food              3490
# ...                ...
# Others            2440
# Parent           10000
# Shelter          24120
# Transportation    3350
#
# [9 rows x 1 columns]

# %%
expense = grouped.amount.sum()
sum(expense)
# Out:
# 49370

# %%
fig_path = '../fig/Expense-1806.png'
with plt.style.context('my_custom_style'):
    plt.figure(figsize=(12, 12))
    ax = expense.plot.pie(colors=['green','red','orange','cyan','yellow','blue','gold'],
                               startangle=90,
                               autopct='%1.1f%%')
    plt.savefig(fig_path)

# %%
expense.to_csv('../data/expense-1806.csv')
