# %%
import pandas as pd
from sqlalchemy import create_engine
from glob import glob

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

data_path = "../data/"
irreg_path = "../data/irreg/"

# %%
year = 2022
quarter = 1
year, quarter
# Out:
# (2022, 1)

# %% [markdown]
# ### Begin of Irregular quarter

# %% [markdown]
# ### Irregular Quarter Plus 1

# %%
file_name   = 'P1-Stocks.csv'
input_file = irreg_path + file_name
col_names   = ['name']
data_ins = pd.read_csv(input_file, sep=',', index_col=None)
data_ins
# Out:
#      name
# 0     AOT
# 1    CITY
# 2  GVREIT
# 3     IRC
# 4    KTIS
# 5   OISHI
# 6    PICO
# 7     SSC
# 8   TFFIF
# 9      UV

# %%
sr = data_ins["name"]
names = sr.values.tolist()
in_p = ', '.join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AOT', 'CITY', 'GVREIT', 'IRC', 'KTIS', 'OISHI', 'PICO', 'SSC', 'TFFIF', 'UV'"

# %%
sql = '''
SELECT name, COUNT(*) FROM epss 
WHERE name in (%s)
AND ((year = %s AND quarter <= %s + 1)
OR (year = %s - 1 AND quarter > %s + 1))
GROUP BY name
HAVING COUNT(*) < 4
ORDER BY name'''
sql = sql % (in_p, year, quarter, year, quarter)
print(sql)
# Out:
# SELECT name, COUNT(*) FROM epss
# WHERE name in ('AOT', 'CITY', 'GVREIT', 'IRC', 'KTIS', 'OISHI', 'PICO', 'SSC', 'TFFIF', 'UV')
# AND ((year = 2022 AND quarter <= 1 + 1)
# OR (year = 2022 - 1 AND quarter > 1 + 1))
# GROUP BY name
# HAVING COUNT(*) < 4
# ORDER BY name

# %%
df = pd.read_sql(sql, conlt)
df
# Out:
# Empty DataFrame
# Columns: [name, COUNT(*)]
# Index: []

# %% [markdown]
# ### Irregular Quarter Minus 1

# %%
file_name   = 'M1-Stocks.csv'
input_file = irreg_path + file_name
col_names   = ['name']
data_ins = pd.read_csv(input_file, sep=',', index_col=None)
data_ins
# Out:
#       name
# 0   AEONTS
# 1      BCT
# 2    BLAND
# 3      BTS
# 4   BTSGIF
# 5      EPG
# 6   IMPACT
# 7    INGRS
# 8      KYE
# 9      LHK
# 10     LPF
# 11    MACO
# 12     PTL
# 13     SFP
# 14  STANLY
# 15    TIF1
# 16    TLGF
# 17     TMW
# 18      TR
# 19    TSTH
# 20     VGI

# %%
sr = data_ins["name"]
names = sr.values.tolist()
in_p = ', '.join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AEONTS', 'BCT', 'BLAND', 'BTS', 'BTSGIF', 'EPG', 'IMPACT', 'INGRS', 'KYE', 'LHK', 'LPF', 'MACO', 'PTL', 'SFP', 'STANLY', 'TIF1', 'TLGF', 'TMW', 'TR', 'TSTH', 'VGI'"

# %%
sql = '''
SELECT name, COUNT(*) 
FROM epss 
WHERE name in (%s)
AND year = %s - 1
GROUP BY name
HAVING COUNT(*) < 4
ORDER BY name'''
sql = sql % (in_p, year)
print(sql)
# Out:
# SELECT name, COUNT(*)
# FROM epss
# WHERE name in ('AEONTS', 'BCT', 'BLAND', 'BTS', 'BTSGIF', 'EPG', 'IMPACT', 'INGRS', 'KYE', 'LHK', 'LPF', 'MACO', 'PTL', 'SFP', 'STANLY', 'TIF1', 'TLGF', 'TMW', 'TR', 'TSTH', 'VGI')
# AND year = 2022 - 1
# GROUP BY name
# HAVING COUNT(*) < 4
# ORDER BY name

# %%
df = pd.read_sql(sql, conlt)
df
# Out:
# Empty DataFrame
# Columns: [name, COUNT(*)]
# Index: []

# %% [markdown]
# ### End of Irregular quarter

# %% [markdown]
# ### Normal Quarter Stocks

# %%
irreg_files = sorted(glob('../data/irreg/*.csv'))
irreg_files
# Out:
# ['../data/irreg\\M1-Stocks.csv', '../data/irreg\\P1-Stocks.csv']

# %%
col_names = ['name']
df_tmp = pd.concat((pd.read_csv(file) for file in irreg_files), ignore_index=True)
df_tmp
# Out:
#       name
# 0   AEONTS
# 1      BCT
# 2    BLAND
# 3      BTS
# 4   BTSGIF
# 5      EPG
# 6   IMPACT
# 7    INGRS
# 8      KYE
# 9      LHK
# 10     LPF
# 11    MACO
# 12     PTL
# 13     SFP
# 14  STANLY
# 15    TIF1
# 16    TLGF
# 17     TMW
# 18      TR
# 19    TSTH
# 20     VGI
# 21     AOT
# 22    CITY
# 23  GVREIT
# 24     IRC
# 25    KTIS
# 26   OISHI
# 27    PICO
# 28     SSC
# 29   TFFIF
# 30      UV

# %%
sr = df_tmp['name']
names = sr.values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AEONTS', 'BCT', 'BLAND', 'BTS', 'BTSGIF', 'EPG', 'IMPACT', 'INGRS', 'KYE', 'LHK', 'LPF', 'MACO', 'PTL', 'SFP', 'STANLY', 'TIF1', 'TLGF', 'TMW', 'TR', 'TSTH', 'VGI', 'AOT', 'CITY', 'GVREIT', 'IRC', 'KTIS', 'OISHI', 'PICO', 'SSC', 'TFFIF', 'UV'"

# %%
sql = """
SELECT name, COUNT(*) AS quarters 
FROM epss 
WHERE name NOT IN (%s)
AND ((year = %s AND quarter <= %s) OR (year = %s-1 AND quarter >= %s+1))
GROUP BY name
HAVING COUNT(*) < 4
ORDER BY name"""
sql = sql % (in_p, year, quarter, year, quarter)
print(sql)
# Out:
# SELECT name, COUNT(*) AS quarters
# FROM epss
# WHERE name NOT IN ('AEONTS', 'BCT', 'BLAND', 'BTS', 'BTSGIF', 'EPG', 'IMPACT', 'INGRS', 'KYE', 'LHK', 'LPF', 'MACO', 'PTL', 'SFP', 'STANLY', 'TIF1', 'TLGF', 'TMW', 'TR', 'TSTH', 'VGI', 'AOT', 'CITY', 'GVREIT', 'IRC', 'KTIS', 'OISHI', 'PICO', 'SSC', 'TFFIF', 'UV')
# AND ((year = 2022 AND quarter <= 1) OR (year = 2022-1 AND quarter >= 1+1))
# GROUP BY name
# HAVING COUNT(*) < 4
# ORDER BY name

# %%
df = pd.read_sql(sql, conlt)
df
# Out:
#   name  quarters
# 0   MC         3

# %% [markdown]
# ### End of Normal Quarter stocks

# %% [markdown]
# ### New stocks with less than 4 quarters EPS

# %%
#Cannot understand logic
sql = '''
SELECT name, COUNT(*) FROM epss 
WHERE (year = %s AND quarter = %s) 
OR (year = %s-1 AND quarter > %s)
GROUP BY name 
HAVING MAX(quarter) < 4 
ORDER BY name'''
sql = sql % (year, quarter, year, quarter)
print(sql)
# Out:
# SELECT name, COUNT(*) FROM epss
# WHERE (year = 2022 AND quarter = 1)
# OR (year = 2022-1 AND quarter > 1)
# GROUP BY name
# HAVING MAX(quarter) < 4
# ORDER BY name

# %%
df_tmp = pd.read_sql(sql, conlt)
df_tmp
# Out:
# Empty DataFrame
# Columns: [name, COUNT(*)]
# Index: []

# %% [markdown]
# ### Delete EPSS record that unmatch with Tickers in PortPg

# %%
sql = '''
SELECT *
FROM epss E
WHERE E.ticker_id NOT IN
(SELECT id FROM tickers)
'''
df = pd.read_sql(sql, conpg)
df.shape
# Out:
# (0, 14)

# %%
rp = conpg.execute(sql)
rp.rowcount
# Out:
# 0

# %%
sql = '''
SELECT *
FROM epss
'''
epss = pd.read_sql(sql, conlt)
epss.shape
# Out:
# (7148, 14)

# %%
sql = '''
SELECT *
FROM tickers
'''
tickers = pd.read_sql(sql, conpg)
tickers.shape
# Out:
# (400, 9)

# %%
df_merge = pd.merge(epss, tickers, on='name', how='outer', indicator = True)
df_merge.shape
# Out:
# (7318, 23)

# %%
df_left = df_merge[df_merge['_merge'] == 'left_only']
df_left
# Out:
# Empty DataFrame
# Columns: [id_x, name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps, ticker_id, publish_date, id_y, full_name, sector, subsector, market, website, created_at, updated_at, _merge]
# Index: []
#
# [0 rows x 23 columns]

# %%
name_ary = df_left['name'].unique()
name_ary
# Out:
# array([], dtype=object)

# %%
sql = '''
SELECT *
FROM epss
WHERE name IN (%s)
'''
in_p = ', '.join(map(lambda name: "'%s'" % name, name_ary))
sql = sql % (in_p)
errors = pd.read_sql(sql, conlt)
errors
# Out:
# Empty DataFrame
# Columns: [id, name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps, ticker_id, publish_date]
# Index: []

# %% [markdown]
# ### Delete YR_PROFITS record that unmatch with Tickers in PortPg

# %%
sql = """
SELECT name, sector, subsector 
FROM tickers
"""
tickers = pd.read_sql(sql, conpg)
tickers.shape
# Out:
# (400, 3)

# %%
sql = '''
SELECT *
FROM yr_profits
'''
yr_profits = pd.read_sql(sql, conlt)
yr_profits.shape
# Out:
# (4681, 9)

# %%
df_merge = pd.merge(yr_profits, tickers, on="name", how="outer", indicator=True)
df_merge.shape
# Out:
# (4855, 12)

# %%
df_left = df_merge[df_merge["_merge"] == "left_only"]
df_left.shape
# Out:
# (0, 12)

# %%
name_ary = df_left["name"].unique()
name_ary
# Out:
# array([], dtype=object)

# %%
sql = '''
SELECT *
FROM yr_profits
WHERE name IN (%s)
'''
in_p = ', '.join(map(lambda name: "'%s'" % name, name_ary))
sql = sql % (in_p)
errors = pd.read_sql(sql, conlt)
errors
# Out:
# Empty DataFrame
# Columns: [id, name, year, quarter, latest_amt, previous_amt, inc_amt, inc_pct, ticker_id]
# Index: []

# %%
sql = '''
DELETE
FROM yr_profits
WHERE name IN (%s)
'''
in_p = ', '.join(map(lambda name: "'%s'" % name, name_ary))
sql = sql % (in_p)
print(sql)
# Out:
# DELETE
# FROM yr_profits
# WHERE name IN ()

# %%
rp = conlt.execute(sql)
rp.rowcount
# Out:
# 0

# %% [markdown]
# ### Profits table

# %%
pd.set_option('display.max_rows',None)
sql = '''
SELECT * 
FROM profits
ORDER BY name, year, quarter
'''
profits = pd.read_sql(sql, conmy)
profits
# Out:
#       id    name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0   2417     AIT  2022        1     1        571977          455882
# 1   2444      AP  2022        1     1       4870212         5010831
# 2   2367     ASK  2022        1     1       1277644          958779
# 3   2445   BANPU  2022        1     1      18580896        -1963881
# 4   2349     BAY  2022        1     1      34707618        22512053
# 5   2353     BBL  2022        1     1      26702007        16433170
# 6   2378    BCPG  2022        1     1       2850502         1861919
# 7   2447     BCT  2021        4     1       4287324         1036420
# 8   2401    BDMS  2022        1     1      10040447         5984852
# 9   2360      BH  2022        1     1       1849587          530070
# 10  2371     BPP  2022        1     1       5011201         3761295
# 11  2357   COTTO  2022        1     1        608126          482435
# 12  2412    ESSO  2022        1     1       7554525         1184192
# 13  2442   FORTH  2022        1     1        775107          550368
# 14  2376     GGC  2022        1     1        722960          415739
# 15  2362  GLOBAL  2022        1     1       3534362         2305813
# 16  2413    GULF  2022        1     1       9432743         6327529
# 17  2414     IVL  2022        1     1      34349125         7852368
# 18  2355   KBANK  2022        1     1      38636812        32739104
# 19  2348     KKP  2022        1     1       6910731         5101876
# 20  2352     KTB  2022        1     1      24790196        15917212
# 21  2350     KTC  2022        1     1       5992158         5325531
# 22  2437    MEGA  2022        1     1       2227269         1406222
# 23  2361     MST  2022        1     1        765658          626511
# 24  2365     RBF  2022        1     1        507939          446696
# 25  2431     RCL  2022        1     1      23253733         4674119
# 26  2368     RJH  2022        1     1       1377891          436349
# 27  2399  SINGER  2022        1     1        775886          496524
# 28  2419     SIS  2022        1     1        795606          658058
