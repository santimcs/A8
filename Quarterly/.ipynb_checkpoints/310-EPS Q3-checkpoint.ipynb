# %%
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()

year = "2021"
quarter = "3"
today = date.today()
today_str = today.strftime("%Y-%m-%d")
today_str
# Out:
# '2022-01-07'

# %%
#today = date(2021, 11, 11)
today_str = today.strftime("%Y-%m-%d")
today_str
# Out:
# '2022-01-07'

# %%
sql = '''
SELECT * 
FROM epss 
WHERE year = %s AND quarter = %s
AND publish_date >= "%s"'''
sql = sql % (year, quarter, today_str)

epss = pd.read_sql(sql, conlt)
epss.shape[0]
# Out:
# 0

# %%
epss["yoy_gain"] = epss["q_amt"] - epss["y_amt"]
epss["yoy_pct"] = epss["yoy_gain"] / abs(epss["y_amt"]) * 100
epss["acc_gain"] = epss["aq_amt"] - epss["ay_amt"]
epss["acc_pct"] = epss["acc_gain"] / abs(epss["ay_amt"]) * 100

df_pct = epss[
    [
        "name",
        "year",
        "quarter",
        "q_amt",
        "y_amt",
        "yoy_gain",
        "yoy_pct",
        "aq_amt",
        "ay_amt",
        "acc_gain",
        "acc_pct",
    ]
]
df_pct
# Out:
# Empty DataFrame
# Columns: [name, year, quarter, q_amt, y_amt, yoy_gain, yoy_pct, aq_amt, ay_amt, acc_gain, acc_pct]
# Index: []

# %%
cols = ['name','year','quarter','q_amt','y_amt','yoy_gain','yoy_pct']

criteria_1 = df_pct.q_amt > 110000
df_pct.loc[criteria_1,cols]
# Out:
#       name  year  quarter    q_amt   y_amt  yoy_gain      yoy_pct
# 1      BAM  2021        3   576326  271017    305309   112.653081
# 3      CKP  2021        3  1234916  831308    403608    48.550958
# 6      AWC  2021        3   686992 -470590   1157582   245.985253
# 9    GLAND  2021        3   145073  178248    -33175   -18.611710
# 10     SKR  2021        3   339154  102377    236777   231.279487
# ..     ...   ...      ...      ...     ...       ...          ...
# 188   STEC  2021        3   136078  234510    -98432   -41.973477
# 190   AYUD  2021        3   181908  139552     42356    30.351410
# 191     CK  2021        3   275218  774462   -499244   -64.463331
# 194    THE  2021        3   151823  -16286    168109  1032.230136
# 200  THANI  2021        3   400950  472194    -71244   -15.087866
#
# [104 rows x 7 columns]

# %%
criteria_2 = df_pct.y_amt > 100000
df_pct.loc[criteria_2, cols]
# Out:
#       name  year  quarter    q_amt   y_amt  yoy_gain     yoy_pct
# 1      BAM  2021        3   576326  271017    305309  112.653081
# 3      CKP  2021        3  1234916  831308    403608   48.550958
# 4     GFPT  2021        3   -87286  342068   -429354 -125.517149
# 5     ESSO  2021        3    46340  466746   -420406  -90.071688
# 9    GLAND  2021        3   145073  178248    -33175  -18.611710
# ..     ...   ...      ...      ...     ...       ...         ...
# 187   TCCC  2021        3   401834  707077   -305243  -43.169697
# 188   STEC  2021        3   136078  234510    -98432  -41.973477
# 190   AYUD  2021        3   181908  139552     42356   30.351410
# 191     CK  2021        3   275218  774462   -499244  -64.463331
# 200  THANI  2021        3   400950  472194    -71244  -15.087866
#
# [98 rows x 7 columns]

# %%
criteria_3 = df_pct.yoy_pct > 10
df_pct.loc[criteria_3, cols]
# Out:
#        name  year  quarter    q_amt   y_amt  yoy_gain      yoy_pct
# 0     SFLEX  2021        3    43382   37525      5857    15.608261
# 1       BAM  2021        3   576326  271017    305309   112.653081
# 2    WACOAL  2021        3   -48431 -232950    184519    79.209702
# 3       CKP  2021        3  1234916  831308    403608    48.550958
# 6       AWC  2021        3   686992 -470590   1157582   245.985253
# ..      ...   ...      ...      ...     ...       ...          ...
# 193     PLE  2021        3   -40223 -233702    193479    82.788765
# 194     THE  2021        3   151823  -16286    168109  1032.230136
# 195     CWT  2021        3    37509   12111     25398   209.710181
# 198     PR9  2021        3    82947   72190     10757    14.900956
# 199   S & J  2021        3    88643   49588     39055    78.758974
#
# [106 rows x 7 columns]

# %%
df_pct_criteria = criteria_1 & criteria_2 & criteria_3
df_pct.loc[df_pct_criteria, cols]
# Out:
#        name  year  quarter     q_amt     y_amt  yoy_gain     yoy_pct
# 1       BAM  2021        3    576326    271017    305309  112.653081
# 3       CKP  2021        3   1234916    831308    403608   48.550958
# 10      SKR  2021        3    339154    102377    236777  231.279487
# 24     COM7  2021        3    570507    372288    198219   53.243457
# 37      CRC  2021        3   2241387    837347   1404040  167.677200
# 53       PB  2021        3    531529    430812    100717   23.378411
# 64    HREIT  2021        3    141474    116607     24867   21.325478
# 65    STARK  2021        3    912508    395476    517032  130.736631
# 72      PTT  2021        3  23652828  14120183   9532645   67.510775
# 74      SIS  2021        3    215173    153532     61641   40.148634
# 75      TMT  2021        3    341337    155838    185499  119.033227
# 92       EA  2021        3   1616256   1118998    497258   44.437792
# 96   ALUCON  2021        3    194399    135075     59324   43.919304
# ...

# %%
df_pct[df_pct_criteria].sort_values(by=["yoy_pct"], ascending=[False])
# Out:
#        name  year  quarter     q_amt     y_amt  yoy_gain     yoy_pct  \
# 179     BCH  2021        3   2896236    413364   2482872  600.650274
# 184      TR  2021        3   1235872    183051   1052821  575.151734
# 145     CHG  2021        3   1563537    281712   1281825  455.012566
# 10      SKR  2021        3    339154    102377    236777  231.279487
# 37      CRC  2021        3   2241387    837347   1404040  167.677200
# 117    CCET  2021        3    503716    189906    313810  165.244911
# 65    STARK  2021        3    912508    395476    517032  130.736631
# 75      TMT  2021        3    341337    155838    185499  119.033227
# 1       BAM  2021        3    576326    271017    305309  112.653081
# 141    TCAP  2021        3   1333063    638580    694483  108.754267
# 128     BLA  2021        3   1180489    583374    597115  102.355436
# 107   TPIPL  2021        3   1208352    665175    543177   81.659263
# 183    MEGA  2021        3    612614    342048    270566   79.101763
# ...

# %%
df_pct[df_pct_criteria].sort_values(by=["name"], ascending=[True]).shape[0]
# Out:
# 38

# %% [markdown]
# ### If new records pass filter criteria then proceed to create quarterly profits process.

# %%
name = "TCAP"
sql = """SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
FROM epss E JOIN stocks S ON E.name = S.name 
WHERE E.name = '%s'
ORDER BY year DESC, quarter DESC LIMIT 4
"""
sql = sql % (name)
epss = pd.read_sql(sql, conlt)
epss
# Out:
#    name  year  quarter    q_amt    y_amt   aq_amt    ay_amt  q_eps  y_eps  \
# 0  TCAP  2021        3  1333063   638580  3518128   5983533   1.27   0.61
# 1  TCAP  2021        2  1106944  1029369  2185065   5344953   1.06   0.98
# 2  TCAP  2021        1  1078121  4315584  1078121   4315584   1.03   3.86
# 3  TCAP  2020        4   685497  4419948  6669030  10807059   0.67   3.86
#
#    aq_eps  ay_eps
# 0    3.36    5.59
# 1    2.08    4.94
# 2    1.03    3.86
# 3    6.26    9.43

# %%
epss.q_eps.sum()
# Out:
# 4.03

# %% [markdown]
# ### Delete from profits for poorer performance stocks

# %%
sql = '''
DELETE FROM profits
WHERE name = '%s'
AND quarter < %s
'''
sql = sql % (name, quarter)
print(sql)
# Out:
# DELETE FROM profits
# WHERE name = 'MEGA'
# AND quarter < 3

# %%
rp = conlt.execute(sql)
rp.rowcount
# Out:
# 1

# %%
rp = conmy.execute(sql)
rp.rowcount
# Out:
# 0

# %%
rp = conpg.execute(sql)
rp.rowcount
# Out:
# 1

# %%
sql = '''
SELECT name, year, quarter 
FROM profits
ORDER BY name
'''
lt_profits = pd.read_sql(sql, conlt)
lt_profits.set_index('name', inplace=True)
lt_profits.index
# Out:
# Index(['AIT', 'AMATA', 'ASIAN', 'ASK', 'BAY', 'BGRIM', 'BLA', 'BPP', 'CHG',
#        'CKP', 'COM7', 'CPTGF', 'DCC', 'DOHOME', 'EASTW', 'EPG', 'GGC',
#        'GLOBAL', 'GULF', 'GUNKUL', 'HANA', 'HREIT', 'IRPC', 'IVL', 'JMART',
#        'JMT', 'KBANK', 'KCE', 'KTC', 'LALIN', 'LHFG', 'MBKET', 'MCS', 'MTI',
#        'NER', 'PAP', 'PRM', 'PTG', 'PTL', 'PTT', 'PTTGC', 'RATCH', 'RATCH',
#        'RCL', 'RJH', 'ROJNA', 'SAUCE', 'SAWAD', 'SCB', 'SCC', 'SCCC', 'SGP',
#        'SINGER', 'SIS', 'SMT', 'SNC', 'SPALI', 'SPG', 'SSP', 'STA', 'STARK',
#        'SUC', 'SVI', 'SYNEX', 'TK', 'TOP', 'TPIPL', 'TQM', 'TSE', 'TSTH', 'TU',
#        'TVO', 'TYCN', 'VNT', 'WHART'],
#       dtype='object', name='name')
