# %%
import pandas as pd
from sqlalchemy import create_engine
from glob import glob

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
data_path = "../data/"
irreg_path = "../data/irreg/"

# %%
year = 2021
quarter = 4
year, quarter
# Out:
# (2021, 4)

# %%
format_dict = {
    'q_amt':'{:,}','y_amt': '{:,}',   
    'aq_amt':'{:,}','ay_amt':'{:,}','yoy_gain':'{:,}','acc_gain':'{:,}', 
    'q_eps':'{:.4f}','y_eps':'{:.4f}','aq_eps':'{:.4f}','ay_eps':'{:.4f}', 
    'daily_volume':'{:.2f}','beta':'{:.2f}',
    'publish_date':'{:%Y-%m-%d}',    
}

# %% [markdown]
# ### Classify performance after input all EPS

# %%
sql = """
SELECT *
FROM epss
WHERE year = %s AND quarter = %s
ORDER BY name
"""
sql = sql % (year, quarter)
epss = pd.read_sql(sql, conlt)
epss.shape[0]
# Out:
# 320

# %% [markdown]
# ### Merge with stocks to get market information

# %%
sql = '''
SELECT name, price, market, daily_volume, beta
FROM stocks
'''
stocks = pd.read_sql(sql, conlt)
stocks.shape
# Out:
# (339, 5)

# %%
set50 = stocks.market.str.contains('SET50')
set100 = stocks.market.str.contains('SET100')
mai = stocks.market.str.contains('mai')
set = ~(set50 | set100 | mai)

# %%
cdd = stocks[~(set50 | set100)]
cdd.shape
# Out:
# (239, 5)

# %%
sql = """
SELECT name, price, buy, hold, sell, yield, target_price
FROM consensus"""
consensus = pd.read_sql(sql, conlt)
consensus.shape
# Out:
# (288, 7)

# %%
df_merge = pd.merge(cdd, consensus, on='name', how='outer', indicator=True)
df_merge.shape
# Out:
# (348, 12)

# %%
cdd2 = df_merge[df_merge['_merge'] == 'left_only'].copy()
cdd2.shape
# Out:
# (60, 12)

# %%
cdd2.drop(index = [30,110], inplace=True)
cdd2
# Out:
#        name  price_x    market  daily_volume  beta  price_y  buy  hold  sell  \
# 3       AKR     1.02   SET             33.87  1.29      NaN  NaN   NaN   NaN
# 6    AMARIN     5.95   SET              0.17  0.15      NaN  NaN   NaN   NaN
# 7       AMC     5.50   SET             24.16  1.33      NaN  NaN   NaN   NaN
# 15     AYUD    41.25   SET              1.90  0.24      NaN  NaN   NaN   NaN
# 27      CGH     1.41  sSET            291.30  1.79      NaN  NaN   NaN   NaN
# 28    CIMBT     0.86   SET             48.28  1.57      NaN  NaN   NaN   NaN
# 29      CPI     3.82   SET             54.91  0.69      NaN  NaN   NaN   NaN
# 31      CSP     2.88   SET              3.14  1.46      NaN  NaN   NaN   NaN
# 35     DCON     0.51   SET             11.83  1.37      NaN  NaN   NaN   NaN
# 46      FPI     3.32   mai             20.58  0.79      NaN  NaN   NaN   NaN
# 48      FSS     5.40   SET            133.15  1.69      NaN  NaN   NaN   NaN
# 49      GBX     1.53   SET             87.88  0.87      NaN  NaN   NaN   NaN
# 50       GC    12.20   SET              3.49  0.95      NaN  NaN   NaN   NaN
# 53    GLAND     2.06   SET              0.23  0.58      NaN  NaN   NaN   NaN
# 59      ICC    29.75   SET              0.11  0.13      NaN  NaN   NaN   NaN
# 67        J     4.02   SET             39.81  1.53      NaN  NaN   NaN   NaN
# 70      JTS   265.00   SET            328.73  0.33      NaN  NaN   NaN   NaN
# 76      KYE   370.00   SET              1.24  0.21      NaN  NaN   NaN   NaN
# 80      LHK     4.06   SET              2.12  0.71      NaN  NaN   NaN   NaN
# 84      LST     6.30  sSET              9.32  0.58      NaN  NaN   NaN   NaN
# 92      MDX     5.45   SET             14.70  1.53      NaN  NaN   NaN   NaN
# 93      MFC    27.00   SET              2.93  0.17      NaN  NaN   NaN   NaN
# 96      MTI   115.00  sSET              5.12  0.17      NaN  NaN   NaN   NaN
# 97      NCH     1.72   SET             32.92  1.42      NaN  NaN   NaN   NaN
# 98     NNCL     2.48  sSET              2.63  0.77      NaN  NaN   NaN   NaN
# 103      PB    68.50   SET              0.45  0.06      NaN  NaN   NaN   NaN
# 106  BEYOND    13.00   SET             13.95  1.45      NaN  NaN   NaN   NaN
# 107    PERM     2.64   SET             14.66  1.37      NaN  NaN   NaN   NaN
# 108      PL     2.64   SET              1.87  0.73      NaN  NaN   NaN   NaN
# 109     PLE     0.84   SET              2.63  1.64      NaN  NaN   NaN   NaN
# 112     PRG    11.40   SET              0.05  0.29      NaN  NaN   NaN   NaN
# 118     RPC     1.50   SET             60.28  2.27      NaN  NaN   NaN   NaN
# 124   SAUCE    31.00   SET              0.26  0.29      NaN  NaN   NaN   NaN
# 130   SHANG    50.25   SET              0.34  0.34      NaN  NaN   NaN   NaN
# 139     SPG    17.40   SET              0.05  0.42      NaN  NaN   NaN   NaN
# 140     SPI    63.75   SET              0.53 -0.07      NaN  NaN   NaN   NaN
# 143    SSSC     3.14   SET              0.61  0.67      NaN  NaN   NaN   NaN
# 145     SUC    33.25   SET              1.89  0.43      NaN  NaN   NaN   NaN
# 147     SVH   394.00   SET              0.82  0.17      NaN  NaN   NaN   NaN
# 151    TCCC    32.00   SET              1.28  0.19      NaN  NaN   NaN   NaN
# 153     THE     2.66   SET              7.77  1.08      NaN  NaN   NaN   NaN
# 161     TMW    34.50   mai              0.32  0.26      NaN  NaN   NaN   NaN
# 162   TNITY    12.90   SET             80.53  1.17      NaN  NaN   NaN   NaN
# 163    TNPC     2.38   SET              4.67  0.82      NaN  NaN   NaN   NaN
# 176   UPOIC     7.50   SET              1.65  0.45      NaN  NaN   NaN   NaN
# 178    UVAN     7.65  sSET             18.97  0.84      NaN  NaN   NaN   NaN
# 180     VIH     9.80  sSET             16.14 -0.06      NaN  NaN   NaN   NaN
# 182  WACOAL    35.00   SET              0.02  0.09      NaN  NaN   NaN   NaN
# 188   YUASA    15.40   mai              0.23  0.32      NaN  NaN   NaN   NaN
# 202     PDJ     3.26   SET             31.55  1.22      NaN  NaN   NaN   NaN
# 208     EMC     0.24   SET             13.54  1.06      NaN  NaN   NaN   NaN
# 214     SNP    15.90   SET              0.36  0.33      NaN  NaN   NaN   NaN
# 219   TTLPF    22.80   SET              0.22  0.09      NaN  NaN   NaN   NaN
# 221     TQR    12.40   mai              5.34  0.76      NaN  NaN   NaN   NaN
# 227      2S     6.10   SET              5.68  0.90      NaN  NaN   NaN   NaN
# 229     BCT    52.00   SET              1.11  0.51      NaN  NaN   NaN   NaN
# 236    TYCN     3.64   SET              1.07  0.43      NaN  NaN   NaN   NaN
# 238   UOBKH     4.98   SET              5.53  0.40      NaN  NaN   NaN   NaN
#
#      yield  target_price     _merge
# 3      NaN           NaN  left_only
# 6      NaN           NaN  left_only
# 7      NaN           NaN  left_only
# 15     NaN           NaN  left_only
# 27     NaN           NaN  left_only
# 28     NaN           NaN  left_only
# 29     NaN           NaN  left_only
# 31     NaN           NaN  left_only
# 35     NaN           NaN  left_only
# 46     NaN           NaN  left_only
# 48     NaN           NaN  left_only
# 49     NaN           NaN  left_only
# 50     NaN           NaN  left_only
# 53     NaN           NaN  left_only
# 59     NaN           NaN  left_only
# 67     NaN           NaN  left_only
# 70     NaN           NaN  left_only
# 76     NaN           NaN  left_only
# 80     NaN           NaN  left_only
# 84     NaN           NaN  left_only
# 92     NaN           NaN  left_only
# 93     NaN           NaN  left_only
# 96     NaN           NaN  left_only
# 97     NaN           NaN  left_only
# 98     NaN           NaN  left_only
# 103    NaN           NaN  left_only
# 106    NaN           NaN  left_only
# 107    NaN           NaN  left_only
# 108    NaN           NaN  left_only
# 109    NaN           NaN  left_only
# 112    NaN           NaN  left_only
# 118    NaN           NaN  left_only
# 124    NaN           NaN  left_only
# 130    NaN           NaN  left_only
# 139    NaN           NaN  left_only
# 140    NaN           NaN  left_only
# 143    NaN           NaN  left_only
# 145    NaN           NaN  left_only
# 147    NaN           NaN  left_only
# 151    NaN           NaN  left_only
# 153    NaN           NaN  left_only
# 161    NaN           NaN  left_only
# 162    NaN           NaN  left_only
# 163    NaN           NaN  left_only
# 176    NaN           NaN  left_only
# 178    NaN           NaN  left_only
# 180    NaN           NaN  left_only
# 182    NaN           NaN  left_only
# 188    NaN           NaN  left_only
# 202    NaN           NaN  left_only
# 208    NaN           NaN  left_only
# 214    NaN           NaN  left_only
# 219    NaN           NaN  left_only
# 221    NaN           NaN  left_only
# 227    NaN           NaN  left_only
# 229    NaN           NaN  left_only
# 236    NaN           NaN  left_only
# 238    NaN           NaN  left_only

# %%
cdd3 = df_merge[df_merge['_merge'] == 'both'].copy()
cdd3.shape
# Out:
# (179, 12)

# %%
cdd3['grade'] = 0
cdd3.shape
# Out:
# (179, 13)

# %%
df_merge2 = pd.merge(cdd3, epss, on='name', how='inner')
df_merge2.shape
# Out:
# (169, 26)

# %%
def grade(vals):
    qc, qp, aqc, aqp = vals
    if (aqc < 400_000) & (aqp < 400_000):
        if (qc < 100_000) & (qp < 100_000):
            return 1
        else:
            return 2
    else:
        if (qc < 100_000) & (qp < 100_000):
            return 3
        else:
            return 4

# %%
df_merge2["grade"] = df_merge2[["q_amt", "y_amt","aq_amt", "ay_amt"]].apply(grade, axis=1)
df_merge2.shape[0]
# Out:
# 169

# %%
mask_grade_1 = df_merge2["grade"] == 1
df_merge2[mask_grade_1].shape[0]
# Out:
# 55

# %%
mask_grade_2 = df_merge2["grade"] == 2
df_merge2[mask_grade_2].shape[0]
# Out:
# 12

# %%
mask_grade_3 = df_merge2["grade"] == 3
df_merge2[mask_grade_3].shape[0]
# Out:
# 10

# %%
mask_grade_4 = df_merge2["grade"] == 4
df_merge2[mask_grade_4].shape[0]
# Out:
# 92

# %% [markdown]
# ### Special process for quarter 4

# %%
df_merge2[mask_grade_1]
# Out:
#         name  price_x              market  daily_volume  beta  price_y  buy  \
# 4     AMANAH     5.05            sSET             44.06  1.68     5.05  2.0
# 5       ANAN     1.35            sSET             33.85  1.48     1.35  0.0
# 6       APCS     4.80            sSET             22.84  0.94     4.80  1.0
# 8      ARROW     8.10             mai              0.66  0.41     8.30  1.0
# 12        BA     9.20           SETWB             57.77  1.75     9.20  4.0
# 14    BEAUTY     1.43             SET             19.72  1.67     1.46  0.0
# 18       BRR     4.94            sSET              1.04  1.25     3.76  1.0
# 19      BSBM     1.39             SET              3.48  1.20     1.11  0.0
# 20      CCET     2.80            sSET             23.77  1.05     1.86  0.0
# 22       CWT     3.26             SET             82.16  1.09     3.48  1.0
# 25     DEMCO     3.34            sSET             53.04  1.33     3.82  0.0
# 28     DUSIT     9.15             SET              0.96  0.43     9.15  1.0
# 30       ECL     2.80             SET             88.19  1.71     2.80  2.0
# 32       EKH     7.70            sSET             18.49  0.30     7.70  3.0
# 41     HTECH     4.90             SET             11.50  1.51     4.90  1.0
# 43       IFS     3.08             SET              5.75  0.85     3.48  1.0
# 44       IHL     3.78             SET              1.36  1.30     4.12  0.0
# 46      INET     7.35             SET            123.32  1.52     7.35  0.0
# 47       IRC    15.30             SET              4.11  0.39    15.30  2.0
# 48       JAS     3.42             SET            541.11  1.22     3.42  0.0
# 52    KAMART     4.34            sSET             18.90  0.96     3.82  0.0
# 58       LIT     2.10             mai             14.50  1.09     3.12  0.0
# 63      MBAX     5.35             mai              3.72  0.62     6.25  0.0
# 68       MSC     6.00             SET              5.86  0.65     6.50  1.0
# 70       NYT     4.50  sSET / SETTHSI             15.77  1.42     4.50  4.0
# 74       PDG     4.04             mai              0.82  0.37     4.06  1.0
# 75      PREB     8.55             SET              1.33  0.56     8.55  1.0
# 77     RICHY     1.24             SET             40.65  1.00     1.87  1.0
# 80         S     1.92  sSET / SETTHSI              7.78  1.35     1.92  0.0
# 82    SAMTEL     8.25            sSET             17.06  0.92     8.25  0.0
# 92     SMART     0.90             mai              9.14  0.93     0.83  1.0
# 94       SMT     4.46            sSET             31.92  1.26     4.46  3.0
# 98        SQ     2.20             SET             14.50  1.50     2.20  1.0
# 99    SRICHA    14.30            sSET              9.87  0.92    14.30  1.0
# 100    SUSCO     3.34            sSET             18.77  0.71     3.34  2.0
# 102     SVOA     2.88             SET            183.49  1.78     1.03  0.0
# 103     TACC     7.15             mai             11.37  0.56     7.15  5.0
# 105    THREL     4.68             SET             85.80  0.98     4.68  0.0
# 109      TKN     7.95            sSET             82.78  1.66     7.95  0.0
# 112      TNR     7.70            sSET              0.59  0.45     9.10  1.0
# 113      TOG     9.60            sSET             23.50  1.55     9.60  1.0
# 128     WIIK     2.06             SET              3.62  1.32     2.58  0.0
# 129     WORK    23.60             SET             97.74  1.10    25.00  2.0
# 136      GPI     1.73             SET              2.63  1.28     1.98  0.0
# 138    HUMAN    11.40            sSET            144.36  0.79    11.40  2.0
# 139      RSP     2.50             SET             11.43  1.54     1.63  0.0
# 143    CHAYO    11.50             SET             99.79  1.77    11.50  5.0
# 147  LHHOTEL     7.35             SET              2.16  0.68     9.30  0.0
# 150    S & J     1.92  sSET / SETTHSI              7.78  1.35     3.04  1.0
# 151     SISB     9.05            sSET              1.93  0.52     9.05  2.0
# 158    SABUY    26.50             SET            460.31  1.93    26.50  1.0
# 163    SFLEX     4.46            sSET             12.16  0.37     4.46  2.0
# 164      AAV     2.40  sSET / SETTHSI             49.72  1.70     2.40  4.0
# 167       IP    19.00             mai             26.72  0.62    19.00  1.0
# 168    INSET     5.65             SET             99.12  0.00     5.65  2.0
#
#      hold  sell  yield  ...   q_amt    y_amt   aq_amt   ay_amt    q_eps  \
# 4     1.0   0.0    3.4  ...   76563    77090   307164   290708  0.07700
# 5     1.0   4.0    2.8  ... -220012   -74397  -457342  -206577 -0.09000
# 6     0.0   0.0    1.5  ...    1822    47018   210608    14072  0.00270
# 8     0.0   0.0    5.4  ...    4314    32685   128738   168984  0.01000
# 12    2.0   0.0    0.2  ... -141403  -400693 -8549862 -5283182 -0.07000
# 14    0.0   1.0    0.0  ...   -8440    18911   -80768  -104882 -0.01000
# 18    0.0   0.0    3.2  ...   16754   -52136   129311     6137  0.02000
# 19    1.0   0.0    8.1  ...    5562    18711    72120    84018  0.00100
# 20    1.0   0.0    4.8  ... -291983   -38399   272953   209607 -0.05000
# 22    0.0   0.0    1.2  ...   39577    75595   172152   117031  0.06000
# 25    1.0   0.0    2.1  ...   70119    60515   100864    55201  0.10000
# 28    0.0   0.0    0.0  ... -391412  -133464  -994997 -1011135 -0.41000
# 30    0.0   0.0    3.6  ...   72500    27029   194013    61679  0.06540
# 32    1.0   0.0    2.5  ...   89573    45180   344830    72104  0.14930
# 41    0.0   0.0   -4.9  ...   32646    14505   135282    52991  0.11000
# 43    0.0   0.0    4.9  ...   43742    34369   152824   133616  0.09000
# 44    0.0   0.0    0.0  ...   35908     9400   140742   -44306  0.06000
# 46    1.0   0.0    1.4  ...   35767   -57681   162886    10242  0.08000
# 47    1.0   0.0    5.1  ...   29268    81559   340031   219063  0.15000
# 48    1.0   0.0    0.0  ...   45098  -935370 -1500704 -3134017  0.01000
# 52    0.0   1.0    3.1  ...   61062    38353   292873   132824  0.06700
# 58    0.0   0.0    5.1  ...  -96866    19364   -95493    71241 -0.43600
# 63    0.0   0.0    4.6  ...   37357    15743    62408   176063  0.20000
# 68    0.0   0.0    7.1  ...   56754    21943   197286   155795  0.16000
# 70    1.0   0.0    5.3  ...   61070    90711   242643   228568  0.05000
# 74    0.0   0.0    3.4  ...   12597    21202    55242    98255  0.03000
# 75    0.0   0.0    8.1  ...   86023    56540   241622   165666  0.27900
# 77    0.0   0.0    5.4  ...   -4944    42995   202089   101516 -0.01000
# 80    1.0   0.0    0.5  ...   96657    53928   373167   275907  0.82000
# 82    1.0   0.0    2.6  ...  -12767   -82134    61385  -287504 -0.02000
# 92    0.0   0.0    0.0  ...    9410    15798    39869    45807  0.00880
# 94    1.0   0.0    2.5  ...   46018    32286   209703    81388  0.05100
# 98    0.0   0.0    5.4  ...   41962    71590   350752   240988  0.04000
# 99    1.0   0.0    5.3  ...   -4860    68787   341517   142245 -0.01600
# 100   1.0   0.0    3.7  ...   18939    99121   233527   217655  0.02000
# 102   0.0   0.0    3.9  ...   57645    69369   159907   138879  0.06100
# 103   0.0   0.0    4.9  ...   57838    51244   214239   188380  0.09000
# 105   1.0   0.0    3.8  ...   12543    48809    98496   121435  0.02000
# 109   1.0   0.0    2.4  ...   84430   -20871   182125   242621  0.06000
# 112   0.0   0.0    2.9  ... -584288    43177  -464842   111431 -1.95000
# 113   0.0   0.0    5.8  ...   76237    63057   310121    68781  0.16000
# 128   0.0   0.0    0.0  ...   11355    30899    91417   109342  0.00620
# 129   2.0   0.0    2.7  ...  -17462    34949   324206   159114 -0.04000
# 136   1.0   0.0    4.0  ...  -45602   -34630    30794    34092 -0.08000
# 138   0.0   0.0    1.6  ...   42235    44421   169822   165754  0.06000
# 139   1.0   0.0    1.2  ...   32897    27512    29569     4288  0.04428
# 143   0.0   0.0    0.8  ...   48584    36356   218999   155354  0.04100
# 147   1.0   0.0    0.0  ... -108174   -62609  -437024  -484970 -0.20110
# 150   0.0   0.0    0.0  ...   96657    53928   373167   275907  0.82000
# 151   0.0   0.0    1.2  ...   26589    68077   208753   159933  0.03000
# 158   0.0   0.0    0.9  ...   76782    31796   213605   102058  0.06750
# 163   1.0   0.0    2.3  ...   28831    40378   149415   142805  0.03000
# 164   4.0   1.0    0.0  ... -992745 -1114449 -6647486 -4764092 -0.13260
# 167   0.0   0.0    1.4  ...   36063     3285   105216    52537  0.12000
# 168   0.0   0.0    2.8  ...   39694    33290   170539   135491  0.07000
#
#        y_eps  aq_eps  ay_eps  ticker_id  publish_date
# 4    0.07300  0.3000  0.2800         19    2022-02-15
# 5   -0.06000 -0.2600 -0.1900         23    2022-02-24
# 6    0.07090  0.3190  0.0210         27    2022-02-18
# 8    0.13000  0.5000  0.6600         31    2022-02-23
# 12  -0.19000 -4.1500 -2.5600         45    2022-02-24
# 14   0.00000 -0.0300 -0.0400         55    2022-02-25
# 18  -0.06400  0.1590  0.0080         78    2022-02-24
# 19   0.01200  0.0600  0.0700         79    2022-02-21
# 20  -0.01000  0.0600  0.0400         88    2022-02-25
# 22   0.12000  0.2700  0.1900        134    2022-02-28
# 25   0.09000  0.1400  0.0800        139    2022-02-25
# 28  -0.16000 -1.1200 -1.2000        145    2022-02-25
# 30   0.02440  0.1750  0.0556        153    2022-02-24
# 32   0.07560  0.5773  0.1205        159    2022-02-24
# 41   0.05000  0.4500  0.1800        213    2022-02-28
# 43   0.07000  0.3100  0.2700        219    2022-02-22
# 44   0.02000  0.2400 -0.0700        220    2022-02-25
# 46   0.06000  0.3300  0.2000        223    2022-02-24
# 47   0.42000  1.7700  1.1200        225    2021-11-25
# 48  -0.11000 -0.1700 -0.3700        233    2022-02-24
# 52   0.04300  0.3300  0.1500        243    2022-02-24
# 58   0.08600 -0.4300  0.3200        273    2022-02-23
# 63   0.08000  0.3300  0.9200        288    2022-02-17
# 68   0.06000  0.5500  0.4300        313    2022-02-24
# 70   0.07000  0.2000  0.1800        336    2022-02-21
# 74   0.04000  0.1900  0.3300        347    2022-02-17
# 75   0.18300  0.7830  0.5370        372    2022-02-24
# 77   0.03000  0.1600  0.0800        398    2022-02-28
# 80   0.36000  2.6600  1.8400        410    2022-02-24
# 82  -0.14000  0.1000 -0.4700        418    2022-02-24
# 92   0.01720  0.0419  0.0498        453    2022-02-17
# 94   0.03700  0.2510  0.0970        456    2022-02-17
# 98   0.06000  0.3100  0.2100        472    2022-02-25
# 99   0.22200  1.1020  0.4590        474    2022-02-28
# 100  0.10000  0.2300  0.2100        488    2022-02-22
# 102  0.07400  0.1690  0.1470        492    2022-02-25
# 103  0.08000  0.3500  0.3100        498    2022-02-24
# 105  0.08000  0.1600  0.2000        526    2022-02-22
# 109 -0.01000  0.1300  0.1800        533    2022-02-22
# 112  0.14000 -1.5500  0.3700        553    2022-02-23
# 113  0.14000  0.6500  0.1500        554    2022-02-17
# 128  0.05700  0.1357  0.2363        625    2022-02-23
# 129  0.07900  0.7340  0.3600        628    2022-02-24
# 136 -0.05000  0.0500  0.0600        652    2022-02-24
# 138  0.06000  0.2500  0.2400        655    2022-02-28
# 139  0.03706  0.0398  0.0058        659    2022-02-24
# 143  0.03790  0.2403  0.2002        671    2022-02-24
# 147 -0.11640 -0.8124 -0.9016        679    2022-02-28
# 150  0.36000  2.6600  1.8400        693    2022-02-24
# 151  0.07000  0.2200  0.1700        683    2022-02-24
# 158  0.03290  0.2010  0.1120        721    2022-02-22
# 163  0.05000  0.1800  0.1700        731    2022-02-25
# 164 -0.22980 -1.2985 -0.9823        732    2022-02-24
# 167  0.01200  0.3600  0.1820        736    2022-02-25
# 168  0.05000  0.2800  0.2200        738    2022-02-18
#
# [55 rows x 26 columns]

# %% [markdown]
# ### Process for worse performance stocks

# %%
cols = 'name q_amt y_amt aq_amt ay_amt market daily_volume beta'.split()
cols

# %%
pd.set_option('display.max_rows', 100)
worse1 = df_merge[mask_grade_1]
worse1[cols].style.format(format_dict)

# %%
worse2 = df_merge[mask_grade_2]
worse2[cols].style.format(format_dict)

# %%
set50 = worse1.market.str.contains('SET50')
set100 = worse1.market.str.contains('SET100')
mai = worse1.market.str.contains('mai')
set = ~(set50 | set100 | mai)

# %%
worse1[~(set | mai)]

# %%
cdd1 = worse1[set | mai]
cdd1.shape[0]

# %%
cdd2 = worse2[worse2.daily_volume < 10.0]
cdd2.shape[0]

# %% [markdown]
# ### Combine dataframes

# %%
frames = [cdd1, cdd2]
cdd = pd.concat(frames, sort=False)
cdd.sort_values(['name'],ascending=[True])

# %% [markdown]
# ### End of Process for worse performance stocks

# %%
sr = cdd['name']
sr

# %%
file_name = 'new-exempts.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
output_file, box_file, data_file

# %%
sr.to_csv(output_file,index=False)
sr.to_csv(box_file,index=False)
sr.to_csv(data_file,index=False)
