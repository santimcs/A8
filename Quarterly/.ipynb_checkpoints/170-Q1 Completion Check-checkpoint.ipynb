# %%
import pandas as pd
from sqlalchemy import create_engine
from glob import glob

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

data_path = "../data/"
irreg_path = "../data/irreg/"

# %%
year = 2021
quarter = 1
year, quarter
# Out:
# (2021, 1)

# %% [markdown]
# ### Begin of Irregular quarter

# %% [markdown]
# ### Irregular Quarter Plus 2

# %%
file_name   = 'P2-Stocks.csv'
input_file = irreg_path + file_name
col_names   = ['name']
data_ins = pd.read_csv(input_file, sep=',', header=None, index_col=None, names=col_names)
data_ins
# Out:
#   name
# 0  TNH

# %%
sr = data_ins['name']
names = sr.values.tolist()
in_p = ', '.join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'TNH'"

# %%
sql = '''
SELECT name, COUNT(*) FROM epss 
WHERE name in (%s)
AND ((year = %s AND quarter <= %s + 2)
OR (year = %s - 1 AND quarter > %s + 2))
GROUP BY name
HAVING COUNT(*) < 4
ORDER BY name'''
sql = sql % (in_p, year, quarter, year, quarter)
print(sql)
# Out:
# SELECT name, COUNT(*) FROM epss
# WHERE name in ('TNH')
# AND ((year = 2021 AND quarter <= 1 + 2)
# OR (year = 2021 - 1 AND quarter > 1 + 2))
# GROUP BY name
# HAVING COUNT(*) < 4
# ORDER BY name

# %%
df = pd.read_sql(sql, conlt)
df
# Out:
# Empty DataFrame
# Columns: [name, COUNT(*)]
# Index: []

# %% [markdown]
# ### Irregular Quarter Plus 1

# %%
file_name   = 'P1-Stocks.csv'
input_file = irreg_path + file_name
col_names   = ['name']
data_ins = pd.read_csv(input_file, sep=',', header=None, index_col=None, names=col_names)
data_ins
# Out:
#      name
# 0     AOT
# 1    CITY
# 2  GVREIT
# 3     IRC
# 4    KTIS
# 5   OISHI
# 6    PICO
# 7     SSC
# 8     TSC
# 9      UV

# %%
sr = data_ins["name"]
names = sr.values.tolist()
in_p = ', '.join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AOT', 'CITY', 'GVREIT', 'IRC', 'KTIS', 'OISHI', 'PICO', 'SSC', 'TSC', 'UV'"

# %%
sql = '''
SELECT name, COUNT(*) FROM epss 
WHERE name in (%s)
AND ((year = %s AND quarter <= %s + 1)
OR (year = %s - 1 AND quarter > %s + 1))
GROUP BY name
HAVING COUNT(*) < 4
ORDER BY name'''
sql = sql % (in_p, year, quarter, year, quarter)
print(sql)
# Out:
# SELECT name, COUNT(*) FROM epss
# WHERE name in ('AOT', 'CITY', 'GVREIT', 'IRC', 'KTIS', 'OISHI', 'PICO', 'SSC', 'TSC', 'UV')
# AND ((year = 2021 AND quarter <= 1 + 1)
# OR (year = 2021 - 1 AND quarter > 1 + 1))
# GROUP BY name
# HAVING COUNT(*) < 4
# ORDER BY name

# %%
df = pd.read_sql(sql, conlt)
df
# Out:
# Empty DataFrame
# Columns: [name, COUNT(*)]
# Index: []

# %% [markdown]
# ### Irregular Quarter Minus 1

# %%
file_name   = 'M1-Stocks.csv'
input_file = irreg_path + file_name
col_names   = ['name']
data_ins = pd.read_csv(input_file, sep=',', header=None, index_col=None, names=col_names)
data_ins
# Out:
#       name
# 0   AEONTS
# 1    BLAND
# 2      BTS
# 3   BTSGIF
# 4      EPG
# 5   IMPACT
# 6    INGRS
# 7      KYE
# 8      LHK
# 9     MACO
# 10     PTL
# 11     SFP
# 12  STANLY
# 13    TIF1
# 14    TLGF
# 15     TMW
# 16      TR
# 17    TSTH
# 18     VGI
# 19   WHABT

# %%
sr = data_ins["name"]
names = sr.values.tolist()
in_p = ', '.join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AEONTS', 'BLAND', 'BTS', 'BTSGIF', 'EPG', 'IMPACT', 'INGRS', 'KYE', 'LHK', 'MACO', 'PTL', 'SFP', 'STANLY', 'TIF1', 'TLGF', 'TMW', 'TR', 'TSTH', 'VGI', 'WHABT'"

# %%
sql = '''
SELECT name, COUNT(*) FROM epss 
WHERE name in (%s)
AND year = %s - 1
GROUP BY name
HAVING COUNT(*) < 4
ORDER BY name'''
sql = sql % (in_p, year)
print(sql)
# Out:
# SELECT name, COUNT(*) FROM epss
# WHERE name in ('AEONTS', 'BLAND', 'BTS', 'BTSGIF', 'EPG', 'IMPACT', 'INGRS', 'KYE', 'LHK', 'MACO', 'PTL', 'SFP', 'STANLY', 'TIF1', 'TLGF', 'TMW', 'TR', 'TSTH', 'VGI', 'WHABT')
# AND year = 2021 - 1
# GROUP BY name
# HAVING COUNT(*) < 4
# ORDER BY name

# %%
df = pd.read_sql(sql, conlt)
df
# Out:
# Empty DataFrame
# Columns: [name, COUNT(*)]
# Index: []

# %% [markdown]
# ### End of Irregular quarter

# %% [markdown]
# ### Normal Quarter Stocks

# %%
irreg_files = sorted(glob('../data/irreg/*.csv'))
irreg_files
# Out:
# ['../data/irreg\\M1-Stocks.csv',
#  '../data/irreg\\P1-Stocks.csv',
#  '../data/irreg\\P2-Stocks.csv']

# %%
col_names = ['name']
df_tmp = pd.concat((pd.read_csv(file) for file in irreg_files), ignore_index=True)
df_tmp
# Out:
#       name
# 0   AEONTS
# 1    BLAND
# 2      BTS
# 3   BTSGIF
# 4      EPG
# 5   IMPACT
# 6    INGRS
# 7      KYE
# 8      LHK
# 9     MACO
# 10     PTL
# 11     SFP
# 12  STANLY
# 13    TIF1
# 14    TLGF
# 15     TMW
# 16      TR
# 17    TSTH
# 18     VGI
# 19   WHABT
# 20     AOT
# 21    CITY
# 22  GVREIT
# 23     IRC
# 24    KTIS
# 25   OISHI
# 26    PICO
# 27     SSC
# 28     TSC
# 29      UV
# 30     TNH

# %%
sr = df_tmp['name']
names = sr.values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AEONTS', 'BLAND', 'BTS', 'BTSGIF', 'EPG', 'IMPACT', 'INGRS', 'KYE', 'LHK', 'MACO', 'PTL', 'SFP', 'STANLY', 'TIF1', 'TLGF', 'TMW', 'TR', 'TSTH', 'VGI', 'WHABT', 'AOT', 'CITY', 'GVREIT', 'IRC', 'KTIS', 'OISHI', 'PICO', 'SSC', 'TSC', 'UV', 'TNH'"

# %%
sql = """
SELECT name, COUNT(*) AS quarters 
FROM epss 
WHERE name NOT IN (%s)
AND ((year = %s AND quarter <= %s) OR (year = %s-1 AND quarter >= %s+1))
GROUP BY name
HAVING COUNT(*) < 4
ORDER BY name"""
sql = sql % (in_p, year, quarter, year, quarter)
print(sql)
# Out:
# SELECT name, COUNT(*) AS quarters
# FROM epss
# WHERE name NOT IN ('AEONTS', 'BLAND', 'BTS', 'BTSGIF', 'EPG', 'IMPACT', 'INGRS', 'KYE', 'LHK', 'MACO', 'PTL', 'SFP', 'STANLY', 'TIF1', 'TLGF', 'TMW', 'TR', 'TSTH', 'VGI', 'WHABT', 'AOT', 'CITY', 'GVREIT', 'IRC', 'KTIS', 'OISHI', 'PICO', 'SSC', 'TSC', 'UV', 'TNH')
# AND ((year = 2021 AND quarter <= 1) OR (year = 2021-1 AND quarter >= 1+1))
# GROUP BY name
# HAVING COUNT(*) < 4
# ORDER BY name

# %%
df = pd.read_sql(sql, conlt)
df
# Out:
#      name  quarters
# 0      EP         1
# 1      OR         3
# 2   SABUY         1
# 3  TIDLOR         1
# 4     TQR         1

# %% [markdown]
# ### End of Normal Quarter stocks

# %% [markdown]
# ### New stocks with less than 4 quarters EPS

# %%
#Cannot understand logic
sql = '''
SELECT name, COUNT(*) FROM epss 
WHERE (year = %s AND quarter = %s) 
OR (year = %s-1 AND quarter > %s)
GROUP BY name 
HAVING MAX(quarter) < 4 
ORDER BY name'''
sql = sql % (year, quarter, year, quarter)
print(sql)
# Out:
# SELECT name, COUNT(*) FROM epss
# WHERE (year = 2021 AND quarter = 1)
# OR (year = 2021-1 AND quarter > 1)
# GROUP BY name
# HAVING MAX(quarter) < 4
# ORDER BY name

# %%
df_tmp = pd.read_sql(sql, conlt)
df_tmp
# Out:
#      name  COUNT(*)
# 0      EP         1
# 1   SABUY         1
# 2  TIDLOR         1
# 3     TQR         1

# %% [markdown]
# ### Delete EPSS record that unmatch with Tickers in PortPg

# %%
sql = '''
SELECT *
FROM epss E
WHERE E.ticker_id NOT IN
(SELECT id FROM tickers)
'''
df = pd.read_sql(sql, conpg)
df.shape
# Out:
# (0, 14)

# %%
rp = conpg.execute(sql)
rp.rowcount
# Out:
# 0

# %%
sql = '''
SELECT *
FROM epss
'''
epss = pd.read_sql(sql, conlt)
epss.shape
# Out:
# (9703, 14)

# %%
sql = '''
SELECT *
FROM tickers
'''
tickers = pd.read_sql(sql, conpg)
tickers.shape
# Out:
# (389, 9)

# %%
df_merge = pd.merge(epss, tickers, on='name', how='outer', indicator = True)
df_merge.shape
# Out:
# (9703, 23)

# %%
df_left = df_merge[df_merge['_merge'] == 'left_only']
df_left
# Out:
# Empty DataFrame
# Columns: [id_x, name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps, ticker_id, publish_date, id_y, full_name, sector, subsector, market, website, created_at, updated_at, _merge]
# Index: []
#
# [0 rows x 23 columns]

# %%
name_ary = df_left['name'].unique()
name_ary
# Out:
# array([], dtype=object)

# %%
sql = '''
SELECT *
FROM epss
WHERE name IN (%s)
'''
in_p = ', '.join(map(lambda name: "'%s'" % name, name_ary))
sql = sql % (in_p)
errors = pd.read_sql(sql, conlt)
errors
# Out:
# Empty DataFrame
# Columns: [id, name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps, ticker_id, publish_date]
# Index: []

# %% [markdown]
# ### Delete YR_PROFITS record that unmatch with Tickers in PortPg

# %%
sql = """
SELECT name, sector, subsector 
FROM tickers
"""
tickers = pd.read_sql(sql, conpg)
tickers.shape
# Out:
# (389, 3)

# %%
sql = '''
SELECT *
FROM yr_profits
'''
yr_profits = pd.read_sql(sql, conlt)
yr_profits.shape
# Out:
# (6034, 9)

# %%
df_merge = pd.merge(yr_profits, tickers, on="name", how="outer", indicator=True)
df_merge.shape
# Out:
# (6049, 12)

# %%
df_left = df_merge[df_merge["_merge"] == "left_only"]
df_left.shape
# Out:
# (0, 12)

# %%
name_ary = df_left["name"].unique()
name_ary
# Out:
# array([], dtype=object)

# %%
sql = '''
SELECT *
FROM yr_profits
WHERE name IN (%s)
'''
in_p = ', '.join(map(lambda name: "'%s'" % name, name_ary))
sql = sql % (in_p)
errors = pd.read_sql(sql, conlt)
errors
# Out:
# Empty DataFrame
# Columns: [id, name, year, quarter, latest_amt, previous_amt, inc_amt, inc_pct, ticker_id]
# Index: []

# %%
sql = '''
DELETE
FROM yr_profits
WHERE name IN (%s)
'''
in_p = ', '.join(map(lambda name: "'%s'" % name, name_ary))
sql = sql % (in_p)
print(sql)
# Out:
# DELETE
# FROM yr_profits
# WHERE name IN ()

# %%
rp = conlt.execute(sql)
rp.rowcount
# Out:
# 0

# %% [markdown]
# ### Profits table

# %%
pd.set_option('display.max_rows',None)
sql = '''
SELECT * 
FROM profits
ORDER BY name, year, quarter
'''
profits = pd.read_sql(sql, conmy)
profits
# Out:
#       id    name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0   2016      AP  2021        1     1       5010831         2607844
# 1   1984   ASIAN  2021        1     1        928093          177942
# 2   1935     ASK  2021        1     1        958779          874555
# 3   2007     BCH  2021        1     1       1294039         1145941
# 4   2020     BGC  2021        1     1        537823          510234
# 5   2011     BKI  2021        1     1       2852925         2538062
# 6   2013     CHG  2021        1     0        941917          712417
# 7   1949    COM7  2021        1     1       1768408         1254088
# 8   1990     CPF  2021        1     1      26856926        20287329
# 9   1923     DCC  2021        1     1       1711210         1033969
# 10  1907   DELTA  2021        1     1       8001920         2730385
# 11  2015  DOHOME  2021        1     1       1092533          656129
# 12  2031     DRT  2021        1     1        585184          527811
# 13  1939    EGCO  2021        1     0       9731861         8896644
# 14  2033     EPG  2020        4     0       1218890         1002796
# 15  1926      GC  2021        1     1        169017          119050
# 16  1924  GLOBAL  2021        1     1       2305813         2167689
# 17  2010    GULF  2021        1     0       6327529         3180621
# 18  1988  GUNKUL  2021        1     0       3581829         2361537
# 19  1996    HANA  2021        1     0       2005220         1705046
# 20  2001   HREIT  2021        1     1        732493          711113
# 21  1925     IVL  2021        1     1       7852368         2115100
# 22  1992   JMART  2021        1     1       1026552          520330
# 23  1993     JMT  2021        1     0       1123058          743646
# 24  1943     KCE  2021        1     1       1205287         1090736
# 25  2032   LALIN  2021        1     0       1405725          885626
# 26  1931     MCS  2021        1     1        971658          755434
# 27  1995    MEGA  2021        1     0       1406222         1204789
# 28  2014     MTC  2021        1     1       5350238         4469447
# 29  2017     NER  2021        1     0       1165281          497842
# 30  1960     ORI  2021        1     1       2891841         2901660
# 31  1958      PM  2021        1     1        451932          250288
# 32  1989     PRM  2021        1     0       1666901         1068523
# 33  1991     PTG  2021        1     0       2222132         1244258
# 34  1997     PTT  2021        1     1      71907779        62084169
# 35  1921   PTTEP  2021        1     1      25585211        44935859
# 36  2018   PTTGC  2021        1     1      18678590        -3544689
# 37  2012   RATCH  2021        1     0       7013715         5582839
# 38  1936     RJH  2021        1     0        436349          266245
# 39  2027   ROJNA  2021        1     0       2483424          618652
# 40  2028   SAWAD  2021        1     1       4836398         3946325
# 41  1922     SCC  2021        1     1      42086625        27323094
# 42  1986    SCCC  2021        1     1       3918109         2877924
# 43  1987    SENA  2021        1     0       1118457          960564
# 44  2019     SGP  2021        1     1       2908691         1275083
# 45  1948  SINGER  2021        1     1        496524          212739
# 46  1952     SIS  2021        1     1        658058          459628
# 47  2003    SMPC  2021        1     1        586969          436599
# 48  1951     STA  2021        1     1      14635570         1333289
# 49  2029     SUC  2021        1     0       1107419          802294
# 50  1947   SYNEX  2021        1     1        695419          471477
# 51  1956   TASCO  2021        1     0       4797759         1621884
# 52  2030    TCCC  2021        1     1       1702328          943810
# 53  1942     TIP  2021        1     1       2175605         1870830
# 54  2024   TISCO  2021        1     1       6345021         7024620
# 55  1994     TOA  2021        1     1       2279866         1950342
# 56  2009   TPIPL  2021        1     1       2259219         1267373
# 57  2002   TPIPP  2021        1     0       4599705         4591273
# 58  1985     TQM  2021        1     1        724313          579999
# 59  1930      TU  2021        1     1       7032761         3558706
# 60  2004     TVO  2021        1     1       2044482         1546620
#
#     inc_amt_y   inc_pct_y  latest_amt_q  ...   q_amt_c    y_amt  inc_amt_py  \
# 0     2402987   92.140000       5010831  ...   1402754   618458      784296
# 1      750151  421.570000        928093  ...    214839   104802      110037
# 2       84224    9.630000        958779  ...    276197   200482       75715
# 3      148098   12.920000       1294039  ...    323774   259140       64634
# 4       27589    5.410000        537823  ...    182428   161016       21412
# 5      314863   12.410000       2852925  ...    816116   668787      147329
# 6      229500   32.210000        941917  ...    251785   186485       65300
# 7      514320   41.010000       1768408  ...    565608   287882      277726
# 8     6569597   32.380000      26856926  ...   6945465  6110928      834537
# 9      677241   65.500000       1711210  ...    493133   367268      125865
# 10    5271535  193.070000       8001920  ...   1756771   856489      900282
# 11     436404   66.510000       1092533  ...    543153   177301      365852
# 12      57373   10.870000        585184  ...    195965   168201       27764
# 13     835217    9.390000       9731861  ...    585461  -413369      998830
# 14     216094   21.549149       1218890  ...    403732   245439      158293
# 15      49967   41.970000        169017  ...     67783    34810       32973
# 16     138124    6.370000       2305813  ...    965774   615924      349850
# 17    3146908   98.940000       6327529  ...   1632160  -413254     2045414
# 18    1220292   51.670000       3581829  ...    608590   439097      169493
# 19     300174   17.610000       2005220  ...    301195   203716       97479
# 20      21380    3.010000        732493  ...    250168   126750      123418
# 21    5737268  271.250000       7852368  ...   6008807   570715     5438092
# 22     506222   97.290000       1026552  ...    333464   104783      228681
# 23     379412   51.020000       1123058  ...    282826   206809       76017
# 24     114551   10.500000       1205287  ...    503323   424823       78500
# 25     520099   58.730000       1405725  ...    319712   247612       72100
# 26     216224   28.620000        971658  ...    233572   215992       17580
# 27     201433   16.720000       1406222  ...    333548   319977       13571
# 28     880791   19.710000       5350238  ...   1373656  1237342      136314
# 29     667439  134.070000       1165281  ...    366498    59894      306604
# 23    29.345842
# 24    11.219416
# 25    32.225745
# 26    12.190792
# 27    16.120494
# 28     8.841226
# 29   237.843091
# 30    17.848772
# 31    32.152548
# 32    29.562170
# 33    79.563635
# 34  1057.299602
# 35   180.548140
# 36  4487.292592
# 37    23.688881
# 38    37.974478
# 39   149.412038
# 40    12.566324
# 41    39.166239
# 42    13.522810
# 43    23.964759
# 44    71.055712
# 45    57.168123
# 46    18.923842
# 47    23.567894
# 48   472.187732
# 49   263.652366
# 50    21.256383
# 51   111.125577
# 52   110.788917
# 53    14.609496
# 54    11.685486
# 55    21.284062
# 56   253.843241
# 57     7.516502
# 58     9.624396
# 59    41.143010
# 60    32.912650
#
# [61 rows x 23 columns]

# %% [markdown]
# ### End of Delete Profits records

# %%
sql = """
SELECT * 
FROM tickers
LIMIT 1"""
tickers = pd.read_sql(sql, conlt)
tickers.dtypes
# Out:
# id             int64
# name          object
# full_name     object
# sector        object
# subsector     object
# market        object
# website       object
# created_at    object
# updated_at    object
# dtype: object

# %%
sql = """
SELECT DISTINCT T.sector, T.subsector
FROM profits P
JOIN tickers T ON P.ticker_id = T.id
ORDER BY T.sector, T.subsector
"""
pwc = pd.read_sql(sql, conlt)
pwc
# Out:
#                      sector                               subsector
# 0      Agro & Food Industry                            Agribusiness
# 1      Agro & Food Industry                         Food & Beverage
# 2         Consumer Products                                 Fashion
# 3                Financials                                 Banking
# 4                Financials                    Finance & Securities
# 5                Financials                               Insurance
# 6               Industrials                               Packaging
# 7               Industrials              Petrochemicals & Chemicals
# 8               Industrials                                   Steel
# 9   Property & Construction                  Construction Materials
# 10  Property & Construction                    Property Development
# 11  Property & Construction                   Property Fund & REITs
# 12                Resources                      Energy & Utilities
# 13                 Services                                Commerce
# 14                 Services                    Health Care Services
# 15                 Services              Transportation & Logistics
# 16               Technology                   Electronic Components
# 17               Technology  Information & Communication Technology

# %%
sql = """
SELECT * 
FROM consensus
LIMIT 1"""
consensus = pd.read_sql(sql, conlt)
consensus
# Out:
#    id    name  price  buy  hold  sell  eps_a  eps_b    pe  pbv  yield  \
# 0   2  ADVANC  174.5   12     0     0   9.27    9.7  18.8  6.2    3.8
#
#    target_price status  ticker_id                  created_at  \
# 0           220      X          6  2017-07-23 09:50:15.621932
#
#                    updated_at
# 0  2021-06-15 02:51:09.212382

# %%
sql = """
SELECT P.name, year, quarter, C.buy, C.hold, C.sell
FROM profits P
JOIN tickers T ON P.ticker_id = T.id
JOIN consensus C ON C.ticker_id = T.id
ORDER BY C.buy DESC
"""
pwc = pd.read_sql(sql, conlt)
pwc
# Out:
#        name  year  quarter  buy  hold  sell
# 0     PTTGC  2021        1   18     1     0
# 1        TU  2021        1   16     3     0
# 2       PTT  2021        1   16     0     0
# 3       KCE  2021        1   13     0     1
# 4       CPF  2021        1   13     1     0
# 5       BCH  2021        1   13     4     0
# 6        AP  2021        1   13     1     0
# 7       CHG  2021        1   12     4     0
# 8       MTC  2021        1   12     2     0
# 9       IVL  2021        1   11     4     1
# 10     GPSC  2021        1   10     2     1
# 11    BGRIM  2021        1   10     2     0
# 12      PTG  2021        1   10     0     0
# 13    AMATA  2021        1   10     1     1
# 14      CBG  2021        1   10     2     0
# 15    SAWAD  2021        1   10     5     0
# 16     HANA  2021        1    8     3     2
# 17      TVO  2021        1    8     2     0
# 18     GULF  2021        1    8     2     0
# 19      EPG  2020        4    8     1     0
# 20   GLOBAL  2021        1    7     2     0
# 21     MEGA  2021        1    7     1     0
# 22    RATCH  2021        1    7     1     0
# 23      NER  2021        1    7     0     0
# 24     COM7  2021        1    6     3     0
# 25      STA  2021        1    6     1     1
# 26     SCCC  2021        1    6     0     0
# 27      TOA  2021        1    6     1     0
# 28    PTTEP  2021        1    5     2     0
# 29     EGCO  2021        1    5     2     0
# 30      PRM  2021        1    5     1     0
# 31      JMT  2021        1    5     0     0
# 32   DOHOME  2021        1    5     1     0
# 33    NOBLE  2021        1    5     0     0
# 34      KTC  2021        1    5     1     2
# 35      TQM  2021        1    4     0     0
# 36   GUNKUL  2021        1    4     1     0
# 37      DCC  2021        1    3     2     0
# 38      RJH  2021        1    3     2     1
# 39   SINGER  2021        1    3     0     0
# 40    TASCO  2021        1    3     5     1
# 41    ASIAN  2021        1    3     1     0
# 42     SENA  2021        1    3     0     0
# 43    JMART  2021        1    3     0     0
# 44    TPIPL  2021        1    3     0     0
# 45      BGC  2021        1    3     1     0
# 46    TISCO  2021        1    3     0     0
# 47      SCC  2021        1    2     2     0
# 48      MCS  2021        1    2     0     0
# 49    SYNEX  2021        1    2     5     0
# 50      SIS  2021        1    2     0     0
# 51    HREIT  2021        1    2     0     0
# 52    TPIPP  2021        1    2     1     0
# 53     SMPC  2021        1    2     1     0
# 54      DIF  2021        1    2     1     0
# 55     TCAP  2021        1    2     6     0
# 56    ROJNA  2021        1    2     0     0
# 57      DRT  2021        1    2     0     0
# 58    DELTA  2021        1    1     1     1
# 59  BOFFICE  2021        1    1     0     0
# 60      ASK  2021        1    1     1     1
# 61       PM  2021        1    1     0     0
# 62      BKI  2021        1    1     0     0
# 63    LALIN  2021        1    1     2     0
# 64      SGP  2021        1    0     1     0

# %% [markdown]
# ### Delete Profits records by Name

# %%
sql = '''
SELECT * 
FROM profits
ORDER BY name, year, quarter'''
profits = pd.read_sql(sql, conlt)
profits.shape
# Out:
# (74, 23)

# %%
names = '''
'''.split()
in_p = ', '.join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# ''

# %%
sql = '''
DELETE FROM profits
WHERE name IN (%s)'''
sql = sql % in_p
print(sql)
# Out:
# DELETE FROM profits
# WHERE name IN ()

# %%
rp = conlt.execute(sql)
rp.rowcount
# Out:
# 0

# %% [markdown]
# ### Delete profits by year

# %%
sql = '''
DELETE FROM profits
WHERE year = 2020'''
#sql = sql % in_p
print(sql)
# Out:
# DELETE FROM profits
# WHERE year = 2020

# %%
rp = conlt.execute(sql)
rp.rowcount
# Out:
# 0

# %% [markdown]
# ### End of Delete profits by year
