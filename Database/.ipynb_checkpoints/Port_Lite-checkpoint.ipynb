# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

format_dict = {
    'qty':'{:,}','price':'{:.2f}','amount':'{:,.2f}'
}
cols = 'trade name qty price active'.split()

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2022, 5, 14), datetime.date(2022, 5, 13))

# %%
#yesterday = date(2021, 5, 14)
yesterday
# Out:
# datetime.date(2022, 5, 13)

# %% [markdown]
# ### Matching check with profits in portmy database

# %%
format_dict = {
    'shares':'{:,}',    
    'q4':'{:.4f}','q3':'{:.4f}','q2':'{:.4f}','q1':'{:.4f}','dividend':'{:.4f}',
    'xdate':'{:%Y-%m-%d}','paiddate':'{:%Y-%m-%d}',
}

# %%
sql = '''
SELECT *
FROM stocks
ORDER BY market, name'''
stocks = pd.read_sql(sql, conlite)
stocks.dtypes
# Out:
# id                 int64
# name              object
# max_price        float64
# min_price        float64
# status            object
# buy_target       float64
# sell_target      float64
# volume           float64
# beta             float64
# cost             float64
# qty                int64
# buy_spread         int64
# sell_spread        int64
# available_qty      int64
# bl                 int64
# sh                 int64
# reason            object
# market            object
# dtype: object

# %%
sql = '''
SELECT *
FROM profits
ORDER BY name'''
profits = pd.read_sql(sql, conmy)
profits.shape
# Out:
# (34, 23)

# %%
df_merge = pd.merge(stocks, profits, on='name', how='outer', indicator=True)
df_merge.shape
# Out:
# (68, 27)

# %%
names = df_merge[df_merge._merge == 'right_only']['name']
names
# Out:
# 50      AIT
# 51      ASK
# 52      BAY
# 53     BCPG
# 54       BH
# 55      BPP
# 56    COTTO
# 57     ESSO
# 58      GGC
# 59      IVL
# 60      MST
# 61      PTL
# 62      RBF
# 63      SIS
# 64     SMPC
# 65     SPRC
# 66      TOP
# 67      TTB
# Name: name, dtype: object

# %%
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AIT', 'ASK', 'BAY', 'BCPG', 'BH', 'BPP', 'COTTO', 'ESSO', 'GGC', 'IVL', 'MST', 'PTL', 'RBF', 'SIS', 'SMPC', 'SPRC', 'TOP', 'TTB'"

# %%
sql = """
SELECT * 
FROM stocks
WHERE name IN (%s)"""
sql = sql % in_p
my_stocks = pd.read_sql(sql, conmy)
my_stocks
# Out:
#      id   name                                  market   price  max_price  \
# 0    11    AIT                                sSET        7.05       9.80
# 1    38    ASK                                 SET       44.75      49.50
# 2    49    BAY                                 SET       34.75      39.25
# 3    53   BCPG  SET100 / SETCLMV / SETHD / SETTHSI       12.20      15.40
# 4    61     BH             SET50 / SETCLMV / SETWB      165.50     175.00
# 5    74    BPP  SET100 / SETCLMV / SETHD / SETTHSI       16.20      20.30
# 6   709  COTTO                                 SET        2.14       3.18
# 7   165   ESSO                              SET100        8.55       8.90
# 8   188    GGC                                sSET       14.20      14.40
# 9   231    IVL                     SET50 / SETTHSI       47.00      52.00
# 10  290    MST                                 SET       11.80      14.70
# 11  382    PTL                                 SET       24.90      31.75
# 12  702    RBF            SET100 / SETCLMV / SETWB       17.20      24.50
# 13  449    SIS                                sSET       40.00      48.75
# 14  455   SMPC                                sSET       13.60      14.20
# 15  470   SPRC                    SET100 / SETCLMV       10.10      11.50
# 16  555    TOP           SET50 / SETCLMV / SETTHSI       54.25      61.50
# 17  541    TTB             SET50 / SETHD / SETTHSI        1.28       1.50
#
#     min_price      pe   pbv   paid_up  market_cap  daily_volume  beta  \
# 0        4.12   13.80  2.38   1031.60     7272.81        140.03  1.00
# 1       20.06   19.64  2.55   2639.22    23620.99         59.77  0.81
# 2       27.25    7.56  0.81  73557.62   255612.72         52.47  1.29
# 3       11.10   17.56  1.30  14470.45    35307.89        157.15  0.95
# 4      116.50  108.33  7.62    794.89   131553.59        480.52  0.43
# 5       15.30   15.79  1.08  30477.32    49373.25         28.02  0.83
# 6        1.55   21.86  1.38   5962.62    12760.01         10.15  0.87
# 7        7.00    6.66  1.54  17075.18    29590.34        173.92  1.03
# 8        9.60   44.02  1.46   9724.83    14536.07          9.31  0.96
# 9       36.00   10.04  1.66   5614.55   263883.94       1112.71  1.41
# 10       9.30    8.85  1.40   2854.07     6735.61          4.79  0.59
# 11      22.30    6.77  1.28    900.00    22410.00         82.83  0.78
# 12      14.70   81.89  8.14   2000.00    34400.00        154.65  1.17
# 13      25.75   17.67  4.31    350.20    14007.95         33.27  1.75
# 14      10.00   10.01  2.95    535.51     7282.89         14.45  0.66
# 15       7.75    9.23  1.27  30004.44    43792.61        376.23  1.05
# 16      42.50    8.80  0.92  20400.28   110671.51        817.89  1.22
# 17       0.95   11.81  0.59  91791.73   123677.28        708.25  1.40
#
#     ticker_id                  created_at                  updated_at
# 0          11  2017-07-23 07:24:21.511814  2022-04-23 07:59:15.976370
# 1          38  2017-07-23 07:24:24.813799  2022-04-23 07:59:16.069839
# 2          49  2017-07-23 07:24:26.121801  2022-04-23 07:59:16.119414
# 3          53  2017-07-23 07:24:26.597527  2022-04-23 07:59:16.144197
# 4          61  2017-07-23 07:24:27.506069  2022-04-23 07:59:16.220382
# 5          74  2017-07-23 07:24:29.294209  2022-04-23 07:59:16.269758
# 6         710  2021-01-26 16:02:29.528911  2022-04-23 07:59:16.396054
# 7         165  2017-07-23 07:24:41.623403  2022-04-23 07:59:16.582726
# 8         188  2017-07-23 07:24:45.913164  2022-04-23 07:59:16.642888
# 9         231  2017-07-23 07:24:52.636551  2022-04-23 07:59:16.890998
# 10        290  2017-07-23 07:24:59.950822  2022-04-23 07:59:17.185297
# 11        382  2017-07-23 07:25:15.502568  2022-04-23 07:59:17.393950
# 12        703  2019-11-20 04:28:54.041765  2022-04-23 07:59:17.442525
# 13        449  2017-07-23 07:25:26.260437  2022-04-23 07:59:17.622924
# 14        455  2017-07-23 07:25:27.192504  2022-04-23 07:59:17.669999
# 15        470  2017-07-23 07:25:29.084945  2022-04-23 07:59:17.748199
# 16        555  2017-07-23 07:25:41.632818  2022-04-23 07:59:18.079655
# 17        541  2017-07-23 07:25:39.022815  2022-04-23 07:59:18.139507

# %%
sql = """
SELECT name, market, max_price, min_price, daily_volume, beta 
FROM stocks
WHERE name IN (%s)"""
sql = sql % in_p
mst = pd.read_sql(sql, conmy)
mst
# Out:
#      name                                  market  max_price  min_price  \
# 0     AIT                                sSET           9.80       4.12
# 1     ASK                                 SET          49.50      20.06
# 2     BAY                                 SET          39.25      27.25
# 3    BCPG  SET100 / SETCLMV / SETHD / SETTHSI          15.40      11.10
# 4      BH             SET50 / SETCLMV / SETWB         175.00     116.50
# 5     BPP  SET100 / SETCLMV / SETHD / SETTHSI          20.30      15.30
# 6   COTTO                                 SET           3.18       1.55
# 7    ESSO                              SET100           8.90       7.00
# 8     GGC                                sSET          14.40       9.60
# 9     IVL                     SET50 / SETTHSI          52.00      36.00
# 10    MST                                 SET          14.70       9.30
# 11    PTL                                 SET          31.75      22.30
# 12    RBF            SET100 / SETCLMV / SETWB          24.50      14.70
# 13    SIS                                sSET          48.75      25.75
# 14   SMPC                                sSET          14.20      10.00
# 15   SPRC                    SET100 / SETCLMV          11.50       7.75
# 16    TOP           SET50 / SETCLMV / SETTHSI          61.50      42.50
# 17    TTB             SET50 / SETHD / SETTHSI           1.50       0.95
#
#     daily_volume  beta
# 0         140.03  1.00
# 1          59.77  0.81
# 2          52.47  1.29
# 3         157.15  0.95
# 4         480.52  0.43
# 5          28.02  0.83
# 6          10.15  0.87
# 7         173.92  1.03
# 8           9.31  0.96
# 9        1112.71  1.41
# 10          4.79  0.59
# 11         82.83  0.78
# 12        154.65  1.17
# 13         33.27  1.75
# 14         14.45  0.66
# 15        376.23  1.05
# 16        817.89  1.22
# 17        708.25  1.40

# %%
mst.dtypes
# Out:
# name             object
# market           object
# max_price       float64
# min_price       float64
# daily_volume    float64
# beta            float64
# dtype: object

# %%
rcds = mst.values.tolist()
len(rcds)
# Out:
# 18

# %%
for rcd in rcds:
    print(rcd)
# Out:
# ['AIT', 'sSET    ', 9.8, 4.12, 140.03, 1.0]
# ['ASK', 'SET    ', 49.5, 20.06, 59.77, 0.81]
# ['BAY', 'SET    ', 39.25, 27.25, 52.47, 1.29]
# ['BCPG', 'SET100 / SETCLMV / SETHD / SETTHSI    ', 15.4, 11.1, 157.15, 0.95]
# ['BH', 'SET50 / SETCLMV / SETWB    ', 175.0, 116.5, 480.52, 0.43]
# ['BPP', 'SET100 / SETCLMV / SETHD / SETTHSI    ', 20.3, 15.3, 28.02, 0.83]
# ['COTTO', 'SET    ', 3.18, 1.55, 10.15, 0.87]
# ['ESSO', 'SET100    ', 8.9, 7.0, 173.92, 1.03]
# ['GGC', 'sSET    ', 14.4, 9.6, 9.31, 0.96]
# ['IVL', 'SET50 / SETTHSI    ', 52.0, 36.0, 1112.71, 1.41]
# ['MST', 'SET    ', 14.7, 9.3, 4.79, 0.59]
# ['PTL', 'SET    ', 31.75, 22.3, 82.83, 0.78]
# ['RBF', 'SET100 / SETCLMV / SETWB    ', 24.5, 14.7, 154.65, 1.17]
# ['SIS', 'sSET    ', 48.75, 25.75, 33.27, 1.75]
# ['SMPC', 'sSET    ', 14.2, 10.0, 14.45, 0.66]
# ['SPRC', 'SET100 / SETCLMV    ', 11.5, 7.75, 376.23, 1.05]
# ['TOP', 'SET50 / SETCLMV / SETTHSI    ', 61.5, 42.5, 817.89, 1.22]
# ['TTB', 'SET50 / SETHD / SETTHSI    ', 1.5, 0.95, 708.25, 1.4]

# %%
for rcd in rcds:
    conmy.execute("""INSERT INTO stocks (id, name, max_price, min_price, \
status, buy_target, sell_target, volume, beta, cost, qty, buy_spread, sell_spread, available_qty, bl, sh, \
reason, market) \
VALUES( ?, ?, ?, ?, ?, ?, ?, ?, ?,?, ?, ?, ?, ?, ?, ?, ?, ?)""", rcd)

# %% [markdown]
# ### End of Process insert profit records to stocks

# %%
sql = '''
SELECT *
FROM dividend
'''
dividend = pd.read_sql(sql, const)
dividend.drop(['PRICE', 'PERCENT'], axis=1, inplace=True)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend.dtypes
# Out:
# name                object
# q4                 float64
# q3                 float64
# q2                 float64
# q1                 float64
# dividend           float64
# shares               int64
# xdate       datetime64[ns]
# paiddate    datetime64[ns]
# kind                object
# actual               int64
# dtype: object

# %%
dividend.sort_values(['xdate'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_881fa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >q4</th>
#       <th class="col_heading level0 col2" >q3</th>
#       <th class="col_heading level0 col3" >q2</th>
#       <th class="col_heading level0 col4" >q1</th>
#       <th class="col_heading level0 col5" >dividend</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >xdate</th>
#       <th class="col_heading level0 col8" >paiddate</th>
#       <th class="col_heading level0 col9" >kind</th>
#       <th class="col_heading level0 col10" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_881fa_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_881fa_row0_col0" class="data row0 col0" >HTC</td>
#       <td id="T_881fa_row0_col1" class="data row0 col1" >1.1200</td>
#       <td id="T_881fa_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_881fa_row0_col3" class="data row0 col3" >0.8300</td>
#       <td id="T_881fa_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_881fa_row0_col5" class="data row0 col5" >1.9500</td>
#       <td id="T_881fa_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_881fa_row0_col7" class="data row0 col7" >2021-09-23</td>
#       <td id="T_881fa_row0_col8" class="data row0 col8" >2021-09-23</td>
#       <td id="T_881fa_row0_col9" class="data row0 col9" ></td>
#       <td id="T_881fa_row0_col10" class="data row0 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_881fa_level0_row1" class="row_heading level0 row1" >65</th>
#       <td id="T_881fa_row1_col0" class="data row1 col0" >LPF</td>
#       <td id="T_881fa_row1_col1" class="data row1 col1" >0.1719</td>
#       <td id="T_881fa_row1_col2" class="data row1 col2" >0.1894</td>
#       <td id="T_881fa_row1_col3" class="data row1 col3" >0.1793</td>
#       <td id="T_881fa_row1_col4" class="data row1 col4" >0.1878</td>
#       <td id="T_881fa_row1_col5" class="data row1 col5" >0.7284</td>
#       <td id="T_881fa_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_881fa_row1_col7" class="data row1 col7" >2022-01-28</td>
#       <td id="T_881fa_row1_col8" class="data row1 col8" >2022-02-15</td>
#       <td id="T_881fa_row1_col9" class="data row1 col9" ></td>
#       <td id="T_881fa_row1_col10" class="data row1 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_881fa_level0_row2" class="row_heading level0 row2" >31</th>
#       <td id="T_881fa_row2_col0" class="data row2 col0" >GLOBAL</td>
#       <td id="T_881fa_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_881fa_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_881fa_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_881fa_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_881fa_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_881fa_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_881fa_row2_col7" class="data row2 col7" >2022-02-02</td>
#       <td id="T_881fa_row2_col8" class="data row2 col8" >2022-02-02</td>
#       <td id="T_881fa_row2_col9" class="data row2 col9" ></td>
#       <td id="T_881fa_row2_col10" class="data row2 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_881fa_level0_row3" class="row_heading level0 row3" >68</th>
#       <td id="T_881fa_row3_col0" class="data row3 col0" >IP</td>
#       <td id="T_881fa_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_881fa_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_881fa_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_881fa_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_881fa_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_881fa_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_881fa_row3_col7" class="data row3 col7" >2022-02-02</td>
#       <td id="T_881fa_row3_col8" class="data row3 col8" >2022-02-02</td>
#       <td id="T_881fa_row3_col9" class="data row3 col9" ></td>
#       <td id="T_881fa_row3_col10" class="data row3 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_881fa_level0_row4" class="row_heading level0 row4" >74</th>
#       <td id="T_881fa_row4_col0" class="data row4 col0" >DOHOME</td>
#       <td id="T_881fa_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_881fa_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_881fa_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_881fa_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_881fa_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_881fa_row4_col6" class="data row4 col6" >7,200</td>
#       <td id="T_881fa_row4_col7" class="data row4 col7" >2022-02-02</td>
#       <td id="T_881fa_row4_col8" class="data row4 col8" >2022-02-02</td>
#       <td id="T_881fa_row4_col9" class="data row4 col9" ></td>
#       <td id="T_881fa_row4_col10" class="data row4 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_881fa_level0_row5" class="row_heading level0 row5" >77</th>
#       <td id="T_881fa_row5_col0" class="data row5 col0" >STARK</td>
#       <td id="T_881fa_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_881fa_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_881fa_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_881fa_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_881fa_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_881fa_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_881fa_row5_col7" class="data row5 col7" >2022-02-02</td>
#       <td id="T_881fa_row5_col8" class="data row5 col8" >2022-02-02</td>
#       <td id="T_881fa_row5_col9" class="data row5 col9" ></td>
#       <td id="T_881fa_row5_col10" class="data row5 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_881fa_level0_row6" class="row_heading level0 row6" >78</th>
#       <td id="T_881fa_row6_col0" class="data row6 col0" >PTTEP</td>
#       <td id="T_881fa_row6_col1" class="data row6 col1" >3.0000</td>
#       <td id="T_881fa_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_881fa_row6_col3" class="data row6 col3" >2.0000</td>
#       <td id="T_881fa_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_881fa_row6_col5" class="data row6 col5" >5.0000</td>
#       <td id="T_881fa_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_881fa_row6_col7" class="data row6 col7" >2022-02-10</td>
#       <td id="T_881fa_row6_col8" class="data row6 col8" >2022-04-18</td>
#       <td id="T_881fa_row6_col9" class="data row6 col9" ></td>
#       <td id="T_881fa_row6_col10" class="data row6 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_881fa_level0_row7" class="row_heading level0 row7" >75</th>
#       <td id="T_881fa_row7_col0" class="data row7 col0" >SCB</td>
#       <td id="T_881fa_row7_col1" class="data row7 col1" >2.6300</td>
#       <td id="T_881fa_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_881fa_row7_col3" class="data row7 col3" >1.4300</td>
#       <td id="T_881fa_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_881fa_row7_col5" class="data row7 col5" >4.0600</td>
#       <td id="T_881fa_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_881fa_row7_col7" class="data row7 col7" >2022-02-14</td>
#       <td id="T_881fa_row7_col8" class="data row7 col8" >2022-04-22</td>
#       <td id="T_881fa_row7_col9" class="data row7 col9" ></td>
#       <td id="T_881fa_row7_col10" class="data row7 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_881fa_level0_row8" class="row_heading level0 row8" >40</th>
#       <td id="T_881fa_row8_col0" class="data row8 col0" >ADVANC</td>
#       <td id="T_881fa_row8_col1" class="data row8 col1" >4.2400</td>
#       <td id="T_881fa_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_881fa_row8_col3" class="data row8 col3" >3.4500</td>
#       <td id="T_881fa_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_881fa_row8_col5" class="data row8 col5" >7.6

# %%
df_merge = pd.merge(stocks, dividend, on='name', how='outer', indicator=True)
left_mask= df_merge._merge == 'left_only'
df_merge[left_mask]
#no_dividend.sort_values(['xdate'],ascending=[True])
# Out:
# Empty DataFrame
# Columns: [name, buy_target, market, status, q4, q3, q2, q1, dividend, shares, xdate, paiddate, kind, actual, _merge]
# Index: []

# %% [markdown]
# ### End of Process

# %% [markdown]
# ### Consensus table

# %%
sql = '''
SELECT * FROM consensus ORDER BY name'''
css = pd.read_sql(sql, conlite)
css

# %%
sql = '''
SELECT *
FROM profits
ORDER BY name'''
df_prf = pd.read_sql(sql, conmy)
df_prf.shape

# %%
df_merge = pd.merge(df_prf,df_stk,on='name',how='outer',indicator=True)
df_merge.shape

# %%
left_mask= df_merge._merge == 'left_only'
df_merge[left_mask]

# %%
right_mask= df_merge._merge == 'right_only'
df_merge[right_mask]

# %%
both_mask= df_merge._merge == 'both'
df_merge[both_mask]

# %%
sql = '''
SELECT * FROM SALES ORDER BY name'''
sales = pd.read_sql(sql, conlite)
sales.shape[0]

# %%
sql = '''
DELETE FROM sales
WHERE name = "TCAP"'''
rp = conlite.execute(sql)
rp.rowcount
