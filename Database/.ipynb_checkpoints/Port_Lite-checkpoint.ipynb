# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

format_dict = {
    'qty':'{:,}','price':'{:.2f}','amount':'{:,.2f}'
}
cols = 'trade name qty price active'.split()

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2022, 2, 26), datetime.date(2022, 2, 25))

# %%
#yesterday = date(2021, 5, 14)
yesterday
# Out:
# datetime.date(2022, 2, 25)

# %% [markdown]
# ### Consensus table

# %%
sql = '''
SELECT * FROM consensus ORDER BY name'''
css = pd.read_sql(sql, conlite)
css
# Out:
#        id   name  price  buy  hold  sell  eps_a  eps_b    pe  pbv  yield  \
# 0    2415    AAV   2.64    3     2     1  -0.48   0.04  -5.5  1.1    0.0
# 1    2722    ABM   1.37    1     0     0   0.13   0.16  10.5  1.2    3.6
# 2    2754  ABPIF   2.56    0     0     1   0.25  -1.19  10.2  1.1    9.8
# 3    2775    ACE   3.64    2     0     0   0.21   0.32  17.3  2.7    1.4
# 4    2680    ADB   0.76    0     0     0   0.01   0.02  76.0  0.8    1.3
# ..    ...    ...    ...  ...   ...   ...    ...    ...   ...  ...    ...
# 407  2753     WP   5.10    0     0     1   0.39   0.49  13.1  1.9    3.5
# 408  2674    WPH   3.26    0     0     0   0.07   0.11  46.6  1.8    0.9
# 409  2648     XO  12.90    1     0     0   0.76   0.79  17.0  4.6    3.0
# 410  2750    ZEN  11.60    3     1     0   0.31   0.49  37.4  2.8    1.7
# 411  2649   ZIGA   6.00    1     0     0   0.33   0.32  18.2  0.0    3.8
#
#      consensus_price status  stock_id
# 0               2.73      Z       NaN
# 1               2.51      Z       NaN
# 2               2.04      Z       NaN
# 3               5.10      Z       NaN
# 4               0.00      Z       NaN
# ..               ...    ...       ...
# 407             4.70      Z       NaN
# 408             0.00      Z       NaN
# 409            15.30      Z       NaN
# 410            14.10      Z       NaN
# 411             7.15      Z       NaN
#
# [412 rows x 14 columns]

# %% [markdown]
# ### Matching check with profits in portmy database

# %%
sql = '''
SELECT *
FROM stocks
WHERE qty = 0
ORDER BY name'''
df_stk = pd.read_sql(sql, conlite)
df_stk
# Out:
#      id    name  max_price  min_price status  buy_target  sell_target  volume  \
# 0   705   ASIAN        0.0       0.00      O       15.20            0    0.00
# 1   706     BAM        0.0       0.00      O       20.50            0    0.00
# 2   707    BDMS        0.0       0.00      O       23.20            0    0.00
# 3   708     CHG        0.0       0.00      O        3.36            0    0.00
# 4   709  GLOBAL        0.0       0.00      O       19.40            0    0.00
# 5   526   HREIT        9.3       7.35      T        0.00            0    4.80
# 6   710     IMH        0.0       0.00      O       21.00            0    0.00
# 7   711    SENA        0.0       0.00      O        4.90            0    0.00
# 8   703    SMPC       14.2      10.00      X        0.00            0   17.27
# 9   712   TPIPL        0.0       0.00      O        1.70            0    0.00
# 10  713      TU        0.0       0.00      O       19.80            0    0.00
# 11  714   VIBHA        0.0       0.00      O        2.22            0    0.00
#
#     beta  cost  qty  buy_spread  sell_spread  available_qty  bl  sh reason  \
# 0   0.00  0.00    0          -4            4              0   0   0
# 1   0.00  0.00    0          -4            4              0   0   0
# 2   0.00  0.00    0          -4            4              0   0   0
# 3   0.00  0.00    0          -4            4              0   0   0
# 4   0.00  0.00    0          -4            4              0   0   0
# 5   0.33  8.95    0          -5            5          30000   0  12  RD03%
# 6   0.00  0.00    0          -4            4              0   0   0
# 7   0.00  0.00    0          -4            4              0   0   0
# 8   0.58  0.00    0          -4            4              0   0   0
# 9   0.00  0.00    0          -4            4              0   0   0
# 10  0.00  0.00    0          -4            4              0   0   0
# 11  0.00  0.00    0          -4            4              0   0   0
#
#     market
# 0      SET
# 1   SET100
# 2    SET50
# 3   SET100
# 4    SET50
# 5      SET
# 6      mai
# 7      SET
# 8      SET
# 9      SET
# 10   SET50
# 11     SET

# %%
sql = '''
SELECT *
FROM profits
ORDER BY name'''
df_prf = pd.read_sql(sql, conmy)
df_prf.shape
# Out:
# (60, 23)

# %%
df_merge = pd.merge(df_prf,df_stk,on='name',how='outer',indicator=True)
df_merge.shape
# Out:
# (73, 41)

# %%
left_mask= df_merge._merge == 'left_only'
df_merge[left_mask]
# Out:
#       id_x  name    year  quarter  kind  latest_amt_y  previous_amt_y  \
# 0   2016.0    AP  2021.0      1.0   1.0     5010831.0       2607844.0
# 12  2031.0   DRT  2021.0      1.0   1.0      585184.0        527811.0
# 51  2030.0  TCCC  2021.0      1.0   1.0     1702328.0        943810.0
#
#     inc_amt_y  inc_pct_y  latest_amt_q  ...  volume  beta  cost  qty  \
# 0   2402987.0      92.14     5010831.0  ...     NaN   NaN   NaN  NaN
# 12    57373.0      10.87      585184.0  ...     NaN   NaN   NaN  NaN
# 51   758518.0      80.37     1702328.0  ...     NaN   NaN   NaN  NaN
#
#     buy_spread  sell_spread  available_qty  bl  sh     _merge
# 0          NaN          NaN            NaN NaN NaN  left_only
# 12         NaN          NaN            NaN NaN NaN  left_only
# 51         NaN          NaN            NaN NaN NaN  left_only
#
# [3 rows x 41 columns]

# %%
right_mask= df_merge._merge == 'right_only'
df_merge[right_mask]
# Out:
#     id_x      name  year  quarter  kind  latest_amt_y  previous_amt_y  \
# 60   NaN    ADVANC   NaN      NaN   NaN           NaN             NaN
# 61   NaN     AMATA   NaN      NaN   NaN           NaN             NaN
# 62   NaN     CPNCG   NaN      NaN   NaN           NaN             NaN
# 63   NaN       DIF   NaN      NaN   NaN           NaN             NaN
# 64   NaN    GVREIT   NaN      NaN   NaN           NaN             NaN
# 65   NaN     JASIF   NaN      NaN   NaN           NaN             NaN
# 66   NaN        LH   NaN      NaN   NaN           NaN             NaN
# 67   NaN        MC   NaN      NaN   NaN           NaN             NaN
# 68   NaN     NOBLE   NaN      NaN   NaN           NaN             NaN
# 69   NaN      POPF   NaN      NaN   NaN           NaN             NaN
# 70   NaN  SUPEREIF   NaN      NaN   NaN           NaN             NaN
# 71   NaN      TCAP   NaN      NaN   NaN           NaN             NaN
# 72   NaN     TTLPF   NaN      NaN   NaN           NaN             NaN
#
#     inc_amt_y  inc_pct_y  latest_amt_q  ...   volume  beta    cost      qty  \
# 60        NaN        NaN           NaN  ...  1189.41  0.64  190.00    300.0
# 61        NaN        NaN           NaN  ...   276.45  1.46   24.00   3000.0
# 62        NaN        NaN           NaN  ...     3.60  0.39   10.70  10000.0
# 63        NaN        NaN           NaN  ...   195.96  0.24   14.70  10000.0
# 64        NaN        NaN           NaN  ...     3.52  0.22   10.50  10000.0
# 65        NaN        NaN           NaN  ...   112.30  0.21   10.10   3500.0
# 66        NaN        NaN           NaN  ...   459.36  1.09   11.15   6000.0
# 67        NaN        NaN           NaN  ...    30.75  0.58    0.00      0.0
# 68        NaN        NaN           NaN  ...   106.66  0.54    8.60   6000.0
# 69        NaN        NaN           NaN  ...     1.59  0.25   10.90  10000.0
# 70        NaN        NaN           NaN  ...     6.97  0.31   10.90  10000.0
# 71        NaN        NaN           NaN  ...   286.66  1.06   35.90   5000.0
# 72        NaN        NaN           NaN  ...     0.09 -0.11   21.70   1000.0
#
#     buy_spread  sell_spread  available_qty   bl    sh      _merge
# 60       -13.0         12.0          600.0  0.0   0.0  right_only
# 61       -13.0         14.0        12000.0  0.0  12.0  right_only
# 62        -4.0          4.0        10000.0  0.0   0.0  right_only
# 63        -5.0          5.0       100000.0  0.0   0.0  right_only
# 64        -9.0          5.0        10000.0  0.0   0.0  right_only
# 65        -5.0          4.0       100000.0  0.0   0.0  right_only
# 66        -6.0          5.0        42000.0  0.0  12.0  right_only
# 67        -4.0          4.0            0.0  0.0   0.0  right_only
# 68       -15.0         16.0        18000.0  0.0   0.0  right_only
# 69        -4.0          4.0        10000.0  0.0   0.0  right_only
# 70        -4.0          4.0        10000.0  0.0   0.0  right_only
# 71       -12.0         12.0         5000.0  3.0   0.0  right_only
# 72        -8.0          7.0         8800.0  0.0   0.0  right_only
#
# [13 rows x 41 columns]

# %%
both_mask= df_merge._merge == 'both'
df_merge[both_mask]
# Out:
#       id_x    name    year  quarter  kind  latest_amt_y  previous_amt_y  \
# 1   1984.0   ASIAN  2021.0      1.0   1.0      928093.0        177942.0
# 2   1935.0     ASK  2021.0      1.0   1.0      958779.0        874555.0
# 3   2007.0     BCH  2021.0      1.0   1.0     1294039.0       1145941.0
# 4   2020.0     BGC  2021.0      1.0   1.0      537823.0        510234.0
# 5   2011.0     BKI  2021.0      1.0   1.0     2852925.0       2538062.0
# 6   2013.0     CHG  2021.0      1.0   0.0      941917.0        712417.0
# 7   1949.0    COM7  2021.0      1.0   1.0     1768408.0       1254088.0
# 28    667439.0     134.07     1165281.0  ...   479.30  0.12    0.00      0.0
# 29     -9819.0      -0.34     2891841.0  ...   173.27  1.04    9.35   5000.0
# 30    201644.0      80.56      451932.0  ...     6.15  0.50    0.00  10000.0
# 31    598378.0      56.00     1666901.0  ...   248.35  0.78    8.65   3000.0
# 32    977874.0      78.59     2222132.0  ...   642.07  0.77   16.30   5000.0
# 33   9823610.0      15.82    71907779.0  ...  2924.73  1.25    0.00   2400.0
# 34 -19350648.0     -43.06    25585211.0  ...  1438.11  1.26  116.00   1000.0
# 35  22223279.0     626.95    18678590.0  ...  1262.92  1.46   68.00   1000.0
# 36   1430876.0      25.63     7013715.0  ...   283.88  0.68   52.00   3000.0
# 37    170104.0      63.89      436349.0  ...    16.14  0.43    0.00   3000.0
# 38   1864772.0     301.43     2483424.0  ...    63.14  0.72    6.35   5000.0
# 39    890073.0      22.55     4836398.0  ...  1366.93  1.15    0.00      0.0
# 40  14763531.0      54.03    42086625.0  ...  1347.36  0.71  460.00    100.0
# 41   1040185.0      36.14     3918109.0  ...    61.52  0.68  170.00    600.0
# 42    157893.0      16.44     1118457.0  ...    11.01  0.91    4.02  10000.0
# 43   1633608.0     128.12     2908691.0  ...   103.07  0.79   12.30   6000.0
# 44    283785.0     133.40      496524.0  ...   221.56  0.52    0.00   2000.0
# 45    198430.0      43.17      658058.0  ...   112.41  0.91   17.40   6000.0
# 46    150370.0      34.44      586969.0  ...    15.24  0.39   11.40   4000.0
# 47  13302281.0     997.70    14635570.0  ...  1774.95 -0.34   30.00   3000.0
# 48    305125.0      38.03     1107419.0  ...     1.51  0.18    0.00      0.0
# 49    223942.0      47.50      695419.0  ...   216.87  0.81    0.00   4000.0
# 50   3175875.0     195.81     4797759.0  ...   586.02  0.78    0.00      0.0
# 52    304775.0      16.29     2175605.0  ...    36.58  0.37   30.00   3000.0
# 53   -679599.0      -9.67     6345021.0  ...   705.05  0.81   97.50   1000.0
# 54    329524.0      16.90     2279866.0  ...   102.11  0.74   35.00   9000.0
# 55    991846.0      78.26     2259219.0  ...    76.39  0.59    0.00      0.0
# 56      8432.0       0.18     4599705.0  ...    66.40  0.57    4.19  10000.0
# 57    144314.0      24.88      724313.0  ...   188.96  0.27  112.00    600.0
# 58   3474055.0      97.62     7032761.0  ...   440.94  0.57   13.60   4000.0
# 59    497862.0      32.19     2044482.0  ...   171.17  0.25   33.00   2000.0
#
#     buy_spread  sell_spread  available_qty   bl    sh  _merge
# 1        -11.0         15.0        25000.0  0.0  12.0    both
# 2         -4.0          4.0            0.0  0.0   0.0    both
# 3         -4.0          4.0            0.0  1.0   0.0    both
# 4        -12.0         14.0        20000.0  0.0  12.0    both
# 5         -4.0          4.0          300.0  0.0   0.0    both
# 6         -7.0          8.0            0.0  0.0   0.0    both
# 7        -12.0         16.0            0.0  0.0   0.0    both
# 8         -9.0          9.0        10000.0  0.0  12.0    both
# 9         -7.0          8.0        40000.0  0.0  12.0    both
# 10        -4.0          4.0            0.0  0.0   0.0    both
# 11        -4.0          4.0            0.0  0.0   0.0    both
# 13       -17.0         16.0          900.0  0.0   0.0    both
# 14        -4.0          5.0         3000.0  0.0  12.0    both
# 15       -11.0         11.0            0.0  0.0   0.0    both
# 16       -11.0         13.0            0.0  6.0   0.0    both
# 17        -8.0          9.0        40000.0  0.0  12.0    both
# 18        -4.0          4.0            0.0  0.0   0.0    both
# 19        -5.0          5.0        30000.0  0.0   6.0    both
# 20       -16.0         16.0        10000.0  0.0  12.0    both
# 21        -4.0          4.0            0.0  0.0   0.0    both
# 22        -9.0         14.0            0.0  0.0   0.0    both
# 23        -4.0          4.0            0.0  0.0   0.0    both
# 24        -4.0          4.0            0.0  0.0   0.0    both
# 25        -7.0          9.0        80000.0  6.0  12.0    both
# 26       -11.0         13.0            0.0  1.0   0.0    both
# 27       -17.0         16.0         3000.0  3.0   0.0    both
# 28       -13.0         14.0            0.0  0.0   0.0    both
# 29       -16.0         18.0        55000.0  0.0  12.0    both
# 30        -4.0          4.0            0.0  0.0   0.0    both
# 31       -15.0         21.0        33000.0  3.0  12.0    both
# 32       -16.0         16.0            0.0  1.0   0.0    both
# 33        -4.0          4.0            0.0  6.0   0.0    both
# 34        -4.0          4.0         1000.0  0.0   0.0    both
# 35       -14.0         11.0         7000.0  3.0  12.0    both
# 36       -17.0         21.0         3000.0  0.0   3.0    both
# 37        -4.0          4.0            0.0  3.0   0.0    both
# 38        -7.0          6.0        15000.0  0.0  24.0    both
# 39        -4.0          4.0            0.0  0.0   0.0    both
# 40       -17.0         16.0          200.0  0.0  12.0    both
# 41       -16.0         16.0          600.0  0.0  12.0    both
# 42       -11.0         11.0        60000.0  0.0  24.0    both
# 43        -4.0          4.0         9000.0  0.0   0.0    both
# 44        -4.0          4.0            0.0  0.0   0.0    both
# 45       -11.0         18.0            0.0  0.0   0.0    both
# 46        -9.0         12.0        24000.0  6.0   3.0    both
# 47       -10.0         15.0            0.0  3.0   0.0    both
# 48        -4.0          4.0            0.0  0.0   0.0    both
# 49       -10.0         15.0            0.0  1.0   0.0    both
# 50        -4.0          4.0            0.0  0.0   0.0    both
# 52        -7.0          9.0            0.0  0.0  12.0    both
# 53       -15.0         19.0         2000.0  1.0  12.0    both
# 54        -4.0          4.0            0.0  0.0   0.0    both
# 55        -5.0          7.0            0.0  1.0   0.0    both
# 56       -12.0         11.0        60000.0  0.0  12.0    both
# 57       -28.0         29.0          900.0  6.0   1.0    both
# 58        -9.0          8.0        14000.0  0.0  15.0    both
# 59        -7.0          9.0         6000.0  0.0   0.0    both
#
# [57 rows x 41 columns]

# %%
sql = '''
SELECT * FROM SALES ORDER BY name'''
sales = pd.read_sql(sql, conlite)
sales.shape[0]
# Out:
# 4120

# %%
sql = '''
DELETE FROM sales
WHERE name = "TCAP"'''
rp = conlite.execute(sql)
rp.rowcount
# Out:
# 93
