# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 5, 31)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_08e47_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08e47_level0_row0" class="row_heading level0 row0" >220</th>
#       <td id="T_08e47_row0_col0" class="data row0 col0" >TYCN</td>
#       <td id="T_08e47_row0_col1" class="data row0 col1" >3.86</td>
#       <td id="T_08e47_row0_col2" class="data row0 col2" >35</td>
#       <td id="T_08e47_row0_col3" class="data row0 col3" >0.46</td>
#       <td id="T_08e47_row0_col4" class="data row0 col4" >13.53</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row1" class="row_heading level0 row1" >194</th>
#       <td id="T_08e47_row1_col0" class="data row1 col0" >THG</td>
#       <td id="T_08e47_row1_col1" class="data row1 col1" >75.00</td>
#       <td id="T_08e47_row1_col2" class="data row1 col2" >1,457</td>
#       <td id="T_08e47_row1_col3" class="data row1 col3" >7.00</td>
#       <td id="T_08e47_row1_col4" class="data row1 col4" >10.29</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row2" class="row_heading level0 row2" >143</th>
#       <td id="T_08e47_row2_col0" class="data row2 col0" >PSL</td>
#       <td id="T_08e47_row2_col1" class="data row2 col1" >19.80</td>
#       <td id="T_08e47_row2_col2" class="data row2 col2" >529</td>
#       <td id="T_08e47_row2_col3" class="data row2 col3" >1.20</td>
#       <td id="T_08e47_row2_col4" class="data row2 col4" >6.45</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row3" class="row_heading level0 row3" >141</th>
#       <td id="T_08e47_row3_col0" class="data row3 col0" >PRM</td>
#       <td id="T_08e47_row3_col1" class="data row3 col1" >6.15</td>
#       <td id="T_08e47_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_08e47_row3_col3" class="data row3 col3" >0.35</td>
#       <td id="T_08e47_row3_col4" class="data row3 col4" >6.03</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row4" class="row_heading level0 row4" >57</th>
#       <td id="T_08e47_row4_col0" class="data row4 col0" >DCON</td>
#       <td id="T_08e47_row4_col1" class="data row4 col1" >0.46</td>
#       <td id="T_08e47_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_08e47_row4_col3" class="data row4 col3" >0.02</td>
#       <td id="T_08e47_row4_col4" class="data row4 col4" >4.55</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row5" class="row_heading level0 row5" >213</th>
#       <td id="T_08e47_row5_col0" class="data row5 col0" >TTA</td>
#       <td id="T_08e47_row5_col1" class="data row5 col1" >10.10</td>
#       <td id="T_08e47_row5_col2" class="data row5 col2" >327</td>
#       <td id="T_08e47_row5_col3" class="data row5 col3" >0.40</td>
#       <td id="T_08e47_row5_col4" class="data row5 col4" >4.12</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row6" class="row_heading level0 row6" >69</th>
#       <td id="T_08e47_row6_col0" class="data row6 col0" >ESSO</td>
#       <td id="T_08e47_row6_col1" class="data row6 col1" >10.30</td>
#       <td id="T_08e47_row6_col2" class="data row6 col2" >314</td>
#       <td id="T_08e47_row6_col3" class="data row6 col3" >0.40</td>
#       <td id="T_08e47_row6_col4" class="data row6 col4" >4.04</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row7" class="row_heading level0 row7" >152</th>
#       <td id="T_08e47_row7_col0" class="data row7 col0" >RCL</td>
#       <td id="T_08e47_row7_col1" class="data row7 col1" >46.25</td>
#       <td id="T_08e47_row7_col2" class="data row7 col2" >331</td>
#       <td id="T_08e47_row7_col3" class="data row7 col3" >1.75</td>
#       <td id="T_08e47_row7_col4" class="data row7 col4" >3.93</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row8" class="row_heading level0 row8" >222</th>
#       <td id="T_08e47_row8_col0" class="data row8 col0" >VGI</td>
#       <td id="T_08e47_row8_col1" class="data row8 col1" >5.35</td>
#       <td id="T_08e47_row8_col2" class="data row8 col2" >299</td>
#       <td id="T_08e47_row8_col3" class="data row8 col3" >0.20</td>
#       <td id="T_08e47_row8_col4" class="data row8 col4" >3.88</td>
#     </tr>
#     <tr>
#       <th id="T_08e47_level0_row9" class="row_heading level0 row9" >77</th>
#       <td id="T_08e47_row9_col0" class="data row9 col0" >GRAMMY</td>
#       <td id="T_08e47_row9_col1" class="data row9 col1" >11.10</td>
#       <td id="T_08e47_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_08e47_row9_col3" class="data row9 col3" >0.40</td>
#       <td id="T_08e47_row9_col4" class="data row9 col4" >3.74</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_08502_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08502_level0_row0" class="row_heading level0 row0" >64</th>
#       <td id="T_08502_row0_col0" class="data row0 col0" >EASTW</td>
#       <td id="T_08502_row0_col1" class="data row0 col1" >6.30</td>
#       <td id="T_08502_row0_col2" class="data row0 col2" >91</td>
#       <td id="T_08502_row0_col3" class="data row0 col3" >-0.25</td>
#       <td id="T_08502_row0_col4" class="data row0 col4" >-3.82</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row1" class="row_heading level0 row1" >85</th>
#       <td id="T_08502_row1_col0" class="data row1 col0" >HTC</td>
#       <td id="T_08502_row1_col1" class="data row1 col1" >30.25</td>
#       <td id="T_08502_row1_col2" class="data row1 col2" >30</td>
#       <td id="T_08502_row1_col3" class="data row1 col3" >-1.00</td>
#       <td id="T_08502_row1_col4" class="data row1 col4" >-3.20</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row2" class="row_heading level0 row2" >98</th>
#       <td id="T_08502_row2_col0" class="data row2 col0" >JMT</td>
#       <td id="T_08502_row2_col1" class="data row2 col1" >77.50</td>
#       <td id="T_08502_row2_col2" class="data row2 col2" >4,694</td>
#       <td id="T_08502_row2_col3" class="data row2 col3" >-2.50</td>
#       <td id="T_08502_row2_col4" class="data row2 col4" >-3.12</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row3" class="row_heading level0 row3" >31</th>
#       <td id="T_08502_row3_col0" class="data row3 col0" >BFIT</td>
#       <td id="T_08502_row3_col1" class="data row3 col1" >31.50</td>
#       <td id="T_08502_row3_col2" class="data row3 col2" >29</td>
#       <td id="T_08502_row3_col3" class="data row3 col3" >-1.00</td>
#       <td id="T_08502_row3_col4" class="data row3 col4" >-3.08</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row4" class="row_heading level0 row4" >169</th>
#       <td id="T_08502_row4_col0" class="data row4 col0" >SIS</td>
#       <td id="T_08502_row4_col1" class="data row4 col1" >29.50</td>
#       <td id="T_08502_row4_col2" class="data row4 col2" >51</td>
#       <td id="T_08502_row4_col3" class="data row4 col3" >-0.75</td>
#       <td id="T_08502_row4_col4" class="data row4 col4" >-2.48</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row5" class="row_heading level0 row5" >229</th>
#       <td id="T_08502_row5_col0" class="data row5 col0" >WORK</td>
#       <td id="T_08502_row5_col1" class="data row5 col1" >23.80</td>
#       <td id="T_08502_row5_col2" class="data row5 col2" >38</td>
#       <td id="T_08502_row5_col3" class="data row5 col3" >-0.60</td>
#       <td id="T_08502_row5_col4" class="data row5 col4" >-2.46</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row6" class="row_heading level0 row6" >91</th>
#       <td id="T_08502_row6_col0" class="data row6 col0" >INOX</td>
#       <td id="T_08502_row6_col1" class="data row6 col1" >1.27</td>
#       <td id="T_08502_row6_col2" class="data row6 col2" >38</td>
#       <td id="T_08502_row6_col3" class="data row6 col3" >-0.03</td>
#       <td id="T_08502_row6_col4" class="data row6 col4" >-2.31</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row7" class="row_heading level0 row7" >14</th>
#       <td id="T_08502_row7_col0" class="data row7 col0" >ASK</td>
#       <td id="T_08502_row7_col1" class="data row7 col1" >42.25</td>
#       <td id="T_08502_row7_col2" class="data row7 col2" >176</td>
#       <td id="T_08502_row7_col3" class="data row7 col3" >-1.00</td>
#       <td id="T_08502_row7_col4" class="data row7 col4" >-2.31</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_08502_row8_col0" class="data row8 col0" >AIT</td>
#       <td id="T_08502_row8_col1" class="data row8 col1" >6.95</td>
#       <td id="T_08502_row8_col2" class="data row8 col2" >42</td>
#       <td id="T_08502_row8_col3" class="data row8 col3" >-0.15</td>
#       <td id="T_08502_row8_col4" class="data row8 col4" >-2.11</td>
#     </tr>
#     <tr>
#       <th id="T_08502_level0_row9" class="row_heading level0 row9" >105</th>
#       <td id="T_08502_row9_col0" class="data row9 col0" >KSL</td>
#       <td id="T_08502_row9_col1" class="data row9 col1" >3.86</td>
#       <td id="T_08502_row9_col2" class="data row9 col2" >43</td>
#       <td id="T_08502_row9_col3" class="data row9 col3" >-0.08</td>
#       <td id="T_08502_row9_col4" class="data row9 col4" >-2.03</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_af892_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af892_level0_row0" class="row_heading level0 row0" >98</th>
#       <td id="T_af892_row0_col0" class="data row0 col0" >JMT</td>
#       <td id="T_af892_row0_col1" class="data row0 col1" >77.50</td>
#       <td id="T_af892_row0_col2" class="data row0 col2" >4,694</td>
#       <td id="T_af892_row0_col3" class="data row0 col3" >-2.50</td>
#       <td id="T_af892_row0_col4" class="data row0 col4" >-3.12</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row1" class="row_heading level0 row1" >27</th>
#       <td id="T_af892_row1_col0" class="data row1 col0" >BDMS</td>
#       <td id="T_af892_row1_col1" class="data row1 col1" >25.75</td>
#       <td id="T_af892_row1_col2" class="data row1 col2" >3,421</td>
#       <td id="T_af892_row1_col3" class="data row1 col3" >0.25</td>
#       <td id="T_af892_row1_col4" class="data row1 col4" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_af892_row2_col0" class="data row2 col0" >AOT</td>
#       <td id="T_af892_row2_col1" class="data row2 col1" >69.75</td>
#       <td id="T_af892_row2_col2" class="data row2 col2" >3,391</td>
#       <td id="T_af892_row2_col3" class="data row2 col3" >0.25</td>
#       <td id="T_af892_row2_col4" class="data row2 col4" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_af892_row3_col0" class="data row3 col0" >ADVANC</td>
#       <td id="T_af892_row3_col1" class="data row3 col1" >217.00</td>
#       <td id="T_af892_row3_col2" class="data row3 col2" >3,259</td>
#       <td id="T_af892_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_af892_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row4" class="row_heading level0 row4" >146</th>
#       <td id="T_af892_row4_col0" class="data row4 col0" >PTT</td>
#       <td id="T_af892_row4_col1" class="data row4 col1" >38.25</td>
#       <td id="T_af892_row4_col2" class="data row4 col2" >3,157</td>
#       <td id="T_af892_row4_col3" class="data row4 col3" >0.25</td>
#       <td id="T_af892_row4_col4" class="data row4 col4" >0.66</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row5" class="row_heading level0 row5" >147</th>
#       <td id="T_af892_row5_col0" class="data row5 col0" >PTTEP</td>
#       <td id="T_af892_row5_col1" class="data row5 col1" >169.50</td>
#       <td id="T_af892_row5_col2" class="data row5 col2" >2,848</td>
#       <td id="T_af892_row5_col3" class="data row5 col3" >4.00</td>
#       <td id="T_af892_row5_col4" class="data row5 col4" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row6" class="row_heading level0 row6" >63</th>
#       <td id="T_af892_row6_col0" class="data row6 col0" >EA</td>
#       <td id="T_af892_row6_col1" class="data row6 col1" >89.75</td>
#       <td id="T_af892_row6_col2" class="data row6 col2" >2,116</td>
#       <td id="T_af892_row6_col3" class="data row6 col3" >0.25</td>
#       <td id="T_af892_row6_col4" class="data row6 col4" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row7" class="row_heading level0 row7" >161</th>
#       <td id="T_af892_row7_col0" class="data row7 col0" >SCB</td>
#       <td id="T_af892_row7_col1" class="data row7 col1" >113.00</td>
#       <td id="T_af892_row7_col2" class="data row7 col2" >1,986</td>
#       <td id="T_af892_row7_col3" class="data row7 col3" >0.50</td>
#       <td id="T_af892_row7_col4" class="data row7 col4" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row8" class="row_heading level0 row8" >132</th>
#       <td id="T_af892_row8_col0" class="data row8 col0" >OR</td>
#       <td id="T_af892_row8_col1" class="data row8 col1" >27.75</td>
#       <td id="T_af892_row8_col2" class="data row8 col2" >1,921</td>
#       <td id="T_af892_row8_col3" class="data row8 col3" >0.50</td>
#       <td id="T_af892_row8_col4" class="data row8 col4" >1.83</td>
#     </tr>
#     <tr>
#       <th id="T_af892_level0_row9" class="row_heading level0 row9" >49</th>
#       <td id="T_af892_row9_col0" class="data row9 col0" >CPALL</td>
#       <td id="T_af892_row9_col1" class="data row9 col1" >66.25</td>
#       <td id="T_af892_row9_col2" class="data row9 col2" >1,873</td>
#       <td id="T_af892_row9_col3" class="data row9 col3" >0.50</td>
#       <td id="T_af892_row9_col4" class="data row9 col4" >0.76</td>
#     </tr>
#   </tbody>
# </table>
