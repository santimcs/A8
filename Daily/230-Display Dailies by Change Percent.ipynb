# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 20)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f120a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f120a_level0_row0" class="row_heading level0 row0" >187</th>
#       <td id="T_f120a_row0_col0" class="data row0 col0" >TASCO</td>
#       <td id="T_f120a_row0_col1" class="data row0 col1" >16.90</td>
#       <td id="T_f120a_row0_col2" class="data row0 col2" >266</td>
#       <td id="T_f120a_row0_col3" class="data row0 col3" >1.00</td>
#       <td id="T_f120a_row0_col4" class="data row0 col4" >6.29</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row1" class="row_heading level0 row1" >78</th>
#       <td id="T_f120a_row1_col0" class="data row1 col0" >GUNKUL</td>
#       <td id="T_f120a_row1_col1" class="data row1 col1" >5.55</td>
#       <td id="T_f120a_row1_col2" class="data row1 col2" >413</td>
#       <td id="T_f120a_row1_col3" class="data row1 col3" >0.30</td>
#       <td id="T_f120a_row1_col4" class="data row1 col4" >5.71</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row2" class="row_heading level0 row2" >57</th>
#       <td id="T_f120a_row2_col0" class="data row2 col0" >DELTA</td>
#       <td id="T_f120a_row2_col1" class="data row2 col1" >305.00</td>
#       <td id="T_f120a_row2_col2" class="data row2 col2" >819</td>
#       <td id="T_f120a_row2_col3" class="data row2 col3" >13.00</td>
#       <td id="T_f120a_row2_col4" class="data row2 col4" >4.45</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row3" class="row_heading level0 row3" >216</th>
#       <td id="T_f120a_row3_col0" class="data row3 col0" >TVI</td>
#       <td id="T_f120a_row3_col1" class="data row3 col1" >19.20</td>
#       <td id="T_f120a_row3_col2" class="data row3 col2" >38</td>
#       <td id="T_f120a_row3_col3" class="data row3 col3" >0.80</td>
#       <td id="T_f120a_row3_col4" class="data row3 col4" >4.35</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row4" class="row_heading level0 row4" >69</th>
#       <td id="T_f120a_row4_col0" class="data row4 col0" >FORTH</td>
#       <td id="T_f120a_row4_col1" class="data row4 col1" >44.50</td>
#       <td id="T_f120a_row4_col2" class="data row4 col2" >235</td>
#       <td id="T_f120a_row4_col3" class="data row4 col3" >1.75</td>
#       <td id="T_f120a_row4_col4" class="data row4 col4" >4.09</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row5" class="row_heading level0 row5" >17</th>
#       <td id="T_f120a_row5_col0" class="data row5 col0" >BA</td>
#       <td id="T_f120a_row5_col1" class="data row5 col1" >10.80</td>
#       <td id="T_f120a_row5_col2" class="data row5 col2" >94</td>
#       <td id="T_f120a_row5_col3" class="data row5 col3" >0.40</td>
#       <td id="T_f120a_row5_col4" class="data row5 col4" >3.85</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row6" class="row_heading level0 row6" >32</th>
#       <td id="T_f120a_row6_col0" class="data row6 col0" >BGRIM</td>
#       <td id="T_f120a_row6_col1" class="data row6 col1" >35.50</td>
#       <td id="T_f120a_row6_col2" class="data row6 col2" >945</td>
#       <td id="T_f120a_row6_col3" class="data row6 col3" >1.25</td>
#       <td id="T_f120a_row6_col4" class="data row6 col4" >3.65</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row7" class="row_heading level0 row7" >170</th>
#       <td id="T_f120a_row7_col0" class="data row7 col0" >SMPC</td>
#       <td id="T_f120a_row7_col1" class="data row7 col1" >14.80</td>
#       <td id="T_f120a_row7_col2" class="data row7 col2" >18</td>
#       <td id="T_f120a_row7_col3" class="data row7 col3" >0.50</td>
#       <td id="T_f120a_row7_col4" class="data row7 col4" >3.50</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row8" class="row_heading level0 row8" >70</th>
#       <td id="T_f120a_row8_col0" class="data row8 col0" >FSMART</td>
#       <td id="T_f120a_row8_col1" class="data row8 col1" >19.00</td>
#       <td id="T_f120a_row8_col2" class="data row8 col2" >230</td>
#       <td id="T_f120a_row8_col3" class="data row8 col3" >0.60</td>
#       <td id="T_f120a_row8_col4" class="data row8 col4" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_f120a_level0_row9" class="row_heading level0 row9" >151</th>
#       <td id="T_f120a_row9_col0" class="data row9 col0" >RJH</td>
#       <td id="T_f120a_row9_col1" class="data row9 col1" >33.50</td>
#       <td id="T_f120a_row9_col2" class="data row9 col2" >19</td>
#       <td id="T_f120a_row9_col3" class="data row9 col3" >1.00</td>
#       <td id="T_f120a_row9_col4" class="data row9 col4" >3.08</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3910_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3910_level0_row0" class="row_heading level0 row0" >95</th>
#       <td id="T_a3910_row0_col0" class="data row0 col0" >JMART</td>
#       <td id="T_a3910_row0_col1" class="data row0 col1" >52.50</td>
#       <td id="T_a3910_row0_col2" class="data row0 col2" >628</td>
#       <td id="T_a3910_row0_col3" class="data row0 col3" >-3.00</td>
#       <td id="T_a3910_row0_col4" class="data row0 col4" >-5.41</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row1" class="row_heading level0 row1" >165</th>
#       <td id="T_a3910_row1_col0" class="data row1 col0" >SINGER</td>
#       <td id="T_a3910_row1_col1" class="data row1 col1" >46.50</td>
#       <td id="T_a3910_row1_col2" class="data row1 col2" >183</td>
#       <td id="T_a3910_row1_col3" class="data row1 col3" >-2.25</td>
#       <td id="T_a3910_row1_col4" class="data row1 col4" >-4.62</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_a3910_row2_col0" class="data row2 col0" >TMT</td>
#       <td id="T_a3910_row2_col1" class="data row2 col1" >8.70</td>
#       <td id="T_a3910_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_a3910_row2_col3" class="data row2 col3" >-0.30</td>
#       <td id="T_a3910_row2_col4" class="data row2 col4" >-3.33</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row3" class="row_heading level0 row3" >59</th>
#       <td id="T_a3910_row3_col0" class="data row3 col0" >DOHOME</td>
#       <td id="T_a3910_row3_col1" class="data row3 col1" >16.60</td>
#       <td id="T_a3910_row3_col2" class="data row3 col2" >143</td>
#       <td id="T_a3910_row3_col3" class="data row3 col3" >-0.50</td>
#       <td id="T_a3910_row3_col4" class="data row3 col4" >-2.92</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row4" class="row_heading level0 row4" >159</th>
#       <td id="T_a3910_row4_col0" class="data row4 col0" >SCB</td>
#       <td id="T_a3910_row4_col1" class="data row4 col1" >103.00</td>
#       <td id="T_a3910_row4_col2" class="data row4 col2" >2,654</td>
#       <td id="T_a3910_row4_col3" class="data row4 col3" >-3.00</td>
#       <td id="T_a3910_row4_col4" class="data row4 col4" >-2.83</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row5" class="row_heading level0 row5" >72</th>
#       <td id="T_a3910_row5_col0" class="data row5 col0" >GFPT</td>
#       <td id="T_a3910_row5_col1" class="data row5 col1" >17.60</td>
#       <td id="T_a3910_row5_col2" class="data row5 col2" >49</td>
#       <td id="T_a3910_row5_col3" class="data row5 col3" >-0.50</td>
#       <td id="T_a3910_row5_col4" class="data row5 col4" >-2.76</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row6" class="row_heading level0 row6" >96</th>
#       <td id="T_a3910_row6_col0" class="data row6 col0" >JMT</td>
#       <td id="T_a3910_row6_col1" class="data row6 col1" >71.75</td>
#       <td id="T_a3910_row6_col2" class="data row6 col2" >767</td>
#       <td id="T_a3910_row6_col3" class="data row6 col3" >-2.00</td>
#       <td id="T_a3910_row6_col4" class="data row6 col4" >-2.71</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row7" class="row_heading level0 row7" >180</th>
#       <td id="T_a3910_row7_col0" class="data row7 col0" >STARK</td>
#       <td id="T_a3910_row7_col1" class="data row7 col1" >4.34</td>
#       <td id="T_a3910_row7_col2" class="data row7 col2" >41</td>
#       <td id="T_a3910_row7_col3" class="data row7 col3" >-0.12</td>
#       <td id="T_a3910_row7_col4" class="data row7 col4" >-2.69</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row8" class="row_heading level0 row8" >183</th>
#       <td id="T_a3910_row8_col0" class="data row8 col0" >SUPER</td>
#       <td id="T_a3910_row8_col1" class="data row8 col1" >0.75</td>
#       <td id="T_a3910_row8_col2" class="data row8 col2" >168</td>
#       <td id="T_a3910_row8_col3" class="data row8 col3" >-0.02</td>
#       <td id="T_a3910_row8_col4" class="data row8 col4" >-2.60</td>
#     </tr>
#     <tr>
#       <th id="T_a3910_level0_row9" class="row_heading level0 row9" >224</th>
#       <td id="T_a3910_row9_col0" class="data row9 col0" >WHAIR</td>
#       <td id="T_a3910_row9_col1" class="data row9 col1" >7.55</td>
#       <td id="T_a3910_row9_col2" class="data row9 col2" >13</td>
#       <td id="T_a3910_row9_col3" class="data row9 col3" >-0.20</td>
#       <td id="T_a3910_row9_col4" class="data row9 col4" >-2.58</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d711a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d711a_level0_row0" class="row_heading level0 row0" >145</th>
#       <td id="T_d711a_row0_col0" class="data row0 col0" >PTTEP</td>
#       <td id="T_d711a_row0_col1" class="data row0 col1" >158.50</td>
#       <td id="T_d711a_row0_col2" class="data row0 col2" >2,695</td>
#       <td id="T_d711a_row0_col3" class="data row0 col3" >-4.00</td>
#       <td id="T_d711a_row0_col4" class="data row0 col4" >-2.46</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row1" class="row_heading level0 row1" >159</th>
#       <td id="T_d711a_row1_col0" class="data row1 col0" >SCB</td>
#       <td id="T_d711a_row1_col1" class="data row1 col1" >103.00</td>
#       <td id="T_d711a_row1_col2" class="data row1 col2" >2,654</td>
#       <td id="T_d711a_row1_col3" class="data row1 col3" >-3.00</td>
#       <td id="T_d711a_row1_col4" class="data row1 col4" >-2.83</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_d711a_row2_col0" class="data row2 col0" >AOT</td>
#       <td id="T_d711a_row2_col1" class="data row2 col1" >69.25</td>
#       <td id="T_d711a_row2_col2" class="data row2 col2" >1,929</td>
#       <td id="T_d711a_row2_col3" class="data row2 col3" >1.50</td>
#       <td id="T_d711a_row2_col4" class="data row2 col4" >2.21</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row3" class="row_heading level0 row3" >98</th>
#       <td id="T_d711a_row3_col0" class="data row3 col0" >KBANK</td>
#       <td id="T_d711a_row3_col1" class="data row3 col1" >148.50</td>
#       <td id="T_d711a_row3_col2" class="data row3 col2" >1,871</td>
#       <td id="T_d711a_row3_col3" class="data row3 col3" >-1.50</td>
#       <td id="T_d711a_row3_col4" class="data row3 col4" >-1.00</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row4" class="row_heading level0 row4" >48</th>
#       <td id="T_d711a_row4_col0" class="data row4 col0" >CPALL</td>
#       <td id="T_d711a_row4_col1" class="data row4 col1" >60.25</td>
#       <td id="T_d711a_row4_col2" class="data row4 col2" >1,862</td>
#       <td id="T_d711a_row4_col3" class="data row4 col3" >0.25</td>
#       <td id="T_d711a_row4_col4" class="data row4 col4" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row5" class="row_heading level0 row5" >144</th>
#       <td id="T_d711a_row5_col0" class="data row5 col0" >PTT</td>
#       <td id="T_d711a_row5_col1" class="data row5 col1" >33.25</td>
#       <td id="T_d711a_row5_col2" class="data row5 col2" >1,470</td>
#       <td id="T_d711a_row5_col3" class="data row5 col3" >-0.25</td>
#       <td id="T_d711a_row5_col4" class="data row5 col4" >-0.75</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row6" class="row_heading level0 row6" >21</th>
#       <td id="T_d711a_row6_col0" class="data row6 col0" >BBL</td>
#       <td id="T_d711a_row6_col1" class="data row6 col1" >134.50</td>
#       <td id="T_d711a_row6_col2" class="data row6 col2" >1,302</td>
#       <td id="T_d711a_row6_col3" class="data row6 col3" >-1.50</td>
#       <td id="T_d711a_row6_col4" class="data row6 col4" >-1.10</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row7" class="row_heading level0 row7" >19</th>
#       <td id="T_d711a_row7_col0" class="data row7 col0" >BANPU</td>
#       <td id="T_d711a_row7_col1" class="data row7 col1" >12.50</td>
#       <td id="T_d711a_row7_col2" class="data row7 col2" >1,269</td>
#       <td id="T_d711a_row7_col3" class="data row7 col3" >-0.10</td>
#       <td id="T_d711a_row7_col4" class="data row7 col4" >-0.79</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row8" class="row_heading level0 row8" >203</th>
#       <td id="T_d711a_row8_col0" class="data row8 col0" >TOP</td>
#       <td id="T_d711a_row8_col1" class="data row8 col1" >49.50</td>
#       <td id="T_d711a_row8_col2" class="data row8 col2" >1,120</td>
#       <td id="T_d711a_row8_col3" class="data row8 col3" >0.00</td>
#       <td id="T_d711a_row8_col4" class="data row8 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d711a_level0_row9" class="row_heading level0 row9" >32</th>
#       <td id="T_d711a_row9_col0" class="data row9 col0" >BGRIM</td>
#       <td id="T_d711a_row9_col1" class="data row9 col1" >35.50</td>
#       <td id="T_d711a_row9_col2" class="data row9 col2" >945</td>
#       <td id="T_d711a_row9_col3" class="data row9 col3" >1.25</td>
#       <td id="T_d711a_row9_col4" class="data row9 col4" >3.65</td>
#     </tr>
#   </tbody>
# </table>
