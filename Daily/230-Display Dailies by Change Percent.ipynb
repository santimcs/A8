# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 5, 24)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ecb29_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecb29_level0_row0" class="row_heading level0 row0" >79</th>
#       <td id="T_ecb29_row0_col0" class="data row0 col0" >GUNKUL</td>
#       <td id="T_ecb29_row0_col1" class="data row0 col1" >5.65</td>
#       <td id="T_ecb29_row0_col2" class="data row0 col2" >1,204</td>
#       <td id="T_ecb29_row0_col3" class="data row0 col3" >0.30</td>
#       <td id="T_ecb29_row0_col4" class="data row0 col4" >5.61</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row1" class="row_heading level0 row1" >185</th>
#       <td id="T_ecb29_row1_col0" class="data row1 col0" >STGT</td>
#       <td id="T_ecb29_row1_col1" class="data row1 col1" >21.10</td>
#       <td id="T_ecb29_row1_col2" class="data row1 col2" >673</td>
#       <td id="T_ecb29_row1_col3" class="data row1 col3" >1.10</td>
#       <td id="T_ecb29_row1_col4" class="data row1 col4" >5.50</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row2" class="row_heading level0 row2" >99</th>
#       <td id="T_ecb29_row2_col0" class="data row2 col0" >JWD</td>
#       <td id="T_ecb29_row2_col1" class="data row2 col1" >15.70</td>
#       <td id="T_ecb29_row2_col2" class="data row2 col2" >220</td>
#       <td id="T_ecb29_row2_col3" class="data row2 col3" >0.80</td>
#       <td id="T_ecb29_row2_col4" class="data row2 col4" >5.37</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_ecb29_row3_col0" class="data row3 col0" >FORTH</td>
#       <td id="T_ecb29_row3_col1" class="data row3 col1" >50.50</td>
#       <td id="T_ecb29_row3_col2" class="data row3 col2" >573</td>
#       <td id="T_ecb29_row3_col3" class="data row3 col3" >2.25</td>
#       <td id="T_ecb29_row3_col4" class="data row3 col4" >4.66</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row4" class="row_heading level0 row4" >71</th>
#       <td id="T_ecb29_row4_col0" class="data row4 col0" >FSMART</td>
#       <td id="T_ecb29_row4_col1" class="data row4 col1" >22.80</td>
#       <td id="T_ecb29_row4_col2" class="data row4 col2" >790</td>
#       <td id="T_ecb29_row4_col3" class="data row4 col3" >1.00</td>
#       <td id="T_ecb29_row4_col4" class="data row4 col4" >4.59</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row5" class="row_heading level0 row5" >204</th>
#       <td id="T_ecb29_row5_col0" class="data row5 col0" >TMW</td>
#       <td id="T_ecb29_row5_col1" class="data row5 col1" >35.75</td>
#       <td id="T_ecb29_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_ecb29_row5_col3" class="data row5 col3" >1.50</td>
#       <td id="T_ecb29_row5_col4" class="data row5 col4" >4.38</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row6" class="row_heading level0 row6" >133</th>
#       <td id="T_ecb29_row6_col0" class="data row6 col0" >ORI</td>
#       <td id="T_ecb29_row6_col1" class="data row6 col1" >10.20</td>
#       <td id="T_ecb29_row6_col2" class="data row6 col2" >257</td>
#       <td id="T_ecb29_row6_col3" class="data row6 col3" >0.35</td>
#       <td id="T_ecb29_row6_col4" class="data row6 col4" >3.55</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row7" class="row_heading level0 row7" >88</th>
#       <td id="T_ecb29_row7_col0" class="data row7 col0" >IMH</td>
#       <td id="T_ecb29_row7_col1" class="data row7 col1" >18.00</td>
#       <td id="T_ecb29_row7_col2" class="data row7 col2" >30</td>
#       <td id="T_ecb29_row7_col3" class="data row7 col3" >0.60</td>
#       <td id="T_ecb29_row7_col4" class="data row7 col4" >3.45</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row8" class="row_heading level0 row8" >120</th>
#       <td id="T_ecb29_row8_col0" class="data row8 col0" >MAJOR</td>
#       <td id="T_ecb29_row8_col1" class="data row8 col1" >21.20</td>
#       <td id="T_ecb29_row8_col2" class="data row8 col2" >218</td>
#       <td id="T_ecb29_row8_col3" class="data row8 col3" >0.70</td>
#       <td id="T_ecb29_row8_col4" class="data row8 col4" >3.41</td>
#     </tr>
#     <tr>
#       <th id="T_ecb29_level0_row9" class="row_heading level0 row9" >225</th>
#       <td id="T_ecb29_row9_col0" class="data row9 col0" >VNG</td>
#       <td id="T_ecb29_row9_col1" class="data row9 col1" >8.35</td>
#       <td id="T_ecb29_row9_col2" class="data row9 col2" >35</td>
#       <td id="T_ecb29_row9_col3" class="data row9 col3" >0.25</td>
#       <td id="T_ecb29_row9_col4" class="data row9 col4" >3.09</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_248a9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_248a9_level0_row0" class="row_heading level0 row0" >24</th>
#       <td id="T_248a9_row0_col0" class="data row0 col0" >BCP</td>
#       <td id="T_248a9_row0_col1" class="data row0 col1" >32.50</td>
#       <td id="T_248a9_row0_col2" class="data row0 col2" >337</td>
#       <td id="T_248a9_row0_col3" class="data row0 col3" >-1.25</td>
#       <td id="T_248a9_row0_col4" class="data row0 col4" >-3.70</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row1" class="row_heading level0 row1" >161</th>
#       <td id="T_248a9_row1_col0" class="data row1 col0" >SCB</td>
#       <td id="T_248a9_row1_col1" class="data row1 col1" >111.00</td>
#       <td id="T_248a9_row1_col2" class="data row1 col2" >1,903</td>
#       <td id="T_248a9_row1_col3" class="data row1 col3" >-4.00</td>
#       <td id="T_248a9_row1_col4" class="data row1 col4" >-3.48</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row2" class="row_heading level0 row2" >31</th>
#       <td id="T_248a9_row2_col0" class="data row2 col0" >BFIT</td>
#       <td id="T_248a9_row2_col1" class="data row2 col1" >29.75</td>
#       <td id="T_248a9_row2_col2" class="data row2 col2" >27</td>
#       <td id="T_248a9_row2_col3" class="data row2 col3" >-1.00</td>
#       <td id="T_248a9_row2_col4" class="data row2 col4" >-3.25</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_248a9_row3_col0" class="data row3 col0" >AMATA</td>
#       <td id="T_248a9_row3_col1" class="data row3 col1" >19.20</td>
#       <td id="T_248a9_row3_col2" class="data row3 col2" >119</td>
#       <td id="T_248a9_row3_col3" class="data row3 col3" >-0.60</td>
#       <td id="T_248a9_row3_col4" class="data row3 col4" >-3.03</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row4" class="row_heading level0 row4" >157</th>
#       <td id="T_248a9_row4_col0" class="data row4 col0" >SAPPE</td>
#       <td id="T_248a9_row4_col1" class="data row4 col1" >34.25</td>
#       <td id="T_248a9_row4_col2" class="data row4 col2" >62</td>
#       <td id="T_248a9_row4_col3" class="data row4 col3" >-1.00</td>
#       <td id="T_248a9_row4_col4" class="data row4 col4" >-2.84</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row5" class="row_heading level0 row5" >75</th>
#       <td id="T_248a9_row5_col0" class="data row5 col0" >GLOBAL</td>
#       <td id="T_248a9_row5_col1" class="data row5 col1" >20.90</td>
#       <td id="T_248a9_row5_col2" class="data row5 col2" >212</td>
#       <td id="T_248a9_row5_col3" class="data row5 col3" >-0.60</td>
#       <td id="T_248a9_row5_col4" class="data row5 col4" >-2.79</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row6" class="row_heading level0 row6" >35</th>
#       <td id="T_248a9_row6_col0" class="data row6 col0" >BJC</td>
#       <td id="T_248a9_row6_col1" class="data row6 col1" >35.50</td>
#       <td id="T_248a9_row6_col2" class="data row6 col2" >173</td>
#       <td id="T_248a9_row6_col3" class="data row6 col3" >-1.00</td>
#       <td id="T_248a9_row6_col4" class="data row6 col4" >-2.74</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row7" class="row_heading level0 row7" >223</th>
#       <td id="T_248a9_row7_col0" class="data row7 col0" >VGI</td>
#       <td id="T_248a9_row7_col1" class="data row7 col1" >4.74</td>
#       <td id="T_248a9_row7_col2" class="data row7 col2" >119</td>
#       <td id="T_248a9_row7_col3" class="data row7 col3" >-0.12</td>
#       <td id="T_248a9_row7_col4" class="data row7 col4" >-2.47</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row8" class="row_heading level0 row8" >143</th>
#       <td id="T_248a9_row8_col0" class="data row8 col0" >PSL</td>
#       <td id="T_248a9_row8_col1" class="data row8 col1" >20.50</td>
#       <td id="T_248a9_row8_col2" class="data row8 col2" >142</td>
#       <td id="T_248a9_row8_col3" class="data row8 col3" >-0.50</td>
#       <td id="T_248a9_row8_col4" class="data row8 col4" >-2.38</td>
#     </tr>
#     <tr>
#       <th id="T_248a9_level0_row9" class="row_heading level0 row9" >128</th>
#       <td id="T_248a9_row9_col0" class="data row9 col0" >MTC</td>
#       <td id="T_248a9_row9_col1" class="data row9 col1" >43.75</td>
#       <td id="T_248a9_row9_col2" class="data row9 col2" >403</td>
#       <td id="T_248a9_row9_col3" class="data row9 col3" >-1.00</td>
#       <td id="T_248a9_row9_col4" class="data row9 col4" >-2.23</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e520b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e520b_level0_row0" class="row_heading level0 row0" >27</th>
#       <td id="T_e520b_row0_col0" class="data row0 col0" >BDMS</td>
#       <td id="T_e520b_row0_col1" class="data row0 col1" >26.50</td>
#       <td id="T_e520b_row0_col2" class="data row0 col2" >2,737</td>
#       <td id="T_e520b_row0_col3" class="data row0 col3" >-0.50</td>
#       <td id="T_e520b_row0_col4" class="data row0 col4" >-1.85</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e520b_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_e520b_row1_col1" class="data row1 col1" >224.00</td>
#       <td id="T_e520b_row1_col2" class="data row1 col2" >2,401</td>
#       <td id="T_e520b_row1_col3" class="data row1 col3" >4.00</td>
#       <td id="T_e520b_row1_col4" class="data row1 col4" >1.82</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row2" class="row_heading level0 row2" >146</th>
#       <td id="T_e520b_row2_col0" class="data row2 col0" >PTT</td>
#       <td id="T_e520b_row2_col1" class="data row2 col1" >37.00</td>
#       <td id="T_e520b_row2_col2" class="data row2 col2" >2,242</td>
#       <td id="T_e520b_row2_col3" class="data row2 col3" >-0.50</td>
#       <td id="T_e520b_row2_col4" class="data row2 col4" >-1.33</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_e520b_row3_col0" class="data row3 col0" >AOT</td>
#       <td id="T_e520b_row3_col1" class="data row3 col1" >69.00</td>
#       <td id="T_e520b_row3_col2" class="data row3 col2" >2,149</td>
#       <td id="T_e520b_row3_col3" class="data row3 col3" >-0.50</td>
#       <td id="T_e520b_row3_col4" class="data row3 col4" >-0.72</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row4" class="row_heading level0 row4" >161</th>
#       <td id="T_e520b_row4_col0" class="data row4 col0" >SCB</td>
#       <td id="T_e520b_row4_col1" class="data row4 col1" >111.00</td>
#       <td id="T_e520b_row4_col2" class="data row4 col2" >1,903</td>
#       <td id="T_e520b_row4_col3" class="data row4 col3" >-4.00</td>
#       <td id="T_e520b_row4_col4" class="data row4 col4" >-3.48</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row5" class="row_heading level0 row5" >147</th>
#       <td id="T_e520b_row5_col0" class="data row5 col0" >PTTEP</td>
#       <td id="T_e520b_row5_col1" class="data row5 col1" >155.50</td>
#       <td id="T_e520b_row5_col2" class="data row5 col2" >1,592</td>
#       <td id="T_e520b_row5_col3" class="data row5 col3" >-1.50</td>
#       <td id="T_e520b_row5_col4" class="data row5 col4" >-0.96</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row6" class="row_heading level0 row6" >49</th>
#       <td id="T_e520b_row6_col0" class="data row6 col0" >CPALL</td>
#       <td id="T_e520b_row6_col1" class="data row6 col1" >64.00</td>
#       <td id="T_e520b_row6_col2" class="data row6 col2" >1,384</td>
#       <td id="T_e520b_row6_col3" class="data row6 col3" >-1.25</td>
#       <td id="T_e520b_row6_col4" class="data row6 col4" >-1.92</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row7" class="row_heading level0 row7" >100</th>
#       <td id="T_e520b_row7_col0" class="data row7 col0" >KBANK</td>
#       <td id="T_e520b_row7_col1" class="data row7 col1" >145.00</td>
#       <td id="T_e520b_row7_col2" class="data row7 col2" >1,304</td>
#       <td id="T_e520b_row7_col3" class="data row7 col3" >-0.50</td>
#       <td id="T_e520b_row7_col4" class="data row7 col4" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row8" class="row_heading level0 row8" >79</th>
#       <td id="T_e520b_row8_col0" class="data row8 col0" >GUNKUL</td>
#       <td id="T_e520b_row8_col1" class="data row8 col1" >5.65</td>
#       <td id="T_e520b_row8_col2" class="data row8 col2" >1,204</td>
#       <td id="T_e520b_row8_col3" class="data row8 col3" >0.30</td>
#       <td id="T_e520b_row8_col4" class="data row8 col4" >5.61</td>
#     </tr>
#     <tr>
#       <th id="T_e520b_level0_row9" class="row_heading level0 row9" >20</th>
#       <td id="T_e520b_row9_col0" class="data row9 col0" >BANPU</td>
#       <td id="T_e520b_row9_col1" class="data row9 col1" >12.10</td>
#       <td id="T_e520b_row9_col2" class="data row9 col2" >1,097</td>
#       <td id="T_e520b_row9_col3" class="data row9 col3" >-0.10</td>
#       <td id="T_e520b_row9_col4" class="data row9 col4" >-0.82</td>
#     </tr>
#   </tbody>
# </table>
