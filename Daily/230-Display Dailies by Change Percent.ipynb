# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 7)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b852_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b852_level0_row0" class="row_heading level0 row0" >219</th>
#       <td id="T_9b852_row0_col0" class="data row0 col0" >TYCN</td>
#       <td id="T_9b852_row0_col1" class="data row0 col1" >3.94</td>
#       <td id="T_9b852_row0_col2" class="data row0 col2" >137</td>
#       <td id="T_9b852_row0_col3" class="data row0 col3" >0.30</td>
#       <td id="T_9b852_row0_col4" class="data row0 col4" >8.24</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row1" class="row_heading level0 row1" >68</th>
#       <td id="T_9b852_row1_col0" class="data row1 col0" >ESSO</td>
#       <td id="T_9b852_row1_col1" class="data row1 col1" >11.20</td>
#       <td id="T_9b852_row1_col2" class="data row1 col2" >729</td>
#       <td id="T_9b852_row1_col3" class="data row1 col3" >0.80</td>
#       <td id="T_9b852_row1_col4" class="data row1 col4" >7.69</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row2" class="row_heading level0 row2" >135</th>
#       <td id="T_9b852_row2_col0" class="data row2 col0" >PCSGH</td>
#       <td id="T_9b852_row2_col1" class="data row2 col1" >5.40</td>
#       <td id="T_9b852_row2_col2" class="data row2 col2" >36</td>
#       <td id="T_9b852_row2_col3" class="data row2 col3" >0.25</td>
#       <td id="T_9b852_row2_col4" class="data row2 col4" >4.85</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row3" class="row_heading level0 row3" >69</th>
#       <td id="T_9b852_row3_col0" class="data row3 col0" >FORTH</td>
#       <td id="T_9b852_row3_col1" class="data row3 col1" >47.00</td>
#       <td id="T_9b852_row3_col2" class="data row3 col2" >479</td>
#       <td id="T_9b852_row3_col3" class="data row3 col3" >2.00</td>
#       <td id="T_9b852_row3_col4" class="data row3 col4" >4.44</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row4" class="row_heading level0 row4" >78</th>
#       <td id="T_9b852_row4_col0" class="data row4 col0" >GUNKUL</td>
#       <td id="T_9b852_row4_col1" class="data row4 col1" >5.90</td>
#       <td id="T_9b852_row4_col2" class="data row4 col2" >826</td>
#       <td id="T_9b852_row4_col3" class="data row4 col3" >0.20</td>
#       <td id="T_9b852_row4_col4" class="data row4 col4" >3.51</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row5" class="row_heading level0 row5" >111</th>
#       <td id="T_9b852_row5_col0" class="data row5 col0" >LHFG</td>
#       <td id="T_9b852_row5_col1" class="data row5 col1" >1.32</td>
#       <td id="T_9b852_row5_col2" class="data row5 col2" >23</td>
#       <td id="T_9b852_row5_col3" class="data row5 col3" >0.04</td>
#       <td id="T_9b852_row5_col4" class="data row5 col4" >3.12</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_9b852_row6_col0" class="data row6 col0" >BANPU</td>
#       <td id="T_9b852_row6_col1" class="data row6 col1" >13.30</td>
#       <td id="T_9b852_row6_col2" class="data row6 col2" >3,442</td>
#       <td id="T_9b852_row6_col3" class="data row6 col3" >0.40</td>
#       <td id="T_9b852_row6_col4" class="data row6 col4" >3.10</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row7" class="row_heading level0 row7" >23</th>
#       <td id="T_9b852_row7_col0" class="data row7 col0" >BCP</td>
#       <td id="T_9b852_row7_col1" class="data row7 col1" >34.25</td>
#       <td id="T_9b852_row7_col2" class="data row7 col2" >457</td>
#       <td id="T_9b852_row7_col3" class="data row7 col3" >1.00</td>
#       <td id="T_9b852_row7_col4" class="data row7 col4" >3.01</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row8" class="row_heading level0 row8" >210</th>
#       <td id="T_9b852_row8_col0" class="data row8 col0" >TSE</td>
#       <td id="T_9b852_row8_col1" class="data row8 col1" >2.34</td>
#       <td id="T_9b852_row8_col2" class="data row8 col2" >90</td>
#       <td id="T_9b852_row8_col3" class="data row8 col3" >0.06</td>
#       <td id="T_9b852_row8_col4" class="data row8 col4" >2.63</td>
#     </tr>
#     <tr>
#       <th id="T_9b852_level0_row9" class="row_heading level0 row9" >176</th>
#       <td id="T_9b852_row9_col0" class="data row9 col0" >SPRC</td>
#       <td id="T_9b852_row9_col1" class="data row9 col1" >13.00</td>
#       <td id="T_9b852_row9_col2" class="data row9 col2" >562</td>
#       <td id="T_9b852_row9_col3" class="data row9 col3" >0.30</td>
#       <td id="T_9b852_row9_col4" class="data row9 col4" >2.36</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc4b6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc4b6_level0_row0" class="row_heading level0 row0" >98</th>
#       <td id="T_bc4b6_row0_col0" class="data row0 col0" >JWD</td>
#       <td id="T_bc4b6_row0_col1" class="data row0 col1" >15.20</td>
#       <td id="T_bc4b6_row0_col2" class="data row0 col2" >116</td>
#       <td id="T_bc4b6_row0_col3" class="data row0 col3" >-0.80</td>
#       <td id="T_bc4b6_row0_col4" class="data row0 col4" >-5.00</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row1" class="row_heading level0 row1" >115</th>
#       <td id="T_bc4b6_row1_col0" class="data row1 col0" >LPH</td>
#       <td id="T_bc4b6_row1_col1" class="data row1 col1" >5.70</td>
#       <td id="T_bc4b6_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_bc4b6_row1_col3" class="data row1 col3" >-0.25</td>
#       <td id="T_bc4b6_row1_col4" class="data row1 col4" >-4.20</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row2" class="row_heading level0 row2" >179</th>
#       <td id="T_bc4b6_row2_col0" class="data row2 col0" >STA</td>
#       <td id="T_bc4b6_row2_col1" class="data row2 col1" >23.20</td>
#       <td id="T_bc4b6_row2_col2" class="data row2 col2" >360</td>
#       <td id="T_bc4b6_row2_col3" class="data row2 col3" >-1.00</td>
#       <td id="T_bc4b6_row2_col4" class="data row2 col4" >-4.13</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row3" class="row_heading level0 row3" >120</th>
#       <td id="T_bc4b6_row3_col0" class="data row3 col0" >MAKRO</td>
#       <td id="T_bc4b6_row3_col1" class="data row3 col1" >35.75</td>
#       <td id="T_bc4b6_row3_col2" class="data row3 col2" >859</td>
#       <td id="T_bc4b6_row3_col3" class="data row3 col3" >-1.50</td>
#       <td id="T_bc4b6_row3_col4" class="data row3 col4" >-4.03</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row4" class="row_heading level0 row4" >26</th>
#       <td id="T_bc4b6_row4_col0" class="data row4 col0" >BDMS</td>
#       <td id="T_bc4b6_row4_col1" class="data row4 col1" >25.00</td>
#       <td id="T_bc4b6_row4_col2" class="data row4 col2" >1,825</td>
#       <td id="T_bc4b6_row4_col3" class="data row4 col3" >-1.00</td>
#       <td id="T_bc4b6_row4_col4" class="data row4 col4" >-3.85</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row5" class="row_heading level0 row5" >80</th>
#       <td id="T_bc4b6_row5_col0" class="data row5 col0" >HANA</td>
#       <td id="T_bc4b6_row5_col1" class="data row5 col1" >44.75</td>
#       <td id="T_bc4b6_row5_col2" class="data row5 col2" >345</td>
#       <td id="T_bc4b6_row5_col3" class="data row5 col3" >-1.75</td>
#       <td id="T_bc4b6_row5_col4" class="data row5 col4" >-3.76</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row6" class="row_heading level0 row6" >193</th>
#       <td id="T_bc4b6_row6_col0" class="data row6 col0" >THG</td>
#       <td id="T_bc4b6_row6_col1" class="data row6 col1" >57.25</td>
#       <td id="T_bc4b6_row6_col2" class="data row6 col2" >902</td>
#       <td id="T_bc4b6_row6_col3" class="data row6 col3" >-2.00</td>
#       <td id="T_bc4b6_row6_col4" class="data row6 col4" >-3.38</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row7" class="row_heading level0 row7" >166</th>
#       <td id="T_bc4b6_row7_col0" class="data row7 col0" >SINGER</td>
#       <td id="T_bc4b6_row7_col1" class="data row7 col1" >50.25</td>
#       <td id="T_bc4b6_row7_col2" class="data row7 col2" >131</td>
#       <td id="T_bc4b6_row7_col3" class="data row7 col3" >-1.75</td>
#       <td id="T_bc4b6_row7_col4" class="data row7 col4" >-3.37</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row8" class="row_heading level0 row8" >196</th>
#       <td id="T_bc4b6_row8_col0" class="data row8 col0" >TIPCO</td>
#       <td id="T_bc4b6_row8_col1" class="data row8 col1" >9.10</td>
#       <td id="T_bc4b6_row8_col2" class="data row8 col2" >30</td>
#       <td id="T_bc4b6_row8_col3" class="data row8 col3" >-0.30</td>
#       <td id="T_bc4b6_row8_col4" class="data row8 col4" >-3.19</td>
#     </tr>
#     <tr>
#       <th id="T_bc4b6_level0_row9" class="row_heading level0 row9" >13</th>
#       <td id="T_bc4b6_row9_col0" class="data row9 col0" >ASK</td>
#       <td id="T_bc4b6_row9_col1" class="data row9 col1" >39.00</td>
#       <td id="T_bc4b6_row9_col2" class="data row9 col2" >40</td>
#       <td id="T_bc4b6_row9_col3" class="data row9 col3" >-1.25</td>
#       <td id="T_bc4b6_row9_col4" class="data row9 col4" >-3.11</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b096_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b096_level0_row0" class="row_heading level0 row0" >19</th>
#       <td id="T_8b096_row0_col0" class="data row0 col0" >BANPU</td>
#       <td id="T_8b096_row0_col1" class="data row0 col1" >13.30</td>
#       <td id="T_8b096_row0_col2" class="data row0 col2" >3,442</td>
#       <td id="T_8b096_row0_col3" class="data row0 col3" >0.40</td>
#       <td id="T_8b096_row0_col4" class="data row0 col4" >3.10</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_8b096_row1_col0" class="data row1 col0" >AOT</td>
#       <td id="T_8b096_row1_col1" class="data row1 col1" >68.50</td>
#       <td id="T_8b096_row1_col2" class="data row1 col2" >2,134</td>
#       <td id="T_8b096_row1_col3" class="data row1 col3" >-1.00</td>
#       <td id="T_8b096_row1_col4" class="data row1 col4" >-1.44</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row2" class="row_heading level0 row2" >26</th>
#       <td id="T_8b096_row2_col0" class="data row2 col0" >BDMS</td>
#       <td id="T_8b096_row2_col1" class="data row2 col1" >25.00</td>
#       <td id="T_8b096_row2_col2" class="data row2 col2" >1,825</td>
#       <td id="T_8b096_row2_col3" class="data row2 col3" >-1.00</td>
#       <td id="T_8b096_row2_col4" class="data row2 col4" >-3.85</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row3" class="row_heading level0 row3" >146</th>
#       <td id="T_8b096_row3_col0" class="data row3 col0" >PTTEP</td>
#       <td id="T_8b096_row3_col1" class="data row3 col1" >169.00</td>
#       <td id="T_8b096_row3_col2" class="data row3 col2" >1,791</td>
#       <td id="T_8b096_row3_col3" class="data row3 col3" >0.50</td>
#       <td id="T_8b096_row3_col4" class="data row3 col4" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row4" class="row_heading level0 row4" >105</th>
#       <td id="T_8b096_row4_col0" class="data row4 col0" >KTB</td>
#       <td id="T_8b096_row4_col1" class="data row4 col1" >15.60</td>
#       <td id="T_8b096_row4_col2" class="data row4 col2" >1,345</td>
#       <td id="T_8b096_row4_col3" class="data row4 col3" >-0.10</td>
#       <td id="T_8b096_row4_col4" class="data row4 col4" >-0.64</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row5" class="row_heading level0 row5" >145</th>
#       <td id="T_8b096_row5_col0" class="data row5 col0" >PTT</td>
#       <td id="T_8b096_row5_col1" class="data row5 col1" >38.00</td>
#       <td id="T_8b096_row5_col2" class="data row5 col2" >1,330</td>
#       <td id="T_8b096_row5_col3" class="data row5 col3" >-0.25</td>
#       <td id="T_8b096_row5_col4" class="data row5 col4" >-0.65</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row6" class="row_heading level0 row6" >204</th>
#       <td id="T_8b096_row6_col0" class="data row6 col0" >TOP</td>
#       <td id="T_8b096_row6_col1" class="data row6 col1" >59.50</td>
#       <td id="T_8b096_row6_col2" class="data row6 col2" >1,063</td>
#       <td id="T_8b096_row6_col3" class="data row6 col3" >1.25</td>
#       <td id="T_8b096_row6_col4" class="data row6 col4" >2.15</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row7" class="row_heading level0 row7" >99</th>
#       <td id="T_8b096_row7_col0" class="data row7 col0" >KBANK</td>
#       <td id="T_8b096_row7_col1" class="data row7 col1" >144.00</td>
#       <td id="T_8b096_row7_col2" class="data row7 col2" >1,052</td>
#       <td id="T_8b096_row7_col3" class="data row7 col3" >-1.50</td>
#       <td id="T_8b096_row7_col4" class="data row7 col4" >-1.03</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_8b096_row8_col0" class="data row8 col0" >ADVANC</td>
#       <td id="T_8b096_row8_col1" class="data row8 col1" >212.00</td>
#       <td id="T_8b096_row8_col2" class="data row8 col2" >941</td>
#       <td id="T_8b096_row8_col3" class="data row8 col3" >-2.00</td>
#       <td id="T_8b096_row8_col4" class="data row8 col4" >-0.93</td>
#     </tr>
#     <tr>
#       <th id="T_8b096_level0_row9" class="row_heading level0 row9" >48</th>
#       <td id="T_8b096_row9_col0" class="data row9 col0" >CPALL</td>
#       <td id="T_8b096_row9_col1" class="data row9 col1" >64.00</td>
#       <td id="T_8b096_row9_col2" class="data row9 col2" >925</td>
#       <td id="T_8b096_row9_col3" class="data row9 col3" >-1.00</td>
#       <td id="T_8b096_row9_col4" class="data row9 col4" >-1.54</td>
#     </tr>
#   </tbody>
# </table>
