# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 2)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0394f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0394f_level0_row0" class="row_heading level0 row0" >199</th>
#       <td id="T_0394f_row0_col0" class="data row0 col0" >TK</td>
#       <td id="T_0394f_row0_col1" class="data row0 col1" >11.80</td>
#       <td id="T_0394f_row0_col2" class="data row0 col2" >49</td>
#       <td id="T_0394f_row0_col3" class="data row0 col3" >0.80</td>
#       <td id="T_0394f_row0_col4" class="data row0 col4" >7.27</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row1" class="row_heading level0 row1" >156</th>
#       <td id="T_0394f_row1_col0" class="data row1 col0" >S11</td>
#       <td id="T_0394f_row1_col1" class="data row1 col1" >6.05</td>
#       <td id="T_0394f_row1_col2" class="data row1 col2" >19</td>
#       <td id="T_0394f_row1_col3" class="data row1 col3" >0.25</td>
#       <td id="T_0394f_row1_col4" class="data row1 col4" >4.31</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_0394f_row2_col0" class="data row2 col0" >ANAN</td>
#       <td id="T_0394f_row2_col1" class="data row2 col1" >1.38</td>
#       <td id="T_0394f_row2_col2" class="data row2 col2" >81</td>
#       <td id="T_0394f_row2_col3" class="data row2 col3" >0.04</td>
#       <td id="T_0394f_row2_col4" class="data row2 col4" >2.99</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row3" class="row_heading level0 row3" >177</th>
#       <td id="T_0394f_row3_col0" class="data row3 col0" >SPRC</td>
#       <td id="T_0394f_row3_col1" class="data row3 col1" >12.50</td>
#       <td id="T_0394f_row3_col2" class="data row3 col2" >498</td>
#       <td id="T_0394f_row3_col3" class="data row3 col3" >0.30</td>
#       <td id="T_0394f_row3_col4" class="data row3 col4" >2.46</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row4" class="row_heading level0 row4" >91</th>
#       <td id="T_0394f_row4_col0" class="data row4 col0" >INOX</td>
#       <td id="T_0394f_row4_col1" class="data row4 col1" >1.30</td>
#       <td id="T_0394f_row4_col2" class="data row4 col2" >42</td>
#       <td id="T_0394f_row4_col3" class="data row4 col3" >0.03</td>
#       <td id="T_0394f_row4_col4" class="data row4 col4" >2.36</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row5" class="row_heading level0 row5" >143</th>
#       <td id="T_0394f_row5_col0" class="data row5 col0" >PSL</td>
#       <td id="T_0394f_row5_col1" class="data row5 col1" >19.90</td>
#       <td id="T_0394f_row5_col2" class="data row5 col2" >129</td>
#       <td id="T_0394f_row5_col3" class="data row5 col3" >0.40</td>
#       <td id="T_0394f_row5_col4" class="data row5 col4" >2.05</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row6" class="row_heading level0 row6" >213</th>
#       <td id="T_0394f_row6_col0" class="data row6 col0" >TTA</td>
#       <td id="T_0394f_row6_col1" class="data row6 col1" >10.20</td>
#       <td id="T_0394f_row6_col2" class="data row6 col2" >185</td>
#       <td id="T_0394f_row6_col3" class="data row6 col3" >0.20</td>
#       <td id="T_0394f_row6_col4" class="data row6 col4" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row7" class="row_heading level0 row7" >75</th>
#       <td id="T_0394f_row7_col0" class="data row7 col0" >GLOBAL</td>
#       <td id="T_0394f_row7_col1" class="data row7 col1" >21.30</td>
#       <td id="T_0394f_row7_col2" class="data row7 col2" >177</td>
#       <td id="T_0394f_row7_col3" class="data row7 col3" >0.40</td>
#       <td id="T_0394f_row7_col4" class="data row7 col4" >1.91</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row8" class="row_heading level0 row8" >228</th>
#       <td id="T_0394f_row8_col0" class="data row8 col0" >WICE</td>
#       <td id="T_0394f_row8_col1" class="data row8 col1" >16.30</td>
#       <td id="T_0394f_row8_col2" class="data row8 col2" >287</td>
#       <td id="T_0394f_row8_col3" class="data row8 col3" >0.30</td>
#       <td id="T_0394f_row8_col4" class="data row8 col4" >1.88</td>
#     </tr>
#     <tr>
#       <th id="T_0394f_level0_row9" class="row_heading level0 row9" >77</th>
#       <td id="T_0394f_row9_col0" class="data row9 col0" >GRAMMY</td>
#       <td id="T_0394f_row9_col1" class="data row9 col1" >11.60</td>
#       <td id="T_0394f_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_0394f_row9_col3" class="data row9 col3" >0.20</td>
#       <td id="T_0394f_row9_col4" class="data row9 col4" >1.75</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e89c6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e89c6_level0_row0" class="row_heading level0 row0" >194</th>
#       <td id="T_e89c6_row0_col0" class="data row0 col0" >THG</td>
#       <td id="T_e89c6_row0_col1" class="data row0 col1" >63.75</td>
#       <td id="T_e89c6_row0_col2" class="data row0 col2" >1,893</td>
#       <td id="T_e89c6_row0_col3" class="data row0 col3" >-9.25</td>
#       <td id="T_e89c6_row0_col4" class="data row0 col4" >-12.67</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row1" class="row_heading level0 row1" >197</th>
#       <td id="T_e89c6_row1_col0" class="data row1 col0" >TIPCO</td>
#       <td id="T_e89c6_row1_col1" class="data row1 col1" >9.30</td>
#       <td id="T_e89c6_row1_col2" class="data row1 col2" >86</td>
#       <td id="T_e89c6_row1_col3" class="data row1 col3" >-0.55</td>
#       <td id="T_e89c6_row1_col4" class="data row1 col4" >-5.58</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row2" class="row_heading level0 row2" >196</th>
#       <td id="T_e89c6_row2_col0" class="data row2 col0" >TIPH</td>
#       <td id="T_e89c6_row2_col1" class="data row2 col1" >63.50</td>
#       <td id="T_e89c6_row2_col2" class="data row2 col2" >730</td>
#       <td id="T_e89c6_row2_col3" class="data row2 col3" >-2.75</td>
#       <td id="T_e89c6_row2_col4" class="data row2 col4" >-4.15</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row3" class="row_heading level0 row3" >170</th>
#       <td id="T_e89c6_row3_col0" class="data row3 col0" >SKN</td>
#       <td id="T_e89c6_row3_col1" class="data row3 col1" >7.70</td>
#       <td id="T_e89c6_row3_col2" class="data row3 col2" >49</td>
#       <td id="T_e89c6_row3_col3" class="data row3 col3" >-0.30</td>
#       <td id="T_e89c6_row3_col4" class="data row3 col4" >-3.75</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row4" class="row_heading level0 row4" >47</th>
#       <td id="T_e89c6_row4_col0" class="data row4 col0" >COM7</td>
#       <td id="T_e89c6_row4_col1" class="data row4 col1" >36.25</td>
#       <td id="T_e89c6_row4_col2" class="data row4 col2" >688</td>
#       <td id="T_e89c6_row4_col3" class="data row4 col3" >-1.25</td>
#       <td id="T_e89c6_row4_col4" class="data row4 col4" >-3.33</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row5" class="row_heading level0 row5" >223</th>
#       <td id="T_e89c6_row5_col0" class="data row5 col0" >VIBHA</td>
#       <td id="T_e89c6_row5_col1" class="data row5 col1" >2.56</td>
#       <td id="T_e89c6_row5_col2" class="data row5 col2" >28</td>
#       <td id="T_e89c6_row5_col3" class="data row5 col3" >-0.08</td>
#       <td id="T_e89c6_row5_col4" class="data row5 col4" >-3.03</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row6" class="row_heading level0 row6" >136</th>
#       <td id="T_e89c6_row6_col0" class="data row6 col0" >PCSGH</td>
#       <td id="T_e89c6_row6_col1" class="data row6 col1" >5.10</td>
#       <td id="T_e89c6_row6_col2" class="data row6 col2" >15</td>
#       <td id="T_e89c6_row6_col3" class="data row6 col3" >-0.15</td>
#       <td id="T_e89c6_row6_col4" class="data row6 col4" >-2.86</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row7" class="row_heading level0 row7" >188</th>
#       <td id="T_e89c6_row7_col0" class="data row7 col0" >SYNEX</td>
#       <td id="T_e89c6_row7_col1" class="data row7 col1" >21.30</td>
#       <td id="T_e89c6_row7_col2" class="data row7 col2" >64</td>
#       <td id="T_e89c6_row7_col3" class="data row7 col3" >-0.60</td>
#       <td id="T_e89c6_row7_col4" class="data row7 col4" >-2.74</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row8" class="row_heading level0 row8" >72</th>
#       <td id="T_e89c6_row8_col0" class="data row8 col0" >GC</td>
#       <td id="T_e89c6_row8_col1" class="data row8 col1" >5.65</td>
#       <td id="T_e89c6_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_e89c6_row8_col3" class="data row8 col3" >-0.15</td>
#       <td id="T_e89c6_row8_col4" class="data row8 col4" >-2.59</td>
#     </tr>
#     <tr>
#       <th id="T_e89c6_level0_row9" class="row_heading level0 row9" >229</th>
#       <td id="T_e89c6_row9_col0" class="data row9 col0" >WORK</td>
#       <td id="T_e89c6_row9_col1" class="data row9 col1" >23.30</td>
#       <td id="T_e89c6_row9_col2" class="data row9 col2" >38</td>
#       <td id="T_e89c6_row9_col3" class="data row9 col3" >-0.60</td>
#       <td id="T_e89c6_row9_col4" class="data row9 col4" >-2.51</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_44be4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44be4_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_44be4_row0_col0" class="data row0 col0" >BANPU</td>
#       <td id="T_44be4_row0_col1" class="data row0 col1" >12.60</td>
#       <td id="T_44be4_row0_col2" class="data row0 col2" >2,637</td>
#       <td id="T_44be4_row0_col3" class="data row0 col3" >0.20</td>
#       <td id="T_44be4_row0_col4" class="data row0 col4" >1.61</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row1" class="row_heading level0 row1" >27</th>
#       <td id="T_44be4_row1_col0" class="data row1 col0" >BDMS</td>
#       <td id="T_44be4_row1_col1" class="data row1 col1" >25.75</td>
#       <td id="T_44be4_row1_col2" class="data row1 col2" >2,410</td>
#       <td id="T_44be4_row1_col3" class="data row1 col3" >-0.50</td>
#       <td id="T_44be4_row1_col4" class="data row1 col4" >-1.90</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row2" class="row_heading level0 row2" >147</th>
#       <td id="T_44be4_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_44be4_row2_col1" class="data row2 col1" >166.50</td>
#       <td id="T_44be4_row2_col2" class="data row2 col2" >2,198</td>
#       <td id="T_44be4_row2_col3" class="data row2 col3" >-1.00</td>
#       <td id="T_44be4_row2_col4" class="data row2 col4" >-0.60</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row3" class="row_heading level0 row3" >194</th>
#       <td id="T_44be4_row3_col0" class="data row3 col0" >THG</td>
#       <td id="T_44be4_row3_col1" class="data row3 col1" >63.75</td>
#       <td id="T_44be4_row3_col2" class="data row3 col2" >1,893</td>
#       <td id="T_44be4_row3_col3" class="data row3 col3" >-9.25</td>
#       <td id="T_44be4_row3_col4" class="data row3 col4" >-12.67</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row4" class="row_heading level0 row4" >49</th>
#       <td id="T_44be4_row4_col0" class="data row4 col0" >CPALL</td>
#       <td id="T_44be4_row4_col1" class="data row4 col1" >65.00</td>
#       <td id="T_44be4_row4_col2" class="data row4 col2" >1,314</td>
#       <td id="T_44be4_row4_col3" class="data row4 col3" >-1.00</td>
#       <td id="T_44be4_row4_col4" class="data row4 col4" >-1.52</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row5" class="row_heading level0 row5" >146</th>
#       <td id="T_44be4_row5_col0" class="data row5 col0" >PTT</td>
#       <td id="T_44be4_row5_col1" class="data row5 col1" >38.00</td>
#       <td id="T_44be4_row5_col2" class="data row5 col2" >1,149</td>
#       <td id="T_44be4_row5_col3" class="data row5 col3" >-0.25</td>
#       <td id="T_44be4_row5_col4" class="data row5 col4" >-0.65</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row6" class="row_heading level0 row6" >95</th>
#       <td id="T_44be4_row6_col0" class="data row6 col0" >IVL</td>
#       <td id="T_44be4_row6_col1" class="data row6 col1" >49.75</td>
#       <td id="T_44be4_row6_col2" class="data row6 col2" >1,007</td>
#       <td id="T_44be4_row6_col3" class="data row6 col3" >0.75</td>
#       <td id="T_44be4_row6_col4" class="data row6 col4" >1.53</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_44be4_row7_col0" class="data row7 col0" >ADVANC</td>
#       <td id="T_44be4_row7_col1" class="data row7 col1" >217.00</td>
#       <td id="T_44be4_row7_col2" class="data row7 col2" >976</td>
#       <td id="T_44be4_row7_col3" class="data row7 col3" >-3.00</td>
#       <td id="T_44be4_row7_col4" class="data row7 col4" >-1.36</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row8" class="row_heading level0 row8" >161</th>
#       <td id="T_44be4_row8_col0" class="data row8 col0" >SCB</td>
#       <td id="T_44be4_row8_col1" class="data row8 col1" >110.50</td>
#       <td id="T_44be4_row8_col2" class="data row8 col2" >965</td>
#       <td id="T_44be4_row8_col3" class="data row8 col3" >-1.00</td>
#       <td id="T_44be4_row8_col4" class="data row8 col4" >-0.90</td>
#     </tr>
#     <tr>
#       <th id="T_44be4_level0_row9" class="row_heading level0 row9" >78</th>
#       <td id="T_44be4_row9_col0" class="data row9 col0" >GULF</td>
#       <td id="T_44be4_row9_col1" class="data row9 col1" >47.75</td>
#       <td id="T_44be4_row9_col2" class="data row9 col2" >949</td>
#       <td id="T_44be4_row9_col3" class="data row9 col3" >-1.00</td>
#       <td id="T_44be4_row9_col4" class="data row9 col4" >-2.05</td>
#     </tr>
#   </tbody>
# </table>
