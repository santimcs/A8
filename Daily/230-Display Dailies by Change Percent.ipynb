# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 1)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d5135_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5135_level0_row0" class="row_heading level0 row0" >197</th>
#       <td id="T_d5135_row0_col0" class="data row0 col0" >TIPCO</td>
#       <td id="T_d5135_row0_col1" class="data row0 col1" >9.85</td>
#       <td id="T_d5135_row0_col2" class="data row0 col2" >451</td>
#       <td id="T_d5135_row0_col3" class="data row0 col3" >0.80</td>
#       <td id="T_d5135_row0_col4" class="data row0 col4" >8.84</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row1" class="row_heading level0 row1" >72</th>
#       <td id="T_d5135_row1_col0" class="data row1 col0" >GC</td>
#       <td id="T_d5135_row1_col1" class="data row1 col1" >5.80</td>
#       <td id="T_d5135_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_d5135_row1_col3" class="data row1 col3" >0.25</td>
#       <td id="T_d5135_row1_col4" class="data row1 col4" >4.50</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row2" class="row_heading level0 row2" >137</th>
#       <td id="T_d5135_row2_col0" class="data row2 col0" >PDG</td>
#       <td id="T_d5135_row2_col1" class="data row2 col1" >3.72</td>
#       <td id="T_d5135_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_d5135_row2_col3" class="data row2 col3" >0.14</td>
#       <td id="T_d5135_row2_col4" class="data row2 col4" >3.91</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row3" class="row_heading level0 row3" >37</th>
#       <td id="T_d5135_row3_col0" class="data row3 col0" >BLA</td>
#       <td id="T_d5135_row3_col1" class="data row3 col1" >40.50</td>
#       <td id="T_d5135_row3_col2" class="data row3 col2" >518</td>
#       <td id="T_d5135_row3_col3" class="data row3 col3" >1.50</td>
#       <td id="T_d5135_row3_col4" class="data row3 col4" >3.85</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row4" class="row_heading level0 row4" >210</th>
#       <td id="T_d5135_row4_col0" class="data row4 col0" >TRUE</td>
#       <td id="T_d5135_row4_col1" class="data row4 col1" >4.56</td>
#       <td id="T_d5135_row4_col2" class="data row4 col2" >2,228</td>
#       <td id="T_d5135_row4_col3" class="data row4 col3" >0.16</td>
#       <td id="T_d5135_row4_col4" class="data row4 col4" >3.64</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row5" class="row_heading level0 row5" >90</th>
#       <td id="T_d5135_row5_col0" class="data row5 col0" >INGRS</td>
#       <td id="T_d5135_row5_col1" class="data row5 col1" >0.69</td>
#       <td id="T_d5135_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_d5135_row5_col3" class="data row5 col3" >0.02</td>
#       <td id="T_d5135_row5_col4" class="data row5 col4" >2.99</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row6" class="row_heading level0 row6" >136</th>
#       <td id="T_d5135_row6_col0" class="data row6 col0" >PCSGH</td>
#       <td id="T_d5135_row6_col1" class="data row6 col1" >5.25</td>
#       <td id="T_d5135_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_d5135_row6_col3" class="data row6 col3" >0.15</td>
#       <td id="T_d5135_row6_col4" class="data row6 col4" >2.94</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row7" class="row_heading level0 row7" >62</th>
#       <td id="T_d5135_row7_col0" class="data row7 col0" >DTAC</td>
#       <td id="T_d5135_row7_col1" class="data row7 col1" >44.25</td>
#       <td id="T_d5135_row7_col2" class="data row7 col2" >642</td>
#       <td id="T_d5135_row7_col3" class="data row7 col3" >1.25</td>
#       <td id="T_d5135_row7_col4" class="data row7 col4" >2.91</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row8" class="row_heading level0 row8" >77</th>
#       <td id="T_d5135_row8_col0" class="data row8 col0" >GRAMMY</td>
#       <td id="T_d5135_row8_col1" class="data row8 col1" >11.40</td>
#       <td id="T_d5135_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_d5135_row8_col3" class="data row8 col3" >0.30</td>
#       <td id="T_d5135_row8_col4" class="data row8 col4" >2.70</td>
#     </tr>
#     <tr>
#       <th id="T_d5135_level0_row9" class="row_heading level0 row9" >64</th>
#       <td id="T_d5135_row9_col0" class="data row9 col0" >EASTW</td>
#       <td id="T_d5135_row9_col1" class="data row9 col1" >6.45</td>
#       <td id="T_d5135_row9_col2" class="data row9 col2" >26</td>
#       <td id="T_d5135_row9_col3" class="data row9 col3" >0.15</td>
#       <td id="T_d5135_row9_col4" class="data row9 col4" >2.38</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_604ca_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_604ca_level0_row0" class="row_heading level0 row0" >70</th>
#       <td id="T_604ca_row0_col0" class="data row0 col0" >FORTH</td>
#       <td id="T_604ca_row0_col1" class="data row0 col1" >45.50</td>
#       <td id="T_604ca_row0_col2" class="data row0 col2" >453</td>
#       <td id="T_604ca_row0_col3" class="data row0 col3" >-3.00</td>
#       <td id="T_604ca_row0_col4" class="data row0 col4" >-6.19</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row1" class="row_heading level0 row1" >113</th>
#       <td id="T_604ca_row1_col0" class="data row1 col0" >LHK</td>
#       <td id="T_604ca_row1_col1" class="data row1 col1" >5.35</td>
#       <td id="T_604ca_row1_col2" class="data row1 col2" >41</td>
#       <td id="T_604ca_row1_col3" class="data row1 col3" >-0.35</td>
#       <td id="T_604ca_row1_col4" class="data row1 col4" >-6.14</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row2" class="row_heading level0 row2" >71</th>
#       <td id="T_604ca_row2_col0" class="data row2 col0" >FSMART</td>
#       <td id="T_604ca_row2_col1" class="data row2 col1" >19.60</td>
#       <td id="T_604ca_row2_col2" class="data row2 col2" >107</td>
#       <td id="T_604ca_row2_col3" class="data row2 col3" >-0.80</td>
#       <td id="T_604ca_row2_col4" class="data row2 col4" >-3.92</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row3" class="row_heading level0 row3" >204</th>
#       <td id="T_604ca_row3_col0" class="data row3 col0" >TOA</td>
#       <td id="T_604ca_row3_col1" class="data row3 col1" >27.75</td>
#       <td id="T_604ca_row3_col2" class="data row3 col2" >32</td>
#       <td id="T_604ca_row3_col3" class="data row3 col3" >-1.00</td>
#       <td id="T_604ca_row3_col4" class="data row3 col4" >-3.48</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row4" class="row_heading level0 row4" >203</th>
#       <td id="T_604ca_row4_col0" class="data row4 col0" >TMW</td>
#       <td id="T_604ca_row4_col1" class="data row4 col1" >35.25</td>
#       <td id="T_604ca_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_604ca_row4_col3" class="data row4 col3" >-1.25</td>
#       <td id="T_604ca_row4_col4" class="data row4 col4" >-3.42</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row5" class="row_heading level0 row5" >224</th>
#       <td id="T_604ca_row5_col0" class="data row5 col0" >VNG</td>
#       <td id="T_604ca_row5_col1" class="data row5 col1" >8.25</td>
#       <td id="T_604ca_row5_col2" class="data row5 col2" >84</td>
#       <td id="T_604ca_row5_col3" class="data row5 col3" >-0.25</td>
#       <td id="T_604ca_row5_col4" class="data row5 col4" >-2.94</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row6" class="row_heading level0 row6" >115</th>
#       <td id="T_604ca_row6_col0" class="data row6 col0" >LPF</td>
#       <td id="T_604ca_row6_col1" class="data row6 col1" >13.50</td>
#       <td id="T_604ca_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_604ca_row6_col3" class="data row6 col3" >-0.40</td>
#       <td id="T_604ca_row6_col4" class="data row6 col4" >-2.88</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row7" class="row_heading level0 row7" >194</th>
#       <td id="T_604ca_row7_col0" class="data row7 col0" >THG</td>
#       <td id="T_604ca_row7_col1" class="data row7 col1" >73.00</td>
#       <td id="T_604ca_row7_col2" class="data row7 col2" >1,785</td>
#       <td id="T_604ca_row7_col3" class="data row7 col3" >-2.00</td>
#       <td id="T_604ca_row7_col4" class="data row7 col4" >-2.67</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row8" class="row_heading level0 row8" >141</th>
#       <td id="T_604ca_row8_col0" class="data row8 col0" >PRM</td>
#       <td id="T_604ca_row8_col1" class="data row8 col1" >6.00</td>
#       <td id="T_604ca_row8_col2" class="data row8 col2" >38</td>
#       <td id="T_604ca_row8_col3" class="data row8 col3" >-0.15</td>
#       <td id="T_604ca_row8_col4" class="data row8 col4" >-2.44</td>
#     </tr>
#     <tr>
#       <th id="T_604ca_level0_row9" class="row_heading level0 row9" >176</th>
#       <td id="T_604ca_row9_col0" class="data row9 col0" >SPCG</td>
#       <td id="T_604ca_row9_col1" class="data row9 col1" >16.70</td>
#       <td id="T_604ca_row9_col2" class="data row9 col2" >12</td>
#       <td id="T_604ca_row9_col3" class="data row9 col3" >-0.40</td>
#       <td id="T_604ca_row9_col4" class="data row9 col4" >-2.34</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b42be_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b42be_level0_row0" class="row_heading level0 row0" >59</th>
#       <td id="T_b42be_row0_col0" class="data row0 col0" >DIF</td>
#       <td id="T_b42be_row0_col1" class="data row0 col1" >13.70</td>
#       <td id="T_b42be_row0_col2" class="data row0 col2" >4,808</td>
#       <td id="T_b42be_row0_col3" class="data row0 col3" >-0.30</td>
#       <td id="T_b42be_row0_col4" class="data row0 col4" >-2.14</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row1" class="row_heading level0 row1" >27</th>
#       <td id="T_b42be_row1_col0" class="data row1 col0" >BDMS</td>
#       <td id="T_b42be_row1_col1" class="data row1 col1" >26.25</td>
#       <td id="T_b42be_row1_col2" class="data row1 col2" >2,297</td>
#       <td id="T_b42be_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_b42be_row1_col4" class="data row1 col4" >1.94</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row2" class="row_heading level0 row2" >210</th>
#       <td id="T_b42be_row2_col0" class="data row2 col0" >TRUE</td>
#       <td id="T_b42be_row2_col1" class="data row2 col1" >4.56</td>
#       <td id="T_b42be_row2_col2" class="data row2 col2" >2,228</td>
#       <td id="T_b42be_row2_col3" class="data row2 col3" >0.16</td>
#       <td id="T_b42be_row2_col4" class="data row2 col4" >3.64</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row3" class="row_heading level0 row3" >147</th>
#       <td id="T_b42be_row3_col0" class="data row3 col0" >PTTEP</td>
#       <td id="T_b42be_row3_col1" class="data row3 col1" >167.50</td>
#       <td id="T_b42be_row3_col2" class="data row3 col2" >2,199</td>
#       <td id="T_b42be_row3_col3" class="data row3 col3" >-2.00</td>
#       <td id="T_b42be_row3_col4" class="data row3 col4" >-1.18</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row4" class="row_heading level0 row4" >146</th>
#       <td id="T_b42be_row4_col0" class="data row4 col0" >PTT</td>
#       <td id="T_b42be_row4_col1" class="data row4 col1" >38.25</td>
#       <td id="T_b42be_row4_col2" class="data row4 col2" >2,004</td>
#       <td id="T_b42be_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_b42be_row4_col4" class="data row4 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row5" class="row_heading level0 row5" >194</th>
#       <td id="T_b42be_row5_col0" class="data row5 col0" >THG</td>
#       <td id="T_b42be_row5_col1" class="data row5 col1" >73.00</td>
#       <td id="T_b42be_row5_col2" class="data row5 col2" >1,785</td>
#       <td id="T_b42be_row5_col3" class="data row5 col3" >-2.00</td>
#       <td id="T_b42be_row5_col4" class="data row5 col4" >-2.67</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row6" class="row_heading level0 row6" >11</th>
#       <td id="T_b42be_row6_col0" class="data row6 col0" >AOT</td>
#       <td id="T_b42be_row6_col1" class="data row6 col1" >69.50</td>
#       <td id="T_b42be_row6_col2" class="data row6 col2" >1,762</td>
#       <td id="T_b42be_row6_col3" class="data row6 col3" >-0.25</td>
#       <td id="T_b42be_row6_col4" class="data row6 col4" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row7" class="row_heading level0 row7" >98</th>
#       <td id="T_b42be_row7_col0" class="data row7 col0" >JMT</td>
#       <td id="T_b42be_row7_col1" class="data row7 col1" >77.75</td>
#       <td id="T_b42be_row7_col2" class="data row7 col2" >1,164</td>
#       <td id="T_b42be_row7_col3" class="data row7 col3" >0.25</td>
#       <td id="T_b42be_row7_col4" class="data row7 col4" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row8" class="row_heading level0 row8" >42</th>
#       <td id="T_b42be_row8_col0" class="data row8 col0" >CBG</td>
#       <td id="T_b42be_row8_col1" class="data row8 col1" >110.00</td>
#       <td id="T_b42be_row8_col2" class="data row8 col2" >1,127</td>
#       <td id="T_b42be_row8_col3" class="data row8 col3" >-0.50</td>
#       <td id="T_b42be_row8_col4" class="data row8 col4" >-0.45</td>
#     </tr>
#     <tr>
#       <th id="T_b42be_level0_row9" class="row_heading level0 row9" >76</th>
#       <td id="T_b42be_row9_col0" class="data row9 col0" >GPSC</td>
#       <td id="T_b42be_row9_col1" class="data row9 col1" >68.00</td>
#       <td id="T_b42be_row9_col2" class="data row9 col2" >1,051</td>
#       <td id="T_b42be_row9_col3" class="data row9 col3" >1.25</td>
#       <td id="T_b42be_row9_col4" class="data row9 col4" >1.87</td>
#     </tr>
#   </tbody>
# </table>
