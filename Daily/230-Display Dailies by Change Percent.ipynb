# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 10, 7)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b73b6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b73b6_level0_row0" class="row_heading level0 row0" >85</th>
#       <td id="T_b73b6_row0_col0" class="data row0 col0" >ICHI</td>
#       <td id="T_b73b6_row0_col1" class="data row0 col1" >9.30</td>
#       <td id="T_b73b6_row0_col2" class="data row0 col2" >113</td>
#       <td id="T_b73b6_row0_col3" class="data row0 col3" >0.55</td>
#       <td id="T_b73b6_row0_col4" class="data row0 col4" >6.29</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row1" class="row_heading level0 row1" >104</th>
#       <td id="T_b73b6_row1_col0" class="data row1 col0" >KSL</td>
#       <td id="T_b73b6_row1_col1" class="data row1 col1" >3.92</td>
#       <td id="T_b73b6_row1_col2" class="data row1 col2" >31</td>
#       <td id="T_b73b6_row1_col3" class="data row1 col3" >0.18</td>
#       <td id="T_b73b6_row1_col4" class="data row1 col4" >4.81</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row2" class="row_heading level0 row2" >228</th>
#       <td id="T_b73b6_row2_col0" class="data row2 col0" >WHAUP</td>
#       <td id="T_b73b6_row2_col1" class="data row2 col1" >4.02</td>
#       <td id="T_b73b6_row2_col2" class="data row2 col2" >12</td>
#       <td id="T_b73b6_row2_col3" class="data row2 col3" >0.16</td>
#       <td id="T_b73b6_row2_col4" class="data row2 col4" >4.15</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row3" class="row_heading level0 row3" >47</th>
#       <td id="T_b73b6_row3_col0" class="data row3 col0" >COTTO</td>
#       <td id="T_b73b6_row3_col1" class="data row3 col1" >2.16</td>
#       <td id="T_b73b6_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_b73b6_row3_col3" class="data row3 col3" >0.08</td>
#       <td id="T_b73b6_row3_col4" class="data row3 col4" >3.85</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_b73b6_row4_col0" class="data row4 col0" >NER</td>
#       <td id="T_b73b6_row4_col1" class="data row4 col1" >5.65</td>
#       <td id="T_b73b6_row4_col2" class="data row4 col2" >73</td>
#       <td id="T_b73b6_row4_col3" class="data row4 col3" >0.15</td>
#       <td id="T_b73b6_row4_col4" class="data row4 col4" >2.73</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row5" class="row_heading level0 row5" >131</th>
#       <td id="T_b73b6_row5_col0" class="data row5 col0" >ONEE</td>
#       <td id="T_b73b6_row5_col1" class="data row5 col1" >10.00</td>
#       <td id="T_b73b6_row5_col2" class="data row5 col2" >73</td>
#       <td id="T_b73b6_row5_col3" class="data row5 col3" >0.25</td>
#       <td id="T_b73b6_row5_col4" class="data row5 col4" >2.56</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row6" class="row_heading level0 row6" >42</th>
#       <td id="T_b73b6_row6_col0" class="data row6 col0" >CENTEL</td>
#       <td id="T_b73b6_row6_col1" class="data row6 col1" >50.50</td>
#       <td id="T_b73b6_row6_col2" class="data row6 col2" >111</td>
#       <td id="T_b73b6_row6_col3" class="data row6 col3" >1.00</td>
#       <td id="T_b73b6_row6_col4" class="data row6 col4" >2.02</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row7" class="row_heading level0 row7" >194</th>
#       <td id="T_b73b6_row7_col0" class="data row7 col0" >THG</td>
#       <td id="T_b73b6_row7_col1" class="data row7 col1" >67.50</td>
#       <td id="T_b73b6_row7_col2" class="data row7 col2" >482</td>
#       <td id="T_b73b6_row7_col3" class="data row7 col3" >1.25</td>
#       <td id="T_b73b6_row7_col4" class="data row7 col4" >1.89</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row8" class="row_heading level0 row8" >77</th>
#       <td id="T_b73b6_row8_col0" class="data row8 col0" >GRAMMY</td>
#       <td id="T_b73b6_row8_col1" class="data row8 col1" >11.20</td>
#       <td id="T_b73b6_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_b73b6_row8_col3" class="data row8 col3" >0.20</td>
#       <td id="T_b73b6_row8_col4" class="data row8 col4" >1.82</td>
#     </tr>
#     <tr>
#       <th id="T_b73b6_level0_row9" class="row_heading level0 row9" >225</th>
#       <td id="T_b73b6_row9_col0" class="data row9 col0" >WHA</td>
#       <td id="T_b73b6_row9_col1" class="data row9 col1" >3.56</td>
#       <td id="T_b73b6_row9_col2" class="data row9 col2" >87</td>
#       <td id="T_b73b6_row9_col3" class="data row9 col3" >0.06</td>
#       <td id="T_b73b6_row9_col4" class="data row9 col4" >1.71</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3fd6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fd6d_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_3fd6d_row0_col0" class="data row0 col0" >AIE</td>
#       <td id="T_3fd6d_row0_col1" class="data row0 col1" >3.58</td>
#       <td id="T_3fd6d_row0_col2" class="data row0 col2" >518</td>
#       <td id="T_3fd6d_row0_col3" class="data row0 col3" >-0.84</td>
#       <td id="T_3fd6d_row0_col4" class="data row0 col4" >-19.00</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row1" class="row_heading level0 row1" >57</th>
#       <td id="T_3fd6d_row1_col0" class="data row1 col0" >DELTA</td>
#       <td id="T_3fd6d_row1_col1" class="data row1 col1" >658.00</td>
#       <td id="T_3fd6d_row1_col2" class="data row1 col2" >3,549</td>
#       <td id="T_3fd6d_row1_col3" class="data row1 col3" >-42.00</td>
#       <td id="T_3fd6d_row1_col4" class="data row1 col4" >-6.00</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_3fd6d_row2_col0" class="data row2 col0" >ANAN</td>
#       <td id="T_3fd6d_row2_col1" class="data row2 col1" >1.43</td>
#       <td id="T_3fd6d_row2_col2" class="data row2 col2" >128</td>
#       <td id="T_3fd6d_row2_col3" class="data row2 col3" >-0.09</td>
#       <td id="T_3fd6d_row2_col4" class="data row2 col4" >-5.92</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row3" class="row_heading level0 row3" >216</th>
#       <td id="T_3fd6d_row3_col0" class="data row3 col0" >TTW</td>
#       <td id="T_3fd6d_row3_col1" class="data row3 col1" >9.05</td>
#       <td id="T_3fd6d_row3_col2" class="data row3 col2" >253</td>
#       <td id="T_3fd6d_row3_col3" class="data row3 col3" >-0.50</td>
#       <td id="T_3fd6d_row3_col4" class="data row3 col4" >-5.24</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row4" class="row_heading level0 row4" >169</th>
#       <td id="T_3fd6d_row4_col0" class="data row4 col0" >SIS</td>
#       <td id="T_3fd6d_row4_col1" class="data row4 col1" >25.00</td>
#       <td id="T_3fd6d_row4_col2" class="data row4 col2" >16</td>
#       <td id="T_3fd6d_row4_col3" class="data row4 col3" >-1.25</td>
#       <td id="T_3fd6d_row4_col4" class="data row4 col4" >-4.76</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row5" class="row_heading level0 row5" >89</th>
#       <td id="T_3fd6d_row5_col0" class="data row5 col0" >INGRS</td>
#       <td id="T_3fd6d_row5_col1" class="data row5 col1" >0.69</td>
#       <td id="T_3fd6d_row5_col2" class="data row5 col2" >9</td>
#       <td id="T_3fd6d_row5_col3" class="data row5 col3" >-0.03</td>
#       <td id="T_3fd6d_row5_col4" class="data row5 col4" >-4.17</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row6" class="row_heading level0 row6" >87</th>
#       <td id="T_3fd6d_row6_col0" class="data row6 col0" >IMH</td>
#       <td id="T_3fd6d_row6_col1" class="data row6 col1" >11.70</td>
#       <td id="T_3fd6d_row6_col2" class="data row6 col2" >8</td>
#       <td id="T_3fd6d_row6_col3" class="data row6 col3" >-0.50</td>
#       <td id="T_3fd6d_row6_col4" class="data row6 col4" >-4.10</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row7" class="row_heading level0 row7" >208</th>
#       <td id="T_3fd6d_row7_col0" class="data row7 col0" >TQM</td>
#       <td id="T_3fd6d_row7_col1" class="data row7 col1" >35.50</td>
#       <td id="T_3fd6d_row7_col2" class="data row7 col2" >130</td>
#       <td id="T_3fd6d_row7_col3" class="data row7 col3" >-1.50</td>
#       <td id="T_3fd6d_row7_col4" class="data row7 col4" >-4.05</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row8" class="row_heading level0 row8" >81</th>
#       <td id="T_3fd6d_row8_col0" class="data row8 col0" >HANA</td>
#       <td id="T_3fd6d_row8_col1" class="data row8 col1" >37.75</td>
#       <td id="T_3fd6d_row8_col2" class="data row8 col2" >294</td>
#       <td id="T_3fd6d_row8_col3" class="data row8 col3" >-1.50</td>
#       <td id="T_3fd6d_row8_col4" class="data row8 col4" >-3.82</td>
#     </tr>
#     <tr>
#       <th id="T_3fd6d_level0_row9" class="row_heading level0 row9" >195</th>
#       <td id="T_3fd6d_row9_col0" class="data row9 col0" >TIDLOR</td>
#       <td id="T_3fd6d_row9_col1" class="data row9 col1" >26.25</td>
#       <td id="T_3fd6d_row9_col2" class="data row9 col2" >280</td>
#       <td id="T_3fd6d_row9_col3" class="data row9 col3" >-1.00</td>
#       <td id="T_3fd6d_row9_col4" class="data row9 col4" >-3.67</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a79f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a79f_level0_row0" class="row_heading level0 row0" >57</th>
#       <td id="T_7a79f_row0_col0" class="data row0 col0" >DELTA</td>
#       <td id="T_7a79f_row0_col1" class="data row0 col1" >658.00</td>
#       <td id="T_7a79f_row0_col2" class="data row0 col2" >3,549</td>
#       <td id="T_7a79f_row0_col3" class="data row0 col3" >-42.00</td>
#       <td id="T_7a79f_row0_col4" class="data row0 col4" >-6.00</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row1" class="row_heading level0 row1" >147</th>
#       <td id="T_7a79f_row1_col0" class="data row1 col0" >PTTEP</td>
#       <td id="T_7a79f_row1_col1" class="data row1 col1" >170.00</td>
#       <td id="T_7a79f_row1_col2" class="data row1 col2" >2,061</td>
#       <td id="T_7a79f_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_7a79f_row1_col4" class="data row1 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row2" class="row_heading level0 row2" >146</th>
#       <td id="T_7a79f_row2_col0" class="data row2 col0" >PTT</td>
#       <td id="T_7a79f_row2_col1" class="data row2 col1" >34.50</td>
#       <td id="T_7a79f_row2_col2" class="data row2 col2" >2,021</td>
#       <td id="T_7a79f_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_7a79f_row2_col4" class="data row2 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_7a79f_row3_col0" class="data row3 col0" >BANPU</td>
#       <td id="T_7a79f_row3_col1" class="data row3 col1" >12.30</td>
#       <td id="T_7a79f_row3_col2" class="data row3 col2" >1,376</td>
#       <td id="T_7a79f_row3_col3" class="data row3 col3" >-0.40</td>
#       <td id="T_7a79f_row3_col4" class="data row3 col4" >-3.15</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row4" class="row_heading level0 row4" >26</th>
#       <td id="T_7a79f_row4_col0" class="data row4 col0" >BDMS</td>
#       <td id="T_7a79f_row4_col1" class="data row4 col1" >29.50</td>
#       <td id="T_7a79f_row4_col2" class="data row4 col2" >1,167</td>
#       <td id="T_7a79f_row4_col3" class="data row4 col3" >0.25</td>
#       <td id="T_7a79f_row4_col4" class="data row4 col4" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row5" class="row_heading level0 row5" >41</th>
#       <td id="T_7a79f_row5_col0" class="data row5 col0" >CBG</td>
#       <td id="T_7a79f_row5_col1" class="data row5 col1" >82.00</td>
#       <td id="T_7a79f_row5_col2" class="data row5 col2" >1,035</td>
#       <td id="T_7a79f_row5_col3" class="data row5 col3" >-0.25</td>
#       <td id="T_7a79f_row5_col4" class="data row5 col4" >-0.30</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row6" class="row_heading level0 row6" >99</th>
#       <td id="T_7a79f_row6_col0" class="data row6 col0" >KBANK</td>
#       <td id="T_7a79f_row6_col1" class="data row6 col1" >143.00</td>
#       <td id="T_7a79f_row6_col2" class="data row6 col2" >970</td>
#       <td id="T_7a79f_row6_col3" class="data row6 col3" >0.50</td>
#       <td id="T_7a79f_row6_col4" class="data row6 col4" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row7" class="row_heading level0 row7" >164</th>
#       <td id="T_7a79f_row7_col0" class="data row7 col0" >SCGP</td>
#       <td id="T_7a79f_row7_col1" class="data row7 col1" >52.50</td>
#       <td id="T_7a79f_row7_col2" class="data row7 col2" >921</td>
#       <td id="T_7a79f_row7_col3" class="data row7 col3" >-1.75</td>
#       <td id="T_7a79f_row7_col4" class="data row7 col4" >-3.23</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_7a79f_row8_col0" class="data row8 col0" >AOT</td>
#       <td id="T_7a79f_row8_col1" class="data row8 col1" >73.00</td>
#       <td id="T_7a79f_row8_col2" class="data row8 col2" >900</td>
#       <td id="T_7a79f_row8_col3" class="data row8 col3" >0.50</td>
#       <td id="T_7a79f_row8_col4" class="data row8 col4" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_7a79f_level0_row9" class="row_heading level0 row9" >162</th>
#       <td id="T_7a79f_row9_col0" class="data row9 col0" >SCC</td>
#       <td id="T_7a79f_row9_col1" class="data row9 col1" >318.00</td>
#       <td id="T_7a79f_row9_col2" class="data row9 col2" >790</td>
#       <td id="T_7a79f_row9_col3" class="data row9 col3" >-3.00</td>
#       <td id="T_7a79f_row9_col4" class="data row9 col4" >-0.93</td>
#     </tr>
#   </tbody>
# </table>
