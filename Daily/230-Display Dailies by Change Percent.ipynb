# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 8, 18)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5513_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5513_level0_row0" class="row_heading level0 row0" >208</th>
#       <td id="T_f5513_row0_col0" class="data row0 col0" >TR</td>
#       <td id="T_f5513_row0_col1" class="data row0 col1" >50.25</td>
#       <td id="T_f5513_row0_col2" class="data row0 col2" >28</td>
#       <td id="T_f5513_row0_col3" class="data row0 col3" >3.25</td>
#       <td id="T_f5513_row0_col4" class="data row0 col4" >6.91</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row1" class="row_heading level0 row1" >25</th>
#       <td id="T_f5513_row1_col0" class="data row1 col0" >BCT</td>
#       <td id="T_f5513_row1_col1" class="data row1 col1" >59.00</td>
#       <td id="T_f5513_row1_col2" class="data row1 col2" >39</td>
#       <td id="T_f5513_row1_col3" class="data row1 col3" >3.75</td>
#       <td id="T_f5513_row1_col4" class="data row1 col4" >6.79</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f5513_row2_col0" class="data row2 col0" >AH</td>
#       <td id="T_f5513_row2_col1" class="data row2 col1" >24.50</td>
#       <td id="T_f5513_row2_col2" class="data row2 col2" >139</td>
#       <td id="T_f5513_row2_col3" class="data row2 col3" >1.50</td>
#       <td id="T_f5513_row2_col4" class="data row2 col4" >6.52</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row3" class="row_heading level0 row3" >85</th>
#       <td id="T_f5513_row3_col0" class="data row3 col0" >HTC</td>
#       <td id="T_f5513_row3_col1" class="data row3 col1" >31.00</td>
#       <td id="T_f5513_row3_col2" class="data row3 col2" >19</td>
#       <td id="T_f5513_row3_col3" class="data row3 col3" >1.25</td>
#       <td id="T_f5513_row3_col4" class="data row3 col4" >4.20</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row4" class="row_heading level0 row4" >158</th>
#       <td id="T_f5513_row4_col0" class="data row4 col0" >SAPPE</td>
#       <td id="T_f5513_row4_col1" class="data row4 col1" >39.00</td>
#       <td id="T_f5513_row4_col2" class="data row4 col2" >135</td>
#       <td id="T_f5513_row4_col3" class="data row4 col3" >1.50</td>
#       <td id="T_f5513_row4_col4" class="data row4 col4" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row5" class="row_heading level0 row5" >172</th>
#       <td id="T_f5513_row5_col0" class="data row5 col0" >SKR</td>
#       <td id="T_f5513_row5_col1" class="data row5 col1" >13.00</td>
#       <td id="T_f5513_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_f5513_row5_col3" class="data row5 col3" >0.50</td>
#       <td id="T_f5513_row5_col4" class="data row5 col4" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row6" class="row_heading level0 row6" >224</th>
#       <td id="T_f5513_row6_col0" class="data row6 col0" >WHA</td>
#       <td id="T_f5513_row6_col1" class="data row6 col1" >3.26</td>
#       <td id="T_f5513_row6_col2" class="data row6 col2" >419</td>
#       <td id="T_f5513_row6_col3" class="data row6 col3" >0.12</td>
#       <td id="T_f5513_row6_col4" class="data row6 col4" >3.82</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row7" class="row_heading level0 row7" >60</th>
#       <td id="T_f5513_row7_col0" class="data row7 col0" >DOHOME</td>
#       <td id="T_f5513_row7_col1" class="data row7 col1" >16.50</td>
#       <td id="T_f5513_row7_col2" class="data row7 col2" >210</td>
#       <td id="T_f5513_row7_col3" class="data row7 col3" >0.60</td>
#       <td id="T_f5513_row7_col4" class="data row7 col4" >3.77</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_f5513_row8_col0" class="data row8 col0" >BEC</td>
#       <td id="T_f5513_row8_col1" class="data row8 col1" >12.90</td>
#       <td id="T_f5513_row8_col2" class="data row8 col2" >112</td>
#       <td id="T_f5513_row8_col3" class="data row8 col3" >0.40</td>
#       <td id="T_f5513_row8_col4" class="data row8 col4" >3.20</td>
#     </tr>
#     <tr>
#       <th id="T_f5513_level0_row9" class="row_heading level0 row9" >228</th>
#       <td id="T_f5513_row9_col0" class="data row9 col0" >WICE</td>
#       <td id="T_f5513_row9_col1" class="data row9 col1" >13.50</td>
#       <td id="T_f5513_row9_col2" class="data row9 col2" >183</td>
#       <td id="T_f5513_row9_col3" class="data row9 col3" >0.40</td>
#       <td id="T_f5513_row9_col4" class="data row9 col4" >3.05</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba29d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba29d_level0_row0" class="row_heading level0 row0" >153</th>
#       <td id="T_ba29d_row0_col0" class="data row0 col0" >RCL</td>
#       <td id="T_ba29d_row0_col1" class="data row0 col1" >35.25</td>
#       <td id="T_ba29d_row0_col2" class="data row0 col2" >312</td>
#       <td id="T_ba29d_row0_col3" class="data row0 col3" >-2.75</td>
#       <td id="T_ba29d_row0_col4" class="data row0 col4" >-7.24</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row1" class="row_heading level0 row1" >174</th>
#       <td id="T_ba29d_row1_col0" class="data row1 col0" >SNC</td>
#       <td id="T_ba29d_row1_col1" class="data row1 col1" >17.50</td>
#       <td id="T_ba29d_row1_col2" class="data row1 col2" >18</td>
#       <td id="T_ba29d_row1_col3" class="data row1 col3" >-0.70</td>
#       <td id="T_ba29d_row1_col4" class="data row1 col4" >-3.85</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row2" class="row_heading level0 row2" >34</th>
#       <td id="T_ba29d_row2_col0" class="data row2 col0" >BH</td>
#       <td id="T_ba29d_row2_col1" class="data row2 col1" >186.50</td>
#       <td id="T_ba29d_row2_col2" class="data row2 col2" >19,017</td>
#       <td id="T_ba29d_row2_col3" class="data row2 col3" >-7.00</td>
#       <td id="T_ba29d_row2_col4" class="data row2 col4" >-3.62</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row3" class="row_heading level0 row3" >44</th>
#       <td id="T_ba29d_row3_col0" class="data row3 col0" >CHG</td>
#       <td id="T_ba29d_row3_col1" class="data row3 col1" >3.76</td>
#       <td id="T_ba29d_row3_col2" class="data row3 col2" >309</td>
#       <td id="T_ba29d_row3_col3" class="data row3 col3" >-0.12</td>
#       <td id="T_ba29d_row3_col4" class="data row3 col4" >-3.09</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row4" class="row_heading level0 row4" >78</th>
#       <td id="T_ba29d_row4_col0" class="data row4 col0" >GRAMMY</td>
#       <td id="T_ba29d_row4_col1" class="data row4 col1" >10.70</td>
#       <td id="T_ba29d_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_ba29d_row4_col3" class="data row4 col3" >-0.30</td>
#       <td id="T_ba29d_row4_col4" class="data row4 col4" >-2.73</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row5" class="row_heading level0 row5" >120</th>
#       <td id="T_ba29d_row5_col0" class="data row5 col0" >MAJOR</td>
#       <td id="T_ba29d_row5_col1" class="data row5 col1" >19.60</td>
#       <td id="T_ba29d_row5_col2" class="data row5 col2" >101</td>
#       <td id="T_ba29d_row5_col3" class="data row5 col3" >-0.50</td>
#       <td id="T_ba29d_row5_col4" class="data row5 col4" >-2.49</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row6" class="row_heading level0 row6" >42</th>
#       <td id="T_ba29d_row6_col0" class="data row6 col0" >CBG</td>
#       <td id="T_ba29d_row6_col1" class="data row6 col1" >109.00</td>
#       <td id="T_ba29d_row6_col2" class="data row6 col2" >774</td>
#       <td id="T_ba29d_row6_col3" class="data row6 col3" >-2.50</td>
#       <td id="T_ba29d_row6_col4" class="data row6 col4" >-2.24</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row7" class="row_heading level0 row7" >139</th>
#       <td id="T_ba29d_row7_col0" class="data row7 col0" >PLANB</td>
#       <td id="T_ba29d_row7_col1" class="data row7 col1" >6.65</td>
#       <td id="T_ba29d_row7_col2" class="data row7 col2" >79</td>
#       <td id="T_ba29d_row7_col3" class="data row7 col3" >-0.15</td>
#       <td id="T_ba29d_row7_col4" class="data row7 col4" >-2.21</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row8" class="row_heading level0 row8" >22</th>
#       <td id="T_ba29d_row8_col0" class="data row8 col0" >BCH</td>
#       <td id="T_ba29d_row8_col1" class="data row8 col1" >19.80</td>
#       <td id="T_ba29d_row8_col2" class="data row8 col2" >509</td>
#       <td id="T_ba29d_row8_col3" class="data row8 col3" >-0.40</td>
#       <td id="T_ba29d_row8_col4" class="data row8 col4" >-1.98</td>
#     </tr>
#     <tr>
#       <th id="T_ba29d_level0_row9" class="row_heading level0 row9" >38</th>
#       <td id="T_ba29d_row9_col0" class="data row9 col0" >BLAND</td>
#       <td id="T_ba29d_row9_col1" class="data row9 col1" >1.00</td>
#       <td id="T_ba29d_row9_col2" class="data row9 col2" >63</td>
#       <td id="T_ba29d_row9_col3" class="data row9 col3" >-0.02</td>
#       <td id="T_ba29d_row9_col4" class="data row9 col4" >-1.96</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_af9e3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af9e3_level0_row0" class="row_heading level0 row0" >34</th>
#       <td id="T_af9e3_row0_col0" class="data row0 col0" >BH</td>
#       <td id="T_af9e3_row0_col1" class="data row0 col1" >186.50</td>
#       <td id="T_af9e3_row0_col2" class="data row0 col2" >19,017</td>
#       <td id="T_af9e3_row0_col3" class="data row0 col3" >-7.00</td>
#       <td id="T_af9e3_row0_col4" class="data row0 col4" >-3.62</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row1" class="row_heading level0 row1" >26</th>
#       <td id="T_af9e3_row1_col0" class="data row1 col0" >BDMS</td>
#       <td id="T_af9e3_row1_col1" class="data row1 col1" >27.25</td>
#       <td id="T_af9e3_row1_col2" class="data row1 col2" >3,447</td>
#       <td id="T_af9e3_row1_col3" class="data row1 col3" >-0.50</td>
#       <td id="T_af9e3_row1_col4" class="data row1 col4" >-1.80</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_af9e3_row2_col0" class="data row2 col0" >BANPU</td>
#       <td id="T_af9e3_row2_col1" class="data row2 col1" >13.90</td>
#       <td id="T_af9e3_row2_col2" class="data row2 col2" >3,245</td>
#       <td id="T_af9e3_row2_col3" class="data row2 col3" >-0.10</td>
#       <td id="T_af9e3_row2_col4" class="data row2 col4" >-0.71</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row3" class="row_heading level0 row3" >100</th>
#       <td id="T_af9e3_row3_col0" class="data row3 col0" >KBANK</td>
#       <td id="T_af9e3_row3_col1" class="data row3 col1" >154.00</td>
#       <td id="T_af9e3_row3_col2" class="data row3 col2" >2,375</td>
#       <td id="T_af9e3_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_af9e3_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row4" class="row_heading level0 row4" >147</th>
#       <td id="T_af9e3_row4_col0" class="data row4 col0" >PTT</td>
#       <td id="T_af9e3_row4_col1" class="data row4 col1" >37.25</td>
#       <td id="T_af9e3_row4_col2" class="data row4 col2" >1,701</td>
#       <td id="T_af9e3_row4_col3" class="data row4 col3" >-0.50</td>
#       <td id="T_af9e3_row4_col4" class="data row4 col4" >-1.32</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row5" class="row_heading level0 row5" >204</th>
#       <td id="T_af9e3_row5_col0" class="data row5 col0" >TOP</td>
#       <td id="T_af9e3_row5_col1" class="data row5 col1" >57.00</td>
#       <td id="T_af9e3_row5_col2" class="data row5 col2" >1,587</td>
#       <td id="T_af9e3_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_af9e3_row5_col4" class="data row5 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_af9e3_row6_col0" class="data row6 col0" >AOT</td>
#       <td id="T_af9e3_row6_col1" class="data row6 col1" >72.00</td>
#       <td id="T_af9e3_row6_col2" class="data row6 col2" >1,391</td>
#       <td id="T_af9e3_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_af9e3_row6_col4" class="data row6 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row7" class="row_heading level0 row7" >58</th>
#       <td id="T_af9e3_row7_col0" class="data row7 col0" >DELTA</td>
#       <td id="T_af9e3_row7_col1" class="data row7 col1" >576.00</td>
#       <td id="T_af9e3_row7_col2" class="data row7 col2" >1,343</td>
#       <td id="T_af9e3_row7_col3" class="data row7 col3" >-10.00</td>
#       <td id="T_af9e3_row7_col4" class="data row7 col4" >-1.71</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row8" class="row_heading level0 row8" >148</th>
#       <td id="T_af9e3_row8_col0" class="data row8 col0" >PTTEP</td>
#       <td id="T_af9e3_row8_col1" class="data row8 col1" >155.00</td>
#       <td id="T_af9e3_row8_col2" class="data row8 col2" >1,267</td>
#       <td id="T_af9e3_row8_col3" class="data row8 col3" >0.00</td>
#       <td id="T_af9e3_row8_col4" class="data row8 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_af9e3_level0_row9" class="row_heading level0 row9" >49</th>
#       <td id="T_af9e3_row9_col0" class="data row9 col0" >CPALL</td>
#       <td id="T_af9e3_row9_col1" class="data row9 col1" >61.00</td>
#       <td id="T_af9e3_row9_col2" class="data row9 col2" >1,069</td>
#       <td id="T_af9e3_row9_col3" class="data row9 col3" >0.25</td>
#       <td id="T_af9e3_row9_col4" class="data row9 col4" >0.41</td>
#     </tr>
#   </tbody>
# </table>
