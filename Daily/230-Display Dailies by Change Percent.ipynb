# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 8, 29)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8767_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8767_level0_row0" class="row_heading level0 row0" >78</th>
#       <td id="T_a8767_row0_col0" class="data row0 col0" >GRAMMY</td>
#       <td id="T_a8767_row0_col1" class="data row0 col1" >11.30</td>
#       <td id="T_a8767_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a8767_row0_col3" class="data row0 col3" >0.50</td>
#       <td id="T_a8767_row0_col4" class="data row0 col4" >4.63</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row1" class="row_heading level0 row1" >193</th>
#       <td id="T_a8767_row1_col0" class="data row1 col0" >TFG</td>
#       <td id="T_a8767_row1_col1" class="data row1 col1" >6.30</td>
#       <td id="T_a8767_row1_col2" class="data row1 col2" >67</td>
#       <td id="T_a8767_row1_col3" class="data row1 col3" >0.25</td>
#       <td id="T_a8767_row1_col4" class="data row1 col4" >4.13</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row2" class="row_heading level0 row2" >110</th>
#       <td id="T_a8767_row2_col0" class="data row2 col0" >LANNA</td>
#       <td id="T_a8767_row2_col1" class="data row2 col1" >24.40</td>
#       <td id="T_a8767_row2_col2" class="data row2 col2" >344</td>
#       <td id="T_a8767_row2_col3" class="data row2 col3" >0.70</td>
#       <td id="T_a8767_row2_col4" class="data row2 col4" >2.95</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row3" class="row_heading level0 row3" >148</th>
#       <td id="T_a8767_row3_col0" class="data row3 col0" >PTTEP</td>
#       <td id="T_a8767_row3_col1" class="data row3 col1" >172.00</td>
#       <td id="T_a8767_row3_col2" class="data row3 col2" >2,980</td>
#       <td id="T_a8767_row3_col3" class="data row3 col3" >4.50</td>
#       <td id="T_a8767_row3_col4" class="data row3 col4" >2.69</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row4" class="row_heading level0 row4" >37</th>
#       <td id="T_a8767_row4_col0" class="data row4 col0" >BLA</td>
#       <td id="T_a8767_row4_col1" class="data row4 col1" >36.25</td>
#       <td id="T_a8767_row4_col2" class="data row4 col2" >1,209</td>
#       <td id="T_a8767_row4_col3" class="data row4 col3" >0.75</td>
#       <td id="T_a8767_row4_col4" class="data row4 col4" >2.11</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row5" class="row_heading level0 row5" >74</th>
#       <td id="T_a8767_row5_col0" class="data row5 col0" >GFPT</td>
#       <td id="T_a8767_row5_col1" class="data row5 col1" >15.70</td>
#       <td id="T_a8767_row5_col2" class="data row5 col2" >61</td>
#       <td id="T_a8767_row5_col3" class="data row5 col3" >0.30</td>
#       <td id="T_a8767_row5_col4" class="data row5 col4" >1.95</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row6" class="row_heading level0 row6" >158</th>
#       <td id="T_a8767_row6_col0" class="data row6 col0" >SAPPE</td>
#       <td id="T_a8767_row6_col1" class="data row6 col1" >43.00</td>
#       <td id="T_a8767_row6_col2" class="data row6 col2" >107</td>
#       <td id="T_a8767_row6_col3" class="data row6 col3" >0.75</td>
#       <td id="T_a8767_row6_col4" class="data row6 col4" >1.78</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row7" class="row_heading level0 row7" >142</th>
#       <td id="T_a8767_row7_col0" class="data row7 col0" >PRM</td>
#       <td id="T_a8767_row7_col1" class="data row7 col1" >6.00</td>
#       <td id="T_a8767_row7_col2" class="data row7 col2" >33</td>
#       <td id="T_a8767_row7_col3" class="data row7 col3" >0.10</td>
#       <td id="T_a8767_row7_col4" class="data row7 col4" >1.69</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row8" class="row_heading level0 row8" >224</th>
#       <td id="T_a8767_row8_col0" class="data row8 col0" >VIBHA</td>
#       <td id="T_a8767_row8_col1" class="data row8 col1" >2.66</td>
#       <td id="T_a8767_row8_col2" class="data row8 col2" >41</td>
#       <td id="T_a8767_row8_col3" class="data row8 col3" >0.04</td>
#       <td id="T_a8767_row8_col4" class="data row8 col4" >1.53</td>
#     </tr>
#     <tr>
#       <th id="T_a8767_level0_row9" class="row_heading level0 row9" >80</th>
#       <td id="T_a8767_row9_col0" class="data row9 col0" >GUNKUL</td>
#       <td id="T_a8767_row9_col1" class="data row9 col1" >5.05</td>
#       <td id="T_a8767_row9_col2" class="data row9 col2" >223</td>
#       <td id="T_a8767_row9_col3" class="data row9 col3" >0.07</td>
#       <td id="T_a8767_row9_col4" class="data row9 col4" >1.41</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c9352_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9352_level0_row0" class="row_heading level0 row0" >58</th>
#       <td id="T_c9352_row0_col0" class="data row0 col0" >DELTA</td>
#       <td id="T_c9352_row0_col1" class="data row0 col1" >534.00</td>
#       <td id="T_c9352_row0_col2" class="data row0 col2" >2,045</td>
#       <td id="T_c9352_row0_col3" class="data row0 col3" >-44.00</td>
#       <td id="T_c9352_row0_col4" class="data row0 col4" >-7.61</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row1" class="row_heading level0 row1" >27</th>
#       <td id="T_c9352_row1_col0" class="data row1 col0" >BE8</td>
#       <td id="T_c9352_row1_col1" class="data row1 col1" >56.75</td>
#       <td id="T_c9352_row1_col2" class="data row1 col2" >239</td>
#       <td id="T_c9352_row1_col3" class="data row1 col3" >-3.75</td>
#       <td id="T_c9352_row1_col4" class="data row1 col4" >-6.20</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row2" class="row_heading level0 row2" >196</th>
#       <td id="T_c9352_row2_col0" class="data row2 col0" >TIDLOR</td>
#       <td id="T_c9352_row2_col1" class="data row2 col1" >28.75</td>
#       <td id="T_c9352_row2_col2" class="data row2 col2" >805</td>
#       <td id="T_c9352_row2_col3" class="data row2 col3" >-1.50</td>
#       <td id="T_c9352_row2_col4" class="data row2 col4" >-4.96</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row3" class="row_heading level0 row3" >144</th>
#       <td id="T_c9352_row3_col0" class="data row3 col0" >PSL</td>
#       <td id="T_c9352_row3_col1" class="data row3 col1" >14.70</td>
#       <td id="T_c9352_row3_col2" class="data row3 col2" >283</td>
#       <td id="T_c9352_row3_col3" class="data row3 col3" >-0.70</td>
#       <td id="T_c9352_row3_col4" class="data row3 col4" >-4.55</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row4" class="row_heading level0 row4" >82</th>
#       <td id="T_c9352_row4_col0" class="data row4 col0" >HANA</td>
#       <td id="T_c9352_row4_col1" class="data row4 col1" >43.25</td>
#       <td id="T_c9352_row4_col2" class="data row4 col2" >500</td>
#       <td id="T_c9352_row4_col3" class="data row4 col3" >-1.75</td>
#       <td id="T_c9352_row4_col4" class="data row4 col4" >-3.89</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_c9352_row5_col0" class="data row5 col0" >DOHOME</td>
#       <td id="T_c9352_row5_col1" class="data row5 col1" >15.20</td>
#       <td id="T_c9352_row5_col2" class="data row5 col2" >345</td>
#       <td id="T_c9352_row5_col3" class="data row5 col3" >-0.60</td>
#       <td id="T_c9352_row5_col4" class="data row5 col4" >-3.80</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row6" class="row_heading level0 row6" >109</th>
#       <td id="T_c9352_row6_col0" class="data row6 col0" >LALIN</td>
#       <td id="T_c9352_row6_col1" class="data row6 col1" >8.90</td>
#       <td id="T_c9352_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_c9352_row6_col3" class="data row6 col3" >-0.35</td>
#       <td id="T_c9352_row6_col4" class="data row6 col4" >-3.78</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row7" class="row_heading level0 row7" >153</th>
#       <td id="T_c9352_row7_col0" class="data row7 col0" >RCL</td>
#       <td id="T_c9352_row7_col1" class="data row7 col1" >33.25</td>
#       <td id="T_c9352_row7_col2" class="data row7 col2" >210</td>
#       <td id="T_c9352_row7_col3" class="data row7 col3" >-1.25</td>
#       <td id="T_c9352_row7_col4" class="data row7 col4" >-3.62</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row8" class="row_heading level0 row8" >230</th>
#       <td id="T_c9352_row8_col0" class="data row8 col0" >WICE</td>
#       <td id="T_c9352_row8_col1" class="data row8 col1" >13.40</td>
#       <td id="T_c9352_row8_col2" class="data row8 col2" >148</td>
#       <td id="T_c9352_row8_col3" class="data row8 col3" >-0.50</td>
#       <td id="T_c9352_row8_col4" class="data row8 col4" >-3.60</td>
#     </tr>
#     <tr>
#       <th id="T_c9352_level0_row9" class="row_heading level0 row9" >169</th>
#       <td id="T_c9352_row9_col0" class="data row9 col0" >SIRI</td>
#       <td id="T_c9352_row9_col1" class="data row9 col1" >1.09</td>
#       <td id="T_c9352_row9_col2" class="data row9 col2" >98</td>
#       <td id="T_c9352_row9_col3" class="data row9 col3" >-0.04</td>
#       <td id="T_c9352_row9_col4" class="data row9 col4" >-3.54</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b7846_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7846_level0_row0" class="row_heading level0 row0" >19</th>
#       <td id="T_b7846_row0_col0" class="data row0 col0" >BANPU</td>
#       <td id="T_b7846_row0_col1" class="data row0 col1" >14.80</td>
#       <td id="T_b7846_row0_col2" class="data row0 col2" >4,042</td>
#       <td id="T_b7846_row0_col3" class="data row0 col3" >0.20</td>
#       <td id="T_b7846_row0_col4" class="data row0 col4" >1.37</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row1" class="row_heading level0 row1" >100</th>
#       <td id="T_b7846_row1_col0" class="data row1 col0" >KBANK</td>
#       <td id="T_b7846_row1_col1" class="data row1 col1" >155.00</td>
#       <td id="T_b7846_row1_col2" class="data row1 col2" >3,172</td>
#       <td id="T_b7846_row1_col3" class="data row1 col3" >-2.00</td>
#       <td id="T_b7846_row1_col4" class="data row1 col4" >-1.27</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row2" class="row_heading level0 row2" >148</th>
#       <td id="T_b7846_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_b7846_row2_col1" class="data row2 col1" >172.00</td>
#       <td id="T_b7846_row2_col2" class="data row2 col2" >2,980</td>
#       <td id="T_b7846_row2_col3" class="data row2 col3" >4.50</td>
#       <td id="T_b7846_row2_col4" class="data row2 col4" >2.69</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row3" class="row_heading level0 row3" >147</th>
#       <td id="T_b7846_row3_col0" class="data row3 col0" >PTT</td>
#       <td id="T_b7846_row3_col1" class="data row3 col1" >37.50</td>
#       <td id="T_b7846_row3_col2" class="data row3 col2" >2,426</td>
#       <td id="T_b7846_row3_col3" class="data row3 col3" >-0.50</td>
#       <td id="T_b7846_row3_col4" class="data row3 col4" >-1.32</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row4" class="row_heading level0 row4" >58</th>
#       <td id="T_b7846_row4_col0" class="data row4 col0" >DELTA</td>
#       <td id="T_b7846_row4_col1" class="data row4 col1" >534.00</td>
#       <td id="T_b7846_row4_col2" class="data row4 col2" >2,045</td>
#       <td id="T_b7846_row4_col3" class="data row4 col3" >-44.00</td>
#       <td id="T_b7846_row4_col4" class="data row4 col4" >-7.61</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row5" class="row_heading level0 row5" >162</th>
#       <td id="T_b7846_row5_col0" class="data row5 col0" >SCB</td>
#       <td id="T_b7846_row5_col1" class="data row5 col1" >108.50</td>
#       <td id="T_b7846_row5_col2" class="data row5 col2" >1,992</td>
#       <td id="T_b7846_row5_col3" class="data row5 col3" >-2.00</td>
#       <td id="T_b7846_row5_col4" class="data row5 col4" >-1.81</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_b7846_row6_col0" class="data row6 col0" >AOT</td>
#       <td id="T_b7846_row6_col1" class="data row6 col1" >71.25</td>
#       <td id="T_b7846_row6_col2" class="data row6 col2" >1,953</td>
#       <td id="T_b7846_row6_col3" class="data row6 col3" >-1.00</td>
#       <td id="T_b7846_row6_col4" class="data row6 col4" >-1.38</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row7" class="row_heading level0 row7" >34</th>
#       <td id="T_b7846_row7_col0" class="data row7 col0" >BH</td>
#       <td id="T_b7846_row7_col1" class="data row7 col1" >215.00</td>
#       <td id="T_b7846_row7_col2" class="data row7 col2" >1,887</td>
#       <td id="T_b7846_row7_col3" class="data row7 col3" >-1.00</td>
#       <td id="T_b7846_row7_col4" class="data row7 col4" >-0.46</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row8" class="row_heading level0 row8" >79</th>
#       <td id="T_b7846_row8_col0" class="data row8 col0" >GULF</td>
#       <td id="T_b7846_row8_col1" class="data row8 col1" >50.25</td>
#       <td id="T_b7846_row8_col2" class="data row8 col2" >1,595</td>
#       <td id="T_b7846_row8_col3" class="data row8 col3" >-1.25</td>
#       <td id="T_b7846_row8_col4" class="data row8 col4" >-2.43</td>
#     </tr>
#     <tr>
#       <th id="T_b7846_level0_row9" class="row_heading level0 row9" >126</th>
#       <td id="T_b7846_row9_col0" class="data row9 col0" >MINT</td>
#       <td id="T_b7846_row9_col1" class="data row9 col1" >32.00</td>
#       <td id="T_b7846_row9_col2" class="data row9 col2" >1,380</td>
#       <td id="T_b7846_row9_col3" class="data row9 col3" >-1.00</td>
#       <td id="T_b7846_row9_col4" class="data row9 col4" >-3.03</td>
#     </tr>
#   </tbody>
# </table>
