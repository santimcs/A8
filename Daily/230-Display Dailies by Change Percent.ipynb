# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 8, 4)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c553c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c553c_level0_row0" class="row_heading level0 row0" >71</th>
#       <td id="T_c553c_row0_col0" class="data row0 col0" >FORTH</td>
#       <td id="T_c553c_row0_col1" class="data row0 col1" >49.00</td>
#       <td id="T_c553c_row0_col2" class="data row0 col2" >424</td>
#       <td id="T_c553c_row0_col3" class="data row0 col3" >2.75</td>
#       <td id="T_c553c_row0_col4" class="data row0 col4" >5.95</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row1" class="row_heading level0 row1" >165</th>
#       <td id="T_c553c_row1_col0" class="data row1 col0" >SCGP</td>
#       <td id="T_c553c_row1_col1" class="data row1 col1" >54.75</td>
#       <td id="T_c553c_row1_col2" class="data row1 col2" >1,443</td>
#       <td id="T_c553c_row1_col3" class="data row1 col3" >3.00</td>
#       <td id="T_c553c_row1_col4" class="data row1 col4" >5.80</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row2" class="row_heading level0 row2" >160</th>
#       <td id="T_c553c_row2_col0" class="data row2 col0" >SAWAD</td>
#       <td id="T_c553c_row2_col1" class="data row2 col1" >53.25</td>
#       <td id="T_c553c_row2_col2" class="data row2 col2" >969</td>
#       <td id="T_c553c_row2_col3" class="data row2 col3" >2.50</td>
#       <td id="T_c553c_row2_col4" class="data row2 col4" >4.93</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_c553c_row3_col0" class="data row3 col0" >MTC</td>
#       <td id="T_c553c_row3_col1" class="data row3 col1" >50.75</td>
#       <td id="T_c553c_row3_col2" class="data row3 col2" >1,152</td>
#       <td id="T_c553c_row3_col3" class="data row3 col3" >2.00</td>
#       <td id="T_c553c_row3_col4" class="data row3 col4" >4.10</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row4" class="row_heading level0 row4" >59</th>
#       <td id="T_c553c_row4_col0" class="data row4 col0" >DELTA</td>
#       <td id="T_c553c_row4_col1" class="data row4 col1" >542.00</td>
#       <td id="T_c553c_row4_col2" class="data row4 col2" >3,234</td>
#       <td id="T_c553c_row4_col3" class="data row4 col3" >20.00</td>
#       <td id="T_c553c_row4_col4" class="data row4 col4" >3.83</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row5" class="row_heading level0 row5" >196</th>
#       <td id="T_c553c_row5_col0" class="data row5 col0" >TIDLOR</td>
#       <td id="T_c553c_row5_col1" class="data row5 col1" >30.00</td>
#       <td id="T_c553c_row5_col2" class="data row5 col2" >717</td>
#       <td id="T_c553c_row5_col3" class="data row5 col3" >1.00</td>
#       <td id="T_c553c_row5_col4" class="data row5 col4" >3.45</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row6" class="row_heading level0 row6" >74</th>
#       <td id="T_c553c_row6_col0" class="data row6 col0" >GFPT</td>
#       <td id="T_c553c_row6_col1" class="data row6 col1" >15.30</td>
#       <td id="T_c553c_row6_col2" class="data row6 col2" >79</td>
#       <td id="T_c553c_row6_col3" class="data row6 col3" >0.50</td>
#       <td id="T_c553c_row6_col4" class="data row6 col4" >3.38</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_c553c_row7_col0" class="data row7 col0" >BE8</td>
#       <td id="T_c553c_row7_col1" class="data row7 col1" >56.00</td>
#       <td id="T_c553c_row7_col2" class="data row7 col2" >236</td>
#       <td id="T_c553c_row7_col3" class="data row7 col3" >1.75</td>
#       <td id="T_c553c_row7_col4" class="data row7 col4" >3.23</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row8" class="row_heading level0 row8" >190</th>
#       <td id="T_c553c_row8_col0" class="data row8 col0" >TASCO</td>
#       <td id="T_c553c_row8_col1" class="data row8 col1" >16.80</td>
#       <td id="T_c553c_row8_col2" class="data row8 col2" >146</td>
#       <td id="T_c553c_row8_col3" class="data row8 col3" >0.50</td>
#       <td id="T_c553c_row8_col4" class="data row8 col4" >3.07</td>
#     </tr>
#     <tr>
#       <th id="T_c553c_level0_row9" class="row_heading level0 row9" >61</th>
#       <td id="T_c553c_row9_col0" class="data row9 col0" >DOHOME</td>
#       <td id="T_c553c_row9_col1" class="data row9 col1" >15.50</td>
#       <td id="T_c553c_row9_col2" class="data row9 col2" >59</td>
#       <td id="T_c553c_row9_col3" class="data row9 col3" >0.40</td>
#       <td id="T_c553c_row9_col4" class="data row9 col4" >2.65</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_232fa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_232fa_level0_row0" class="row_heading level0 row0" >110</th>
#       <td id="T_232fa_row0_col0" class="data row0 col0" >LANNA</td>
#       <td id="T_232fa_row0_col1" class="data row0 col1" >20.90</td>
#       <td id="T_232fa_row0_col2" class="data row0 col2" >232</td>
#       <td id="T_232fa_row0_col3" class="data row0 col3" >-1.40</td>
#       <td id="T_232fa_row0_col4" class="data row0 col4" >-6.28</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row1" class="row_heading level0 row1" >178</th>
#       <td id="T_232fa_row1_col0" class="data row1 col0" >SPRC</td>
#       <td id="T_232fa_row1_col1" class="data row1 col1" >11.00</td>
#       <td id="T_232fa_row1_col2" class="data row1 col2" >433</td>
#       <td id="T_232fa_row1_col3" class="data row1 col3" >-0.60</td>
#       <td id="T_232fa_row1_col4" class="data row1 col4" >-5.17</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row2" class="row_heading level0 row2" >148</th>
#       <td id="T_232fa_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_232fa_row2_col1" class="data row2 col1" >154.50</td>
#       <td id="T_232fa_row2_col2" class="data row2 col2" >6,477</td>
#       <td id="T_232fa_row2_col3" class="data row2 col3" >-7.00</td>
#       <td id="T_232fa_row2_col4" class="data row2 col4" >-4.33</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row3" class="row_heading level0 row3" >119</th>
#       <td id="T_232fa_row3_col0" class="data row3 col0" >MACO</td>
#       <td id="T_232fa_row3_col1" class="data row3 col1" >0.49</td>
#       <td id="T_232fa_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_232fa_row3_col3" class="data row3 col3" >-0.02</td>
#       <td id="T_232fa_row3_col4" class="data row3 col4" >-3.92</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row4" class="row_heading level0 row4" >20</th>
#       <td id="T_232fa_row4_col0" class="data row4 col0" >BANPU</td>
#       <td id="T_232fa_row4_col1" class="data row4 col1" >12.80</td>
#       <td id="T_232fa_row4_col2" class="data row4 col2" >3,222</td>
#       <td id="T_232fa_row4_col3" class="data row4 col3" >-0.50</td>
#       <td id="T_232fa_row4_col4" class="data row4 col4" >-3.76</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row5" class="row_heading level0 row5" >70</th>
#       <td id="T_232fa_row5_col0" class="data row5 col0" >ESSO</td>
#       <td id="T_232fa_row5_col1" class="data row5 col1" >10.60</td>
#       <td id="T_232fa_row5_col2" class="data row5 col2" >171</td>
#       <td id="T_232fa_row5_col3" class="data row5 col3" >-0.40</td>
#       <td id="T_232fa_row5_col4" class="data row5 col4" >-3.64</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row6" class="row_heading level0 row6" >158</th>
#       <td id="T_232fa_row6_col0" class="data row6 col0" >SAPPE</td>
#       <td id="T_232fa_row6_col1" class="data row6 col1" >37.50</td>
#       <td id="T_232fa_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_232fa_row6_col3" class="data row6 col3" >-1.25</td>
#       <td id="T_232fa_row6_col4" class="data row6 col4" >-3.23</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row7" class="row_heading level0 row7" >132</th>
#       <td id="T_232fa_row7_col0" class="data row7 col0" >ONEE</td>
#       <td id="T_232fa_row7_col1" class="data row7 col1" >9.35</td>
#       <td id="T_232fa_row7_col2" class="data row7 col2" >137</td>
#       <td id="T_232fa_row7_col3" class="data row7 col3" >-0.30</td>
#       <td id="T_232fa_row7_col4" class="data row7 col4" >-3.11</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row8" class="row_heading level0 row8" >23</th>
#       <td id="T_232fa_row8_col0" class="data row8 col0" >BCH</td>
#       <td id="T_232fa_row8_col1" class="data row8 col1" >20.20</td>
#       <td id="T_232fa_row8_col2" class="data row8 col2" >453</td>
#       <td id="T_232fa_row8_col3" class="data row8 col3" >-0.60</td>
#       <td id="T_232fa_row8_col4" class="data row8 col4" >-2.88</td>
#     </tr>
#     <tr>
#       <th id="T_232fa_level0_row9" class="row_heading level0 row9" >24</th>
#       <td id="T_232fa_row9_col0" class="data row9 col0" >BCP</td>
#       <td id="T_232fa_row9_col1" class="data row9 col1" >29.50</td>
#       <td id="T_232fa_row9_col2" class="data row9 col2" >376</td>
#       <td id="T_232fa_row9_col3" class="data row9 col3" >-0.75</td>
#       <td id="T_232fa_row9_col4" class="data row9 col4" >-2.48</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_694a8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_694a8_level0_row0" class="row_heading level0 row0" >148</th>
#       <td id="T_694a8_row0_col0" class="data row0 col0" >PTTEP</td>
#       <td id="T_694a8_row0_col1" class="data row0 col1" >154.50</td>
#       <td id="T_694a8_row0_col2" class="data row0 col2" >6,477</td>
#       <td id="T_694a8_row0_col3" class="data row0 col3" >-7.00</td>
#       <td id="T_694a8_row0_col4" class="data row0 col4" >-4.33</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row1" class="row_heading level0 row1" >59</th>
#       <td id="T_694a8_row1_col0" class="data row1 col0" >DELTA</td>
#       <td id="T_694a8_row1_col1" class="data row1 col1" >542.00</td>
#       <td id="T_694a8_row1_col2" class="data row1 col2" >3,234</td>
#       <td id="T_694a8_row1_col3" class="data row1 col3" >20.00</td>
#       <td id="T_694a8_row1_col4" class="data row1 col4" >3.83</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_694a8_row2_col0" class="data row2 col0" >BANPU</td>
#       <td id="T_694a8_row2_col1" class="data row2 col1" >12.80</td>
#       <td id="T_694a8_row2_col2" class="data row2 col2" >3,222</td>
#       <td id="T_694a8_row2_col3" class="data row2 col3" >-0.50</td>
#       <td id="T_694a8_row2_col4" class="data row2 col4" >-3.76</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_694a8_row3_col0" class="data row3 col0" >AOT</td>
#       <td id="T_694a8_row3_col1" class="data row3 col1" >71.25</td>
#       <td id="T_694a8_row3_col2" class="data row3 col2" >2,224</td>
#       <td id="T_694a8_row3_col3" class="data row3 col3" >0.50</td>
#       <td id="T_694a8_row3_col4" class="data row3 col4" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row4" class="row_heading level0 row4" >27</th>
#       <td id="T_694a8_row4_col0" class="data row4 col0" >BDMS</td>
#       <td id="T_694a8_row4_col1" class="data row4 col1" >27.25</td>
#       <td id="T_694a8_row4_col2" class="data row4 col2" >1,560</td>
#       <td id="T_694a8_row4_col3" class="data row4 col3" >-0.50</td>
#       <td id="T_694a8_row4_col4" class="data row4 col4" >-1.80</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row5" class="row_heading level0 row5" >95</th>
#       <td id="T_694a8_row5_col0" class="data row5 col0" >IVL</td>
#       <td id="T_694a8_row5_col1" class="data row5 col1" >44.00</td>
#       <td id="T_694a8_row5_col2" class="data row5 col2" >1,558</td>
#       <td id="T_694a8_row5_col3" class="data row5 col3" >-0.50</td>
#       <td id="T_694a8_row5_col4" class="data row5 col4" >-1.12</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row6" class="row_heading level0 row6" >165</th>
#       <td id="T_694a8_row6_col0" class="data row6 col0" >SCGP</td>
#       <td id="T_694a8_row6_col1" class="data row6 col1" >54.75</td>
#       <td id="T_694a8_row6_col2" class="data row6 col2" >1,443</td>
#       <td id="T_694a8_row6_col3" class="data row6 col3" >3.00</td>
#       <td id="T_694a8_row6_col4" class="data row6 col4" >5.80</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row7" class="row_heading level0 row7" >79</th>
#       <td id="T_694a8_row7_col0" class="data row7 col0" >GULF</td>
#       <td id="T_694a8_row7_col1" class="data row7 col1" >49.00</td>
#       <td id="T_694a8_row7_col2" class="data row7 col2" >1,357</td>
#       <td id="T_694a8_row7_col3" class="data row7 col3" >0.75</td>
#       <td id="T_694a8_row7_col4" class="data row7 col4" >1.55</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row8" class="row_heading level0 row8" >100</th>
#       <td id="T_694a8_row8_col0" class="data row8 col0" >KBANK</td>
#       <td id="T_694a8_row8_col1" class="data row8 col1" >145.00</td>
#       <td id="T_694a8_row8_col2" class="data row8 col2" >1,195</td>
#       <td id="T_694a8_row8_col3" class="data row8 col3" >0.00</td>
#       <td id="T_694a8_row8_col4" class="data row8 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_694a8_level0_row9" class="row_heading level0 row9" >128</th>
#       <td id="T_694a8_row9_col0" class="data row9 col0" >MTC</td>
#       <td id="T_694a8_row9_col1" class="data row9 col1" >50.75</td>
#       <td id="T_694a8_row9_col2" class="data row9 col2" >1,152</td>
#       <td id="T_694a8_row9_col3" class="data row9 col3" >2.00</td>
#       <td id="T_694a8_row9_col4" class="data row9 col4" >4.10</td>
#     </tr>
#   </tbody>
# </table>
