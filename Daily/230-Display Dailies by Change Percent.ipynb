# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 7, 18)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f25d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f25d_level0_row0" class="row_heading level0 row0" >143</th>
#       <td id="T_7f25d_row0_col0" class="data row0 col0" >PSL</td>
#       <td id="T_7f25d_row0_col1" class="data row0 col1" >18.10</td>
#       <td id="T_7f25d_row0_col2" class="data row0 col2" >285</td>
#       <td id="T_7f25d_row0_col3" class="data row0 col3" >1.10</td>
#       <td id="T_7f25d_row0_col4" class="data row0 col4" >6.47</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row1" class="row_heading level0 row1" >152</th>
#       <td id="T_7f25d_row1_col0" class="data row1 col0" >RCL</td>
#       <td id="T_7f25d_row1_col1" class="data row1 col1" >34.75</td>
#       <td id="T_7f25d_row1_col2" class="data row1 col2" >251</td>
#       <td id="T_7f25d_row1_col3" class="data row1 col3" >2.00</td>
#       <td id="T_7f25d_row1_col4" class="data row1 col4" >6.11</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row2" class="row_heading level0 row2" >213</th>
#       <td id="T_7f25d_row2_col0" class="data row2 col0" >TTA</td>
#       <td id="T_7f25d_row2_col1" class="data row2 col1" >8.80</td>
#       <td id="T_7f25d_row2_col2" class="data row2 col2" >144</td>
#       <td id="T_7f25d_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_7f25d_row2_col4" class="data row2 col4" >6.02</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row3" class="row_heading level0 row3" >121</th>
#       <td id="T_7f25d_row3_col0" class="data row3 col0" >MBAX</td>
#       <td id="T_7f25d_row3_col1" class="data row3 col1" >6.00</td>
#       <td id="T_7f25d_row3_col2" class="data row3 col2" >14</td>
#       <td id="T_7f25d_row3_col3" class="data row3 col3" >0.30</td>
#       <td id="T_7f25d_row3_col4" class="data row3 col4" >5.26</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row4" class="row_heading level0 row4" >182</th>
#       <td id="T_7f25d_row4_col0" class="data row4 col0" >STARK</td>
#       <td id="T_7f25d_row4_col1" class="data row4 col1" >4.20</td>
#       <td id="T_7f25d_row4_col2" class="data row4 col2" >60</td>
#       <td id="T_7f25d_row4_col3" class="data row4 col3" >0.20</td>
#       <td id="T_7f25d_row4_col4" class="data row4 col4" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row5" class="row_heading level0 row5" >58</th>
#       <td id="T_7f25d_row5_col0" class="data row5 col0" >DELTA</td>
#       <td id="T_7f25d_row5_col1" class="data row5 col1" >339.00</td>
#       <td id="T_7f25d_row5_col2" class="data row5 col2" >758</td>
#       <td id="T_7f25d_row5_col3" class="data row5 col3" >16.00</td>
#       <td id="T_7f25d_row5_col4" class="data row5 col4" >4.95</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row6" class="row_heading level0 row6" >145</th>
#       <td id="T_7f25d_row6_col0" class="data row6 col0" >PTL</td>
#       <td id="T_7f25d_row6_col1" class="data row6 col1" >21.70</td>
#       <td id="T_7f25d_row6_col2" class="data row6 col2" >11</td>
#       <td id="T_7f25d_row6_col3" class="data row6 col3" >0.90</td>
#       <td id="T_7f25d_row6_col4" class="data row6 col4" >4.33</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row7" class="row_heading level0 row7" >14</th>
#       <td id="T_7f25d_row7_col0" class="data row7 col0" >ASK</td>
#       <td id="T_7f25d_row7_col1" class="data row7 col1" >31.25</td>
#       <td id="T_7f25d_row7_col2" class="data row7 col2" >66</td>
#       <td id="T_7f25d_row7_col3" class="data row7 col3" >1.25</td>
#       <td id="T_7f25d_row7_col4" class="data row7 col4" >4.17</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row8" class="row_heading level0 row8" >196</th>
#       <td id="T_7f25d_row8_col0" class="data row8 col0" >TIPH</td>
#       <td id="T_7f25d_row8_col1" class="data row8 col1" >58.00</td>
#       <td id="T_7f25d_row8_col2" class="data row8 col2" >259</td>
#       <td id="T_7f25d_row8_col3" class="data row8 col3" >2.25</td>
#       <td id="T_7f25d_row8_col4" class="data row8 col4" >4.04</td>
#     </tr>
#     <tr>
#       <th id="T_7f25d_level0_row9" class="row_heading level0 row9" >229</th>
#       <td id="T_7f25d_row9_col0" class="data row9 col0" >WICE</td>
#       <td id="T_7f25d_row9_col1" class="data row9 col1" >11.10</td>
#       <td id="T_7f25d_row9_col2" class="data row9 col2" >62</td>
#       <td id="T_7f25d_row9_col3" class="data row9 col3" >0.40</td>
#       <td id="T_7f25d_row9_col4" class="data row9 col4" >3.74</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4f8b9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f8b9_level0_row0" class="row_heading level0 row0" >124</th>
#       <td id="T_4f8b9_row0_col0" class="data row0 col0" >MEGA</td>
#       <td id="T_4f8b9_row0_col1" class="data row0 col1" >47.50</td>
#       <td id="T_4f8b9_row0_col2" class="data row0 col2" >557</td>
#       <td id="T_4f8b9_row0_col3" class="data row0 col3" >-5.25</td>
#       <td id="T_4f8b9_row0_col4" class="data row0 col4" >-9.95</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row1" class="row_heading level0 row1" >101</th>
#       <td id="T_4f8b9_row1_col0" class="data row1 col0" >KEX</td>
#       <td id="T_4f8b9_row1_col1" class="data row1 col1" >23.40</td>
#       <td id="T_4f8b9_row1_col2" class="data row1 col2" >769</td>
#       <td id="T_4f8b9_row1_col3" class="data row1 col3" >-2.35</td>
#       <td id="T_4f8b9_row1_col4" class="data row1 col4" >-9.13</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row2" class="row_heading level0 row2" >66</th>
#       <td id="T_4f8b9_row2_col0" class="data row2 col0" >EGATIF</td>
#       <td id="T_4f8b9_row2_col1" class="data row2 col1" >6.90</td>
#       <td id="T_4f8b9_row2_col2" class="data row2 col2" >55</td>
#       <td id="T_4f8b9_row2_col3" class="data row2 col3" >-0.45</td>
#       <td id="T_4f8b9_row2_col4" class="data row2 col4" >-6.12</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row3" class="row_heading level0 row3" >34</th>
#       <td id="T_4f8b9_row3_col0" class="data row3 col0" >BH</td>
#       <td id="T_4f8b9_row3_col1" class="data row3 col1" >178.50</td>
#       <td id="T_4f8b9_row3_col2" class="data row3 col2" >1,125</td>
#       <td id="T_4f8b9_row3_col3" class="data row3 col3" >-10.00</td>
#       <td id="T_4f8b9_row3_col4" class="data row3 col4" >-5.31</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row4" class="row_heading level0 row4" >60</th>
#       <td id="T_4f8b9_row4_col0" class="data row4 col0" >DOHOME</td>
#       <td id="T_4f8b9_row4_col1" class="data row4 col1" >14.10</td>
#       <td id="T_4f8b9_row4_col2" class="data row4 col2" >309</td>
#       <td id="T_4f8b9_row4_col3" class="data row4 col3" >-0.70</td>
#       <td id="T_4f8b9_row4_col4" class="data row4 col4" >-4.73</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row5" class="row_heading level0 row5" >157</th>
#       <td id="T_4f8b9_row5_col0" class="data row5 col0" >SAPPE</td>
#       <td id="T_4f8b9_row5_col1" class="data row5 col1" >36.25</td>
#       <td id="T_4f8b9_row5_col2" class="data row5 col2" >91</td>
#       <td id="T_4f8b9_row5_col3" class="data row5 col3" >-1.25</td>
#       <td id="T_4f8b9_row5_col4" class="data row5 col4" >-3.33</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row6" class="row_heading level0 row6" >151</th>
#       <td id="T_4f8b9_row6_col0" class="data row6 col0" >RBF</td>
#       <td id="T_4f8b9_row6_col1" class="data row6 col1" >12.60</td>
#       <td id="T_4f8b9_row6_col2" class="data row6 col2" >64</td>
#       <td id="T_4f8b9_row6_col3" class="data row6 col3" >-0.40</td>
#       <td id="T_4f8b9_row6_col4" class="data row6 col4" >-3.08</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row7" class="row_heading level0 row7" >42</th>
#       <td id="T_4f8b9_row7_col0" class="data row7 col0" >CBG</td>
#       <td id="T_4f8b9_row7_col1" class="data row7 col1" >111.00</td>
#       <td id="T_4f8b9_row7_col2" class="data row7 col2" >1,599</td>
#       <td id="T_4f8b9_row7_col3" class="data row7 col3" >-3.50</td>
#       <td id="T_4f8b9_row7_col4" class="data row7 col4" >-3.06</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row8" class="row_heading level0 row8" >47</th>
#       <td id="T_4f8b9_row8_col0" class="data row8 col0" >COM7</td>
#       <td id="T_4f8b9_row8_col1" class="data row8 col1" >27.75</td>
#       <td id="T_4f8b9_row8_col2" class="data row8 col2" >655</td>
#       <td id="T_4f8b9_row8_col3" class="data row8 col3" >-0.75</td>
#       <td id="T_4f8b9_row8_col4" class="data row8 col4" >-2.63</td>
#     </tr>
#     <tr>
#       <th id="T_4f8b9_level0_row9" class="row_heading level0 row9" >170</th>
#       <td id="T_4f8b9_row9_col0" class="data row9 col0" >SKN</td>
#       <td id="T_4f8b9_row9_col1" class="data row9 col1" >6.25</td>
#       <td id="T_4f8b9_row9_col2" class="data row9 col2" >7</td>
#       <td id="T_4f8b9_row9_col3" class="data row9 col3" >-0.15</td>
#       <td id="T_4f8b9_row9_col4" class="data row9 col4" >-2.34</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e323f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e323f_level0_row0" class="row_heading level0 row0" >147</th>
#       <td id="T_e323f_row0_col0" class="data row0 col0" >PTTEP</td>
#       <td id="T_e323f_row0_col1" class="data row0 col1" >158.00</td>
#       <td id="T_e323f_row0_col2" class="data row0 col2" >2,705</td>
#       <td id="T_e323f_row0_col3" class="data row0 col3" >4.00</td>
#       <td id="T_e323f_row0_col4" class="data row0 col4" >2.60</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row1" class="row_heading level0 row1" >146</th>
#       <td id="T_e323f_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_e323f_row1_col1" class="data row1 col1" >34.50</td>
#       <td id="T_e323f_row1_col2" class="data row1 col2" >2,122</td>
#       <td id="T_e323f_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_e323f_row1_col4" class="data row1 col4" >2.99</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row2" class="row_heading level0 row2" >161</th>
#       <td id="T_e323f_row2_col0" class="data row2 col0" >SCB</td>
#       <td id="T_e323f_row2_col1" class="data row2 col1" >95.25</td>
#       <td id="T_e323f_row2_col2" class="data row2 col2" >1,757</td>
#       <td id="T_e323f_row2_col3" class="data row2 col3" >1.25</td>
#       <td id="T_e323f_row2_col4" class="data row2 col4" >1.33</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row3" class="row_heading level0 row3" >42</th>
#       <td id="T_e323f_row3_col0" class="data row3 col0" >CBG</td>
#       <td id="T_e323f_row3_col1" class="data row3 col1" >111.00</td>
#       <td id="T_e323f_row3_col2" class="data row3 col2" >1,599</td>
#       <td id="T_e323f_row3_col3" class="data row3 col3" >-3.50</td>
#       <td id="T_e323f_row3_col4" class="data row3 col4" >-3.06</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row4" class="row_heading level0 row4" >27</th>
#       <td id="T_e323f_row4_col0" class="data row4 col0" >BDMS</td>
#       <td id="T_e323f_row4_col1" class="data row4 col1" >26.50</td>
#       <td id="T_e323f_row4_col2" class="data row4 col2" >1,557</td>
#       <td id="T_e323f_row4_col3" class="data row4 col3" >-0.50</td>
#       <td id="T_e323f_row4_col4" class="data row4 col4" >-1.85</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row5" class="row_heading level0 row5" >99</th>
#       <td id="T_e323f_row5_col0" class="data row5 col0" >KBANK</td>
#       <td id="T_e323f_row5_col1" class="data row5 col1" >141.00</td>
#       <td id="T_e323f_row5_col2" class="data row5 col2" >1,398</td>
#       <td id="T_e323f_row5_col3" class="data row5 col3" >1.00</td>
#       <td id="T_e323f_row5_col4" class="data row5 col4" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row6" class="row_heading level0 row6" >34</th>
#       <td id="T_e323f_row6_col0" class="data row6 col0" >BH</td>
#       <td id="T_e323f_row6_col1" class="data row6 col1" >178.50</td>
#       <td id="T_e323f_row6_col2" class="data row6 col2" >1,125</td>
#       <td id="T_e323f_row6_col3" class="data row6 col3" >-10.00</td>
#       <td id="T_e323f_row6_col4" class="data row6 col4" >-5.31</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_e323f_row7_col0" class="data row7 col0" >AOT</td>
#       <td id="T_e323f_row7_col1" class="data row7 col1" >70.00</td>
#       <td id="T_e323f_row7_col2" class="data row7 col2" >1,117</td>
#       <td id="T_e323f_row7_col3" class="data row7 col3" >0.25</td>
#       <td id="T_e323f_row7_col4" class="data row7 col4" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row8" class="row_heading level0 row8" >49</th>
#       <td id="T_e323f_row8_col0" class="data row8 col0" >CPALL</td>
#       <td id="T_e323f_row8_col1" class="data row8 col1" >61.50</td>
#       <td id="T_e323f_row8_col2" class="data row8 col2" >1,021</td>
#       <td id="T_e323f_row8_col3" class="data row8 col3" >0.25</td>
#       <td id="T_e323f_row8_col4" class="data row8 col4" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_e323f_level0_row9" class="row_heading level0 row9" >20</th>
#       <td id="T_e323f_row9_col0" class="data row9 col0" >BANPU</td>
#       <td id="T_e323f_row9_col1" class="data row9 col1" >12.80</td>
#       <td id="T_e323f_row9_col2" class="data row9 col2" >968</td>
#       <td id="T_e323f_row9_col3" class="data row9 col3" >0.30</td>
#       <td id="T_e323f_row9_col4" class="data row9 col4" >2.40</td>
#     </tr>
#   </tbody>
# </table>
