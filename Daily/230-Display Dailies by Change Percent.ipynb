# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 5, 27)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3765_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3765_level0_row0" class="row_heading level0 row0" >113</th>
#       <td id="T_e3765_row0_col0" class="data row0 col0" >LHK</td>
#       <td id="T_e3765_row0_col1" class="data row0 col1" >5.85</td>
#       <td id="T_e3765_row0_col2" class="data row0 col2" >231</td>
#       <td id="T_e3765_row0_col3" class="data row0 col3" >0.70</td>
#       <td id="T_e3765_row0_col4" class="data row0 col4" >13.59</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row1" class="row_heading level0 row1" >91</th>
#       <td id="T_e3765_row1_col0" class="data row1 col0" >INOX</td>
#       <td id="T_e3765_row1_col1" class="data row1 col1" >1.30</td>
#       <td id="T_e3765_row1_col2" class="data row1 col2" >134</td>
#       <td id="T_e3765_row1_col3" class="data row1 col3" >0.10</td>
#       <td id="T_e3765_row1_col4" class="data row1 col4" >8.33</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row2" class="row_heading level0 row2" >212</th>
#       <td id="T_e3765_row2_col0" class="data row2 col0" >TSTH</td>
#       <td id="T_e3765_row2_col1" class="data row2 col1" >1.42</td>
#       <td id="T_e3765_row2_col2" class="data row2 col2" >111</td>
#       <td id="T_e3765_row2_col3" class="data row2 col3" >0.09</td>
#       <td id="T_e3765_row2_col4" class="data row2 col4" >6.77</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row3" class="row_heading level0 row3" >114</th>
#       <td id="T_e3765_row3_col0" class="data row3 col0" >LIT</td>
#       <td id="T_e3765_row3_col1" class="data row3 col1" >2.18</td>
#       <td id="T_e3765_row3_col2" class="data row3 col2" >13</td>
#       <td id="T_e3765_row3_col3" class="data row3 col3" >0.12</td>
#       <td id="T_e3765_row3_col4" class="data row3 col4" >5.83</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row4" class="row_heading level0 row4" >101</th>
#       <td id="T_e3765_row4_col0" class="data row4 col0" >KCE</td>
#       <td id="T_e3765_row4_col1" class="data row4 col1" >65.00</td>
#       <td id="T_e3765_row4_col2" class="data row4 col2" >1,353</td>
#       <td id="T_e3765_row4_col3" class="data row4 col3" >3.25</td>
#       <td id="T_e3765_row4_col4" class="data row4 col4" >5.26</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row5" class="row_heading level0 row5" >187</th>
#       <td id="T_e3765_row5_col0" class="data row5 col0" >SVI</td>
#       <td id="T_e3765_row5_col1" class="data row5 col1" >7.70</td>
#       <td id="T_e3765_row5_col2" class="data row5 col2" >63</td>
#       <td id="T_e3765_row5_col3" class="data row5 col3" >0.35</td>
#       <td id="T_e3765_row5_col4" class="data row5 col4" >4.76</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row6" class="row_heading level0 row6" >194</th>
#       <td id="T_e3765_row6_col0" class="data row6 col0" >THG</td>
#       <td id="T_e3765_row6_col1" class="data row6 col1" >70.25</td>
#       <td id="T_e3765_row6_col2" class="data row6 col2" >774</td>
#       <td id="T_e3765_row6_col3" class="data row6 col3" >3.00</td>
#       <td id="T_e3765_row6_col4" class="data row6 col4" >4.46</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row7" class="row_heading level0 row7" >119</th>
#       <td id="T_e3765_row7_col0" class="data row7 col0" >MACO</td>
#       <td id="T_e3765_row7_col1" class="data row7 col1" >0.72</td>
#       <td id="T_e3765_row7_col2" class="data row7 col2" >37</td>
#       <td id="T_e3765_row7_col3" class="data row7 col3" >0.03</td>
#       <td id="T_e3765_row7_col4" class="data row7 col4" >4.35</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row8" class="row_heading level0 row8" >69</th>
#       <td id="T_e3765_row8_col0" class="data row8 col0" >ESSO</td>
#       <td id="T_e3765_row8_col1" class="data row8 col1" >9.95</td>
#       <td id="T_e3765_row8_col2" class="data row8 col2" >412</td>
#       <td id="T_e3765_row8_col3" class="data row8 col3" >0.35</td>
#       <td id="T_e3765_row8_col4" class="data row8 col4" >3.65</td>
#     </tr>
#     <tr>
#       <th id="T_e3765_level0_row9" class="row_heading level0 row9" >147</th>
#       <td id="T_e3765_row9_col0" class="data row9 col0" >PTTEP</td>
#       <td id="T_e3765_row9_col1" class="data row9 col1" >165.50</td>
#       <td id="T_e3765_row9_col2" class="data row9 col2" >3,669</td>
#       <td id="T_e3765_row9_col3" class="data row9 col3" >5.50</td>
#       <td id="T_e3765_row9_col4" class="data row9 col4" >3.44</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d120_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d120_level0_row0" class="row_heading level0 row0" >213</th>
#       <td id="T_3d120_row0_col0" class="data row0 col0" >TTA</td>
#       <td id="T_3d120_row0_col1" class="data row0 col1" >9.70</td>
#       <td id="T_3d120_row0_col2" class="data row0 col2" >490</td>
#       <td id="T_3d120_row0_col3" class="data row0 col3" >-0.60</td>
#       <td id="T_3d120_row0_col4" class="data row0 col4" >-5.83</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row1" class="row_heading level0 row1" >143</th>
#       <td id="T_3d120_row1_col0" class="data row1 col0" >PSL</td>
#       <td id="T_3d120_row1_col1" class="data row1 col1" >19.10</td>
#       <td id="T_3d120_row1_col2" class="data row1 col2" >356</td>
#       <td id="T_3d120_row1_col3" class="data row1 col3" >-1.10</td>
#       <td id="T_3d120_row1_col4" class="data row1 col4" >-5.45</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row2" class="row_heading level0 row2" >210</th>
#       <td id="T_3d120_row2_col0" class="data row2 col0" >TRUE</td>
#       <td id="T_3d120_row2_col1" class="data row2 col1" >4.36</td>
#       <td id="T_3d120_row2_col2" class="data row2 col2" >800</td>
#       <td id="T_3d120_row2_col3" class="data row2 col3" >-0.16</td>
#       <td id="T_3d120_row2_col4" class="data row2 col4" >-3.54</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row3" class="row_heading level0 row3" >152</th>
#       <td id="T_3d120_row3_col0" class="data row3 col0" >RCL</td>
#       <td id="T_3d120_row3_col1" class="data row3 col1" >45.00</td>
#       <td id="T_3d120_row3_col2" class="data row3 col2" >407</td>
#       <td id="T_3d120_row3_col3" class="data row3 col3" >-1.50</td>
#       <td id="T_3d120_row3_col4" class="data row3 col4" >-3.23</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row4" class="row_heading level0 row4" >182</th>
#       <td id="T_3d120_row4_col0" class="data row4 col0" >STARK</td>
#       <td id="T_3d120_row4_col1" class="data row4 col1" >4.90</td>
#       <td id="T_3d120_row4_col2" class="data row4 col2" >307</td>
#       <td id="T_3d120_row4_col3" class="data row4 col3" >-0.15</td>
#       <td id="T_3d120_row4_col4" class="data row4 col4" >-2.97</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row5" class="row_heading level0 row5" >102</th>
#       <td id="T_3d120_row5_col0" class="data row5 col0" >KEX</td>
#       <td id="T_3d120_row5_col1" class="data row5 col1" >22.90</td>
#       <td id="T_3d120_row5_col2" class="data row5 col2" >314</td>
#       <td id="T_3d120_row5_col3" class="data row5 col3" >-0.70</td>
#       <td id="T_3d120_row5_col4" class="data row5 col4" >-2.97</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row6" class="row_heading level0 row6" >62</th>
#       <td id="T_3d120_row6_col0" class="data row6 col0" >DTAC</td>
#       <td id="T_3d120_row6_col1" class="data row6 col1" >42.75</td>
#       <td id="T_3d120_row6_col2" class="data row6 col2" >274</td>
#       <td id="T_3d120_row6_col3" class="data row6 col3" >-1.25</td>
#       <td id="T_3d120_row6_col4" class="data row6 col4" >-2.84</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row7" class="row_heading level0 row7" >218</th>
#       <td id="T_3d120_row7_col0" class="data row7 col0" >TVI</td>
#       <td id="T_3d120_row7_col1" class="data row7 col1" >16.60</td>
#       <td id="T_3d120_row7_col2" class="data row7 col2" >15</td>
#       <td id="T_3d120_row7_col3" class="data row7 col3" >-0.40</td>
#       <td id="T_3d120_row7_col4" class="data row7 col4" >-2.35</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row8" class="row_heading level0 row8" >57</th>
#       <td id="T_3d120_row8_col0" class="data row8 col0" >DCON</td>
#       <td id="T_3d120_row8_col1" class="data row8 col1" >0.44</td>
#       <td id="T_3d120_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_3d120_row8_col3" class="data row8 col3" >-0.01</td>
#       <td id="T_3d120_row8_col4" class="data row8 col4" >-2.22</td>
#     </tr>
#     <tr>
#       <th id="T_3d120_level0_row9" class="row_heading level0 row9" >173</th>
#       <td id="T_3d120_row9_col0" class="data row9 col0" >SNC</td>
#       <td id="T_3d120_row9_col1" class="data row9 col1" >18.90</td>
#       <td id="T_3d120_row9_col2" class="data row9 col2" >40</td>
#       <td id="T_3d120_row9_col3" class="data row9 col3" >-0.40</td>
#       <td id="T_3d120_row9_col4" class="data row9 col4" >-2.07</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ef3f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ef3f_level0_row0" class="row_heading level0 row0" >147</th>
#       <td id="T_1ef3f_row0_col0" class="data row0 col0" >PTTEP</td>
#       <td id="T_1ef3f_row0_col1" class="data row0 col1" >165.50</td>
#       <td id="T_1ef3f_row0_col2" class="data row0 col2" >3,669</td>
#       <td id="T_1ef3f_row0_col3" class="data row0 col3" >5.50</td>
#       <td id="T_1ef3f_row0_col4" class="data row0 col4" >3.44</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_1ef3f_row1_col0" class="data row1 col0" >AOT</td>
#       <td id="T_1ef3f_row1_col1" class="data row1 col1" >69.00</td>
#       <td id="T_1ef3f_row1_col2" class="data row1 col2" >2,520</td>
#       <td id="T_1ef3f_row1_col3" class="data row1 col3" >-0.75</td>
#       <td id="T_1ef3f_row1_col4" class="data row1 col4" >-1.08</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row2" class="row_heading level0 row2" >100</th>
#       <td id="T_1ef3f_row2_col0" class="data row2 col0" >KBANK</td>
#       <td id="T_1ef3f_row2_col1" class="data row2 col1" >146.50</td>
#       <td id="T_1ef3f_row2_col2" class="data row2 col2" >1,899</td>
#       <td id="T_1ef3f_row2_col3" class="data row2 col3" >2.00</td>
#       <td id="T_1ef3f_row2_col4" class="data row2 col4" >1.38</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row3" class="row_heading level0 row3" >27</th>
#       <td id="T_1ef3f_row3_col0" class="data row3 col0" >BDMS</td>
#       <td id="T_1ef3f_row3_col1" class="data row3 col1" >25.50</td>
#       <td id="T_1ef3f_row3_col2" class="data row3 col2" >1,842</td>
#       <td id="T_1ef3f_row3_col3" class="data row3 col3" >-0.50</td>
#       <td id="T_1ef3f_row3_col4" class="data row3 col4" >-1.92</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_1ef3f_row4_col0" class="data row4 col0" >ADVANC</td>
#       <td id="T_1ef3f_row4_col1" class="data row4 col1" >218.00</td>
#       <td id="T_1ef3f_row4_col2" class="data row4 col2" >1,827</td>
#       <td id="T_1ef3f_row4_col3" class="data row4 col3" >-4.00</td>
#       <td id="T_1ef3f_row4_col4" class="data row4 col4" >-1.80</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row5" class="row_heading level0 row5" >63</th>
#       <td id="T_1ef3f_row5_col0" class="data row5 col0" >EA</td>
#       <td id="T_1ef3f_row5_col1" class="data row5 col1" >88.75</td>
#       <td id="T_1ef3f_row5_col2" class="data row5 col2" >1,578</td>
#       <td id="T_1ef3f_row5_col3" class="data row5 col3" >0.75</td>
#       <td id="T_1ef3f_row5_col4" class="data row5 col4" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row6" class="row_heading level0 row6" >146</th>
#       <td id="T_1ef3f_row6_col0" class="data row6 col0" >PTT</td>
#       <td id="T_1ef3f_row6_col1" class="data row6 col1" >37.50</td>
#       <td id="T_1ef3f_row6_col2" class="data row6 col2" >1,355</td>
#       <td id="T_1ef3f_row6_col3" class="data row6 col3" >0.50</td>
#       <td id="T_1ef3f_row6_col4" class="data row6 col4" >1.35</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row7" class="row_heading level0 row7" >101</th>
#       <td id="T_1ef3f_row7_col0" class="data row7 col0" >KCE</td>
#       <td id="T_1ef3f_row7_col1" class="data row7 col1" >65.00</td>
#       <td id="T_1ef3f_row7_col2" class="data row7 col2" >1,353</td>
#       <td id="T_1ef3f_row7_col3" class="data row7 col3" >3.25</td>
#       <td id="T_1ef3f_row7_col4" class="data row7 col4" >5.26</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row8" class="row_heading level0 row8" >49</th>
#       <td id="T_1ef3f_row8_col0" class="data row8 col0" >CPALL</td>
#       <td id="T_1ef3f_row8_col1" class="data row8 col1" >65.00</td>
#       <td id="T_1ef3f_row8_col2" class="data row8 col2" >1,228</td>
#       <td id="T_1ef3f_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_1ef3f_row8_col4" class="data row8 col4" >1.56</td>
#     </tr>
#     <tr>
#       <th id="T_1ef3f_level0_row9" class="row_heading level0 row9" >50</th>
#       <td id="T_1ef3f_row9_col0" class="data row9 col0" >CPF</td>
#       <td id="T_1ef3f_row9_col1" class="data row9 col1" >26.00</td>
#       <td id="T_1ef3f_row9_col2" class="data row9 col2" >1,161</td>
#       <td id="T_1ef3f_row9_col3" class="data row9 col3" >0.00</td>
#       <td id="T_1ef3f_row9_col4" class="data row9 col4" >0.00</td>
#     </tr>
#   </tbody>
# </table>
