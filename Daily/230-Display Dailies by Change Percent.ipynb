# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 11, 18)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c43f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c43f3_level0_row0" class="row_heading level0 row0" >81</th>
#       <td id="T_c43f3_row0_col0" class="data row0 col0" >HANA</td>
#       <td id="T_c43f3_row0_col1" class="data row0 col1" >50.50</td>
#       <td id="T_c43f3_row0_col2" class="data row0 col2" >2,654</td>
#       <td id="T_c43f3_row0_col3" class="data row0 col3" >5.75</td>
#       <td id="T_c43f3_row0_col4" class="data row0 col4" >12.85</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row1" class="row_heading level0 row1" >101</th>
#       <td id="T_c43f3_row1_col0" class="data row1 col0" >KCE</td>
#       <td id="T_c43f3_row1_col1" class="data row1 col1" >51.25</td>
#       <td id="T_c43f3_row1_col2" class="data row1 col2" >2,198</td>
#       <td id="T_c43f3_row1_col3" class="data row1 col3" >3.50</td>
#       <td id="T_c43f3_row1_col4" class="data row1 col4" >7.33</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row2" class="row_heading level0 row2" >85</th>
#       <td id="T_c43f3_row2_col0" class="data row2 col0" >ICHI</td>
#       <td id="T_c43f3_row2_col1" class="data row2 col1" >11.50</td>
#       <td id="T_c43f3_row2_col2" class="data row2 col2" >172</td>
#       <td id="T_c43f3_row2_col3" class="data row2 col3" >0.60</td>
#       <td id="T_c43f3_row2_col4" class="data row2 col4" >5.50</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row3" class="row_heading level0 row3" >88</th>
#       <td id="T_c43f3_row3_col0" class="data row3 col0" >IMH</td>
#       <td id="T_c43f3_row3_col1" class="data row3 col1" >13.40</td>
#       <td id="T_c43f3_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_c43f3_row3_col3" class="data row3 col3" >0.60</td>
#       <td id="T_c43f3_row3_col4" class="data row3 col4" >4.69</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row4" class="row_heading level0 row4" >121</th>
#       <td id="T_c43f3_row4_col0" class="data row4 col0" >MAKRO</td>
#       <td id="T_c43f3_row4_col1" class="data row4 col1" >38.00</td>
#       <td id="T_c43f3_row4_col2" class="data row4 col2" >1,001</td>
#       <td id="T_c43f3_row4_col3" class="data row4 col3" >1.50</td>
#       <td id="T_c43f3_row4_col4" class="data row4 col4" >4.11</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row5" class="row_heading level0 row5" >57</th>
#       <td id="T_c43f3_row5_col0" class="data row5 col0" >DELTA</td>
#       <td id="T_c43f3_row5_col1" class="data row5 col1" >660.00</td>
#       <td id="T_c43f3_row5_col2" class="data row5 col2" >1,670</td>
#       <td id="T_c43f3_row5_col3" class="data row5 col3" >22.00</td>
#       <td id="T_c43f3_row5_col4" class="data row5 col4" >3.45</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row6" class="row_heading level0 row6" >189</th>
#       <td id="T_c43f3_row6_col0" class="data row6 col0" >SVI</td>
#       <td id="T_c43f3_row6_col1" class="data row6 col1" >9.40</td>
#       <td id="T_c43f3_row6_col2" class="data row6 col2" >153</td>
#       <td id="T_c43f3_row6_col3" class="data row6 col3" >0.30</td>
#       <td id="T_c43f3_row6_col4" class="data row6 col4" >3.30</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row7" class="row_heading level0 row7" >218</th>
#       <td id="T_c43f3_row7_col0" class="data row7 col0" >TTW</td>
#       <td id="T_c43f3_row7_col1" class="data row7 col1" >8.90</td>
#       <td id="T_c43f3_row7_col2" class="data row7 col2" >32</td>
#       <td id="T_c43f3_row7_col3" class="data row7 col3" >0.25</td>
#       <td id="T_c43f3_row7_col4" class="data row7 col4" >2.89</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_c43f3_row8_col0" class="data row8 col0" >ASK</td>
#       <td id="T_c43f3_row8_col1" class="data row8 col1" >34.50</td>
#       <td id="T_c43f3_row8_col2" class="data row8 col2" >36</td>
#       <td id="T_c43f3_row8_col3" class="data row8 col3" >0.75</td>
#       <td id="T_c43f3_row8_col4" class="data row8 col4" >2.22</td>
#     </tr>
#     <tr>
#       <th id="T_c43f3_level0_row9" class="row_heading level0 row9" >145</th>
#       <td id="T_c43f3_row9_col0" class="data row9 col0" >PTG</td>
#       <td id="T_c43f3_row9_col1" class="data row9 col1" >14.30</td>
#       <td id="T_c43f3_row9_col2" class="data row9 col2" >195</td>
#       <td id="T_c43f3_row9_col3" class="data row9 col3" >0.30</td>
#       <td id="T_c43f3_row9_col4" class="data row9 col4" >2.14</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff758_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff758_level0_row0" class="row_heading level0 row0" >69</th>
#       <td id="T_ff758_row0_col0" class="data row0 col0" >FORTH</td>
#       <td id="T_ff758_row0_col1" class="data row0 col1" >37.75</td>
#       <td id="T_ff758_row0_col2" class="data row0 col2" >410</td>
#       <td id="T_ff758_row0_col3" class="data row0 col3" >-3.50</td>
#       <td id="T_ff758_row0_col4" class="data row0 col4" >-8.48</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row1" class="row_heading level0 row1" >220</th>
#       <td id="T_ff758_row1_col0" class="data row1 col0" >TVI</td>
#       <td id="T_ff758_row1_col1" class="data row1 col1" >11.80</td>
#       <td id="T_ff758_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_ff758_row1_col3" class="data row1 col3" >-0.80</td>
#       <td id="T_ff758_row1_col4" class="data row1 col4" >-6.35</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row2" class="row_heading level0 row2" >17</th>
#       <td id="T_ff758_row2_col0" class="data row2 col0" >BA</td>
#       <td id="T_ff758_row2_col1" class="data row2 col1" >12.40</td>
#       <td id="T_ff758_row2_col2" class="data row2 col2" >127</td>
#       <td id="T_ff758_row2_col3" class="data row2 col3" >-0.80</td>
#       <td id="T_ff758_row2_col4" class="data row2 col4" >-6.06</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row3" class="row_heading level0 row3" >71</th>
#       <td id="T_ff758_row3_col0" class="data row3 col0" >FSMART</td>
#       <td id="T_ff758_row3_col1" class="data row3 col1" >14.30</td>
#       <td id="T_ff758_row3_col2" class="data row3 col2" >121</td>
#       <td id="T_ff758_row3_col3" class="data row3 col3" >-0.80</td>
#       <td id="T_ff758_row3_col4" class="data row3 col4" >-5.30</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row4" class="row_heading level0 row4" >184</th>
#       <td id="T_ff758_row4_col0" class="data row4 col0" >STARK</td>
#       <td id="T_ff758_row4_col1" class="data row4 col1" >3.16</td>
#       <td id="T_ff758_row4_col2" class="data row4 col2" >145</td>
#       <td id="T_ff758_row4_col3" class="data row4 col3" >-0.12</td>
#       <td id="T_ff758_row4_col4" class="data row4 col4" >-3.66</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row5" class="row_heading level0 row5" >180</th>
#       <td id="T_ff758_row5_col0" class="data row5 col0" >SPRIME</td>
#       <td id="T_ff758_row5_col1" class="data row5 col1" >6.75</td>
#       <td id="T_ff758_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_ff758_row5_col3" class="data row5 col3" >-0.25</td>
#       <td id="T_ff758_row5_col4" class="data row5 col4" >-3.57</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row6" class="row_heading level0 row6" >131</th>
#       <td id="T_ff758_row6_col0" class="data row6 col0" >OISHI</td>
#       <td id="T_ff758_row6_col1" class="data row6 col1" >48.50</td>
#       <td id="T_ff758_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_ff758_row6_col3" class="data row6 col3" >-1.75</td>
#       <td id="T_ff758_row6_col4" class="data row6 col4" >-3.48</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row7" class="row_heading level0 row7" >158</th>
#       <td id="T_ff758_row7_col0" class="data row7 col0" >SABUY</td>
#       <td id="T_ff758_row7_col1" class="data row7 col1" >11.70</td>
#       <td id="T_ff758_row7_col2" class="data row7 col2" >87</td>
#       <td id="T_ff758_row7_col3" class="data row7 col3" >-0.40</td>
#       <td id="T_ff758_row7_col4" class="data row7 col4" >-3.31</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row8" class="row_heading level0 row8" >42</th>
#       <td id="T_ff758_row8_col0" class="data row8 col0" >CENTEL</td>
#       <td id="T_ff758_row8_col1" class="data row8 col1" >45.75</td>
#       <td id="T_ff758_row8_col2" class="data row8 col2" >486</td>
#       <td id="T_ff758_row8_col3" class="data row8 col3" >-1.50</td>
#       <td id="T_ff758_row8_col4" class="data row8 col4" >-3.17</td>
#     </tr>
#     <tr>
#       <th id="T_ff758_level0_row9" class="row_heading level0 row9" >3</th>
#       <td id="T_ff758_row9_col0" class="data row9 col0" >AH</td>
#       <td id="T_ff758_row9_col1" class="data row9 col1" >31.00</td>
#       <td id="T_ff758_row9_col2" class="data row9 col2" >119</td>
#       <td id="T_ff758_row9_col3" class="data row9 col3" >-1.00</td>
#       <td id="T_ff758_row9_col4" class="data row9 col4" >-3.12</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d2a02_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2a02_level0_row0" class="row_heading level0 row0" >81</th>
#       <td id="T_d2a02_row0_col0" class="data row0 col0" >HANA</td>
#       <td id="T_d2a02_row0_col1" class="data row0 col1" >50.50</td>
#       <td id="T_d2a02_row0_col2" class="data row0 col2" >2,654</td>
#       <td id="T_d2a02_row0_col3" class="data row0 col3" >5.75</td>
#       <td id="T_d2a02_row0_col4" class="data row0 col4" >12.85</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row1" class="row_heading level0 row1" >147</th>
#       <td id="T_d2a02_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_d2a02_row1_col1" class="data row1 col1" >33.50</td>
#       <td id="T_d2a02_row1_col2" class="data row1 col2" >2,356</td>
#       <td id="T_d2a02_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_d2a02_row1_col4" class="data row1 col4" >1.52</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row2" class="row_heading level0 row2" >101</th>
#       <td id="T_d2a02_row2_col0" class="data row2 col0" >KCE</td>
#       <td id="T_d2a02_row2_col1" class="data row2 col1" >51.25</td>
#       <td id="T_d2a02_row2_col2" class="data row2 col2" >2,198</td>
#       <td id="T_d2a02_row2_col3" class="data row2 col3" >3.50</td>
#       <td id="T_d2a02_row2_col4" class="data row2 col4" >7.33</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_d2a02_row3_col0" class="data row3 col0" >CPALL</td>
#       <td id="T_d2a02_row3_col1" class="data row3 col1" >62.75</td>
#       <td id="T_d2a02_row3_col2" class="data row3 col2" >2,087</td>
#       <td id="T_d2a02_row3_col3" class="data row3 col3" >0.25</td>
#       <td id="T_d2a02_row3_col4" class="data row3 col4" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_d2a02_row4_col0" class="data row4 col0" >AOT</td>
#       <td id="T_d2a02_row4_col1" class="data row4 col1" >74.00</td>
#       <td id="T_d2a02_row4_col2" class="data row4 col2" >1,884</td>
#       <td id="T_d2a02_row4_col3" class="data row4 col3" >-0.50</td>
#       <td id="T_d2a02_row4_col4" class="data row4 col4" >-0.67</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row5" class="row_heading level0 row5" >57</th>
#       <td id="T_d2a02_row5_col0" class="data row5 col0" >DELTA</td>
#       <td id="T_d2a02_row5_col1" class="data row5 col1" >660.00</td>
#       <td id="T_d2a02_row5_col2" class="data row5 col2" >1,670</td>
#       <td id="T_d2a02_row5_col3" class="data row5 col3" >22.00</td>
#       <td id="T_d2a02_row5_col4" class="data row5 col4" >3.45</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row6" class="row_heading level0 row6" >148</th>
#       <td id="T_d2a02_row6_col0" class="data row6 col0" >PTTEP</td>
#       <td id="T_d2a02_row6_col1" class="data row6 col1" >187.00</td>
#       <td id="T_d2a02_row6_col2" class="data row6 col2" >1,627</td>
#       <td id="T_d2a02_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_d2a02_row6_col4" class="data row6 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row7" class="row_heading level0 row7" >33</th>
#       <td id="T_d2a02_row7_col0" class="data row7 col0" >BH</td>
#       <td id="T_d2a02_row7_col1" class="data row7 col1" >212.00</td>
#       <td id="T_d2a02_row7_col2" class="data row7 col2" >1,608</td>
#       <td id="T_d2a02_row7_col3" class="data row7 col3" >-1.00</td>
#       <td id="T_d2a02_row7_col4" class="data row7 col4" >-0.47</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_d2a02_row8_col0" class="data row8 col0" >ADVANC</td>
#       <td id="T_d2a02_row8_col1" class="data row8 col1" >190.00</td>
#       <td id="T_d2a02_row8_col2" class="data row8 col2" >1,499</td>
#       <td id="T_d2a02_row8_col3" class="data row8 col3" >3.00</td>
#       <td id="T_d2a02_row8_col4" class="data row8 col4" >1.60</td>
#     </tr>
#     <tr>
#       <th id="T_d2a02_level0_row9" class="row_heading level0 row9" >100</th>
#       <td id="T_d2a02_row9_col0" class="data row9 col0" >KBANK</td>
#       <td id="T_d2a02_row9_col1" class="data row9 col1" >143.00</td>
#       <td id="T_d2a02_row9_col2" class="data row9 col2" >1,321</td>
#       <td id="T_d2a02_row9_col3" class="data row9 col3" >-0.50</td>
#       <td id="T_d2a02_row9_col4" class="data row9 col4" >-0.35</td>
#     </tr>
#   </tbody>
# </table>
