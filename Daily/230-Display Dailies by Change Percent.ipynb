# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 28)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_186a1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_186a1_level0_row0" class="row_heading level0 row0" >175</th>
#       <td id="T_186a1_row0_col0" class="data row0 col0" >SPRC</td>
#       <td id="T_186a1_row0_col1" class="data row0 col1" >12.20</td>
#       <td id="T_186a1_row0_col2" class="data row0 col2" >362</td>
#       <td id="T_186a1_row0_col3" class="data row0 col3" >0.50</td>
#       <td id="T_186a1_row0_col4" class="data row0 col4" >4.27</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row1" class="row_heading level0 row1" >23</th>
#       <td id="T_186a1_row1_col0" class="data row1 col0" >BCP</td>
#       <td id="T_186a1_row1_col1" class="data row1 col1" >31.75</td>
#       <td id="T_186a1_row1_col2" class="data row1 col2" >232</td>
#       <td id="T_186a1_row1_col3" class="data row1 col3" >1.25</td>
#       <td id="T_186a1_row1_col4" class="data row1 col4" >4.10</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row2" class="row_heading level0 row2" >211</th>
#       <td id="T_186a1_row2_col0" class="data row2 col0" >TTA</td>
#       <td id="T_186a1_row2_col1" class="data row2 col1" >9.25</td>
#       <td id="T_186a1_row2_col2" class="data row2 col2" >142</td>
#       <td id="T_186a1_row2_col3" class="data row2 col3" >0.35</td>
#       <td id="T_186a1_row2_col4" class="data row2 col4" >3.93</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row3" class="row_heading level0 row3" >145</th>
#       <td id="T_186a1_row3_col0" class="data row3 col0" >PTTEP</td>
#       <td id="T_186a1_row3_col1" class="data row3 col1" >162.50</td>
#       <td id="T_186a1_row3_col2" class="data row3 col2" >3,632</td>
#       <td id="T_186a1_row3_col3" class="data row3 col3" >6.00</td>
#       <td id="T_186a1_row3_col4" class="data row3 col4" >3.83</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row4" class="row_heading level0 row4" >17</th>
#       <td id="T_186a1_row4_col0" class="data row4 col0" >BA</td>
#       <td id="T_186a1_row4_col1" class="data row4 col1" >11.10</td>
#       <td id="T_186a1_row4_col2" class="data row4 col2" >37</td>
#       <td id="T_186a1_row4_col3" class="data row4 col3" >0.40</td>
#       <td id="T_186a1_row4_col4" class="data row4 col4" >3.74</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row5" class="row_heading level0 row5" >94</th>
#       <td id="T_186a1_row5_col0" class="data row5 col0" >JASIF</td>
#       <td id="T_186a1_row5_col1" class="data row5 col1" >9.95</td>
#       <td id="T_186a1_row5_col2" class="data row5 col2" >609</td>
#       <td id="T_186a1_row5_col3" class="data row5 col3" >0.35</td>
#       <td id="T_186a1_row5_col4" class="data row5 col4" >3.65</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row6" class="row_heading level0 row6" >78</th>
#       <td id="T_186a1_row6_col0" class="data row6 col0" >GUNKUL</td>
#       <td id="T_186a1_row6_col1" class="data row6 col1" >5.75</td>
#       <td id="T_186a1_row6_col2" class="data row6 col2" >450</td>
#       <td id="T_186a1_row6_col3" class="data row6 col3" >0.20</td>
#       <td id="T_186a1_row6_col4" class="data row6 col4" >3.60</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row7" class="row_heading level0 row7" >144</th>
#       <td id="T_186a1_row7_col0" class="data row7 col0" >PTT</td>
#       <td id="T_186a1_row7_col1" class="data row7 col1" >35.00</td>
#       <td id="T_186a1_row7_col2" class="data row7 col2" >3,579</td>
#       <td id="T_186a1_row7_col3" class="data row7 col3" >1.00</td>
#       <td id="T_186a1_row7_col4" class="data row7 col4" >2.94</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row8" class="row_heading level0 row8" >51</th>
#       <td id="T_186a1_row8_col0" class="data row8 col0" >CPNCG</td>
#       <td id="T_186a1_row8_col1" class="data row8 col1" >11.30</td>
#       <td id="T_186a1_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_186a1_row8_col3" class="data row8 col3" >0.30</td>
#       <td id="T_186a1_row8_col4" class="data row8 col4" >2.73</td>
#     </tr>
#     <tr>
#       <th id="T_186a1_level0_row9" class="row_heading level0 row9" >154</th>
#       <td id="T_186a1_row9_col0" class="data row9 col0" >S11</td>
#       <td id="T_186a1_row9_col1" class="data row9 col1" >5.65</td>
#       <td id="T_186a1_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_186a1_row9_col3" class="data row9 col3" >0.15</td>
#       <td id="T_186a1_row9_col4" class="data row9 col4" >2.73</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_00997_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00997_level0_row0" class="row_heading level0 row0" >46</th>
#       <td id="T_00997_row0_col0" class="data row0 col0" >COM7</td>
#       <td id="T_00997_row0_col1" class="data row0 col1" >31.25</td>
#       <td id="T_00997_row0_col2" class="data row0 col2" >854</td>
#       <td id="T_00997_row0_col3" class="data row0 col3" >-1.25</td>
#       <td id="T_00997_row0_col4" class="data row0 col4" >-3.85</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row1" class="row_heading level0 row1" >187</th>
#       <td id="T_00997_row1_col0" class="data row1 col0" >TASCO</td>
#       <td id="T_00997_row1_col1" class="data row1 col1" >16.00</td>
#       <td id="T_00997_row1_col2" class="data row1 col2" >94</td>
#       <td id="T_00997_row1_col3" class="data row1 col3" >-0.40</td>
#       <td id="T_00997_row1_col4" class="data row1 col4" >-2.44</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_00997_row2_col0" class="data row2 col0" >ASIAN</td>
#       <td id="T_00997_row2_col1" class="data row2 col1" >17.40</td>
#       <td id="T_00997_row2_col2" class="data row2 col2" >181</td>
#       <td id="T_00997_row2_col3" class="data row2 col3" >-0.40</td>
#       <td id="T_00997_row2_col4" class="data row2 col4" >-2.25</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_00997_row3_col0" class="data row3 col0" >ASK</td>
#       <td id="T_00997_row3_col1" class="data row3 col1" >33.50</td>
#       <td id="T_00997_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_00997_row3_col3" class="data row3 col3" >-0.75</td>
#       <td id="T_00997_row3_col4" class="data row3 col4" >-2.19</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row4" class="row_heading level0 row4" >91</th>
#       <td id="T_00997_row4_col0" class="data row4 col0" >IP</td>
#       <td id="T_00997_row4_col1" class="data row4 col1" >18.70</td>
#       <td id="T_00997_row4_col2" class="data row4 col2" >18</td>
#       <td id="T_00997_row4_col3" class="data row4 col3" >-0.40</td>
#       <td id="T_00997_row4_col4" class="data row4 col4" >-2.09</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row5" class="row_heading level0 row5" >28</th>
#       <td id="T_00997_row5_col0" class="data row5 col0" >BEC</td>
#       <td id="T_00997_row5_col1" class="data row5 col1" >14.20</td>
#       <td id="T_00997_row5_col2" class="data row5 col2" >98</td>
#       <td id="T_00997_row5_col3" class="data row5 col3" >-0.30</td>
#       <td id="T_00997_row5_col4" class="data row5 col4" >-2.07</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row6" class="row_heading level0 row6" >32</th>
#       <td id="T_00997_row6_col0" class="data row6 col0" >BGRIM</td>
#       <td id="T_00997_row6_col1" class="data row6 col1" >36.00</td>
#       <td id="T_00997_row6_col2" class="data row6 col2" >375</td>
#       <td id="T_00997_row6_col3" class="data row6 col3" >-0.75</td>
#       <td id="T_00997_row6_col4" class="data row6 col4" >-2.04</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row7" class="row_heading level0 row7" >171</th>
#       <td id="T_00997_row7_col0" class="data row7 col0" >SNC</td>
#       <td id="T_00997_row7_col1" class="data row7 col1" >18.20</td>
#       <td id="T_00997_row7_col2" class="data row7 col2" >25</td>
#       <td id="T_00997_row7_col3" class="data row7 col3" >-0.30</td>
#       <td id="T_00997_row7_col4" class="data row7 col4" >-1.62</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row8" class="row_heading level0 row8" >69</th>
#       <td id="T_00997_row8_col0" class="data row8 col0" >FORTH</td>
#       <td id="T_00997_row8_col1" class="data row8 col1" >45.75</td>
#       <td id="T_00997_row8_col2" class="data row8 col2" >66</td>
#       <td id="T_00997_row8_col3" class="data row8 col3" >-0.75</td>
#       <td id="T_00997_row8_col4" class="data row8 col4" >-1.61</td>
#     </tr>
#     <tr>
#       <th id="T_00997_level0_row9" class="row_heading level0 row9" >4</th>
#       <td id="T_00997_row9_col0" class="data row9 col0" >AIE</td>
#       <td id="T_00997_row9_col1" class="data row9 col1" >3.72</td>
#       <td id="T_00997_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_00997_row9_col3" class="data row9 col3" >-0.06</td>
#       <td id="T_00997_row9_col4" class="data row9 col4" >-1.59</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f489_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f489_level0_row0" class="row_heading level0 row0" >145</th>
#       <td id="T_7f489_row0_col0" class="data row0 col0" >PTTEP</td>
#       <td id="T_7f489_row0_col1" class="data row0 col1" >162.50</td>
#       <td id="T_7f489_row0_col2" class="data row0 col2" >3,632</td>
#       <td id="T_7f489_row0_col3" class="data row0 col3" >6.00</td>
#       <td id="T_7f489_row0_col4" class="data row0 col4" >3.83</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row1" class="row_heading level0 row1" >144</th>
#       <td id="T_7f489_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_7f489_row1_col1" class="data row1 col1" >35.00</td>
#       <td id="T_7f489_row1_col2" class="data row1 col2" >3,579</td>
#       <td id="T_7f489_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_7f489_row1_col4" class="data row1 col4" >2.94</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_7f489_row2_col0" class="data row2 col0" >AOT</td>
#       <td id="T_7f489_row2_col1" class="data row2 col1" >72.00</td>
#       <td id="T_7f489_row2_col2" class="data row2 col2" >3,120</td>
#       <td id="T_7f489_row2_col3" class="data row2 col3" >1.75</td>
#       <td id="T_7f489_row2_col4" class="data row2 col4" >2.49</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_7f489_row3_col0" class="data row3 col0" >CPALL</td>
#       <td id="T_7f489_row3_col1" class="data row3 col1" >61.25</td>
#       <td id="T_7f489_row3_col2" class="data row3 col2" >1,725</td>
#       <td id="T_7f489_row3_col3" class="data row3 col3" >0.50</td>
#       <td id="T_7f489_row3_col4" class="data row3 col4" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row4" class="row_heading level0 row4" >160</th>
#       <td id="T_7f489_row4_col0" class="data row4 col0" >SCC</td>
#       <td id="T_7f489_row4_col1" class="data row4 col1" >382.00</td>
#       <td id="T_7f489_row4_col2" class="data row4 col2" >1,249</td>
#       <td id="T_7f489_row4_col3" class="data row4 col3" >1.00</td>
#       <td id="T_7f489_row4_col4" class="data row4 col4" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row5" class="row_heading level0 row5" >98</th>
#       <td id="T_7f489_row5_col0" class="data row5 col0" >KBANK</td>
#       <td id="T_7f489_row5_col1" class="data row5 col1" >150.50</td>
#       <td id="T_7f489_row5_col2" class="data row5 col2" >1,210</td>
#       <td id="T_7f489_row5_col3" class="data row5 col3" >0.50</td>
#       <td id="T_7f489_row5_col4" class="data row5 col4" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row6" class="row_heading level0 row6" >203</th>
#       <td id="T_7f489_row6_col0" class="data row6 col0" >TOP</td>
#       <td id="T_7f489_row6_col1" class="data row6 col1" >52.25</td>
#       <td id="T_7f489_row6_col2" class="data row6 col2" >1,066</td>
#       <td id="T_7f489_row6_col3" class="data row6 col3" >1.25</td>
#       <td id="T_7f489_row6_col4" class="data row6 col4" >2.45</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row7" class="row_heading level0 row7" >159</th>
#       <td id="T_7f489_row7_col0" class="data row7 col0" >SCB</td>
#       <td id="T_7f489_row7_col1" class="data row7 col1" >104.50</td>
#       <td id="T_7f489_row7_col2" class="data row7 col2" >973</td>
#       <td id="T_7f489_row7_col3" class="data row7 col3" >0.50</td>
#       <td id="T_7f489_row7_col4" class="data row7 col4" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_7f489_row8_col0" class="data row8 col0" >ADVANC</td>
#       <td id="T_7f489_row8_col1" class="data row8 col1" >204.00</td>
#       <td id="T_7f489_row8_col2" class="data row8 col2" >971</td>
#       <td id="T_7f489_row8_col3" class="data row8 col3" >2.00</td>
#       <td id="T_7f489_row8_col4" class="data row8 col4" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_7f489_level0_row9" class="row_heading level0 row9" >26</th>
#       <td id="T_7f489_row9_col0" class="data row9 col0" >BDMS</td>
#       <td id="T_7f489_row9_col1" class="data row9 col1" >24.90</td>
#       <td id="T_7f489_row9_col2" class="data row9 col2" >893</td>
#       <td id="T_7f489_row9_col3" class="data row9 col3" >0.10</td>
#       <td id="T_7f489_row9_col4" class="data row9 col4" >0.40</td>
#     </tr>
#   </tbody>
# </table>
