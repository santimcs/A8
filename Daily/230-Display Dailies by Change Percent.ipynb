# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 7, 1)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_56ccf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56ccf_level0_row0" class="row_heading level0 row0" >97</th>
#       <td id="T_56ccf_row0_col0" class="data row0 col0" >JWD</td>
#       <td id="T_56ccf_row0_col1" class="data row0 col1" >14.60</td>
#       <td id="T_56ccf_row0_col2" class="data row0 col2" >81</td>
#       <td id="T_56ccf_row0_col3" class="data row0 col3" >0.80</td>
#       <td id="T_56ccf_row0_col4" class="data row0 col4" >5.80</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row1" class="row_heading level0 row1" >167</th>
#       <td id="T_56ccf_row1_col0" class="data row1 col0" >SIS</td>
#       <td id="T_56ccf_row1_col1" class="data row1 col1" >27.75</td>
#       <td id="T_56ccf_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_56ccf_row1_col3" class="data row1 col3" >1.25</td>
#       <td id="T_56ccf_row1_col4" class="data row1 col4" >4.72</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_56ccf_row2_col0" class="data row2 col0" >CPALL</td>
#       <td id="T_56ccf_row2_col1" class="data row2 col1" >62.25</td>
#       <td id="T_56ccf_row2_col2" class="data row2 col2" >1,891</td>
#       <td id="T_56ccf_row2_col3" class="data row2 col3" >2.25</td>
#       <td id="T_56ccf_row2_col4" class="data row2 col4" >3.75</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row3" class="row_heading level0 row3" >76</th>
#       <td id="T_56ccf_row3_col0" class="data row3 col0" >GRAMMY</td>
#       <td id="T_56ccf_row3_col1" class="data row3 col1" >11.50</td>
#       <td id="T_56ccf_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_56ccf_row3_col3" class="data row3 col3" >0.40</td>
#       <td id="T_56ccf_row3_col4" class="data row3 col4" >3.60</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row4" class="row_heading level0 row4" >32</th>
#       <td id="T_56ccf_row4_col0" class="data row4 col0" >BGRIM</td>
#       <td id="T_56ccf_row4_col1" class="data row4 col1" >36.00</td>
#       <td id="T_56ccf_row4_col2" class="data row4 col2" >612</td>
#       <td id="T_56ccf_row4_col3" class="data row4 col3" >1.00</td>
#       <td id="T_56ccf_row4_col4" class="data row4 col4" >2.86</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row5" class="row_heading level0 row5" >75</th>
#       <td id="T_56ccf_row5_col0" class="data row5 col0" >GPSC</td>
#       <td id="T_56ccf_row5_col1" class="data row5 col1" >66.25</td>
#       <td id="T_56ccf_row5_col2" class="data row5 col2" >516</td>
#       <td id="T_56ccf_row5_col3" class="data row5 col3" >1.75</td>
#       <td id="T_56ccf_row5_col4" class="data row5 col4" >2.71</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row6" class="row_heading level0 row6" >45</th>
#       <td id="T_56ccf_row6_col0" class="data row6 col0" >CKP</td>
#       <td id="T_56ccf_row6_col1" class="data row6 col1" >5.70</td>
#       <td id="T_56ccf_row6_col2" class="data row6 col2" >40</td>
#       <td id="T_56ccf_row6_col3" class="data row6 col3" >0.15</td>
#       <td id="T_56ccf_row6_col4" class="data row6 col4" >2.70</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row7" class="row_heading level0 row7" >227</th>
#       <td id="T_56ccf_row7_col0" class="data row7 col0" >WICE</td>
#       <td id="T_56ccf_row7_col1" class="data row7 col1" >12.30</td>
#       <td id="T_56ccf_row7_col2" class="data row7 col2" >125</td>
#       <td id="T_56ccf_row7_col3" class="data row7 col3" >0.30</td>
#       <td id="T_56ccf_row7_col4" class="data row7 col4" >2.50</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row8" class="row_heading level0 row8" >64</th>
#       <td id="T_56ccf_row8_col0" class="data row8 col0" >ECL</td>
#       <td id="T_56ccf_row8_col1" class="data row8 col1" >2.56</td>
#       <td id="T_56ccf_row8_col2" class="data row8 col2" >11</td>
#       <td id="T_56ccf_row8_col3" class="data row8 col3" >0.06</td>
#       <td id="T_56ccf_row8_col4" class="data row8 col4" >2.40</td>
#     </tr>
#     <tr>
#       <th id="T_56ccf_level0_row9" class="row_heading level0 row9" >72</th>
#       <td id="T_56ccf_row9_col0" class="data row9 col0" >GFPT</td>
#       <td id="T_56ccf_row9_col1" class="data row9 col1" >17.50</td>
#       <td id="T_56ccf_row9_col2" class="data row9 col2" >104</td>
#       <td id="T_56ccf_row9_col3" class="data row9 col3" >0.40</td>
#       <td id="T_56ccf_row9_col4" class="data row9 col4" >2.34</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ad7d1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad7d1_level0_row0" class="row_heading level0 row0" >86</th>
#       <td id="T_ad7d1_row0_col0" class="data row0 col0" >IMH</td>
#       <td id="T_ad7d1_row0_col1" class="data row0 col1" >13.80</td>
#       <td id="T_ad7d1_row0_col2" class="data row0 col2" >33</td>
#       <td id="T_ad7d1_row0_col3" class="data row0 col3" >-1.60</td>
#       <td id="T_ad7d1_row0_col4" class="data row0 col4" >-10.39</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row1" class="row_heading level0 row1" >59</th>
#       <td id="T_ad7d1_row1_col0" class="data row1 col0" >DOHOME</td>
#       <td id="T_ad7d1_row1_col1" class="data row1 col1" >15.80</td>
#       <td id="T_ad7d1_row1_col2" class="data row1 col2" >274</td>
#       <td id="T_ad7d1_row1_col3" class="data row1 col3" >-1.40</td>
#       <td id="T_ad7d1_row1_col4" class="data row1 col4" >-8.14</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row2" class="row_heading level0 row2" >202</th>
#       <td id="T_ad7d1_row2_col0" class="data row2 col0" >TOA</td>
#       <td id="T_ad7d1_row2_col1" class="data row2 col1" >28.00</td>
#       <td id="T_ad7d1_row2_col2" class="data row2 col2" >39</td>
#       <td id="T_ad7d1_row2_col3" class="data row2 col3" >-1.25</td>
#       <td id="T_ad7d1_row2_col4" class="data row2 col4" >-4.27</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row3" class="row_heading level0 row3" >149</th>
#       <td id="T_ad7d1_row3_col0" class="data row3 col0" >RBF</td>
#       <td id="T_ad7d1_row3_col1" class="data row3 col1" >14.90</td>
#       <td id="T_ad7d1_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_ad7d1_row3_col3" class="data row3 col3" >-0.60</td>
#       <td id="T_ad7d1_row3_col4" class="data row3 col4" >-3.87</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row4" class="row_heading level0 row4" >123</th>
#       <td id="T_ad7d1_row4_col0" class="data row4 col0" >MEGA</td>
#       <td id="T_ad7d1_row4_col1" class="data row4 col1" >48.75</td>
#       <td id="T_ad7d1_row4_col2" class="data row4 col2" >172</td>
#       <td id="T_ad7d1_row4_col3" class="data row4 col3" >-1.75</td>
#       <td id="T_ad7d1_row4_col4" class="data row4 col4" >-3.47</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row5" class="row_heading level0 row5" >120</th>
#       <td id="T_ad7d1_row5_col0" class="data row5 col0" >MBAX</td>
#       <td id="T_ad7d1_row5_col1" class="data row5 col1" >5.65</td>
#       <td id="T_ad7d1_row5_col2" class="data row5 col2" >42</td>
#       <td id="T_ad7d1_row5_col3" class="data row5 col3" >-0.20</td>
#       <td id="T_ad7d1_row5_col4" class="data row5 col4" >-3.42</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row6" class="row_heading level0 row6" >46</th>
#       <td id="T_ad7d1_row6_col0" class="data row6 col0" >COM7</td>
#       <td id="T_ad7d1_row6_col1" class="data row6 col1" >29.00</td>
#       <td id="T_ad7d1_row6_col2" class="data row6 col2" >819</td>
#       <td id="T_ad7d1_row6_col3" class="data row6 col3" >-1.00</td>
#       <td id="T_ad7d1_row6_col4" class="data row6 col4" >-3.33</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row7" class="row_heading level0 row7" >74</th>
#       <td id="T_ad7d1_row7_col0" class="data row7 col0" >GLOBAL</td>
#       <td id="T_ad7d1_row7_col1" class="data row7 col1" >17.80</td>
#       <td id="T_ad7d1_row7_col2" class="data row7 col2" >267</td>
#       <td id="T_ad7d1_row7_col3" class="data row7 col3" >-0.60</td>
#       <td id="T_ad7d1_row7_col4" class="data row7 col4" >-3.26</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row8" class="row_heading level0 row8" >182</th>
#       <td id="T_ad7d1_row8_col0" class="data row8 col0" >STGT</td>
#       <td id="T_ad7d1_row8_col1" class="data row8 col1" >15.80</td>
#       <td id="T_ad7d1_row8_col2" class="data row8 col2" >236</td>
#       <td id="T_ad7d1_row8_col3" class="data row8 col3" >-0.50</td>
#       <td id="T_ad7d1_row8_col4" class="data row8 col4" >-3.07</td>
#     </tr>
#     <tr>
#       <th id="T_ad7d1_level0_row9" class="row_heading level0 row9" >215</th>
#       <td id="T_ad7d1_row9_col0" class="data row9 col0" >TU</td>
#       <td id="T_ad7d1_row9_col1" class="data row9 col1" >16.60</td>
#       <td id="T_ad7d1_row9_col2" class="data row9 col2" >1,347</td>
#       <td id="T_ad7d1_row9_col3" class="data row9 col3" >-0.50</td>
#       <td id="T_ad7d1_row9_col4" class="data row9 col4" >-2.92</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_209c0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_209c0_level0_row0" class="row_heading level0 row0" >98</th>
#       <td id="T_209c0_row0_col0" class="data row0 col0" >KBANK</td>
#       <td id="T_209c0_row0_col1" class="data row0 col1" >151.50</td>
#       <td id="T_209c0_row0_col2" class="data row0 col2" >2,245</td>
#       <td id="T_209c0_row0_col3" class="data row0 col3" >1.00</td>
#       <td id="T_209c0_row0_col4" class="data row0 col4" >0.66</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row1" class="row_heading level0 row1" >145</th>
#       <td id="T_209c0_row1_col0" class="data row1 col0" >PTTEP</td>
#       <td id="T_209c0_row1_col1" class="data row1 col1" >159.00</td>
#       <td id="T_209c0_row1_col2" class="data row1 col2" >2,087</td>
#       <td id="T_209c0_row1_col3" class="data row1 col3" >-0.50</td>
#       <td id="T_209c0_row1_col4" class="data row1 col4" >-0.31</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_209c0_row2_col0" class="data row2 col0" >CPALL</td>
#       <td id="T_209c0_row2_col1" class="data row2 col1" >62.25</td>
#       <td id="T_209c0_row2_col2" class="data row2 col2" >1,891</td>
#       <td id="T_209c0_row2_col3" class="data row2 col3" >2.25</td>
#       <td id="T_209c0_row2_col4" class="data row2 col4" >3.75</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_209c0_row3_col0" class="data row3 col0" >BANPU</td>
#       <td id="T_209c0_row3_col1" class="data row3 col1" >12.40</td>
#       <td id="T_209c0_row3_col2" class="data row3 col2" >1,840</td>
#       <td id="T_209c0_row3_col3" class="data row3 col3" >-0.20</td>
#       <td id="T_209c0_row3_col4" class="data row3 col4" >-1.59</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row4" class="row_heading level0 row4" >96</th>
#       <td id="T_209c0_row4_col0" class="data row4 col0" >JMT</td>
#       <td id="T_209c0_row4_col1" class="data row4 col1" >74.75</td>
#       <td id="T_209c0_row4_col2" class="data row4 col2" >1,617</td>
#       <td id="T_209c0_row4_col3" class="data row4 col3" >1.50</td>
#       <td id="T_209c0_row4_col4" class="data row4 col4" >2.05</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_209c0_row5_col0" class="data row5 col0" >AOT</td>
#       <td id="T_209c0_row5_col1" class="data row5 col1" >70.50</td>
#       <td id="T_209c0_row5_col2" class="data row5 col2" >1,435</td>
#       <td id="T_209c0_row5_col3" class="data row5 col3" >-0.50</td>
#       <td id="T_209c0_row5_col4" class="data row5 col4" >-0.70</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row6" class="row_heading level0 row6" >215</th>
#       <td id="T_209c0_row6_col0" class="data row6 col0" >TU</td>
#       <td id="T_209c0_row6_col1" class="data row6 col1" >16.60</td>
#       <td id="T_209c0_row6_col2" class="data row6 col2" >1,347</td>
#       <td id="T_209c0_row6_col3" class="data row6 col3" >-0.50</td>
#       <td id="T_209c0_row6_col4" class="data row6 col4" >-2.92</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_209c0_row7_col0" class="data row7 col0" >ADVANC</td>
#       <td id="T_209c0_row7_col1" class="data row7 col1" >197.50</td>
#       <td id="T_209c0_row7_col2" class="data row7 col2" >1,200</td>
#       <td id="T_209c0_row7_col3" class="data row7 col3" >3.00</td>
#       <td id="T_209c0_row7_col4" class="data row7 col4" >1.54</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row8" class="row_heading level0 row8" >95</th>
#       <td id="T_209c0_row8_col0" class="data row8 col0" >JMART</td>
#       <td id="T_209c0_row8_col1" class="data row8 col1" >51.75</td>
#       <td id="T_209c0_row8_col2" class="data row8 col2" >926</td>
#       <td id="T_209c0_row8_col3" class="data row8 col3" >0.75</td>
#       <td id="T_209c0_row8_col4" class="data row8 col4" >1.47</td>
#     </tr>
#     <tr>
#       <th id="T_209c0_level0_row9" class="row_heading level0 row9" >144</th>
#       <td id="T_209c0_row9_col0" class="data row9 col0" >PTT</td>
#       <td id="T_209c0_row9_col1" class="data row9 col1" >34.50</td>
#       <td id="T_209c0_row9_col2" class="data row9 col2" >919</td>
#       <td id="T_209c0_row9_col3" class="data row9 col3" >0.50</td>
#       <td id="T_209c0_row9_col4" class="data row9 col4" >1.47</td>
#     </tr>
#   </tbody>
# </table>
