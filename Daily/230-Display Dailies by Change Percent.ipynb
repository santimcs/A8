# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 17)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e62c8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e62c8_level0_row0" class="row_heading level0 row0" >69</th>
#       <td id="T_e62c8_row0_col0" class="data row0 col0" >FORTH</td>
#       <td id="T_e62c8_row0_col1" class="data row0 col1" >42.75</td>
#       <td id="T_e62c8_row0_col2" class="data row0 col2" >226</td>
#       <td id="T_e62c8_row0_col3" class="data row0 col3" >2.50</td>
#       <td id="T_e62c8_row0_col4" class="data row0 col4" >6.21</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row1" class="row_heading level0 row1" >182</th>
#       <td id="T_e62c8_row1_col0" class="data row1 col0" >STGT</td>
#       <td id="T_e62c8_row1_col1" class="data row1 col1" >17.00</td>
#       <td id="T_e62c8_row1_col2" class="data row1 col2" >382</td>
#       <td id="T_e62c8_row1_col3" class="data row1 col3" >0.90</td>
#       <td id="T_e62c8_row1_col4" class="data row1 col4" >5.59</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row2" class="row_heading level0 row2" >208</th>
#       <td id="T_e62c8_row2_col0" class="data row2 col0" >TRUE</td>
#       <td id="T_e62c8_row2_col1" class="data row2 col1" >4.64</td>
#       <td id="T_e62c8_row2_col2" class="data row2 col2" >1,330</td>
#       <td id="T_e62c8_row2_col3" class="data row2 col3" >0.22</td>
#       <td id="T_e62c8_row2_col4" class="data row2 col4" >4.98</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row3" class="row_heading level0 row3" >220</th>
#       <td id="T_e62c8_row3_col0" class="data row3 col0" >VGI</td>
#       <td id="T_e62c8_row3_col1" class="data row3 col1" >5.10</td>
#       <td id="T_e62c8_row3_col2" class="data row3 col2" >178</td>
#       <td id="T_e62c8_row3_col3" class="data row3 col3" >0.24</td>
#       <td id="T_e62c8_row3_col4" class="data row3 col4" >4.94</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row4" class="row_heading level0 row4" >75</th>
#       <td id="T_e62c8_row4_col0" class="data row4 col0" >GPSC</td>
#       <td id="T_e62c8_row4_col1" class="data row4 col1" >64.50</td>
#       <td id="T_e62c8_row4_col2" class="data row4 col2" >1,316</td>
#       <td id="T_e62c8_row4_col3" class="data row4 col3" >3.00</td>
#       <td id="T_e62c8_row4_col4" class="data row4 col4" >4.88</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row5" class="row_heading level0 row5" >56</th>
#       <td id="T_e62c8_row5_col0" class="data row5 col0" >DCON</td>
#       <td id="T_e62c8_row5_col1" class="data row5 col1" >0.44</td>
#       <td id="T_e62c8_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_e62c8_row5_col3" class="data row5 col3" >0.02</td>
#       <td id="T_e62c8_row5_col4" class="data row5 col4" >4.76</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row6" class="row_heading level0 row6" >61</th>
#       <td id="T_e62c8_row6_col0" class="data row6 col0" >DTAC</td>
#       <td id="T_e62c8_row6_col1" class="data row6 col1" >44.50</td>
#       <td id="T_e62c8_row6_col2" class="data row6 col2" >479</td>
#       <td id="T_e62c8_row6_col3" class="data row6 col3" >2.00</td>
#       <td id="T_e62c8_row6_col4" class="data row6 col4" >4.71</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row7" class="row_heading level0 row7" >202</th>
#       <td id="T_e62c8_row7_col0" class="data row7 col0" >TOA</td>
#       <td id="T_e62c8_row7_col1" class="data row7 col1" >26.25</td>
#       <td id="T_e62c8_row7_col2" class="data row7 col2" >17</td>
#       <td id="T_e62c8_row7_col3" class="data row7 col3" >1.00</td>
#       <td id="T_e62c8_row7_col4" class="data row7 col4" >3.96</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row8" class="row_heading level0 row8" >70</th>
#       <td id="T_e62c8_row8_col0" class="data row8 col0" >FSMART</td>
#       <td id="T_e62c8_row8_col1" class="data row8 col1" >18.40</td>
#       <td id="T_e62c8_row8_col2" class="data row8 col2" >108</td>
#       <td id="T_e62c8_row8_col3" class="data row8 col3" >0.70</td>
#       <td id="T_e62c8_row8_col4" class="data row8 col4" >3.95</td>
#     </tr>
#     <tr>
#       <th id="T_e62c8_level0_row9" class="row_heading level0 row9" >81</th>
#       <td id="T_e62c8_row9_col0" class="data row9 col0" >HFT</td>
#       <td id="T_e62c8_row9_col1" class="data row9 col1" >6.80</td>
#       <td id="T_e62c8_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_e62c8_row9_col3" class="data row9 col3" >0.25</td>
#       <td id="T_e62c8_row9_col4" class="data row9 col4" >3.82</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b20ce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b20ce_level0_row0" class="row_heading level0 row0" >175</th>
#       <td id="T_b20ce_row0_col0" class="data row0 col0" >SPRC</td>
#       <td id="T_b20ce_row0_col1" class="data row0 col1" >11.30</td>
#       <td id="T_b20ce_row0_col2" class="data row0 col2" >1,122</td>
#       <td id="T_b20ce_row0_col3" class="data row0 col3" >-1.20</td>
#       <td id="T_b20ce_row0_col4" class="data row0 col4" >-9.60</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row1" class="row_heading level0 row1" >68</th>
#       <td id="T_b20ce_row1_col0" class="data row1 col0" >ESSO</td>
#       <td id="T_b20ce_row1_col1" class="data row1 col1" >10.70</td>
#       <td id="T_b20ce_row1_col2" class="data row1 col2" >879</td>
#       <td id="T_b20ce_row1_col3" class="data row1 col3" >-1.10</td>
#       <td id="T_b20ce_row1_col4" class="data row1 col4" >-9.32</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row2" class="row_heading level0 row2" >23</th>
#       <td id="T_b20ce_row2_col0" class="data row2 col0" >BCP</td>
#       <td id="T_b20ce_row2_col1" class="data row2 col1" >29.25</td>
#       <td id="T_b20ce_row2_col2" class="data row2 col2" >810</td>
#       <td id="T_b20ce_row2_col3" class="data row2 col3" >-3.00</td>
#       <td id="T_b20ce_row2_col4" class="data row2 col4" >-9.30</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row3" class="row_heading level0 row3" >203</th>
#       <td id="T_b20ce_row3_col0" class="data row3 col0" >TOP</td>
#       <td id="T_b20ce_row3_col1" class="data row3 col1" >49.50</td>
#       <td id="T_b20ce_row3_col2" class="data row3 col2" >3,198</td>
#       <td id="T_b20ce_row3_col3" class="data row3 col3" >-3.75</td>
#       <td id="T_b20ce_row3_col4" class="data row3 col4" >-7.04</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row4" class="row_heading level0 row4" >92</th>
#       <td id="T_b20ce_row4_col0" class="data row4 col0" >IRPC</td>
#       <td id="T_b20ce_row4_col1" class="data row4 col1" >3.10</td>
#       <td id="T_b20ce_row4_col2" class="data row4 col2" >1,239</td>
#       <td id="T_b20ce_row4_col3" class="data row4 col3" >-0.20</td>
#       <td id="T_b20ce_row4_col4" class="data row4 col4" >-6.06</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row5" class="row_heading level0 row5" >93</th>
#       <td id="T_b20ce_row5_col0" class="data row5 col0" >IVL</td>
#       <td id="T_b20ce_row5_col1" class="data row5 col1" >47.50</td>
#       <td id="T_b20ce_row5_col2" class="data row5 col2" >1,507</td>
#       <td id="T_b20ce_row5_col3" class="data row5 col3" >-2.75</td>
#       <td id="T_b20ce_row5_col4" class="data row5 col4" >-5.47</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row6" class="row_heading level0 row6" >123</th>
#       <td id="T_b20ce_row6_col0" class="data row6 col0" >MEGA</td>
#       <td id="T_b20ce_row6_col1" class="data row6 col1" >49.00</td>
#       <td id="T_b20ce_row6_col2" class="data row6 col2" >246</td>
#       <td id="T_b20ce_row6_col3" class="data row6 col3" >-2.75</td>
#       <td id="T_b20ce_row6_col4" class="data row6 col4" >-5.31</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row7" class="row_heading level0 row7" >86</th>
#       <td id="T_b20ce_row7_col0" class="data row7 col0" >IMH</td>
#       <td id="T_b20ce_row7_col1" class="data row7 col1" >15.00</td>
#       <td id="T_b20ce_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_b20ce_row7_col3" class="data row7 col3" >-0.60</td>
#       <td id="T_b20ce_row7_col4" class="data row7 col4" >-3.85</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row8" class="row_heading level0 row8" >194</th>
#       <td id="T_b20ce_row8_col0" class="data row8 col0" >TIPH</td>
#       <td id="T_b20ce_row8_col1" class="data row8 col1" >63.75</td>
#       <td id="T_b20ce_row8_col2" class="data row8 col2" >790</td>
#       <td id="T_b20ce_row8_col3" class="data row8 col3" >-2.50</td>
#       <td id="T_b20ce_row8_col4" class="data row8 col4" >-3.77</td>
#     </tr>
#     <tr>
#       <th id="T_b20ce_level0_row9" class="row_heading level0 row9" >144</th>
#       <td id="T_b20ce_row9_col0" class="data row9 col0" >PTT</td>
#       <td id="T_b20ce_row9_col1" class="data row9 col1" >33.50</td>
#       <td id="T_b20ce_row9_col2" class="data row9 col2" >8,554</td>
#       <td id="T_b20ce_row9_col3" class="data row9 col3" >-1.25</td>
#       <td id="T_b20ce_row9_col4" class="data row9 col4" >-3.60</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9faa2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9faa2_level0_row0" class="row_heading level0 row0" >144</th>
#       <td id="T_9faa2_row0_col0" class="data row0 col0" >PTT</td>
#       <td id="T_9faa2_row0_col1" class="data row0 col1" >33.50</td>
#       <td id="T_9faa2_row0_col2" class="data row0 col2" >8,554</td>
#       <td id="T_9faa2_row0_col3" class="data row0 col3" >-1.25</td>
#       <td id="T_9faa2_row0_col4" class="data row0 col4" >-3.60</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row1" class="row_heading level0 row1" >98</th>
#       <td id="T_9faa2_row1_col0" class="data row1 col0" >KBANK</td>
#       <td id="T_9faa2_row1_col1" class="data row1 col1" >150.00</td>
#       <td id="T_9faa2_row1_col2" class="data row1 col2" >4,288</td>
#       <td id="T_9faa2_row1_col3" class="data row1 col3" >2.00</td>
#       <td id="T_9faa2_row1_col4" class="data row1 col4" >1.35</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row2" class="row_heading level0 row2" >145</th>
#       <td id="T_9faa2_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_9faa2_row2_col1" class="data row2 col1" >162.50</td>
#       <td id="T_9faa2_row2_col2" class="data row2 col2" >3,318</td>
#       <td id="T_9faa2_row2_col3" class="data row2 col3" >-3.50</td>
#       <td id="T_9faa2_row2_col4" class="data row2 col4" >-2.11</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row3" class="row_heading level0 row3" >203</th>
#       <td id="T_9faa2_row3_col0" class="data row3 col0" >TOP</td>
#       <td id="T_9faa2_row3_col1" class="data row3 col1" >49.50</td>
#       <td id="T_9faa2_row3_col2" class="data row3 col2" >3,198</td>
#       <td id="T_9faa2_row3_col3" class="data row3 col3" >-3.75</td>
#       <td id="T_9faa2_row3_col4" class="data row3 col4" >-7.04</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row4" class="row_heading level0 row4" >159</th>
#       <td id="T_9faa2_row4_col0" class="data row4 col0" >SCB</td>
#       <td id="T_9faa2_row4_col1" class="data row4 col1" >106.00</td>
#       <td id="T_9faa2_row4_col2" class="data row4 col2" >3,126</td>
#       <td id="T_9faa2_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_9faa2_row4_col4" class="data row4 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row5" class="row_heading level0 row5" >48</th>
#       <td id="T_9faa2_row5_col0" class="data row5 col0" >CPALL</td>
#       <td id="T_9faa2_row5_col1" class="data row5 col1" >60.00</td>
#       <td id="T_9faa2_row5_col2" class="data row5 col2" >2,775</td>
#       <td id="T_9faa2_row5_col3" class="data row5 col3" >0.25</td>
#       <td id="T_9faa2_row5_col4" class="data row5 col4" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_9faa2_row6_col0" class="data row6 col0" >BANPU</td>
#       <td id="T_9faa2_row6_col1" class="data row6 col1" >12.60</td>
#       <td id="T_9faa2_row6_col2" class="data row6 col2" >2,590</td>
#       <td id="T_9faa2_row6_col3" class="data row6 col3" >-0.30</td>
#       <td id="T_9faa2_row6_col4" class="data row6 col4" >-2.33</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_9faa2_row7_col0" class="data row7 col0" >AOT</td>
#       <td id="T_9faa2_row7_col1" class="data row7 col1" >67.75</td>
#       <td id="T_9faa2_row7_col2" class="data row7 col2" >2,315</td>
#       <td id="T_9faa2_row7_col3" class="data row7 col3" >0.25</td>
#       <td id="T_9faa2_row7_col4" class="data row7 col4" >0.37</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row8" class="row_heading level0 row8" >21</th>
#       <td id="T_9faa2_row8_col0" class="data row8 col0" >BBL</td>
#       <td id="T_9faa2_row8_col1" class="data row8 col1" >136.00</td>
#       <td id="T_9faa2_row8_col2" class="data row8 col2" >2,223</td>
#       <td id="T_9faa2_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_9faa2_row8_col4" class="data row8 col4" >0.74</td>
#     </tr>
#     <tr>
#       <th id="T_9faa2_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_9faa2_row9_col0" class="data row9 col0" >ADVANC</td>
#       <td id="T_9faa2_row9_col1" class="data row9 col1" >202.00</td>
#       <td id="T_9faa2_row9_col2" class="data row9 col2" >2,186</td>
#       <td id="T_9faa2_row9_col3" class="data row9 col3" >2.50</td>
#       <td id="T_9faa2_row9_col4" class="data row9 col4" >1.25</td>
#     </tr>
#   </tbody>
# </table>
