# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 14)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3bd1f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bd1f_level0_row0" class="row_heading level0 row0" >190</th>
#       <td id="T_3bd1f_row0_col0" class="data row0 col0" >TFG</td>
#       <td id="T_3bd1f_row0_col1" class="data row0 col1" >5.50</td>
#       <td id="T_3bd1f_row0_col2" class="data row0 col2" >168</td>
#       <td id="T_3bd1f_row0_col3" class="data row0 col3" >0.40</td>
#       <td id="T_3bd1f_row0_col4" class="data row0 col4" >7.84</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_3bd1f_row1_col0" class="data row1 col0" >ASIAN</td>
#       <td id="T_3bd1f_row1_col1" class="data row1 col1" >17.30</td>
#       <td id="T_3bd1f_row1_col2" class="data row1 col2" >352</td>
#       <td id="T_3bd1f_row1_col3" class="data row1 col3" >0.80</td>
#       <td id="T_3bd1f_row1_col4" class="data row1 col4" >4.85</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row2" class="row_heading level0 row2" >68</th>
#       <td id="T_3bd1f_row2_col0" class="data row2 col0" >ESSO</td>
#       <td id="T_3bd1f_row2_col1" class="data row2 col1" >12.30</td>
#       <td id="T_3bd1f_row2_col2" class="data row2 col2" >1,147</td>
#       <td id="T_3bd1f_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_3bd1f_row2_col4" class="data row2 col4" >4.24</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row3" class="row_heading level0 row3" >76</th>
#       <td id="T_3bd1f_row3_col0" class="data row3 col0" >GRAMMY</td>
#       <td id="T_3bd1f_row3_col1" class="data row3 col1" >11.50</td>
#       <td id="T_3bd1f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_3bd1f_row3_col3" class="data row3 col3" >0.40</td>
#       <td id="T_3bd1f_row3_col4" class="data row3 col4" >3.60</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row4" class="row_heading level0 row4" >93</th>
#       <td id="T_3bd1f_row4_col0" class="data row4 col0" >IVL</td>
#       <td id="T_3bd1f_row4_col1" class="data row4 col1" >51.25</td>
#       <td id="T_3bd1f_row4_col2" class="data row4 col2" >1,714</td>
#       <td id="T_3bd1f_row4_col3" class="data row4 col3" >1.75</td>
#       <td id="T_3bd1f_row4_col4" class="data row4 col4" >3.54</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row5" class="row_heading level0 row5" >192</th>
#       <td id="T_3bd1f_row5_col0" class="data row5 col0" >THG</td>
#       <td id="T_3bd1f_row5_col1" class="data row5 col1" >57.75</td>
#       <td id="T_3bd1f_row5_col2" class="data row5 col2" >387</td>
#       <td id="T_3bd1f_row5_col3" class="data row5 col3" >1.75</td>
#       <td id="T_3bd1f_row5_col4" class="data row5 col4" >3.12</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_3bd1f_row6_col0" class="data row6 col0" >BANPU</td>
#       <td id="T_3bd1f_row6_col1" class="data row6 col1" >13.40</td>
#       <td id="T_3bd1f_row6_col2" class="data row6 col2" >3,193</td>
#       <td id="T_3bd1f_row6_col3" class="data row6 col3" >0.40</td>
#       <td id="T_3bd1f_row6_col4" class="data row6 col4" >3.08</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row7" class="row_heading level0 row7" >57</th>
#       <td id="T_3bd1f_row7_col0" class="data row7 col0" >DELTA</td>
#       <td id="T_3bd1f_row7_col1" class="data row7 col1" >314.00</td>
#       <td id="T_3bd1f_row7_col2" class="data row7 col2" >324</td>
#       <td id="T_3bd1f_row7_col3" class="data row7 col3" >9.00</td>
#       <td id="T_3bd1f_row7_col4" class="data row7 col4" >2.95</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row8" class="row_heading level0 row8" >37</th>
#       <td id="T_3bd1f_row8_col0" class="data row8 col0" >BLAND</td>
#       <td id="T_3bd1f_row8_col1" class="data row8 col1" >1.05</td>
#       <td id="T_3bd1f_row8_col2" class="data row8 col2" >13</td>
#       <td id="T_3bd1f_row8_col3" class="data row8 col3" >0.03</td>
#       <td id="T_3bd1f_row8_col4" class="data row8 col4" >2.94</td>
#     </tr>
#     <tr>
#       <th id="T_3bd1f_level0_row9" class="row_heading level0 row9" >108</th>
#       <td id="T_3bd1f_row9_col0" class="data row9 col0" >LANNA</td>
#       <td id="T_3bd1f_row9_col1" class="data row9 col1" >21.00</td>
#       <td id="T_3bd1f_row9_col2" class="data row9 col2" >284</td>
#       <td id="T_3bd1f_row9_col3" class="data row9 col3" >0.60</td>
#       <td id="T_3bd1f_row9_col4" class="data row9 col4" >2.94</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8438_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8438_level0_row0" class="row_heading level0 row0" >69</th>
#       <td id="T_b8438_row0_col0" class="data row0 col0" >FORTH</td>
#       <td id="T_b8438_row0_col1" class="data row0 col1" >42.25</td>
#       <td id="T_b8438_row0_col2" class="data row0 col2" >228</td>
#       <td id="T_b8438_row0_col3" class="data row0 col3" >-1.75</td>
#       <td id="T_b8438_row0_col4" class="data row0 col4" >-3.98</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row1" class="row_heading level0 row1" >167</th>
#       <td id="T_b8438_row1_col0" class="data row1 col0" >SIS</td>
#       <td id="T_b8438_row1_col1" class="data row1 col1" >26.50</td>
#       <td id="T_b8438_row1_col2" class="data row1 col2" >44</td>
#       <td id="T_b8438_row1_col3" class="data row1 col3" >-1.00</td>
#       <td id="T_b8438_row1_col4" class="data row1 col4" >-3.64</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row2" class="row_heading level0 row2" >56</th>
#       <td id="T_b8438_row2_col0" class="data row2 col0" >DCON</td>
#       <td id="T_b8438_row2_col1" class="data row2 col1" >0.44</td>
#       <td id="T_b8438_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_b8438_row2_col3" class="data row2 col3" >-0.01</td>
#       <td id="T_b8438_row2_col4" class="data row2 col4" >-2.22</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row3" class="row_heading level0 row3" >169</th>
#       <td id="T_b8438_row3_col0" class="data row3 col0" >SKR</td>
#       <td id="T_b8438_row3_col1" class="data row3 col1" >13.30</td>
#       <td id="T_b8438_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_b8438_row3_col3" class="data row3 col3" >-0.30</td>
#       <td id="T_b8438_row3_col4" class="data row3 col4" >-2.21</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row4" class="row_heading level0 row4" >219</th>
#       <td id="T_b8438_row4_col0" class="data row4 col0" >VGI</td>
#       <td id="T_b8438_row4_col1" class="data row4 col1" >4.94</td>
#       <td id="T_b8438_row4_col2" class="data row4 col2" >130</td>
#       <td id="T_b8438_row4_col3" class="data row4 col3" >-0.11</td>
#       <td id="T_b8438_row4_col4" class="data row4 col4" >-2.18</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row5" class="row_heading level0 row5" >226</th>
#       <td id="T_b8438_row5_col0" class="data row5 col0" >WICE</td>
#       <td id="T_b8438_row5_col1" class="data row5 col1" >14.70</td>
#       <td id="T_b8438_row5_col2" class="data row5 col2" >103</td>
#       <td id="T_b8438_row5_col3" class="data row5 col3" >-0.30</td>
#       <td id="T_b8438_row5_col4" class="data row5 col4" >-2.00</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row6" class="row_heading level0 row6" >149</th>
#       <td id="T_b8438_row6_col0" class="data row6 col0" >RBF</td>
#       <td id="T_b8438_row6_col1" class="data row6 col1" >14.80</td>
#       <td id="T_b8438_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_b8438_row6_col3" class="data row6 col3" >-0.30</td>
#       <td id="T_b8438_row6_col4" class="data row6 col4" >-1.99</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row7" class="row_heading level0 row7" >47</th>
#       <td id="T_b8438_row7_col0" class="data row7 col0" >COTTO</td>
#       <td id="T_b8438_row7_col1" class="data row7 col1" >2.08</td>
#       <td id="T_b8438_row7_col2" class="data row7 col2" >12</td>
#       <td id="T_b8438_row7_col3" class="data row7 col3" >-0.04</td>
#       <td id="T_b8438_row7_col4" class="data row7 col4" >-1.89</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row8" class="row_heading level0 row8" >220</th>
#       <td id="T_b8438_row8_col0" class="data row8 col0" >VIBHA</td>
#       <td id="T_b8438_row8_col1" class="data row8 col1" >2.44</td>
#       <td id="T_b8438_row8_col2" class="data row8 col2" >20</td>
#       <td id="T_b8438_row8_col3" class="data row8 col3" >-0.04</td>
#       <td id="T_b8438_row8_col4" class="data row8 col4" >-1.61</td>
#     </tr>
#     <tr>
#       <th id="T_b8438_level0_row9" class="row_heading level0 row9" >6</th>
#       <td id="T_b8438_row9_col0" class="data row9 col0" >AIT</td>
#       <td id="T_b8438_row9_col1" class="data row9 col1" >6.20</td>
#       <td id="T_b8438_row9_col2" class="data row9 col2" >39</td>
#       <td id="T_b8438_row9_col3" class="data row9 col3" >-0.10</td>
#       <td id="T_b8438_row9_col4" class="data row9 col4" >-1.59</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b91fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b91fb_level0_row0" class="row_heading level0 row0" >19</th>
#       <td id="T_b91fb_row0_col0" class="data row0 col0" >BANPU</td>
#       <td id="T_b91fb_row0_col1" class="data row0 col1" >13.40</td>
#       <td id="T_b91fb_row0_col2" class="data row0 col2" >3,193</td>
#       <td id="T_b91fb_row0_col3" class="data row0 col3" >0.40</td>
#       <td id="T_b91fb_row0_col4" class="data row0 col4" >3.08</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row1" class="row_heading level0 row1" >93</th>
#       <td id="T_b91fb_row1_col0" class="data row1 col0" >IVL</td>
#       <td id="T_b91fb_row1_col1" class="data row1 col1" >51.25</td>
#       <td id="T_b91fb_row1_col2" class="data row1 col2" >1,714</td>
#       <td id="T_b91fb_row1_col3" class="data row1 col3" >1.75</td>
#       <td id="T_b91fb_row1_col4" class="data row1 col4" >3.54</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row2" class="row_heading level0 row2" >98</th>
#       <td id="T_b91fb_row2_col0" class="data row2 col0" >KBANK</td>
#       <td id="T_b91fb_row2_col1" class="data row2 col1" >147.50</td>
#       <td id="T_b91fb_row2_col2" class="data row2 col2" >1,702</td>
#       <td id="T_b91fb_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_b91fb_row2_col4" class="data row2 col4" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row3" class="row_heading level0 row3" >21</th>
#       <td id="T_b91fb_row3_col0" class="data row3 col0" >BBL</td>
#       <td id="T_b91fb_row3_col1" class="data row3 col1" >134.50</td>
#       <td id="T_b91fb_row3_col2" class="data row3 col2" >1,675</td>
#       <td id="T_b91fb_row3_col3" class="data row3 col3" >1.50</td>
#       <td id="T_b91fb_row3_col4" class="data row3 col4" >1.13</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_b91fb_row4_col0" class="data row4 col0" >AOT</td>
#       <td id="T_b91fb_row4_col1" class="data row4 col1" >68.00</td>
#       <td id="T_b91fb_row4_col2" class="data row4 col2" >1,563</td>
#       <td id="T_b91fb_row4_col3" class="data row4 col3" >-0.25</td>
#       <td id="T_b91fb_row4_col4" class="data row4 col4" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row5" class="row_heading level0 row5" >159</th>
#       <td id="T_b91fb_row5_col0" class="data row5 col0" >SCB</td>
#       <td id="T_b91fb_row5_col1" class="data row5 col1" >107.50</td>
#       <td id="T_b91fb_row5_col2" class="data row5 col2" >1,491</td>
#       <td id="T_b91fb_row5_col3" class="data row5 col3" >-0.50</td>
#       <td id="T_b91fb_row5_col4" class="data row5 col4" >-0.46</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row6" class="row_heading level0 row6" >203</th>
#       <td id="T_b91fb_row6_col0" class="data row6 col0" >TOP</td>
#       <td id="T_b91fb_row6_col1" class="data row6 col1" >54.50</td>
#       <td id="T_b91fb_row6_col2" class="data row6 col2" >1,457</td>
#       <td id="T_b91fb_row6_col3" class="data row6 col3" >1.00</td>
#       <td id="T_b91fb_row6_col4" class="data row6 col4" >1.87</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row7" class="row_heading level0 row7" >48</th>
#       <td id="T_b91fb_row7_col0" class="data row7 col0" >CPALL</td>
#       <td id="T_b91fb_row7_col1" class="data row7 col1" >62.25</td>
#       <td id="T_b91fb_row7_col2" class="data row7 col2" >1,391</td>
#       <td id="T_b91fb_row7_col3" class="data row7 col3" >0.50</td>
#       <td id="T_b91fb_row7_col4" class="data row7 col4" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row8" class="row_heading level0 row8" >145</th>
#       <td id="T_b91fb_row8_col0" class="data row8 col0" >PTTEP</td>
#       <td id="T_b91fb_row8_col1" class="data row8 col1" >173.50</td>
#       <td id="T_b91fb_row8_col2" class="data row8 col2" >1,283</td>
#       <td id="T_b91fb_row8_col3" class="data row8 col3" >0.50</td>
#       <td id="T_b91fb_row8_col4" class="data row8 col4" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_b91fb_level0_row9" class="row_heading level0 row9" >68</th>
#       <td id="T_b91fb_row9_col0" class="data row9 col0" >ESSO</td>
#       <td id="T_b91fb_row9_col1" class="data row9 col1" >12.30</td>
#       <td id="T_b91fb_row9_col2" class="data row9 col2" >1,147</td>
#       <td id="T_b91fb_row9_col3" class="data row9 col3" >0.50</td>
#       <td id="T_b91fb_row9_col4" class="data row9 col4" >4.24</td>
#     </tr>
#   </tbody>
# </table>
