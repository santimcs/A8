# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 27)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_763a8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_763a8_level0_row0" class="row_heading level0 row0" >70</th>
#       <td id="T_763a8_row0_col0" class="data row0 col0" >FSMART</td>
#       <td id="T_763a8_row0_col1" class="data row0 col1" >20.50</td>
#       <td id="T_763a8_row0_col2" class="data row0 col2" >234</td>
#       <td id="T_763a8_row0_col3" class="data row0 col3" >1.30</td>
#       <td id="T_763a8_row0_col4" class="data row0 col4" >6.77</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row1" class="row_heading level0 row1" >171</th>
#       <td id="T_763a8_row1_col0" class="data row1 col0" >SNC</td>
#       <td id="T_763a8_row1_col1" class="data row1 col1" >18.50</td>
#       <td id="T_763a8_row1_col2" class="data row1 col2" >35</td>
#       <td id="T_763a8_row1_col3" class="data row1 col3" >1.10</td>
#       <td id="T_763a8_row1_col4" class="data row1 col4" >6.32</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row2" class="row_heading level0 row2" >80</th>
#       <td id="T_763a8_row2_col0" class="data row2 col0" >HANA</td>
#       <td id="T_763a8_row2_col1" class="data row2 col1" >42.75</td>
#       <td id="T_763a8_row2_col2" class="data row2 col2" >749</td>
#       <td id="T_763a8_row2_col3" class="data row2 col3" >2.25</td>
#       <td id="T_763a8_row2_col4" class="data row2 col4" >5.56</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row3" class="row_heading level0 row3" >199</th>
#       <td id="T_763a8_row3_col0" class="data row3 col0" >TKS</td>
#       <td id="T_763a8_row3_col1" class="data row3 col1" >10.30</td>
#       <td id="T_763a8_row3_col2" class="data row3 col2" >31</td>
#       <td id="T_763a8_row3_col3" class="data row3 col3" >0.45</td>
#       <td id="T_763a8_row3_col4" class="data row3 col4" >4.57</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row4" class="row_heading level0 row4" >69</th>
#       <td id="T_763a8_row4_col0" class="data row4 col0" >FORTH</td>
#       <td id="T_763a8_row4_col1" class="data row4 col1" >46.50</td>
#       <td id="T_763a8_row4_col2" class="data row4 col2" >257</td>
#       <td id="T_763a8_row4_col3" class="data row4 col3" >2.00</td>
#       <td id="T_763a8_row4_col4" class="data row4 col4" >4.49</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_763a8_row5_col0" class="data row5 col0" >ACE</td>
#       <td id="T_763a8_row5_col1" class="data row5 col1" >2.84</td>
#       <td id="T_763a8_row5_col2" class="data row5 col2" >140</td>
#       <td id="T_763a8_row5_col3" class="data row5 col3" >0.12</td>
#       <td id="T_763a8_row5_col4" class="data row5 col4" >4.41</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row6" class="row_heading level0 row6" >57</th>
#       <td id="T_763a8_row6_col0" class="data row6 col0" >DELTA</td>
#       <td id="T_763a8_row6_col1" class="data row6 col1" >336.00</td>
#       <td id="T_763a8_row6_col2" class="data row6 col2" >968</td>
#       <td id="T_763a8_row6_col3" class="data row6 col3" >13.00</td>
#       <td id="T_763a8_row6_col4" class="data row6 col4" >4.02</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row7" class="row_heading level0 row7" >51</th>
#       <td id="T_763a8_row7_col0" class="data row7 col0" >CPNCG</td>
#       <td id="T_763a8_row7_col1" class="data row7 col1" >11.00</td>
#       <td id="T_763a8_row7_col2" class="data row7 col2" >7</td>
#       <td id="T_763a8_row7_col3" class="data row7 col3" >0.40</td>
#       <td id="T_763a8_row7_col4" class="data row7 col4" >3.77</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row8" class="row_heading level0 row8" >167</th>
#       <td id="T_763a8_row8_col0" class="data row8 col0" >SIS</td>
#       <td id="T_763a8_row8_col1" class="data row8 col1" >27.75</td>
#       <td id="T_763a8_row8_col2" class="data row8 col2" >36</td>
#       <td id="T_763a8_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_763a8_row8_col4" class="data row8 col4" >3.74</td>
#     </tr>
#     <tr>
#       <th id="T_763a8_level0_row9" class="row_heading level0 row9" >120</th>
#       <td id="T_763a8_row9_col0" class="data row9 col0" >MBAX</td>
#       <td id="T_763a8_row9_col1" class="data row9 col1" >5.60</td>
#       <td id="T_763a8_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_763a8_row9_col3" class="data row9 col3" >0.20</td>
#       <td id="T_763a8_row9_col4" class="data row9 col4" >3.70</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7bd0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7bd0_level0_row0" class="row_heading level0 row0" >223</th>
#       <td id="T_a7bd0_row0_col0" class="data row0 col0" >WHAIR</td>
#       <td id="T_a7bd0_row0_col1" class="data row0 col1" >7.20</td>
#       <td id="T_a7bd0_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_a7bd0_row0_col3" class="data row0 col3" >-0.20</td>
#       <td id="T_a7bd0_row0_col4" class="data row0 col4" >-2.70</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row1" class="row_heading level0 row1" >190</th>
#       <td id="T_a7bd0_row1_col0" class="data row1 col0" >TFG</td>
#       <td id="T_a7bd0_row1_col1" class="data row1 col1" >6.30</td>
#       <td id="T_a7bd0_row1_col2" class="data row1 col2" >102</td>
#       <td id="T_a7bd0_row1_col3" class="data row1 col3" >-0.15</td>
#       <td id="T_a7bd0_row1_col4" class="data row1 col4" >-2.33</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row2" class="row_heading level0 row2" >72</th>
#       <td id="T_a7bd0_row2_col0" class="data row2 col0" >GFPT</td>
#       <td id="T_a7bd0_row2_col1" class="data row2 col1" >17.50</td>
#       <td id="T_a7bd0_row2_col2" class="data row2 col2" >120</td>
#       <td id="T_a7bd0_row2_col3" class="data row2 col3" >-0.40</td>
#       <td id="T_a7bd0_row2_col4" class="data row2 col4" >-2.23</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row3" class="row_heading level0 row3" >55</th>
#       <td id="T_a7bd0_row3_col0" class="data row3 col0" >DCC</td>
#       <td id="T_a7bd0_row3_col1" class="data row3 col1" >2.76</td>
#       <td id="T_a7bd0_row3_col2" class="data row3 col2" >41</td>
#       <td id="T_a7bd0_row3_col3" class="data row3 col3" >-0.06</td>
#       <td id="T_a7bd0_row3_col4" class="data row3 col4" >-2.13</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row4" class="row_heading level0 row4" >134</th>
#       <td id="T_a7bd0_row4_col0" class="data row4 col0" >PCSGH</td>
#       <td id="T_a7bd0_row4_col1" class="data row4 col1" >5.15</td>
#       <td id="T_a7bd0_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_a7bd0_row4_col3" class="data row4 col3" >-0.10</td>
#       <td id="T_a7bd0_row4_col4" class="data row4 col4" >-1.90</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row5" class="row_heading level0 row5" >147</th>
#       <td id="T_a7bd0_row5_col0" class="data row5 col0" >QH</td>
#       <td id="T_a7bd0_row5_col1" class="data row5 col1" >2.10</td>
#       <td id="T_a7bd0_row5_col2" class="data row5 col2" >223</td>
#       <td id="T_a7bd0_row5_col3" class="data row5 col3" >-0.04</td>
#       <td id="T_a7bd0_row5_col4" class="data row5 col4" >-1.87</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row6" class="row_heading level0 row6" >118</th>
#       <td id="T_a7bd0_row6_col0" class="data row6 col0" >MAJOR</td>
#       <td id="T_a7bd0_row6_col1" class="data row6 col1" >21.50</td>
#       <td id="T_a7bd0_row6_col2" class="data row6 col2" >101</td>
#       <td id="T_a7bd0_row6_col3" class="data row6 col3" >-0.40</td>
#       <td id="T_a7bd0_row6_col4" class="data row6 col4" >-1.83</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row7" class="row_heading level0 row7" >17</th>
#       <td id="T_a7bd0_row7_col0" class="data row7 col0" >BA</td>
#       <td id="T_a7bd0_row7_col1" class="data row7 col1" >10.70</td>
#       <td id="T_a7bd0_row7_col2" class="data row7 col2" >40</td>
#       <td id="T_a7bd0_row7_col3" class="data row7 col3" >-0.20</td>
#       <td id="T_a7bd0_row7_col4" class="data row7 col4" >-1.83</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row8" class="row_heading level0 row8" >36</th>
#       <td id="T_a7bd0_row8_col0" class="data row8 col0" >BLA</td>
#       <td id="T_a7bd0_row8_col1" class="data row8 col1" >41.25</td>
#       <td id="T_a7bd0_row8_col2" class="data row8 col2" >248</td>
#       <td id="T_a7bd0_row8_col3" class="data row8 col3" >-0.75</td>
#       <td id="T_a7bd0_row8_col4" class="data row8 col4" >-1.79</td>
#     </tr>
#     <tr>
#       <th id="T_a7bd0_level0_row9" class="row_heading level0 row9" >154</th>
#       <td id="T_a7bd0_row9_col0" class="data row9 col0" >S11</td>
#       <td id="T_a7bd0_row9_col1" class="data row9 col1" >5.50</td>
#       <td id="T_a7bd0_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_a7bd0_row9_col3" class="data row9 col3" >-0.10</td>
#       <td id="T_a7bd0_row9_col4" class="data row9 col4" >-1.79</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5cc5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5cc5_level0_row0" class="row_heading level0 row0" >145</th>
#       <td id="T_c5cc5_row0_col0" class="data row0 col0" >PTTEP</td>
#       <td id="T_c5cc5_row0_col1" class="data row0 col1" >156.50</td>
#       <td id="T_c5cc5_row0_col2" class="data row0 col2" >2,688</td>
#       <td id="T_c5cc5_row0_col3" class="data row0 col3" >3.00</td>
#       <td id="T_c5cc5_row0_col4" class="data row0 col4" >1.95</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_c5cc5_row1_col0" class="data row1 col0" >BANPU</td>
#       <td id="T_c5cc5_row1_col1" class="data row1 col1" >12.50</td>
#       <td id="T_c5cc5_row1_col2" class="data row1 col2" >2,401</td>
#       <td id="T_c5cc5_row1_col3" class="data row1 col3" >0.30</td>
#       <td id="T_c5cc5_row1_col4" class="data row1 col4" >2.46</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row2" class="row_heading level0 row2" >98</th>
#       <td id="T_c5cc5_row2_col0" class="data row2 col0" >KBANK</td>
#       <td id="T_c5cc5_row2_col1" class="data row2 col1" >150.00</td>
#       <td id="T_c5cc5_row2_col2" class="data row2 col2" >2,124</td>
#       <td id="T_c5cc5_row2_col3" class="data row2 col3" >2.00</td>
#       <td id="T_c5cc5_row2_col4" class="data row2 col4" >1.35</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row3" class="row_heading level0 row3" >144</th>
#       <td id="T_c5cc5_row3_col0" class="data row3 col0" >PTT</td>
#       <td id="T_c5cc5_row3_col1" class="data row3 col1" >34.00</td>
#       <td id="T_c5cc5_row3_col2" class="data row3 col2" >2,036</td>
#       <td id="T_c5cc5_row3_col3" class="data row3 col3" >0.75</td>
#       <td id="T_c5cc5_row3_col4" class="data row3 col4" >2.26</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row4" class="row_heading level0 row4" >160</th>
#       <td id="T_c5cc5_row4_col0" class="data row4 col0" >SCC</td>
#       <td id="T_c5cc5_row4_col1" class="data row4 col1" >381.00</td>
#       <td id="T_c5cc5_row4_col2" class="data row4 col2" >1,705</td>
#       <td id="T_c5cc5_row4_col3" class="data row4 col3" >2.00</td>
#       <td id="T_c5cc5_row4_col4" class="data row4 col4" >0.53</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row5" class="row_heading level0 row5" >48</th>
#       <td id="T_c5cc5_row5_col0" class="data row5 col0" >CPALL</td>
#       <td id="T_c5cc5_row5_col1" class="data row5 col1" >60.75</td>
#       <td id="T_c5cc5_row5_col2" class="data row5 col2" >1,508</td>
#       <td id="T_c5cc5_row5_col3" class="data row5 col3" >1.25</td>
#       <td id="T_c5cc5_row5_col4" class="data row5 col4" >2.10</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_c5cc5_row6_col0" class="data row6 col0" >AOT</td>
#       <td id="T_c5cc5_row6_col1" class="data row6 col1" >70.25</td>
#       <td id="T_c5cc5_row6_col2" class="data row6 col2" >1,362</td>
#       <td id="T_c5cc5_row6_col3" class="data row6 col3" >0.50</td>
#       <td id="T_c5cc5_row6_col4" class="data row6 col4" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row7" class="row_heading level0 row7" >203</th>
#       <td id="T_c5cc5_row7_col0" class="data row7 col0" >TOP</td>
#       <td id="T_c5cc5_row7_col1" class="data row7 col1" >51.00</td>
#       <td id="T_c5cc5_row7_col2" class="data row7 col2" >1,019</td>
#       <td id="T_c5cc5_row7_col3" class="data row7 col3" >1.25</td>
#       <td id="T_c5cc5_row7_col4" class="data row7 col4" >2.51</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row8" class="row_heading level0 row8" >162</th>
#       <td id="T_c5cc5_row8_col0" class="data row8 col0" >SCGP</td>
#       <td id="T_c5cc5_row8_col1" class="data row8 col1" >56.25</td>
#       <td id="T_c5cc5_row8_col2" class="data row8 col2" >983</td>
#       <td id="T_c5cc5_row8_col3" class="data row8 col3" >1.25</td>
#       <td id="T_c5cc5_row8_col4" class="data row8 col4" >2.27</td>
#     </tr>
#     <tr>
#       <th id="T_c5cc5_level0_row9" class="row_heading level0 row9" >57</th>
#       <td id="T_c5cc5_row9_col0" class="data row9 col0" >DELTA</td>
#       <td id="T_c5cc5_row9_col1" class="data row9 col1" >336.00</td>
#       <td id="T_c5cc5_row9_col2" class="data row9 col2" >968</td>
#       <td id="T_c5cc5_row9_col3" class="data row9 col3" >13.00</td>
#       <td id="T_c5cc5_row9_col4" class="data row9 col4" >4.02</td>
#     </tr>
#   </tbody>
# </table>
