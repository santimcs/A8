# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 8, 11)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_63a56_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63a56_level0_row0" class="row_heading level0 row0" >119</th>
#       <td id="T_63a56_row0_col0" class="data row0 col0" >MACO</td>
#       <td id="T_63a56_row0_col1" class="data row0 col1" >0.52</td>
#       <td id="T_63a56_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_63a56_row0_col3" class="data row0 col3" >0.03</td>
#       <td id="T_63a56_row0_col4" class="data row0 col4" >6.12</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_63a56_row1_col0" class="data row1 col0" >AIT</td>
#       <td id="T_63a56_row1_col1" class="data row1 col1" >6.50</td>
#       <td id="T_63a56_row1_col2" class="data row1 col2" >255</td>
#       <td id="T_63a56_row1_col3" class="data row1 col3" >0.35</td>
#       <td id="T_63a56_row1_col4" class="data row1 col4" >5.69</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row2" class="row_heading level0 row2" >27</th>
#       <td id="T_63a56_row2_col0" class="data row2 col0" >BE8</td>
#       <td id="T_63a56_row2_col1" class="data row2 col1" >58.75</td>
#       <td id="T_63a56_row2_col2" class="data row2 col2" >237</td>
#       <td id="T_63a56_row2_col3" class="data row2 col3" >3.00</td>
#       <td id="T_63a56_row2_col4" class="data row2 col4" >5.38</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row3" class="row_heading level0 row3" >201</th>
#       <td id="T_63a56_row3_col0" class="data row3 col0" >TKN</td>
#       <td id="T_63a56_row3_col1" class="data row3 col1" >7.50</td>
#       <td id="T_63a56_row3_col2" class="data row3 col2" >35</td>
#       <td id="T_63a56_row3_col3" class="data row3 col3" >0.35</td>
#       <td id="T_63a56_row3_col4" class="data row3 col4" >4.90</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row4" class="row_heading level0 row4" >26</th>
#       <td id="T_63a56_row4_col0" class="data row4 col0" >BDMS</td>
#       <td id="T_63a56_row4_col1" class="data row4 col1" >28.25</td>
#       <td id="T_63a56_row4_col2" class="data row4 col2" >2,980</td>
#       <td id="T_63a56_row4_col3" class="data row4 col3" >1.25</td>
#       <td id="T_63a56_row4_col4" class="data row4 col4" >4.63</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row5" class="row_heading level0 row5" >34</th>
#       <td id="T_63a56_row5_col0" class="data row5 col0" >BH</td>
#       <td id="T_63a56_row5_col1" class="data row5 col1" >190.00</td>
#       <td id="T_63a56_row5_col2" class="data row5 col2" >3,269</td>
#       <td id="T_63a56_row5_col3" class="data row5 col3" >8.00</td>
#       <td id="T_63a56_row5_col4" class="data row5 col4" >4.40</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row6" class="row_heading level0 row6" >195</th>
#       <td id="T_63a56_row6_col0" class="data row6 col0" >THG</td>
#       <td id="T_63a56_row6_col1" class="data row6 col1" >67.00</td>
#       <td id="T_63a56_row6_col2" class="data row6 col2" >814</td>
#       <td id="T_63a56_row6_col3" class="data row6 col3" >2.50</td>
#       <td id="T_63a56_row6_col4" class="data row6 col4" >3.88</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row7" class="row_heading level0 row7" >131</th>
#       <td id="T_63a56_row7_col0" class="data row7 col0" >OISHI</td>
#       <td id="T_63a56_row7_col1" class="data row7 col1" >48.50</td>
#       <td id="T_63a56_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_63a56_row7_col3" class="data row7 col3" >1.75</td>
#       <td id="T_63a56_row7_col4" class="data row7 col4" >3.74</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row8" class="row_heading level0 row8" >82</th>
#       <td id="T_63a56_row8_col0" class="data row8 col0" >HANA</td>
#       <td id="T_63a56_row8_col1" class="data row8 col1" >44.50</td>
#       <td id="T_63a56_row8_col2" class="data row8 col2" >388</td>
#       <td id="T_63a56_row8_col3" class="data row8 col3" >1.50</td>
#       <td id="T_63a56_row8_col4" class="data row8 col4" >3.49</td>
#     </tr>
#     <tr>
#       <th id="T_63a56_level0_row9" class="row_heading level0 row9" >118</th>
#       <td id="T_63a56_row9_col0" class="data row9 col0" >M</td>
#       <td id="T_63a56_row9_col1" class="data row9 col1" >54.00</td>
#       <td id="T_63a56_row9_col2" class="data row9 col2" >259</td>
#       <td id="T_63a56_row9_col3" class="data row9 col3" >1.75</td>
#       <td id="T_63a56_row9_col4" class="data row9 col4" >3.35</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9fc65_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fc65_level0_row0" class="row_heading level0 row0" >102</th>
#       <td id="T_9fc65_row0_col0" class="data row0 col0" >KEX</td>
#       <td id="T_9fc65_row0_col1" class="data row0 col1" >21.20</td>
#       <td id="T_9fc65_row0_col2" class="data row0 col2" >390</td>
#       <td id="T_9fc65_row0_col3" class="data row0 col3" >-1.90</td>
#       <td id="T_9fc65_row0_col4" class="data row0 col4" >-8.23</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row1" class="row_heading level0 row1" >72</th>
#       <td id="T_9fc65_row1_col0" class="data row1 col0" >FSMART</td>
#       <td id="T_9fc65_row1_col1" class="data row1 col1" >19.70</td>
#       <td id="T_9fc65_row1_col2" class="data row1 col2" >242</td>
#       <td id="T_9fc65_row1_col3" class="data row1 col3" >-1.10</td>
#       <td id="T_9fc65_row1_col4" class="data row1 col4" >-5.29</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row2" class="row_heading level0 row2" >197</th>
#       <td id="T_9fc65_row2_col0" class="data row2 col0" >TIPH</td>
#       <td id="T_9fc65_row2_col1" class="data row2 col1" >57.00</td>
#       <td id="T_9fc65_row2_col2" class="data row2 col2" >356</td>
#       <td id="T_9fc65_row2_col3" class="data row2 col3" >-2.25</td>
#       <td id="T_9fc65_row2_col4" class="data row2 col4" >-3.80</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row3" class="row_heading level0 row3" >231</th>
#       <td id="T_9fc65_row3_col0" class="data row3 col0" >WORK</td>
#       <td id="T_9fc65_row3_col1" class="data row3 col1" >18.20</td>
#       <td id="T_9fc65_row3_col2" class="data row3 col2" >53</td>
#       <td id="T_9fc65_row3_col3" class="data row3 col3" >-0.70</td>
#       <td id="T_9fc65_row3_col4" class="data row3 col4" >-3.70</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row4" class="row_heading level0 row4" >213</th>
#       <td id="T_9fc65_row4_col0" class="data row4 col0" >TSTH</td>
#       <td id="T_9fc65_row4_col1" class="data row4 col1" >1.04</td>
#       <td id="T_9fc65_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_9fc65_row4_col3" class="data row4 col3" >-0.04</td>
#       <td id="T_9fc65_row4_col4" class="data row4 col4" >-3.70</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row5" class="row_heading level0 row5" >128</th>
#       <td id="T_9fc65_row5_col0" class="data row5 col0" >MTC</td>
#       <td id="T_9fc65_row5_col1" class="data row5 col1" >45.75</td>
#       <td id="T_9fc65_row5_col2" class="data row5 col2" >965</td>
#       <td id="T_9fc65_row5_col3" class="data row5 col3" >-1.75</td>
#       <td id="T_9fc65_row5_col4" class="data row5 col4" >-3.68</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_9fc65_row6_col0" class="data row6 col0" >FORTH</td>
#       <td id="T_9fc65_row6_col1" class="data row6 col1" >47.25</td>
#       <td id="T_9fc65_row6_col2" class="data row6 col2" >224</td>
#       <td id="T_9fc65_row6_col3" class="data row6 col3" >-1.75</td>
#       <td id="T_9fc65_row6_col4" class="data row6 col4" >-3.57</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row7" class="row_heading level0 row7" >13</th>
#       <td id="T_9fc65_row7_col0" class="data row7 col0" >ASK</td>
#       <td id="T_9fc65_row7_col1" class="data row7 col1" >35.50</td>
#       <td id="T_9fc65_row7_col2" class="data row7 col2" >39</td>
#       <td id="T_9fc65_row7_col3" class="data row7 col3" >-1.25</td>
#       <td id="T_9fc65_row7_col4" class="data row7 col4" >-3.40</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row8" class="row_heading level0 row8" >230</th>
#       <td id="T_9fc65_row8_col0" class="data row8 col0" >WICE</td>
#       <td id="T_9fc65_row8_col1" class="data row8 col1" >12.20</td>
#       <td id="T_9fc65_row8_col2" class="data row8 col2" >85</td>
#       <td id="T_9fc65_row8_col3" class="data row8 col3" >-0.40</td>
#       <td id="T_9fc65_row8_col4" class="data row8 col4" >-3.17</td>
#     </tr>
#     <tr>
#       <th id="T_9fc65_level0_row9" class="row_heading level0 row9" >95</th>
#       <td id="T_9fc65_row9_col0" class="data row9 col0" >IVL</td>
#       <td id="T_9fc65_row9_col1" class="data row9 col1" >42.75</td>
#       <td id="T_9fc65_row9_col2" class="data row9 col2" >3,298</td>
#       <td id="T_9fc65_row9_col3" class="data row9 col3" >-1.25</td>
#       <td id="T_9fc65_row9_col4" class="data row9 col4" >-2.84</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_05dbf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05dbf_level0_row0" class="row_heading level0 row0" >49</th>
#       <td id="T_05dbf_row0_col0" class="data row0 col0" >CPALL</td>
#       <td id="T_05dbf_row0_col1" class="data row0 col1" >60.00</td>
#       <td id="T_05dbf_row0_col2" class="data row0 col2" >3,577</td>
#       <td id="T_05dbf_row0_col3" class="data row0 col3" >-1.25</td>
#       <td id="T_05dbf_row0_col4" class="data row0 col4" >-2.04</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row1" class="row_heading level0 row1" >95</th>
#       <td id="T_05dbf_row1_col0" class="data row1 col0" >IVL</td>
#       <td id="T_05dbf_row1_col1" class="data row1 col1" >42.75</td>
#       <td id="T_05dbf_row1_col2" class="data row1 col2" >3,298</td>
#       <td id="T_05dbf_row1_col3" class="data row1 col3" >-1.25</td>
#       <td id="T_05dbf_row1_col4" class="data row1 col4" >-2.84</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row2" class="row_heading level0 row2" >34</th>
#       <td id="T_05dbf_row2_col0" class="data row2 col0" >BH</td>
#       <td id="T_05dbf_row2_col1" class="data row2 col1" >190.00</td>
#       <td id="T_05dbf_row2_col2" class="data row2 col2" >3,269</td>
#       <td id="T_05dbf_row2_col3" class="data row2 col3" >8.00</td>
#       <td id="T_05dbf_row2_col4" class="data row2 col4" >4.40</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row3" class="row_heading level0 row3" >100</th>
#       <td id="T_05dbf_row3_col0" class="data row3 col0" >KBANK</td>
#       <td id="T_05dbf_row3_col1" class="data row3 col1" >149.00</td>
#       <td id="T_05dbf_row3_col2" class="data row3 col2" >3,122</td>
#       <td id="T_05dbf_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_05dbf_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row4" class="row_heading level0 row4" >26</th>
#       <td id="T_05dbf_row4_col0" class="data row4 col0" >BDMS</td>
#       <td id="T_05dbf_row4_col1" class="data row4 col1" >28.25</td>
#       <td id="T_05dbf_row4_col2" class="data row4 col2" >2,980</td>
#       <td id="T_05dbf_row4_col3" class="data row4 col3" >1.25</td>
#       <td id="T_05dbf_row4_col4" class="data row4 col4" >4.63</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row5" class="row_heading level0 row5" >19</th>
#       <td id="T_05dbf_row5_col0" class="data row5 col0" >BANPU</td>
#       <td id="T_05dbf_row5_col1" class="data row5 col1" >13.30</td>
#       <td id="T_05dbf_row5_col2" class="data row5 col2" >2,404</td>
#       <td id="T_05dbf_row5_col3" class="data row5 col3" >0.10</td>
#       <td id="T_05dbf_row5_col4" class="data row5 col4" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row6" class="row_heading level0 row6" >58</th>
#       <td id="T_05dbf_row6_col0" class="data row6 col0" >DELTA</td>
#       <td id="T_05dbf_row6_col1" class="data row6 col1" >554.00</td>
#       <td id="T_05dbf_row6_col2" class="data row6 col2" >2,163</td>
#       <td id="T_05dbf_row6_col3" class="data row6 col3" >10.00</td>
#       <td id="T_05dbf_row6_col4" class="data row6 col4" >1.84</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row7" class="row_heading level0 row7" >98</th>
#       <td id="T_05dbf_row7_col0" class="data row7 col0" >JMT</td>
#       <td id="T_05dbf_row7_col1" class="data row7 col1" >78.00</td>
#       <td id="T_05dbf_row7_col2" class="data row7 col2" >2,137</td>
#       <td id="T_05dbf_row7_col3" class="data row7 col3" >-1.00</td>
#       <td id="T_05dbf_row7_col4" class="data row7 col4" >-1.27</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_05dbf_row8_col0" class="data row8 col0" >ADVANC</td>
#       <td id="T_05dbf_row8_col1" class="data row8 col1" >199.50</td>
#       <td id="T_05dbf_row8_col2" class="data row8 col2" >1,960</td>
#       <td id="T_05dbf_row8_col3" class="data row8 col3" >-2.50</td>
#       <td id="T_05dbf_row8_col4" class="data row8 col4" >-1.24</td>
#     </tr>
#     <tr>
#       <th id="T_05dbf_level0_row9" class="row_heading level0 row9" >147</th>
#       <td id="T_05dbf_row9_col0" class="data row9 col0" >PTT</td>
#       <td id="T_05dbf_row9_col1" class="data row9 col1" >37.00</td>
#       <td id="T_05dbf_row9_col2" class="data row9 col2" >1,876</td>
#       <td id="T_05dbf_row9_col3" class="data row9 col3" >0.25</td>
#       <td id="T_05dbf_row9_col4" class="data row9 col4" >0.68</td>
#     </tr>
#   </tbody>
# </table>
