# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 7, 7)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2d924_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d924_level0_row0" class="row_heading level0 row0" >88</th>
#       <td id="T_2d924_row0_col0" class="data row0 col0" >INGRS</td>
#       <td id="T_2d924_row0_col1" class="data row0 col1" >0.60</td>
#       <td id="T_2d924_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_2d924_row0_col3" class="data row0 col3" >0.05</td>
#       <td id="T_2d924_row0_col4" class="data row0 col4" >9.09</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row1" class="row_heading level0 row1" >100</th>
#       <td id="T_2d924_row1_col0" class="data row1 col0" >KEX</td>
#       <td id="T_2d924_row1_col1" class="data row1 col1" >26.00</td>
#       <td id="T_2d924_row1_col2" class="data row1 col2" >724</td>
#       <td id="T_2d924_row1_col3" class="data row1 col3" >2.00</td>
#       <td id="T_2d924_row1_col4" class="data row1 col4" >8.33</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row2" class="row_heading level0 row2" >84</th>
#       <td id="T_2d924_row2_col0" class="data row2 col0" >ICHI</td>
#       <td id="T_2d924_row2_col1" class="data row2 col1" >7.85</td>
#       <td id="T_2d924_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_2d924_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_2d924_row2_col4" class="data row2 col4" >6.80</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row3" class="row_heading level0 row3" >57</th>
#       <td id="T_2d924_row3_col0" class="data row3 col0" >DELTA</td>
#       <td id="T_2d924_row3_col1" class="data row3 col1" >331.00</td>
#       <td id="T_2d924_row3_col2" class="data row3 col2" >591</td>
#       <td id="T_2d924_row3_col3" class="data row3 col3" >19.00</td>
#       <td id="T_2d924_row3_col4" class="data row3 col4" >6.09</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row4" class="row_heading level0 row4" >202</th>
#       <td id="T_2d924_row4_col0" class="data row4 col0" >TOA</td>
#       <td id="T_2d924_row4_col1" class="data row4 col1" >28.00</td>
#       <td id="T_2d924_row4_col2" class="data row4 col2" >26</td>
#       <td id="T_2d924_row4_col3" class="data row4 col3" >1.50</td>
#       <td id="T_2d924_row4_col4" class="data row4 col4" >5.66</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_2d924_row5_col0" class="data row5 col0" >ASK</td>
#       <td id="T_2d924_row5_col1" class="data row5 col1" >31.25</td>
#       <td id="T_2d924_row5_col2" class="data row5 col2" >55</td>
#       <td id="T_2d924_row5_col3" class="data row5 col3" >1.50</td>
#       <td id="T_2d924_row5_col4" class="data row5 col4" >5.04</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row6" class="row_heading level0 row6" >166</th>
#       <td id="T_2d924_row6_col0" class="data row6 col0" >SINGER</td>
#       <td id="T_2d924_row6_col1" class="data row6 col1" >38.75</td>
#       <td id="T_2d924_row6_col2" class="data row6 col2" >287</td>
#       <td id="T_2d924_row6_col3" class="data row6 col3" >1.75</td>
#       <td id="T_2d924_row6_col4" class="data row6 col4" >4.73</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row7" class="row_heading level0 row7" >36</th>
#       <td id="T_2d924_row7_col0" class="data row7 col0" >BLA</td>
#       <td id="T_2d924_row7_col1" class="data row7 col1" >39.75</td>
#       <td id="T_2d924_row7_col2" class="data row7 col2" >425</td>
#       <td id="T_2d924_row7_col3" class="data row7 col3" >1.75</td>
#       <td id="T_2d924_row7_col4" class="data row7 col4" >4.61</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row8" class="row_heading level0 row8" >50</th>
#       <td id="T_2d924_row8_col0" class="data row8 col0" >CPN</td>
#       <td id="T_2d924_row8_col1" class="data row8 col1" >62.75</td>
#       <td id="T_2d924_row8_col2" class="data row8 col2" >917</td>
#       <td id="T_2d924_row8_col3" class="data row8 col3" >2.75</td>
#       <td id="T_2d924_row8_col4" class="data row8 col4" >4.58</td>
#     </tr>
#     <tr>
#       <th id="T_2d924_level0_row9" class="row_heading level0 row9" >228</th>
#       <td id="T_2d924_row9_col0" class="data row9 col0" >WORK</td>
#       <td id="T_2d924_row9_col1" class="data row9 col1" >19.80</td>
#       <td id="T_2d924_row9_col2" class="data row9 col2" >30</td>
#       <td id="T_2d924_row9_col3" class="data row9 col3" >0.80</td>
#       <td id="T_2d924_row9_col4" class="data row9 col4" >4.21</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8678_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8678_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_a8678_row0_col0" class="data row0 col0" >KTB</td>
#       <td id="T_a8678_row0_col1" class="data row0 col1" >14.70</td>
#       <td id="T_a8678_row0_col2" class="data row0 col2" >1,636</td>
#       <td id="T_a8678_row0_col3" class="data row0 col3" >-0.60</td>
#       <td id="T_a8678_row0_col4" class="data row0 col4" >-3.92</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row1" class="row_heading level0 row1" >175</th>
#       <td id="T_a8678_row1_col0" class="data row1 col0" >SPRC</td>
#       <td id="T_a8678_row1_col1" class="data row1 col1" >11.70</td>
#       <td id="T_a8678_row1_col2" class="data row1 col2" >239</td>
#       <td id="T_a8678_row1_col3" class="data row1 col3" >-0.30</td>
#       <td id="T_a8678_row1_col4" class="data row1 col4" >-2.50</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row2" class="row_heading level0 row2" >163</th>
#       <td id="T_a8678_row2_col0" class="data row2 col0" >SCGP</td>
#       <td id="T_a8678_row2_col1" class="data row2 col1" >53.50</td>
#       <td id="T_a8678_row2_col2" class="data row2 col2" >678</td>
#       <td id="T_a8678_row2_col3" class="data row2 col3" >-1.00</td>
#       <td id="T_a8678_row2_col4" class="data row2 col4" >-1.83</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row3" class="row_heading level0 row3" >113</th>
#       <td id="T_a8678_row3_col0" class="data row3 col0" >LPF</td>
#       <td id="T_a8678_row3_col1" class="data row3 col1" >14.00</td>
#       <td id="T_a8678_row3_col2" class="data row3 col2" >19</td>
#       <td id="T_a8678_row3_col3" class="data row3 col3" >-0.20</td>
#       <td id="T_a8678_row3_col4" class="data row3 col4" >-1.41</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_a8678_row4_col0" class="data row4 col0" >NOBLE</td>
#       <td id="T_a8678_row4_col1" class="data row4 col1" >4.42</td>
#       <td id="T_a8678_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_a8678_row4_col3" class="data row4 col3" >-0.06</td>
#       <td id="T_a8678_row4_col4" class="data row4 col4" >-1.34</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row5" class="row_heading level0 row5" >182</th>
#       <td id="T_a8678_row5_col0" class="data row5 col0" >STGT</td>
#       <td id="T_a8678_row5_col1" class="data row5 col1" >16.50</td>
#       <td id="T_a8678_row5_col2" class="data row5 col2" >198</td>
#       <td id="T_a8678_row5_col3" class="data row5 col3" >-0.20</td>
#       <td id="T_a8678_row5_col4" class="data row5 col4" >-1.20</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row6" class="row_heading level0 row6" >29</th>
#       <td id="T_a8678_row6_col0" class="data row6 col0" >BEM</td>
#       <td id="T_a8678_row6_col1" class="data row6 col1" >8.50</td>
#       <td id="T_a8678_row6_col2" class="data row6 col2" >847</td>
#       <td id="T_a8678_row6_col3" class="data row6 col3" >-0.10</td>
#       <td id="T_a8678_row6_col4" class="data row6 col4" >-1.16</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row7" class="row_heading level0 row7" >21</th>
#       <td id="T_a8678_row7_col0" class="data row7 col0" >BBL</td>
#       <td id="T_a8678_row7_col1" class="data row7 col1" >130.00</td>
#       <td id="T_a8678_row7_col2" class="data row7 col2" >1,651</td>
#       <td id="T_a8678_row7_col3" class="data row7 col3" >-1.50</td>
#       <td id="T_a8678_row7_col4" class="data row7 col4" >-1.14</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row8" class="row_heading level0 row8" >98</th>
#       <td id="T_a8678_row8_col0" class="data row8 col0" >KBANK</td>
#       <td id="T_a8678_row8_col1" class="data row8 col1" >146.00</td>
#       <td id="T_a8678_row8_col2" class="data row8 col2" >2,737</td>
#       <td id="T_a8678_row8_col3" class="data row8 col3" >-1.50</td>
#       <td id="T_a8678_row8_col4" class="data row8 col4" >-1.02</td>
#     </tr>
#     <tr>
#       <th id="T_a8678_level0_row9" class="row_heading level0 row9" >160</th>
#       <td id="T_a8678_row9_col0" class="data row9 col0" >SCB</td>
#       <td id="T_a8678_row9_col1" class="data row9 col1" >99.00</td>
#       <td id="T_a8678_row9_col2" class="data row9 col2" >2,011</td>
#       <td id="T_a8678_row9_col3" class="data row9 col3" >-1.00</td>
#       <td id="T_a8678_row9_col4" class="data row9 col4" >-1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9bfab_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bfab_level0_row0" class="row_heading level0 row0" >48</th>
#       <td id="T_9bfab_row0_col0" class="data row0 col0" >CPALL</td>
#       <td id="T_9bfab_row0_col1" class="data row0 col1" >64.00</td>
#       <td id="T_9bfab_row0_col2" class="data row0 col2" >3,034</td>
#       <td id="T_9bfab_row0_col3" class="data row0 col3" >2.00</td>
#       <td id="T_9bfab_row0_col4" class="data row0 col4" >3.23</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row1" class="row_heading level0 row1" >146</th>
#       <td id="T_9bfab_row1_col0" class="data row1 col0" >PTTEP</td>
#       <td id="T_9bfab_row1_col1" class="data row1 col1" >156.50</td>
#       <td id="T_9bfab_row1_col2" class="data row1 col2" >2,867</td>
#       <td id="T_9bfab_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_9bfab_row1_col4" class="data row1 col4" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row2" class="row_heading level0 row2" >98</th>
#       <td id="T_9bfab_row2_col0" class="data row2 col0" >KBANK</td>
#       <td id="T_9bfab_row2_col1" class="data row2 col1" >146.00</td>
#       <td id="T_9bfab_row2_col2" class="data row2 col2" >2,737</td>
#       <td id="T_9bfab_row2_col3" class="data row2 col3" >-1.50</td>
#       <td id="T_9bfab_row2_col4" class="data row2 col4" >-1.02</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row3" class="row_heading level0 row3" >145</th>
#       <td id="T_9bfab_row3_col0" class="data row3 col0" >PTT</td>
#       <td id="T_9bfab_row3_col1" class="data row3 col1" >34.75</td>
#       <td id="T_9bfab_row3_col2" class="data row3 col2" >2,531</td>
#       <td id="T_9bfab_row3_col3" class="data row3 col3" >0.75</td>
#       <td id="T_9bfab_row3_col4" class="data row3 col4" >2.21</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row4" class="row_heading level0 row4" >160</th>
#       <td id="T_9bfab_row4_col0" class="data row4 col0" >SCB</td>
#       <td id="T_9bfab_row4_col1" class="data row4 col1" >99.00</td>
#       <td id="T_9bfab_row4_col2" class="data row4 col2" >2,011</td>
#       <td id="T_9bfab_row4_col3" class="data row4 col3" >-1.00</td>
#       <td id="T_9bfab_row4_col4" class="data row4 col4" >-1.00</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row5" class="row_heading level0 row5" >19</th>
#       <td id="T_9bfab_row5_col0" class="data row5 col0" >BANPU</td>
#       <td id="T_9bfab_row5_col1" class="data row5 col1" >12.40</td>
#       <td id="T_9bfab_row5_col2" class="data row5 col2" >1,714</td>
#       <td id="T_9bfab_row5_col3" class="data row5 col3" >0.20</td>
#       <td id="T_9bfab_row5_col4" class="data row5 col4" >1.64</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row6" class="row_heading level0 row6" >21</th>
#       <td id="T_9bfab_row6_col0" class="data row6 col0" >BBL</td>
#       <td id="T_9bfab_row6_col1" class="data row6 col1" >130.00</td>
#       <td id="T_9bfab_row6_col2" class="data row6 col2" >1,651</td>
#       <td id="T_9bfab_row6_col3" class="data row6 col3" >-1.50</td>
#       <td id="T_9bfab_row6_col4" class="data row6 col4" >-1.14</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row7" class="row_heading level0 row7" >104</th>
#       <td id="T_9bfab_row7_col0" class="data row7 col0" >KTB</td>
#       <td id="T_9bfab_row7_col1" class="data row7 col1" >14.70</td>
#       <td id="T_9bfab_row7_col2" class="data row7 col2" >1,636</td>
#       <td id="T_9bfab_row7_col3" class="data row7 col3" >-0.60</td>
#       <td id="T_9bfab_row7_col4" class="data row7 col4" >-3.92</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_9bfab_row8_col0" class="data row8 col0" >AOT</td>
#       <td id="T_9bfab_row8_col1" class="data row8 col1" >71.25</td>
#       <td id="T_9bfab_row8_col2" class="data row8 col2" >1,598</td>
#       <td id="T_9bfab_row8_col3" class="data row8 col3" >0.75</td>
#       <td id="T_9bfab_row8_col4" class="data row8 col4" >1.06</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row9" class="row_heading level0 row9" >41</th>
#       <td id="T_9bfab_row9_col0" class="data row9 col0" >CBG</td>
#       <td id="T_9bfab_row9_col1" class="data row9 col1" >113.00</td>
#       <td id="T_9bfab_row9_col2" class="data row9 col2" >1,585</td>
#       <td id="T_9bfab_row9_col3" class="data row9 col3" >3.50</td>
#       <td id="T_9bfab_row9_col4" class="data row9 col4" >3.20</td>
#     </tr>
#   </tbody>
# </table>
