# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 12, 2)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a01e2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a01e2_level0_row0" class="row_heading level0 row0" >99</th>
#       <td id="T_a01e2_row0_col0" class="data row0 col0" >JWD</td>
#       <td id="T_a01e2_row0_col1" class="data row0 col1" >22.00</td>
#       <td id="T_a01e2_row0_col2" class="data row0 col2" >392</td>
#       <td id="T_a01e2_row0_col3" class="data row0 col3" >1.50</td>
#       <td id="T_a01e2_row0_col4" class="data row0 col4" >7.32</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row1" class="row_heading level0 row1" >151</th>
#       <td id="T_a01e2_row1_col0" class="data row1 col0" >RBF</td>
#       <td id="T_a01e2_row1_col1" class="data row1 col1" >13.30</td>
#       <td id="T_a01e2_row1_col2" class="data row1 col2" >193</td>
#       <td id="T_a01e2_row1_col3" class="data row1 col3" >0.90</td>
#       <td id="T_a01e2_row1_col4" class="data row1 col4" >7.26</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row2" class="row_heading level0 row2" >93</th>
#       <td id="T_a01e2_row2_col0" class="data row2 col0" >IP</td>
#       <td id="T_a01e2_row2_col1" class="data row2 col1" >15.00</td>
#       <td id="T_a01e2_row2_col2" class="data row2 col2" >19</td>
#       <td id="T_a01e2_row2_col3" class="data row2 col3" >0.80</td>
#       <td id="T_a01e2_row2_col4" class="data row2 col4" >5.63</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row3" class="row_heading level0 row3" >154</th>
#       <td id="T_a01e2_row3_col0" class="data row3 col0" >ROJNA</td>
#       <td id="T_a01e2_row3_col1" class="data row3 col1" >6.00</td>
#       <td id="T_a01e2_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_a01e2_row3_col3" class="data row3 col3" >0.30</td>
#       <td id="T_a01e2_row3_col4" class="data row3 col4" >5.26</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row4" class="row_heading level0 row4" >156</th>
#       <td id="T_a01e2_row4_col0" class="data row4 col0" >S11</td>
#       <td id="T_a01e2_row4_col1" class="data row4 col1" >5.05</td>
#       <td id="T_a01e2_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_a01e2_row4_col3" class="data row4 col3" >0.21</td>
#       <td id="T_a01e2_row4_col4" class="data row4 col4" >4.34</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row5" class="row_heading level0 row5" >230</th>
#       <td id="T_a01e2_row5_col0" class="data row5 col0" >WICE</td>
#       <td id="T_a01e2_row5_col1" class="data row5 col1" >11.20</td>
#       <td id="T_a01e2_row5_col2" class="data row5 col2" >59</td>
#       <td id="T_a01e2_row5_col3" class="data row5 col3" >0.40</td>
#       <td id="T_a01e2_row5_col4" class="data row5 col4" >3.70</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row6" class="row_heading level0 row6" >90</th>
#       <td id="T_a01e2_row6_col0" class="data row6 col0" >INGRS</td>
#       <td id="T_a01e2_row6_col1" class="data row6 col1" >0.59</td>
#       <td id="T_a01e2_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_a01e2_row6_col3" class="data row6 col3" >0.02</td>
#       <td id="T_a01e2_row6_col4" class="data row6 col4" >3.51</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row7" class="row_heading level0 row7" >72</th>
#       <td id="T_a01e2_row7_col0" class="data row7 col0" >GC</td>
#       <td id="T_a01e2_row7_col1" class="data row7 col1" >5.55</td>
#       <td id="T_a01e2_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_a01e2_row7_col3" class="data row7 col3" >0.15</td>
#       <td id="T_a01e2_row7_col4" class="data row7 col4" >2.78</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row8" class="row_heading level0 row8" >188</th>
#       <td id="T_a01e2_row8_col0" class="data row8 col0" >SVI</td>
#       <td id="T_a01e2_row8_col1" class="data row8 col1" >11.40</td>
#       <td id="T_a01e2_row8_col2" class="data row8 col2" >645</td>
#       <td id="T_a01e2_row8_col3" class="data row8 col3" >0.30</td>
#       <td id="T_a01e2_row8_col4" class="data row8 col4" >2.70</td>
#     </tr>
#     <tr>
#       <th id="T_a01e2_level0_row9" class="row_heading level0 row9" >56</th>
#       <td id="T_a01e2_row9_col0" class="data row9 col0" >DCON</td>
#       <td id="T_a01e2_row9_col1" class="data row9 col1" >0.38</td>
#       <td id="T_a01e2_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_a01e2_row9_col3" class="data row9 col3" >0.01</td>
#       <td id="T_a01e2_row9_col4" class="data row9 col4" >2.70</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_06b45_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06b45_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_06b45_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_06b45_row0_col1" class="data row0 col1" >33.25</td>
#       <td id="T_06b45_row0_col2" class="data row0 col2" >120</td>
#       <td id="T_06b45_row0_col3" class="data row0 col3" >-1.75</td>
#       <td id="T_06b45_row0_col4" class="data row0 col4" >-5.00</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row1" class="row_heading level0 row1" >159</th>
#       <td id="T_06b45_row1_col0" class="data row1 col0" >SAT</td>
#       <td id="T_06b45_row1_col1" class="data row1 col1" >21.30</td>
#       <td id="T_06b45_row1_col2" class="data row1 col2" >86</td>
#       <td id="T_06b45_row1_col3" class="data row1 col3" >-0.70</td>
#       <td id="T_06b45_row1_col4" class="data row1 col4" >-3.18</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row2" class="row_heading level0 row2" >170</th>
#       <td id="T_06b45_row2_col0" class="data row2 col0" >SIS</td>
#       <td id="T_06b45_row2_col1" class="data row2 col1" >26.25</td>
#       <td id="T_06b45_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_06b45_row2_col3" class="data row2 col3" >-0.75</td>
#       <td id="T_06b45_row2_col4" class="data row2 col4" >-2.78</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row3" class="row_heading level0 row3" >77</th>
#       <td id="T_06b45_row3_col0" class="data row3 col0" >GRAMMY</td>
#       <td id="T_06b45_row3_col1" class="data row3 col1" >10.70</td>
#       <td id="T_06b45_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_06b45_row3_col3" class="data row3 col3" >-0.30</td>
#       <td id="T_06b45_row3_col4" class="data row3 col4" >-2.73</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row4" class="row_heading level0 row4" >148</th>
#       <td id="T_06b45_row4_col0" class="data row4 col0" >PTTGC</td>
#       <td id="T_06b45_row4_col1" class="data row4 col1" >46.75</td>
#       <td id="T_06b45_row4_col2" class="data row4 col2" >998</td>
#       <td id="T_06b45_row4_col3" class="data row4 col3" >-1.25</td>
#       <td id="T_06b45_row4_col4" class="data row4 col4" >-2.60</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row5" class="row_heading level0 row5" >161</th>
#       <td id="T_06b45_row5_col0" class="data row5 col0" >SC</td>
#       <td id="T_06b45_row5_col1" class="data row5 col1" >4.30</td>
#       <td id="T_06b45_row5_col2" class="data row5 col2" >244</td>
#       <td id="T_06b45_row5_col3" class="data row5 col3" >-0.10</td>
#       <td id="T_06b45_row5_col4" class="data row5 col4" >-2.27</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row6" class="row_heading level0 row6" >81</th>
#       <td id="T_06b45_row6_col0" class="data row6 col0" >HANA</td>
#       <td id="T_06b45_row6_col1" class="data row6 col1" >54.50</td>
#       <td id="T_06b45_row6_col2" class="data row6 col2" >1,262</td>
#       <td id="T_06b45_row6_col3" class="data row6 col3" >-1.25</td>
#       <td id="T_06b45_row6_col4" class="data row6 col4" >-2.24</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row7" class="row_heading level0 row7" >189</th>
#       <td id="T_06b45_row7_col0" class="data row7 col0" >SYNEX</td>
#       <td id="T_06b45_row7_col1" class="data row7 col1" >17.60</td>
#       <td id="T_06b45_row7_col2" class="data row7 col2" >31</td>
#       <td id="T_06b45_row7_col3" class="data row7 col3" >-0.40</td>
#       <td id="T_06b45_row7_col4" class="data row7 col4" >-2.22</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row8" class="row_heading level0 row8" >45</th>
#       <td id="T_06b45_row8_col0" class="data row8 col0" >CKP</td>
#       <td id="T_06b45_row8_col1" class="data row8 col1" >4.76</td>
#       <td id="T_06b45_row8_col2" class="data row8 col2" >114</td>
#       <td id="T_06b45_row8_col3" class="data row8 col3" >-0.10</td>
#       <td id="T_06b45_row8_col4" class="data row8 col4" >-2.06</td>
#     </tr>
#     <tr>
#       <th id="T_06b45_level0_row9" class="row_heading level0 row9" >71</th>
#       <td id="T_06b45_row9_col0" class="data row9 col0" >FSMART</td>
#       <td id="T_06b45_row9_col1" class="data row9 col1" >14.40</td>
#       <td id="T_06b45_row9_col2" class="data row9 col2" >54</td>
#       <td id="T_06b45_row9_col3" class="data row9 col3" >-0.30</td>
#       <td id="T_06b45_row9_col4" class="data row9 col4" >-2.04</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_90e1f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90e1f_level0_row0" class="row_heading level0 row0" >57</th>
#       <td id="T_90e1f_row0_col0" class="data row0 col0" >DELTA</td>
#       <td id="T_90e1f_row0_col1" class="data row0 col1" >772.00</td>
#       <td id="T_90e1f_row0_col2" class="data row0 col2" >3,425</td>
#       <td id="T_90e1f_row0_col3" class="data row0 col3" >8.00</td>
#       <td id="T_90e1f_row0_col4" class="data row0 col4" >1.05</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row1" class="row_heading level0 row1" >147</th>
#       <td id="T_90e1f_row1_col0" class="data row1 col0" >PTTEP</td>
#       <td id="T_90e1f_row1_col1" class="data row1 col1" >182.50</td>
#       <td id="T_90e1f_row1_col2" class="data row1 col2" >2,602</td>
#       <td id="T_90e1f_row1_col3" class="data row1 col3" >-3.50</td>
#       <td id="T_90e1f_row1_col4" class="data row1 col4" >-1.88</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_90e1f_row2_col0" class="data row2 col0" >CPALL</td>
#       <td id="T_90e1f_row2_col1" class="data row2 col1" >64.75</td>
#       <td id="T_90e1f_row2_col2" class="data row2 col2" >1,589</td>
#       <td id="T_90e1f_row2_col3" class="data row2 col3" >-1.00</td>
#       <td id="T_90e1f_row2_col4" class="data row2 col4" >-1.52</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row3" class="row_heading level0 row3" >26</th>
#       <td id="T_90e1f_row3_col0" class="data row3 col0" >BDMS</td>
#       <td id="T_90e1f_row3_col1" class="data row3 col1" >29.00</td>
#       <td id="T_90e1f_row3_col2" class="data row3 col2" >1,490</td>
#       <td id="T_90e1f_row3_col3" class="data row3 col3" >-0.25</td>
#       <td id="T_90e1f_row3_col4" class="data row3 col4" >-0.85</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_90e1f_row4_col0" class="data row4 col0" >AOT</td>
#       <td id="T_90e1f_row4_col1" class="data row4 col1" >73.75</td>
#       <td id="T_90e1f_row4_col2" class="data row4 col2" >1,366</td>
#       <td id="T_90e1f_row4_col3" class="data row4 col3" >-0.25</td>
#       <td id="T_90e1f_row4_col4" class="data row4 col4" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row5" class="row_heading level0 row5" >169</th>
#       <td id="T_90e1f_row5_col0" class="data row5 col0" >SIRI</td>
#       <td id="T_90e1f_row5_col1" class="data row5 col1" >1.71</td>
#       <td id="T_90e1f_row5_col2" class="data row5 col2" >1,351</td>
#       <td id="T_90e1f_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_90e1f_row5_col4" class="data row5 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row6" class="row_heading level0 row6" >100</th>
#       <td id="T_90e1f_row6_col0" class="data row6 col0" >KBANK</td>
#       <td id="T_90e1f_row6_col1" class="data row6 col1" >142.50</td>
#       <td id="T_90e1f_row6_col2" class="data row6 col2" >1,324</td>
#       <td id="T_90e1f_row6_col3" class="data row6 col3" >-1.50</td>
#       <td id="T_90e1f_row6_col4" class="data row6 col4" >-1.04</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row7" class="row_heading level0 row7" >81</th>
#       <td id="T_90e1f_row7_col0" class="data row7 col0" >HANA</td>
#       <td id="T_90e1f_row7_col1" class="data row7 col1" >54.50</td>
#       <td id="T_90e1f_row7_col2" class="data row7 col2" >1,262</td>
#       <td id="T_90e1f_row7_col3" class="data row7 col3" >-1.25</td>
#       <td id="T_90e1f_row7_col4" class="data row7 col4" >-2.24</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row8" class="row_heading level0 row8" >163</th>
#       <td id="T_90e1f_row8_col0" class="data row8 col0" >SCC</td>
#       <td id="T_90e1f_row8_col1" class="data row8 col1" >334.00</td>
#       <td id="T_90e1f_row8_col2" class="data row8 col2" >1,007</td>
#       <td id="T_90e1f_row8_col3" class="data row8 col3" >-5.00</td>
#       <td id="T_90e1f_row8_col4" class="data row8 col4" >-1.47</td>
#     </tr>
#     <tr>
#       <th id="T_90e1f_level0_row9" class="row_heading level0 row9" >148</th>
#       <td id="T_90e1f_row9_col0" class="data row9 col0" >PTTGC</td>
#       <td id="T_90e1f_row9_col1" class="data row9 col1" >46.75</td>
#       <td id="T_90e1f_row9_col2" class="data row9 col2" >998</td>
#       <td id="T_90e1f_row9_col3" class="data row9 col3" >-1.25</td>
#       <td id="T_90e1f_row9_col4" class="data row9 col4" >-2.60</td>
#     </tr>
#   </tbody>
# </table>
