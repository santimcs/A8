# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 11, 24)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2bb0b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bb0b_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_2bb0b_row0_col0" class="data row0 col0" >ANAN</td>
#       <td id="T_2bb0b_row0_col1" class="data row0 col1" >1.47</td>
#       <td id="T_2bb0b_row0_col2" class="data row0 col2" >142</td>
#       <td id="T_2bb0b_row0_col3" class="data row0 col3" >0.14</td>
#       <td id="T_2bb0b_row0_col4" class="data row0 col4" >10.53</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row1" class="row_heading level0 row1" >88</th>
#       <td id="T_2bb0b_row1_col0" class="data row1 col0" >IMH</td>
#       <td id="T_2bb0b_row1_col1" class="data row1 col1" >14.10</td>
#       <td id="T_2bb0b_row1_col2" class="data row1 col2" >44</td>
#       <td id="T_2bb0b_row1_col3" class="data row1 col3" >1.10</td>
#       <td id="T_2bb0b_row1_col4" class="data row1 col4" >8.46</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row2" class="row_heading level0 row2" >191</th>
#       <td id="T_2bb0b_row2_col0" class="data row2 col0" >TASCO</td>
#       <td id="T_2bb0b_row2_col1" class="data row2 col1" >17.70</td>
#       <td id="T_2bb0b_row2_col2" class="data row2 col2" >280</td>
#       <td id="T_2bb0b_row2_col3" class="data row2 col3" >0.70</td>
#       <td id="T_2bb0b_row2_col4" class="data row2 col4" >4.12</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row3" class="row_heading level0 row3" >130</th>
#       <td id="T_2bb0b_row3_col0" class="data row3 col0" >NOBLE</td>
#       <td id="T_2bb0b_row3_col1" class="data row3 col1" >4.82</td>
#       <td id="T_2bb0b_row3_col2" class="data row3 col2" >18</td>
#       <td id="T_2bb0b_row3_col3" class="data row3 col3" >0.18</td>
#       <td id="T_2bb0b_row3_col4" class="data row3 col4" >3.88</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row4" class="row_heading level0 row4" >189</th>
#       <td id="T_2bb0b_row4_col0" class="data row4 col0" >SVI</td>
#       <td id="T_2bb0b_row4_col1" class="data row4 col1" >9.45</td>
#       <td id="T_2bb0b_row4_col2" class="data row4 col2" >122</td>
#       <td id="T_2bb0b_row4_col3" class="data row4 col3" >0.25</td>
#       <td id="T_2bb0b_row4_col4" class="data row4 col4" >2.72</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row5" class="row_heading level0 row5" >42</th>
#       <td id="T_2bb0b_row5_col0" class="data row5 col0" >CENTEL</td>
#       <td id="T_2bb0b_row5_col1" class="data row5 col1" >48.25</td>
#       <td id="T_2bb0b_row5_col2" class="data row5 col2" >309</td>
#       <td id="T_2bb0b_row5_col3" class="data row5 col3" >1.25</td>
#       <td id="T_2bb0b_row5_col4" class="data row5 col4" >2.66</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row6" class="row_heading level0 row6" >22</th>
#       <td id="T_2bb0b_row6_col0" class="data row6 col0" >BCH</td>
#       <td id="T_2bb0b_row6_col1" class="data row6 col1" >20.40</td>
#       <td id="T_2bb0b_row6_col2" class="data row6 col2" >698</td>
#       <td id="T_2bb0b_row6_col3" class="data row6 col3" >0.50</td>
#       <td id="T_2bb0b_row6_col4" class="data row6 col4" >2.51</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row7" class="row_heading level0 row7" >68</th>
#       <td id="T_2bb0b_row7_col0" class="data row7 col0" >ESSO</td>
#       <td id="T_2bb0b_row7_col1" class="data row7 col1" >12.70</td>
#       <td id="T_2bb0b_row7_col2" class="data row7 col2" >365</td>
#       <td id="T_2bb0b_row7_col3" class="data row7 col3" >0.30</td>
#       <td id="T_2bb0b_row7_col4" class="data row7 col4" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row8" class="row_heading level0 row8" >97</th>
#       <td id="T_2bb0b_row8_col0" class="data row8 col0" >JMART</td>
#       <td id="T_2bb0b_row8_col1" class="data row8 col1" >43.00</td>
#       <td id="T_2bb0b_row8_col2" class="data row8 col2" >315</td>
#       <td id="T_2bb0b_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_2bb0b_row8_col4" class="data row8 col4" >2.38</td>
#     </tr>
#     <tr>
#       <th id="T_2bb0b_level0_row9" class="row_heading level0 row9" >161</th>
#       <td id="T_2bb0b_row9_col0" class="data row9 col0" >SAWAD</td>
#       <td id="T_2bb0b_row9_col1" class="data row9 col1" >45.00</td>
#       <td id="T_2bb0b_row9_col2" class="data row9 col2" >609</td>
#       <td id="T_2bb0b_row9_col3" class="data row9 col3" >1.00</td>
#       <td id="T_2bb0b_row9_col4" class="data row9 col4" >2.27</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b3b97_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3b97_level0_row0" class="row_heading level0 row0" >153</th>
#       <td id="T_b3b97_row0_col0" class="data row0 col0" >RCL</td>
#       <td id="T_b3b97_row0_col1" class="data row0 col1" >28.75</td>
#       <td id="T_b3b97_row0_col2" class="data row0 col2" >184</td>
#       <td id="T_b3b97_row0_col3" class="data row0 col3" >-2.50</td>
#       <td id="T_b3b97_row0_col4" class="data row0 col4" >-8.00</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row1" class="row_heading level0 row1" >69</th>
#       <td id="T_b3b97_row1_col0" class="data row1 col0" >FORTH</td>
#       <td id="T_b3b97_row1_col1" class="data row1 col1" >35.75</td>
#       <td id="T_b3b97_row1_col2" class="data row1 col2" >162</td>
#       <td id="T_b3b97_row1_col3" class="data row1 col3" >-2.00</td>
#       <td id="T_b3b97_row1_col4" class="data row1 col4" >-5.30</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row2" class="row_heading level0 row2" >71</th>
#       <td id="T_b3b97_row2_col0" class="data row2 col0" >FSMART</td>
#       <td id="T_b3b97_row2_col1" class="data row2 col1" >13.80</td>
#       <td id="T_b3b97_row2_col2" class="data row2 col2" >130</td>
#       <td id="T_b3b97_row2_col3" class="data row2 col3" >-0.60</td>
#       <td id="T_b3b97_row2_col4" class="data row2 col4" >-4.17</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row3" class="row_heading level0 row3" >90</th>
#       <td id="T_b3b97_row3_col0" class="data row3 col0" >INGRS</td>
#       <td id="T_b3b97_row3_col1" class="data row3 col1" >0.55</td>
#       <td id="T_b3b97_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_b3b97_row3_col3" class="data row3 col3" >-0.02</td>
#       <td id="T_b3b97_row3_col4" class="data row3 col4" >-3.51</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row4" class="row_heading level0 row4" >40</th>
#       <td id="T_b3b97_row4_col0" class="data row4 col0" >BTSGIF</td>
#       <td id="T_b3b97_row4_col1" class="data row4 col1" >3.88</td>
#       <td id="T_b3b97_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_b3b97_row4_col3" class="data row4 col3" >-0.14</td>
#       <td id="T_b3b97_row4_col4" class="data row4 col4" >-3.48</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row5" class="row_heading level0 row5" >144</th>
#       <td id="T_b3b97_row5_col0" class="data row5 col0" >PSL</td>
#       <td id="T_b3b97_row5_col1" class="data row5 col1" >14.20</td>
#       <td id="T_b3b97_row5_col2" class="data row5 col2" >91</td>
#       <td id="T_b3b97_row5_col3" class="data row5 col3" >-0.50</td>
#       <td id="T_b3b97_row5_col4" class="data row5 col4" >-3.40</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row6" class="row_heading level0 row6" >174</th>
#       <td id="T_b3b97_row6_col0" class="data row6 col0" >SMPC</td>
#       <td id="T_b3b97_row6_col1" class="data row6 col1" >13.10</td>
#       <td id="T_b3b97_row6_col2" class="data row6 col2" >17</td>
#       <td id="T_b3b97_row6_col3" class="data row6 col3" >-0.40</td>
#       <td id="T_b3b97_row6_col4" class="data row6 col4" >-2.96</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row7" class="row_heading level0 row7" >56</th>
#       <td id="T_b3b97_row7_col0" class="data row7 col0" >DCON</td>
#       <td id="T_b3b97_row7_col1" class="data row7 col1" >0.37</td>
#       <td id="T_b3b97_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_b3b97_row7_col3" class="data row7 col3" >-0.01</td>
#       <td id="T_b3b97_row7_col4" class="data row7 col4" >-2.63</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row8" class="row_heading level0 row8" >121</th>
#       <td id="T_b3b97_row8_col0" class="data row8 col0" >MAKRO</td>
#       <td id="T_b3b97_row8_col1" class="data row8 col1" >38.25</td>
#       <td id="T_b3b97_row8_col2" class="data row8 col2" >602</td>
#       <td id="T_b3b97_row8_col3" class="data row8 col3" >-1.00</td>
#       <td id="T_b3b97_row8_col4" class="data row8 col4" >-2.55</td>
#     </tr>
#     <tr>
#       <th id="T_b3b97_level0_row9" class="row_heading level0 row9" >110</th>
#       <td id="T_b3b97_row9_col0" class="data row9 col0" >LANNA</td>
#       <td id="T_b3b97_row9_col1" class="data row9 col1" >17.50</td>
#       <td id="T_b3b97_row9_col2" class="data row9 col2" >42</td>
#       <td id="T_b3b97_row9_col3" class="data row9 col3" >-0.40</td>
#       <td id="T_b3b97_row9_col4" class="data row9 col4" >-2.23</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35bdd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35bdd_level0_row0" class="row_heading level0 row0" >147</th>
#       <td id="T_35bdd_row0_col0" class="data row0 col0" >PTT</td>
#       <td id="T_35bdd_row0_col1" class="data row0 col1" >33.75</td>
#       <td id="T_35bdd_row0_col2" class="data row0 col2" >1,813</td>
#       <td id="T_35bdd_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_35bdd_row0_col4" class="data row0 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_35bdd_row1_col0" class="data row1 col0" >BANPU</td>
#       <td id="T_35bdd_row1_col1" class="data row1 col1" >13.10</td>
#       <td id="T_35bdd_row1_col2" class="data row1 col2" >1,549</td>
#       <td id="T_35bdd_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_35bdd_row1_col4" class="data row1 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row2" class="row_heading level0 row2" >148</th>
#       <td id="T_35bdd_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_35bdd_row2_col1" class="data row2 col1" >190.00</td>
#       <td id="T_35bdd_row2_col2" class="data row2 col2" >1,444</td>
#       <td id="T_35bdd_row2_col3" class="data row2 col3" >-3.50</td>
#       <td id="T_35bdd_row2_col4" class="data row2 col4" >-1.81</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row3" class="row_heading level0 row3" >26</th>
#       <td id="T_35bdd_row3_col0" class="data row3 col0" >BDMS</td>
#       <td id="T_35bdd_row3_col1" class="data row3 col1" >29.50</td>
#       <td id="T_35bdd_row3_col2" class="data row3 col2" >1,269</td>
#       <td id="T_35bdd_row3_col3" class="data row3 col3" >-0.25</td>
#       <td id="T_35bdd_row3_col4" class="data row3 col4" >-0.84</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row4" class="row_heading level0 row4" >81</th>
#       <td id="T_35bdd_row4_col0" class="data row4 col0" >HANA</td>
#       <td id="T_35bdd_row4_col1" class="data row4 col1" >50.75</td>
#       <td id="T_35bdd_row4_col2" class="data row4 col2" >1,062</td>
#       <td id="T_35bdd_row4_col3" class="data row4 col3" >0.75</td>
#       <td id="T_35bdd_row4_col4" class="data row4 col4" >1.50</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_35bdd_row5_col0" class="data row5 col0" >ADVANC</td>
#       <td id="T_35bdd_row5_col1" class="data row5 col1" >189.00</td>
#       <td id="T_35bdd_row5_col2" class="data row5 col2" >895</td>
#       <td id="T_35bdd_row5_col3" class="data row5 col3" >-1.00</td>
#       <td id="T_35bdd_row5_col4" class="data row5 col4" >-0.53</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row6" class="row_heading level0 row6" >48</th>
#       <td id="T_35bdd_row6_col0" class="data row6 col0" >CPALL</td>
#       <td id="T_35bdd_row6_col1" class="data row6 col1" >63.25</td>
#       <td id="T_35bdd_row6_col2" class="data row6 col2" >878</td>
#       <td id="T_35bdd_row6_col3" class="data row6 col3" >0.50</td>
#       <td id="T_35bdd_row6_col4" class="data row6 col4" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row7" class="row_heading level0 row7" >49</th>
#       <td id="T_35bdd_row7_col0" class="data row7 col0" >CPF</td>
#       <td id="T_35bdd_row7_col1" class="data row7 col1" >23.60</td>
#       <td id="T_35bdd_row7_col2" class="data row7 col2" >855</td>
#       <td id="T_35bdd_row7_col3" class="data row7 col3" >-0.20</td>
#       <td id="T_35bdd_row7_col4" class="data row7 col4" >-0.84</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row8" class="row_heading level0 row8" >78</th>
#       <td id="T_35bdd_row8_col0" class="data row8 col0" >GULF</td>
#       <td id="T_35bdd_row8_col1" class="data row8 col1" >52.50</td>
#       <td id="T_35bdd_row8_col2" class="data row8 col2" >837</td>
#       <td id="T_35bdd_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_35bdd_row8_col4" class="data row8 col4" >1.94</td>
#     </tr>
#     <tr>
#       <th id="T_35bdd_level0_row9" class="row_heading level0 row9" >196</th>
#       <td id="T_35bdd_row9_col0" class="data row9 col0" >THG</td>
#       <td id="T_35bdd_row9_col1" class="data row9 col1" >70.25</td>
#       <td id="T_35bdd_row9_col2" class="data row9 col2" >779</td>
#       <td id="T_35bdd_row9_col3" class="data row9 col3" >-0.25</td>
#       <td id="T_35bdd_row9_col4" class="data row9 col4" >-0.35</td>
#     </tr>
#   </tbody>
# </table>
