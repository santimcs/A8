# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 7, 27)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b2207_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2207_level0_row0" class="row_heading level0 row0" >58</th>
#       <td id="T_b2207_row0_col0" class="data row0 col0" >DELTA</td>
#       <td id="T_b2207_row0_col1" class="data row0 col1" >474.00</td>
#       <td id="T_b2207_row0_col2" class="data row0 col2" >6,502</td>
#       <td id="T_b2207_row0_col3" class="data row0 col3" >106.00</td>
#       <td id="T_b2207_row0_col4" class="data row0 col4" >28.80</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row1" class="row_heading level0 row1" >186</th>
#       <td id="T_b2207_row1_col0" class="data row1 col0" >SVI</td>
#       <td id="T_b2207_row1_col1" class="data row1 col1" >7.85</td>
#       <td id="T_b2207_row1_col2" class="data row1 col2" >258</td>
#       <td id="T_b2207_row1_col3" class="data row1 col3" >0.60</td>
#       <td id="T_b2207_row1_col4" class="data row1 col4" >8.28</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row2" class="row_heading level0 row2" >64</th>
#       <td id="T_b2207_row2_col0" class="data row2 col0" >EASTW</td>
#       <td id="T_b2207_row2_col1" class="data row2 col1" >6.90</td>
#       <td id="T_b2207_row2_col2" class="data row2 col2" >22</td>
#       <td id="T_b2207_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_b2207_row2_col4" class="data row2 col4" >7.81</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row3" class="row_heading level0 row3" >100</th>
#       <td id="T_b2207_row3_col0" class="data row3 col0" >KCE</td>
#       <td id="T_b2207_row3_col1" class="data row3 col1" >62.75</td>
#       <td id="T_b2207_row3_col2" class="data row3 col2" >1,947</td>
#       <td id="T_b2207_row3_col3" class="data row3 col3" >4.25</td>
#       <td id="T_b2207_row3_col4" class="data row3 col4" >7.26</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row4" class="row_heading level0 row4" >81</th>
#       <td id="T_b2207_row4_col0" class="data row4 col0" >HANA</td>
#       <td id="T_b2207_row4_col1" class="data row4 col1" >45.75</td>
#       <td id="T_b2207_row4_col2" class="data row4 col2" >1,170</td>
#       <td id="T_b2207_row4_col3" class="data row4 col3" >2.75</td>
#       <td id="T_b2207_row4_col4" class="data row4 col4" >6.40</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row5" class="row_heading level0 row5" >219</th>
#       <td id="T_b2207_row5_col0" class="data row5 col0" >TYCN</td>
#       <td id="T_b2207_row5_col1" class="data row5 col1" >3.18</td>
#       <td id="T_b2207_row5_col2" class="data row5 col2" >23</td>
#       <td id="T_b2207_row5_col3" class="data row5 col3" >0.18</td>
#       <td id="T_b2207_row5_col4" class="data row5 col4" >6.00</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row6" class="row_heading level0 row6" >60</th>
#       <td id="T_b2207_row6_col0" class="data row6 col0" >DOHOME</td>
#       <td id="T_b2207_row6_col1" class="data row6 col1" >16.10</td>
#       <td id="T_b2207_row6_col2" class="data row6 col2" >191</td>
#       <td id="T_b2207_row6_col3" class="data row6 col3" >0.90</td>
#       <td id="T_b2207_row6_col4" class="data row6 col4" >5.92</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row7" class="row_heading level0 row7" >151</th>
#       <td id="T_b2207_row7_col0" class="data row7 col0" >RBF</td>
#       <td id="T_b2207_row7_col1" class="data row7 col1" >12.80</td>
#       <td id="T_b2207_row7_col2" class="data row7 col2" >57</td>
#       <td id="T_b2207_row7_col3" class="data row7 col3" >0.70</td>
#       <td id="T_b2207_row7_col4" class="data row7 col4" >5.79</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row8" class="row_heading level0 row8" >31</th>
#       <td id="T_b2207_row8_col0" class="data row8 col0" >BFIT</td>
#       <td id="T_b2207_row8_col1" class="data row8 col1" >28.25</td>
#       <td id="T_b2207_row8_col2" class="data row8 col2" >18</td>
#       <td id="T_b2207_row8_col3" class="data row8 col3" >1.25</td>
#       <td id="T_b2207_row8_col4" class="data row8 col4" >4.63</td>
#     </tr>
#     <tr>
#       <th id="T_b2207_level0_row9" class="row_heading level0 row9" >45</th>
#       <td id="T_b2207_row9_col0" class="data row9 col0" >CK</td>
#       <td id="T_b2207_row9_col1" class="data row9 col1" >21.40</td>
#       <td id="T_b2207_row9_col2" class="data row9 col2" >225</td>
#       <td id="T_b2207_row9_col3" class="data row9 col3" >0.90</td>
#       <td id="T_b2207_row9_col4" class="data row9 col4" >4.39</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3ef19_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ef19_level0_row0" class="row_heading level0 row0" >109</th>
#       <td id="T_3ef19_row0_col0" class="data row0 col0" >LANNA</td>
#       <td id="T_3ef19_row0_col1" class="data row0 col1" >22.60</td>
#       <td id="T_3ef19_row0_col2" class="data row0 col2" >531</td>
#       <td id="T_3ef19_row0_col3" class="data row0 col3" >-0.90</td>
#       <td id="T_3ef19_row0_col4" class="data row0 col4" >-3.83</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row1" class="row_heading level0 row1" >70</th>
#       <td id="T_3ef19_row1_col0" class="data row1 col0" >FORTH</td>
#       <td id="T_3ef19_row1_col1" class="data row1 col1" >44.50</td>
#       <td id="T_3ef19_row1_col2" class="data row1 col2" >310</td>
#       <td id="T_3ef19_row1_col3" class="data row1 col3" >-1.00</td>
#       <td id="T_3ef19_row1_col4" class="data row1 col4" >-2.20</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row2" class="row_heading level0 row2" >47</th>
#       <td id="T_3ef19_row2_col0" class="data row2 col0" >COM7</td>
#       <td id="T_3ef19_row2_col1" class="data row2 col1" >30.50</td>
#       <td id="T_3ef19_row2_col2" class="data row2 col2" >630</td>
#       <td id="T_3ef19_row2_col3" class="data row2 col3" >-0.50</td>
#       <td id="T_3ef19_row2_col4" class="data row2 col4" >-1.61</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row3" class="row_heading level0 row3" >71</th>
#       <td id="T_3ef19_row3_col0" class="data row3 col0" >FSMART</td>
#       <td id="T_3ef19_row3_col1" class="data row3 col1" >19.60</td>
#       <td id="T_3ef19_row3_col2" class="data row3 col2" >348</td>
#       <td id="T_3ef19_row3_col3" class="data row3 col3" >-0.30</td>
#       <td id="T_3ef19_row3_col4" class="data row3 col4" >-1.51</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row4" class="row_heading level0 row4" >66</th>
#       <td id="T_3ef19_row4_col0" class="data row4 col0" >EGATIF</td>
#       <td id="T_3ef19_row4_col1" class="data row4 col1" >6.55</td>
#       <td id="T_3ef19_row4_col2" class="data row4 col2" >15</td>
#       <td id="T_3ef19_row4_col3" class="data row4 col3" >-0.10</td>
#       <td id="T_3ef19_row4_col4" class="data row4 col4" >-1.50</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row5" class="row_heading level0 row5" >113</th>
#       <td id="T_3ef19_row5_col0" class="data row5 col0" >LIT</td>
#       <td id="T_3ef19_row5_col1" class="data row5 col1" >1.99</td>
#       <td id="T_3ef19_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_3ef19_row5_col3" class="data row5 col3" >-0.03</td>
#       <td id="T_3ef19_row5_col4" class="data row5 col4" >-1.49</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row6" class="row_heading level0 row6" >198</th>
#       <td id="T_3ef19_row6_col0" class="data row6 col0" >TK</td>
#       <td id="T_3ef19_row6_col1" class="data row6 col1" >9.95</td>
#       <td id="T_3ef19_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_3ef19_row6_col3" class="data row6 col3" >-0.15</td>
#       <td id="T_3ef19_row6_col4" class="data row6 col4" >-1.49</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row7" class="row_heading level0 row7" >83</th>
#       <td id="T_3ef19_row7_col0" class="data row7 col0" >HMPRO</td>
#       <td id="T_3ef19_row7_col1" class="data row7 col1" >13.30</td>
#       <td id="T_3ef19_row7_col2" class="data row7 col2" >492</td>
#       <td id="T_3ef19_row7_col3" class="data row7 col3" >-0.20</td>
#       <td id="T_3ef19_row7_col4" class="data row7 col4" >-1.48</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row8" class="row_heading level0 row8" >202</th>
#       <td id="T_3ef19_row8_col0" class="data row8 col0" >TMW</td>
#       <td id="T_3ef19_row8_col1" class="data row8 col1" >33.50</td>
#       <td id="T_3ef19_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_3ef19_row8_col3" class="data row8 col3" >-0.50</td>
#       <td id="T_3ef19_row8_col4" class="data row8 col4" >-1.47</td>
#     </tr>
#     <tr>
#       <th id="T_3ef19_level0_row9" class="row_heading level0 row9" >164</th>
#       <td id="T_3ef19_row9_col0" class="data row9 col0" >SCGP</td>
#       <td id="T_3ef19_row9_col1" class="data row9 col1" >51.00</td>
#       <td id="T_3ef19_row9_col2" class="data row9 col2" >1,094</td>
#       <td id="T_3ef19_row9_col3" class="data row9 col3" >-0.75</td>
#       <td id="T_3ef19_row9_col4" class="data row9 col4" >-1.45</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_56f4d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56f4d_level0_row0" class="row_heading level0 row0" >58</th>
#       <td id="T_56f4d_row0_col0" class="data row0 col0" >DELTA</td>
#       <td id="T_56f4d_row0_col1" class="data row0 col1" >474.00</td>
#       <td id="T_56f4d_row0_col2" class="data row0 col2" >6,502</td>
#       <td id="T_56f4d_row0_col3" class="data row0 col3" >106.00</td>
#       <td id="T_56f4d_row0_col4" class="data row0 col4" >28.80</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_56f4d_row1_col0" class="data row1 col0" >BANPU</td>
#       <td id="T_56f4d_row1_col1" class="data row1 col1" >13.40</td>
#       <td id="T_56f4d_row1_col2" class="data row1 col2" >2,099</td>
#       <td id="T_56f4d_row1_col3" class="data row1 col3" >0.30</td>
#       <td id="T_56f4d_row1_col4" class="data row1 col4" >2.29</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row2" class="row_heading level0 row2" >99</th>
#       <td id="T_56f4d_row2_col0" class="data row2 col0" >KBANK</td>
#       <td id="T_56f4d_row2_col1" class="data row2 col1" >146.00</td>
#       <td id="T_56f4d_row2_col2" class="data row2 col2" >1,996</td>
#       <td id="T_56f4d_row2_col3" class="data row2 col3" >1.00</td>
#       <td id="T_56f4d_row2_col4" class="data row2 col4" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row3" class="row_heading level0 row3" >100</th>
#       <td id="T_56f4d_row3_col0" class="data row3 col0" >KCE</td>
#       <td id="T_56f4d_row3_col1" class="data row3 col1" >62.75</td>
#       <td id="T_56f4d_row3_col2" class="data row3 col2" >1,947</td>
#       <td id="T_56f4d_row3_col3" class="data row3 col3" >4.25</td>
#       <td id="T_56f4d_row3_col4" class="data row3 col4" >7.26</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row4" class="row_heading level0 row4" >147</th>
#       <td id="T_56f4d_row4_col0" class="data row4 col0" >PTTEP</td>
#       <td id="T_56f4d_row4_col1" class="data row4 col1" >162.50</td>
#       <td id="T_56f4d_row4_col2" class="data row4 col2" >1,414</td>
#       <td id="T_56f4d_row4_col3" class="data row4 col3" >1.00</td>
#       <td id="T_56f4d_row4_col4" class="data row4 col4" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row5" class="row_heading level0 row5" >162</th>
#       <td id="T_56f4d_row5_col0" class="data row5 col0" >SCC</td>
#       <td id="T_56f4d_row5_col1" class="data row5 col1" >373.00</td>
#       <td id="T_56f4d_row5_col2" class="data row5 col2" >1,356</td>
#       <td id="T_56f4d_row5_col3" class="data row5 col3" >3.00</td>
#       <td id="T_56f4d_row5_col4" class="data row5 col4" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row6" class="row_heading level0 row6" >11</th>
#       <td id="T_56f4d_row6_col0" class="data row6 col0" >AOT</td>
#       <td id="T_56f4d_row6_col1" class="data row6 col1" >70.25</td>
#       <td id="T_56f4d_row6_col2" class="data row6 col2" >1,219</td>
#       <td id="T_56f4d_row6_col3" class="data row6 col3" >1.00</td>
#       <td id="T_56f4d_row6_col4" class="data row6 col4" >1.44</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row7" class="row_heading level0 row7" >81</th>
#       <td id="T_56f4d_row7_col0" class="data row7 col0" >HANA</td>
#       <td id="T_56f4d_row7_col1" class="data row7 col1" >45.75</td>
#       <td id="T_56f4d_row7_col2" class="data row7 col2" >1,170</td>
#       <td id="T_56f4d_row7_col3" class="data row7 col3" >2.75</td>
#       <td id="T_56f4d_row7_col4" class="data row7 col4" >6.40</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row8" class="row_heading level0 row8" >161</th>
#       <td id="T_56f4d_row8_col0" class="data row8 col0" >SCB</td>
#       <td id="T_56f4d_row8_col1" class="data row8 col1" >101.50</td>
#       <td id="T_56f4d_row8_col2" class="data row8 col2" >1,167</td>
#       <td id="T_56f4d_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_56f4d_row8_col4" class="data row8 col4" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_56f4d_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_56f4d_row9_col0" class="data row9 col0" >ADVANC</td>
#       <td id="T_56f4d_row9_col1" class="data row9 col1" >201.00</td>
#       <td id="T_56f4d_row9_col2" class="data row9 col2" >1,151</td>
#       <td id="T_56f4d_row9_col3" class="data row9 col3" >3.00</td>
#       <td id="T_56f4d_row9_col4" class="data row9 col4" >1.52</td>
#     </tr>
#   </tbody>
# </table>
