# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 8, 16)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b231f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b231f_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_b231f_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_b231f_row0_col1" class="data row0 col1" >23.00</td>
#       <td id="T_b231f_row0_col2" class="data row0 col2" >97</td>
#       <td id="T_b231f_row0_col3" class="data row0 col3" >1.80</td>
#       <td id="T_b231f_row0_col4" class="data row0 col4" >8.49</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row1" class="row_heading level0 row1" >58</th>
#       <td id="T_b231f_row1_col0" class="data row1 col0" >DELTA</td>
#       <td id="T_b231f_row1_col1" class="data row1 col1" >590.00</td>
#       <td id="T_b231f_row1_col2" class="data row1 col2" >4,175</td>
#       <td id="T_b231f_row1_col3" class="data row1 col3" >40.00</td>
#       <td id="T_b231f_row1_col4" class="data row1 col4" >7.27</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row2" class="row_heading level0 row2" >152</th>
#       <td id="T_b231f_row2_col0" class="data row2 col0" >RBF</td>
#       <td id="T_b231f_row2_col1" class="data row2 col1" >13.80</td>
#       <td id="T_b231f_row2_col2" class="data row2 col2" >201</td>
#       <td id="T_b231f_row2_col3" class="data row2 col3" >0.70</td>
#       <td id="T_b231f_row2_col4" class="data row2 col4" >5.34</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row3" class="row_heading level0 row3" >178</th>
#       <td id="T_b231f_row3_col0" class="data row3 col0" >SPRC</td>
#       <td id="T_b231f_row3_col1" class="data row3 col1" >12.30</td>
#       <td id="T_b231f_row3_col2" class="data row3 col2" >761</td>
#       <td id="T_b231f_row3_col3" class="data row3 col3" >0.60</td>
#       <td id="T_b231f_row3_col4" class="data row3 col4" >5.13</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row4" class="row_heading level0 row4" >221</th>
#       <td id="T_b231f_row4_col0" class="data row4 col0" >TYCN</td>
#       <td id="T_b231f_row4_col1" class="data row4 col1" >3.14</td>
#       <td id="T_b231f_row4_col2" class="data row4 col2" >62</td>
#       <td id="T_b231f_row4_col3" class="data row4 col3" >0.14</td>
#       <td id="T_b231f_row4_col4" class="data row4 col4" >4.67</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row5" class="row_heading level0 row5" >99</th>
#       <td id="T_b231f_row5_col0" class="data row5 col0" >JWD</td>
#       <td id="T_b231f_row5_col1" class="data row5 col1" >15.90</td>
#       <td id="T_b231f_row5_col2" class="data row5 col2" >165</td>
#       <td id="T_b231f_row5_col3" class="data row5 col3" >0.70</td>
#       <td id="T_b231f_row5_col4" class="data row5 col4" >4.61</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row6" class="row_heading level0 row6" >25</th>
#       <td id="T_b231f_row6_col0" class="data row6 col0" >BCT</td>
#       <td id="T_b231f_row6_col1" class="data row6 col1" >54.50</td>
#       <td id="T_b231f_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_b231f_row6_col3" class="data row6 col3" >2.25</td>
#       <td id="T_b231f_row6_col4" class="data row6 col4" >4.31</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row7" class="row_heading level0 row7" >76</th>
#       <td id="T_b231f_row7_col0" class="data row7 col0" >GLOBAL</td>
#       <td id="T_b231f_row7_col1" class="data row7 col1" >19.40</td>
#       <td id="T_b231f_row7_col2" class="data row7 col2" >295</td>
#       <td id="T_b231f_row7_col3" class="data row7 col3" >0.70</td>
#       <td id="T_b231f_row7_col4" class="data row7 col4" >3.74</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row8" class="row_heading level0 row8" >219</th>
#       <td id="T_b231f_row8_col0" class="data row8 col0" >TVI</td>
#       <td id="T_b231f_row8_col1" class="data row8 col1" >17.20</td>
#       <td id="T_b231f_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_b231f_row8_col3" class="data row8 col3" >0.60</td>
#       <td id="T_b231f_row8_col4" class="data row8 col4" >3.61</td>
#     </tr>
#     <tr>
#       <th id="T_b231f_level0_row9" class="row_heading level0 row9" >69</th>
#       <td id="T_b231f_row9_col0" class="data row9 col0" >ESSO</td>
#       <td id="T_b231f_row9_col1" class="data row9 col1" >11.60</td>
#       <td id="T_b231f_row9_col2" class="data row9 col2" >545</td>
#       <td id="T_b231f_row9_col3" class="data row9 col3" >0.40</td>
#       <td id="T_b231f_row9_col4" class="data row9 col4" >3.57</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b14c1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b14c1_level0_row0" class="row_heading level0 row0" >188</th>
#       <td id="T_b14c1_row0_col0" class="data row0 col0" >SVI</td>
#       <td id="T_b14c1_row0_col1" class="data row0 col1" >7.80</td>
#       <td id="T_b14c1_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_b14c1_row0_col3" class="data row0 col3" >-0.40</td>
#       <td id="T_b14c1_row0_col4" class="data row0 col4" >-4.88</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row1" class="row_heading level0 row1" >70</th>
#       <td id="T_b14c1_row1_col0" class="data row1 col0" >FORTH</td>
#       <td id="T_b14c1_row1_col1" class="data row1 col1" >46.50</td>
#       <td id="T_b14c1_row1_col2" class="data row1 col2" >281</td>
#       <td id="T_b14c1_row1_col3" class="data row1 col3" >-2.00</td>
#       <td id="T_b14c1_row1_col4" class="data row1 col4" >-4.12</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row2" class="row_heading level0 row2" >209</th>
#       <td id="T_b14c1_row2_col0" class="data row2 col0" >TQM</td>
#       <td id="T_b14c1_row2_col1" class="data row2 col1" >42.00</td>
#       <td id="T_b14c1_row2_col2" class="data row2 col2" >490</td>
#       <td id="T_b14c1_row2_col3" class="data row2 col3" >-1.75</td>
#       <td id="T_b14c1_row2_col4" class="data row2 col4" >-4.00</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row3" class="row_heading level0 row3" >119</th>
#       <td id="T_b14c1_row3_col0" class="data row3 col0" >MACO</td>
#       <td id="T_b14c1_row3_col1" class="data row3 col1" >0.50</td>
#       <td id="T_b14c1_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_b14c1_row3_col3" class="data row3 col3" >-0.02</td>
#       <td id="T_b14c1_row3_col4" class="data row3 col4" >-3.85</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row4" class="row_heading level0 row4" >45</th>
#       <td id="T_b14c1_row4_col0" class="data row4 col0" >CK</td>
#       <td id="T_b14c1_row4_col1" class="data row4 col1" >20.30</td>
#       <td id="T_b14c1_row4_col2" class="data row4 col2" >217</td>
#       <td id="T_b14c1_row4_col3" class="data row4 col3" >-0.70</td>
#       <td id="T_b14c1_row4_col4" class="data row4 col4" >-3.33</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row5" class="row_heading level0 row5" >184</th>
#       <td id="T_b14c1_row5_col0" class="data row5 col0" >STEC</td>
#       <td id="T_b14c1_row5_col1" class="data row5 col1" >12.00</td>
#       <td id="T_b14c1_row5_col2" class="data row5 col2" >210</td>
#       <td id="T_b14c1_row5_col3" class="data row5 col3" >-0.40</td>
#       <td id="T_b14c1_row5_col4" class="data row5 col4" >-3.23</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row6" class="row_heading level0 row6" >156</th>
#       <td id="T_b14c1_row6_col0" class="data row6 col0" >RS</td>
#       <td id="T_b14c1_row6_col1" class="data row6 col1" >15.10</td>
#       <td id="T_b14c1_row6_col2" class="data row6 col2" >76</td>
#       <td id="T_b14c1_row6_col3" class="data row6 col3" >-0.50</td>
#       <td id="T_b14c1_row6_col4" class="data row6 col4" >-3.21</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row7" class="row_heading level0 row7" >98</th>
#       <td id="T_b14c1_row7_col0" class="data row7 col0" >JMT</td>
#       <td id="T_b14c1_row7_col1" class="data row7 col1" >76.50</td>
#       <td id="T_b14c1_row7_col2" class="data row7 col2" >1,528</td>
#       <td id="T_b14c1_row7_col3" class="data row7 col3" >-2.25</td>
#       <td id="T_b14c1_row7_col4" class="data row7 col4" >-2.86</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row8" class="row_heading level0 row8" >168</th>
#       <td id="T_b14c1_row8_col0" class="data row8 col0" >SINGER</td>
#       <td id="T_b14c1_row8_col1" class="data row8 col1" >45.25</td>
#       <td id="T_b14c1_row8_col2" class="data row8 col2" >192</td>
#       <td id="T_b14c1_row8_col3" class="data row8 col3" >-1.25</td>
#       <td id="T_b14c1_row8_col4" class="data row8 col4" >-2.69</td>
#     </tr>
#     <tr>
#       <th id="T_b14c1_level0_row9" class="row_heading level0 row9" >63</th>
#       <td id="T_b14c1_row9_col0" class="data row9 col0" >EA</td>
#       <td id="T_b14c1_row9_col1" class="data row9 col1" >83.75</td>
#       <td id="T_b14c1_row9_col2" class="data row9 col2" >1,110</td>
#       <td id="T_b14c1_row9_col3" class="data row9 col3" >-2.25</td>
#       <td id="T_b14c1_row9_col4" class="data row9 col4" >-2.62</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4456e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4456e_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_4456e_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_4456e_row0_col1" class="data row0 col1" >71.50</td>
#       <td id="T_4456e_row0_col2" class="data row0 col2" >4,694</td>
#       <td id="T_4456e_row0_col3" class="data row0 col3" >-1.00</td>
#       <td id="T_4456e_row0_col4" class="data row0 col4" >-1.38</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row1" class="row_heading level0 row1" >58</th>
#       <td id="T_4456e_row1_col0" class="data row1 col0" >DELTA</td>
#       <td id="T_4456e_row1_col1" class="data row1 col1" >590.00</td>
#       <td id="T_4456e_row1_col2" class="data row1 col2" >4,175</td>
#       <td id="T_4456e_row1_col3" class="data row1 col3" >40.00</td>
#       <td id="T_4456e_row1_col4" class="data row1 col4" >7.27</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row2" class="row_heading level0 row2" >147</th>
#       <td id="T_4456e_row2_col0" class="data row2 col0" >PTT</td>
#       <td id="T_4456e_row2_col1" class="data row2 col1" >37.50</td>
#       <td id="T_4456e_row2_col2" class="data row2 col2" >2,837</td>
#       <td id="T_4456e_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_4456e_row2_col4" class="data row2 col4" >1.35</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row3" class="row_heading level0 row3" >100</th>
#       <td id="T_4456e_row3_col0" class="data row3 col0" >KBANK</td>
#       <td id="T_4456e_row3_col1" class="data row3 col1" >151.50</td>
#       <td id="T_4456e_row3_col2" class="data row3 col2" >2,397</td>
#       <td id="T_4456e_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_4456e_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row4" class="row_heading level0 row4" >148</th>
#       <td id="T_4456e_row4_col0" class="data row4 col0" >PTTEP</td>
#       <td id="T_4456e_row4_col1" class="data row4 col1" >156.00</td>
#       <td id="T_4456e_row4_col2" class="data row4 col2" >2,366</td>
#       <td id="T_4456e_row4_col3" class="data row4 col3" >1.50</td>
#       <td id="T_4456e_row4_col4" class="data row4 col4" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row5" class="row_heading level0 row5" >34</th>
#       <td id="T_4456e_row5_col0" class="data row5 col0" >BH</td>
#       <td id="T_4456e_row5_col1" class="data row5 col1" >189.50</td>
#       <td id="T_4456e_row5_col2" class="data row5 col2" >2,286</td>
#       <td id="T_4456e_row5_col3" class="data row5 col3" >1.00</td>
#       <td id="T_4456e_row5_col4" class="data row5 col4" >0.53</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_4456e_row6_col0" class="data row6 col0" >BANPU</td>
#       <td id="T_4456e_row6_col1" class="data row6 col1" >13.60</td>
#       <td id="T_4456e_row6_col2" class="data row6 col2" >2,271</td>
#       <td id="T_4456e_row6_col3" class="data row6 col3" >0.20</td>
#       <td id="T_4456e_row6_col4" class="data row6 col4" >1.49</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row7" class="row_heading level0 row7" >98</th>
#       <td id="T_4456e_row7_col0" class="data row7 col0" >JMT</td>
#       <td id="T_4456e_row7_col1" class="data row7 col1" >76.50</td>
#       <td id="T_4456e_row7_col2" class="data row7 col2" >1,528</td>
#       <td id="T_4456e_row7_col3" class="data row7 col3" >-2.25</td>
#       <td id="T_4456e_row7_col4" class="data row7 col4" >-2.86</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row8" class="row_heading level0 row8" >49</th>
#       <td id="T_4456e_row8_col0" class="data row8 col0" >CPALL</td>
#       <td id="T_4456e_row8_col1" class="data row8 col1" >59.50</td>
#       <td id="T_4456e_row8_col2" class="data row8 col2" >1,468</td>
#       <td id="T_4456e_row8_col3" class="data row8 col3" >0.00</td>
#       <td id="T_4456e_row8_col4" class="data row8 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_4456e_level0_row9" class="row_heading level0 row9" >95</th>
#       <td id="T_4456e_row9_col0" class="data row9 col0" >IVL</td>
#       <td id="T_4456e_row9_col1" class="data row9 col1" >44.00</td>
#       <td id="T_4456e_row9_col2" class="data row9 col2" >1,296</td>
#       <td id="T_4456e_row9_col3" class="data row9 col3" >0.75</td>
#       <td id="T_4456e_row9_col4" class="data row9 col4" >1.73</td>
#     </tr>
#   </tbody>
# </table>
