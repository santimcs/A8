# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 7, 12)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_94b9c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94b9c_level0_row0" class="row_heading level0 row0" >120</th>
#       <td id="T_94b9c_row0_col0" class="data row0 col0" >MBAX</td>
#       <td id="T_94b9c_row0_col1" class="data row0 col1" >5.85</td>
#       <td id="T_94b9c_row0_col2" class="data row0 col2" >19</td>
#       <td id="T_94b9c_row0_col3" class="data row0 col3" >0.35</td>
#       <td id="T_94b9c_row0_col4" class="data row0 col4" >6.36</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row1" class="row_heading level0 row1" >219</th>
#       <td id="T_94b9c_row1_col0" class="data row1 col0" >TYCN</td>
#       <td id="T_94b9c_row1_col1" class="data row1 col1" >3.16</td>
#       <td id="T_94b9c_row1_col2" class="data row1 col2" >17</td>
#       <td id="T_94b9c_row1_col3" class="data row1 col3" >0.18</td>
#       <td id="T_94b9c_row1_col4" class="data row1 col4" >6.04</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row2" class="row_heading level0 row2" >171</th>
#       <td id="T_94b9c_row2_col0" class="data row2 col0" >SMPC</td>
#       <td id="T_94b9c_row2_col1" class="data row2 col1" >15.10</td>
#       <td id="T_94b9c_row2_col2" class="data row2 col2" >12</td>
#       <td id="T_94b9c_row2_col3" class="data row2 col3" >0.70</td>
#       <td id="T_94b9c_row2_col4" class="data row2 col4" >4.86</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row3" class="row_heading level0 row3" >80</th>
#       <td id="T_94b9c_row3_col0" class="data row3 col0" >HANA</td>
#       <td id="T_94b9c_row3_col1" class="data row3 col1" >39.75</td>
#       <td id="T_94b9c_row3_col2" class="data row3 col2" >337</td>
#       <td id="T_94b9c_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_94b9c_row3_col4" class="data row3 col4" >2.58</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row4" class="row_heading level0 row4" >22</th>
#       <td id="T_94b9c_row4_col0" class="data row4 col0" >BCH</td>
#       <td id="T_94b9c_row4_col1" class="data row4 col1" >20.30</td>
#       <td id="T_94b9c_row4_col2" class="data row4 col2" >459</td>
#       <td id="T_94b9c_row4_col3" class="data row4 col3" >0.50</td>
#       <td id="T_94b9c_row4_col4" class="data row4 col4" >2.53</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row5" class="row_heading level0 row5" >66</th>
#       <td id="T_94b9c_row5_col0" class="data row5 col0" >EGCO</td>
#       <td id="T_94b9c_row5_col1" class="data row5 col1" >183.50</td>
#       <td id="T_94b9c_row5_col2" class="data row5 col2" >839</td>
#       <td id="T_94b9c_row5_col3" class="data row5 col3" >4.00</td>
#       <td id="T_94b9c_row5_col4" class="data row5 col4" >2.23</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row6" class="row_heading level0 row6" >168</th>
#       <td id="T_94b9c_row6_col0" class="data row6 col0" >SIS</td>
#       <td id="T_94b9c_row6_col1" class="data row6 col1" >27.00</td>
#       <td id="T_94b9c_row6_col2" class="data row6 col2" >19</td>
#       <td id="T_94b9c_row6_col3" class="data row6 col3" >0.50</td>
#       <td id="T_94b9c_row6_col4" class="data row6 col4" >1.89</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row7" class="row_heading level0 row7" >26</th>
#       <td id="T_94b9c_row7_col0" class="data row7 col0" >BDMS</td>
#       <td id="T_94b9c_row7_col1" class="data row7 col1" >27.00</td>
#       <td id="T_94b9c_row7_col2" class="data row7 col2" >1,474</td>
#       <td id="T_94b9c_row7_col3" class="data row7 col3" >0.50</td>
#       <td id="T_94b9c_row7_col4" class="data row7 col4" >1.89</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row8" class="row_heading level0 row8" >111</th>
#       <td id="T_94b9c_row8_col0" class="data row8 col0" >LHK</td>
#       <td id="T_94b9c_row8_col1" class="data row8 col1" >4.34</td>
#       <td id="T_94b9c_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_94b9c_row8_col3" class="data row8 col3" >0.08</td>
#       <td id="T_94b9c_row8_col4" class="data row8 col4" >1.88</td>
#     </tr>
#     <tr>
#       <th id="T_94b9c_level0_row9" class="row_heading level0 row9" >187</th>
#       <td id="T_94b9c_row9_col0" class="data row9 col0" >SYNEX</td>
#       <td id="T_94b9c_row9_col1" class="data row9 col1" >17.10</td>
#       <td id="T_94b9c_row9_col2" class="data row9 col2" >40</td>
#       <td id="T_94b9c_row9_col3" class="data row9 col3" >0.30</td>
#       <td id="T_94b9c_row9_col4" class="data row9 col4" >1.79</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7b38_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7b38_level0_row0" class="row_heading level0 row0" >137</th>
#       <td id="T_c7b38_row0_col0" class="data row0 col0" >PLANB</td>
#       <td id="T_c7b38_row0_col1" class="data row0 col1" >6.00</td>
#       <td id="T_c7b38_row0_col2" class="data row0 col2" >253</td>
#       <td id="T_c7b38_row0_col3" class="data row0 col3" >-0.35</td>
#       <td id="T_c7b38_row0_col4" class="data row0 col4" >-5.51</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row1" class="row_heading level0 row1" >207</th>
#       <td id="T_c7b38_row1_col0" class="data row1 col0" >TQM</td>
#       <td id="T_c7b38_row1_col1" class="data row1 col1" >44.25</td>
#       <td id="T_c7b38_row1_col2" class="data row1 col2" >373</td>
#       <td id="T_c7b38_row1_col3" class="data row1 col3" >-2.50</td>
#       <td id="T_c7b38_row1_col4" class="data row1 col4" >-5.35</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row2" class="row_heading level0 row2" >228</th>
#       <td id="T_c7b38_row2_col0" class="data row2 col0" >WICE</td>
#       <td id="T_c7b38_row2_col1" class="data row2 col1" >11.10</td>
#       <td id="T_c7b38_row2_col2" class="data row2 col2" >97</td>
#       <td id="T_c7b38_row2_col3" class="data row2 col3" >-0.50</td>
#       <td id="T_c7b38_row2_col4" class="data row2 col4" >-4.31</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row3" class="row_heading level0 row3" >221</th>
#       <td id="T_c7b38_row3_col0" class="data row3 col0" >VGI</td>
#       <td id="T_c7b38_row3_col1" class="data row3 col1" >4.52</td>
#       <td id="T_c7b38_row3_col2" class="data row3 col2" >386</td>
#       <td id="T_c7b38_row3_col3" class="data row3 col3" >-0.20</td>
#       <td id="T_c7b38_row3_col4" class="data row3 col4" >-4.24</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row4" class="row_heading level0 row4" >203</th>
#       <td id="T_c7b38_row4_col0" class="data row4 col0" >TOA</td>
#       <td id="T_c7b38_row4_col1" class="data row4 col1" >26.75</td>
#       <td id="T_c7b38_row4_col2" class="data row4 col2" >42</td>
#       <td id="T_c7b38_row4_col3" class="data row4 col3" >-1.00</td>
#       <td id="T_c7b38_row4_col4" class="data row4 col4" >-3.60</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row5" class="row_heading level0 row5" >46</th>
#       <td id="T_c7b38_row5_col0" class="data row5 col0" >COM7</td>
#       <td id="T_c7b38_row5_col1" class="data row5 col1" >27.00</td>
#       <td id="T_c7b38_row5_col2" class="data row5 col2" >547</td>
#       <td id="T_c7b38_row5_col3" class="data row5 col3" >-1.00</td>
#       <td id="T_c7b38_row5_col4" class="data row5 col4" >-3.57</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row6" class="row_heading level0 row6" >183</th>
#       <td id="T_c7b38_row6_col0" class="data row6 col0" >STGT</td>
#       <td id="T_c7b38_row6_col1" class="data row6 col1" >16.20</td>
#       <td id="T_c7b38_row6_col2" class="data row6 col2" >228</td>
#       <td id="T_c7b38_row6_col3" class="data row6 col3" >-0.60</td>
#       <td id="T_c7b38_row6_col4" class="data row6 col4" >-3.57</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row7" class="row_heading level0 row7" >166</th>
#       <td id="T_c7b38_row7_col0" class="data row7 col0" >SINGER</td>
#       <td id="T_c7b38_row7_col1" class="data row7 col1" >36.25</td>
#       <td id="T_c7b38_row7_col2" class="data row7 col2" >163</td>
#       <td id="T_c7b38_row7_col3" class="data row7 col3" >-1.25</td>
#       <td id="T_c7b38_row7_col4" class="data row7 col4" >-3.33</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row8" class="row_heading level0 row8" >95</th>
#       <td id="T_c7b38_row8_col0" class="data row8 col0" >JMART</td>
#       <td id="T_c7b38_row8_col1" class="data row8 col1" >44.00</td>
#       <td id="T_c7b38_row8_col2" class="data row8 col2" >936</td>
#       <td id="T_c7b38_row8_col3" class="data row8 col3" >-1.50</td>
#       <td id="T_c7b38_row8_col4" class="data row8 col4" >-3.30</td>
#     </tr>
#     <tr>
#       <th id="T_c7b38_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7b38_row9_col0" class="data row9 col0" >ANAN</td>
#       <td id="T_c7b38_row9_col1" class="data row9 col1" >1.27</td>
#       <td id="T_c7b38_row9_col2" class="data row9 col2" >12</td>
#       <td id="T_c7b38_row9_col3" class="data row9 col3" >-0.04</td>
#       <td id="T_c7b38_row9_col4" class="data row9 col4" >-3.05</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ffc44_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffc44_level0_row0" class="row_heading level0 row0" >145</th>
#       <td id="T_ffc44_row0_col0" class="data row0 col0" >PTT</td>
#       <td id="T_ffc44_row0_col1" class="data row0 col1" >33.75</td>
#       <td id="T_ffc44_row0_col2" class="data row0 col2" >1,520</td>
#       <td id="T_ffc44_row0_col3" class="data row0 col3" >-0.25</td>
#       <td id="T_ffc44_row0_col4" class="data row0 col4" >-0.74</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row1" class="row_heading level0 row1" >26</th>
#       <td id="T_ffc44_row1_col0" class="data row1 col0" >BDMS</td>
#       <td id="T_ffc44_row1_col1" class="data row1 col1" >27.00</td>
#       <td id="T_ffc44_row1_col2" class="data row1 col2" >1,474</td>
#       <td id="T_ffc44_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_ffc44_row1_col4" class="data row1 col4" >1.89</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row2" class="row_heading level0 row2" >146</th>
#       <td id="T_ffc44_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_ffc44_row2_col1" class="data row2 col1" >160.00</td>
#       <td id="T_ffc44_row2_col2" class="data row2 col2" >1,451</td>
#       <td id="T_ffc44_row2_col3" class="data row2 col3" >-1.50</td>
#       <td id="T_ffc44_row2_col4" class="data row2 col4" >-0.93</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row3" class="row_heading level0 row3" >160</th>
#       <td id="T_ffc44_row3_col0" class="data row3 col0" >SCB</td>
#       <td id="T_ffc44_row3_col1" class="data row3 col1" >100.00</td>
#       <td id="T_ffc44_row3_col2" class="data row3 col2" >1,414</td>
#       <td id="T_ffc44_row3_col3" class="data row3 col3" >-2.00</td>
#       <td id="T_ffc44_row3_col4" class="data row3 col4" >-1.96</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row4" class="row_heading level0 row4" >98</th>
#       <td id="T_ffc44_row4_col0" class="data row4 col0" >KBANK</td>
#       <td id="T_ffc44_row4_col1" class="data row4 col1" >146.50</td>
#       <td id="T_ffc44_row4_col2" class="data row4 col2" >1,287</td>
#       <td id="T_ffc44_row4_col3" class="data row4 col3" >0.50</td>
#       <td id="T_ffc44_row4_col4" class="data row4 col4" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_ffc44_row5_col0" class="data row5 col0" >AOT</td>
#       <td id="T_ffc44_row5_col1" class="data row5 col1" >70.00</td>
#       <td id="T_ffc44_row5_col2" class="data row5 col2" >1,171</td>
#       <td id="T_ffc44_row5_col3" class="data row5 col3" >-0.75</td>
#       <td id="T_ffc44_row5_col4" class="data row5 col4" >-1.06</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row6" class="row_heading level0 row6" >48</th>
#       <td id="T_ffc44_row6_col0" class="data row6 col0" >CPALL</td>
#       <td id="T_ffc44_row6_col1" class="data row6 col1" >62.75</td>
#       <td id="T_ffc44_row6_col2" class="data row6 col2" >1,110</td>
#       <td id="T_ffc44_row6_col3" class="data row6 col3" >-0.25</td>
#       <td id="T_ffc44_row6_col4" class="data row6 col4" >-0.40</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row7" class="row_heading level0 row7" >62</th>
#       <td id="T_ffc44_row7_col0" class="data row7 col0" >EA</td>
#       <td id="T_ffc44_row7_col1" class="data row7 col1" >78.00</td>
#       <td id="T_ffc44_row7_col2" class="data row7 col2" >1,055</td>
#       <td id="T_ffc44_row7_col3" class="data row7 col3" >-1.00</td>
#       <td id="T_ffc44_row7_col4" class="data row7 col4" >-1.27</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row8" class="row_heading level0 row8" >161</th>
#       <td id="T_ffc44_row8_col0" class="data row8 col0" >SCC</td>
#       <td id="T_ffc44_row8_col1" class="data row8 col1" >375.00</td>
#       <td id="T_ffc44_row8_col2" class="data row8 col2" >982</td>
#       <td id="T_ffc44_row8_col3" class="data row8 col3" >-4.00</td>
#       <td id="T_ffc44_row8_col4" class="data row8 col4" >-1.06</td>
#     </tr>
#     <tr>
#       <th id="T_ffc44_level0_row9" class="row_heading level0 row9" >19</th>
#       <td id="T_ffc44_row9_col0" class="data row9 col0" >BANPU</td>
#       <td id="T_ffc44_row9_col1" class="data row9 col1" >12.80</td>
#       <td id="T_ffc44_row9_col2" class="data row9 col2" >971</td>
#       <td id="T_ffc44_row9_col3" class="data row9 col3" >-0.10</td>
#       <td id="T_ffc44_row9_col4" class="data row9 col4" >-0.78</td>
#     </tr>
#   </tbody>
# </table>
