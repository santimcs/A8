# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 11, 10)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8684d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8684d_level0_row0" class="row_heading level0 row0" >202</th>
#       <td id="T_8684d_row0_col0" class="data row0 col0" >TKN</td>
#       <td id="T_8684d_row0_col1" class="data row0 col1" >9.35</td>
#       <td id="T_8684d_row0_col2" class="data row0 col2" >700</td>
#       <td id="T_8684d_row0_col3" class="data row0 col3" >2.15</td>
#       <td id="T_8684d_row0_col4" class="data row0 col4" >29.86</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row1" class="row_heading level0 row1" >85</th>
#       <td id="T_8684d_row1_col0" class="data row1 col0" >ICHI</td>
#       <td id="T_8684d_row1_col1" class="data row1 col1" >11.20</td>
#       <td id="T_8684d_row1_col2" class="data row1 col2" >431</td>
#       <td id="T_8684d_row1_col3" class="data row1 col3" >0.70</td>
#       <td id="T_8684d_row1_col4" class="data row1 col4" >6.67</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row2" class="row_heading level0 row2" >169</th>
#       <td id="T_8684d_row2_col0" class="data row2 col0" >SINGER</td>
#       <td id="T_8684d_row2_col1" class="data row2 col1" >36.50</td>
#       <td id="T_8684d_row2_col2" class="data row2 col2" >479</td>
#       <td id="T_8684d_row2_col3" class="data row2 col3" >2.25</td>
#       <td id="T_8684d_row2_col4" class="data row2 col4" >6.57</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row3" class="row_heading level0 row3" >22</th>
#       <td id="T_8684d_row3_col0" class="data row3 col0" >BCH</td>
#       <td id="T_8684d_row3_col1" class="data row3 col1" >19.80</td>
#       <td id="T_8684d_row3_col2" class="data row3 col2" >1,453</td>
#       <td id="T_8684d_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_8684d_row3_col4" class="data row3 col4" >5.32</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row4" class="row_heading level0 row4" >176</th>
#       <td id="T_8684d_row4_col0" class="data row4 col0" >SPALI</td>
#       <td id="T_8684d_row4_col1" class="data row4 col1" >22.90</td>
#       <td id="T_8684d_row4_col2" class="data row4 col2" >713</td>
#       <td id="T_8684d_row4_col3" class="data row4 col3" >0.90</td>
#       <td id="T_8684d_row4_col4" class="data row4 col4" >4.09</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row5" class="row_heading level0 row5" >33</th>
#       <td id="T_8684d_row5_col0" class="data row5 col0" >BH</td>
#       <td id="T_8684d_row5_col1" class="data row5 col1" >233.00</td>
#       <td id="T_8684d_row5_col2" class="data row5 col2" >2,177</td>
#       <td id="T_8684d_row5_col3" class="data row5 col3" >9.00</td>
#       <td id="T_8684d_row5_col4" class="data row5 col4" >4.02</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row6" class="row_heading level0 row6" >42</th>
#       <td id="T_8684d_row6_col0" class="data row6 col0" >CENTEL</td>
#       <td id="T_8684d_row6_col1" class="data row6 col1" >50.00</td>
#       <td id="T_8684d_row6_col2" class="data row6 col2" >280</td>
#       <td id="T_8684d_row6_col3" class="data row6 col3" >1.75</td>
#       <td id="T_8684d_row6_col4" class="data row6 col4" >3.63</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row7" class="row_heading level0 row7" >120</th>
#       <td id="T_8684d_row7_col0" class="data row7 col0" >MAJOR</td>
#       <td id="T_8684d_row7_col1" class="data row7 col1" >19.40</td>
#       <td id="T_8684d_row7_col2" class="data row7 col2" >185</td>
#       <td id="T_8684d_row7_col3" class="data row7 col3" >0.60</td>
#       <td id="T_8684d_row7_col4" class="data row7 col4" >3.19</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row8" class="row_heading level0 row8" >98</th>
#       <td id="T_8684d_row8_col0" class="data row8 col0" >JMT</td>
#       <td id="T_8684d_row8_col1" class="data row8 col1" >65.25</td>
#       <td id="T_8684d_row8_col2" class="data row8 col2" >708</td>
#       <td id="T_8684d_row8_col3" class="data row8 col3" >2.00</td>
#       <td id="T_8684d_row8_col4" class="data row8 col4" >3.16</td>
#     </tr>
#     <tr>
#       <th id="T_8684d_level0_row9" class="row_heading level0 row9" >184</th>
#       <td id="T_8684d_row9_col0" class="data row9 col0" >STARK</td>
#       <td id="T_8684d_row9_col1" class="data row9 col1" >3.40</td>
#       <td id="T_8684d_row9_col2" class="data row9 col2" >144</td>
#       <td id="T_8684d_row9_col3" class="data row9 col3" >0.10</td>
#       <td id="T_8684d_row9_col4" class="data row9 col4" >3.03</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2710_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2710_level0_row0" class="row_heading level0 row0" >220</th>
#       <td id="T_e2710_row0_col0" class="data row0 col0" >TVI</td>
#       <td id="T_e2710_row0_col1" class="data row0 col1" >13.30</td>
#       <td id="T_e2710_row0_col2" class="data row0 col2" >64</td>
#       <td id="T_e2710_row0_col3" class="data row0 col3" >-3.20</td>
#       <td id="T_e2710_row0_col4" class="data row0 col4" >-19.39</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row1" class="row_heading level0 row1" >34</th>
#       <td id="T_e2710_row1_col0" class="data row1 col0" >BJC</td>
#       <td id="T_e2710_row1_col1" class="data row1 col1" >32.00</td>
#       <td id="T_e2710_row1_col2" class="data row1 col2" >788</td>
#       <td id="T_e2710_row1_col3" class="data row1 col3" >-2.50</td>
#       <td id="T_e2710_row1_col4" class="data row1 col4" >-7.25</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row2" class="row_heading level0 row2" >231</th>
#       <td id="T_e2710_row2_col0" class="data row2 col0" >WICE</td>
#       <td id="T_e2710_row2_col1" class="data row2 col1" >10.60</td>
#       <td id="T_e2710_row2_col2" class="data row2 col2" >104</td>
#       <td id="T_e2710_row2_col3" class="data row2 col3" >-0.60</td>
#       <td id="T_e2710_row2_col4" class="data row2 col4" >-5.36</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row3" class="row_heading level0 row3" >158</th>
#       <td id="T_e2710_row3_col0" class="data row3 col0" >SABUY</td>
#       <td id="T_e2710_row3_col1" class="data row3 col1" >12.40</td>
#       <td id="T_e2710_row3_col2" class="data row3 col2" >353</td>
#       <td id="T_e2710_row3_col3" class="data row3 col3" >-0.70</td>
#       <td id="T_e2710_row3_col4" class="data row3 col4" >-5.34</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row4" class="row_heading level0 row4" >69</th>
#       <td id="T_e2710_row4_col0" class="data row4 col0" >FORTH</td>
#       <td id="T_e2710_row4_col1" class="data row4 col1" >43.50</td>
#       <td id="T_e2710_row4_col2" class="data row4 col2" >120</td>
#       <td id="T_e2710_row4_col3" class="data row4 col3" >-1.75</td>
#       <td id="T_e2710_row4_col4" class="data row4 col4" >-3.87</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row5" class="row_heading level0 row5" >207</th>
#       <td id="T_e2710_row5_col0" class="data row5 col0" >TOP</td>
#       <td id="T_e2710_row5_col1" class="data row5 col1" >54.50</td>
#       <td id="T_e2710_row5_col2" class="data row5 col2" >751</td>
#       <td id="T_e2710_row5_col3" class="data row5 col3" >-2.00</td>
#       <td id="T_e2710_row5_col4" class="data row5 col4" >-3.54</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row6" class="row_heading level0 row6" >186</th>
#       <td id="T_e2710_row6_col0" class="data row6 col0" >STGT</td>
#       <td id="T_e2710_row6_col1" class="data row6 col1" >9.85</td>
#       <td id="T_e2710_row6_col2" class="data row6 col2" >336</td>
#       <td id="T_e2710_row6_col3" class="data row6 col3" >-0.35</td>
#       <td id="T_e2710_row6_col4" class="data row6 col4" >-3.43</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row7" class="row_heading level0 row7" >68</th>
#       <td id="T_e2710_row7_col0" class="data row7 col0" >ESSO</td>
#       <td id="T_e2710_row7_col1" class="data row7 col1" >13.20</td>
#       <td id="T_e2710_row7_col2" class="data row7 col2" >349</td>
#       <td id="T_e2710_row7_col3" class="data row7 col3" >-0.40</td>
#       <td id="T_e2710_row7_col4" class="data row7 col4" >-2.94</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row8" class="row_heading level0 row8" >230</th>
#       <td id="T_e2710_row8_col0" class="data row8 col0" >WHAUP</td>
#       <td id="T_e2710_row8_col1" class="data row8 col1" >3.96</td>
#       <td id="T_e2710_row8_col2" class="data row8 col2" >27</td>
#       <td id="T_e2710_row8_col3" class="data row8 col3" >-0.12</td>
#       <td id="T_e2710_row8_col4" class="data row8 col4" >-2.94</td>
#     </tr>
#     <tr>
#       <th id="T_e2710_level0_row9" class="row_heading level0 row9" >174</th>
#       <td id="T_e2710_row9_col0" class="data row9 col0" >SMPC</td>
#       <td id="T_e2710_row9_col1" class="data row9 col1" >13.90</td>
#       <td id="T_e2710_row9_col2" class="data row9 col2" >23</td>
#       <td id="T_e2710_row9_col3" class="data row9 col3" >-0.40</td>
#       <td id="T_e2710_row9_col4" class="data row9 col4" >-2.80</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_69654_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69654_level0_row0" class="row_heading level0 row0" >148</th>
#       <td id="T_69654_row0_col0" class="data row0 col0" >PTTEP</td>
#       <td id="T_69654_row0_col1" class="data row0 col1" >189.50</td>
#       <td id="T_69654_row0_col2" class="data row0 col2" >2,726</td>
#       <td id="T_69654_row0_col3" class="data row0 col3" >-3.50</td>
#       <td id="T_69654_row0_col4" class="data row0 col4" >-1.81</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row1" class="row_heading level0 row1" >147</th>
#       <td id="T_69654_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_69654_row1_col1" class="data row1 col1" >34.25</td>
#       <td id="T_69654_row1_col2" class="data row1 col2" >2,270</td>
#       <td id="T_69654_row1_col3" class="data row1 col3" >-0.75</td>
#       <td id="T_69654_row1_col4" class="data row1 col4" >-2.14</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row2" class="row_heading level0 row2" >33</th>
#       <td id="T_69654_row2_col0" class="data row2 col0" >BH</td>
#       <td id="T_69654_row2_col1" class="data row2 col1" >233.00</td>
#       <td id="T_69654_row2_col2" class="data row2 col2" >2,177</td>
#       <td id="T_69654_row2_col3" class="data row2 col3" >9.00</td>
#       <td id="T_69654_row2_col4" class="data row2 col4" >4.02</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row3" class="row_heading level0 row3" >126</th>
#       <td id="T_69654_row3_col0" class="data row3 col0" >MINT</td>
#       <td id="T_69654_row3_col1" class="data row3 col1" >29.75</td>
#       <td id="T_69654_row3_col2" class="data row3 col2" >2,074</td>
#       <td id="T_69654_row3_col3" class="data row3 col3" >0.75</td>
#       <td id="T_69654_row3_col4" class="data row3 col4" >2.59</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row4" class="row_heading level0 row4" >19</th>
#       <td id="T_69654_row4_col0" class="data row4 col0" >BANPU</td>
#       <td id="T_69654_row4_col1" class="data row4 col1" >12.70</td>
#       <td id="T_69654_row4_col2" class="data row4 col2" >1,762</td>
#       <td id="T_69654_row4_col3" class="data row4 col3" >0.10</td>
#       <td id="T_69654_row4_col4" class="data row4 col4" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row5" class="row_heading level0 row5" >100</th>
#       <td id="T_69654_row5_col0" class="data row5 col0" >KBANK</td>
#       <td id="T_69654_row5_col1" class="data row5 col1" >148.00</td>
#       <td id="T_69654_row5_col2" class="data row5 col2" >1,545</td>
#       <td id="T_69654_row5_col3" class="data row5 col3" >0.50</td>
#       <td id="T_69654_row5_col4" class="data row5 col4" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row6" class="row_heading level0 row6" >26</th>
#       <td id="T_69654_row6_col0" class="data row6 col0" >BDMS</td>
#       <td id="T_69654_row6_col1" class="data row6 col1" >31.25</td>
#       <td id="T_69654_row6_col2" class="data row6 col2" >1,530</td>
#       <td id="T_69654_row6_col3" class="data row6 col3" >0.75</td>
#       <td id="T_69654_row6_col4" class="data row6 col4" >2.46</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row7" class="row_heading level0 row7" >196</th>
#       <td id="T_69654_row7_col0" class="data row7 col0" >THG</td>
#       <td id="T_69654_row7_col1" class="data row7 col1" >74.50</td>
#       <td id="T_69654_row7_col2" class="data row7 col2" >1,463</td>
#       <td id="T_69654_row7_col3" class="data row7 col3" >-1.25</td>
#       <td id="T_69654_row7_col4" class="data row7 col4" >-1.65</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row8" class="row_heading level0 row8" >22</th>
#       <td id="T_69654_row8_col0" class="data row8 col0" >BCH</td>
#       <td id="T_69654_row8_col1" class="data row8 col1" >19.80</td>
#       <td id="T_69654_row8_col2" class="data row8 col2" >1,453</td>
#       <td id="T_69654_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_69654_row8_col4" class="data row8 col4" >5.32</td>
#     </tr>
#     <tr>
#       <th id="T_69654_level0_row9" class="row_heading level0 row9" >149</th>
#       <td id="T_69654_row9_col0" class="data row9 col0" >PTTGC</td>
#       <td id="T_69654_row9_col1" class="data row9 col1" >46.50</td>
#       <td id="T_69654_row9_col2" class="data row9 col2" >1,390</td>
#       <td id="T_69654_row9_col3" class="data row9 col3" >-0.50</td>
#       <td id="T_69654_row9_col4" class="data row9 col4" >-1.06</td>
#     </tr>
#   </tbody>
# </table>
