# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 6, 24)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_74f38_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74f38_level0_row0" class="row_heading level0 row0" >225</th>
#       <td id="T_74f38_row0_col0" class="data row0 col0" >WHART</td>
#       <td id="T_74f38_row0_col1" class="data row0 col1" >10.10</td>
#       <td id="T_74f38_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_74f38_row0_col3" class="data row0 col3" >0.40</td>
#       <td id="T_74f38_row0_col4" class="data row0 col4" >4.12</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row1" class="row_heading level0 row1" >40</th>
#       <td id="T_74f38_row1_col0" class="data row1 col0" >BTSGIF</td>
#       <td id="T_74f38_row1_col1" class="data row1 col1" >4.30</td>
#       <td id="T_74f38_row1_col2" class="data row1 col2" >30</td>
#       <td id="T_74f38_row1_col3" class="data row1 col3" >0.16</td>
#       <td id="T_74f38_row1_col4" class="data row1 col4" >3.86</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row2" class="row_heading level0 row2" >94</th>
#       <td id="T_74f38_row2_col0" class="data row2 col0" >JASIF</td>
#       <td id="T_74f38_row2_col1" class="data row2 col1" >9.60</td>
#       <td id="T_74f38_row2_col2" class="data row2 col2" >1,501</td>
#       <td id="T_74f38_row2_col3" class="data row2 col3" >0.35</td>
#       <td id="T_74f38_row2_col4" class="data row2 col4" >3.78</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row3" class="row_heading level0 row3" >160</th>
#       <td id="T_74f38_row3_col0" class="data row3 col0" >SCC</td>
#       <td id="T_74f38_row3_col1" class="data row3 col1" >379.00</td>
#       <td id="T_74f38_row3_col2" class="data row3 col2" >4,270</td>
#       <td id="T_74f38_row3_col3" class="data row3 col3" >13.00</td>
#       <td id="T_74f38_row3_col4" class="data row3 col4" >3.55</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row4" class="row_heading level0 row4" >22</th>
#       <td id="T_74f38_row4_col0" class="data row4 col0" >BCH</td>
#       <td id="T_74f38_row4_col1" class="data row4 col1" >18.90</td>
#       <td id="T_74f38_row4_col2" class="data row4 col2" >367</td>
#       <td id="T_74f38_row4_col3" class="data row4 col3" >0.60</td>
#       <td id="T_74f38_row4_col4" class="data row4 col4" >3.28</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row5" class="row_heading level0 row5" >57</th>
#       <td id="T_74f38_row5_col0" class="data row5 col0" >DELTA</td>
#       <td id="T_74f38_row5_col1" class="data row5 col1" >323.00</td>
#       <td id="T_74f38_row5_col2" class="data row5 col2" >787</td>
#       <td id="T_74f38_row5_col3" class="data row5 col3" >10.00</td>
#       <td id="T_74f38_row5_col4" class="data row5 col4" >3.19</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row6" class="row_heading level0 row6" >192</th>
#       <td id="T_74f38_row6_col0" class="data row6 col0" >THG</td>
#       <td id="T_74f38_row6_col1" class="data row6 col1" >62.50</td>
#       <td id="T_74f38_row6_col2" class="data row6 col2" >326</td>
#       <td id="T_74f38_row6_col3" class="data row6 col3" >1.75</td>
#       <td id="T_74f38_row6_col4" class="data row6 col4" >2.88</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row7" class="row_heading level0 row7" >155</th>
#       <td id="T_74f38_row7_col0" class="data row7 col0" >SAPPE</td>
#       <td id="T_74f38_row7_col1" class="data row7 col1" >36.50</td>
#       <td id="T_74f38_row7_col2" class="data row7 col2" >111</td>
#       <td id="T_74f38_row7_col3" class="data row7 col3" >1.00</td>
#       <td id="T_74f38_row7_col4" class="data row7 col4" >2.82</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row8" class="row_heading level0 row8" >148</th>
#       <td id="T_74f38_row8_col0" class="data row8 col0" >RATCH</td>
#       <td id="T_74f38_row8_col1" class="data row8 col1" >37.00</td>
#       <td id="T_74f38_row8_col2" class="data row8 col2" >600</td>
#       <td id="T_74f38_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_74f38_row8_col4" class="data row8 col4" >2.78</td>
#     </tr>
#     <tr>
#       <th id="T_74f38_level0_row9" class="row_heading level0 row9" >186</th>
#       <td id="T_74f38_row9_col0" class="data row9 col0" >SYNEX</td>
#       <td id="T_74f38_row9_col1" class="data row9 col1" >18.50</td>
#       <td id="T_74f38_row9_col2" class="data row9 col2" >29</td>
#       <td id="T_74f38_row9_col3" class="data row9 col3" >0.50</td>
#       <td id="T_74f38_row9_col4" class="data row9 col4" >2.78</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9d66_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9d66_level0_row0" class="row_heading level0 row0" >36</th>
#       <td id="T_b9d66_row0_col0" class="data row0 col0" >BLA</td>
#       <td id="T_b9d66_row0_col1" class="data row0 col1" >42.00</td>
#       <td id="T_b9d66_row0_col2" class="data row0 col2" >314</td>
#       <td id="T_b9d66_row0_col3" class="data row0 col3" >-1.75</td>
#       <td id="T_b9d66_row0_col4" class="data row0 col4" >-4.00</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row1" class="row_heading level0 row1" >197</th>
#       <td id="T_b9d66_row1_col0" class="data row1 col0" >TK</td>
#       <td id="T_b9d66_row1_col1" class="data row1 col1" >10.50</td>
#       <td id="T_b9d66_row1_col2" class="data row1 col2" >9</td>
#       <td id="T_b9d66_row1_col3" class="data row1 col3" >-0.30</td>
#       <td id="T_b9d66_row1_col4" class="data row1 col4" >-2.78</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row2" class="row_heading level0 row2" >68</th>
#       <td id="T_b9d66_row2_col0" class="data row2 col0" >ESSO</td>
#       <td id="T_b9d66_row2_col1" class="data row2 col1" >11.10</td>
#       <td id="T_b9d66_row2_col2" class="data row2 col2" >874</td>
#       <td id="T_b9d66_row2_col3" class="data row2 col3" >-0.30</td>
#       <td id="T_b9d66_row2_col4" class="data row2 col4" >-2.63</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row3" class="row_heading level0 row3" >175</th>
#       <td id="T_b9d66_row3_col0" class="data row3 col0" >SPRC</td>
#       <td id="T_b9d66_row3_col1" class="data row3 col1" >11.70</td>
#       <td id="T_b9d66_row3_col2" class="data row3 col2" >533</td>
#       <td id="T_b9d66_row3_col3" class="data row3 col3" >-0.30</td>
#       <td id="T_b9d66_row3_col4" class="data row3 col4" >-2.50</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row4" class="row_heading level0 row4" >218</th>
#       <td id="T_b9d66_row4_col0" class="data row4 col0" >TYCN</td>
#       <td id="T_b9d66_row4_col1" class="data row4 col1" >3.24</td>
#       <td id="T_b9d66_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_b9d66_row4_col3" class="data row4 col3" >-0.08</td>
#       <td id="T_b9d66_row4_col4" class="data row4 col4" >-2.41</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row5" class="row_heading level0 row5" >72</th>
#       <td id="T_b9d66_row5_col0" class="data row5 col0" >GFPT</td>
#       <td id="T_b9d66_row5_col1" class="data row5 col1" >17.90</td>
#       <td id="T_b9d66_row5_col2" class="data row5 col2" >73</td>
#       <td id="T_b9d66_row5_col3" class="data row5 col3" >-0.40</td>
#       <td id="T_b9d66_row5_col4" class="data row5 col4" >-2.19</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row6" class="row_heading level0 row6" >108</th>
#       <td id="T_b9d66_row6_col0" class="data row6 col0" >LANNA</td>
#       <td id="T_b9d66_row6_col1" class="data row6 col1" >19.00</td>
#       <td id="T_b9d66_row6_col2" class="data row6 col2" >56</td>
#       <td id="T_b9d66_row6_col3" class="data row6 col3" >-0.40</td>
#       <td id="T_b9d66_row6_col4" class="data row6 col4" >-2.06</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_b9d66_row7_col0" class="data row7 col0" >AP</td>
#       <td id="T_b9d66_row7_col1" class="data row7 col1" >9.80</td>
#       <td id="T_b9d66_row7_col2" class="data row7 col2" >307</td>
#       <td id="T_b9d66_row7_col3" class="data row7 col3" >-0.20</td>
#       <td id="T_b9d66_row7_col4" class="data row7 col4" >-2.00</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row8" class="row_heading level0 row8" >12</th>
#       <td id="T_b9d66_row8_col0" class="data row8 col0" >ASIAN</td>
#       <td id="T_b9d66_row8_col1" class="data row8 col1" >18.00</td>
#       <td id="T_b9d66_row8_col2" class="data row8 col2" >138</td>
#       <td id="T_b9d66_row8_col3" class="data row8 col3" >-0.30</td>
#       <td id="T_b9d66_row8_col4" class="data row8 col4" >-1.64</td>
#     </tr>
#     <tr>
#       <th id="T_b9d66_level0_row9" class="row_heading level0 row9" >19</th>
#       <td id="T_b9d66_row9_col0" class="data row9 col0" >BANPU</td>
#       <td id="T_b9d66_row9_col1" class="data row9 col1" >12.20</td>
#       <td id="T_b9d66_row9_col2" class="data row9 col2" >2,355</td>
#       <td id="T_b9d66_row9_col3" class="data row9 col3" >-0.20</td>
#       <td id="T_b9d66_row9_col4" class="data row9 col4" >-1.61</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_96327_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96327_level0_row0" class="row_heading level0 row0" >160</th>
#       <td id="T_96327_row0_col0" class="data row0 col0" >SCC</td>
#       <td id="T_96327_row0_col1" class="data row0 col1" >379.00</td>
#       <td id="T_96327_row0_col2" class="data row0 col2" >4,270</td>
#       <td id="T_96327_row0_col3" class="data row0 col3" >13.00</td>
#       <td id="T_96327_row0_col4" class="data row0 col4" >3.55</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row1" class="row_heading level0 row1" >144</th>
#       <td id="T_96327_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_96327_row1_col1" class="data row1 col1" >33.25</td>
#       <td id="T_96327_row1_col2" class="data row1 col2" >3,341</td>
#       <td id="T_96327_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_96327_row1_col4" class="data row1 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row2" class="row_heading level0 row2" >145</th>
#       <td id="T_96327_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_96327_row2_col1" class="data row2 col1" >153.50</td>
#       <td id="T_96327_row2_col2" class="data row2 col2" >2,639</td>
#       <td id="T_96327_row2_col3" class="data row2 col3" >-0.50</td>
#       <td id="T_96327_row2_col4" class="data row2 col4" >-0.32</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_96327_row3_col0" class="data row3 col0" >BANPU</td>
#       <td id="T_96327_row3_col1" class="data row3 col1" >12.20</td>
#       <td id="T_96327_row3_col2" class="data row3 col2" >2,355</td>
#       <td id="T_96327_row3_col3" class="data row3 col3" >-0.20</td>
#       <td id="T_96327_row3_col4" class="data row3 col4" >-1.61</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_96327_row4_col0" class="data row4 col0" >ADVANC</td>
#       <td id="T_96327_row4_col1" class="data row4 col1" >202.00</td>
#       <td id="T_96327_row4_col2" class="data row4 col2" >1,940</td>
#       <td id="T_96327_row4_col3" class="data row4 col3" >5.00</td>
#       <td id="T_96327_row4_col4" class="data row4 col4" >2.54</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row5" class="row_heading level0 row5" >98</th>
#       <td id="T_96327_row5_col0" class="data row5 col0" >KBANK</td>
#       <td id="T_96327_row5_col1" class="data row5 col1" >148.00</td>
#       <td id="T_96327_row5_col2" class="data row5 col2" >1,926</td>
#       <td id="T_96327_row5_col3" class="data row5 col3" >0.50</td>
#       <td id="T_96327_row5_col4" class="data row5 col4" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_96327_row6_col0" class="data row6 col0" >AOT</td>
#       <td id="T_96327_row6_col1" class="data row6 col1" >69.75</td>
#       <td id="T_96327_row6_col2" class="data row6 col2" >1,788</td>
#       <td id="T_96327_row6_col3" class="data row6 col3" >0.75</td>
#       <td id="T_96327_row6_col4" class="data row6 col4" >1.09</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row7" class="row_heading level0 row7" >48</th>
#       <td id="T_96327_row7_col0" class="data row7 col0" >CPALL</td>
#       <td id="T_96327_row7_col1" class="data row7 col1" >59.50</td>
#       <td id="T_96327_row7_col2" class="data row7 col2" >1,595</td>
#       <td id="T_96327_row7_col3" class="data row7 col3" >0.25</td>
#       <td id="T_96327_row7_col4" class="data row7 col4" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row8" class="row_heading level0 row8" >94</th>
#       <td id="T_96327_row8_col0" class="data row8 col0" >JASIF</td>
#       <td id="T_96327_row8_col1" class="data row8 col1" >9.60</td>
#       <td id="T_96327_row8_col2" class="data row8 col2" >1,501</td>
#       <td id="T_96327_row8_col3" class="data row8 col3" >0.35</td>
#       <td id="T_96327_row8_col4" class="data row8 col4" >3.78</td>
#     </tr>
#     <tr>
#       <th id="T_96327_level0_row9" class="row_heading level0 row9" >26</th>
#       <td id="T_96327_row9_col0" class="data row9 col0" >BDMS</td>
#       <td id="T_96327_row9_col1" class="data row9 col1" >24.90</td>
#       <td id="T_96327_row9_col2" class="data row9 col2" >1,499</td>
#       <td id="T_96327_row9_col3" class="data row9 col3" >0.20</td>
#       <td id="T_96327_row9_col4" class="data row9 col4" >0.81</td>
#     </tr>
#   </tbody>
# </table>
