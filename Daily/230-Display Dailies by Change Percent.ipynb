# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 5, 30)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c1339_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1339_level0_row0" class="row_heading level0 row0" >85</th>
#       <td id="T_c1339_row0_col0" class="data row0 col0" >HTC</td>
#       <td id="T_c1339_row0_col1" class="data row0 col1" >31.25</td>
#       <td id="T_c1339_row0_col2" class="data row0 col2" >94</td>
#       <td id="T_c1339_row0_col3" class="data row0 col3" >2.25</td>
#       <td id="T_c1339_row0_col4" class="data row0 col4" >7.76</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row1" class="row_heading level0 row1" >70</th>
#       <td id="T_c1339_row1_col0" class="data row1 col0" >FORTH</td>
#       <td id="T_c1339_row1_col1" class="data row1 col1" >49.00</td>
#       <td id="T_c1339_row1_col2" class="data row1 col2" >540</td>
#       <td id="T_c1339_row1_col3" class="data row1 col3" >3.50</td>
#       <td id="T_c1339_row1_col4" class="data row1 col4" >7.69</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row2" class="row_heading level0 row2" >26</th>
#       <td id="T_c1339_row2_col0" class="data row2 col0" >BCT</td>
#       <td id="T_c1339_row2_col1" class="data row2 col1" >53.50</td>
#       <td id="T_c1339_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_c1339_row2_col3" class="data row2 col3" >3.50</td>
#       <td id="T_c1339_row2_col4" class="data row2 col4" >7.00</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row3" class="row_heading level0 row3" >193</th>
#       <td id="T_c1339_row3_col0" class="data row3 col0" >THANI</td>
#       <td id="T_c1339_row3_col1" class="data row3 col1" >4.58</td>
#       <td id="T_c1339_row3_col2" class="data row3 col2" >428</td>
#       <td id="T_c1339_row3_col3" class="data row3 col3" >0.28</td>
#       <td id="T_c1339_row3_col4" class="data row3 col4" >6.51</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row4" class="row_heading level0 row4" >128</th>
#       <td id="T_c1339_row4_col0" class="data row4 col0" >MTC</td>
#       <td id="T_c1339_row4_col1" class="data row4 col1" >50.00</td>
#       <td id="T_c1339_row4_col2" class="data row4 col2" >1,295</td>
#       <td id="T_c1339_row4_col3" class="data row4 col3" >2.50</td>
#       <td id="T_c1339_row4_col4" class="data row4 col4" >5.26</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row5" class="row_heading level0 row5" >23</th>
#       <td id="T_c1339_row5_col0" class="data row5 col0" >BCH</td>
#       <td id="T_c1339_row5_col1" class="data row5 col1" >19.90</td>
#       <td id="T_c1339_row5_col2" class="data row5 col2" >518</td>
#       <td id="T_c1339_row5_col3" class="data row5 col3" >0.90</td>
#       <td id="T_c1339_row5_col4" class="data row5 col4" >4.74</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row6" class="row_heading level0 row6" >65</th>
#       <td id="T_c1339_row6_col0" class="data row6 col0" >ECL</td>
#       <td id="T_c1339_row6_col1" class="data row6 col1" >2.68</td>
#       <td id="T_c1339_row6_col2" class="data row6 col2" >184</td>
#       <td id="T_c1339_row6_col3" class="data row6 col3" >0.12</td>
#       <td id="T_c1339_row6_col4" class="data row6 col4" >4.69</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_c1339_row7_col0" class="data row7 col0" >ANAN</td>
#       <td id="T_c1339_row7_col1" class="data row7 col1" >1.34</td>
#       <td id="T_c1339_row7_col2" class="data row7 col2" >26</td>
#       <td id="T_c1339_row7_col3" class="data row7 col3" >0.06</td>
#       <td id="T_c1339_row7_col4" class="data row7 col4" >4.69</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row8" class="row_heading level0 row8" >180</th>
#       <td id="T_c1339_row8_col0" class="data row8 col0" >STA</td>
#       <td id="T_c1339_row8_col1" class="data row8 col1" >25.00</td>
#       <td id="T_c1339_row8_col2" class="data row8 col2" >342</td>
#       <td id="T_c1339_row8_col3" class="data row8 col3" >1.10</td>
#       <td id="T_c1339_row8_col4" class="data row8 col4" >4.60</td>
#     </tr>
#     <tr>
#       <th id="T_c1339_level0_row9" class="row_heading level0 row9" >151</th>
#       <td id="T_c1339_row9_col0" class="data row9 col0" >RBF</td>
#       <td id="T_c1339_row9_col1" class="data row9 col1" >16.00</td>
#       <td id="T_c1339_row9_col2" class="data row9 col2" >159</td>
#       <td id="T_c1339_row9_col3" class="data row9 col3" >0.70</td>
#       <td id="T_c1339_row9_col4" class="data row9 col4" >4.58</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_45faa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45faa_level0_row0" class="row_heading level0 row0" >194</th>
#       <td id="T_45faa_row0_col0" class="data row0 col0" >THG</td>
#       <td id="T_45faa_row0_col1" class="data row0 col1" >68.00</td>
#       <td id="T_45faa_row0_col2" class="data row0 col2" >743</td>
#       <td id="T_45faa_row0_col3" class="data row0 col3" >-2.25</td>
#       <td id="T_45faa_row0_col4" class="data row0 col4" >-3.20</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row1" class="row_heading level0 row1" >143</th>
#       <td id="T_45faa_row1_col0" class="data row1 col0" >PSL</td>
#       <td id="T_45faa_row1_col1" class="data row1 col1" >18.60</td>
#       <td id="T_45faa_row1_col2" class="data row1 col2" >215</td>
#       <td id="T_45faa_row1_col3" class="data row1 col3" >-0.50</td>
#       <td id="T_45faa_row1_col4" class="data row1 col4" >-2.62</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row2" class="row_heading level0 row2" >73</th>
#       <td id="T_45faa_row2_col0" class="data row2 col0" >GFPT</td>
#       <td id="T_45faa_row2_col1" class="data row2 col1" >16.40</td>
#       <td id="T_45faa_row2_col2" class="data row2 col2" >87</td>
#       <td id="T_45faa_row2_col3" class="data row2 col3" >-0.40</td>
#       <td id="T_45faa_row2_col4" class="data row2 col4" >-2.38</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row3" class="row_heading level0 row3" >68</th>
#       <td id="T_45faa_row3_col0" class="data row3 col0" >EPG</td>
#       <td id="T_45faa_row3_col1" class="data row3 col1" >10.10</td>
#       <td id="T_45faa_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_45faa_row3_col3" class="data row3 col3" >-0.20</td>
#       <td id="T_45faa_row3_col4" class="data row3 col4" >-1.94</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row4" class="row_heading level0 row4" >113</th>
#       <td id="T_45faa_row4_col0" class="data row4 col0" >LHK</td>
#       <td id="T_45faa_row4_col1" class="data row4 col1" >5.75</td>
#       <td id="T_45faa_row4_col2" class="data row4 col2" >55</td>
#       <td id="T_45faa_row4_col3" class="data row4 col3" >-0.10</td>
#       <td id="T_45faa_row4_col4" class="data row4 col4" >-1.71</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row5" class="row_heading level0 row5" >212</th>
#       <td id="T_45faa_row5_col0" class="data row5 col0" >TSTH</td>
#       <td id="T_45faa_row5_col1" class="data row5 col1" >1.40</td>
#       <td id="T_45faa_row5_col2" class="data row5 col2" >24</td>
#       <td id="T_45faa_row5_col3" class="data row5 col3" >-0.02</td>
#       <td id="T_45faa_row5_col4" class="data row5 col4" >-1.41</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_45faa_row6_col0" class="data row6 col0" >ALUCON</td>
#       <td id="T_45faa_row6_col1" class="data row6 col1" >190.50</td>
#       <td id="T_45faa_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_45faa_row6_col3" class="data row6 col3" >-2.50</td>
#       <td id="T_45faa_row6_col4" class="data row6 col4" >-1.30</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row7" class="row_heading level0 row7" >228</th>
#       <td id="T_45faa_row7_col0" class="data row7 col0" >WICE</td>
#       <td id="T_45faa_row7_col1" class="data row7 col1" >15.50</td>
#       <td id="T_45faa_row7_col2" class="data row7 col2" >194</td>
#       <td id="T_45faa_row7_col3" class="data row7 col3" >-0.20</td>
#       <td id="T_45faa_row7_col4" class="data row7 col4" >-1.27</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row8" class="row_heading level0 row8" >152</th>
#       <td id="T_45faa_row8_col0" class="data row8 col0" >RCL</td>
#       <td id="T_45faa_row8_col1" class="data row8 col1" >44.50</td>
#       <td id="T_45faa_row8_col2" class="data row8 col2" >257</td>
#       <td id="T_45faa_row8_col3" class="data row8 col3" >-0.50</td>
#       <td id="T_45faa_row8_col4" class="data row8 col4" >-1.11</td>
#     </tr>
#     <tr>
#       <th id="T_45faa_level0_row9" class="row_heading level0 row9" >226</th>
#       <td id="T_45faa_row9_col0" class="data row9 col0" >WHART</td>
#       <td id="T_45faa_row9_col1" class="data row9 col1" >10.40</td>
#       <td id="T_45faa_row9_col2" class="data row9 col2" >11</td>
#       <td id="T_45faa_row9_col3" class="data row9 col3" >-0.10</td>
#       <td id="T_45faa_row9_col4" class="data row9 col4" >-0.95</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_71b4f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71b4f_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_71b4f_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_71b4f_row0_col1" class="data row0 col1" >69.50</td>
#       <td id="T_71b4f_row0_col2" class="data row0 col2" >4,240</td>
#       <td id="T_71b4f_row0_col3" class="data row0 col3" >0.50</td>
#       <td id="T_71b4f_row0_col4" class="data row0 col4" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row1" class="row_heading level0 row1" >146</th>
#       <td id="T_71b4f_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_71b4f_row1_col1" class="data row1 col1" >38.00</td>
#       <td id="T_71b4f_row1_col2" class="data row1 col2" >2,309</td>
#       <td id="T_71b4f_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_71b4f_row1_col4" class="data row1 col4" >1.33</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row2" class="row_heading level0 row2" >147</th>
#       <td id="T_71b4f_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_71b4f_row2_col1" class="data row2 col1" >165.50</td>
#       <td id="T_71b4f_row2_col2" class="data row2 col2" >1,764</td>
#       <td id="T_71b4f_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_71b4f_row2_col4" class="data row2 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row3" class="row_heading level0 row3" >27</th>
#       <td id="T_71b4f_row3_col0" class="data row3 col0" >BDMS</td>
#       <td id="T_71b4f_row3_col1" class="data row3 col1" >25.50</td>
#       <td id="T_71b4f_row3_col2" class="data row3 col2" >1,654</td>
#       <td id="T_71b4f_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_71b4f_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row4" class="row_heading level0 row4" >101</th>
#       <td id="T_71b4f_row4_col0" class="data row4 col0" >KCE</td>
#       <td id="T_71b4f_row4_col1" class="data row4 col1" >66.25</td>
#       <td id="T_71b4f_row4_col2" class="data row4 col2" >1,553</td>
#       <td id="T_71b4f_row4_col3" class="data row4 col3" >1.25</td>
#       <td id="T_71b4f_row4_col4" class="data row4 col4" >1.92</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row5" class="row_heading level0 row5" >100</th>
#       <td id="T_71b4f_row5_col0" class="data row5 col0" >KBANK</td>
#       <td id="T_71b4f_row5_col1" class="data row5 col1" >148.00</td>
#       <td id="T_71b4f_row5_col2" class="data row5 col2" >1,541</td>
#       <td id="T_71b4f_row5_col3" class="data row5 col3" >1.50</td>
#       <td id="T_71b4f_row5_col4" class="data row5 col4" >1.02</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row6" class="row_heading level0 row6" >128</th>
#       <td id="T_71b4f_row6_col0" class="data row6 col0" >MTC</td>
#       <td id="T_71b4f_row6_col1" class="data row6 col1" >50.00</td>
#       <td id="T_71b4f_row6_col2" class="data row6 col2" >1,295</td>
#       <td id="T_71b4f_row6_col3" class="data row6 col3" >2.50</td>
#       <td id="T_71b4f_row6_col4" class="data row6 col4" >5.26</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row7" class="row_heading level0 row7" >195</th>
#       <td id="T_71b4f_row7_col0" class="data row7 col0" >TIDLOR</td>
#       <td id="T_71b4f_row7_col1" class="data row7 col1" >33.75</td>
#       <td id="T_71b4f_row7_col2" class="data row7 col2" >1,291</td>
#       <td id="T_71b4f_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_71b4f_row7_col4" class="data row7 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row8" class="row_heading level0 row8" >49</th>
#       <td id="T_71b4f_row8_col0" class="data row8 col0" >CPALL</td>
#       <td id="T_71b4f_row8_col1" class="data row8 col1" >65.75</td>
#       <td id="T_71b4f_row8_col2" class="data row8 col2" >1,177</td>
#       <td id="T_71b4f_row8_col3" class="data row8 col3" >0.75</td>
#       <td id="T_71b4f_row8_col4" class="data row8 col4" >1.15</td>
#     </tr>
#     <tr>
#       <th id="T_71b4f_level0_row9" class="row_heading level0 row9" >132</th>
#       <td id="T_71b4f_row9_col0" class="data row9 col0" >OR</td>
#       <td id="T_71b4f_row9_col1" class="data row9 col1" >27.25</td>
#       <td id="T_71b4f_row9_col2" class="data row9 col2" >1,162</td>
#       <td id="T_71b4f_row9_col3" class="data row9 col3" >0.25</td>
#       <td id="T_71b4f_row9_col4" class="data row9 col4" >0.93</td>
#     </tr>
#   </tbody>
# </table>
