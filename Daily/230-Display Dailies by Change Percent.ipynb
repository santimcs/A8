# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 8, 24)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_09fbd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09fbd_level0_row0" class="row_heading level0 row0" >119</th>
#       <td id="T_09fbd_row0_col0" class="data row0 col0" >MACO</td>
#       <td id="T_09fbd_row0_col1" class="data row0 col1" >0.56</td>
#       <td id="T_09fbd_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_09fbd_row0_col3" class="data row0 col3" >0.04</td>
#       <td id="T_09fbd_row0_col4" class="data row0 col4" >7.69</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row1" class="row_heading level0 row1" >202</th>
#       <td id="T_09fbd_row1_col0" class="data row1 col0" >TKS</td>
#       <td id="T_09fbd_row1_col1" class="data row1 col1" >11.30</td>
#       <td id="T_09fbd_row1_col2" class="data row1 col2" >86</td>
#       <td id="T_09fbd_row1_col3" class="data row1 col3" >0.80</td>
#       <td id="T_09fbd_row1_col4" class="data row1 col4" >7.62</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_09fbd_row2_col0" class="data row2 col0" >COTTO</td>
#       <td id="T_09fbd_row2_col1" class="data row2 col1" >2.10</td>
#       <td id="T_09fbd_row2_col2" class="data row2 col2" >38</td>
#       <td id="T_09fbd_row2_col3" class="data row2 col3" >0.10</td>
#       <td id="T_09fbd_row2_col4" class="data row2 col4" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_09fbd_row3_col0" class="data row3 col0" >FORTH</td>
#       <td id="T_09fbd_row3_col1" class="data row3 col1" >55.25</td>
#       <td id="T_09fbd_row3_col2" class="data row3 col2" >328</td>
#       <td id="T_09fbd_row3_col3" class="data row3 col3" >2.50</td>
#       <td id="T_09fbd_row3_col4" class="data row3 col4" >4.74</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row4" class="row_heading level0 row4" >148</th>
#       <td id="T_09fbd_row4_col0" class="data row4 col0" >PTTEP</td>
#       <td id="T_09fbd_row4_col1" class="data row4 col1" >168.00</td>
#       <td id="T_09fbd_row4_col2" class="data row4 col2" >6,073</td>
#       <td id="T_09fbd_row4_col3" class="data row4 col3" >7.00</td>
#       <td id="T_09fbd_row4_col4" class="data row4 col4" >4.35</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row5" class="row_heading level0 row5" >155</th>
#       <td id="T_09fbd_row5_col0" class="data row5 col0" >ROJNA</td>
#       <td id="T_09fbd_row5_col1" class="data row5 col1" >6.15</td>
#       <td id="T_09fbd_row5_col2" class="data row5 col2" >31</td>
#       <td id="T_09fbd_row5_col3" class="data row5 col3" >0.25</td>
#       <td id="T_09fbd_row5_col4" class="data row5 col4" >4.24</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row6" class="row_heading level0 row6" >132</th>
#       <td id="T_09fbd_row6_col0" class="data row6 col0" >ONEE</td>
#       <td id="T_09fbd_row6_col1" class="data row6 col1" >9.90</td>
#       <td id="T_09fbd_row6_col2" class="data row6 col2" >146</td>
#       <td id="T_09fbd_row6_col3" class="data row6 col3" >0.40</td>
#       <td id="T_09fbd_row6_col4" class="data row6 col4" >4.21</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row7" class="row_heading level0 row7" >95</th>
#       <td id="T_09fbd_row7_col0" class="data row7 col0" >IVL</td>
#       <td id="T_09fbd_row7_col1" class="data row7 col1" >45.75</td>
#       <td id="T_09fbd_row7_col2" class="data row7 col2" >2,022</td>
#       <td id="T_09fbd_row7_col3" class="data row7 col3" >1.75</td>
#       <td id="T_09fbd_row7_col4" class="data row7 col4" >3.98</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row8" class="row_heading level0 row8" >12</th>
#       <td id="T_09fbd_row8_col0" class="data row8 col0" >ASIAN</td>
#       <td id="T_09fbd_row8_col1" class="data row8 col1" >17.30</td>
#       <td id="T_09fbd_row8_col2" class="data row8 col2" >174</td>
#       <td id="T_09fbd_row8_col3" class="data row8 col3" >0.60</td>
#       <td id="T_09fbd_row8_col4" class="data row8 col4" >3.59</td>
#     </tr>
#     <tr>
#       <th id="T_09fbd_level0_row9" class="row_heading level0 row9" >205</th>
#       <td id="T_09fbd_row9_col0" class="data row9 col0" >TOA</td>
#       <td id="T_09fbd_row9_col1" class="data row9 col1" >30.25</td>
#       <td id="T_09fbd_row9_col2" class="data row9 col2" >74</td>
#       <td id="T_09fbd_row9_col3" class="data row9 col3" >1.00</td>
#       <td id="T_09fbd_row9_col4" class="data row9 col4" >3.42</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbdb2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbdb2_level0_row0" class="row_heading level0 row0" >122</th>
#       <td id="T_dbdb2_row0_col0" class="data row0 col0" >MBAX</td>
#       <td id="T_dbdb2_row0_col1" class="data row0 col1" >5.45</td>
#       <td id="T_dbdb2_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_dbdb2_row0_col3" class="data row0 col3" >-0.85</td>
#       <td id="T_dbdb2_row0_col4" class="data row0 col4" >-13.49</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row1" class="row_heading level0 row1" >58</th>
#       <td id="T_dbdb2_row1_col0" class="data row1 col0" >DELTA</td>
#       <td id="T_dbdb2_row1_col1" class="data row1 col1" >554.00</td>
#       <td id="T_dbdb2_row1_col2" class="data row1 col2" >1,569</td>
#       <td id="T_dbdb2_row1_col3" class="data row1 col3" >-26.00</td>
#       <td id="T_dbdb2_row1_col4" class="data row1 col4" >-4.48</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row2" class="row_heading level0 row2" >115</th>
#       <td id="T_dbdb2_row2_col0" class="data row2 col0" >LPF</td>
#       <td id="T_dbdb2_row2_col1" class="data row2 col1" >13.90</td>
#       <td id="T_dbdb2_row2_col2" class="data row2 col2" >11</td>
#       <td id="T_dbdb2_row2_col3" class="data row2 col3" >-0.50</td>
#       <td id="T_dbdb2_row2_col4" class="data row2 col4" >-3.47</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row3" class="row_heading level0 row3" >92</th>
#       <td id="T_dbdb2_row3_col0" class="data row3 col0" >INTUCH</td>
#       <td id="T_dbdb2_row3_col1" class="data row3 col1" >73.25</td>
#       <td id="T_dbdb2_row3_col2" class="data row3 col2" >324</td>
#       <td id="T_dbdb2_row3_col3" class="data row3 col3" >-2.50</td>
#       <td id="T_dbdb2_row3_col4" class="data row3 col4" >-3.30</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row4" class="row_heading level0 row4" >178</th>
#       <td id="T_dbdb2_row4_col0" class="data row4 col0" >SPRC</td>
#       <td id="T_dbdb2_row4_col1" class="data row4 col1" >12.80</td>
#       <td id="T_dbdb2_row4_col2" class="data row4 col2" >570</td>
#       <td id="T_dbdb2_row4_col3" class="data row4 col3" >-0.40</td>
#       <td id="T_dbdb2_row4_col4" class="data row4 col4" >-3.03</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row5" class="row_heading level0 row5" >176</th>
#       <td id="T_dbdb2_row5_col0" class="data row5 col0" >SPC</td>
#       <td id="T_dbdb2_row5_col1" class="data row5 col1" >66.25</td>
#       <td id="T_dbdb2_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_dbdb2_row5_col3" class="data row5 col3" >-2.00</td>
#       <td id="T_dbdb2_row5_col4" class="data row5 col4" >-2.93</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row6" class="row_heading level0 row6" >221</th>
#       <td id="T_dbdb2_row6_col0" class="data row6 col0" >TYCN</td>
#       <td id="T_dbdb2_row6_col1" class="data row6 col1" >3.06</td>
#       <td id="T_dbdb2_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_dbdb2_row6_col3" class="data row6 col3" >-0.08</td>
#       <td id="T_dbdb2_row6_col4" class="data row6 col4" >-2.55</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row7" class="row_heading level0 row7" >5</th>
#       <td id="T_dbdb2_row7_col0" class="data row7 col0" >AIMIRT</td>
#       <td id="T_dbdb2_row7_col1" class="data row7 col1" >12.10</td>
#       <td id="T_dbdb2_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_dbdb2_row7_col3" class="data row7 col3" >-0.30</td>
#       <td id="T_dbdb2_row7_col4" class="data row7 col4" >-2.42</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row8" class="row_heading level0 row8" >219</th>
#       <td id="T_dbdb2_row8_col0" class="data row8 col0" >TVI</td>
#       <td id="T_dbdb2_row8_col1" class="data row8 col1" >16.90</td>
#       <td id="T_dbdb2_row8_col2" class="data row8 col2" >6</td>
#       <td id="T_dbdb2_row8_col3" class="data row8 col3" >-0.40</td>
#       <td id="T_dbdb2_row8_col4" class="data row8 col4" >-2.31</td>
#     </tr>
#     <tr>
#       <th id="T_dbdb2_level0_row9" class="row_heading level0 row9" >82</th>
#       <td id="T_dbdb2_row9_col0" class="data row9 col0" >HANA</td>
#       <td id="T_dbdb2_row9_col1" class="data row9 col1" >43.75</td>
#       <td id="T_dbdb2_row9_col2" class="data row9 col2" >193</td>
#       <td id="T_dbdb2_row9_col3" class="data row9 col3" >-1.00</td>
#       <td id="T_dbdb2_row9_col4" class="data row9 col4" >-2.23</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6af17_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6af17_level0_row0" class="row_heading level0 row0" >148</th>
#       <td id="T_6af17_row0_col0" class="data row0 col0" >PTTEP</td>
#       <td id="T_6af17_row0_col1" class="data row0 col1" >168.00</td>
#       <td id="T_6af17_row0_col2" class="data row0 col2" >6,073</td>
#       <td id="T_6af17_row0_col3" class="data row0 col3" >7.00</td>
#       <td id="T_6af17_row0_col4" class="data row0 col4" >4.35</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_6af17_row1_col0" class="data row1 col0" >BANPU</td>
#       <td id="T_6af17_row1_col1" class="data row1 col1" >14.50</td>
#       <td id="T_6af17_row1_col2" class="data row1 col2" >4,703</td>
#       <td id="T_6af17_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_6af17_row1_col4" class="data row1 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row2" class="row_heading level0 row2" >147</th>
#       <td id="T_6af17_row2_col0" class="data row2 col0" >PTT</td>
#       <td id="T_6af17_row2_col1" class="data row2 col1" >37.75</td>
#       <td id="T_6af17_row2_col2" class="data row2 col2" >3,665</td>
#       <td id="T_6af17_row2_col3" class="data row2 col3" >0.25</td>
#       <td id="T_6af17_row2_col4" class="data row2 col4" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row3" class="row_heading level0 row3" >100</th>
#       <td id="T_6af17_row3_col0" class="data row3 col0" >KBANK</td>
#       <td id="T_6af17_row3_col1" class="data row3 col1" >156.00</td>
#       <td id="T_6af17_row3_col2" class="data row3 col2" >3,322</td>
#       <td id="T_6af17_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_6af17_row3_col4" class="data row3 col4" >0.65</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row4" class="row_heading level0 row4" >162</th>
#       <td id="T_6af17_row4_col0" class="data row4 col0" >SCB</td>
#       <td id="T_6af17_row4_col1" class="data row4 col1" >104.50</td>
#       <td id="T_6af17_row4_col2" class="data row4 col2" >2,289</td>
#       <td id="T_6af17_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_6af17_row4_col4" class="data row4 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row5" class="row_heading level0 row5" >34</th>
#       <td id="T_6af17_row5_col0" class="data row5 col0" >BH</td>
#       <td id="T_6af17_row5_col1" class="data row5 col1" >211.00</td>
#       <td id="T_6af17_row5_col2" class="data row5 col2" >2,185</td>
#       <td id="T_6af17_row5_col3" class="data row5 col3" >-3.00</td>
#       <td id="T_6af17_row5_col4" class="data row5 col4" >-1.40</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row6" class="row_heading level0 row6" >95</th>
#       <td id="T_6af17_row6_col0" class="data row6 col0" >IVL</td>
#       <td id="T_6af17_row6_col1" class="data row6 col1" >45.75</td>
#       <td id="T_6af17_row6_col2" class="data row6 col2" >2,022</td>
#       <td id="T_6af17_row6_col3" class="data row6 col3" >1.75</td>
#       <td id="T_6af17_row6_col4" class="data row6 col4" >3.98</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row7" class="row_heading level0 row7" >58</th>
#       <td id="T_6af17_row7_col0" class="data row7 col0" >DELTA</td>
#       <td id="T_6af17_row7_col1" class="data row7 col1" >554.00</td>
#       <td id="T_6af17_row7_col2" class="data row7 col2" >1,569</td>
#       <td id="T_6af17_row7_col3" class="data row7 col3" >-26.00</td>
#       <td id="T_6af17_row7_col4" class="data row7 col4" >-4.48</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_6af17_row8_col0" class="data row8 col0" >AOT</td>
#       <td id="T_6af17_row8_col1" class="data row8 col1" >71.50</td>
#       <td id="T_6af17_row8_col2" class="data row8 col2" >1,492</td>
#       <td id="T_6af17_row8_col3" class="data row8 col3" >0.00</td>
#       <td id="T_6af17_row8_col4" class="data row8 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6af17_level0_row9" class="row_heading level0 row9" >206</th>
#       <td id="T_6af17_row9_col0" class="data row9 col0" >TOP</td>
#       <td id="T_6af17_row9_col1" class="data row9 col1" >60.25</td>
#       <td id="T_6af17_row9_col2" class="data row9 col2" >1,374</td>
#       <td id="T_6af17_row9_col3" class="data row9 col3" >0.75</td>
#       <td id="T_6af17_row9_col4" class="data row9 col4" >1.26</td>
#     </tr>
#   </tbody>
# </table>
