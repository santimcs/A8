# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 8, 23)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies[df_dailies['daily_volume'] == '-']
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_99df3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99df3_level0_row0" class="row_heading level0 row0" >34</th>
#       <td id="T_99df3_row0_col0" class="data row0 col0" >BH</td>
#       <td id="T_99df3_row0_col1" class="data row0 col1" >214.00</td>
#       <td id="T_99df3_row0_col2" class="data row0 col2" >3,867</td>
#       <td id="T_99df3_row0_col3" class="data row0 col3" >19.50</td>
#       <td id="T_99df3_row0_col4" class="data row0 col4" >10.03</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row1" class="row_heading level0 row1" >110</th>
#       <td id="T_99df3_row1_col0" class="data row1 col0" >LANNA</td>
#       <td id="T_99df3_row1_col1" class="data row1 col1" >23.80</td>
#       <td id="T_99df3_row1_col2" class="data row1 col2" >652</td>
#       <td id="T_99df3_row1_col3" class="data row1 col3" >1.40</td>
#       <td id="T_99df3_row1_col4" class="data row1 col4" >6.25</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row2" class="row_heading level0 row2" >86</th>
#       <td id="T_99df3_row2_col0" class="data row2 col0" >ICHI</td>
#       <td id="T_99df3_row2_col1" class="data row2 col1" >8.60</td>
#       <td id="T_99df3_row2_col2" class="data row2 col2" >76</td>
#       <td id="T_99df3_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_99df3_row2_col4" class="data row2 col4" >6.17</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row3" class="row_heading level0 row3" >17</th>
#       <td id="T_99df3_row3_col0" class="data row3 col0" >BA</td>
#       <td id="T_99df3_row3_col1" class="data row3 col1" >10.80</td>
#       <td id="T_99df3_row3_col2" class="data row3 col2" >101</td>
#       <td id="T_99df3_row3_col3" class="data row3 col3" >0.50</td>
#       <td id="T_99df3_row3_col4" class="data row3 col4" >4.85</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row4" class="row_heading level0 row4" >58</th>
#       <td id="T_99df3_row4_col0" class="data row4 col0" >DELTA</td>
#       <td id="T_99df3_row4_col1" class="data row4 col1" >580.00</td>
#       <td id="T_99df3_row4_col2" class="data row4 col2" >1,890</td>
#       <td id="T_99df3_row4_col3" class="data row4 col3" >26.00</td>
#       <td id="T_99df3_row4_col4" class="data row4 col4" >4.69</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row5" class="row_heading level0 row5" >74</th>
#       <td id="T_99df3_row5_col0" class="data row5 col0" >GFPT</td>
#       <td id="T_99df3_row5_col1" class="data row5 col1" >15.80</td>
#       <td id="T_99df3_row5_col2" class="data row5 col2" >126</td>
#       <td id="T_99df3_row5_col3" class="data row5 col3" >0.70</td>
#       <td id="T_99df3_row5_col4" class="data row5 col4" >4.64</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_99df3_row6_col0" class="data row6 col0" >BANPU</td>
#       <td id="T_99df3_row6_col1" class="data row6 col1" >14.50</td>
#       <td id="T_99df3_row6_col2" class="data row6 col2" >5,508</td>
#       <td id="T_99df3_row6_col3" class="data row6 col3" >0.60</td>
#       <td id="T_99df3_row6_col4" class="data row6 col4" >4.32</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row7" class="row_heading level0 row7" >193</th>
#       <td id="T_99df3_row7_col0" class="data row7 col0" >TFG</td>
#       <td id="T_99df3_row7_col1" class="data row7 col1" >6.45</td>
#       <td id="T_99df3_row7_col2" class="data row7 col2" >268</td>
#       <td id="T_99df3_row7_col3" class="data row7 col3" >0.25</td>
#       <td id="T_99df3_row7_col4" class="data row7 col4" >4.03</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row8" class="row_heading level0 row8" >119</th>
#       <td id="T_99df3_row8_col0" class="data row8 col0" >MACO</td>
#       <td id="T_99df3_row8_col1" class="data row8 col1" >0.52</td>
#       <td id="T_99df3_row8_col2" class="data row8 col2" >7</td>
#       <td id="T_99df3_row8_col3" class="data row8 col3" >0.02</td>
#       <td id="T_99df3_row8_col4" class="data row8 col4" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_99df3_level0_row9" class="row_heading level0 row9" >168</th>
#       <td id="T_99df3_row9_col0" class="data row9 col0" >SINGER</td>
#       <td id="T_99df3_row9_col1" class="data row9 col1" >45.50</td>
#       <td id="T_99df3_row9_col2" class="data row9 col2" >174</td>
#       <td id="T_99df3_row9_col3" class="data row9 col3" >1.75</td>
#       <td id="T_99df3_row9_col4" class="data row9 col4" >4.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0a57b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a57b_level0_row0" class="row_heading level0 row0" >185</th>
#       <td id="T_0a57b_row0_col0" class="data row0 col0" >STGT</td>
#       <td id="T_0a57b_row0_col1" class="data row0 col1" >14.80</td>
#       <td id="T_0a57b_row0_col2" class="data row0 col2" >299</td>
#       <td id="T_0a57b_row0_col3" class="data row0 col3" >-0.90</td>
#       <td id="T_0a57b_row0_col4" class="data row0 col4" >-5.73</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row1" class="row_heading level0 row1" >181</th>
#       <td id="T_0a57b_row1_col0" class="data row1 col0" >STA</td>
#       <td id="T_0a57b_row1_col1" class="data row1 col1" >21.10</td>
#       <td id="T_0a57b_row1_col2" class="data row1 col2" >304</td>
#       <td id="T_0a57b_row1_col3" class="data row1 col3" >-1.20</td>
#       <td id="T_0a57b_row1_col4" class="data row1 col4" >-5.38</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row2" class="row_heading level0 row2" >72</th>
#       <td id="T_0a57b_row2_col0" class="data row2 col0" >FSMART</td>
#       <td id="T_0a57b_row2_col1" class="data row2 col1" >20.40</td>
#       <td id="T_0a57b_row2_col2" class="data row2 col2" >583</td>
#       <td id="T_0a57b_row2_col3" class="data row2 col3" >-1.00</td>
#       <td id="T_0a57b_row2_col4" class="data row2 col4" >-4.67</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row3" class="row_heading level0 row3" >175</th>
#       <td id="T_0a57b_row3_col0" class="data row3 col0" >SPALI</td>
#       <td id="T_0a57b_row3_col1" class="data row3 col1" >19.60</td>
#       <td id="T_0a57b_row3_col2" class="data row3 col2" >184</td>
#       <td id="T_0a57b_row3_col3" class="data row3 col3" >-0.70</td>
#       <td id="T_0a57b_row3_col4" class="data row3 col4" >-3.45</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row4" class="row_heading level0 row4" >137</th>
#       <td id="T_0a57b_row4_col0" class="data row4 col0" >PCSGH</td>
#       <td id="T_0a57b_row4_col1" class="data row4 col1" >5.00</td>
#       <td id="T_0a57b_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_0a57b_row4_col3" class="data row4 col3" >-0.15</td>
#       <td id="T_0a57b_row4_col4" class="data row4 col4" >-2.91</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row5" class="row_heading level0 row5" >171</th>
#       <td id="T_0a57b_row5_col0" class="data row5 col0" >SKN</td>
#       <td id="T_0a57b_row5_col1" class="data row5 col1" >5.50</td>
#       <td id="T_0a57b_row5_col2" class="data row5 col2" >18</td>
#       <td id="T_0a57b_row5_col3" class="data row5 col3" >-0.15</td>
#       <td id="T_0a57b_row5_col4" class="data row5 col4" >-2.65</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row6" class="row_heading level0 row6" >116</th>
#       <td id="T_0a57b_row6_col0" class="data row6 col0" >LPH</td>
#       <td id="T_0a57b_row6_col1" class="data row6 col1" >5.75</td>
#       <td id="T_0a57b_row6_col2" class="data row6 col2" >8</td>
#       <td id="T_0a57b_row6_col3" class="data row6 col3" >-0.15</td>
#       <td id="T_0a57b_row6_col4" class="data row6 col4" >-2.54</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row7" class="row_heading level0 row7" >173</th>
#       <td id="T_0a57b_row7_col0" class="data row7 col0" >SMPC</td>
#       <td id="T_0a57b_row7_col1" class="data row7 col1" >15.40</td>
#       <td id="T_0a57b_row7_col2" class="data row7 col2" >24</td>
#       <td id="T_0a57b_row7_col3" class="data row7 col3" >-0.40</td>
#       <td id="T_0a57b_row7_col4" class="data row7 col4" >-2.53</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row8" class="row_heading level0 row8" >227</th>
#       <td id="T_0a57b_row8_col0" class="data row8 col0" >WHAIR</td>
#       <td id="T_0a57b_row8_col1" class="data row8 col1" >7.50</td>
#       <td id="T_0a57b_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_0a57b_row8_col3" class="data row8 col3" >-0.15</td>
#       <td id="T_0a57b_row8_col4" class="data row8 col4" >-1.96</td>
#     </tr>
#     <tr>
#       <th id="T_0a57b_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_0a57b_row9_col0" class="data row9 col0" >AP</td>
#       <td id="T_0a57b_row9_col1" class="data row9 col1" >10.20</td>
#       <td id="T_0a57b_row9_col2" class="data row9 col2" >138</td>
#       <td id="T_0a57b_row9_col3" class="data row9 col3" >-0.20</td>
#       <td id="T_0a57b_row9_col4" class="data row9 col4" >-1.92</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff6aa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price</th>
#       <th class="col_heading level0 col2" >daily_volume</th>
#       <th class="col_heading level0 col3" >chg_amt</th>
#       <th class="col_heading level0 col4" >chg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff6aa_level0_row0" class="row_heading level0 row0" >19</th>
#       <td id="T_ff6aa_row0_col0" class="data row0 col0" >BANPU</td>
#       <td id="T_ff6aa_row0_col1" class="data row0 col1" >14.50</td>
#       <td id="T_ff6aa_row0_col2" class="data row0 col2" >5,508</td>
#       <td id="T_ff6aa_row0_col3" class="data row0 col3" >0.60</td>
#       <td id="T_ff6aa_row0_col4" class="data row0 col4" >4.32</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row1" class="row_heading level0 row1" >34</th>
#       <td id="T_ff6aa_row1_col0" class="data row1 col0" >BH</td>
#       <td id="T_ff6aa_row1_col1" class="data row1 col1" >214.00</td>
#       <td id="T_ff6aa_row1_col2" class="data row1 col2" >3,867</td>
#       <td id="T_ff6aa_row1_col3" class="data row1 col3" >19.50</td>
#       <td id="T_ff6aa_row1_col4" class="data row1 col4" >10.03</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row2" class="row_heading level0 row2" >148</th>
#       <td id="T_ff6aa_row2_col0" class="data row2 col0" >PTTEP</td>
#       <td id="T_ff6aa_row2_col1" class="data row2 col1" >161.00</td>
#       <td id="T_ff6aa_row2_col2" class="data row2 col2" >3,549</td>
#       <td id="T_ff6aa_row2_col3" class="data row2 col3" >3.50</td>
#       <td id="T_ff6aa_row2_col4" class="data row2 col4" >2.22</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row3" class="row_heading level0 row3" >100</th>
#       <td id="T_ff6aa_row3_col0" class="data row3 col0" >KBANK</td>
#       <td id="T_ff6aa_row3_col1" class="data row3 col1" >155.00</td>
#       <td id="T_ff6aa_row3_col2" class="data row3 col2" >3,066</td>
#       <td id="T_ff6aa_row3_col3" class="data row3 col3" >1.50</td>
#       <td id="T_ff6aa_row3_col4" class="data row3 col4" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row4" class="row_heading level0 row4" >58</th>
#       <td id="T_ff6aa_row4_col0" class="data row4 col0" >DELTA</td>
#       <td id="T_ff6aa_row4_col1" class="data row4 col1" >580.00</td>
#       <td id="T_ff6aa_row4_col2" class="data row4 col2" >1,890</td>
#       <td id="T_ff6aa_row4_col3" class="data row4 col3" >26.00</td>
#       <td id="T_ff6aa_row4_col4" class="data row4 col4" >4.69</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row5" class="row_heading level0 row5" >147</th>
#       <td id="T_ff6aa_row5_col0" class="data row5 col0" >PTT</td>
#       <td id="T_ff6aa_row5_col1" class="data row5 col1" >37.50</td>
#       <td id="T_ff6aa_row5_col2" class="data row5 col2" >1,779</td>
#       <td id="T_ff6aa_row5_col3" class="data row5 col3" >0.75</td>
#       <td id="T_ff6aa_row5_col4" class="data row5 col4" >2.04</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row6" class="row_heading level0 row6" >1</th>
#       <td id="T_ff6aa_row6_col0" class="data row6 col0" >ADVANC</td>
#       <td id="T_ff6aa_row6_col1" class="data row6 col1" >193.50</td>
#       <td id="T_ff6aa_row6_col2" class="data row6 col2" >1,709</td>
#       <td id="T_ff6aa_row6_col3" class="data row6 col3" >-0.50</td>
#       <td id="T_ff6aa_row6_col4" class="data row6 col4" >-0.26</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row7" class="row_heading level0 row7" >162</th>
#       <td id="T_ff6aa_row7_col0" class="data row7 col0" >SCB</td>
#       <td id="T_ff6aa_row7_col1" class="data row7 col1" >104.50</td>
#       <td id="T_ff6aa_row7_col2" class="data row7 col2" >1,600</td>
#       <td id="T_ff6aa_row7_col3" class="data row7 col3" >1.00</td>
#       <td id="T_ff6aa_row7_col4" class="data row7 col4" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row8" class="row_heading level0 row8" >21</th>
#       <td id="T_ff6aa_row8_col0" class="data row8 col0" >BBL</td>
#       <td id="T_ff6aa_row8_col1" class="data row8 col1" >136.50</td>
#       <td id="T_ff6aa_row8_col2" class="data row8 col2" >1,494</td>
#       <td id="T_ff6aa_row8_col3" class="data row8 col3" >1.50</td>
#       <td id="T_ff6aa_row8_col4" class="data row8 col4" >1.11</td>
#     </tr>
#     <tr>
#       <th id="T_ff6aa_level0_row9" class="row_heading level0 row9" >26</th>
#       <td id="T_ff6aa_row9_col0" class="data row9 col0" >BDMS</td>
#       <td id="T_ff6aa_row9_col1" class="data row9 col1" >28.25</td>
#       <td id="T_ff6aa_row9_col2" class="data row9 col2" >1,385</td>
#       <td id="T_ff6aa_row9_col3" class="data row9 col3" >1.00</td>
#       <td id="T_ff6aa_row9_col4" class="data row9 col4" >3.67</td>
#     </tr>
#   </tbody>
# </table>
