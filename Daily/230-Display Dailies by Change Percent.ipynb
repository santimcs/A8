# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

format_dict = {
    'daily_volume':'{:,}', 'price':'{:.2f}', 'chg_amt':'{:.2f}', 'chg_pct':'{:.2f}'
}

today = date.today()
today
# Out:
# datetime.date(2022, 12, 16)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])
df_dailies.query("daily_volume == '-'")
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.query("name == 'DELTA'")
# Out:
#      name  price  daily_volume  chg_amt  chg_pct
# 57  DELTA  686.0          2438    -26.0    -3.65

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10)
# Out:
#        name  price  daily_volume  chg_amt  chg_pct
# 170    SIRI   1.83           864     0.08     4.57
# 153     RCL  30.00           191     1.25     4.35
# 158   SABUY  10.40           142     0.40     4.00
# 206     TOA  34.00            90     1.25     3.82
# 144     PSL  15.60           274     0.50     3.31
# 17       BA  13.00            50     0.40     3.17
# 65   EGATIF   6.75            26     0.20     3.05
# 215     TTA   8.45           131     0.25     3.05
# 162      SC   4.22           124     0.12     2.93
# 73     GFPT  13.00            24     0.30     2.36

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10)
# Out:
#        name   price  daily_volume  chg_amt  chg_pct
# 184   STARK    2.48          1462    -0.26    -9.49
# 69    FORTH   30.25           119    -1.75    -5.47
# 40   BTSGIF    3.76           237    -0.16    -4.08
# 13      ASK   35.75            84    -1.50    -4.03
# 71   FSMART   12.40            64    -0.50    -3.88
# 57    DELTA  686.00          2438   -26.00    -3.65
# 169  SINGER   27.50           405    -1.00    -3.51
# 27      BE8   62.00           236    -1.75    -2.75
# 202     TKN   11.00            92    -0.30    -2.65
# 198    TIPH   47.50           222    -1.25    -2.56

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10)
# Out:
#       name   price  daily_volume  chg_amt  chg_pct
# 57   DELTA  686.00          2438   -26.00    -3.65
# 147    PTT   31.25          2390    -0.25    -0.79
# 49     CPF   24.40          2300     0.50     2.09
# 148  PTTEP  172.50          2269    -0.50    -0.29
# 10     AOT   73.50          1812     0.25     0.34
# 133     OR   23.50          1795    -0.60    -2.49
# 16     AWC    6.15          1483     0.00     0.00
# 184  STARK    2.48          1462    -0.26    -9.49
# 48   CPALL   66.00          1445     0.75     1.15
# 30     BEM    9.65          1422     0.05     0.52
