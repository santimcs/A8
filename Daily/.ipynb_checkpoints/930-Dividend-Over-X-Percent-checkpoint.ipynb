# %% [markdown]
# ### Restart and run all cells

# %% [markdown]
# ### stock: dividend, price

# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

format_dict = {
               'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
               'price_x':'{:,.2f}','to_price':'{:,.2f}',
               'current':'{:,.2f}','div_amt':'{:,.2f}','amount':'{:,.2f}','yield':'{:,.2f}',
               'Q4':'{:,.2f}','Q3':'{:,.2f}','Q2':'{:,.2f}','Q1':'{:,.2f}','DIVIDEND':'{:,.2f}',
               'qty':'{:,}','shares':'{:,}','qty_z':'{:,}'
              }
pd.set_option("display.max_rows", None)

today = date.today()
today
# Out:
# datetime.date(2021, 12, 27)

# %%
sql = '''
SELECT *
FROM dividend
ORDER BY name'''
df_dividend = pd.read_sql(sql, const)
df_dividend.shape
# Out:
# (83, 13)

# %%
sql = '''
SELECT D.name, P.name
FROM dividend D
LEFT JOIN price P
ON D.name = P.name
AND P.date = "%s"
WHERE P.name IS NULL
'''
sql = sql % today
df_left = pd.read_sql(sql, const)
df_left
# Out:
#      name  name
# 0      AI  None
# 1   MBKET  None
# 2      PT  None
# 3   TEAMG  None
# 4     TIP  None
# 5  TPRIME  None

# %% [markdown]
# ### If above statement consists stock names, must delete from dividend as there are no price records

# %%
name = 'AI'

# %%
sql = '''
SELECT *
FROM dividend
WHERE name = "%s"'''
sql = sql % name
df_dividend = pd.read_sql(sql, const)
df_dividend
# Out:
#   NAME    Q4   Q3   Q2   Q1  DIVIDEND  PRICE  PERCENT  SHARES       XDATE  \
# 0   AI  0.15  0.0  0.0  0.0      0.15    0.0      0.0     0.0  2021-03-04
#
#      PAIDDATE KIND  ACTUAL
# 0  2021-04-22            0

# %%
sql = '''
SELECT *
FROM price
WHERE name = "%s"
ORDER BY date DESC'''
sql = sql % name
df_price = pd.read_sql(sql, const)
df_price.head()
# Out:
# Empty DataFrame
# Columns: [name, date, price, maxp, minp, qty, opnp]
# Index: []

# %%
sqlDel = '''
DELETE FROM dividend
WHERE name = "%s"'''
sqlDel = sqlDel % name
rp = const.execute(sqlDel)
rp.rowcount
# Out:
# 1

# %%
old_name ='MBKET'
new_name ='MST'

# %% [markdown]
# ### End of Loop

# %%
sql = '''
SELECT D.name, Q4, Q3, Q2, Q1, DIVIDEND, shares, DIVIDEND * shares AS div_amt,
P.price AS current, shares*P.price AS amount,
FORMAT(DIVIDEND/P.price*100,2) AS yield, XDATE, PAIDDATE, ACTUAL
FROM dividend D
JOIN price P
WHERE D.name = P.name
AND P.date = "%s"'''
sql = sql % today
print(sql)
# Out:
# SELECT D.name, Q4, Q3, Q2, Q1, DIVIDEND, shares, DIVIDEND * shares AS div_amt,
# P.price AS current, shares*P.price AS amount,
# FORMAT(DIVIDEND/P.price*100,2) AS yield, XDATE, PAIDDATE, ACTUAL
# FROM dividend D
# JOIN price P
# WHERE D.name = P.name
# AND P.date = "2021-12-23"

# %%
div_price = pd.read_sql(sql, const)
div_price['yield'] = div_price['yield'].astype(float)
div_price['shares'] = div_price['shares'].astype(int)
div_price.shape
# Out:
# (77, 14)

# %%
div_price.nlargest(3, 'div_amt')[['name','div_amt']]
# Out:
#      name   div_amt
# 35    STA  105000.0
# 2     MCS   95900.0
# 48  JASIF   95000.0

# %%
y_ovr_8 = div_price['yield'] >= 7.00
div_price[y_ovr_8].sort_values(['yield'],ascending=[False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9938f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >Q4</th>
#       <th class="col_heading level0 col2" >Q3</th>
#       <th class="col_heading level0 col3" >Q2</th>
#       <th class="col_heading level0 col4" >Q1</th>
#       <th class="col_heading level0 col5" >DIVIDEND</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >div_amt</th>
#       <th class="col_heading level0 col8" >current</th>
#       <th class="col_heading level0 col9" >amount</th>
#       <th class="col_heading level0 col10" >yield</th>
#       <th class="col_heading level0 col11" >XDATE</th>
#       <th class="col_heading level0 col12" >PAIDDATE</th>
#       <th class="col_heading level0 col13" >ACTUAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9938f_level0_row0" class="row_heading level0 row0" >35</th>
#       <td id="T_9938f_row0_col0" class="data row0 col0" >STA</td>
#       <td id="T_9938f_row0_col1" class="data row0 col1" >1.75</td>
#       <td id="T_9938f_row0_col2" class="data row0 col2" >1.25</td>
#       <td id="T_9938f_row0_col3" class="data row0 col3" >1.25</td>
#       <td id="T_9938f_row0_col4" class="data row0 col4" >1.00</td>
#       <td id="T_9938f_row0_col5" class="data row0 col5" >5.25</td>
#       <td id="T_9938f_row0_col6" class="data row0 col6" >20,000</td>
#       <td id="T_9938f_row0_col7" class="data row0 col7" >105,000.00</td>
#       <td id="T_9938f_row0_col8" class="data row0 col8" >30.50</td>
#       <td id="T_9938f_row0_col9" class="data row0 col9" >610,000.00</td>
#       <td id="T_9938f_row0_col10" class="data row0 col10" >17.21</td>
#       <td id="T_9938f_row0_col11" class="data row0 col11" >2021-11-19</td>
#       <td id="T_9938f_row0_col12" class="data row0 col12" >2021-12-08</td>
#       <td id="T_9938f_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9938f_level0_row1" class="row_heading level0 row1" >33</th>
#       <td id="T_9938f_row1_col0" class="data row1 col0" >STGT</td>
#       <td id="T_9938f_row1_col1" class="data row1 col1" >2.00</td>
#       <td id="T_9938f_row1_col2" class="data row1 col2" >1.25</td>
#       <td id="T_9938f_row1_col3" class="data row1 col3" >1.25</td>
#       <td id="T_9938f_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_9938f_row1_col5" class="data row1 col5" >4.50</td>
#       <td id="T_9938f_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_9938f_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_9938f_row1_col8" class="data row1 col8" >29.75</td>
#       <td id="T_9938f_row1_col9" class="data row1 col9" >0.00</td>
#       <td id="T_9938f_row1_col10" class="data row1 col10" >15.13</td>
#       <td id="T_9938f_row1_col11" class="data row1 col11" >2021-11-19</td>
#       <td id="T_9938f_row1_col12" class="data row1 col12" >2021-12-07</td>
#       <td id="T_9938f_row1_col13" class="data row1 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9938f_level0_row2" class="row_heading level0 row2" >46</th>
#       <td id="T_9938f_row2_col0" class="data row2 col0" >NOBLE</td>
#       <td id="T_9938f_row2_col1" class="data row2 col1" >0.50</td>
#       <td id="T_9938f_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_9938f_row2_col3" class="data row2 col3" >0.35</td>
#       <td id="T_9938f_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_9938f_row2_col5" class="data row2 col5" >0.85</td>
#       <td id="T_9938f_row2_col6" class="data row2 col6" >63,000</td>
#       <td id="T_9938f_row2_col7" class="data row2 col7" >53,550.00</td>
#       <td id="T_9938f_row2_col8" class="data row2 col8" >6.10</td>
#       <td id="T_9938f_row2_col9" class="data row2 col9" >384,300.00</td>
#       <td id="T_9938f_row2_col10" class="data row2 col10" >13.93</td>
#       <td id="T_9938f_row2_col11" class="data row2 col11" >2021-08-24</td>
#       <td id="T_9938f_row2_col12" class="data row2 col12" >2021-09-07</td>
#       <td id="T_9938f_row2_col13" class="data row2 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9938f_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_9938f_row3_col0" class="data row3 col0" >TMT</td>
#       <td id="T_9938f_row3_col1" class="data row3 col1" >0.50</td>
#       <td id="T_9938f_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_9938f_row3_col3" class="data row3 col3" >0.60</td>
#       <td id="T_9938f_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_9938f_row3_col5" class="data row3 col5" >1.10</td>
#       <td id="T_9938f_row3_col6" class="data row3 col6" >27,000</td>
#       <td id="T_9938f_row3_col7" class="data row3 col7" >29,700.00</td>
#       <td id="T_9938f_row3_col8" class="data row3 col8" >10.40</td>
#       <td id="T_9938f_row3_col9" class="data row3 col9" >280,800.00</td>
#       <td id="T_9938f_row3_col10" class="data row3 col10" >10.58</td>
#       <td id="T_9938f_row3_col11" class="data row3 col11" >2021-08-27</td>
#       <td id="T_9938f_row3_col12" class="data row3 col12" >2021-09-10</td>
#       <td id="T_9938f_row3_col13" class="data row3 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9938f_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_9938f_row4_col0" class="data row4 col0" >MCS</td>
#       <td id="T_9938f_row4_col1" class="data row4 col1" >0.60</td>
#       <td id="T_9938f_row4_col2" class="data row4 col2" >0.37</td>
#       <td id="T_9938f_row4_col3" class="data row4 col3" >0.40</td>
#       <td id="T_9938f_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_9938f_row4_col5" class="data row4 col5" >1.37</td>
#       <td id="T_9938f_row4_col6" class="data row4 col6" >70,000</td>
#       <td id="T_9938f_row4_col7" class="data row4 col7" >95,900.00</td>
#       <td id="T_9938f_row4_col8" class="data row4 col8" >14.60</td>
#       <td id="T_9938f_row4_col9" class="data row4 col9" >1,022,000.00</td>
#       <td id="T_9938f_row4_col10" class="data row4 col10" >9.38</td>
#       <td id="T_9938f_row4_col11" class="data row4 col11" >2021-11-25</td>
#       <td id="T_9938f_row4_col12" class="data row4 col12" >2021-12-09</td>
#       <td id="T_9938f_row4_col13" class="data row4 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9938f_level0_row5" class="row_heading level0 row5" >48</th>
#       <td id="T_9938f_row5_col0" class="data row5 col0" >JASIF</td>
#       <td id="T_9938f_row5_col1" class="data row5 col1" >0.25</td>
#       <td id="T_9938f_row5_col2" class="data row5 col2" >0.22</td>
#       <td id="T_9938f_row5_col3" class="data row5 col3" >0.24</td>
#       <td id="T_9938f_row5_col4" class="data row5 col4" >0.24</td>
#       <td id="T_9938f_row5_col5" class="data row5 col5" >0.95</td>
#       <td id="T_9938f_row5_col6" class="data row5 col6" >100,000</td>
#       <td id="T_9938f_row5_col7" class="data row5 col7" >95,000.00</td>
#       <td id="T_9938f_row5_col8" class="data row5 col8" >10.30</td>
#       <td id="T_9938f_row5_col9" class="data row5 col9" >1,030,000.00</td>
#       <td id="T_9938f_row5_col10" class="data row5 col10" >9.22</td>
#       <td id="T_9938f_row5_col11" class="data row5 col11" >2021-11-19</td>
#       <td id="T_9938f_row5_col12" class="data row5 col12" >2021-12-08</td>
#       <td id="T_9938f_row5_col13" class="data row5 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9938f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9938f_row6_col0" class="data row6 col0" >PDG</td>
#       <td id="T_9938f_row6_col1" class="data row6 col1" >0.22</td>
#       <td id="T_9938f_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_9938f_row6_col3" class="data row6 col3" >0.10</td>
#       <td id="T_9938f_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_9938f_row6_col5" class="data row6 col5" >0.32</td>
#       <td id="T_9938f_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_9938f_row6_col7" class="data row6 col7" >0.00</td>
#       <td id="T_9938f_row6_col8" class="data row6 col8" >3.96</td>
#       <td id="T_9938f_row6_col9"

# %%
not_due = div_price['ACTUAL'] == 1
div_price[not_due].sort_values(['yield'],ascending=[False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_327e9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >Q4</th>
#       <th class="col_heading level0 col2" >Q3</th>
#       <th class="col_heading level0 col3" >Q2</th>
#       <th class="col_heading level0 col4" >Q1</th>
#       <th class="col_heading level0 col5" >DIVIDEND</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >div_amt</th>
#       <th class="col_heading level0 col8" >current</th>
#       <th class="col_heading level0 col9" >amount</th>
#       <th class="col_heading level0 col10" >yield</th>
#       <th class="col_heading level0 col11" >XDATE</th>
#       <th class="col_heading level0 col12" >PAIDDATE</th>
#       <th class="col_heading level0 col13" >ACTUAL</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
div_price[y_ovr_8 & not_due].sort_values(['XDATE','name'],ascending=[True,True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3eeda_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >Q4</th>
#       <th class="col_heading level0 col2" >Q3</th>
#       <th class="col_heading level0 col3" >Q2</th>
#       <th class="col_heading level0 col4" >Q1</th>
#       <th class="col_heading level0 col5" >DIVIDEND</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >div_amt</th>
#       <th class="col_heading level0 col8" >current</th>
#       <th class="col_heading level0 col9" >amount</th>
#       <th class="col_heading level0 col10" >yield</th>
#       <th class="col_heading level0 col11" >XDATE</th>
#       <th class="col_heading level0 col12" >PAIDDATE</th>
#       <th class="col_heading level0 col13" >ACTUAL</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
in_port = div_price['shares'] > 0
div_price[in_port].sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_15019_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >Q4</th>
#       <th class="col_heading level0 col2" >Q3</th>
#       <th class="col_heading level0 col3" >Q2</th>
#       <th class="col_heading level0 col4" >Q1</th>
#       <th class="col_heading level0 col5" >DIVIDEND</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >div_amt</th>
#       <th class="col_heading level0 col8" >current</th>
#       <th class="col_heading level0 col9" >amount</th>
#       <th class="col_heading level0 col10" >yield</th>
#       <th class="col_heading level0 col11" >XDATE</th>
#       <th class="col_heading level0 col12" >PAIDDATE</th>
#       <th class="col_heading level0 col13" >ACTUAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15019_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_15019_row0_col0" class="data row0 col0" >ASIAN</td>
#       <td id="T_15019_row0_col1" class="data row0 col1" >0.55</td>
#       <td id="T_15019_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T
]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_897d1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >Q4</th>
#       <th class="col_heading level0 col2" >Q3</th>
#       <th class="col_heading level0 col3" >Q2</th>
#       <th class="col_heading level0 col4" >Q1</th>
#       <th class="col_heading level0 col5" >DIVIDEND</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >div_amt</th>
#       <th class="col_heading level0 col8" >current</th>
#       <th class="col_heading level0 col9" >amount</th>
#       <th class="col_heading level0 col10" >yield</th>
#       <th class="col_heading level0 col11" >XDATE</th>
#       <th class="col_heading level0 col12" >PAIDDATE</th>
#       <th class="col_heading level0 col13" >ACTUAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_897d1_level0_row0" class="row_heading level0 row0" >35</th>
#       <td id="T_897d1_row0_col0" class="data row0 col0" >STA</td>
#       <td id="T_897d1_row0_col1" class="data row0 col1" >1.75</td>
#       <td id="T_897d1_row0_col2" class="data row0 col2" >1.25</td>
#       <td id="T_897d1_row0_col3" class="data row0 col3" >1.25</td>
#       <td id="T_897d1_row0_col4" class="data row0 col4" >1.00</td>
#       <td id="T_897d1_row0_col5" class="data row0 col5" >5.25</td>
#       <td id="T_897d1_row0_col6" class="data row0 col6" >20,000</td>
#       <td id="T_897d1_row0_col7" class="data row0 col7" >105,000.00</td>
#       <td id="T_897d1_row0_col8" class="data row0 col8" >30.50</td>
#       <td id="T_897d1_row0_col9" class="data row0 col9" >610,000.00</td>
#       <td id="T_897d1_row0_col10" class="data row0 col10" >17.21</td>
#       <td id="T_897d1_row0_col11" class="data row0 col11" >2021-11-19</td>
#       <td id="T_897d1_row0_col12" class="data row0 col12" >2021-12-08</td>
#       <td id="T_897d1_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_897d1_level0_row1" class="row_heading level0 row1" >46</th>
#       <td id="T_897d1_row1_col0" class="data row1 col0" >NOBLE</td>
#       <td id="T_897d1_row1_col1" class="data row1 col1" >0.50</td>
#       <td id="T_897d1_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_897d1_row1_col3" class="data row1 col3" >0.35</td>
#       <td id="T_897d1_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_897d1_row1_col5" class="data row1 col5" >0.85</td>
#       <td id="T_897d1_row1_col6" class="data row1 col6" >63,000</td>
#       <td id="T_897d1_row1_col7" class="data row1 col7" >53,550.00</td>
#       <td id="T_897d1_row1_col8" class="data row1 col8" >6.10</td>
#       <td id="T_897d1_row1_col9" class="data row1 col9" >384,300.00</td>
#       <td id="T_897d1_row1_col10" class="data row1 col10" >13.93</td>
#       <td id="T_897d1_row1_col11" class="data row1 col11" >2021-08-24</td>
#       <td id="T_897d1_row1_col12" class="data row1 col12" >2021-09-07</td>
#       <td id="T_897d1_row1_col13" class="data row1 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_897d1_level0_row2" class="row_heading level0 row2" >24</th>
#       <td id="T_897d1_row2_col0" class="data row2 col0" >TMT</td>
#       <td id="T_897d1_row2_col1" class="data row2 col1" >0.50</td>
#       <td id="T_897d1_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_897d1_row2_col3" class="data row2 col3" >0.60</td>
#       <td id="T_897d1_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T
#       <td id="T_897d1_row5_col6" class="data row5 col6" >30,000</td>
#       <td id="T_897d1_row5_col7" class="data row5 col7" >20,796.00</td>
#       <td id="T_897d1_row5_col8" class="data row5 col8" >8.90</td>
#       <td id="T_897d1_row5_col9" class="data row5 col9" >267,000.00</td>
#       <td id="T_897d1_row5_col10" class="data row5 col10" >7.79</td>
#       <td id="T_897d1_row5_col11" class="data row5 col11" >2021-11-23</td>
#       <td id="T_897d1_row5_col12" class="data row5 col12" >2021-12-23</td>
#       <td id="T_897d1_row5_col13" class="data row5 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_897d1_level0_row6" class="row_heading level0 row6" >30</th>
#       <td id="T_897d1_row6_col0" class="data row6 col0" >DIF</td>
#       <td id="T_897d1_row6_col1" class="data row6 col1" >0.26</td>
#       <td id="T_897d1_row6_col2" class="data row6 col2" >0.26</td>
#       <td id="T_897d1_row6_col3" class="data row6 col3" >0.26</td>
#       <td id="T_897d1_row6_col4" class="data row6 col4" >0.26</td>
#       <td id="T_897d1_row6_col5" class="data row6 col5" >1.04</td>
#       <td id="T_897d1_row6_col6" class="data row6 col6" >60,000</td>
#       <td id="T_897d1_row6_col7" class="data row6 col7" >62,640.00</td>
#       <td id="T_897d1_row6_col8" class="data row6 col8" >13.90</td>

# %%
dividend = div_price[y_ovr_8 & in_port].div_amt.sum()
cost = div_price[y_ovr_8 & in_port].amount.sum()
yld = round(dividend / cost * 100,2)
(dividend, cost, yld)
# Out:
# (497836.0, 4912600.0, 10.13)

# %%
file_name = 'DIV-OVR-8%.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
data_file, output_file, box_file
# Out:
# ('../data/DIV-OVR-8%.csv',
#  '\\Users\\User\\iCloudDrive\\DIV-OVR-8%.csv',
#  '\\Users\\User\\Dropbox\\DIV-OVR-8%.csv')

# %%
div_price[y_ovr_8 & in_port].sort_values(['yield','name'],ascending=[False,True]).to_csv(data_file)
div_price[y_ovr_8 & in_port].sort_values(['yield','name'],ascending=[False,True]).to_csv(output_file)
div_price[y_ovr_8 & in_port].sort_values(['yield','name'],ascending=[False,True]).to_csv(box_file)

# %%
div_price[~y_ovr_8 & in_port].sort_values(['yield','name'],ascending=[False,True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e284c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >Q4</th>
#       <th class="col_heading level0 col2" >Q3</th>
#       <th class="col_heading level0 col3" >Q2</th>
#       <th class="col_heading level0 col4" >Q1</th>
#       <th class="col_heading level0 col5" >DIVIDEND</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >div_amt</th>
#       <th class="col_heading level0 col8" >current</th>
#       <th class="col_heading level0 col9" >amount</th>
#       <th class="col_heading level0 col10" >yield</th>
#       <th class="col_heading level0 col11" >XDATE</th>
#       <th class="col_heading level0 col12" >PAIDDATE</th>
#       <th class="col_heading level0 col13" >ACTUAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e284c_level0_row0" class="row_heading level0 row0" >68</th>
#       <td id="T_e284c_row0_col0" class="data row0 col0" >TISCO</td>
#       <td id="T_e284c_row0_col1" class="data row0 col1" >6.30</td>
#       <td id="T_e284c_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_e284c_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_e284c_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T
>0</td>
#     </tr>
#     <tr>
#       <th id="T_e284c_level0_row4" class="row_heading level0 row4" >51</th>
#       <td id="T_e284c_row4_col0" class="data row4 col0" >PTTGC</td>
#       <td id="T_e284c_row4_col1" class="data row4 col1" >1.00</td>
#       <td id="T_e284c_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_e284c_row4_col3" class="data row4 col3" >2.00</td>
#       <td id="T_e284c_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_e284c_row4_col5" class="data row4 col5" >3.00</td>
#       <td id="T_e284c_row4_col6" class="data row4 col6" >6,000</td>
#       <td id="T_e284c_row4_col7" class="data row4 col7" >18,000.00</td>
#       <td id="T_e284c_row4_col8" class="data row4 col8" >58.25</td>
#       <td id="T_e284c_row4_col9" class="data row4 col9" >349,500.00</td>
#       <td id="T_e284c_row4_col10" class="data row4 col10" >5.15</td>
#       <td id="T_e284c_row4_col11" class="data row4 col11" >2021-09-03</td>
#       <td id="T_e284c_row4_col12" class="data row4 col12" >2021-09-22</td>
#       <td id="T_e284c_row4_col13" class="data row4 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e284c_level0_row5" class="row_heading level0 row5" >75</th>
#       <td id="T_e284c_row5_col0" class="data row5 col0" >RJH</td>
#       <td id="T_e284c_row5_col1" class="data row5 col1" >0.20</td>
#       <td id="T_e284c_row5_col2" class="data row5 col2" >1.10</td>
#       <td id="T_e284c_row5_col3" class="data row5 col3" >0.40</td>
#       <td id="T_e284c_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_e284c_row5_col5" class="data row5 col5" >1.70</td>
#       <td id="T_e284c_row5_col6" class="data row5 col6" >4,500</td>
#       <td id="T_e284c_row5_col7" class="data row5 col7" >7,650.00</td>
#       <td id="T_e284c_row5_col8" class="data row5 col8" >33.00</td>
#       <td id="T_e284c_row5_col9" class="data row5 col9" >148,500.00</td>
#       <td id="T_e284c_row5_col10" class="data row5 col10" >5.15</td>
#       <td id="T_e284c_row5_col11" class="data row5 col11" >2021-11-22</td>
#       <td id="T_e284c_row5_col12" class="data row5 col12" >2021-12-07</td>
#       <td id="T_e284c_row5_col13" class="data row5 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e284c_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_e284c_row6_col0" class="data row6 col0" >SCC</td>
#       <td id="T_e284c_row6_col1" class="data row6 col1" >8.50</td>
#       <td id="T_e284c_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_e284c_row6_col3" class="data row6 col3" >8.50</td>
#       <td id="T_e284c_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_e284c_row6_col5" class="data row6 col5" >17.00</td>
#       <td id="T_e284c_row6_col6" class="data row6 col6" >600</td>
#       <td id="T_e284c_row6_col7" class="data row6 col7" >10,200.00</td>
#       <td id="T_e284c_row6_col8" class="data row6 col8" >380.00</td>
#       <td id="T_e284c_row6_

# %%
dividend = div_price[~y_ovr_8 & in_port].div_amt.sum()
cost = div_price[~y_ovr_8 & in_port].amount.sum()
yld = round(dividend / cost * 100,2)
(dividend, cost, yld)
# Out:
# (162042.5, 5373225.0, 3.02)
