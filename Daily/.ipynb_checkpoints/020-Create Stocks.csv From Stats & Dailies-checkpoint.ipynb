# %% [markdown]
# #### SQLite port_lite database: sales, stocks table
# #### csv files: daily-watch-list, daily-sales, monitors, stocks-all

# %%
import numpy as np
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

today = date.today()
yesterday = today - timedelta(days=1)
yesterday
# Out:
# datetime.date(2022, 5, 14)

# %% [markdown]
# ### Yesterday = Last business day

# %%
yesterday = date(2022, 5, 13)
yesterday
# Out:
# datetime.date(2022, 5, 13)

# %% [markdown]
# ### Restart and Run All Cells

# %%
cols = 'fm_date to_date fm_price to_price qty max_price min_price percent status'.split()

# %%
format_dict = {
    'fm_price':'{:.2f}','to_price':'{:.2f}','diff':'{:.2f}',
    'max_price':'{:.2f}','min_price':'{:.2f}',
    'volume':'{:,.2f}','beta':'{:,.2f}',
    'pct':'{:,.2f}%','percent':'{:,.2f}%',   
    'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',
    
    'qty':'{:,}','available_qty':'{:,}',
    'cost':'{:.2f}','buy_target':'{:.2f}','sell_target':'{:.2f}',
}

# %% [markdown]
# ### Begin of Tables in the process

# %%
sql = """
SELECT * 
FROM sales 
ORDER BY id DESC LIMIT 1
"""
tmp = pd.read_sql(sql, conlite)
tmp["fm_date"] = pd.to_datetime(tmp["fm_date"])
tmp["to_date"] = pd.to_datetime(tmp["to_date"])
tmp["created_at"] = pd.to_datetime(tmp["created_at"])
tmp["updated_at"] = pd.to_datetime(tmp["updated_at"])
tmp.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_64b5b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >fm_date</th>
#       <th class="col_heading level0 col3" >to_date</th>
#       <th class="col_heading level0 col4" >days</th>
#       <th class="col_heading level0 col5" >fm_price</th>
#       <th class="col_heading level0 col6" >to_price</th>
#       <th class="col_heading level0 col7" >diff</th>
#       <th class="col_heading level0 col8" >pct</th>
#       <th class="col_heading level0 col9" >ttl_spread</th>
#       <th class="col_heading level0 col10" >avg_spread</th>
#       <th class="col_heading level0 col11" >max_price</th>
#       <th class="col_heading level0 col12" >min_price</th>
#       <th class="col_heading level0 col13" >qty</th>
#       <th class="col_heading level0 col14" >created_at</th>
#       <th class="col_heading level0 col15" >updated_at</th>
#       <th class="col_heading level0 col16" >latest_date_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64b5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64b5b_row0_col0" class="data row0 col0" >1129011</td>
#       <td id="T_64b5b_row0_col1" class="data row0 col1" >WHART</td>
#       <td id="T_64b5b_row0_col2" class="data row0 col2" >2022-05-12</td>
#       <td id="T_64b5b_row0_col3" class="data row0 col3" >2022-05-13</td>
#       <td id="T_64b5b_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_64b5b_row0_col5" class="data row0 col5" >10.50</td>
#       <td id="T_64b5b_row0_col6" class="data row0 col6" >10.60</td>
#       <td id="T_64b5b_row0_col7" class="data row0 col7" >0.10</td>
#       <td id="T_64b5b_row0_col8" class="data row0 col8" >0.95%</td>
#       <td id="T_64b5b_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_64b5b_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_64b5b_row0_col11" class="data row0 col11" >10.70</td>
#       <td id="T_64b5b_row0_col12" class="data row0 col12" >10.50</td>
#       <td id="T_64b5b_row0_col13" class="data row0 col13" >347,367</td>
#       <td id="T_64b5b_row0_col14" class="data row0 col14" >2022-05-15</td>
#       <td id="T_64b5b_row0_col15" class="data row0 col15" >2022-05-15</td>
#       <td id="T_64b5b_row0_col16" class="data row0 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = tmp["name"]
name = names.to_string(index=False)
sql = """
SELECT * 
FROM stocks
WHERE name = '%s'
"""
sql = sql % name
print(sql)
tmp = pd.read_sql(sql, conlite)
tmp.style.format(format_dict)
# Out:
# SELECT *
# FROM stocks
# WHERE name = 'WHART'
# <style type="text/css">
# </style>
# <table id="T_6f59e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >max_price</th>
#       <th class="col_heading level0 col3" >min_price</th>
#       <th class="col_heading level0 col4" >status</th>
#       <th class="col_heading level0 col5" >buy_target</th>
#       <th class="col_heading level0 col6" >sell_target</th>
#       <th class="col_heading level0 col7" >volume</th>
#       <th class="col_heading level0 col8" >beta</th>
#       <th class="col_heading level0 col9" >cost</th>
#       <th class="col_heading level0 col10" >qty</th>
#       <th class="col_heading level0 col11" >buy_spread</th>
#       <th class="col_heading level0 col12" >sell_spread</th>
#       <th class="col_heading level0 col13" >available_qty</th>
#       <th class="col_heading level0 col14" >bl</th>
#       <th class="col_heading level0 col15" >sh</th>
#       <th class="col_heading level0 col16" >reason</th>
#       <th class="col_heading level0 col17" >market</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f59e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f59e_row0_col0" class="data row0 col0" >687</td>
#       <td id="T_6f59e_row0_col1" class="data row0 col1" >WHART</td>
#       <td id="T_6f59e_row0_col2" class="data row0 col2" >14.08</td>
#       <td id="T_6f59e_row0_col3" class="data row0 col3" >10.80</td>
#       <td id="T_6f59e_row0_col4" class="data row0 col4" >B</td>
#       <td id="T_6f59e_row0_col5" class="data row0 col5" >10.50</td>
#       <td id="T_6f59e_row0_col6" class="data row0 col6" >12.40</td>
#       <td id="T_6f59e_row0_col7" class="data row0 col7" >24.74</td>
#       <td id="T_6f59e_row0_col8" class="data row0 col8" >0.21</td>
#       <td id="T_6f59e_row0_col9" class="data row0 col9" >12.30</td>
#       <td id="T_6f59e_row0_col10" class="data row0 col10" >10,000</td>
#       <td id="T_6f59e_row0_col11" class="data row0 col11" >-5</td>
#       <td id="T_6f59e_row0_col12" class="data row0 col12" >4</td>
#       <td id="T_6f59e_row0_col13" class="data row0 col13" >20,000</td>
#       <td id="T_6f59e_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_6f59e_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_6f59e_row0_col16" class="data row0 col16" >RD10pct</td>
#       <td id="T_6f59e_row0_col17" class="data row0 col17" >SET</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### End of Tables in the process

# %%
sql = """
SELECT a.name,fm_date,to_date,fm_price,to_price,
a.qty,a.max_price,a.min_price,t.status,t.market
FROM sales a 
JOIN stocks t ON a.name = t.name 
WHERE to_date >= '%s' AND t.status IN ("B","I", "O", "S") 
ORDER BY t.status, a.name
"""
sql = sql % yesterday
print(sql)
# Out:
# SELECT a.name,fm_date,to_date,fm_price,to_price,
# a.qty,a.max_price,a.min_price,t.status,t.market
# FROM sales a
# JOIN stocks t ON a.name = t.name
# WHERE to_date >= '2022-05-13' AND t.status IN ("B","I", "O", "S")
# ORDER BY t.status, a.name

# %%
df = pd.read_sql(sql, conlite)
df.set_index(["name"], inplace=True)
df['fm_date'] = pd.to_datetime(df['fm_date'])
df['to_date'] = pd.to_datetime(df['to_date'])
df['diff'] = (df['to_price'] - df['fm_price'])
df['percent'] = round(df['diff']/df['fm_price']*100,2)
df.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a09c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fm_date</th>
#       <th class="col_heading level0 col1" >to_date</th>
#       <th class="col_heading level0 col2" >fm_price</th>
#       <th class="col_heading level0 col3" >to_price</th>
#       <th class="col_heading level0 col4" >qty</th>
#       <th class="col_heading level0 col5" >max_price</th>
#       <th class="col_heading level0 col6" >min_price</th>
#       <th class="col_heading level0 col7" >status</th>
#       <th class="col_heading level0 col8" >market</th>
#       <th class="col_heading level0 col9" >diff</th>
#       <th class="col_heading level0 col10" >percent</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a09c_level0_row0" class="row_heading level0 row0" >DIF</th>
#       <td id="T_5a09c_row0_col0" class="data row0 col0" >2022-05-06</td>
#       <td id="T_5a09c_row0_col1" class="data row0 col1" >2022-05-13</td>
#       <td id="T_5a09c_row0_col2" class="data row0 col2" >14.10</td>
#       <td id="T_5a09c_row0_col3" class="data row0 col3" >14.30</td>
#       <td id="T_5a09c_row0_col4" class="data row0 col4" >72,640,747</td>
#       <td id="T_5a09c_row0_col5" class="data row0 col5" >14.30</td>
#       <td id="T_5a09c_row0_col6" class="data row0 col6" >14.10</td>
#       <td id="T_5a09c_row0_col7" class="data row0 col7" >B</td>
#       <td id="T_5a09c_row0_col8" class="data row0 col8" >SET</td>
#       <td id="T_5a09c_row0_col9" class="data row0 col9" >0.20</td>
#       <td id="T_5a09c_row0_col10" class="data row0 col10" >1.42%</td>
#     </tr>
#     <tr>
#       <th id="T_5a09c_level0_row1" class="row_heading level0 row1" >HREIT</th>
#       <td id="T_5a09c_row1_col0" class="data row1 col0" >2022-05-12</td>
#       <td id="T_5a09c_row1_col1" class="data row1 col1" >2022-05-13</td>
#       <td id="T_5a09c_row1_col2" class="data row1 col2" >8.30</td>
#       <td id="T_5a09c_row1_col3" class="data row1 col3" >8.35</td>
#       <td id="T_5a09c_row1_col4" class="data row1 col4" >126,700</td>
#       <td id="T_5a09c_row1_col5" class="data row1 col5" >8.35</td>
#       <td id="T_5a09c_row1_col6" class="data row1 col6" >8.30</td>
#       <td id="T_5a09c_row1_col7" class="data row1 col7" >B</td>
#       <td id="T_5a09c_row1_col8" class="data row1 col8" >SET</td>
#       <td id="T_5a09c_row1_col9" class="data row1 col9" >0.05</td>
#       <td id="T_5a09c_row1_col10" class="data row1 col10" >0.60%</td>
#     </tr>
#     <tr>
#       <th id="T_5a09c_level0_row2" class="row_heading level0 row2" >JASIF</th>
#       <td id="T_5a09c_row2_col0" class="data row2 col0" >2022-05-11</td>
#       <td id="T_5a09c_row2_col1" class="data row2 col1" >2022-05-13</td>
#       <td id="T_5a09c_row2_col2" class="data row2 col2" >10.90</td>
#       <td id="T_5a09c_row2_col3" class="data row2 col3" >11.00</td>
#       <td id="T_5a09c_row2_col4" class="data row2 col4" >36,287,104</td>
#       <td id="T_5a09c_row2_col5" class="data row2 col5" >11.00</td>
#       <td id="T_5a09c_row2_col6" class="data row2 col6" >10.90</td>
#       <td id="T_5a09c_row2_col7" class="data row2 col7" >B</td>
#       <td id="T_5a09c_row2_col8" class="data row2 col8" >SET</td>
#       <td id="T_5a09c_row2_col9" class="data row2 col9" >0.10</td>
#       <td id="T_5a09c_row2_col10" class="data row2 col10" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_5a09c_level0_row3" class="row_heading level0 row3" >WHART</th>
#       <td id="T_5a09c_row3_col0" class="data row3 col0" >2022-05-12</td>
#       <td id="T_5a09c_row3_col1" class="data row3 col1" >2022-05-13</td>
#       <td id="T_5a09c_row3_col2" class="data row3 col2" >10.50</td>
#       <td id="T_5a09c_row3_col3" class="data row3 col3" >10.60</td>
#       <td id="T_5a09c_row3_col4" class="data row3 col4" >347,367</td>
#       <td id="T_5a09c_row3_col5" class="data row3 col5" >10.70</td>
#       <td id="T_5a09c_row3_col6" class="data row3 col6" >10.50</td>
#       <td id="T_5a09c_row3_col7" class="data row3 col7" >B</td>
#       <td id="T_5a09c_row3_col8" class="data row3 col8" >SET</td>
#       <td id="T_5a09c_row3_col9" class="data row3 col9" >0.10</td>
#       <td id="T_5a09c_row3_col10" class="data row3 col10" >0.95%</td>
#     </tr>
#     <tr>
#       <th id="T_5a09c_level0_row4" class="row_heading level0 row4" >BCH</th>
#       <td id="T_5a09c_row4_col0" class="data row4 col0" >2022-05-12</td>
#       <td id="T_5a09c_row4_col1" class="data row4 col1" >2022-05-13</td>
#       <td id="T_5a09c_row4_col2" class="data row4 col2" >19.00</td>
#       <td id="T_5a09c_row4_col3" class="data row4 col3" >20.00</td>
#       <td id="T_5a09c_row4_col4" class="data row4 col4" >21,122,243</td>
#       <td id="T_5a09c_row4_col5" class="data row4 col5" >20.00</td>
#       <td id="T_5a09c_row4_col6" class="data row4 col6" >19.20</td>
#       <td id="T_5a09c_row4_col7" class="data row4 col7" >I</td>
#       <td id="T_5a09c_row4_col8" class="data row4 col8" >SET100</td>
#       <td id="T_5a09c_row4_col9" class="data row4 col9" >1.00</td>
#       <td id="T_5a09c_row4_col10" class="data row4 col10" >5.26%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Price change up or down more than 3%

# %%
#df['bdays'] = np.busday_count(df['fm_date'],df['to_date'])
#df['bdays'] = 1
df['bdays'] = (df['to_date'] - df['fm_date']).dt.days
watch_list = df.loc[
    abs(df.percent) >= 3,
    ['percent','status','fm_price','to_price','market','fm_date','bdays','max_price','min_price']
]
watch_list.sort_values(by="percent",ascending=False).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef3cd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >percent</th>
#       <th class="col_heading level0 col1" >status</th>
#       <th class="col_heading level0 col2" >fm_price</th>
#       <th class="col_heading level0 col3" >to_price</th>
#       <th class="col_heading level0 col4" >market</th>
#       <th class="col_heading level0 col5" >fm_date</th>
#       <th class="col_heading level0 col6" >bdays</th>
#       <th class="col_heading level0 col7" >max_price</th>
#       <th class="col_heading level0 col8" >min_price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef3cd_level0_row0" class="row_heading level0 row0" >BDMS</th>
#       <td id="T_ef3cd_row0_col0" class="data row0 col0" >8.00%</td>
#       <td id="T_ef3cd_row0_col1" class="data row0 col1" >O</td>
#       <td id="T_ef3cd_row0_col2" class="data row0 col2" >25.00</td>
#       <td id="T_ef3cd_row0_col3" class="data row0 col3" >27.00</td>
#       <td id="T_ef3cd_row0_col4" class="data row0 col4" >SET50</td>
#       <td id="T_ef3cd_row0_col5" class="data row0 col5" >2022-05-11</td>
#       <td id="T_ef3cd_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_ef3cd_row0_col7" class="data row0 col7" >27.50</td>
#       <td id="T_ef3cd_row0_col8" class="data row0 col8" >25.00</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row1" class="row_heading level0 row1" >IVL</th>
#       <td id="T_ef3cd_row1_col0" class="data row1 col0" >6.29%</td>
#       <td id="T_ef3cd_row1_col1" class="data row1 col1" >O</td>
#       <td id="T_ef3cd_row1_col2" class="data row1 col2" >43.75</td>
#       <td id="T_ef3cd_row1_col3" class="data row1 col3" >46.50</td>
#       <td id="T_ef3cd_row1_col4" class="data row1 col4" >SET50</td>
#       <td id="T_ef3cd_row1_col5" class="data row1 col5" >2022-05-09</td>
#       <td id="T_ef3cd_row1_col6" class="data row1 col6" >4</td>
#       <td id="T_ef3cd_row1_col7" class="data row1 col7" >46.75</td>
#       <td id="T_ef3cd_row1_col8" class="data row1 col8" >42.75</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row2" class="row_heading level0 row2" >BCH</th>
#       <td id="T_ef3cd_row2_col0" class="data row2 col0" >5.26%</td>
#       <td id="T_ef3cd_row2_col1" class="data row2 col1" >I</td>
#       <td id="T_ef3cd_row2_col2" class="data row2 col2" >19.00</td>
#       <td id="T_ef3cd_row2_col3" class="data row2 col3" >20.00</td>
#       <td id="T_ef3cd_row2_col4" class="data row2 col4" >SET100</td>
#       <td id="T_ef3cd_row2_col5" class="data row2 col5" >2022-05-12</td>
#       <td id="T_ef3cd_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_ef3cd_row2_col7" class="data row2 col7" >20.00</td>
#       <td id="T_ef3cd_row2_col8" class="data row2 col8" >19.20</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row3" class="row_heading level0 row3" >BBL</th>
#       <td id="T_ef3cd_row3_col0" class="data row3 col0" >-3.10%</td>
#       <td id="T_ef3cd_row3_col1" class="data row3 col1" >O</td>
#       <td id="T_ef3cd_row3_col2" class="data row3 col2" >129.00</td>
#       <td id="T_ef3cd_row3_col3" class="data row3 col3" >125.00</td>
#       <td id="T_ef3cd_row3_col4" class="data row3 col4" >SET50</td>
#       <td id="T_ef3cd_row3_col5" class="data row3 col5" >2022-05-10</td>
#       <td id="T_ef3cd_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_ef3cd_row3_col7" class="data row3 col7" >129.00</td>
#       <td id="T_ef3cd_row3_col8" class="data row3 col8" >125.00</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row4" class="row_heading level0 row4" >KKP</th>
#       <td id="T_ef3cd_row4_col0" class="data row4 col0" >-3.15%</td>
#       <td id="T_ef3cd_row4_col1" class="data row4 col1" >O</td>
#       <td id="T_ef3cd_row4_col2" class="data row4 col2" >71.50</td>
#       <td id="T_ef3cd_row4_col3" class="data row4 col3" >69.25</td>
#       <td id="T_ef3cd_row4_col4" class="data row4 col4" >SET100</td>
#       <td id="T_ef3cd_row4_col5" class="data row4 col5" >2022-05-10</td>
#       <td id="T_ef3cd_row4_col6" class="data row4 col6" >3</td>
#       <td id="T_ef3cd_row4_col7" class="data row4 col7" >71.75</td>
#       <td id="T_ef3cd_row4_col8" class="data row4 col8" >68.75</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row5" class="row_heading level0 row5" >PTT</th>
#       <td id="T_ef3cd_row5_col0" class="data row5 col0" >-3.33%</td>
#       <td id="T_ef3cd_row5_col1" class="data row5 col1" >I</td>
#       <td id="T_ef3cd_row5_col2" class="data row5 col2" >37.50</td>
#       <td id="T_ef3cd_row5_col3" class="data row5 col3" >36.25</td>
#       <td id="T_ef3cd_row5_col4" class="data row5 col4" >SET50</td>
#       <td id="T_ef3cd_row5_col5" class="data row5 col5" >2022-05-05</td>
#       <td id="T_ef3cd_row5_col6" class="data row5 col6" >8</td>
#       <td id="T_ef3cd_row5_col7" class="data row5 col7" >37.75</td>
#       <td id="T_ef3cd_row5_col8" class="data row5 col8" >36.25</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row6" class="row_heading level0 row6" >KBANK</th>
#       <td id="T_ef3cd_row6_col0" class="data row6 col0" >-3.40%</td>
#       <td id="T_ef3cd_row6_col1" class="data row6 col1" >O</td>
#       <td id="T_ef3cd_row6_col2" class="data row6 col2" >147.00</td>
#       <td id="T_ef3cd_row6_col3" class="data row6 col3" >142.00</td>
#       <td id="T_ef3cd_row6_col4" class="data row6 col4" >SET50</td>
#       <td id="T_ef3cd_row6_col5" class="data row6 col5" >2022-05-10</td>
#       <td id="T_ef3cd_row6_col6" class="data row6 col6" >3</td>
#       <td id="T_ef3cd_row6_col7" class="data row6 col7" >146.50</td>
#       <td id="T_ef3cd_row6_col8" class="data row6 col8" >141.00</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row7" class="row_heading level0 row7" >RATCH</th>
#       <td id="T_ef3cd_row7_col0" class="data row7 col0" >-3.77%</td>
#       <td id="T_ef3cd_row7_col1" class="data row7 col1" >I</td>
#       <td id="T_ef3cd_row7_col2" class="data row7 col2" >39.75</td>
#       <td id="T_ef3cd_row7_col3" class="data row7 col3" >38.25</td>
#       <td id="T_ef3cd_row7_col4" class="data row7 col4" >SET50</td>
#       <td id="T_ef3cd_row7_col5" class="data row7 col5" >2022-05-12</td>
#       <td id="T_ef3cd_row7_col6" class="data row7 col6" >1</td>
#       <td id="T_ef3cd_row7_col7" class="data row7 col7" >39.75</td>
#       <td id="T_ef3cd_row7_col8" class="data row7 col8" >38.00</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row8" class="row_heading level0 row8" >IP</th>
#       <td id="T_ef3cd_row8_col0" class="data row8 col0" >-4.19%</td>
#       <td id="T_ef3cd_row8_col1" class="data row8 col1" >I</td>
#       <td id="T_ef3cd_row8_col2" class="data row8 col2" >19.10</td>
#       <td id="T_ef3cd_row8_col3" class="data row8 col3" >18.30</td>
#       <td id="T_ef3cd_row8_col4" class="data row8 col4" >mai</td>
#       <td id="T_ef3cd_row8_col5" class="data row8 col5" >2022-05-10</td>
#       <td id="T_ef3cd_row8_col6" class="data row8 col6" >3</td>
#       <td id="T_ef3cd_row8_col7" class="data row8 col7" >19.20</td>
#       <td id="T_ef3cd_row8_col8" class="data row8 col8" >18.00</td>
#     </tr>
#     <tr>
#       <th id="T_ef3cd_level0_row9" class="row_heading level0 row9" >MAKRO</th>
#       <td id="T_ef3cd_row9_col0" class="data row9 col0" >-8.11%</td>
#       <td id="T_ef3cd_row9_col1" class="data row9 col1" >I</td>
#       <td id="T_ef3cd_row9_col2" class="data row9 col2" >37.00</td>
#       <td id="T_ef3cd_row9_col3" class="data row9 col3" >34.00</td>
#       <td id="T_ef3cd_row9_col4" class="data row9 col4" >SET</td>
#       <td id="T_ef3cd_row9_col5" class="data row9 col5" >2022-05-10</td>
#       <td id="T_ef3cd_row9_col6" class="da

# %%
file_name = "daily-watch-list.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

watch_list.sort_values(['percent'],ascending=[False]).to_csv(output_file)
watch_list.sort_values(['percent'],ascending=[False]).to_csv(data_file)
watch_list.sort_values(['percent'],ascending=[False]).to_csv(box_file)
watch_list.sort_values(['percent'],ascending=[False]).to_csv(one_file)

# %% [markdown]
# ### Create daily-sales from sales

# %%
df[cols].head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2d423_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fm_date</th>
#       <th class="col_heading level0 col1" >to_date</th>
#       <th class="col_heading level0 col2" >fm_price</th>
#       <th class="col_heading level0 col3" >to_price</th>
#       <th class="col_heading level0 col4" >qty</th>
#       <th class="col_heading level0 col5" >max_price</th>
#       <th class="col_heading level0 col6" >min_price</th>
#       <th class="col_heading level0 col7" >percent</th>
#       <th class="col_heading level0 col8" >status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d423_level0_row0" class="row_heading level0 row0" >DIF</th>
#       <td id="T_2d423_row0_col0" class="data row0 col0" >2022-05-06</td>
#       <td id="T_2d423_row0_col1" class="data row0 col1" >2022-05-13</td>
#       <td id="T_2d423_row0_col2" class="data row0 col2" >14.10</td>
#       <td id="T_2d423_row0_col3" class="data row0 col3" >14.30</td>
#       <td id="T_2d423_row0_col4" class="data row0 col4" >72,640,747</td>
#       <td id="T_2d423_row0_col5" class="data row0 col5" >14.30</td>
#       <td id="T_2d423_row0_col6" class="data row0 col6" >14.10</td>
#       <td id="T_2d423_row0_col7" class="data row0 col7" >1.42%</td>
#       <td id="T_2d423_row0_col8" class="data row0 col8" >B</td>
#     </tr>
#     <tr>
#       <th id="T_2d423_level0_row1" class="row_heading level0 row1" >HREIT</th>
#       <td id="T_2d423_row1_col0" class="data row1 col0" >2022-05-12</td>
#       <td id="T_2d423_row1_col1" class="data row1 col1" >2022-05-13</td>
#       <td id="T_2d423_row1_col2" class="data row1 col2" >8.30</td>
#       <td id="T_2d423_row1_col3" class="data row1 col3" >8.35</td>
#       <td id="T_2d423_row1_col4" class="data row1 col4" >126,700</td>
#       <td id="T_2d423_row1_col5" class="data row1 col5" >8.35</td>
#       <td id="T_2d423_row1_col6" class="data row1 col6" >8.30</td>
#       <td id="T_2d423_row1_col7" class="data row1 col7" >0.60%</td>
#       <td id="T_2d423_row1_col8" class="data row1 col8" >B</td>
#     </tr>
#     <tr>
#       <th id="T_2d423_level0_row2" class="row_heading level0 row2" >JASIF</th>
#       <td id="T_2d423_row2_col0" class="data row2 col0" >2022-05-11</td>
#       <td id="T_2d423_row2_col1" class="data row2 col1" >2022-05-13</td>
#       <td id="T_2d423_row2_col2" class="data row2 col2" >10.90</td>
#       <td id="T_2d423_row2_col3" class="data row2 col3" >11.00</td>
#       <td id="T_2d423_row2_col4" class="data row2 col4" >36,287,104</td>
#       <td id="T_2d423_row2_col5" class="data row2 col5" >11.00</td>
#       <td id="T_2d423_row2_col6" class="data row2 col6" >10.90</td>
#       <td id="T_2d423_row2_col7" class="data row2 col7" >0.92%</td>
#       <td id="T_2d423_row2_col8" class="data row2 col8" >B</td>
#     </tr>
#     <tr>
#       <th id="T_2d423_level0_row3" class="row_heading level0 row3" >WHART</th>
#       <td id="T_2d423_row3_col0" class="data row3 col0" >2022-05-12</td>
#       <td id="T_2d423_row3_col1" class="data row3 col1" >2022-05-13</td>
#       <td id="T_2d423_row3_col2" class="data row3 col2" >10.50</td>
#       <td id="T_2d423_row3_col3" class="data row3 col3" >10.60</td>
#       <td id="T_2d423_row3_col4" class="data row3 col4" >347,367</td>
#       <td id="T_2d423_row3_col5" class="data row3 col5" >10.70</td>
#       <td id="T_2d423_row3_col6" class="data row3 col6" >10.50</td>
#       <td id="T_2d423_row3_col7" class="data row3 col7" >0.95%</td>
#       <td id="T_2d423_row3_col8" class="data row3 col8" >B</td>
#     </tr>
#     <tr>
#       <th id="T_2d423_level0_row4" class="row_heading level0 row4" >BCH</th>
#       <td id="T_2d423_row4_col0" class="data row4 col0" >2022-05-12</td>
#       <td id="T_2d423_row4_col1" class="data row4 col1" >2022-05-13</td>
#       <td id="T_2d423_row4_col2" class="data row4 col2" >19.00</td>
#       <td id="T_2d423_row4_col3" class="data row4 col3" >20.00</td>
#       <td id="T_2d423_row4_col4" class="data row4 col4" >21,122,243</td>
#       <td id="T_2d423_row4_col5" class="data row4 col5" >20.00</td>
#       <td id="T_2d423_row4_col6" class="data row4 col6" >19.20</td>
#       <td id="T_2d423_row4_col7" class="data row4 col7" >5.26%</td>
#       <td id="T_2d423_row4_col8" class="data row4 col8" >I</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = "daily-sales.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(output_file,header=None)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(data_file,header=None)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(box_file)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(one_file)

# %% [markdown]
# ### Create monitors from stocks

# %%
sql = """
SELECT name, trade 
FROM orders 
ORDER BY name
"""
monitors = pd.read_sql(sql, conlite)
monitors.set_index(["name"], inplace=True)
monitors.head()
# Out:
#      trade
# name
# BBL      B
# BCH      S
# BDMS     B
# BGC      B
# DIF      B

# %%
sql = """
SELECT trade, COUNT(*) AS 'no. of stocks'
FROM orders 
GROUP BY trade
"""
df_tmp = pd.read_sql(sql, conlite)
df_tmp
# Out:
#   trade  no. of stocks
# 0     B             10
# 1     S             10

# %% [markdown]
# ### output_file = iCloud Drive on PC

# %%
file_name = "monitors.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

monitors.to_csv(data_file, header=None)
monitors.to_csv(box_file)
monitors.to_csv(output_file)
monitors.to_csv(one_file)

# %% [markdown]
# ### End of daily process

# %%
sql = """
SELECT trade, COUNT(*) AS 'no. of stocks'
FROM orders 
GROUP BY trade
"""
df_tmp = pd.read_sql(sql, conlite)
df_tmp
# Out:
#   trade  no. of stocks
# 0     B             10
# 1     S             10

# %%
sql = """
SELECT name, status, market
FROM stocks 
ORDER BY status, name
"""
stocks = pd.read_sql(sql, conlite)
stocks.set_index(["name"], inplace=True)
stocks
# Out:
#        status  market
# name
# DIF         B     SET
# HREIT       B     SET
# JASIF       B     SET
# WHART       B     SET
# BCH         I  SET100
# DOHOME      I  SET100
# IP          I     mai
# MAKRO       I     SET
# NER         I     SET
# PTT         I   SET50
# RATCH       I   SET50
# AIT         O     SET
# BBL         O   SET50
# BCPG        O  SET100
# BDMS        O   SET50
# BGC         O     SET
# BH          O   SET50
# BPP         O  SET100
# COTTO       O     SET
# ESSO        O  SET100
# GGC         O     SET
# IVL         O   SET50
# KBANK       O   SET50
# KKP         O  SET100
# RBF         O  SET100
# SIS         O     SET
# SMPC        O     SET
# SPRC        O  SET100
# TOP         O   SET50
# TTB         O   SET50
# PTTGC       S   SET50
# STA         S  SET100
# SYNEX       S  SET100
# ASP         T     SET
# MCS         T     SET
# RJH         T     SET
# SCCC        T     SET
# SENA        T     SET
# TISCO       T   SET50
# TMT         T     SET
# DCC         U     SET
# KCE         U   SET50
# ORI         U  SET100
# RCL         U  SET100
# SCC         U   SET50
# TPIPL       U     SET
# ASK         X     SET
# BAY         X     SET
# GLOBAL      X   SET50
# GULF        X   SET50
# KTB         X   SET50
# KTC         X   SET50
# MEGA        X  SET100
# MST         X     SET
# SCB         X   SET50
# SINGER      X  SET100
# SNC         X     SET

# %%
file_name = "stocks-all.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

stocks.to_csv(data_file, header=None)
stocks.to_csv(output_file)
stocks.to_csv(box_file)
stocks.to_csv(one_file)

# %%
sql = """
SELECT name, trade 
FROM orders 
WHERE trade IN ("B")
ORDER BY name
"""
buy_candidates = pd.read_sql(sql, conlite)
buy_candidates.set_index(["name"], inplace=True)
buy_candidates
# Out:
#       trade
# name
# BBL       B
# BDMS      B
# BGC       B
# DIF       B
# HREIT     B
# IVL       B
# JASIF     B
# KBANK     B
# KKP       B
# WHART     B

# %%
buy_candidates.shape[0]
# Out:
# 10

# %%
sql = """
SELECT name, trade 
FROM orders 
WHERE trade IN ("S")
ORDER BY name
"""
sell_candidates = pd.read_sql(sql, conlite)
sell_candidates.set_index(["name"], inplace=True)
sell_candidates
# Out:
#        trade
# name
# BCH        S
# DOHOME     S
# IP         S
# MAKRO      S
# NER        S
# PTT        S
# PTTGC      S
# RATCH      S
# STA        S
# SYNEX      S

# %%
sell_candidates.shape[0]
# Out:
# 10
