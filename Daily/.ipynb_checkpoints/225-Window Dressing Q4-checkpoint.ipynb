# %% [markdown]
# #### port_lite: stocks
# #### portpg: stocks
# #### stock: setindex, price, buy
# #### output csv: 5-day_average, extreme

# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

format_dict = {
               'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
               'price_x':'{:,.2f}','to_price':'{:,.2f}','price_y':'{:,.2f}',
               'maxp':'{:,.2f}','max_price':'{:,.2f}',
               'minp':'{:,.2f}','price':'{:,.2f}','opnp':'{:,.2f}',    
               'inc_pct':'{:,.2f}','setindex':'{:,.2f}','prc_pct':'{:,.2f}',
               'qty':'{:,}','qty_x':'{:,}','qty_z':'{:,}'
              }
pd.set_option("display.max_rows", None)

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2021, 12, 27), datetime.date(2021, 12, 26))

# %%
#today = today - timedelta(days=1)
yesterday = today - timedelta(days=3)
today, yesterday
# Out:
# (datetime.date(2021, 12, 27), datetime.date(2021, 12, 24))

# %% [markdown]
# ### Restart and run all cells

# %%
sql = """
SELECT * 
FROM setindex 
WHERE date = '%s'
"""
sql = sql % today

setindex = pd.read_sql(sql, const)
setindex.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c8b35_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >setindex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8b35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8b35_row0_col0" class="data row0 col0" >2021-12-27</td>
#       <td id="T_c8b35_row0_col1" class="data row0 col1" >1,636.50</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT * 
FROM price 
WHERE date = '%s'
"""
sql = sql % today

prices = pd.read_sql(sql, const)
prices.shape
# Out:
# (354, 7)

# %%
sql = """
SELECT * 
FROM stocks
"""
stocks = pd.read_sql(sql, conpg)
stocks.shape
# Out:
# (356, 15)

# %%
df_merge = pd.merge(prices, stocks, on="name", how="inner")
df_merge.shape
# Out:
# (353, 21)

# %% [markdown]
# ### 52 Weeks High

# %%
cols = "name market price_x maxp max_price qty".split()

# %%
Yearly_High = (df_merge.maxp > df_merge.max_price) & (df_merge.qty > 100000)
df_merge[Yearly_High][cols].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_80c1a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >market</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >max_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80c1a_level0_row0" class="row_heading level0 row0" >347</th>
#       <td id="T_80c1a_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_80c1a_row0_col1" class="data row0 col1" >sSET / SETTHSI    </td>
#       <td id="T_80c1a_row0_col2" class="data row0 col2" >28.50</td>
#       <td id="T_80c1a_row0_col3" class="data row0 col3" >28.50</td>
#       <td id="T_80c1a_row0_col4" class="data row0 col4" >28.00</td>
#       <td id="T_80c1a_row0_col5" class="data row0 col5" >3,248,656</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row1" class="row_heading level0 row1" >334</th>
#       <td id="T_80c1a_row1_col0" class="data row1 col0" >AP</td>
#       <td id="T_80c1a_row1_col1" class="data row1 col1" >SET100 / SETHD    </td>
#       <td id="T_80c1a_row1_col2" class="data row1 col2" >9.70</td>
#       <td id="T_80c1a_row1_col3" class="data row1 col3" >9.80</td>
#       <td id="T_80c1a_row1_col4" class="data row1 col4" >9.70</td>
#       <td id="T_80c1a_row1_col5" class="data row1 col5" >25,569,970</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row2" class="row_heading level0 row2" >310</th>
#       <td id="T_80c1a_row2_col0" class="data row2 col0" >BEYOND</td>
#       <td id="T_80c1a_row2_col1" class="data row2 col1" >SET    </td>
#       <td id="T_80c1a_row2_col2" class="data row2 col2" >11.20</td>
#       <td id="T_80c1a_row2_col3" class="data row2 col3" >11.20</td>
#       <td id="T_80c1a_row2_col4" class="data row2 col4" >10.70</td>
#       <td id="T_80c1a_row2_col5" class="data row2 col5" >12,054,520</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row3" class="row_heading level0 row3" >303</th>
#       <td id="T_80c1a_row3_col0" class="data row3 col0" >BLA</td>
#       <td id="T_80c1a_row3_col1" class="data row3 col1" >SET    </td>
#       <td id="T_80c1a_row3_col2" class="data row3 col2" >36.50</td>
#       <td id="T_80c1a_row3_col3" class="data row3 col3" >36.75</td>
#       <td id="T_80c1a_row3_col4" class="data row3 col4" >36.50</td>
#       <td id="T_80c1a_row3_col5" class="data row3 col5" >1,912,696</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row4" class="row_heading level0 row4" >227</th>
#       <td id="T_80c1a_row4_col0" class="data row4 col0" >III</td>
#       <td id="T_80c1a_row4_col1" class="data row4 col1" >sSET    </td>
#       <td id="T_80c1a_row4_col2" class="data row4 col2" >15.50</td>
#       <td id="T_80c1a_row4_col3" class="data row4 col3" >15.90</td>
#       <td id="T_80c1a_row4_col4" class="data row4 col4" >15.60</td>
#       <td id="T_80c1a_row4_col5" class="data row4 col5" >26,362,533</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row5" class="row_heading level0 row5" >206</th>
#       <td id="T_80c1a_row5_col0" class="data row5 col0" >JWD</td>
#       <td id="T_80c1a_row5_col1" class="data row5 col1" >sSET / SETTHSI    </td>
#       <td id="T_80c1a_row5_col2" class="data row5 col2" >20.10</td>
#       <td id="T_80c1a_row5_col3" class="data row5 col3" >20.40</td>
#       <td id="T_80c1a_row5_col4" class="data row5 col4" >19.50</td>
#       <td id="T_80c1a_row5_col5" class="data row5 col5" >14,074,153</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row6" class="row_heading level0 row6" >120</th>
#       <td id="T_80c1a_row6_col0" class="data row6 col0" >SABUY</td>
#       <td id="T_80c1a_row6_col1" class="data row6 col1" >sSET    </td>
#       <td id="T_80c1a_row6_col2" class="data row6 col2" >22.80</td>
#       <td id="T_80c1a_row6_col3" class="data row6 col3" >22.80</td>
#       <td id="T_80c1a_row6_col4" class="data row6 col4" >21.70</td>
#       <td id="T_80c1a_row6_col5" class="data row6 col5" >31,677,048</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row7" class="row_heading level0 row7" >56</th>
#       <td id="T_80c1a_row7_col0" class="data row7 col0" >THG</td>
#       <td id="T_80c1a_row7_col1" class="data row7 col1" >SETCLMV / SETWB    </td>
#       <td id="T_80c1a_row7_col2" class="data row7 col2" >37.00</td>
#       <td id="T_80c1a_row7_col3" class="data row7 col3" >37.00</td>
#       <td id="T_80c1a_row7_col4" class="data row7 col4" >36.75</td>
#       <td id="T_80c1a_row7_col5" class="data row7 col5" >592,991</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row8" class="row_heading level0 row8" >39</th>
#       <td id="T_80c1a_row8_col0" class="data row8 col0" >TOG</td>
#       <td id="T_80c1a_row8_col1" class="data row8 col1" >SET    </td>
#       <td id="T_80c1a_row8_col2" class="data row8 col2" >10.50</td>
#       <td id="T_80c1a_row8_col3" class="data row8 col3" >11.30</td>
#       <td id="T_80c1a_row8_col4" class="data row8 col4" >11.00</td>
#       <td id="T_80c1a_row8_col5" class="data row8 col5" >6,766,351</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row9" class="row_heading level0 row9" >23</th>
#       <td id="T_80c1a_row9_col0" class="data row9 col0" >TVI</td>
#       <td id="T_80c1a_row9_col1" class="data row9 col1" >SET    </td>
#       <td id="T_80c1a_row9_col2" class="data row9 col2" >29.00</td>
#       <td id="T_80c1a_row9_col3" class="data row9 col3" >30.50</td>
#       <td id="T_80c1a_row9_col4" class="data row9 col4" >30.00</td>
#       <td id="T_80c1a_row9_col5" class="data row9 col5" >3,311,198</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row10" class="row_heading level0 row10" >5</th>
#       <td id="T_80c1a_row10_col0" class="data row10 col0" >WICE</td>
#       <td id="T_80c1a_row10_col1" class="data row10 col1" >sSET    </td>
#       <td id="T_80c1a_row10_col2" class="data row10 col2" >19.30</td>
#       <td id="T_80c1a_row10_col3" class="data row10 col3" >19.80</td>
#       <td id="T_80c1a_row10_col4" class="data row10 col4" >19.40</td>
#       <td id="T_80c1a_row10_col5" class="data row10 col5" >8,797,167</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks Low

# %%
colt = "name market price_x minp min_price qty".split()

# %%
Yearly_Low = (df_merge.minp < df_merge.min_price) & (df_merge.qty > 100000)
Final_Low = df_merge[Yearly_Low]
Final_Low[colt].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbf83_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >market</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >minp</th>
#       <th class="col_heading level0 col4" >min_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbf83_level0_row0" class="row_heading level0 row0" >305</th>
#       <td id="T_dbf83_row0_col0" class="data row0 col0" >BJC</td>
#       <td id="T_dbf83_row0_col1" class="data row0 col1" >SET50 / SETCLMV / SETTHSI / SETWB    </td>
#       <td id="T_dbf83_row0_col2" class="data row0 col2" >29.50</td>
#       <td id="T_dbf83_row0_col3" class="data row0 col3" >29.25</td>
#       <td id="T_dbf83_row0_col4" class="data row0 col4" >29.500000</td>
#       <td id="T_dbf83_row0_col5" class="data row0 col5" >15,161,195</td>
#     </tr>
#     <tr>
#       <th id="T_dbf83_level0_row1" class="row_heading level0 row1" >279</th>
#       <td id="T_dbf83_row1_col0" class="data row1 col0" >CPTGF</td>
#       <td id="T_dbf83_row1_col1" class="data row1 col1" >SET    </td>
#       <td id="T_dbf83_row1_col2" class="data row1 col2" >8.65</td>
#       <td id="T_dbf83_row1_col3" class="data row1 col3" >8.60</td>
#       <td id="T_dbf83_row1_col4" class="data row1 col4" >8.700000</td>
#       <td id="T_dbf83_row1_col5" class="data row1 col5" >647,800</td>
#     </tr>
#     <tr>
#       <th id="T_dbf83_level0_row2" class="row_heading level0 row2" >260</th>
#       <td id="T_dbf83_row2_col0" class="data row2 col0" >EGATIF</td>
#       <td id="T_dbf83_row2_col1" class="data row2 col1" >SET    </td>
#       <td id="T_dbf83_row2_col2" class="data row2 col2" >11.70</td>
#       <td id="T_dbf83_row2_col3" class="data row2 col3" >11.60</td>
#       <td id="T_dbf83_row2_col4" class="data row2 col4" >11.700000</td>
#       <td id="T_dbf83_row2_col5" class="data row2 col5" >2,094,546</td>
#     </tr>
#     <tr>
#       <th id="T_dbf83_level0_row3" class="row_heading level0 row3" >192</th>
#       <td id="T_dbf83_row3_col0" class="data row3 col0" >LHHOTEL</td>
#       <td id="T_dbf83_row3_col1" class="data row3 col1" >SET    </td>
#       <td id="T_dbf83_row3_col2" class="data row3 col2" >8.30</td>
#       <td id="T_dbf83_row3_col3" class="data row3 col3" >8.15</td>
#       <td id="T_dbf83_row3_col4" class="data row3 col4" >8.250000</td>
#       <td id="T_dbf83_row3_col5" class="data row3 col5" >343,504</td>
#     </tr>
#     <tr>
#       <th id="T_dbf83_level0_row4" class="row_heading level0 row4" >35</th>
#       <td id="T_dbf83_row4_col0" class="data row4 col0" >TQM</td>
#       <td id="T_dbf83_row4_col1" class="data row4 col1" >SET100    </td>
#       <td id="T_dbf83_row4_col2" class="data row4 col2" >100.50</td>
#       <td id="T_dbf83_row4_col3" class="data row4 col3" >100.00</td>
#       <td id="T_dbf83_row4_col4" class="data row4 col4" >100.500000</td>
#       <td id="T_dbf83_row4_col5" class="data row4 col5" >754,016</td>
#     </tr>
#   </tbody>
# </table>

# %%
set50 = Final_Low["market"].str.contains("SET50")
Final_Low[set50].sort_values(by=["name"],ascending=["True"])
# Out:
#     name        date  price_x  maxp   minp       qty  opnp  id  \
# 305  BJC  2021-12-27     29.5  30.0  29.25  15161195  30.0  68
#
#                                     market  price_y  ...  min_price     pe  \
# 305  SET50 / SETCLMV / SETTHSI / SETWB         30.0  ...       29.5  33.81
#
#       pbv  paid_up  market_cap  daily_volume  beta  ticker_id  \
# 305  1.05   4007.8    120233.9        323.86  0.96         68
#
#                     created_at                 updated_at
# 305 2018-04-26 02:42:11.757560 2021-12-24 23:31:11.522828
#
# [1 rows x 21 columns]

# %%
set100 = Final_Low["market"].str.contains("SET100")
Final_Low[set100].sort_values(by=["name"],ascending=["True"])
# Out:
#    name        date  price_x   maxp   minp     qty   opnp   id      market  \
# 35  TQM  2021-12-27    100.5  103.0  100.0  754016  102.5  664  SET100
#
#     price_y  ...  min_price     pe    pbv  paid_up  market_cap  daily_volume  \
# 35    102.5  ...      100.5  35.91  13.26    300.0     30750.0        123.21
#
#     beta  ticker_id                 created_at                 updated_at
# 35  0.57        657 2019-03-03 15:23:17.869724 2021-12-24 23:58:27.776405
#
# [1 rows x 21 columns]

# %%
sethd = Final_Low["market"].str.contains("SETHD")
Final_Low[sethd]
# Out:
# Empty DataFrame
# Columns: [name, date, price_x, maxp, minp, qty, opnp, id, market, price_y, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Break 5-day Average Volume

# %%
sql = """
SELECT * 
FROM price 
WHERE date = '%s'
"""
sql = sql % today

today_vol = pd.read_sql(sql, const)
today_vol.shape
# Out:
# (354, 7)

# %%
from_date = yesterday - timedelta(days=4)
from_date
# Out:
# datetime.date(2021, 12, 20)

# %%
sql = """
SELECT * 
FROM price 
WHERE date BETWEEN '%s' AND '%s'
"""
sql = sql % (from_date, yesterday)
print(sql)
# Out:
# SELECT *
# FROM price
# WHERE date BETWEEN '2021-12-20' AND '2021-12-24'

# %%
five_day_vol = pd.read_sql(sql, const)
five_day_vol.shape
# Out:
# (1758, 7)

# %%
five_day_mean = five_day_vol.groupby(by=["name"])[["qty","price"]].mean()
five_day_mean.reset_index(inplace=True)

df_merge2 = pd.merge(today_vol, five_day_mean, on=["name"], how="inner")
df_merge2["qty_z"] = df_merge2.qty_y.astype("int64")
df_merge2.shape
# Out:
# (354, 10)

# %%
break_five_day_mean = df_merge2[(df_merge2.qty_x > df_merge2.qty_z)]
break_five_day_mean.shape
# Out:
# (124, 10)

# %%
sql = """
SELECT * 
FROM buy 
WHERE active = 1
"""
buys = pd.read_sql(sql, const)
buys.shape
# Out:
# (34, 10)

# %%
df_merge3 = pd.merge(break_five_day_mean, buys, on=["name"], how="inner")
df_merge3["inc_pct"] = round((df_merge3.qty_x - df_merge3.qty_z) / abs(df_merge3.qty_z) * 100,2)
df_merge3["prc_pct"] = round((df_merge3.price_x - df_merge3.price_y) / abs(df_merge3.price_y) * 100,2)
df_merge3["name prc_pct price_x price_y inc_pct qty_x qty_z".split()].sort_values(["prc_pct"], ascending=False
).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_da18f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >prc_pct</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >price_y</th>
#       <th class="col_heading level0 col4" >inc_pct</th>
#       <th class="col_heading level0 col5" >qty_x</th>
#       <th class="col_heading level0 col6" >qty_z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da18f_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_da18f_row0_col0" class="data row0 col0" >STA</td>
#       <td id="T_da18f_row0_col1" class="data row0 col1" >1.99</td>
#       <td id="T_da18f_row0_col2" class="data row0 col2" >30.75</td>
#       <td id="T_da18f_row0_col3" class="data row0 col3" >30.15</td>
#       <td id="T_da18f_row0_col4" class="data row0 col4" >87.33</td>
#       <td id="T_da18f_row0_col5" class="data row0 col5" >10,542,117</td>
#       <td id="T_da18f_row0_col6" class="data row0 col6" >5,627,495</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_da18f_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_da18f_row1_col1" class="data row1 col1" >0.53</td>
#       <td id="T_da18f_row1_col2" class="data row1 col2" >37.75</td>
#       <td id="T_da18f_row1_col3" class="data row1 col3" >37.55</td>
#       <td id="T_da18f_row1_col4" class="data row1 col4" >12.73</td>
#       <td id="T_da18f_row1_col5" class="data row1 col5" >29,701,947</td>
#       <td id="T_da18f_row1_col6" class="data row1 col6" >26,347,252</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_da18f_row2_col0" class="data row2 col0" >SCC</td>
#       <td id="T_da18f_row2_col1" class="data row2 col1" >0.11</td>
#       <td id="T_da18f_row2_col2" class="data row2 col2" >379.00</td>
#       <td id="T_da18f_row2_col3" class="data row2 col3" >378.60</td>
#       <td id="T_da18f_row2_col4" class="data row2 col4" >15.44</td>
#       <td id="T_da18f_row2_col5" class="data row2 col5" >2,130,866</td>
#       <td id="T_da18f_row2_col6" class="data row2 col6" >1,845,843</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_da18f_row3_col0" class="data row3 col0" >VNT</td>
#       <td id="T_da18f_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_da18f_row3_col2" class="data row3 col2" >38.50</td>
#       <td id="T_da18f_row3_col3" class="data row3 col3" >38.50</td>
#       <td id="T_da18f_row3_col4" class="data row3 col4" >158.22</td>
#       <td id="T_da18f_row3_col5" class="data row3 col5" >2,374,178</td>
#       <td id="T_da18f_row3_col6" class="data row3 col6" >919,439</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_da18f_row4_col0" class="data row4 col0" >BGRIM</td>
#       <td id="T_da18f_row4_col1" class="data row4 col1" >-0.25</td>
#       <td id="T_da18f_row4_col2" class="data row4 col2" >40.00</td>
#       <td id="T_da18f_row4_col3" class="data row4 col3" >40.10</td>
#       <td id="T_da18f_row4_col4" class="data row4 col4" >32.66</td>
#       <td id="T_da18f_row4_col5" class="data row4 col5" >12,980,732</td>
#       <td id="T_da18f_row4_col6" class="data row4 col6" >9,785,053</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_da18f_row5_col0" class="data row5 col0" >MCS</td>
#       <td id="T_da18f_row5_col1" class="data row5 col1" >-0.28</td>
#       <td id="T_da18f_row5_col2" class="data row5 col2" >14.50</td>
#       <td id="T_da18f_row5_col3" class="data row5 col3" >14.54</td>
#       <td id="T_da18f_row5_col4" class="data row5 col4" >167.29</td>
#       <td id="T_da18f_row5_col5" class="data row5 col5" >3,420,083</td>
#       <td id="T_da18f_row5_col6" class="data row5 col6" >1,279,542</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_da18f_row6_col0" class="data row6 col0" >DIF</td>
#       <td id="T_da18f_row6_col1" class="data row6 col1" >-0.43</td>
#       <td id="T_da18f_row6_col2" class="data row6 col2" >13.90</td>
#       <td id="T_da18f_row6_col3" class="data row6 col3" >13.96</td>
#       <td id="T_da18f_row6_col4" class="data row6 col4" >40.73</td>
#       <td id="T_da18f_row6_col5" class="data row6 col5" >5,589,582</td>
#       <td id="T_da18f_row6_col6" class="data row6 col6" >3,971,775</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_da18f_row7_col0" class="data row7 col0" >JASIF</td>
#       <td id="T_da18f_row7_col1" class="data row7 col1" >-0.58</td>
#       <td id="T_da18f_row7_col2" class="data row7 col2" >10.20</td>
#       <td id="T_da18f_row7_col3" class="data row7 col3" >10.26</td>
#       <td id="T_da18f_row7_col4" class="data row7 col4" >40.18</td>
#       <td id="T_da18f_row7_col5" class="data row7 col5" >8,965,594</td>
#       <td id="T_da18f_row7_col6" class="data row7 col6" >6,395,930</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_da18f_row8_col0" class="data row8 col0" >HREIT</td>
#       <td id="T_da18f_row8_col1" class="data row8 col1" >-0.89</td>
#       <td id="T_da18f_row8_col2" class="data row8 col2" >8.90</td>
#       <td id="T_da18f_row8_col3" class="data row8 col3" >8.98</td>
#       <td id="T_da18f_row8_col4" class="data row8 col4" >33.33</td>
#       <td id="T_da18f_row8_col5" class="data row8 col5" >330,872</td>
#       <td id="T_da18f_row8_col6" class="data row8 col6" >248,152</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_da18f_row9_col0" class="data row9 col0" >DCC</td>
#       <td id="T_da18f_row9_col1" class="data row9 col1" >-0.98</td>
#       <td id="T_da18f_row9_col2" class="data row9 col2" >2.82</td>
#       <td id="T_da18f_row9_col3" class="data row9 col3" >2.85</td>
#       <td id="T_da18f_row9_col4" class="data row9 col4" >128.40</td>
#       <td id="T_da18f_row9_col5" class="data row9 col5" >14,992,990</td>
#       <td id="T_da18f_row9_col6" class="data row9 col6" >6,564,384</td>
#     </tr>
#     <tr>
#       <th id="T_da18f_level0_row10" class="row_heading level0 row10" >1</th>
#       <td id="T_da18f_row10_col0" class="data row10 col0" >TMT</td>
#       <td id="T_da18f_row10_col1" class="data row10 col1" >-3.10</td>
#       <td id="T_da18f_row10_col2" class="data row10 col2" >10.00</td>
#       <td id="T_da18f_row10_col3" class="data row10 col3" >10.32</td>
#       <td id="T_da18f_row10_col4" class="data row10 col4" >628.89</td>
#       <td id="T_da18f_row10_col5" class="data row10 col5" >1,816,592</td>
#       <td id="T_da18f_row10_col6" class="data row10 col6" >249,226</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = '5-day-average.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
data_file, output_file, box_file
# Out:
# ('../data/5-day-average.csv',
#  '\\Users\\User\\iCloudDrive\\5-day-average.csv',
#  '\\Users\\User\\Dropbox\\5-day-average.csv')

# %%
colu = "name prc_pct price_x price_y inc_pct qty_x qty_z".split()

# %%
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(data_file)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(output_file)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(box_file)

# %% [markdown]
# ### Extreme price discrepancy

# %%
sql = '''
SELECT name, status
FROM stocks'''
stocks = pd.read_sql(sql, conlite)
stocks.shape[0]
# Out:
# 50

# %%
sr = stocks["name"]
sr.shape
# Out:
# (50,)

# %%
names = sr.values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'MCS', 'PTTGC', 'IVL', 'JASIF', 'DIF', 'ROJNA', 'NOBLE', 'TU', 'DCC', 'HREIT', 'MEGA', 'JMT', 'GULF', 'TISCO', 'SIS', 'TQM', 'STA', 'RATCH', 'SCC', 'NER', 'SYNEX', 'BCH', 'DOHOME', 'PTT', 'RJH', 'SINGER', 'KCE', 'EPG', 'SAT', 'KBANK', 'VNT', 'BGRIM', 'TMT', 'STARK', 'RCL', 'TYCN', 'IP', 'BLA', 'CKP', 'SPALI', 'SVI', 'TOP', 'TSE', 'GLOBAL', 'PTL', 'TSTH', 'ASK', 'IMH', 'TKS', 'TCAP'"

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (today, in_p)
tdy_prices = pd.read_sql(sql, const)
tdy_prices.shape[0]
# Out:
# 50

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (yesterday, in_p)
print(sql)
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2021-12-24' AND name IN ('MCS', 'PTTGC', 'IVL', 'JASIF', 'DIF', 'ROJNA', 'NOBLE', 'TU', 'DCC', 'HREIT', 'MEGA', 'JMT', 'GULF', 'TISCO', 'SIS', 'TQM', 'STA', 'RATCH', 'SCC', 'NER', 'SYNEX', 'BCH', 'DOHOME', 'PTT', 'RJH', 'SINGER', 'KCE', 'EPG', 'SAT', 'KBANK', 'VNT', 'BGRIM', 'TMT', 'STARK', 'RCL', 'TYCN', 'IP', 'BLA', 'CKP', 'SPALI', 'SVI', 'TOP', 'TSE', 'GLOBAL', 'PTL', 'TSTH', 'ASK', 'IMH', 'TKS', 'TCAP')
# ORDER BY name

# %%
ytd_prices = pd.read_sql(sql, const)
ytd_prices.shape[0]
# Out:
# 50

# %%
compare1 = pd.merge(tdy_prices,ytd_prices,on='name',how='inner')
compare1
# Out:
#       name  price_x  price_y
# 0      ASK    42.75    43.50
# 1      BCH    19.90    19.90
# 2    BGRIM    40.00    40.00
# 3      BLA    36.50    36.25
# 4      CKP     5.00     5.00
# 5      DCC     2.82     2.84
# 6      DIF    13.90    14.00
# 7   DOHOME    23.40    23.60
# 8      EPG    11.00    11.00
# 9   GLOBAL    20.20    20.10
# 10    GULF    44.00    43.75
# 11   HREIT     8.90     9.05
# 12     IMH    11.50    11.40
# 13      IP    19.60    19.60
# 14     IVL    43.00    43.00
# 15   JASIF    10.20    10.20
# 16     JMT    67.00    68.00
# 17   KBANK   138.00   138.00
# 18     KCE    90.00    90.00
# 19     MCS    14.50    14.60
# 20    MEGA    51.75    51.75
# 21     NER     7.05     7.10
# 22   NOBLE     6.15     6.15
# 23     PTL    24.40    24.20
# 24     PTT    37.75    38.00
# 25   PTTGC    57.75    58.50
# 26   RATCH    45.00    45.00
# 27     RCL    49.00    49.50
# 28     RJH    32.50    32.75
# 29   ROJNA     6.50     6.50
# 30     SAT    21.20    21.40
# 31     SCC   379.00   380.00
# 32  SINGER    51.75    51.75
# 33     SIS    44.50    44.75
# 34   SPALI    22.70    22.20
# 35     STA    30.75    30.50
# 36   STARK     4.78     4.92
# 37     SVI     7.65     7.45
# 38   SYNEX    34.25    33.50
# 39    TCAP    37.00    37.25
# 40   TISCO    94.25    94.25
# 41     TKS    15.70    15.30
# 42     TMT    10.00    10.30
# 43     TOP    48.25    49.00
# 44     TQM   100.50   102.50
# 45     TSE     2.62     2.64
# 46    TSTH     1.46     1.46
# 47      TU    19.30    19.50
# 48    TYCN     3.60     3.60
# 49     VNT    38.50    38.50

# %%
compare2 = pd.merge(compare1,stocks,on='name',how='inner')
compare2
# Out:
#       name  price_x  price_y status
# 0      ASK    42.75    43.50      X
# 1      BCH    19.90    19.90      U
# 2    BGRIM    40.00    40.00      I
# 3      BLA    36.50    36.25      X
# 4      CKP     5.00     5.00      I
# 5      DCC     2.82     2.84      I
# 6      DIF    13.90    14.00      I
# 7   DOHOME    23.40    23.60      B
# 8      EPG    11.00    11.00      U
# 9   GLOBAL    20.20    20.10      B
# 10    GULF    44.00    43.75      X
# 11   HREIT     8.90     9.05      T
# 12     IMH    11.50    11.40      U
# 13      IP    19.60    19.60      U
# 14     IVL    43.00    43.00      I
# 15   JASIF    10.20    10.20      T
# 16     JMT    67.00    68.00      X
# 17   KBANK   138.00   138.00      I
# 18     KCE    90.00    90.00      I
# 19     MCS    14.50    14.60      I
# 20    MEGA    51.75    51.75      X
# 21     NER     7.05     7.10      I
# 22   NOBLE     6.15     6.15      B
# 23     PTL    24.40    24.20      X
# 24     PTT    37.75    38.00      B
# 25   PTTGC    57.75    58.50      S
# 26   RATCH    45.00    45.00      B
# 27     RCL    49.00    49.50      I
# 28     RJH    32.50    32.75      I
# 29   ROJNA     6.50     6.50      O
# 30     SAT    21.20    21.40      I
# 31     SCC   379.00   380.00      U
# 32  SINGER    51.75    51.75      X
# 33     SIS    44.50    44.75      B
# 34   SPALI    22.70    22.20      X
# 35     STA    30.75    30.50      B
# 36   STARK     4.78     4.92      X
# 37     SVI     7.65     7.45      X
# 38   SYNEX    34.25    33.50      O
# 39    TCAP    37.00    37.25      O
# 40   TISCO    94.25    94.25      T
# 41     TKS    15.70    15.30      X
# 42     TMT    10.00    10.30      T
# 43     TOP    48.25    49.00      I
# 44     TQM   100.50   102.50      X
# 45     TSE     2.62     2.64      X
# 46    TSTH     1.46     1.46      I
# 47      TU    19.30    19.50      I
# 48    TYCN     3.60     3.60      U
# 49     VNT    38.50    38.50      I

# %%
colt = 'name pct price_x price_y status diff'.split()
compare2['diff'] = round((compare2.price_x - compare2.price_y)*1,2)
compare2['pct'] = round(compare2['diff'] / compare2['price_y'] * 100,2)
#compare2.set_index('name',inplace=True)
compare2[colt].sort_values(['pct'],ascending=[False])
# Out:
#       name   pct  price_x  price_y status  diff
# 37     SVI  2.68     7.65     7.45      X  0.20
# 41     TKS  2.61    15.70    15.30      X  0.40
# 34   SPALI  2.25    22.70    22.20      X  0.50
# 38   SYNEX  2.24    34.25    33.50      O  0.75
# 12     IMH  0.88    11.50    11.40      U  0.10
# 23     PTL  0.83    24.40    24.20      X  0.20
# 35     STA  0.82    30.75    30.50      B  0.25
# 3      BLA  0.69    36.50    36.25      X  0.25
# 10    GULF  0.57    44.00    43.75      X  0.25
# 9   GLOBAL  0.50    20.20    20.10      B  0.10
# 20    MEGA  0.00    51.75    51.75      X  0.00
# 32  SINGER  0.00    51.75    51.75      X  0.00
# 46    TSTH  0.00     1.46     1.46      I  0.00
# 29   ROJNA  0.00     6.50     6.50      O  0.00
# 26   RATCH  0.00    45.00    45.00      B  0.00
# 1      BCH  0.00    19.90    19.90      U  0.00
# 40   TISCO  0.00    94.25    94.25      T  0.00
# 22   NOBLE  0.00     6.15     6.15      B  0.00
# 49     VNT  0.00    38.50    38.50      I  0.00
# 8      EPG  0.00    11.00    11.00      U  0.00
# 2    BGRIM  0.00    40.00    40.00      I  0.00
# 17   KBANK  0.00   138.00   138.00      I  0.00
# 15   JASIF  0.00    10.20    10.20      T  0.00
# 14     IVL  0.00    43.00    43.00      I  0.00
# 4      CKP  0.00     5.00     5.00      I  0.00
# 13      IP  0.00    19.60    19.60      U  0.00
# 18     KCE  0.00    90.00    90.00      I  0.00
# 48    TYCN  0.00     3.60     3.60      U  0.00
# 31     SCC -0.26   379.00   380.00      U -1.00
# 33     SIS -0.56    44.50    44.75      B -0.25
# 24     PTT -0.66    37.75    38.00      B -0.25
# 39    TCAP -0.67    37.00    37.25      O -0.25
# 19     MCS -0.68    14.50    14.60      I -0.10
# 5      DCC -0.70     2.82     2.84      I -0.02
# 21     NER -0.70     7.05     7.10      I -0.05
# 6      DIF -0.71    13.90    14.00      I -0.10
# 28     RJH -0.76    32.50    32.75      I -0.25
# 45     TSE -0.76     2.62     2.64      X -0.02
# 7   DOHOME -0.85    23.40    23.60      B -0.20
# 30     SAT -0.93    21.20    21.40      I -0.20
# 27     RCL -1.01    49.00    49.50      I -0.50
# 47      TU -1.03    19.30    19.50      I -0.20
# 25   PTTGC -1.28    57.75    58.50      S -0.75
# 16     JMT -1.47    67.00    68.00      X -1.00
# 43     TOP -1.53    48.25    49.00      I -0.75
# 11   HREIT -1.66     8.90     9.05      T -0.15
# 0      ASK -1.72    42.75    43.50      X -0.75
# 44     TQM -1.95   100.50   102.50      X -2.00
# 36   STARK -2.85     4.78     4.92      X -0.14
# 42     TMT -2.91    10.00    10.30      T -0.30

# %%
criteria = 3
mask = abs(compare2.pct) >= criteria
extremes = compare2[mask].sort_values(['status','pct'],ascending=[True,False])
extremes[colt].sort_values(['status','name'],ascending=[True,True])
# Out:
# Empty DataFrame
# Columns: [name, pct, price_x, price_y, status, diff]
# Index: []

# %%
file_name = 'extremes.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
data_file, output_file, box_file
# Out:
# ('../data/extremes.csv',
#  '\\Users\\User\\iCloudDrive\\extremes.csv',
#  '\\Users\\User\\Dropbox\\extremes.csv')

# %%
extremes[colt].sort_values(['status','name'],ascending=[True,True]).to_csv(data_file)
extremes[colt].sort_values(['status','name'],ascending=[True,True]).to_csv(output_file)
extremes[colt].sort_values(['status','name'],ascending=[True,True]).to_csv(box_file)

# %% [markdown]
# ### One week modal values

# %%
#eow = date(2021, 8, 13)
eow = today
bow = eow - timedelta(days=13)
bow, eow
# Out:
# (datetime.date(2021, 12, 14), datetime.date(2021, 12, 27))

# %%
name = 'PTTGC'
sql = """
SELECT * 
FROM price 
WHERE date BETWEEN '%s' AND '%s' AND name = '%s' 
ORDER BY date DESC"""
sql = sql % (bow, eow, name)
prices = pd.read_sql(sql, const)
prices.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5fb1f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fb1f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5fb1f_row0_col0" class="data row0 col0" >PTTGC</td>
#       <td id="T_5fb1f_row0_col1" class="data row0 col1" >2021-12-27</td>
#       <td id="T_5fb1f_row0_col2" class="data row0 col2" >57.75</td>
#       <td id="T_5fb1f_row0_col3" class="data row0 col3" >58.75</td>
#       <td id="T_5fb1f_row0_col4" class="data row0 col4" >57.75</td>
#       <td id="T_5fb1f_row0_col5" class="data row0 col5" >5,498,189</td>
#       <td id="T_5fb1f_row0_col6" class="data row0 col6" >58.50</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5fb1f_row1_col0" class="data row1 col0" >PTTGC</td>
#       <td id="T_5fb1f_row1_col1" class="data row1 col1" >2021-12-24</td>
#       <td id="T_5fb1f_row1_col2" class="data row1 col2" >58.50</td>
#       <td id="T_5fb1f_row1_col3" class="data row1 col3" >58.75</td>
#       <td id="T_5fb1f_row1_col4" class="data row1 col4" >58.00</td>
#       <td id="T_5fb1f_row1_col5" class="data row1 col5" >5,261,278</td>
#       <td id="T_5fb1f_row1_col6" class="data row1 col6" >58.25</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5fb1f_row2_col0" class="data row2 col0" >PTTGC</td>
#       <td id="T_5fb1f_row2_col1" class="data row2 col1" >2021-12-23</td>
#       <td id="T_5fb1f_row2_col2" class="data row2 col2" >58.25</td>
#       <td id="T_5fb1f_row2_col3" class="data row2 col3" >58.75</td>
#       <td id="T_5fb1f_row2_col4" class="data row2 col4" >58.00</td>
#       <td id="T_5fb1f_row2_col5" class="data row2 col5" >6,964,097</td>
#       <td id="T_5fb1f_row2_col6" class="data row2 col6" >58.25</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5fb1f_row3_col0" class="data row3 col0" >PTTGC</td>
#       <td id="T_5fb1f_row3_col1" class="data row3 col1" >2021-12-22</td>
#       <td id="T_5fb1f_row3_col2" class="data row3 col2" >57.75</td>
#       <td id="T_5fb1f_row3_col3" class="data row3 col3" >58.50</td>
#       <td id="T_5fb1f_row3_col4" class="data row3 col4" >57.50</td>
#       <td id="T_5fb1f_row3_col5" class="data row3 col5" >6,598,850</td>
#       <td id="T_5fb1f_row3_col6" class="data row3 col6" >58.25</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5fb1f_row4_col0" class="data row4 col0" >PTTGC</td>
#       <td id="T_5fb1f_row4_col1" class="data row4 col1" >2021-12-21</td>
#       <td id="T_5fb1f_row4_col2" class="data row4 col2" >57.75</td>
#       <td id="T_5fb1f_row4_col3" class="data row4 col3" >58.25</td>
#       <td id="T_5fb1f_row4_col4" class="data row4 col4" >57.50</td>
#       <td id="T_5fb1f_row4_col5" class="data row4 col5" >5,729,992</td>
#       <td id="T_5fb1f_row4_col6" class="data row4 col6" >58.00</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5fb1f_row5_col0" class="data row5 col0" >PTTGC</td>
#       <td id="T_5fb1f_row5_col1" class="data row5 col1" >2021-12-20</td>
#       <td id="T_5fb1f_row5_col2" class="data row5 col2" >57.50</td>
#       <td id="T_5fb1f_row5_col3" class="data row5 col3" >58.75</td>
#       <td id="T_5fb1f_row5_col4" class="data row5 col4" >57.25</td>
#       <td id="T_5fb1f_row5_col5" class="data row5 col5" >17,735,230</td>
#       <td id="T_5fb1f_row5_col6" class="data row5 col6" >58.50</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5fb1f_row6_col0" class="data row6 col0" >PTTGC</td>
#       <td id="T_5fb1f_row6_col1" class="data row6 col1" >2021-12-17</td>
#       <td id="T_5fb1f_row6_col2" class="data row6 col2" >59.00</td>
#       <td id="T_5fb1f_row6_col3" class="data row6 col3" >59.50</td>
#       <td id="T_5fb1f_row6_col4" class="data row6 col4" >58.50</td>
#       <td id="T_5fb1f_row6_col5" class="data row6 col5" >15,038,540</td>
#       <td id="T_5fb1f_row6_col6" class="data row6 col6" >58.75</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5fb1f_row7_col0" class="data row7 col0" >PTTGC</td>
#       <td id="T_5fb1f_row7_col1" class="data row7 col1" >2021-12-16</td>
#       <td id="T_5fb1f_row7_col2" class="data row7 col2" >59.00</td>
#       <td id="T_5fb1f_row7_col3" class="data row7 col3" >59.00</td>
#       <td id="T_5fb1f_row7_col4" class="data row7 col4" >57.75</td>
#       <td id="T_5fb1f_row7_col5" class="data row7 col5" >13,459,048</td>
#       <td id="T_5fb1f_row7_col6" class="data row7 col6" >58.50</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5fb1f_row8_col0" class="data row8 col0" >PTTGC</td>
#       <td id="T_5fb1f_row8_col1" class="data row8 col1" >2021-12-15</td>
#       <td id="T_5fb1f_row8_col2" class="data row8 col2" >58.00</td>
#       <td id="T_5fb1f_row8_col3" class="data row8 col3" >58.50</td>
#       <td id="T_5fb1f_row8_col4" class="data row8 col4" >57.75</td>
#       <td id="T_5fb1f_row8_col5" class="data row8 col5" >11,037,437</td>
#       <td id="T_5fb1f_row8_col6" class="data row8 col6" >58.25</td>
#     </tr>
#     <tr>
#       <th id="T_5fb1f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5fb1f_row9_col0" class="data row9 col0" >PTTGC</td>
#       <td id="T_5fb1f_row9_col1" class="data row9 col1" >2021-12-14</td>
#       <td id="T_5fb1f_row9_col2" class="data row9 col2" >58.25</td>
#       <td id="T_5fb1f_row9_col3" class="data row9 col3" >58.50</td>
#       <td id="T_5fb1f_row9_col4" class="data row9 col4" >56.75</td>
#       <td id="T_5fb1f_row9_col5" class="data row9 col5" >23,141,779</td>
#       <td id="T_5fb1f_row9_col6" class="data row9 col6" >58.25</td>
#     </tr>
#   </tbody>
# </table>

# %%
prices.minp.value_counts(normalize=True)
# Out:
# 57.75    0.3
# 58.00    0.2
# 57.50    0.2
# 57.25    0.1
# 58.50    0.1
# 56.75    0.1
# Name: minp, dtype: float64

# %%
prices.maxp.value_counts(normalize=True)
# Out:
# 58.75    0.4
# 58.50    0.3
# 58.25    0.1
# 59.50    0.1
# 59.00    0.1
# Name: maxp, dtype: float64
