# %% [markdown]
# #### port_lite: stocks
# #### portpg: stocks
# #### stock: setindex, price, buy
# #### output csv: 5-day_average, extreme

# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

format_dict = {
               'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
               'price_x':'{:,.2f}','to_price':'{:,.2f}','price_y':'{:,.2f}',
               'maxp':'{:,.2f}','max_price':'{:,.2f}',
               'minp':'{:,.2f}','price':'{:,.2f}','opnp':'{:,.2f}',    
               'inc_pct':'{:,.2f}','setindex':'{:,.2f}','prc_pct':'{:,.2f}',
               'qty':'{:,}','qty_x':'{:,}','qty_z':'{:,}'
              }
pd.set_option("display.max_rows", None)

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2021, 12, 27), datetime.date(2021, 12, 26))

# %%
#today = today - timedelta(days=1)
yesterday = today - timedelta(days=3)
today, yesterday
# Out:
# (datetime.date(2021, 12, 27), datetime.date(2021, 12, 24))

# %% [markdown]
# ### Restart and run all cells

# %%
sql = """
SELECT * 
FROM setindex 
WHERE date = '%s'
"""
sql = sql % today

setindex = pd.read_sql(sql, const)
setindex.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c8b35_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >setindex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8b35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8b35_row0_col0" class="data row0 col0" >2021-12-27</td>
#       <td id="T_c8b35_row0_col1" class="data row0 col1" >1,636.50</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT * 
FROM price 
WHERE date = '%s'
"""
sql = sql % today

prices = pd.read_sql(sql, const)
prices.shape
# Out:
# (354, 7)

# %%
sql = """
SELECT * 
FROM stocks
"""
stocks = pd.read_sql(sql, conpg)
stocks.shape
# Out:
# (356, 15)

# %%
df_merge = pd.merge(prices, stocks, on="name", how="inner")
df_merge.shape
# Out:
# (353, 21)

# %% [markdown]
# ### 52 Weeks High

# %%
cols = "name market price_x maxp max_price qty".split()

# %%
Yearly_High = (df_merge.maxp > df_merge.max_price) & (df_merge.qty > 100000)
df_merge[Yearly_High][cols].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_80c1a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >market</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >max_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80c1a_level0_row0" class="row_heading level0 row0" >347</th>
#       <td id="T_80c1a_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_80c1a_row0_col1" class="data row0 col1" >sSET / SETTHSI    </td>
#       <td id="T_80c1a_row0_col2" class="data row0 col2" >28.50</td>
#       <td id="T_80c1a_row0_col3" class="data row0 col3" >28.50</td>
#       <td id="T_80c1a_row0_col4" class="data row0 col4" >28.00</td>
#       <td id="T_80c1a_row0_col5" class="data row0 col5" >3,248,656</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row1" class="row_heading level0 row1" >334</th>
#       <td id="T_80c1a_row1_col0" class="data row1 col0" >AP</td>
#       <td id="T_80c1a_row1_col1" class="data row1 col1" >SET100 / SETHD    </td>
#       <td id="T_80c1a_row1_col2" class="data row1 col2" >9.70</td>
#       <td id="T_80c1a_row1_col3" class="data row1 col3" >9.80</td>
#       <td id="T_80c1a_row1_col4" class="data row1 col4" >9.70</td>
#       <td id="T_80c1a_row1_col5" class="data row1 col5" >25,569,970</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row2" class="row_heading level0 row2" >310</th>
#       <td id="T_80c1a_row2_col0" class="data row2 col0" >BEYOND</td>
#       <td id="T_80c1a_row2_col1" class="data row2 col1" >SET    </td>
#       <td id="T_80c1a_row2_col2" class="data row2 col2" >11.20</td>
#       <td id="T_80c1a_row2_col3" class="data row2 col3" >11.20</td>
#       <td id="T_80c1a_row2_col4" class="data row2 col4" >10.70</td>
#       <td id="T_80c1a_row2_col5" class="data row2 col5" >12,054,520</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row3" class="row_heading level0 row3" >303</th>
#       <td id="T_80c1a_row3_col0" class="data row3 col0" >BLA</td>
#       <td id="T_80c1a_row3_col1" class="data row3 col1" >SET    </td>
#       <td id="T_80c1a_row3_col2" class="data row3 col2" >36.50</td>
#       <td id="T_80c1a_row3_col3" class="data row3 col3" >36.75</td>
#       <td id="T_80c1a_row3_col4" class="data row3 col4" >36.50</td>
#       <td id="T_80c1a_row3_col5" class="data row3 col5" >1,912,696</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row4" class="row_heading level0 row4" >227</th>
#       <td id="T_80c1a_row4_col0" class="data row4 col0" >III</td>
#       <td id="T_80c1a_row4_col1" class="data row4 col1" >sSET    </td>
#       <td id="T_80c1a_row4_col2" class="data row4 col2" >15.50</td>
#       <td id="T_80c1a_row4_col3" class="data row4 col3" >15.90</td>
#       <td id="T_80c1a_row4_col4" class="data row4 col4" >15.60</td>
#       <td id="T_80c1a_row4_col5" class="data row4 col5" >26,362,533</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row5" class="row_heading level0 row5" >206</th>
#       <td id="T_80c1a_row5_col0" class="data row5 col0" >JWD</td>
#       <td id="T_80c1a_row5_col1" class="data row5 col1" >sSET / SETTHSI    </td>
#       <td id="T_80c1a_row5_col2" class="data row5 col2" >20.10</td>
#       <td id="T_80c1a_row5_col3" class="data row5 col3" >20.40</td>
#       <td id="T_80c1a_row5_col4" class="data row5 col4" >19.50</td>
#       <td id="T_80c1a_row5_col5" class="data row5 col5" >14,074,153</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row6" class="row_heading level0 row6" >120</th>
#       <td id="T_80c1a_row6_col0" class="data row6 col0" >SABUY</td>
#       <td id="T_80c1a_row6_col1" class="data row6 col1" >sSET    </td>
#       <td id="T_80c1a_row6_col2" class="data row6 col2" >22.80</td>
#       <td id="T_80c1a_row6_col3" class="data row6 col3" >22.80</td>
#       <td id="T_80c1a_row6_col4" class="data row6 col4" >21.70</td>
#       <td id="T_80c1a_row6_col5" class="data row6 col5" >31,677,048</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row7" class="row_heading level0 row7" >56</th>
#       <td id="T_80c1a_row7_col0" class="data row7 col0" >THG</td>
#       <td id="T_80c1a_row7_col1" class="data row7 col1" >SETCLMV / SETWB    </td>
#       <td id="T_80c1a_row7_col2" class="data row7 col2" >37.00</td>
#       <td id="T_80c1a_row7_col3" class="data row7 col3" >37.00</td>
#       <td id="T_80c1a_row7_col4" class="data row7 col4" >36.75</td>
#       <td id="T_80c1a_row7_col5" class="data row7 col5" >592,991</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row8" class="row_heading level0 row8" >39</th>
#       <td id="T_80c1a_row8_col0" class="data row8 col0" >TOG</td>
#       <td id="T_80c1a_row8_col1" class="data row8 col1" >SET    </td>
#       <td id="T_80c1a_row8_col2" class="data row8 col2" >10.50</td>
#       <td id="T_80c1a_row8_col3" class="data row8 col3" >11.30</td>
#       <td id="T_80c1a_row8_col4" class="data row8 col4" >11.00</td>
#       <td id="T_80c1a_row8_col5" class="data row8 col5" >6,766,351</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row9" class="row_heading level0 row9" >23</th>
#       <td id="T_80c1a_row9_col0" class="data row9 col0" >TVI</td>
#       <td id="T_80c1a_row9_col1" class="data row9 col1" >SET    </td>
#       <td id="T_80c1a_row9_col2" class="data row9 col2" >29.00</td>
#       <td id="T_80c1a_row9_col3" class="data row9 col3" >30.50</td>
#       <td id="T_80c1a_row9_col4" class="data row9 col4" >30.00</td>
#       <td id="T_80c1a_row9_col5" class="data row9 col5" >3,311,198</td>
#     </tr>
#     <tr>
#       <th id="T_80c1a_level0_row10" class="row_heading level0 row10" >5</th>
#       <td id="T_80c1a_row10_col0" class="data row10 col0" >WICE</td>
#       <td id="T_80c1a_row10_col1" class="data row10 col1" >sSET    </td>
#       <td id="T_80c1a_row10_col2" class="data row10 col2" >19.30</td>
#       <td id="T_80c1a_row10_col3" class="data row10 col3" >19.80</td>
#       <td id="T_80c1a_row10_col4" class="data row10 col4" >19.40</td>
#       <td id="T_80c1a_row10_col5" class="data row10 col5" >8,797,167</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks Low

# %%
colt = "name market price_x minp min_price qty".split()

# %%
Yearly_Low = (df_merge.minp < df_merge.min_price) & (df_merge.qty > 100000)
Final_Low = df_merge[Yearly_Low]
Final_Low[colt].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e54f0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >market</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >minp</th>
#       <th class="col_heading level0 col4" >min_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
set50 = Final_Low["market"].str.contains("SET50")
Final_Low[set50].sort_values(by=["name"],ascending=["True"])
# Out:
# Empty DataFrame
# Columns: [name, date, price_x, maxp, minp, qty, opnp, id, market, price_y, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at]
# Index: []
#
# [0 rows x 21 columns]

# %%
set100 = Final_Low["market"].str.contains("SET100")
Final_Low[set100].sort_values(by=["name"],ascending=["True"])
# Out:
# Empty DataFrame
# Columns: [name, date, price_x, maxp, minp, qty, opnp, id, market, price_y, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at]
# Index: []
#
# [0 rows x 21 columns]

# %%
sethd = Final_Low["market"].str.contains("SETHD")
Final_Low[sethd]
# Out:
# Empty DataFrame
# Columns: [name, date, price_x, maxp, minp, qty, opnp, id, market, price_y, max_price, min_price, pe, pbv, paid_up, market_cap, daily_volume, beta, ticker_id, created_at, updated_at]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Break 5-day Average Volume

# %%
sql = """
SELECT * 
FROM price 
WHERE date = '%s'
"""
sql = sql % today

today_vol = pd.read_sql(sql, const)
today_vol.shape
# Out:
# (354, 7)

# %%
from_date = yesterday - timedelta(days=4)
from_date
# Out:
# datetime.date(2021, 12, 18)

# %%
sql = """
SELECT * 
FROM price 
WHERE date BETWEEN '%s' AND '%s'
"""
sql = sql % (from_date, yesterday)

five_day_vol = pd.read_sql(sql, const)
five_day_vol.shape
# Out:
# (1053, 7)

# %%
five_day_mean = five_day_vol.groupby(by=["name"])[["qty","price"]].mean()
five_day_mean.reset_index(inplace=True)

df_merge2 = pd.merge(today_vol, five_day_mean, on=["name"], how="inner")
df_merge2["qty_z"] = df_merge2.qty_y.astype("int64")
df_merge2.shape
# Out:
# (354, 10)

# %%
break_five_day_mean = df_merge2[(df_merge2.qty_x > df_merge2.qty_z)]
break_five_day_mean.shape
# Out:
# (137, 10)

# %%
sql = """
SELECT * 
FROM buy 
WHERE active = 1
"""
buys = pd.read_sql(sql, const)
buys.shape
# Out:
# (34, 10)

# %%
df_merge3 = pd.merge(break_five_day_mean, buys, on=["name"], how="inner")
df_merge3["inc_pct"] = round((df_merge3.qty_x - df_merge3.qty_z) / abs(df_merge3.qty_z) * 100,2)
df_merge3["prc_pct"] = round((df_merge3.price_x - df_merge3.price_y) / abs(df_merge3.price_y) * 100,2)
df_merge3["name prc_pct price_x price_y inc_pct qty_x qty_z".split()].sort_values(["prc_pct"], ascending=False
).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_70e85_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >prc_pct</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >price_y</th>
#       <th class="col_heading level0 col4" >inc_pct</th>
#       <th class="col_heading level0 col5" >qty_x</th>
#       <th class="col_heading level0 col6" >qty_z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70e85_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_70e85_row0_col0" class="data row0 col0" >EPG</td>
#       <td id="T_70e85_row0_col1" class="data row0 col1" >2.44</td>
#       <td id="T_70e85_row0_col2" class="data row0 col2" >11.20</td>
#       <td id="T_70e85_row0_col3" class="data row0 col3" >10.93</td>
#       <td id="T_70e85_row0_col4" class="data row0 col4" >26.76</td>
#       <td id="T_70e85_row0_col5" class="data row0 col5" >12,806,806</td>
#       <td id="T_70e85_row0_col6" class="data row0 col6" >10,103,372</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_70e85_row1_col0" class="data row1 col0" >PTT</td>
#       <td id="T_70e85_row1_col1" class="data row1 col1" >2.01</td>
#       <td id="T_70e85_row1_col2" class="data row1 col2" >38.00</td>
#       <td id="T_70e85_row1_col3" class="data row1 col3" >37.25</td>
#       <td id="T_70e85_row1_col4" class="data row1 col4" >77.96</td>
#       <td id="T_70e85_row1_col5" class="data row1 col5" >41,669,911</td>
#       <td id="T_70e85_row1_col6" class="data row1 col6" >23,415,375</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_70e85_row2_col0" class="data row2 col0" >TISCO</td>
#       <td id="T_70e85_row2_col1" class="data row2 col1" >1.80</td>
#       <td id="T_70e85_row2_col2" class="data row2 col2" >94.50</td>
#       <td id="T_70e85_row2_col3" class="data row2 col3" >92.83</td>
#       <td id="T_70e85_row2_col4" class="data row2 col4" >24.40</td>
#       <td id="T_70e85_row2_col5" class="data row2 col5" >4,747,292</td>
#       <td id="T_70e85_row2_col6" class="data row2 col6" >3,816,051</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_70e85_row3_col0" class="data row3 col0" >NER</td>
#       <td id="T_70e85_row3_col1" class="data row3 col1" >1.66</td>
#       <td id="T_70e85_row3_col2" class="data row3 col2" >7.15</td>
#       <td id="T_70e85_row3_col3" class="data row3 col3" >7.03</td>
#       <td id="T_70e85_row3_col4" class="data row3 col4" >94.72</td>
#       <td id="T_70e85_row3_col5" class="data row3 col5" >19,387,683</td>
#       <td id="T_70e85_row3_col6" class="data row3 col6" >9,956,799</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_70e85_row4_col0" class="data row4 col0" >IVL</td>
#       <td id="T_70e85_row4_col1" class="data row4 col1" >0.58</td>
#       <td id="T_70e85_row4_col2" class="data row4 col2" >43.00</td>
#       <td id="T_70e85_row4_col3" class="data row4 col3" >42.75</td>
#       <td id="T_70e85_row4_col4" class="data row4 col4" >14.98</td>
#       <td id="T_70e85_row4_col5" class="data row4 col5" >16,612,677</td>
#       <td id="T_70e85_row4_col6" class="data row4 col6" >14,448,821</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_70e85_row5_col0" class="data row5 col0" >VNT</td>
#       <td id="T_70e85_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_70e85_row5_col2" class="data row5 col2" >38.50</td>
#       <td id="T_70e85_row5_col3" class="data row5 col3" >38.50</td>
#       <td id="T_70e85_row5_col4" class="data row5 col4" >339.51</td>
#       <td id="T_70e85_row5_col5" class="data row5 col5" >1,366,373</td>
#       <td id="T_70e85_row5_col6" class="data row5 col6" >310,883</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_70e85_row6_col0" class="data row6 col0" >NOBLE</td>
#       <td id="T_70e85_row6_col1" class="data row6 col1" >-0.27</td>
#       <td id="T_70e85_row6_col2" class="data row6 col2" >6.10</td>
#       <td id="T_70e85_row6_col3" class="data row6 col3" >6.12</td>
#       <td id="T_70e85_row6_col4" class="data row6 col4" >46.62</td>
#       <td id="T_70e85_row6_col5" class="data row6 col5" >2,758,970</td>
#       <td id="T_70e85_row6_col6" class="data row6 col6" >1,881,746</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_70e85_row7_col0" class="data row7 col0" >SIS</td>
#       <td id="T_70e85_row7_col1" class="data row7 col1" >-0.73</td>
#       <td id="T_70e85_row7_col2" class="data row7 col2" >45.25</td>
#       <td id="T_70e85_row7_col3" class="data row7 col3" >45.58</td>
#       <td id="T_70e85_row7_col4" class="data row7 col4" >0.43</td>
#       <td id="T_70e85_row7_col5" class="data row7 col5" >1,163,680</td>
#       <td id="T_70e85_row7_col6" class="data row7 col6" >1,158,706</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_70e85_row8_col0" class="data row8 col0" >HREIT</td>
#       <td id="T_70e85_row8_col1" class="data row8 col1" >-0.93</td>
#       <td id="T_70e85_row8_col2" class="data row8 col2" >8.90</td>
#       <td id="T_70e85_row8_col3" class="data row8 col3" >8.98</td>
#       <td id="T_70e85_row8_col4" class="data row8 col4" >30.91</td>
#       <td id="T_70e85_row8_col5" class="data row8 col5" >189,970</td>
#       <td id="T_70e85_row8_col6" class="data row8 col6" >145,117</td>
#     </tr>
#     <tr>
#       <th id="T_70e85_level0_row9" class="row_heading level0 row9" >3</th>
#       <td id="T_70e85_row9_col0" class="data row9 col0" >RJH</td>
#       <td id="T_70e85_row9_col1" class="data row9 col1" >-3.18</td>
#       <td id="T_70e85_row9_col2" class="data row9 col2" >33.00</td>
#       <td id="T_70e85_row9_col3" class="data row9 col3" >34.08</td>
#       <td id="T_70e85_row9_col4" class="data row9 col4" >396.01</td>
#       <td id="T_70e85_row9_col5" class="data row9 col5" >2,265,754</td>
#       <td id="T_70e85_row9_col6" class="data row9 col6" >456,798</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = '5-day-average.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
data_file, output_file, box_file
# Out:
# ('../data/5-day-average.csv',
#  '\\Users\\User\\iCloudDrive\\5-day-average.csv',
#  '\\Users\\User\\Dropbox\\5-day-average.csv')

# %%
colu = "name prc_pct price_x price_y inc_pct qty_x qty_z".split()

# %%
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(data_file)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(output_file)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(box_file)

# %% [markdown]
# ### Extreme price discrepancy

# %%
sql = '''
SELECT name, status
FROM stocks'''
stocks = pd.read_sql(sql, conlite)
stocks.shape[0]
# Out:
# 50

# %%
sr = stocks["name"]
sr.shape
# Out:
# (50,)

# %%
names = sr.values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'MCS', 'PTTGC', 'IVL', 'JASIF', 'LH', 'DIF', 'ROJNA', 'NOBLE', 'TU', 'DCC', 'HREIT', 'MEGA', 'JMT', 'GULF', 'TISCO', 'SIS', 'TQM', 'STA', 'RATCH', 'SCC', 'NER', 'SYNEX', 'BCH', 'DOHOME', 'PTT', 'RJH', 'SINGER', 'KCE', 'EPG', 'SAT', 'KBANK', 'VNT', 'BGRIM', 'TMT', 'STARK', 'RCL', 'TYCN', 'IP', 'BLA', 'CKP', 'SPALI', 'SVI', 'TOP', 'TSE', 'GLOBAL', 'PTL', 'TSTH', 'ASK', 'IMH', 'TKS'"

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (today, in_p)
tdy_prices = pd.read_sql(sql, const)
tdy_prices.shape[0]
# Out:
# 50

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (yesterday, in_p)
print(sql)
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2021-12-22' AND name IN ('MCS', 'PTTGC', 'IVL', 'JASIF', 'LH', 'DIF', 'ROJNA', 'NOBLE', 'TU', 'DCC', 'HREIT', 'MEGA', 'JMT', 'GULF', 'TISCO', 'SIS', 'TQM', 'STA', 'RATCH', 'SCC', 'NER', 'SYNEX', 'BCH', 'DOHOME', 'PTT', 'RJH', 'SINGER', 'KCE', 'EPG', 'SAT', 'KBANK', 'VNT', 'BGRIM', 'TMT', 'STARK', 'RCL', 'TYCN', 'IP', 'BLA', 'CKP', 'SPALI', 'SVI', 'TOP', 'TSE', 'GLOBAL', 'PTL', 'TSTH', 'ASK', 'IMH', 'TKS')
# ORDER BY name

# %%
ytd_prices = pd.read_sql(sql, const)
ytd_prices.shape[0]
# Out:
# 50

# %%
compare1 = pd.merge(tdy_prices,ytd_prices,on='name',how='inner')
compare1
# Out:
#       name  price_x  price_y
# 0      ASK    44.50    46.00
# 1      BCH    19.90    20.10
# 2    BGRIM    40.00    40.25
# 3      BLA    36.25    35.00
# 4      CKP     5.00     5.00
# 5      DCC     2.86     2.88
# 6      DIF    13.90    14.00
# 7   DOHOME    23.80    23.90
# 8      EPG    11.20    11.20
# 9   GLOBAL    20.00    20.20
# 10    GULF    44.00    43.50
# 11   HREIT     8.90     8.95
# 12     IMH    11.60    11.60
# 13      IP    19.70    19.60
# 14     IVL    43.00    42.75
# 15   JASIF    10.30    10.30
# 16     JMT    67.75    67.00
# 17   KBANK   138.50   137.00
# 18     KCE    90.00    89.50
# 19      LH     8.65     8.55
# 20     MCS    14.60    14.50
# 21    MEGA    51.75    51.75
# 22     NER     7.15     7.15
# 23   NOBLE     6.10     6.15
# 24     PTL    24.20    24.20
# 25     PTT    38.00    37.50
# 26   PTTGC    58.25    57.75
# 27   RATCH    44.75    44.25
# 28     RCL    48.00    48.00
# 29     RJH    33.00    33.75
# 30   ROJNA     6.60     6.55
# 31     SAT    21.60    21.40
# 32     SCC   380.00   378.00
# 33  SINGER    52.50    51.75
# 34     SIS    45.25    46.50
# 35   SPALI    22.30    21.70
# 36     STA    30.50    30.25
# 37   STARK     4.80     4.88
# 38     SVI     7.55     7.70
# 39   SYNEX    34.00    34.50
# 40   TISCO    94.50    93.50
# 41     TKS    15.70    16.60
# 42     TMT    10.40    10.40
# 43     TOP    48.75    47.50
# 44     TQM   101.50   102.50
# 45     TSE     2.66     2.64
# 46    TSTH     1.48     1.47
# 47      TU    19.40    19.50
# 48    TYCN     3.60     3.62
# 49     VNT    38.50    38.50

# %%
compare2 = pd.merge(compare1,stocks,on='name',how='inner')
compare2
# Out:
#       name  price_x  price_y status
# 0      ASK    44.50    46.00      X
# 1      BCH    19.90    20.10      U
# 2    BGRIM    40.00    40.25      B
# 3      BLA    36.25    35.00      X
# 4      CKP     5.00     5.00      I
# 5      DCC     2.86     2.88      I
# 6      DIF    13.90    14.00      I
# 7   DOHOME    23.80    23.90      B
# 8      EPG    11.20    11.20      I
# 9   GLOBAL    20.00    20.20      B
# 10    GULF    44.00    43.50      X
# 11   HREIT     8.90     8.95      T
# 12     IMH    11.60    11.60      B
# 13      IP    19.70    19.60      I
# 14     IVL    43.00    42.75      I
# 15   JASIF    10.30    10.30      T
# 16     JMT    67.75    67.00      X
# 17   KBANK   138.50   137.00      B
# 18     KCE    90.00    89.50      I
# 19      LH     8.65     8.55      X
# 20     MCS    14.60    14.50      U
# 21    MEGA    51.75    51.75      X
# 22     NER     7.15     7.15      I
# 23   NOBLE     6.10     6.15      B
# 24     PTL    24.20    24.20      X
# 25     PTT    38.00    37.50      B
# 26   PTTGC    58.25    57.75      U
# 27   RATCH    44.75    44.25      B
# 28     RCL    48.00    48.00      I
# 29     RJH    33.00    33.75      U
# 30   ROJNA     6.60     6.55      O
# 31     SAT    21.60    21.40      I
# 32     SCC   380.00   378.00      U
# 33  SINGER    52.50    51.75      X
# 34     SIS    45.25    46.50      B
# 35   SPALI    22.30    21.70      X
# 36     STA    30.50    30.25      B
# 37   STARK     4.80     4.88      X
# 38     SVI     7.55     7.70      X
# 39   SYNEX    34.00    34.50      O
# 40   TISCO    94.50    93.50      T
# 41     TKS    15.70    16.60      X
# 42     TMT    10.40    10.40      T
# 43     TOP    48.75    47.50      B
# 44     TQM   101.50   102.50      X
# 45     TSE     2.66     2.64      X
# 46    TSTH     1.48     1.47      I
# 47      TU    19.40    19.50      I
# 48    TYCN     3.60     3.62      I
# 49     VNT    38.50    38.50      I

# %%
colt = 'name pct price_x price_y status diff'.split()
compare2['diff'] = round((compare2.price_x - compare2.price_y)*1,2)
compare2['pct'] = round(compare2['diff'] / compare2['price_y'] * 100,2)
#compare2.set_index('name',inplace=True)
compare2[colt].sort_values(['pct'],ascending=[False])
# Out:
#       name   pct  price_x  price_y status  diff
# 3      BLA  3.57    36.25    35.00      X  1.25
# 35   SPALI  2.76    22.30    21.70      X  0.60
# 43     TOP  2.63    48.75    47.50      B  1.25
# 33  SINGER  1.45    52.50    51.75      X  0.75
# 25     PTT  1.33    38.00    37.50      B  0.50
# 19      LH  1.17     8.65     8.55      X  0.10
# 10    GULF  1.15    44.00    43.50      X  0.50
# 27   RATCH  1.13    44.75    44.25      B  0.50
# 16     JMT  1.12    67.75    67.00      X  0.75
# 17   KBANK  1.09   138.50   137.00      B  1.50
# 40   TISCO  1.07    94.50    93.50      T  1.00
# 31     SAT  0.93    21.60    21.40      I  0.20
# 26   PTTGC  0.87    58.25    57.75      U  0.50
# 36     STA  0.83    30.50    30.25      B  0.25
# 45     TSE  0.76     2.66     2.64      X  0.02
# 30   ROJNA  0.76     6.60     6.55      O  0.05
# 20     MCS  0.69    14.60    14.50      U  0.10
# 46    TSTH  0.68     1.48     1.47      I  0.01
# 14     IVL  0.58    43.00    42.75      I  0.25
# 18     KCE  0.56    90.00    89.50      I  0.50
# 32     SCC  0.53   380.00   378.00      U  2.00
# 13      IP  0.51    19.70    19.60      I  0.10
# 42     TMT  0.00    10.40    10.40      T  0.00
# 28     RCL  0.00    48.00    48.00      I  0.00
# 49     VNT  0.00    38.50    38.50      I  0.00
# 24     PTL  0.00    24.20    24.20      X  0.00
# 4      CKP  0.00     5.00     5.00      I  0.00
# 22     NER  0.00     7.15     7.15      I  0.00
# 21    MEGA  0.00    51.75    51.75      X  0.00
# 15   JASIF  0.00    10.30    10.30      T  0.00
# 12     IMH  0.00    11.60    11.60      B  0.00
# 8      EPG  0.00    11.20    11.20      I  0.00
# 7   DOHOME -0.42    23.80    23.90      B -0.10
# 47      TU -0.51    19.40    19.50      I -0.10
# 48    TYCN -0.55     3.60     3.62      I -0.02
# 11   HREIT -0.56     8.90     8.95      T -0.05
# 2    BGRIM -0.62    40.00    40.25      B -0.25
# 5      DCC -0.69     2.86     2.88      I -0.02
# 6      DIF -0.71    13.90    14.00      I -0.10
# 23   NOBLE -0.81     6.10     6.15      B -0.05
# 44     TQM -0.98   101.50   102.50      X -1.00
# 9   GLOBAL -0.99    20.00    20.20      B -0.20
# 1      BCH -1.00    19.90    20.10      U -0.20
# 39   SYNEX -1.45    34.00    34.50      O -0.50
# 37   STARK -1.64     4.80     4.88      X -0.08
# 38     SVI -1.95     7.55     7.70      X -0.15
# 29     RJH -2.22    33.00    33.75      U -0.75
# 34     SIS -2.69    45.25    46.50      B -1.25
# 0      ASK -3.26    44.50    46.00      X -1.50
# 41     TKS -5.42    15.70    16.60      X -0.90

# %%
criteria = 3
mask = abs(compare2.pct) >= criteria
extremes = compare2[mask].sort_values(['status','pct'],ascending=[True,False])
extremes[colt].sort_values(['status','name'],ascending=[True,True])
# Out:
#    name   pct  price_x  price_y status  diff
# 0   ASK -3.26    44.50     46.0      X -1.50
# 3   BLA  3.57    36.25     35.0      X  1.25
# 41  TKS -5.42    15.70     16.6      X -0.90

# %%
file_name = 'extremes.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
data_file, output_file, box_file
# Out:
# ('../data/extremes.csv',
#  '\\Users\\User\\iCloudDrive\\extremes.csv',
#  '\\Users\\User\\Dropbox\\extremes.csv')

# %%
extremes[colt].sort_values(['status','name'],ascending=[True,True]).to_csv(data_file)
extremes[colt].sort_values(['status','name'],ascending=[True,True]).to_csv(output_file)
extremes[colt].sort_values(['status','name'],ascending=[True,True]).to_csv(box_file)

# %% [markdown]
# ### One week modal values

# %%
#eow = date(2021, 8, 13)
eow = today
bow = eow - timedelta(days=14)
bow, eow
# Out:
# (datetime.date(2021, 12, 9), datetime.date(2021, 12, 23))

# %%
name = 'MCS'
sql = """
SELECT * 
FROM price 
WHERE date BETWEEN '%s' AND '%s' AND name = '%s' 
ORDER BY date DESC"""
sql = sql % (bow, eow, name)
prices = pd.read_sql(sql, const)
prices.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_22ac6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22ac6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22ac6_row0_col0" class="data row0 col0" >MCS</td>
#       <td id="T_22ac6_row0_col1" class="data row0 col1" >2021-12-23</td>
#       <td id="T_22ac6_row0_col2" class="data row0 col2" >14.60</td>
#       <td id="T_22ac6_row0_col3" class="data row0 col3" >14.60</td>
#       <td id="T_22ac6_row0_col4" class="data row0 col4" >14.50</td>
#       <td id="T_22ac6_row0_col5" class="data row0 col5" >613,259</td>
#       <td id="T_22ac6_row0_col6" class="data row0 col6" >14.60</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22ac6_row1_col0" class="data row1 col0" >MCS</td>
#       <td id="T_22ac6_row1_col1" class="data row1 col1" >2021-12-22</td>
#       <td id="T_22ac6_row1_col2" class="data row1 col2" >14.50</td>
#       <td id="T_22ac6_row1_col3" class="data row1 col3" >14.60</td>
#       <td id="T_22ac6_row1_col4" class="data row1 col4" >14.40</td>
#       <td id="T_22ac6_row1_col5" class="data row1 col5" >1,366,677</td>
#       <td id="T_22ac6_row1_col6" class="data row1 col6" >14.50</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22ac6_row2_col0" class="data row2 col0" >MCS</td>
#       <td id="T_22ac6_row2_col1" class="data row2 col1" >2021-12-21</td>
#       <td id="T_22ac6_row2_col2" class="data row2 col2" >14.50</td>
#       <td id="T_22ac6_row2_col3" class="data row2 col3" >14.60</td>
#       <td id="T_22ac6_row2_col4" class="data row2 col4" >14.50</td>
#       <td id="T_22ac6_row2_col5" class="data row2 col5" >1,348,152</td>
#       <td id="T_22ac6_row2_col6" class="data row2 col6" >14.60</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_22ac6_row3_col0" class="data row3 col0" >MCS</td>
#       <td id="T_22ac6_row3_col1" class="data row3 col1" >2021-12-20</td>
#       <td id="T_22ac6_row3_col2" class="data row3 col2" >14.50</td>
#       <td id="T_22ac6_row3_col3" class="data row3 col3" >14.80</td>
#       <td id="T_22ac6_row3_col4" class="data row3 col4" >14.50</td>
#       <td id="T_22ac6_row3_col5" class="data row3 col5" >2,632,025</td>
#       <td id="T_22ac6_row3_col6" class="data row3 col6" >14.70</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_22ac6_row4_col0" class="data row4 col0" >MCS</td>
#       <td id="T_22ac6_row4_col1" class="data row4 col1" >2021-12-17</td>
#       <td id="T_22ac6_row4_col2" class="data row4 col2" >14.70</td>
#       <td id="T_22ac6_row4_col3" class="data row4 col3" >14.80</td>
#       <td id="T_22ac6_row4_col4" class="data row4 col4" >14.40</td>
#       <td id="T_22ac6_row4_col5" class="data row4 col5" >7,291,753</td>
#       <td id="T_22ac6_row4_col6" class="data row4 col6" >14.50</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_22ac6_row5_col0" class="data row5 col0" >MCS</td>
#       <td id="T_22ac6_row5_col1" class="data row5 col1" >2021-12-16</td>
#       <td id="T_22ac6_row5_col2" class="data row5 col2" >14.40</td>
#       <td id="T_22ac6_row5_col3" class="data row5 col3" >14.50</td>
#       <td id="T_22ac6_row5_col4" class="data row5 col4" >14.40</td>
#       <td id="T_22ac6_row5_col5" class="data row5 col5" >1,328,697</td>
#       <td id="T_22ac6_row5_col6" class="data row5 col6" >14.50</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_22ac6_row6_col0" class="data row6 col0" >MCS</td>
#       <td id="T_22ac6_row6_col1" class="data row6 col1" >2021-12-15</td>
#       <td id="T_22ac6_row6_col2" class="data row6 col2" >14.50</td>
#       <td id="T_22ac6_row6_col3" class="data row6 col3" >14.50</td>
#       <td id="T_22ac6_row6_col4" class="data row6 col4" >14.30</td>
#       <td id="T_22ac6_row6_col5" class="data row6 col5" >1,207,063</td>
#       <td id="T_22ac6_row6_col6" class="data row6 col6" >14.40</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_22ac6_row7_col0" class="data row7 col0" >MCS</td>
#       <td id="T_22ac6_row7_col1" class="data row7 col1" >2021-12-14</td>
#       <td id="T_22ac6_row7_col2" class="data row7 col2" >14.40</td>
#       <td id="T_22ac6_row7_col3" class="data row7 col3" >14.50</td>
#       <td id="T_22ac6_row7_col4" class="data row7 col4" >14.40</td>
#       <td id="T_22ac6_row7_col5" class="data row7 col5" >950,413</td>
#       <td id="T_22ac6_row7_col6" class="data row7 col6" >14.50</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_22ac6_row8_col0" class="data row8 col0" >MCS</td>
#       <td id="T_22ac6_row8_col1" class="data row8 col1" >2021-12-13</td>
#       <td id="T_22ac6_row8_col2" class="data row8 col2" >14.40</td>
#       <td id="T_22ac6_row8_col3" class="data row8 col3" >14.60</td>
#       <td id="T_22ac6_row8_col4" class="data row8 col4" >14.40</td>
#       <td id="T_22ac6_row8_col5" class="data row8 col5" >3,059,063</td>
#       <td id="T_22ac6_row8_col6" class="data row8 col6" >14.50</td>
#     </tr>
#     <tr>
#       <th id="T_22ac6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_22ac6_row9_col0" class="data row9 col0" >MCS</td>
#       <td id="T_22ac6_row9_col1" class="data row9 col1" >2021-12-09</td>
#       <td id="T_22ac6_row9_col2" class="data row9 col2" >14.50</td>
#       <td id="T_22ac6_row9_col3" class="data row9 col3" >14.60</td>
#       <td id="T_22ac6_row9_col4" class="data row9 col4" >14.40</td>
#       <td id="T_22ac6_row9_col5" class="data row9 col5" >1,043,949</td>
#       <td id="T_22ac6_row9_col6" class="data row9 col6" >14.50</td>
#     </tr>
#   </tbody>
# </table>

# %%
prices.minp.value_counts()
# Out:
# 14.4    6
# 14.5    3
# 14.3    1
# Name: minp, dtype: int64

# %%
prices.maxp.value_counts()
# Out:
# 14.6    5
# 14.5    3
# 14.8    2
# Name: maxp, dtype: int64
