# %% [markdown]
# #### SQLite port_lite database: sales, stocks table
# #### csv files: daily-watch-list, daily-sales, monitors, stocks-all

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

today = date.today()
today
# Out:
# datetime.date(2022, 5, 20)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])

# %%
mask = (df_dailies['daily_volume'] == '-')
df_dailies[mask]
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] * 1000 / 1000000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price            object
# daily_volume      int32
# chg_amt          object
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10)
# Out:
#        name  price  daily_volume chg_amt  chg_pct
# 93       IP  20.60           113   +1.80     9.57
# 183   STARK   4.72           439   +0.40     9.26
# 215     TTA  10.70           423   +0.70     7.00
# 70    FORTH  46.75           194   +2.75     6.25
# 20    BANPU  12.20          1311   +0.50     4.27
# 210     TQM  43.75           126   +1.75     4.17
# 45       CK  20.60           216   +0.80     4.04
# 71   FSMART  21.30           273   +0.80     3.90
# 143     PSL  21.40           303   +0.80     3.88
# 51      CPN  62.25           342   +2.00     3.32

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10)
# Out:
#        name   price  daily_volume chg_amt  chg_pct
# 108     KYE  355.00             7   -9.00    -2.47
# 214    TSTH    1.30            10   -0.03    -2.26
# 179  SPRIME    6.85             0   -0.15    -2.14
# 87      ILM   18.20            24   -0.30    -1.62
# 64    EASTW    6.70            10   -0.10    -1.47
# 82      HFT    6.70             5   -0.10    -1.47
# 35      BJC   36.25           148   -0.50    -1.36
# 99      JWD   15.00            20   -0.20    -1.32
# 150   RATCH   40.00            99   -0.50    -1.23
# 73     GFPT   16.20            54   -0.20    -1.22

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10)
# Out:
#        name   price  daily_volume chg_amt  chg_pct
# 27     BDMS   27.00          2028   +0.25     0.93
# 11      AOT   69.00          1384   +1.00     1.47
# 49    CPALL   65.00          1364   +1.00     1.56
# 20    BANPU   12.20          1311   +0.50     4.27
# 161     SCB  110.00          1166   +2.00     1.85
# 100   KBANK  144.00           729   +2.00     1.41
# 147   PTTEP  156.50           641   +1.00     0.64
# 1    ADVANC  218.00           601   +1.00     0.46
# 146     PTT   37.00           580   +0.75     2.07
# 98      JMT   73.75           575   +2.25     3.15
