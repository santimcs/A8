# %% [markdown]
# #### SQLite port_lite database: sales, stocks table
# #### csv files: daily-watch-list, daily-sales, monitors, stocks-all

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

today = date.today()
today
# Out:
# datetime.date(2022, 5, 19)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])

# %%
mask = (df_dailies['daily_volume'] == '-')
df_dailies[mask]
# Out:
# Empty DataFrame
# Columns: [name, price, daily_volume, chg_amt, chg_pct]
# Index: []

# %%
df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] * 1000 / 1000000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10)
# Out:
#        name  price  daily_volume  chg_amt  chg_pct
# 90    INGRS   0.67            14     0.06     9.84
# 189   TASCO  17.00           407     1.00     6.25
# 154   ROJNA   6.20            14     0.35     5.98
# 184    STGT  18.90           533     0.90     5.00
# 79   GUNKUL   5.35           384     0.25     4.90
# 6       AIT   6.95           104     0.30     4.51
# 121   MAKRO  35.75           486     1.50     4.38
# 30      BEM   8.80          1206     0.35     4.14
# 117     LPN   4.56            16     0.18     4.11
# 230    WORK  23.20           109     0.90     4.04

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10)
# Out:
#        name   price  daily_volume  chg_amt  chg_pct
# 205     TOA   26.75            43    -1.25    -4.46
# 43   CENTEL   40.25           391    -1.25    -3.01
# 44      CHG    3.42           249    -0.10    -2.84
# 172    SMPC   15.10            24    -0.40    -2.58
# 188   SYNEX   21.80           116    -0.50    -2.24
# 204     TMW   34.25             0    -0.75    -2.14
# 136   PCSGH    5.00             0    -0.10    -1.96
# 18       BA   10.70            36    -0.20    -1.83
# 8    ALUCON  190.00             1    -3.50    -1.81
# 165      SF    8.40             1    -0.15    -1.75

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10)
# Out:
#        name   price  daily_volume  chg_amt  chg_pct
# 147   PTTEP  158.50          3761     1.00     0.63
# 100   KBANK  144.00          2931    -0.50    -0.35
# 27     BDMS   26.75          2766     0.00     0.00
# 11      AOT   68.00          2452     0.50     0.74
# 146     PTT   36.75          1959    -0.25    -0.68
# 1    ADVANC  219.00          1397     1.00     0.46
# 49    CPALL   64.25          1381     0.25     0.39
# 22      BBL  126.00          1321     0.50     0.40
# 98      JMT   75.00          1320    -1.00    -1.32
# 20    BANPU   11.90          1316     0.00     0.00
