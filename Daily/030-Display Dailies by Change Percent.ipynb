# %% [markdown]
# #### SQLite port_lite database: sales, stocks table
# #### csv files: daily-watch-list, daily-sales, monitors, stocks-all

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

today = date.today()
today
# Out:
# datetime.date(2022, 5, 24)

# %%
df_dailies = pd.read_csv('../data/dailies.csv',usecols=['name','price','chg_amt','chg_pct','daily_volume'])

# %%
df_dailies.select_dtypes(include='object')
# Out:
#        name
# 0       ACE
# 1    ADVANC
# 2    AEONTS
# 3        AH
# 4       AIE
# ..      ...
# 226     WHA
# 227   WHART
# 228   WHAUP
# 229    WICE
# 230    WORK
#
# [231 rows x 1 columns]

# %%
#mask = (df_dailies['daily_volume'] == '-')
#df_dailies[mask]

# %%
#df_dailies.loc[(df_dailies.daily_volume == '-') ,'daily_volume'] = 0

df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(float)
df_dailies['daily_volume'] = round(df_dailies['daily_volume'] / 1000,0)
df_dailies['daily_volume'] = df_dailies['daily_volume'].astype(int)
df_dailies.dtypes
# Out:
# name             object
# price           float64
# daily_volume      int32
# chg_amt         float64
# chg_pct         float64
# dtype: object

# %%
df_dailies.sort_values(['chg_pct'],ascending=[False]).head(10)
# Out:
#        name  price  daily_volume  chg_amt  chg_pct
# 99      JWD  16.10           129     1.20     8.05
# 185    STGT  21.20           380     1.20     6.00
# 165    SENA   4.22            56     0.22     5.50
# 88      IMH  18.20            19     0.80     4.60
# 73     GFPT  16.50           137     0.60     3.77
# 153     RJH  35.50            63     1.25     3.65
# 229    WICE  16.40            61     0.50     3.14
# 168  SINGER  51.50           136     1.50     3.00
# 200      TK  10.90             3     0.30     2.83
# 79   GUNKUL   5.50           378     0.15     2.80

# %%
df_dailies.sort_values(['chg_pct'],ascending=[True]).head(10)
# Out:
#          name   price  daily_volume  chg_amt  chg_pct
# 166        SF    7.20             0    -0.30    -4.00
# 44        CHG    3.52           114    -0.08    -2.22
# 35        BJC   35.75            78    -0.75    -2.05
# 9       AMATA   19.40            57    -0.40    -2.02
# 77     GRAMMY   10.20             0    -0.20    -1.92
# 143       PSL   20.60            87    -0.40    -1.90
# 161       SCB  113.00           942    -2.00    -1.74
# 187  SUPEREIF   11.90             9    -0.20    -1.65
# 51        CPN   62.00            45    -1.00    -1.59
# 49      CPALL   64.25           862    -1.00    -1.53

# %%
df_dailies.sort_values(['daily_volume'],ascending=[False]).head(10)
# Out:
#        name   price  daily_volume  chg_amt  chg_pct
# 11      AOT   69.00          1352    -0.50    -0.72
# 146     PTT   37.25          1225    -0.25    -0.67
# 1    ADVANC  224.00          1172     4.00     1.82
# 161     SCB  113.00           942    -2.00    -1.74
# 49    CPALL   64.25           862    -1.00    -1.53
# 147   PTTEP  156.50           731    -0.50    -0.32
# 27     BDMS   26.75           717    -0.25    -0.93
# 100   KBANK  146.50           643     1.00     0.69
# 42      CBG  110.00           577     1.50     1.38
# 76     GPSC   64.50           567     1.50     2.38
