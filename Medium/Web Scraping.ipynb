# %%
import pandas as pd
pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')
# Out:
#     Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1    E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2    E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3    E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4    E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
# ..   ..         ...    ...         ...             ...   ...   ...  ..   ...
# 252  E0  26/02/2022  15:00  Man United         Watford     0     0   D     0
# 253  E0  26/02/2022  15:30    Brighton     Aston Villa     0     2   A     0
# 254  E0  26/02/2022  17:30     Everton        Man City     0     1   A     0
# 255  E0  27/02/2022  14:00    West Ham          Wolves     1     0   H     0
# 256  E0  01/03/2022  19:45     Burnley       Leicester     0     2   A     0
#
# ...

# %%
root = 'https://www.football-data.co.uk/mmz4281/'
# creating list of leagues
leagues = ['E0', 'E1']
# looping through leagues, reading multiple csv and appending it into a list
frames = []
for league in leagues:
    df = pd.read_csv(root + "2122" + "/"  + league + ".csv")
    frames.append(df)

# %%
l0 = frames[0]
l0
# Out:
#     Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1    E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2    E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3    E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4    E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
# ..   ..         ...    ...         ...             ...   ...   ...  ..   ...
# 252  E0  26/02/2022  15:00  Man United         Watford     0     0   D     0
# 253  E0  26/02/2022  15:30    Brighton     Aston Villa     0     2   A     0
# 254  E0  26/02/2022  17:30     Everton        Man City     0     1   A     0
# 255  E0  27/02/2022  14:00    West Ham          Wolves     1     0   H     0
# 256  E0  01/03/2022  19:45     Burnley       Leicester     0     2   A     0
#
# ...

# %%
l1 = frames[1]
l1
# Out:
#     Div        Date   Time       HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0    E1  06/08/2021  19:45    Bournemouth         West Brom     2     2   D
# 1    E1  07/08/2021  15:00      Blackburn           Swansea     2     1   H
# 2    E1  07/08/2021  15:00   Bristol City         Blackpool     1     1   D
# 3    E1  07/08/2021  15:00        Cardiff          Barnsley     1     1   D
# 4    E1  07/08/2021  15:00          Derby      Huddersfield     1     1   D
# ..   ..         ...    ...            ...               ...   ...   ...  ..
# 399  E1  26/02/2022  15:00       Millwall  Sheffield United     1     0   H
# 400  E1  26/02/2022  15:00  Nott'm Forest      Bristol City     2     0   H
# 401  E1  26/02/2022  15:00      Peterboro              Hull     0     3   A
# 402  E1  28/02/2022  20:00      West Brom           Swansea     0     2   A
# 403  E1  01/03/2022  19:45        Cardiff             Derby     1     0   H
#
# ...

# %%
df = l0.append(l1, ignore_index=True)
df.shape
# Out:
# (661, 106)

# %%
df.dtypes
# Out:
# Div          object
# Date         object
# Time         object
# HomeTeam     object
# AwayTeam     object
#              ...
# PCAHA       float64
# MaxCAHH     float64
# MaxCAHA     float64
# AvgCAHH     float64
# AvgCAHA     float64
# Length: 106, dtype: object

# %%
simpsons = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

# %%
# getting the first 5 rows of the table "Season 1"
simpsons[1].head()
# Out:
#    No.overall  No. inseason                                Title  \
# 0           1             1  "Simpsons Roasting on an Open Fire"
# 1           2             2                    "Bart the Genius"
# 2           3             3                    "Homer's Odyssey"
# 3           4             4      "There's No Disgrace Like Home"
# 4           5             5                   "Bart the General"
#
#                       Directed by                      Written by  \
# 0                 David Silverman                       Mimi Pond
# 1                 David Silverman                       Jon Vitti
# 2                   Wesley Archer  Jay Kogen & Wallace Wolodarsky
# 3  Gregg Vanzo & Kent Butterworth            Al Jean & Mike Reiss
# 4                 David Silverman               John Swartzwelder
#
#    Original air date Prod.code U.S. viewers(millions)
# 0  December 17, 1989      7G08               26.7[46]
# 1   January 14, 1990      7G02               24.5[46]
# ...
